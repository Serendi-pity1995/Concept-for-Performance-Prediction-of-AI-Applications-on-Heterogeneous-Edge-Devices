# %%
import numpy as np
import os
import keras
from keras import backend as K
import numpy
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Input, BatchNormalization
from tensorflow_model_optimization.quantization.keras import vitis_quantize
from keras.models import Model
import tensorflow as tf



shape_range =range(224,512,32)
for shape_x in shape_range:
    shape_y = shape_x
    X_train=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
    Y_train=np.random.randint(0,10,size=[60,])
    X_test=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
    Y_test=np.random.randint(0,10,size=[60,])
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
    X_train /= 255.0
    X_test /= 255.0
    
    inputs = Input(shape=(shape_x, shape_y, 1))

    conv1 = Conv2D(96, (11, 11), strides=(4, 4), activation='relu')(inputs)
    pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(conv1)
    Norm1 = BatchNormalization()(pool1)

    conv2 = Conv2D(256, kernel_size=(5, 5), activation='relu')(Norm1)
    pool2 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(conv2)
    Norm2 = BatchNormalization()(pool2)

    conv3 = Conv2D(384, kernel_size=(3, 3), activation='relu')(Norm2)
    conv4 = Conv2D(384, kernel_size=(3, 3), activation='relu')(conv3)
    conv5 = Conv2D(256, kernel_size=(3, 3), activation='relu')(conv4)
    pool3 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(conv5)
    Norm3 = BatchNormalization()(pool3)

    flat = Flatten()(Norm3)
    fc1 = Dense(4086, activation='relu')(flat)
    drop1 = Dropout(0.5)(fc1)
    fc2 = Dense(4086, activation='relu')(drop1)
    drop2 = Dropout(0.5)(fc2)

    outputs = Dense(10, activation='softmax')(drop2)

    model = Model(inputs=inputs, outputs=outputs)
    model.summary()

#     model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#     history = model.fit(X_train, Y_train, epochs=1)
#     model.get_weights()[0].dtype
    quantizer = vitis_quantize.VitisQuantizer(model)
    quantized_model = quantizer.quantize_model(calib_dataset = X_test[1:10], weight_bit=8, activation_bit=8)
#     quantized_model.compile(loss='sparse_categorical_crossentropy', metrics=["accuracy"])
    quantized_model.save('quantized.h5')
    # !vai_c_tensorflow2 \
    --model ./quantized.h5 \
    --arch ./arch.json \
    --output_dir ./xmodel_AlexNet \
    --net_name deploy
    os.rename("./xmodel_AlexNet/deploy.xmodel","./xmodel_AlexNet/AlexNet_{shape_x}_{shape_y}.xmodel".format(shape_x=shape_x,shape_y=shape_y))
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 224, 224, 1)]     0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 54, 54, 96)        11712
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 26, 26, 96)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 26, 26, 96)        384
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 22, 22, 256)       614656
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 10, 10, 256)       0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 10, 10, 256)       1024
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 6, 6, 384)         885120
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 4, 4, 384)         1327488
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 1, 1, 384)         0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 1, 1, 384)         1536
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 384)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 4086)              1573110
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4086)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 4086)              16699482
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4086)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                40870
# =================================================================
# Total params: 21,745,462
# Trainable params: 21,743,990
# Non-trainable params: 1,472
# _________________________________________________________________
# 2554764
# 2/2 [==============================] - 1s 324ms/step - loss: 2.9720 - accuracy: 0.1000
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 260ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_126/244504569.py in <module>
#      63     model.get_weights()[0].dtype
#      64     quantizer = vitis_quantize.VitisQuantizer(model)
# ---> 65     quantized_model = quantizer.quantize_model(calib_dataset = X_test[1:10], weight_bit=8, activation_bit=8)
#      66     quantized_model.compile(loss='sparse_categorical_crossentropy', metrics=["accuracy"])
#      67     quantized_model.save('tf2_mnist_classifier_quantized.h5')
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/vitis_quantize.py in quantize_model(self, loss, metrics, calib_dataset, calib_batch_size, calib_steps, eval_dataset, verbose, add_shape_info, input_shape, configs, **kwargs)
#     576       else:
#     577         self._calibrate_without_loss(calib_dataset, calib_batch_size,
# --> 578                                      calib_steps)
#     579
#     580         # Post-quantize adjustment (Only for 8bit)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/vitis_quantize.py in _calibrate_without_loss(self, calib_dataset, calib_batch_size, calib_steps)
#     273     logger.info("Start Quantize Calibration...")
#     274     collector = self._run_model_with_collector(self._qcb_model, calib_dataset,
# --> 275                                                calib_batch_size, calib_steps)
#     276
#     277     #  Create quantize calibration evaluation model
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/vitis_quantize.py in _run_model_with_collector(self, model, dataset, batch_size, steps)
#     217         verbose=1,
#     218         steps=steps,
# --> 219         callbacks=[collector])
#     220     return collector
#     221
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1749           for step in data_handler.steps():
#    1750             callbacks.on_predict_batch_begin(step)
# -> 1751             tmp_batch_outputs = self.predict_function(iterator)
#    1752             if data_handler.should_sync:
#    1753               context.async_wait()
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     931       # This is the first call of __call__, so we have to initialize.
#     932       initializers = []
# --> 933       self._initialize(args, kwds, add_initializers_to=initializers)
#     934     finally:
#     935       # At this point we know that the initialization is complete (or less
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     758     self._concrete_stateful_fn = (
#     759         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 760             *args, **kwds))
#     761
#     762     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3064       args, kwargs = None, None
#    3065     with self._lock:
# -> 3066       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3067     return graph_function
#    3068
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3461
#    3462           self._function_cache.missed.add(call_context_key)
# -> 3463           graph_function = self._create_graph_function(args, kwargs)
#    3464           self._function_cache.primary[cache_key] = graph_function
#    3465
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3306             arg_names=arg_names,
#    3307             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3308             capture_by_value=self._capture_by_value),
#    3309         self._function_attributes,
#    3310         function_spec=self.function_spec,
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1005         _, original_func = tf_decorator.unwrap(python_func)
#    1006
# -> 1007       func_outputs = python_func(*func_args, **func_kwargs)
#    1008
#    1009       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     666         # the function a weak reference to itself to avoid a reference cycle.
#     667         with OptionalXlaContext(compile_with_xla):
# --> 668           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     669         return out
#     670
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     988                     recursive=True,
#     989                     optional_features=autograph_options,
# --> 990                     user_requested=True,
#     991                 ))
#     992           except Exception as e:  # pylint:disable=broad-except
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     380
#     381   if not options.user_requested and conversion.is_allowlisted(f):
# --> 382     return _call_unconverted(f, args, kwargs, options)
#     383
#     384   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     462   if kwargs is not None:
#     463     return f(*args, **kwargs)
# --> 464   return f(*args)
#     465
#     466
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/training.py in step_function(model, iterator)
#    1574
#    1575       data = next(iterator)
# -> 1576       outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1577       outputs = reduce_per_replica(
#    1578           outputs, self.distribute_strategy, reduction='concat')
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1284       fn = autograph.tf_convert(
#    1285           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1286       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1287
#    1288   def reduce(self, reduce_op, value, axis):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2847       kwargs = {}
#    2848     with self._container_strategy().scope():
# -> 2849       return self._call_for_each_replica(fn, args, kwargs)
#    2850
#    2851   def _call_for_each_replica(self, fn, args, kwargs):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    3630   def _call_for_each_replica(self, fn, args, kwargs):
#    3631     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3632       return fn(*args, **kwargs)
#    3633
#    3634   def _reduce_to(self, reduce_op, value, destinations, options):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     690       try:
#     691         with conversion_ctx:
# --> 692           return converted_call(f, args, kwargs, options=options)
#     693       except Exception as e:  # pylint:disable=broad-except
#     694         if hasattr(e, 'ag_error_metadata'):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     380
#     381   if not options.user_requested and conversion.is_allowlisted(f):
# --> 382     return _call_unconverted(f, args, kwargs, options)
#     383
#     384   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     461
#     462   if kwargs is not None:
# --> 463     return f(*args, **kwargs)
#     464   return f(*args)
#     465
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/training.py in run_step(data)
#    1567
#    1568       def run_step(data):
# -> 1569         outputs = model.predict_step(data)
#    1570         # Ensure counter is updated only if `test_step` succeeds.
#    1571         with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/training.py in predict_step(self, data)
#    1535     data = data_adapter.expand_1d(data)
#    1536     x, _, _ = data_adapter.unpack_x_y_sample_weight(data)
# -> 1537     return self(x, training=False)
#    1538
#    1539   def make_predict_function(self, force=False):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/functional.py in call(self, inputs, training, mask)
#     413     """
#     414     return self._run_internal_graph(
# --> 415         inputs, training=training, mask=mask)
#     416
#     417   def compute_output_shape(self, input_shape):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     548
#     549         args, kwargs = node.map_arguments(tensor_dict)
# --> 550         outputs = node.layer(*args, **kwargs)
#     551
#     552         # Update tensor_dict.
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     690       try:
#     691         with conversion_ctx:
# --> 692           return converted_call(f, args, kwargs, options=options)
#     693       except Exception as e:  # pylint:disable=broad-except
#     694         if hasattr(e, 'ag_error_metadata'):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_wrapper.py in tf__call(self, inputs, training)
#      41                 quantizer_vars = ag__.Undefined('quantizer_vars')
#      42                 unquantized_weight = ag__.Undefined('unquantized_weight')
# ---> 43                 ag__.for_stmt(ag__.ld(self)._weight_vars, None, loop_body, get_state_1, set_state_1, (), {'iterate_names': '(unquantized_weight, quantizer, quantizer_vars)'})
#      44                 ag__.converted_call(ag__.ld(self).quantize_config.set_quantize_weights, (ag__.ld(self).layer, ag__.ld(quantized_weights)), None, fscope)
#      45
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in for_stmt(iter_, extra_test, body, get_state, set_state, symbol_names, opts)
#     440
#     441   else:
# --> 442     _py_for_stmt(iter_, extra_test, body, None, None)
#     443
#     444
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_for_stmt(***failed resolving arguments***)
#     469   else:
#     470     for target in iter_:
# --> 471       body(target)
#     472
#     473
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in protected_body(protected_iter)
#     455     original_body = body
#     456     def protected_body(protected_iter):
# --> 457       original_body(protected_iter)
#     458       after_iteration()
#     459       before_iteration()
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_wrapper.py in loop_body(itr)
#      35                 def loop_body(itr):
#      36                     (unquantized_weight, quantizer, quantizer_vars) = itr
# ---> 37                     quantized_weight = ag__.converted_call(ag__.ld(common_utils).smart_cond, (ag__.ld(training), ag__.converted_call(ag__.ld(self)._make_quantizer_fn, (ag__.ld(quantizer), ag__.ld(unquantized_weight), True, ag__.ld(self).mode, ag__.ld(quantizer_vars)), None, fscope), ag__.converted_call(ag__.ld(self)._make_quantizer_fn, (ag__.ld(quantizer), ag__.ld(unquantized_weight), False, ag__.ld(self).mode, ag__.ld(quantizer_vars)), None, fscope)), None, fscope)
#      38                     ag__.converted_call(ag__.ld(quantized_weights).append, (ag__.ld(quantized_weight),), None, fscope)
#      39                 quantizer = ag__.Undefined('quantizer')
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     444         result = converted_f(*effective_args, **kwargs)
#     445       else:
# --> 446         result = converted_f(*effective_args)
#     447     except Exception as e:
#     448       _attach_error_metadata(e, converted_f)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/utils/common_utils.py in tf__smart_cond(pred, true_fn, false_fn, name)
#      35                         do_return = False
#      36                         raise
# ---> 37                 ag__.if_stmt(ag__.converted_call(ag__.ld(isinstance), (ag__.ld(pred), ag__.ld(variables).Variable), None, fscope), if_body, else_body, get_state, set_state, ('do_return', 'retval_'), 2)
#      38                 return fscope.ret(retval_, do_return)
#      39         return tf__smart_cond
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1172     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1173   else:
# -> 1174     _py_if_stmt(cond, body, orelse)
#    1175
#    1176
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1225 def _py_if_stmt(cond, body, orelse):
#    1226   """Overload of if_stmt that executes a Python if statement."""
# -> 1227   return body() if cond else orelse()
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/utils/common_utils.py in else_body()
#      31                     try:
#      32                         do_return = True
# ---> 33                         retval_ = ag__.converted_call(ag__.ld(smart_module).smart_cond, (ag__.ld(pred),), dict(true_fn=ag__.ld(true_fn), false_fn=ag__.ld(false_fn), name=ag__.ld(name)), fscope)
#      34                     except:
#      35                         do_return = False
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     334   if conversion.is_in_allowlist_cache(f, options):
#     335     logging.log(2, 'Allowlisted %s: from cache', f)
# --> 336     return _call_unconverted(f, args, kwargs, options, False)
#     337
#     338   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     461
#     462   if kwargs is not None:
# --> 463     return f(*args, **kwargs)
#     464   return f(*args)
#     465
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/framework/smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      56       return true_fn()
#      57     else:
# ---> 58       return false_fn()
#      59   else:
#      60     return control_flow_ops.cond(pred, true_fn=true_fn, false_fn=false_fn,
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_wrapper.py in quantizer_fn()
#      18                         try:
#      19                             do_return_1 = True
# ---> 20                             retval__1 = ag__.converted_call(ag__.ld(quantizer), (ag__.ld(x), ag__.ld(training), ag__.ld(mode)), dict(weights=ag__.ld(quantizer_vars)), fscope_1)
#      21                         except:
#      22                             do_return_1 = False
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantizers.py in tf____call__(self, inputs, is_training, mode, weights, **kwargs)
#      12                 try:
#      13                     do_return = True
# ---> 14                     retval_ = ag__.converted_call(ag__.ld(vitis_quantize_ops).LastValueQuantPosQuantize, (ag__.ld(inputs), ag__.ld(weights)['quant_pos_var'], ag__.ld(weights)['min_var'], ag__.ld(weights)['max_var']), dict(bit_width=ag__.ld(self).bit_width, method=ag__.ld(self).method, round_mode=ag__.ld(self).round_mode, mode=ag__.ld(mode), is_training=ag__.ld(is_training), symmetry=ag__.ld(self).symmetry, per_channel=ag__.ld(self).per_channel, channel_axis=ag__.ld(self).channel_axis), fscope)
#      15                 except:
#      16                     do_return = False
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_ops.py in tf__LastValueQuantPosQuantize(inputs, quant_pos_var, min_var, max_var, bit_width, method, round_mode, mode, is_training, symmetry, per_channel, channel_axis, name_scope)
#     214                     assign_quantize_pos = ag__.Undefined('assign_quantize_pos')
#     215                     batch_min = ag__.Undefined('batch_min')
# --> 216                     ag__.if_stmt((ag__.ld(mode) == 'ANALYSE'), if_body_8, else_body_8, get_state_8, set_state_8, ('do_return', 'retval_'), 2)
#     217                 return fscope.ret(retval_, do_return)
#     218         return tf__LastValueQuantPosQuantize
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1172     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1173   else:
# -> 1174     _py_if_stmt(cond, body, orelse)
#    1175
#    1176
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1225 def _py_if_stmt(cond, body, orelse):
#    1226   """Overload of if_stmt that executes a Python if statement."""
# -> 1227   return body() if cond else orelse()
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_ops.py in else_body_8()
#     207                         assign_quantize_pos = ag__.Undefined('assign_quantize_pos')
#     208                         batch_min = ag__.Undefined('batch_min')
# --> 209                         ag__.if_stmt(ag__.or_((lambda : ag__.ld(is_training)), (lambda : (ag__.ld(mode) == 'QCB'))), if_body_7, else_body_7, get_state_7, set_state_7, ('do_return', 'retval_'), 2)
#     210                     batch_max = ag__.Undefined('batch_max')
#     211                     assign_max = ag__.Undefined('assign_max')
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1172     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1173   else:
# -> 1174     _py_if_stmt(cond, body, orelse)
#    1175
#    1176
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1225 def _py_if_stmt(cond, body, orelse):
#    1226   """Overload of if_stmt that executes a Python if statement."""
# -> 1227   return body() if cond else orelse()
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_ops.py in if_body_7()
#      64                             assign_min = ag__.converted_call(ag__.ld(tf_compat).assign, (ag__.ld(min_var), ag__.ld(batch_min)), dict(name='assign_min'), fscope)
#      65                             assign_max = ag__.converted_call(ag__.ld(tf_compat).assign, (ag__.ld(max_var), ag__.ld(batch_max)), dict(name='assign_max'), fscope)
# ---> 66                             batch_quantize_pos = ag__.converted_call(ag__.ld(get_quantize_pos), (ag__.ld(inputs), ag__.ld(assign_min), ag__.ld(assign_max), ag__.ld(bit_width), ag__.ld(method), ag__.ld(round_mode), ag__.ld(per_channel), ag__.ld(channel_axis), ag__.ld(symmetry)), None, fscope)
#      67                             assign_quantize_pos = ag__.converted_call(ag__.ld(tf_compat).assign, (ag__.ld(quant_pos_var), ag__.ld(batch_quantize_pos)), dict(name='assign_quantize_pos'), fscope)
#      68
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     444         result = converted_f(*effective_args, **kwargs)
#     445       else:
# --> 446         result = converted_f(*effective_args)
#     447     except Exception as e:
#     448       _attach_error_metadata(e, converted_f)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_ops.py in tf__get_quantize_pos(inputs, f_min, f_max, bit_width, method, round_mode, per_channel, reduce_dims, symmetry)
#     111                             ag__.if_stmt(ag__.and_((lambda : (ag__.ld(method) == 1)), (lambda : (ag__.ld(round_mode) == 0))), if_body_2, else_body_2, get_state_2, set_state_2, ('do_return', 'retval_'), 2)
#     112                         ag__.if_stmt((ag__.ld(method) == 0), if_body_3, else_body_3, get_state_3, set_state_3, ('do_return', 'retval_'), 2)
# --> 113                     ag__.if_stmt(ag__.not_(ag__.ld(symmetry)), if_body_4, else_body_4, get_state_4, set_state_4, ('do_return', 'retval_'), 2)
#     114                 return fscope.ret(retval_, do_return)
#     115         return tf__get_quantize_pos
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1172     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1173   else:
# -> 1174     _py_if_stmt(cond, body, orelse)
#    1175
#    1176
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1225 def _py_if_stmt(cond, body, orelse):
#    1226   """Overload of if_stmt that executes a Python if statement."""
# -> 1227   return body() if cond else orelse()
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_ops.py in else_body_4()
#     110                                 ag__.if_stmt(ag__.and_((lambda : (ag__.ld(method) == 1)), (lambda : (ag__.ld(round_mode) == 1))), if_body_1, else_body_1, get_state_1, set_state_1, ('do_return', 'retval_'), 2)
#     111                             ag__.if_stmt(ag__.and_((lambda : (ag__.ld(method) == 1)), (lambda : (ag__.ld(round_mode) == 0))), if_body_2, else_body_2, get_state_2, set_state_2, ('do_return', 'retval_'), 2)
# --> 112                         ag__.if_stmt((ag__.ld(method) == 0), if_body_3, else_body_3, get_state_3, set_state_3, ('do_return', 'retval_'), 2)
#     113                     ag__.if_stmt(ag__.not_(ag__.ld(symmetry)), if_body_4, else_body_4, get_state_4, set_state_4, ('do_return', 'retval_'), 2)
#     114                 return fscope.ret(retval_, do_return)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1172     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1173   else:
# -> 1174     _py_if_stmt(cond, body, orelse)
#    1175
#    1176
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1225 def _py_if_stmt(cond, body, orelse):
#    1226   """Overload of if_stmt that executes a Python if statement."""
# -> 1227   return body() if cond else orelse()
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_ops.py in else_body_3()
#     109                                     ag__.converted_call(ag__.ld(logger).error, ('', ag__.ld(NotImplementedError)), None, fscope)
#     110                                 ag__.if_stmt(ag__.and_((lambda : (ag__.ld(method) == 1)), (lambda : (ag__.ld(round_mode) == 1))), if_body_1, else_body_1, get_state_1, set_state_1, ('do_return', 'retval_'), 2)
# --> 111                             ag__.if_stmt(ag__.and_((lambda : (ag__.ld(method) == 1)), (lambda : (ag__.ld(round_mode) == 0))), if_body_2, else_body_2, get_state_2, set_state_2, ('do_return', 'retval_'), 2)
#     112                         ag__.if_stmt((ag__.ld(method) == 0), if_body_3, else_body_3, get_state_3, set_state_3, ('do_return', 'retval_'), 2)
#     113                     ag__.if_stmt(ag__.not_(ag__.ld(symmetry)), if_body_4, else_body_4, get_state_4, set_state_4, ('do_return', 'retval_'), 2)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1172     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1173   else:
# -> 1174     _py_if_stmt(cond, body, orelse)
#    1175
#    1176
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1225 def _py_if_stmt(cond, body, orelse):
#    1226   """Overload of if_stmt that executes a Python if statement."""
# -> 1227   return body() if cond else orelse()
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_ops.py in if_body_2()
#      81                                 try:
#      82                                     do_return = True
# ---> 83                                     retval_ = ag__.converted_call(ag__.ld(get_quantize_pos_min_diffs_py3_sym), (ag__.ld(inputs), ag__.ld(f_min), ag__.ld(f_max), ag__.ld(q_min), ag__.ld(q_max), ag__.ld(bit_width), ag__.ld(per_channel), ag__.ld(reduce_dims)), None, fscope)
#      84                                 except:
#      85                                     do_return = False
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     444         result = converted_f(*effective_args, **kwargs)
#     445       else:
# --> 446         result = converted_f(*effective_args)
#     447     except Exception as e:
#     448       _attach_error_metadata(e, converted_f)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_ops.py in tf__get_quantize_pos_min_diffs_py3_sym(inputs, f_min, f_max, q_min, q_max, bit_width, per_channel, reduce_dims)
#      34                     dequantized = ag__.Undefined('dequantized')
#      35                     quantized = ag__.Undefined('quantized')
# ---> 36                     ag__.for_stmt(ag__.converted_call(ag__.ld(range), (5,), None, fscope), None, loop_body, get_state, set_state, (), {'iterate_names': 'i'})
#      37                     pos_offset = ag__.converted_call(ag__.ld(tf).argmin, (ag__.ld(diffs),), None, fscope)
#      38                     quantize_pos = (ag__.ld(non_overflow_pos) + ag__.converted_call(ag__.ld(tf).cast, (ag__.ld(pos_offset), ag__.ld(tf).float32), None, fscope))
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in for_stmt(iter_, extra_test, body, get_state, set_state, symbol_names, opts)
#     440
#     441   else:
# --> 442     _py_for_stmt(iter_, extra_test, body, None, None)
#     443
#     444
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_for_stmt(***failed resolving arguments***)
#     469   else:
#     470     for target in iter_:
# --> 471       body(target)
#     472
#     473
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in protected_body(protected_iter)
#     455     original_body = body
#     456     def protected_body(protected_iter):
# --> 457       original_body(protected_iter)
#     458       after_iteration()
#     459       before_iteration()
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_ops.py in loop_body(itr)
#      24                         with ag__.ld(tf).name_scope('FakeQuantizeWithScale_{}'.format(ag__.ld(i))):
#      25                             scale = ag__.converted_call(ag__.ld(tf).math.pow, (2.0, (ag__.ld(non_overflow_pos) + ag__.ld(i))), dict(name='scale'), fscope)
# ---> 26                             quantized = ag__.converted_call(ag__.ld(py3_sym_quantize), (ag__.ld(inputs), ag__.ld(scale), ag__.ld(q_min), ag__.ld(q_max)), None, fscope)
#      27                             dequantized = ag__.converted_call(ag__.ld(sym_dequantize), (ag__.ld(quantized), ag__.ld(scale), ag__.ld(q_min), ag__.ld(q_max)), None, fscope)
#      28                             diff = ag__.converted_call(ag__.ld(tf).pow, ((ag__.ld(inputs) - ag__.ld(dequantized)), 2), None, fscope)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     430   try:
#     431     program_ctx = converter.ProgramContext(options=options)
# --> 432     converted_f = _convert_actual(target_entity, program_ctx)
#     433     if logging.has_verbosity(2):
#     434       _log_callargs(converted_f, effective_args, kwargs)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in _convert_actual(entity, program_ctx)
#     272                      ' try passing f.python_function instead.')
#     273
# --> 274   transformed, module, source_map = _TRANSPILER.transform(entity, program_ctx)
#     275
#     276   assert not hasattr(transformed, 'ag_module')
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/pyct/transpiler.py in transform(self, obj, user_context)
#     284     """
#     285     if inspect.isfunction(obj) or inspect.ismethod(obj):
# --> 286       return self.transform_function(obj, user_context)
#     287
#     288     raise NotImplementedError('Non-function: {}'.format(type(obj)))
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/pyct/transpiler.py in transform_function(self, fn, user_context)
#     457     if self._cache.has(fn, cache_subkey):
#     458       # Fast path: use a lock-free check.
# --> 459       factory = self._cached_factory(fn, cache_subkey)
#     460
#     461     else:
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/pyct/transpiler.py in _cached_factory(self, fn, cache_subkey)
#     429
#     430   def _cached_factory(self, fn, cache_subkey):
# --> 431     cached_factory = self._cache[fn][cache_subkey]
#     432     logging.log(3, 'Cache hit for %s subkey %s: %s', fn, cache_subkey,
#     433                 cached_factory)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/core/converter.py in __eq__(self, other)
#     176   def __eq__(self, other):
#     177     assert isinstance(other, ConversionOptions)
# --> 178     return self.as_tuple() == other.as_tuple()
#     179
#     180   def __str__(self):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/core/converter.py in as_tuple(self)
#     169   def as_tuple(self):
#     170     return (self.recursive, self.user_requested,
# --> 171             self.internal_convert_user_code, self.optional_features)
#     172
#     173   def __hash__(self):
#
# KeyboardInterrupt:

# %%
import numpy as np
import os
import keras
from keras import backend as K
import numpy
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Input, BatchNormalization
from tensorflow_model_optimization.quantization.keras import vitis_quantize
from keras.models import Model
import tensorflow as tf



shape_range =range(224,512,32)
for shape_x in shape_range:
    shape_y = shape_x
    X_train=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
    Y_train=np.random.randint(0,10,size=[60,])
    X_test=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
    Y_test=np.random.randint(0,10,size=[60,])
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
    X_train /= 255.0
    X_test /= 255.0
    inputs = Input(shape=(shape_x, shape_y, 1))
    for step in range(1,11):
    
        conv1_kernel_num = random.randrange(64,96,2)
        conv1 = Conv2D(conv1_kernel_num, (11, 11), strides=(4, 4), activation='relu')(inputs)
        pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(conv1)
        Norm1 = BatchNormalization()(pool1)

        conv2_kernel_num = random.randrange(128,256,2)
        conv2 = Conv2D(conv2_kernel_num, kernel_size=(5, 5), activation='relu')(Norm1)
        pool2 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(conv2)
        Norm2 = BatchNormalization()(pool2)

        conv3_kernel_num = random.randrange(conv2_kernel_num,384,2)
        conv3 = Conv2D(384, kernel_size=(3, 3), activation='relu')(Norm2)
        conv4_kernel_num = random.randrange(conv3_kernel_num,384,2)
        conv4 = Conv2D(384, kernel_size=(3, 3), activation='relu')(conv3)
        conv4_kernel_num = random.randrange(128,256,2)
        conv5 = Conv2D(conv4_kernel_num, kernel_size=(3, 3), activation='relu')(conv4)
        pool3 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(conv5)
        Norm3 = BatchNormalization()(pool3)

        flat = Flatten()(Norm3)
        Dense1_neuron_num = random.randrange(1072,3072,32)
        fc1 = Dense(Dense1_neuron_num, activation='relu')(flat)
        drop1 = Dropout(0.5)(fc1)
        Dense2_neuron_num = random.randrange(Dense1_neuron_num,3072,32)
        fc2 = Dense(Dense2_neuron_num, activation='relu')(drop1)
        drop2 = Dropout(0.5)(fc2)

        outputs = Dense(10, activation='softmax')(drop2)

        model = Model(inputs=inputs, outputs=outputs)
        model.summary()
        model.save('./AlexNet_h5/AlexNet_{input_x}_{input_y}_{step}.h5'.format(input_x=shape_x,input_y=shape_y,step=step))

    #     model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    #     history = model.fit(X_train, Y_train, epochs=1)
    #     model.get_weights()[0].dtype
        quantizer = vitis_quantize.VitisQuantizer(model)
        quantized_model = quantizer.quantize_model(calib_dataset = X_test[1:10], weight_bit=8, activation_bit=8)
    #     quantized_model.compile(loss='sparse_categorical_crossentropy', metrics=["accuracy"])
        quantized_model.save('quantized.h5')
        # !vai_c_tensorflow2 \
        --model ./quantized.h5 \
        --arch ./arch.json \
        --output_dir ./xmodel_AlexNet \
        --net_name deploy
        os.rename("./xmodel_AlexNet/deploy.xmodel","./xmodel_AlexNet/AlexNet_{shape_x}_{shape_y}_{step}.xmodel".format(shape_x=shape_x,shape_y=shape_y,step=step))
