# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from itertools import product
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow_model_optimization.quantization.keras import vitis_quantize

# input_horizontal =range(32,64,32)
# input_vertical =range(32,64,32)
# for input_x,input_y in product(input_horizontal,input_vertical):
shape_range =range(32,512,32)
for shape_x in shape_range:
    shape_y = shape_x
    X_train=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
    Y_train=np.random.randint(0,10,size=[60,])
    X_test=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
    Y_test=np.random.randint(0,10,size=[60,])
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
    X_train /= 255.0
    X_test /= 255.0
    inputs = Input(shape=(shape_x, shape_y, 1))

    # 卷积层和最大池化层
    conv1 = Conv2D(64, (3,3), padding='same', activation='relu')(inputs)
    conv2 = Conv2D(64, (3,3), padding='same', activation='relu')(conv1)
    pool1 = MaxPooling2D(pool_size=2)(conv2)

    conv3 = Conv2D(128, (3,3), padding='same', activation='relu')(pool1)
    conv4 = Conv2D(128, (3,3), padding='same', activation='relu')(conv3)
    pool2 = MaxPooling2D(pool_size=2)(conv4)

    conv5 = Conv2D(256, (3,3), padding='same', activation='relu')(pool2)
    conv6 = Conv2D(256, (3,3), padding='same', activation='relu')(conv5)
    conv7 = Conv2D(256, (3,3), padding='same', activation='relu')(conv6)
    pool3 = MaxPooling2D(pool_size=2)(conv7)

    conv8 = Conv2D(512, (3,3), padding='same', activation='relu')(pool3)
    conv9 = Conv2D(512, (3,3), padding='same', activation='relu')(conv8)
    conv10 = Conv2D(512, (3,3), padding='same', activation='relu')(conv9)
    pool4 = MaxPooling2D(pool_size=2)(conv10)

    conv11 = Conv2D(512, (3,3), padding='same', activation='relu')(pool4)
    conv12 = Conv2D(512, (3,3), padding='same', activation='relu')(conv11)
    conv13 = Conv2D(256, (3,3), padding='same', activation='relu')(conv12)
    pool5 = MaxPooling2D(pool_size=2)(conv13)

    # 扁平层
    flat = Flatten()(pool5)

    # 全联接层
    fc1 = Dense(4096, activation='relu')(flat)
    fc2 = Dense(4096, activation='relu')(fc1)

    # 输出层
    outputs = Dense(10, activation='softmax')(fc2)


    model = Model(inputs=inputs, outputs=outputs)
    model.summary()
    model.compile(optimizer='adam',
              loss="sparse_categorical_crossentropy", 
              metrics=['accuracy'])
    #history = model.fit(x_train, y_train, epochs=1)
    #model.get_weights()[0].dtype
    quantizer = vitis_quantize.VitisQuantizer(model)
    #quantized_model = quantizer.quantize_model(calib_dataset = X_test[1:8], weight_bit=8, activation_bit=8)
    #quantized_model.compile(loss='sparse_categorical_crossentropy', metrics=["accuracy"])
    quantized_model.save('quantized.h5')
    # !vai_c_tensorflow2 \
            --model ./quantized.h5 \
            --arch ./arch.json \
            --output_dir ./xmodel_vgg16 \
            --net_name deploy
    os.rename("./xmodel_vgg16/deploy.xmodel","./xmodel_vgg16/vgg16_{input_x}_{input_y}.xmodel".format(input_x=shape_x,input_y=shape_y))

# %%
for input_x,input_y in product(input_horizontal,input_vertical):
    x_train = tf.image.resize(x_train, [input_x,input_y])
    x_test = tf.image.resize(x_test, [input_x,input_y])
    print(x_train.shape)
    print(x_train.dtype)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from itertools import product
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow_model_optimization.quantization.keras import vitis_quantize
from keras_flops import get_flops

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

print('Training data: {}, {}'.format(x_train.shape, y_train.shape))
print('Test data: {}, {}'.format(x_test.shape, y_test.shape))
x_train = x_train[0:60]
y_train = y_train[0:60]
x_test = x_test[0:10]
y_test = y_test[0:10]

x_train, x_test = x_train / 255.0, x_test / 255.0
x_train = np.expand_dims(x_train, axis=3)
x_test = np.expand_dims(x_test, axis=3)

input_range =range(32,64,32)

for input_x in input_range:
    input_y = input_x
    x_train = tf.image.resize(x_train, [input_x,input_y])
    x_test = tf.image.resize(x_test, [input_x,input_y])


    inputs = Input(shape=(input_x, input_y, 1))

    # 卷积层和最大池化层
    conv1 = Conv2D(64, (3,3), padding='same', activation='relu')(inputs)
    conv2 = Conv2D(64, (3,3), padding='same', activation='relu')(conv1)
    pool1 = MaxPooling2D(pool_size=2)(conv2)

    conv3 = Conv2D(128, (3,3), padding='same', activation='relu')(pool1)
    conv4 = Conv2D(128, (3,3), padding='same', activation='relu')(conv3)
    pool2 = MaxPooling2D(pool_size=2)(conv4)

    conv5 = Conv2D(256, (3,3), padding='same', activation='relu')(pool2)
    conv6 = Conv2D(256, (3,3), padding='same', activation='relu')(conv5)
    conv7 = Conv2D(256, (3,3), padding='same', activation='relu')(conv6)
    pool3 = MaxPooling2D(pool_size=2)(conv7)

    conv8 = Conv2D(512, (3,3), padding='same', activation='relu')(pool3)
    conv9 = Conv2D(512, (3,3), padding='same', activation='relu')(conv8)
    conv10 = Conv2D(512, (3,3), padding='same', activation='relu')(conv9)
    pool4 = MaxPooling2D(pool_size=2)(conv10)

    conv11 = Conv2D(512, (3,3), padding='same', activation='relu')(pool4)
    conv12 = Conv2D(512, (3,3), padding='same', activation='relu')(conv11)
    conv13 = Conv2D(256, (3,3), padding='same', activation='relu')(conv12)
    pool5 = MaxPooling2D(pool_size=2)(conv13)

    # 扁平层
    flat = Flatten()(pool5)

    # 全联接层
    fc1 = Dense(4096, activation='relu')(flat)
    fc2 = Dense(4096, activation='relu')(fc1)

    # 输出层
    outputs = Dense(10, activation='softmax')(fc2)


    model = Model(inputs=inputs, outputs=outputs)
    model.summary()
    model.compile(optimizer='adam',
              loss="sparse_categorical_crossentropy", 
              metrics=['accuracy'])
    history = model.fit(x_train, y_train, epochs=1)
    model.get_weights()[0].dtype
    quantizer = vitis_quantize.VitisQuantizer(model)
    quantized_model = quantizer.quantize_model(calib_dataset = x_test[1:8], weight_bit=8, activation_bit=8)
    quantized_model.compile(loss='sparse_categorical_crossentropy', metrics=["accuracy"])
    quantized_model.save('tf2_mnist_classifier_quantized.h5')
    # !vai_c_tensorflow2 \
            --model ./tf2_mnist_classifier_quantized.h5 \
            --arch ./arch.json \
            --output_dir ./xmodel \
            --net_name deploy
    os.rename("./xmodel/deploy.xmodel","./xmodel/mnist_classifier_vgg16_{input_x}_{input_y}.xmodel".format(input_x=input_x,input_y=input_y))

# %%
import os
import numpy as np
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from itertools import product
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow_model_optimization.quantization.keras import vitis_quantize

#from keras_flops import get_flops

shape_range =range(192,480,32)
for shape_x in shape_range:
    shape_y = shape_x
    X_train=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
    Y_train=np.random.randint(0,10,size=[60,])
    X_test=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
    Y_test=np.random.randint(0,10,size=[60,])
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
    X_train /= 255.0
    X_test /= 255.0
    inputs = Input(shape=(shape_x, shape_y, 1))
    for step in range(1,11):
        # 卷积层和最大池化层
        conv1_kernel_num = random.randrange(32,64,2)
        conv1 = Conv2D(conv1_kernel_num, (3,3), padding='same', activation='relu')(inputs)
        conv2_kernel_num = random.randrange(conv1_kernel_num,64,2)
        conv2 = Conv2D(conv2_kernel_num, (3,3), padding='same', activation='relu')(conv1)
        pool1 = MaxPooling2D(pool_size=2)(conv2)

        conv3_kernel_num = random.randrange(conv2_kernel_num,128,2)
        conv3 = Conv2D(conv3_kernel_num, (3,3), padding='same', activation='relu')(pool1)
        conv4_kernel_num = random.randrange(conv3_kernel_num,128,2)
        conv4 = Conv2D(conv4_kernel_num, (3,3), padding='same', activation='relu')(conv3)
        pool2 = MaxPooling2D(pool_size=2)(conv4)

        conv5_kernel_num = random.randrange(conv4_kernel_num,256,2)
        conv5 = Conv2D(conv5_kernel_num, (3,3), padding='same', activation='relu')(pool2)
        conv6_kernel_num = random.randrange(conv5_kernel_num,256,2)
        conv6 = Conv2D(conv6_kernel_num, (3,3), padding='same', activation='relu')(conv5)
        conv7_kernel_num = random.randrange(conv6_kernel_num,256,2)
        conv7 = Conv2D(conv7_kernel_num, (3,3), padding='same', activation='relu')(conv6)
        pool3 = MaxPooling2D(pool_size=2)(conv7)

        conv8_kernel_num = random.randrange(conv7_kernel_num,512,2)
        conv8 = Conv2D(conv8_kernel_num, (3,3), padding='same', activation='relu')(pool3)
        conv9_kernel_num = random.randrange(conv8_kernel_num,512,2)
        conv9 = Conv2D(conv9_kernel_num, (3,3), padding='same', activation='relu')(conv8)
        conv10_kernel_num = random.randrange(conv9_kernel_num,512,2)
        conv10 = Conv2D(conv10_kernel_num, (3,3), padding='same', activation='relu')(conv9)
        pool4 = MaxPooling2D(pool_size=2)(conv10)

        conv11_kernel_num = random.randrange(conv10_kernel_num,512,2)
        conv11 = Conv2D(conv11_kernel_num, (3,3), padding='same', activation='relu')(pool4)
        conv12_kernel_num = random.randrange(conv11_kernel_num,512,2)
        conv12 = Conv2D(conv12_kernel_num, (3,3), padding='same', activation='relu')(conv11)
        conv13_kernel_num = random.randrange(128,256,2)
        conv13 = Conv2D(conv13_kernel_num, (3,3), padding='same', activation='relu')(conv12)
        pool5 = MaxPooling2D(pool_size=2)(conv13)

        # 扁平层
        flat = Flatten()(pool5)

        # 全联接层
        Dense1_neuron_num = random.randrange(1072,3072,32)
        fc1 = Dense(Dense1_neuron_num, activation='relu')(flat)
        Dense2_neuron_num = random.randrange(1072,Dense1_neuron_num+1,32)
        fc2 = Dense(Dense2_neuron_num, activation='relu')(fc1)

        # 输出层
        outputs = Dense(10, activation='softmax')(fc2)


        model = Model(inputs=inputs, outputs=outputs)
        model.summary()
        model.save('./vgg16_h5/vgg16_{input_x}_{input_y}_{step}.h5'.format(input_x=shape_x,input_y=shape_y,step=step))

        #model.compile(optimizer='adam',loss="sparse_categorical_crossentropy", metrics=['accuracy'])
        #history = model.fit(x_train, y_train, epochs=1)
        #model.get_weights()[0].dtype
        quantizer = vitis_quantize.VitisQuantizer(model)
        quantized_model = quantizer.quantize_model(calib_dataset = X_test[1:8], weight_bit=8, activation_bit=8)
        #quantized_model.compile(loss='sparse_categorical_crossentropy', metrics=["accuracy"])
        quantized_model.save('quantized.h5')
        # !vai_c_tensorflow2 \
                --model ./quantized.h5 \
                --arch ./arch.json \
                --output_dir ./xmodel_vgg16 \
                --net_name deploy
        os.rename("./xmodel_vgg16/deploy.xmodel","./xmodel_vgg16/vgg16_{input_x}_{input_y}_{step}.xmodel".format(input_x=shape_x,input_y=shape_y,step=step))
# Out:
# Model: "model_85"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 192, 192, 1)]     0
# _________________________________________________________________
# conv2d_1118 (Conv2D)         (None, 192, 192, 50)      500
# _________________________________________________________________
# conv2d_1119 (Conv2D)         (None, 192, 192, 54)      24354
# _________________________________________________________________
# max_pooling2d_430 (MaxPoolin (None, 96, 96, 54)        0
# _________________________________________________________________
# conv2d_1120 (Conv2D)         (None, 96, 96, 126)       61362
# _________________________________________________________________
# conv2d_1121 (Conv2D)         (None, 96, 96, 126)       143010
# _________________________________________________________________
# max_pooling2d_431 (MaxPoolin (None, 48, 48, 126)       0
# _________________________________________________________________
# conv2d_1122 (Conv2D)         (None, 48, 48, 168)       190680
# _________________________________________________________________
# conv2d_1123 (Conv2D)         (None, 48, 48, 254)       384302
# _________________________________________________________________
# conv2d_1124 (Conv2D)         (None, 48, 48, 254)       580898
# _________________________________________________________________
# max_pooling2d_432 (MaxPoolin (None, 24, 24, 254)       0
# _________________________________________________________________
# conv2d_1125 (Conv2D)         (None, 24, 24, 378)       864486
# _________________________________________________________________
# conv2d_1126 (Conv2D)         (None, 24, 24, 424)       1442872
# _________________________________________________________________
# conv2d_1127 (Conv2D)         (None, 24, 24, 486)       1855062
# _________________________________________________________________
# max_pooling2d_433 (MaxPoolin (None, 12, 12, 486)       0
# _________________________________________________________________
# conv2d_1128 (Conv2D)         (None, 12, 12, 490)       2143750
# _________________________________________________________________
# conv2d_1129 (Conv2D)         (None, 12, 12, 500)       2205500
# _________________________________________________________________
# conv2d_1130 (Conv2D)         (None, 12, 12, 228)       1026228
# _________________________________________________________________
# max_pooling2d_434 (MaxPoolin (None, 6, 6, 228)         0
# _________________________________________________________________
# flatten_86 (Flatten)         (None, 8208)              0
# _________________________________________________________________
# dense_256 (Dense)            (None, 1712)              14053808
# _________________________________________________________________
# dense_257 (Dense)            (None, 1520)              2603760
# _________________________________________________________________
# dense_258 (Dense)            (None, 10)                15210
# =================================================================
# Total params: 27,595,782
# Trainable params: 27,595,782
# Non-trainable params: 0
# _________________________________________________________________
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 4s 433ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 8s 8s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 40/40 [00:00<00:00, 25870.80it/s]
# [INFO] infer shape (NHWC)  :100%|█| 67/67 [00:00<00:00, 349.75it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 259.74it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 977.58it/s]
# [INFO] generate xmodel     :100%|█| 67/67 [00:01<00:00, 60.65it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_85, with op num: 125
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 0ee28200ff5f88c0247d400743cf4f7f, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/md5sum.txt"
# Model: "model_86"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 192, 192, 1)]     0
# _________________________________________________________________
# conv2d_1131 (Conv2D)         (None, 192, 192, 56)      560
# _________________________________________________________________
# conv2d_1132 (Conv2D)         (None, 192, 192, 62)      31310
# _________________________________________________________________
# max_pooling2d_435 (MaxPoolin (None, 96, 96, 62)        0
# _________________________________________________________________
# conv2d_1133 (Conv2D)         (None, 96, 96, 104)       58136
# _________________________________________________________________
# conv2d_1134 (Conv2D)         (None, 96, 96, 120)       112440
# _________________________________________________________________
# max_pooling2d_436 (MaxPoolin (None, 48, 48, 120)       0
# _________________________________________________________________
# conv2d_1135 (Conv2D)         (None, 48, 48, 178)       192418
# _________________________________________________________________
# conv2d_1136 (Conv2D)         (None, 48, 48, 198)       317394
# _________________________________________________________________
# conv2d_1137 (Conv2D)         (None, 48, 48, 218)       388694
# _________________________________________________________________
# max_pooling2d_437 (MaxPoolin (None, 24, 24, 218)       0
# _________________________________________________________________
# conv2d_1138 (Conv2D)         (None, 24, 24, 428)       840164
# _________________________________________________________________
# conv2d_1139 (Conv2D)         (None, 24, 24, 496)       1911088
# _________________________________________________________________
# conv2d_1140 (Conv2D)         (None, 24, 24, 496)       2214640
# _________________________________________________________________
# max_pooling2d_438 (MaxPoolin (None, 12, 12, 496)       0
# _________________________________________________________________
# conv2d_1141 (Conv2D)         (None, 12, 12, 508)       2268220
# _________________________________________________________________
# conv2d_1142 (Conv2D)         (None, 12, 12, 508)       2323084
# _________________________________________________________________
# conv2d_1143 (Conv2D)         (None, 12, 12, 192)       878016
# _________________________________________________________________
# max_pooling2d_439 (MaxPoolin (None, 6, 6, 192)         0
# _________________________________________________________________
# flatten_87 (Flatten)         (None, 6912)              0
# _________________________________________________________________
# dense_259 (Dense)            (None, 2768)              19135184
# _________________________________________________________________
# dense_260 (Dense)            (None, 2096)              5803824
# _________________________________________________________________
# dense_261 (Dense)            (None, 10)                20970
# =================================================================
# Total params: 36,496,142
# Trainable params: 36,496,142
# Non-trainable params: 0
# _________________________________________________________________
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 4s 474ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 8s 8s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 40/40 [00:00<00:00, 24321.86it/s]
# [INFO] infer shape (NHWC)  :100%|█| 67/67 [00:00<00:00, 221.59it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 255.14it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 998.52it/s]
# [INFO] generate xmodel     :100%|█| 67/67 [00:01<00:00, 42.53it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_86, with op num: 125
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is c7e0b13f5869f17f47646884e4fad837, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/md5sum.txt"
# Model: "model_87"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 192, 192, 1)]     0
# _________________________________________________________________
# conv2d_1144 (Conv2D)         (None, 192, 192, 58)      580
# _________________________________________________________________
# conv2d_1145 (Conv2D)         (None, 192, 192, 62)      32426
# _________________________________________________________________
# max_pooling2d_440 (MaxPoolin (None, 96, 96, 62)        0
# _________________________________________________________________
# conv2d_1146 (Conv2D)         (None, 96, 96, 82)        45838
# _________________________________________________________________
# conv2d_1147 (Conv2D)         (None, 96, 96, 124)       91636
# _________________________________________________________________
# max_pooling2d_441 (MaxPoolin (None, 48, 48, 124)       0
# _________________________________________________________________
# conv2d_1148 (Conv2D)         (None, 48, 48, 160)       178720
# _________________________________________________________________
# conv2d_1149 (Conv2D)         (None, 48, 48, 186)       268026
# _________________________________________________________________
# conv2d_1150 (Conv2D)         (None, 48, 48, 190)       318250
# _________________________________________________________________
# max_pooling2d_442 (MaxPoolin (None, 24, 24, 190)       0
# _________________________________________________________________
# conv2d_1151 (Conv2D)         (None, 24, 24, 454)       776794
# _________________________________________________________________
# conv2d_1152 (Conv2D)         (None, 24, 24, 480)       1961760
# _________________________________________________________________
# conv2d_1153 (Conv2D)         (None, 24, 24, 506)       2186426
# _________________________________________________________________
# max_pooling2d_443 (MaxPoolin (None, 12, 12, 506)       0
# _________________________________________________________________
# conv2d_1154 (Conv2D)         (None, 12, 12, 508)       2313940
# _________________________________________________________________
# conv2d_1155 (Conv2D)         (None, 12, 12, 510)       2332230
# _________________________________________________________________
# conv2d_1156 (Conv2D)         (None, 12, 12, 134)       615194
# _________________________________________________________________
# max_pooling2d_444 (MaxPoolin (None, 6, 6, 134)         0
# _________________________________________________________________
# flatten_88 (Flatten)         (None, 4824)              0
# _________________________________________________________________
# dense_262 (Dense)            (None, 3056)              14745200
# _________________________________________________________________
# dense_263 (Dense)            (None, 2864)              8755248
# _________________________________________________________________
# dense_264 (Dense)            (None, 10)                28650
# =================================================================
# Total params: 34,650,918
# Trainable params: 34,650,918
# Non-trainable params: 0
# _________________________________________________________________
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 4s 468ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 9s 9s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 40/40 [00:00<00:00, 23706.68it/s]
# [INFO] infer shape (NHWC)  :100%|█| 67/67 [00:00<00:00, 250.14it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 252.20it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 953.47it/s]
# [INFO] generate xmodel     :100%|█| 67/67 [00:01<00:00, 43.94it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_87, with op num: 125
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is e79c02bf3fb306ab598e73bb7a957857, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/md5sum.txt"
# Model: "model_88"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 192, 192, 1)]     0
# _________________________________________________________________
# conv2d_1157 (Conv2D)         (None, 192, 192, 54)      540
# _________________________________________________________________
# conv2d_1158 (Conv2D)         (None, 192, 192, 54)      26298
# _________________________________________________________________
# max_pooling2d_445 (MaxPoolin (None, 96, 96, 54)        0
# _________________________________________________________________
# conv2d_1159 (Conv2D)         (None, 96, 96, 114)       55518
# _________________________________________________________________
# conv2d_1160 (Conv2D)         (None, 96, 96, 120)       123240
# _________________________________________________________________
# max_pooling2d_446 (MaxPoolin (None, 48, 48, 120)       0
# _________________________________________________________________
# conv2d_1161 (Conv2D)         (None, 48, 48, 162)       175122
# _________________________________________________________________
# conv2d_1162 (Conv2D)         (None, 48, 48, 242)       353078
# _________________________________________________________________
# conv2d_1163 (Conv2D)         (None, 48, 48, 250)       544750
# _________________________________________________________________
# max_pooling2d_447 (MaxPoolin (None, 24, 24, 250)       0
# _________________________________________________________________
# conv2d_1164 (Conv2D)         (None, 24, 24, 290)       652790
# _________________________________________________________________
# conv2d_1165 (Conv2D)         (None, 24, 24, 502)       1310722
# _________________________________________________________________
# conv2d_1166 (Conv2D)         (None, 24, 24, 504)       2277576
# _________________________________________________________________
# max_pooling2d_448 (MaxPoolin (None, 12, 12, 504)       0
# _________________________________________________________________
# conv2d_1167 (Conv2D)         (None, 12, 12, 510)       2313870
# _________________________________________________________________
# conv2d_1168 (Conv2D)         (None, 12, 12, 510)       2341410
# _________________________________________________________________
# conv2d_1169 (Conv2D)         (None, 12, 12, 252)       1156932
# _________________________________________________________________
# max_pooling2d_449 (MaxPoolin (None, 6, 6, 252)         0
# _________________________________________________________________
# flatten_89 (Flatten)         (None, 9072)              0
# _________________________________________________________________
# dense_265 (Dense)            (None, 3024)              27436752
# _________________________________________________________________
# dense_266 (Dense)            (None, 2576)              7792400
# _________________________________________________________________
# dense_267 (Dense)            (None, 10)                25770
# =================================================================
# Total params: 46,586,768
# Trainable params: 46,586,768
# Non-trainable params: 0
# _________________________________________________________________
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 6s 614ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 9s 9s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 40/40 [00:00<00:00, 23848.21it/s]
# [INFO] infer shape (NHWC)  :100%|█| 67/67 [00:00<00:00, 258.20it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 246.18it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 971.35it/s]
# [INFO] generate xmodel     :100%|█| 67/67 [00:02<00:00, 30.29it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_88, with op num: 125
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is c5662cc75b1fa4f3e618f685df71602d, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/md5sum.txt"
# Model: "model_89"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 192, 192, 1)]     0
# _________________________________________________________________
# conv2d_1170 (Conv2D)         (None, 192, 192, 32)      320
# _________________________________________________________________
# conv2d_1171 (Conv2D)         (None, 192, 192, 32)      9248
# _________________________________________________________________
# max_pooling2d_450 (MaxPoolin (None, 96, 96, 32)        0
# _________________________________________________________________
# conv2d_1172 (Conv2D)         (None, 96, 96, 116)       33524
# _________________________________________________________________
# conv2d_1173 (Conv2D)         (None, 96, 96, 118)       123310
# _________________________________________________________________
# max_pooling2d_451 (MaxPoolin (None, 48, 48, 118)       0
# _________________________________________________________________
# conv2d_1174 (Conv2D)         (None, 48, 48, 152)       161576
# _________________________________________________________________
# conv2d_1175 (Conv2D)         (None, 48, 48, 208)       284752
# _________________________________________________________________
# conv2d_1176 (Conv2D)         (None, 48, 48, 228)       427044
# _________________________________________________________________
# max_pooling2d_452 (MaxPoolin (None, 24, 24, 228)       0
# _________________________________________________________________
# conv2d_1177 (Conv2D)         (None, 24, 24, 486)       997758
# _________________________________________________________________
# conv2d_1178 (Conv2D)         (None, 24, 24, 500)       2187500
# _________________________________________________________________
# conv2d_1179 (Conv2D)         (None, 24, 24, 504)       2268504
# _________________________________________________________________
# max_pooling2d_453 (MaxPoolin (None, 12, 12, 504)       0
# _________________________________________________________________
# conv2d_1180 (Conv2D)         (None, 12, 12, 504)       2286648
# _________________________________________________________________
# conv2d_1181 (Conv2D)         (None, 12, 12, 506)       2295722
# _________________________________________________________________
# conv2d_1182 (Conv2D)         (None, 12, 12, 230)       1047650
# _________________________________________________________________
# max_pooling2d_454 (MaxPoolin (None, 6, 6, 230)         0
# _________________________________________________________________
# flatten_90 (Flatten)         (None, 8280)              0
# _________________________________________________________________
# dense_268 (Dense)            (None, 1776)              14707056
# _________________________________________________________________
# dense_269 (Dense)            (None, 1744)              3099088
# _________________________________________________________________
# dense_270 (Dense)            (None, 10)                17450
# =================================================================
# Total params: 29,947,150
# Trainable params: 29,947,150
# Non-trainable params: 0
# _________________________________________________________________
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 5s 531ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 8s 8s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 40/40 [00:00<00:00, 21729.33it/s]
# [INFO] infer shape (NHWC)  :100%|█| 67/67 [00:00<00:00, 911.90it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 252.92it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 997.46it/s]
# [INFO] generate xmodel     :100%|█| 67/67 [00:01<00:00, 57.08it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_89, with op num: 125
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is db4946a4a3cf8bf0199d1e1ce63b7723, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/md5sum.txt"
# Model: "model_90"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 192, 192, 1)]     0
# _________________________________________________________________
# conv2d_1183 (Conv2D)         (None, 192, 192, 60)      600
# _________________________________________________________________
# conv2d_1184 (Conv2D)         (None, 192, 192, 62)      33542
# _________________________________________________________________
# max_pooling2d_455 (MaxPoolin (None, 96, 96, 62)        0
# _________________________________________________________________
# conv2d_1185 (Conv2D)         (None, 96, 96, 88)        49192
# _________________________________________________________________
# conv2d_1186 (Conv2D)         (None, 96, 96, 116)       91988
# _________________________________________________________________
# max_pooling2d_456 (MaxPoolin (None, 48, 48, 116)       0
# _________________________________________________________________
# conv2d_1187 (Conv2D)         (None, 48, 48, 144)       150480
# _________________________________________________________________
# conv2d_1188 (Conv2D)         (None, 48, 48, 214)       277558
# _________________________________________________________________
# conv2d_1189 (Conv2D)         (None, 48, 48, 232)       447064
# _________________________________________________________________
# max_pooling2d_457 (MaxPoolin (None, 24, 24, 232)       0
# _________________________________________________________________
# conv2d_1190 (Conv2D)         (None, 24, 24, 368)       768752
# _________________________________________________________________
# conv2d_1191 (Conv2D)         (None, 24, 24, 434)       1437842
# _________________________________________________________________
# conv2d_1192 (Conv2D)         (None, 24, 24, 510)       1992570
# _________________________________________________________________
# max_pooling2d_458 (MaxPoolin (None, 12, 12, 510)       0
# _________________________________________________________________
# conv2d_1193 (Conv2D)         (None, 12, 12, 510)       2341410
# _________________________________________________________________
# conv2d_1194 (Conv2D)         (None, 12, 12, 510)       2341410
# _________________________________________________________________
# conv2d_1195 (Conv2D)         (None, 12, 12, 154)       707014
# _________________________________________________________________
# max_pooling2d_459 (MaxPoolin (None, 6, 6, 154)         0
# _________________________________________________________________
# flatten_91 (Flatten)         (None, 5544)              0
# _________________________________________________________________
# dense_271 (Dense)            (None, 1552)              8605840
# _________________________________________________________________
# dense_272 (Dense)            (None, 1520)              2360560
# _________________________________________________________________
# dense_273 (Dense)            (None, 10)                15210
# =================================================================
# Total params: 21,621,032
# Trainable params: 21,621,032
# Non-trainable params: 0
# _________________________________________________________________
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 3s 380ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 8s 8s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 40/40 [00:00<00:00, 25906.76it/s]
# [INFO] infer shape (NHWC)  :100%|█| 67/67 [00:00<00:00, 1011.92it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 257.33it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 991.91it/s]
# [INFO] generate xmodel     :100%|█| 67/67 [00:00<00:00, 89.21it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_90, with op num: 125
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 08ee808d66a54c37a4e05ca563963d67, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/md5sum.txt"
# Model: "model_91"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 192, 192, 1)]     0
# _________________________________________________________________
# conv2d_1196 (Conv2D)         (None, 192, 192, 52)      520
# _________________________________________________________________
# conv2d_1197 (Conv2D)         (None, 192, 192, 58)      27202
# _________________________________________________________________
# max_pooling2d_460 (MaxPoolin (None, 96, 96, 58)        0
# _________________________________________________________________
# conv2d_1198 (Conv2D)         (None, 96, 96, 70)        36610
# _________________________________________________________________
# conv2d_1199 (Conv2D)         (None, 96, 96, 108)       68148
# _________________________________________________________________
# max_pooling2d_461 (MaxPoolin (None, 48, 48, 108)       0
# _________________________________________________________________
# conv2d_1200 (Conv2D)         (None, 48, 48, 192)       186816
# _________________________________________________________________
# conv2d_1201 (Conv2D)         (None, 48, 48, 222)       383838
# _________________________________________________________________
# conv2d_1202 (Conv2D)         (None, 48, 48, 230)       459770
# _________________________________________________________________
# max_pooling2d_462 (MaxPoolin (None, 24, 24, 230)       0
# _________________________________________________________________
# conv2d_1203 (Conv2D)         (None, 24, 24, 508)       1052068
# _________________________________________________________________
# conv2d_1204 (Conv2D)         (None, 24, 24, 510)       2332230
# _________________________________________________________________
# conv2d_1205 (Conv2D)         (None, 24, 24, 510)       2341410
# _________________________________________________________________
# max_pooling2d_463 (MaxPoolin (None, 12, 12, 510)       0
# _________________________________________________________________
# conv2d_1206 (Conv2D)         (None, 12, 12, 510)       2341410
# _________________________________________________________________
# conv2d_1207 (Conv2D)         (None, 12, 12, 510)       2341410
# _________________________________________________________________
# conv2d_1208 (Conv2D)         (None, 12, 12, 242)       1111022
# _________________________________________________________________
# max_pooling2d_464 (MaxPoolin (None, 6, 6, 242)         0
# _________________________________________________________________
# flatten_92 (Flatten)         (None, 8712)              0
# _________________________________________________________________
# dense_274 (Dense)            (None, 1488)              12964944
# _________________________________________________________________
# dense_275 (Dense)            (None, 1392)              2072688
# _________________________________________________________________
# dense_276 (Dense)            (None, 10)                13930
# =================================================================
# Total params: 27,734,016
# Trainable params: 27,734,016
# Non-trainable params: 0
# _________________________________________________________________
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 4s 445ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 8s 8s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 40/40 [00:00<00:00, 21645.23it/s]
# [INFO] infer shape (NHWC)  :100%|█| 67/67 [00:00<00:00, 869.43it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 255.42it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 982.96it/s]
# [INFO] generate xmodel     :100%|█| 67/67 [00:01<00:00, 65.88it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_91, with op num: 125
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 69bde3c6eb17e08d7196f375c355ece2, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/md5sum.txt"
# Model: "model_92"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 192, 192, 1)]     0
# _________________________________________________________________
# conv2d_1209 (Conv2D)         (None, 192, 192, 38)      380
# _________________________________________________________________
# conv2d_1210 (Conv2D)         (None, 192, 192, 50)      17150
# _________________________________________________________________
# max_pooling2d_465 (MaxPoolin (None, 96, 96, 50)        0
# _________________________________________________________________
# conv2d_1211 (Conv2D)         (None, 96, 96, 62)        27962
# _________________________________________________________________
# conv2d_1212 (Conv2D)         (None, 96, 96, 74)        41366
# _________________________________________________________________
# max_pooling2d_466 (MaxPoolin (None, 48, 48, 74)        0
# _________________________________________________________________
# conv2d_1213 (Conv2D)         (None, 48, 48, 122)       81374
# _________________________________________________________________
# conv2d_1214 (Conv2D)         (None, 48, 48, 252)       276948
# _________________________________________________________________
# conv2d_1215 (Conv2D)         (None, 48, 48, 252)       571788
# _________________________________________________________________
# max_pooling2d_467 (MaxPoolin (None, 24, 24, 252)       0
# _________________________________________________________________
# conv2d_1216 (Conv2D)         (None, 24, 24, 308)       698852
# _________________________________________________________________
# conv2d_1217 (Conv2D)         (None, 24, 24, 308)       854084
# _________________________________________________________________
# conv2d_1218 (Conv2D)         (None, 24, 24, 492)       1364316
# _________________________________________________________________
# max_pooling2d_468 (MaxPoolin (None, 12, 12, 492)       0
# _________________________________________________________________
# conv2d_1219 (Conv2D)         (None, 12, 12, 502)       2223358
# _________________________________________________________________
# conv2d_1220 (Conv2D)         (None, 12, 12, 504)       2277576
# _________________________________________________________________
# conv2d_1221 (Conv2D)         (None, 12, 12, 206)       934622
# _________________________________________________________________
# max_pooling2d_469 (MaxPoolin (None, 6, 6, 206)         0
# _________________________________________________________________
# flatten_93 (Flatten)         (None, 7416)              0
# _________________________________________________________________
# dense_277 (Dense)            (None, 2800)              20767600
# _________________________________________________________________
# dense_278 (Dense)            (None, 2704)              7573904
# _________________________________________________________________
# dense_279 (Dense)            (None, 10)                27050
# =================================================================
# Total params: 37,738,330
# Trainable params: 37,738,330
# Non-trainable params: 0
# _________________________________________________________________
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 5s 544ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 8s 8s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 40/40 [00:00<00:00, 23205.00it/s]
# [INFO] infer shape (NHWC)  :100%|█| 67/67 [00:00<00:00, 220.77it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 257.00it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 972.14it/s]
# [INFO] generate xmodel     :100%|█| 67/67 [00:01<00:00, 37.99it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_92, with op num: 125
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 7ed6e188e450cab5843d3c76d1c41d6a, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/md5sum.txt"
# Model: "model_93"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 192, 192, 1)]     0
# _________________________________________________________________
# conv2d_1222 (Conv2D)         (None, 192, 192, 52)      520
# _________________________________________________________________
# conv2d_1223 (Conv2D)         (None, 192, 192, 52)      24388
# _________________________________________________________________
# max_pooling2d_470 (MaxPoolin (None, 96, 96, 52)        0
# _________________________________________________________________
# conv2d_1224 (Conv2D)         (None, 96, 96, 88)        41272
# _________________________________________________________________
# conv2d_1225 (Conv2D)         (None, 96, 96, 112)       88816
# _________________________________________________________________
# max_pooling2d_471 (MaxPoolin (None, 48, 48, 112)       0
# _________________________________________________________________
# conv2d_1226 (Conv2D)         (None, 48, 48, 166)       167494
# _________________________________________________________________
# conv2d_1227 (Conv2D)         (None, 48, 48, 206)       307970
# _________________________________________________________________
# conv2d_1228 (Conv2D)         (None, 48, 48, 216)       400680
# _________________________________________________________________
# max_pooling2d_472 (MaxPoolin (None, 24, 24, 216)       0
# _________________________________________________________________
# conv2d_1229 (Conv2D)         (None, 24, 24, 260)       505700
# _________________________________________________________________
# conv2d_1230 (Conv2D)         (None, 24, 24, 364)       852124
# _________________________________________________________________
# conv2d_1231 (Conv2D)         (None, 24, 24, 390)       1278030
# _________________________________________________________________
# max_pooling2d_473 (MaxPoolin (None, 12, 12, 390)       0
# _________________________________________________________________
# conv2d_1232 (Conv2D)         (None, 12, 12, 450)       1579950
# _________________________________________________________________
# conv2d_1233 (Conv2D)         (None, 12, 12, 460)       1863460
# _________________________________________________________________
# conv2d_1234 (Conv2D)         (None, 12, 12, 182)       753662
# _________________________________________________________________
# max_pooling2d_474 (MaxPoolin (None, 6, 6, 182)         0
# _________________________________________________________________
# flatten_94 (Flatten)         (None, 6552)              0
# _________________________________________________________________
# dense_280 (Dense)            (None, 1552)              10170256
# _________________________________________________________________
# dense_281 (Dense)            (None, 1456)              2261168
# _________________________________________________________________
# dense_282 (Dense)            (None, 10)                14570
# =================================================================
# Total params: 20,310,060
# Trainable params: 20,310,060
# Non-trainable params: 0
# _________________________________________________________________
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 4s 442ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 8s 8s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# ...
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        [(None, 256, 256, 1)]     0
# _________________________________________________________________
# conv2d_1495 (Conv2D)         (None, 256, 256, 40)      400
# _________________________________________________________________
# conv2d_1496 (Conv2D)         (None, 256, 256, 40)      14440
# _________________________________________________________________
# max_pooling2d_575 (MaxPoolin (None, 128, 128, 40)      0
# _________________________________________________________________
# conv2d_1497 (Conv2D)         (None, 128, 128, 80)      28880
# _________________________________________________________________
# conv2d_1498 (Conv2D)         (None, 128, 128, 118)     85078
# _________________________________________________________________
# max_pooling2d_576 (MaxPoolin (None, 64, 64, 118)       0
# _________________________________________________________________
# conv2d_1499 (Conv2D)         (None, 64, 64, 216)       229608
# _________________________________________________________________
# conv2d_1500 (Conv2D)         (None, 64, 64, 234)       455130
# _________________________________________________________________
# conv2d_1501 (Conv2D)         (None, 64, 64, 238)       501466
# _________________________________________________________________
# max_pooling2d_577 (MaxPoolin (None, 32, 32, 238)       0
# _________________________________________________________________
# conv2d_1502 (Conv2D)         (None, 32, 32, 336)       720048
# _________________________________________________________________
# conv2d_1503 (Conv2D)         (None, 32, 32, 428)       1294700
# _________________________________________________________________
# conv2d_1504 (Conv2D)         (None, 32, 32, 458)       1764674
# _________________________________________________________________
# max_pooling2d_578 (MaxPoolin (None, 16, 16, 458)       0
# _________________________________________________________________
# conv2d_1505 (Conv2D)         (None, 16, 16, 470)       1937810
# _________________________________________________________________
# conv2d_1506 (Conv2D)         (None, 16, 16, 498)       2107038
# _________________________________________________________________
# conv2d_1507 (Conv2D)         (None, 16, 16, 134)       600722
# _________________________________________________________________
# max_pooling2d_579 (MaxPoolin (None, 8, 8, 134)         0
# _________________________________________________________________
# flatten_115 (Flatten)        (None, 8576)              0
# _________________________________________________________________
# dense_343 (Dense)            (None, 2608)              22368816
# _________________________________________________________________
# dense_344 (Dense)            (None, 1296)              3381264
# _________________________________________________________________
# dense_345 (Dense)            (None, 10)                12970
# =================================================================
# Total params: 35,503,044
# Trainable params: 35,503,044
# Non-trainable params: 0
# _________________________________________________________________
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 5s 561ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 9s 9s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 40/40 [00:00<00:00, 24866.19it/s]
# [INFO] infer shape (NHWC)  :100%|█| 67/67 [00:00<00:00, 641.96it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 248.85it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 931.96it/s]
# [INFO] generate xmodel     :100%|█| 67/67 [00:01<00:00, 39.18it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_114, with op num: 125
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 689059efbbd0d1f4688cd20a033b396d, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/md5sum.txt"
# Model: "model_115"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_14 (InputLayer)        [(None, 288, 288, 1)]     0
# _________________________________________________________________
# conv2d_1508 (Conv2D)         (None, 288, 288, 40)      400
# _________________________________________________________________
# conv2d_1509 (Conv2D)         (None, 288, 288, 50)      18050
# _________________________________________________________________
# max_pooling2d_580 (MaxPoolin (None, 144, 144, 50)      0
# _________________________________________________________________
# conv2d_1510 (Conv2D)         (None, 144, 144, 78)      35178
# _________________________________________________________________
# conv2d_1511 (Conv2D)         (None, 144, 144, 82)      57646
# _________________________________________________________________
# max_pooling2d_581 (MaxPoolin (None, 72, 72, 82)        0
# _________________________________________________________________
# conv2d_1512 (Conv2D)         (None, 72, 72, 128)       94592
# _________________________________________________________________
# conv2d_1513 (Conv2D)         (None, 72, 72, 156)       179868
# _________________________________________________________________
# conv2d_1514 (Conv2D)         (None, 72, 72, 156)       219180
# _________________________________________________________________
# max_pooling2d_582 (MaxPoolin (None, 36, 36, 156)       0
# _________________________________________________________________
# conv2d_1515 (Conv2D)         (None, 36, 36, 186)       261330
# _________________________________________________________________
# conv2d_1516 (Conv2D)         (None, 36, 36, 292)       489100
# _________________________________________________________________
# conv2d_1517 (Conv2D)         (None, 36, 36, 322)       846538
# _________________________________________________________________
# max_pooling2d_583 (MaxPoolin (None, 18, 18, 322)       0
# _________________________________________________________________
# conv2d_1518 (Conv2D)         (None, 18, 18, 336)       974064
# _________________________________________________________________
# conv2d_1519 (Conv2D)         (None, 18, 18, 402)       1216050
# _________________________________________________________________
# conv2d_1520 (Conv2D)         (None, 18, 18, 220)       796180
# _________________________________________________________________
# max_pooling2d_584 (MaxPoolin (None, 9, 9, 220)         0
# _________________________________________________________________
# flatten_116 (Flatten)        (None, 17820)             0
# _________________________________________________________________
# dense_346 (Dense)            (None, 2800)              49898800
# _________________________________________________________________
# dense_347 (Dense)            (None, 1552)              4347152
# _________________________________________________________________
# dense_348 (Dense)            (None, 10)                15530
# =================================================================
# Total params: 59,449,658
# Trainable params: 59,449,658
# Non-trainable params: 0
# _________________________________________________________________
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 5s 574ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 9s 9s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 40/40 [00:00<00:00, 23899.17it/s]
# [INFO] infer shape (NHWC)  :100%|█| 67/67 [00:00<00:00, 264.24it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 262.03it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1016.19it/s]
# [INFO] generate xmodel     :100%|█| 67/67 [00:03<00:00, 19.02it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_115, with op num: 125
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is d49bb74507020beafa8d87d4ff36a827, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg16/md5sum.txt"
# Model: "model_116"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_14 (InputLayer)        [(None, 288, 288, 1)]     0
# _________________________________________________________________
# conv2d_1521 (Conv2D)         (None, 288, 288, 42)      420
# _________________________________________________________________
# conv2d_1522 (Conv2D)         (None, 288, 288, 54)      20466
# _________________________________________________________________
# max_pooling2d_585 (MaxPoolin (None, 144, 144, 54)      0
# _________________________________________________________________
# conv2d_1523 (Conv2D)         (None, 144, 144, 64)      31168
# _________________________________________________________________
# conv2d_1524 (Conv2D)         (None, 144, 144, 92)      53084
# _________________________________________________________________
# max_pooling2d_586 (MaxPoolin (None, 72, 72, 92)        0
# _________________________________________________________________
# conv2d_1525 (Conv2D)         (None, 72, 72, 242)       200618
# _________________________________________________________________
# conv2d_1526 (Conv2D)         (None, 72, 72, 244)       531676
# _________________________________________________________________
# conv2d_1527 (Conv2D)         (None, 72, 72, 244)       536068
# _________________________________________________________________
# max_pooling2d_587 (MaxPoolin (None, 36, 36, 244)       0
# _________________________________________________________________
# conv2d_1528 (Conv2D)         (None, 36, 36, 368)       808496
# _________________________________________________________________
# conv2d_1529 (Conv2D)         (None, 36, 36, 388)       1285444
# _________________________________________________________________
# conv2d_1530 (Conv2D)         (None, 36, 36, 488)       1704584
# _________________________________________________________________
# max_pooling2d_588 (MaxPoolin (None, 18, 18, 488)       0
# _________________________________________________________________
# conv2d_1531 (Conv2D)         (None, 18, 18, 490)       2152570
# _________________________________________________________________
# conv2d_1532 (Conv2D)         (None, 18, 18, 504)       2223144
# _________________________________________________________________
# conv2d_1533 (Conv2D)         (None, 18, 18, 174)       789438
# _________________________________________________________________
# max_pooling2d_589 (MaxPoolin (None, 9, 9, 174)         0
# _________________________________________________________________
# flatten_117 (Flatten)        (None, 14094)             0
# _________________________________________________________________
# dense_349 (Dense)            (None, 2736)              38563920
# _________________________________________________________________
# dense_350 (Dense)            (None, 1712)              4685744
# _________________________________________________________________
# dense_351 (Dense)            (None, 10)                17130
# =================================================================
# Total params: 53,603,970
# Trainable params: 53,603,970
# Non-trainable params: 0
# _________________________________________________________________
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 5s 584ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 11s 11s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 40/40 [00:00<00:00, 26804.95it/s]
# [INFO] infer shape (NHWC)  :100%|█| 67/67 [00:00<00:00, 467.51it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 260.56it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 952.28it/s]
# [INFO] generate xmodel     :100%|█| 67/67 [00:02<00:00, 23.84it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_116, with op num: 125
# [UNILOG][INFO] Begin to compile...
