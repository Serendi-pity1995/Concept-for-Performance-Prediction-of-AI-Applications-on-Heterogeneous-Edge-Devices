# %%
import os
import numpy as np
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from itertools import product
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, ZeroPadding2D, Activation, Dropout
from tensorflow_model_optimization.quantization.keras import vitis_quantize
import tensorflow_model_optimization as tfmot

shape_range =range(48,220,34)

for shape_x in shape_range:
    
    shape_y = shape_x
    X_train=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
    Y_train=np.random.randint(0,10,size=[60,])
    X_test=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
    Y_test=np.random.randint(0,10,size=[60,])
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
    X_train /= 255.0
    X_test /= 255.0


    inputs = Input(shape=(shape_x, shape_y, 1))
    for step in range(1,5):
        zeroPadding1 = ZeroPadding2D(padding=1)(inputs)
        conv1_kernel_num = random.randrange(32,64,2)
        conv1 = Conv2D(conv1_kernel_num, (3,3), padding='same', activation='relu')(zeroPadding1)
        pool1 = MaxPooling2D(pool_size=2)(conv1)

        zeroPadding2 = ZeroPadding2D(padding=1)(pool1)
        conv2_kernel_num = random.randrange(conv1_kernel_num,128,2)
        conv2 = Conv2D(conv2_kernel_num, (3,3), padding='same', activation='relu')(zeroPadding2)
        pool2 = MaxPooling2D(pool_size=2)(conv2)

        zeroPadding3 = ZeroPadding2D(padding=1)(pool2)
        conv3_kernel_num = random.randrange(conv2_kernel_num,256,2)
        conv3 = Conv2D(conv3_kernel_num, (3,3), padding='same', activation='relu')(zeroPadding3)

        zeroPadding4 = ZeroPadding2D(padding=1)(conv3)
        conv4_kernel_num = random.randrange(conv3_kernel_num,256,2)
        conv4 = Conv2D(conv4_kernel_num, (3,3), padding='same', activation='relu')(zeroPadding4)
        pool3 = MaxPooling2D(pool_size=2)(conv4)

        zeroPadding5 = ZeroPadding2D(padding=1)(pool3)
        conv5_kernel_num = random.randrange(conv4_kernel_num,512,2)
        conv5 = Conv2D(conv5_kernel_num, (3,3), padding='same', activation='relu')(zeroPadding5)

        zeroPadding6 = ZeroPadding2D(padding=1)(conv5)
        conv6_kernel_num = random.randrange(conv5_kernel_num,512,2)
        conv6 = Conv2D(conv6_kernel_num, (3,3), padding='same', activation='relu')(zeroPadding6)
        pool4 = MaxPooling2D(pool_size=2)(conv6)

        zeroPadding7 = ZeroPadding2D(padding=1)(pool4)
        conv7_kernel_num = random.randrange(conv5_kernel_num,512,2)
        conv7 = Conv2D(conv7_kernel_num, (3,3), padding='same', activation='relu')(zeroPadding7)

        zeroPadding8 = ZeroPadding2D(padding=1)(conv7)
        conv8_kernel_num = random.randrange(conv7_kernel_num,512,2)
        conv8 = Conv2D(conv8_kernel_num, (3,3), padding='same', activation='relu')(zeroPadding8)
        pool5 = MaxPooling2D(pool_size=2)(conv8)

        conv9_kernel_num = random.randrange(conv8_kernel_num,4096,2)
        conv9 = Conv2D(conv9_kernel_num, (7,7), padding='same', activation='relu')(pool5)
        drop1 = Dropout(0.5)(conv9)

        conv10_kernel_num = random.randrange(conv9_kernel_num,4096,2)
        conv10 = Conv2D(conv10_kernel_num, (1,1), padding='same', activation='relu')(pool5)
        drop2 = Dropout(0.5)(conv10)

        conv11 = Conv2D(10, (1,1))(drop2)

        flat = Flatten()(conv11)

        outputs = Dense(10, activation = 'softmax')(flat)


        model = Model(inputs=inputs, outputs=outputs)
        model.summary()
        model.save('./vgg11_h5/vgg11_{input_x}_{input_y}_{step}.h5'.format(input_x=shape_x,input_y=shape_y,step=step))
#         model.compile(optimizer='adam',
#                   loss="sparse_categorical_crossentropy", 
#                   metrics=['accuracy'])
#         history = model.fit(X_train, Y_train, epochs=1)
#         model.get_weights()[0].dtype
        quantizer = vitis_quantize.VitisQuantizer(model)
        quantized_model = quantizer.quantize_model(calib_dataset = X_test[1:8], weight_bit=8, activation_bit=8)
#         quantized_model.compile(loss='sparse_categorical_crossentropy', metrics=["accuracy"])
        quantized_model.save('quantized.h5')
        # !vai_c_tensorflow2 \
                --model ./quantized.h5 \
                --arch ./arch.json \
                --output_dir ./xmodel_vgg11 \
                --net_name deploy
        os.rename("./xmodel_vgg11/deploy.xmodel","./xmodel_vgg11/vgg11_{input_x}_{input_y}_{step}.xmodel".format(input_x=shape_x,input_y=shape_y,step=step))
# Out:
# Model: "model_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 48, 48, 1)]       0
# _________________________________________________________________
# zero_padding2d_96 (ZeroPaddi (None, 50, 50, 1)         0
# _________________________________________________________________
# conv2d_132 (Conv2D)          (None, 50, 50, 62)        620
# _________________________________________________________________
# max_pooling2d_60 (MaxPooling (None, 25, 25, 62)        0
# _________________________________________________________________
# zero_padding2d_97 (ZeroPaddi (None, 27, 27, 62)        0
# _________________________________________________________________
# conv2d_133 (Conv2D)          (None, 27, 27, 108)       60372
# _________________________________________________________________
# max_pooling2d_61 (MaxPooling (None, 13, 13, 108)       0
# _________________________________________________________________
# zero_padding2d_98 (ZeroPaddi (None, 15, 15, 108)       0
# _________________________________________________________________
# conv2d_134 (Conv2D)          (None, 15, 15, 138)       134274
# _________________________________________________________________
# zero_padding2d_99 (ZeroPaddi (None, 17, 17, 138)       0
# _________________________________________________________________
# conv2d_135 (Conv2D)          (None, 17, 17, 216)       268488
# _________________________________________________________________
# max_pooling2d_62 (MaxPooling (None, 8, 8, 216)         0
# _________________________________________________________________
# zero_padding2d_100 (ZeroPadd (None, 10, 10, 216)       0
# _________________________________________________________________
# conv2d_136 (Conv2D)          (None, 10, 10, 494)       960830
# _________________________________________________________________
# zero_padding2d_101 (ZeroPadd (None, 12, 12, 494)       0
# _________________________________________________________________
# conv2d_137 (Conv2D)          (None, 12, 12, 500)       2223500
# _________________________________________________________________
# max_pooling2d_63 (MaxPooling (None, 6, 6, 500)         0
# _________________________________________________________________
# zero_padding2d_102 (ZeroPadd (None, 8, 8, 500)         0
# _________________________________________________________________
# conv2d_138 (Conv2D)          (None, 8, 8, 508)         2286508
# _________________________________________________________________
# zero_padding2d_103 (ZeroPadd (None, 10, 10, 508)       0
# _________________________________________________________________
# conv2d_139 (Conv2D)          (None, 10, 10, 508)       2323084
# _________________________________________________________________
# max_pooling2d_64 (MaxPooling (None, 5, 5, 508)         0
# _________________________________________________________________
# conv2d_141 (Conv2D)          (None, 5, 5, 3724)        1895516
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 5, 5, 3724)        0
# _________________________________________________________________
# conv2d_142 (Conv2D)          (None, 5, 5, 10)          37250
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 250)               0
# _________________________________________________________________
# activation_12 (Activation)   (None, 250)               0
# =================================================================
# Total params: 10,190,442
# Trainable params: 10,190,442
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 240ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 4s 4s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 36/36 [00:00<00:00, 27807.54it/s]
# [INFO] infer shape (NHWC)  :100%|█| 51/51 [00:00<00:00, 11509.79it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 362.84it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1345.84it/s]
# [INFO] generate xmodel     :100%|█| 51/51 [00:00<00:00, 828.96it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_12, with op num: 91
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_142, type = conv2d-fix} has been assigned to CPU: [DPU only supports "input_channel"(3724) less than 3072].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_142_weights, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_142_bias, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 1f1b752292f9d233f0177314a76c124e, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 48, 48, 1)]       0
# _________________________________________________________________
# zero_padding2d_104 (ZeroPadd (None, 50, 50, 1)         0
# _________________________________________________________________
# conv2d_143 (Conv2D)          (None, 50, 50, 46)        460
# _________________________________________________________________
# max_pooling2d_65 (MaxPooling (None, 25, 25, 46)        0
# _________________________________________________________________
# zero_padding2d_105 (ZeroPadd (None, 27, 27, 46)        0
# _________________________________________________________________
# conv2d_144 (Conv2D)          (None, 27, 27, 108)       44820
# _________________________________________________________________
# max_pooling2d_66 (MaxPooling (None, 13, 13, 108)       0
# _________________________________________________________________
# zero_padding2d_106 (ZeroPadd (None, 15, 15, 108)       0
# _________________________________________________________________
# conv2d_145 (Conv2D)          (None, 15, 15, 228)       221844
# _________________________________________________________________
# zero_padding2d_107 (ZeroPadd (None, 17, 17, 228)       0
# _________________________________________________________________
# conv2d_146 (Conv2D)          (None, 17, 17, 250)       513250
# _________________________________________________________________
# max_pooling2d_67 (MaxPooling (None, 8, 8, 250)         0
# _________________________________________________________________
# zero_padding2d_108 (ZeroPadd (None, 10, 10, 250)       0
# _________________________________________________________________
# conv2d_147 (Conv2D)          (None, 10, 10, 464)       1044464
# _________________________________________________________________
# zero_padding2d_109 (ZeroPadd (None, 12, 12, 464)       0
# _________________________________________________________________
# conv2d_148 (Conv2D)          (None, 12, 12, 476)       1988252
# _________________________________________________________________
# max_pooling2d_68 (MaxPooling (None, 6, 6, 476)         0
# _________________________________________________________________
# zero_padding2d_110 (ZeroPadd (None, 8, 8, 476)         0
# _________________________________________________________________
# conv2d_149 (Conv2D)          (None, 8, 8, 470)         2013950
# _________________________________________________________________
# zero_padding2d_111 (ZeroPadd (None, 10, 10, 470)       0
# _________________________________________________________________
# conv2d_150 (Conv2D)          (None, 10, 10, 482)       2039342
# _________________________________________________________________
# max_pooling2d_69 (MaxPooling (None, 5, 5, 482)         0
# _________________________________________________________________
# conv2d_152 (Conv2D)          (None, 5, 5, 3050)        1473150
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 5, 5, 3050)        0
# _________________________________________________________________
# conv2d_153 (Conv2D)          (None, 5, 5, 10)          30510
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 250)               0
# _________________________________________________________________
# activation_13 (Activation)   (None, 250)               0
# =================================================================
# Total params: 9,370,042
# Trainable params: 9,370,042
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 236ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 4s 4s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 36/36 [00:00<00:00, 28538.07it/s]
# [INFO] infer shape (NHWC)  :100%|█| 51/51 [00:00<00:00, 11058.18it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 359.26it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1332.37it/s]
# [INFO] generate xmodel     :100%|█| 51/51 [00:00<00:00, 891.14it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_13, with op num: 91
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 831f7627c3aa1846404c254943024e31, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 48, 48, 1)]       0
# _________________________________________________________________
# zero_padding2d_112 (ZeroPadd (None, 50, 50, 1)         0
# _________________________________________________________________
# conv2d_154 (Conv2D)          (None, 50, 50, 44)        440
# _________________________________________________________________
# max_pooling2d_70 (MaxPooling (None, 25, 25, 44)        0
# _________________________________________________________________
# zero_padding2d_113 (ZeroPadd (None, 27, 27, 44)        0
# _________________________________________________________________
# conv2d_155 (Conv2D)          (None, 27, 27, 116)       46052
# _________________________________________________________________
# max_pooling2d_71 (MaxPooling (None, 13, 13, 116)       0
# _________________________________________________________________
# zero_padding2d_114 (ZeroPadd (None, 15, 15, 116)       0
# _________________________________________________________________
# conv2d_156 (Conv2D)          (None, 15, 15, 164)       171380
# _________________________________________________________________
# zero_padding2d_115 (ZeroPadd (None, 17, 17, 164)       0
# _________________________________________________________________
# conv2d_157 (Conv2D)          (None, 17, 17, 216)       319032
# _________________________________________________________________
# max_pooling2d_72 (MaxPooling (None, 8, 8, 216)         0
# _________________________________________________________________
# zero_padding2d_116 (ZeroPadd (None, 10, 10, 216)       0
# _________________________________________________________________
# conv2d_158 (Conv2D)          (None, 10, 10, 354)       688530
# _________________________________________________________________
# zero_padding2d_117 (ZeroPadd (None, 12, 12, 354)       0
# _________________________________________________________________
# conv2d_159 (Conv2D)          (None, 12, 12, 486)       1548882
# _________________________________________________________________
# max_pooling2d_73 (MaxPooling (None, 6, 6, 486)         0
# _________________________________________________________________
# zero_padding2d_118 (ZeroPadd (None, 8, 8, 486)         0
# _________________________________________________________________
# conv2d_160 (Conv2D)          (None, 8, 8, 472)         2065000
# _________________________________________________________________
# zero_padding2d_119 (ZeroPadd (None, 10, 10, 472)       0
# _________________________________________________________________
# conv2d_161 (Conv2D)          (None, 10, 10, 486)       2065014
# _________________________________________________________________
# max_pooling2d_74 (MaxPooling (None, 5, 5, 486)         0
# _________________________________________________________________
# conv2d_163 (Conv2D)          (None, 5, 5, 3942)        1919754
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 5, 5, 3942)        0
# _________________________________________________________________
# conv2d_164 (Conv2D)          (None, 5, 5, 10)          39430
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 250)               0
# _________________________________________________________________
# activation_14 (Activation)   (None, 250)               0
# =================================================================
# Total params: 8,863,514
# Trainable params: 8,863,514
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 236ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 4s 4s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 36/36 [00:00<00:00, 28870.93it/s]
# [INFO] infer shape (NHWC)  :100%|█| 51/51 [00:00<00:00, 13124.09it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 359.93it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1356.50it/s]
# [INFO] generate xmodel     :100%|█| 51/51 [00:00<00:00, 1015.21it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_14, with op num: 91
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_164, type = conv2d-fix} has been assigned to CPU: [DPU only supports "input_channel"(3942) less than 3072].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_164_weights, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_164_bias, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is adf93ef89e112c8b1002903eade5c167, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 48, 48, 1)]       0
# _________________________________________________________________
# zero_padding2d_120 (ZeroPadd (None, 50, 50, 1)         0
# _________________________________________________________________
# conv2d_165 (Conv2D)          (None, 50, 50, 60)        600
# _________________________________________________________________
# max_pooling2d_75 (MaxPooling (None, 25, 25, 60)        0
# _________________________________________________________________
# zero_padding2d_121 (ZeroPadd (None, 27, 27, 60)        0
# _________________________________________________________________
# conv2d_166 (Conv2D)          (None, 27, 27, 78)        42198
# _________________________________________________________________
# max_pooling2d_76 (MaxPooling (None, 13, 13, 78)        0
# _________________________________________________________________
# zero_padding2d_122 (ZeroPadd (None, 15, 15, 78)        0
# _________________________________________________________________
# conv2d_167 (Conv2D)          (None, 15, 15, 116)       81548
# _________________________________________________________________
# zero_padding2d_123 (ZeroPadd (None, 17, 17, 116)       0
# _________________________________________________________________
# conv2d_168 (Conv2D)          (None, 17, 17, 168)       175560
# _________________________________________________________________
# max_pooling2d_77 (MaxPooling (None, 8, 8, 168)         0
# _________________________________________________________________
# zero_padding2d_124 (ZeroPadd (None, 10, 10, 168)       0
# _________________________________________________________________
# conv2d_169 (Conv2D)          (None, 10, 10, 216)       326808
# _________________________________________________________________
# zero_padding2d_125 (ZeroPadd (None, 12, 12, 216)       0
# _________________________________________________________________
# conv2d_170 (Conv2D)          (None, 12, 12, 498)       968610
# _________________________________________________________________
# max_pooling2d_78 (MaxPooling (None, 6, 6, 498)         0
# _________________________________________________________________
# zero_padding2d_126 (ZeroPadd (None, 8, 8, 498)         0
# _________________________________________________________________
# conv2d_171 (Conv2D)          (None, 8, 8, 220)         986260
# _________________________________________________________________
# zero_padding2d_127 (ZeroPadd (None, 10, 10, 220)       0
# _________________________________________________________________
# conv2d_172 (Conv2D)          (None, 10, 10, 494)       978614
# _________________________________________________________________
# max_pooling2d_79 (MaxPooling (None, 5, 5, 494)         0
# _________________________________________________________________
# conv2d_174 (Conv2D)          (None, 5, 5, 4054)        2006730
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 5, 5, 4054)        0
# _________________________________________________________________
# conv2d_175 (Conv2D)          (None, 5, 5, 10)          40550
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 250)               0
# _________________________________________________________________
# activation_15 (Activation)   (None, 250)               0
# =================================================================
# Total params: 5,607,478
# Trainable params: 5,607,478
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 228ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 4s 4s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 36/36 [00:00<00:00, 28446.67it/s]
# [INFO] infer shape (NHWC)  :100%|█| 51/51 [00:00<00:00, 10595.35it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 352.36it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1322.71it/s]
# [INFO] generate xmodel     :100%|█| 51/51 [00:00<00:00, 1240.67it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_15, with op num: 91
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_175, type = conv2d-fix} has been assigned to CPU: [DPU only supports "input_channel"(4054) less than 3072].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_175_weights, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_175_bias, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 6b868949543f2d0c0928f0131431870e, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 82, 82, 1)]       0
# _________________________________________________________________
# zero_padding2d_128 (ZeroPadd (None, 84, 84, 1)         0
# _________________________________________________________________
# conv2d_176 (Conv2D)          (None, 84, 84, 44)        440
# _________________________________________________________________
# max_pooling2d_80 (MaxPooling (None, 42, 42, 44)        0
# _________________________________________________________________
# zero_padding2d_129 (ZeroPadd (None, 44, 44, 44)        0
# _________________________________________________________________
# conv2d_177 (Conv2D)          (None, 44, 44, 88)        34936
# _________________________________________________________________
# max_pooling2d_81 (MaxPooling (None, 22, 22, 88)        0
# _________________________________________________________________
# zero_padding2d_130 (ZeroPadd (None, 24, 24, 88)        0
# _________________________________________________________________
# conv2d_178 (Conv2D)          (None, 24, 24, 230)       182390
# _________________________________________________________________
# zero_padding2d_131 (ZeroPadd (None, 26, 26, 230)       0
# _________________________________________________________________
# conv2d_179 (Conv2D)          (None, 26, 26, 244)       505324
# _________________________________________________________________
# max_pooling2d_82 (MaxPooling (None, 13, 13, 244)       0
# _________________________________________________________________
# zero_padding2d_132 (ZeroPadd (None, 15, 15, 244)       0
# _________________________________________________________________
# conv2d_180 (Conv2D)          (None, 15, 15, 388)       852436
# _________________________________________________________________
# zero_padding2d_133 (ZeroPadd (None, 17, 17, 388)       0
# _________________________________________________________________
# conv2d_181 (Conv2D)          (None, 17, 17, 448)       1564864
# _________________________________________________________________
# max_pooling2d_83 (MaxPooling (None, 8, 8, 448)         0
# _________________________________________________________________
# zero_padding2d_134 (ZeroPadd (None, 10, 10, 448)       0
# _________________________________________________________________
# conv2d_182 (Conv2D)          (None, 10, 10, 424)       1709992
# _________________________________________________________________
# zero_padding2d_135 (ZeroPadd (None, 12, 12, 424)       0
# _________________________________________________________________
# conv2d_183 (Conv2D)          (None, 12, 12, 492)       1877964
# _________________________________________________________________
# max_pooling2d_84 (MaxPooling (None, 6, 6, 492)         0
# _________________________________________________________________
# conv2d_185 (Conv2D)          (None, 6, 6, 3978)        1961154
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 6, 6, 3978)        0
# _________________________________________________________________
# conv2d_186 (Conv2D)          (None, 6, 6, 10)          39790
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 360)               0
# _________________________________________________________________
# activation_16 (Activation)   (None, 360)               0
# =================================================================
# Total params: 8,729,290
# Trainable params: 8,729,290
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 250ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 4s 4s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 36/36 [00:00<00:00, 28559.66it/s]
# [INFO] infer shape (NHWC)  :100%|█| 51/51 [00:00<00:00, 4673.78it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 338.97it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1343.04it/s]
# [INFO] generate xmodel     :100%|█| 51/51 [00:00<00:00, 854.76it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_16, with op num: 91
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_186, type = conv2d-fix} has been assigned to CPU: [DPU only supports "input_channel"(3978) less than 3072].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_186_weights, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_186_bias, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is e104736c50ab9937beb7513036b07fd5, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 82, 82, 1)]       0
# _________________________________________________________________
# zero_padding2d_136 (ZeroPadd (None, 84, 84, 1)         0
# _________________________________________________________________
# conv2d_187 (Conv2D)          (None, 84, 84, 38)        380
# _________________________________________________________________
# max_pooling2d_85 (MaxPooling (None, 42, 42, 38)        0
# _________________________________________________________________
# zero_padding2d_137 (ZeroPadd (None, 44, 44, 38)        0
# _________________________________________________________________
# conv2d_188 (Conv2D)          (None, 44, 44, 82)        28126
# _________________________________________________________________
# max_pooling2d_86 (MaxPooling (None, 22, 22, 82)        0
# _________________________________________________________________
# zero_padding2d_138 (ZeroPadd (None, 24, 24, 82)        0
# _________________________________________________________________
# conv2d_189 (Conv2D)          (None, 24, 24, 92)        67988
# _________________________________________________________________
# zero_padding2d_139 (ZeroPadd (None, 26, 26, 92)        0
# _________________________________________________________________
# conv2d_190 (Conv2D)          (None, 26, 26, 228)       189012
# _________________________________________________________________
# max_pooling2d_87 (MaxPooling (None, 13, 13, 228)       0
# _________________________________________________________________
# zero_padding2d_140 (ZeroPadd (None, 15, 15, 228)       0
# _________________________________________________________________
# conv2d_191 (Conv2D)          (None, 15, 15, 398)       817094
# _________________________________________________________________
# zero_padding2d_141 (ZeroPadd (None, 17, 17, 398)       0
# _________________________________________________________________
# conv2d_192 (Conv2D)          (None, 17, 17, 466)       1669678
# _________________________________________________________________
# max_pooling2d_88 (MaxPooling (None, 8, 8, 466)         0
# _________________________________________________________________
# zero_padding2d_142 (ZeroPadd (None, 10, 10, 466)       0
# _________________________________________________________________
# conv2d_193 (Conv2D)          (None, 10, 10, 496)       2080720
# _________________________________________________________________
# zero_padding2d_143 (ZeroPadd (None, 12, 12, 496)       0
# _________________________________________________________________
# conv2d_194 (Conv2D)          (None, 12, 12, 502)       2241430
# _________________________________________________________________
# max_pooling2d_89 (MaxPooling (None, 6, 6, 502)         0
# _________________________________________________________________
# conv2d_196 (Conv2D)          (None, 6, 6, 3604)        1812812
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 6, 6, 3604)        0
# _________________________________________________________________
# conv2d_197 (Conv2D)          (None, 6, 6, 10)          36050
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 360)               0
# _________________________________________________________________
# activation_17 (Activation)   (None, 360)               0
# =================================================================
# Total params: 8,943,290
# Trainable params: 8,943,290
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 246ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 4s 4s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 36/36 [00:00<00:00, 27418.73it/s]
# [INFO] infer shape (NHWC)  :100%|█| 51/51 [00:00<00:00, 6036.84it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 352.11it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1321.04it/s]
# [INFO] generate xmodel     :100%|█| 51/51 [00:00<00:00, 949.13it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_17, with op num: 91
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_197, type = conv2d-fix} has been assigned to CPU: [DPU only supports "input_channel"(3604) less than 3072].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_197_weights, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_197_bias, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is e384c9b8b27d14109400168694f006a7, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 82, 82, 1)]       0
# _________________________________________________________________
# zero_padding2d_144 (ZeroPadd (None, 84, 84, 1)         0
# _________________________________________________________________
# conv2d_198 (Conv2D)          (None, 84, 84, 48)        480
# _________________________________________________________________
# max_pooling2d_90 (MaxPooling (None, 42, 42, 48)        0
# _________________________________________________________________
# zero_padding2d_145 (ZeroPadd (None, 44, 44, 48)        0
# _________________________________________________________________
# conv2d_199 (Conv2D)          (None, 44, 44, 114)       49362
# _________________________________________________________________
# max_pooling2d_91 (MaxPooling (None, 22, 22, 114)       0
# _________________________________________________________________
# zero_padding2d_146 (ZeroPadd (None, 24, 24, 114)       0
# _________________________________________________________________
# conv2d_200 (Conv2D)          (None, 24, 24, 192)       197184
# _________________________________________________________________
# zero_padding2d_147 (ZeroPadd (None, 26, 26, 192)       0
# _________________________________________________________________
# conv2d_201 (Conv2D)          (None, 26, 26, 214)       370006
# _________________________________________________________________
# max_pooling2d_92 (MaxPooling (None, 13, 13, 214)       0
# _________________________________________________________________
# zero_padding2d_148 (ZeroPadd (None, 15, 15, 214)       0
# _________________________________________________________________
# conv2d_202 (Conv2D)          (None, 15, 15, 242)       466334
# _________________________________________________________________
# zero_padding2d_149 (ZeroPadd (None, 17, 17, 242)       0
# _________________________________________________________________
# conv2d_203 (Conv2D)          (None, 17, 17, 280)       610120
# _________________________________________________________________
# max_pooling2d_93 (MaxPooling (None, 8, 8, 280)         0
# _________________________________________________________________
# zero_padding2d_150 (ZeroPadd (None, 10, 10, 280)       0
# _________________________________________________________________
# conv2d_204 (Conv2D)          (None, 10, 10, 274)       690754
# _________________________________________________________________
# zero_padding2d_151 (ZeroPadd (None, 12, 12, 274)       0
# _________________________________________________________________
# conv2d_205 (Conv2D)          (None, 12, 12, 484)       1194028
# _________________________________________________________________
# max_pooling2d_94 (MaxPooling (None, 6, 6, 484)         0
# _________________________________________________________________
# conv2d_207 (Conv2D)          (None, 6, 6, 3896)        1889560
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 6, 6, 3896)        0
# _________________________________________________________________
# conv2d_208 (Conv2D)          (None, 6, 6, 10)          38970
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 360)               0
# _________________________________________________________________
# activation_18 (Activation)   (None, 360)               0
# =================================================================
# Total params: 5,506,798
# Trainable params: 5,506,798
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 247ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 4s 4s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 34/34 [00:00<00:00, 23763.76it/s]
# [INFO] infer shape (NHWC)  :100%|█| 58/58 [00:00<00:00, 5050.34it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 252.66it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1076.43it/s]
# [INFO] generate xmodel     :100%|█| 58/58 [00:00<00:00, 223.67it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_2, with op num: 104
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is be94be3b1464976bcb381cfa4c8b20a3, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 82, 82, 1)]       0
# _________________________________________________________________
# zero_padding2d_152 (ZeroPadd (None, 84, 84, 1)         0
# _________________________________________________________________
# conv2d_209 (Conv2D)          (None, 84, 84, 62)        620
# _________________________________________________________________
# max_pooling2d_95 (MaxPooling (None, 42, 42, 62)        0
# _________________________________________________________________
# zero_padding2d_153 (ZeroPadd (None, 44, 44, 62)        0
# _________________________________________________________________
# conv2d_210 (Conv2D)          (None, 44, 44, 118)       65962
# _________________________________________________________________
# max_pooling2d_96 (MaxPooling (None, 22, 22, 118)       0
# ...
# _________________________________________________________________
# activation_33 (Activation)   (None, 1000)              0
# =================================================================
# Total params: 8,367,866
# Trainable params: 8,367,866
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 246ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 5s 5s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 36/36 [00:00<00:00, 27225.92it/s]
# [INFO] infer shape (NHWC)  :100%|█| 51/51 [00:00<00:00, 1431.39it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 340.52it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1270.04it/s]
# [INFO] generate xmodel     :100%|█| 51/51 [00:00<00:00, 994.10it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_33, with op num: 91
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_373, type = conv2d-fix} has been assigned to CPU: [DPU only supports "input_channel"(3366) less than 3072].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_373_weights, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_373_bias, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 8e5c589c72fd7c037a97dca74639ed4a, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 218, 218, 1)]     0
# _________________________________________________________________
# zero_padding2d_272 (ZeroPadd (None, 220, 220, 1)       0
# _________________________________________________________________
# conv2d_374 (Conv2D)          (None, 220, 220, 36)      360
# _________________________________________________________________
# max_pooling2d_170 (MaxPoolin (None, 110, 110, 36)      0
# _________________________________________________________________
# zero_padding2d_273 (ZeroPadd (None, 112, 112, 36)      0
# _________________________________________________________________
# conv2d_375 (Conv2D)          (None, 112, 112, 124)     40300
# _________________________________________________________________
# max_pooling2d_171 (MaxPoolin (None, 56, 56, 124)       0
# _________________________________________________________________
# zero_padding2d_274 (ZeroPadd (None, 58, 58, 124)       0
# _________________________________________________________________
# conv2d_376 (Conv2D)          (None, 58, 58, 212)       236804
# _________________________________________________________________
# zero_padding2d_275 (ZeroPadd (None, 60, 60, 212)       0
# _________________________________________________________________
# conv2d_377 (Conv2D)          (None, 60, 60, 216)       412344
# _________________________________________________________________
# max_pooling2d_172 (MaxPoolin (None, 30, 30, 216)       0
# _________________________________________________________________
# zero_padding2d_276 (ZeroPadd (None, 32, 32, 216)       0
# _________________________________________________________________
# conv2d_378 (Conv2D)          (None, 32, 32, 304)       591280
# _________________________________________________________________
# zero_padding2d_277 (ZeroPadd (None, 34, 34, 304)       0
# _________________________________________________________________
# conv2d_379 (Conv2D)          (None, 34, 34, 494)       1352078
# _________________________________________________________________
# max_pooling2d_173 (MaxPoolin (None, 17, 17, 494)       0
# _________________________________________________________________
# zero_padding2d_278 (ZeroPadd (None, 19, 19, 494)       0
# _________________________________________________________________
# conv2d_380 (Conv2D)          (None, 19, 19, 442)       1965574
# _________________________________________________________________
# zero_padding2d_279 (ZeroPadd (None, 21, 21, 442)       0
# _________________________________________________________________
# conv2d_381 (Conv2D)          (None, 21, 21, 466)       1854214
# _________________________________________________________________
# max_pooling2d_174 (MaxPoolin (None, 10, 10, 466)       0
# _________________________________________________________________
# conv2d_383 (Conv2D)          (None, 10, 10, 1742)      813514
# _________________________________________________________________
# dropout_69 (Dropout)         (None, 10, 10, 1742)      0
# _________________________________________________________________
# conv2d_384 (Conv2D)          (None, 10, 10, 10)        17430
# _________________________________________________________________
# flatten_34 (Flatten)         (None, 1000)              0
# _________________________________________________________________
# activation_34 (Activation)   (None, 1000)              0
# =================================================================
# Total params: 7,283,898
# Trainable params: 7,283,898
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 209ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 5s 5s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 36/36 [00:00<00:00, 23158.73it/s]
# [INFO] infer shape (NHWC)  :100%|█| 51/51 [00:00<00:00, 1231.17it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 350.28it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1362.01it/s]
# [INFO] generate xmodel     :100%|█| 51/51 [00:00<00:00, 1157.88it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_34, with op num: 91
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 0f0aed4ddf02c7efd59dd16e6eb1f0d4, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 218, 218, 1)]     0
# _________________________________________________________________
# zero_padding2d_280 (ZeroPadd (None, 220, 220, 1)       0
# _________________________________________________________________
# conv2d_385 (Conv2D)          (None, 220, 220, 36)      360
# _________________________________________________________________
# max_pooling2d_175 (MaxPoolin (None, 110, 110, 36)      0
# _________________________________________________________________
# zero_padding2d_281 (ZeroPadd (None, 112, 112, 36)      0
# _________________________________________________________________
# conv2d_386 (Conv2D)          (None, 112, 112, 96)      31200
# _________________________________________________________________
# max_pooling2d_176 (MaxPoolin (None, 56, 56, 96)        0
# _________________________________________________________________
# zero_padding2d_282 (ZeroPadd (None, 58, 58, 96)        0
# _________________________________________________________________
# conv2d_387 (Conv2D)          (None, 58, 58, 98)        84770
# _________________________________________________________________
# zero_padding2d_283 (ZeroPadd (None, 60, 60, 98)        0
# _________________________________________________________________
# conv2d_388 (Conv2D)          (None, 60, 60, 158)       139514
# _________________________________________________________________
# max_pooling2d_177 (MaxPoolin (None, 30, 30, 158)       0
# _________________________________________________________________
# zero_padding2d_284 (ZeroPadd (None, 32, 32, 158)       0
# _________________________________________________________________
# conv2d_389 (Conv2D)          (None, 32, 32, 498)       708654
# _________________________________________________________________
# zero_padding2d_285 (ZeroPadd (None, 34, 34, 498)       0
# _________________________________________________________________
# conv2d_390 (Conv2D)          (None, 34, 34, 500)       2241500
# _________________________________________________________________
# max_pooling2d_178 (MaxPoolin (None, 17, 17, 500)       0
# _________________________________________________________________
# zero_padding2d_286 (ZeroPadd (None, 19, 19, 500)       0
# _________________________________________________________________
# conv2d_391 (Conv2D)          (None, 19, 19, 506)       2277506
# _________________________________________________________________
# zero_padding2d_287 (ZeroPadd (None, 21, 21, 506)       0
# _________________________________________________________________
# conv2d_392 (Conv2D)          (None, 21, 21, 506)       2304830
# _________________________________________________________________
# max_pooling2d_179 (MaxPoolin (None, 10, 10, 506)       0
# _________________________________________________________________
# conv2d_394 (Conv2D)          (None, 10, 10, 2138)      1083966
# _________________________________________________________________
# dropout_71 (Dropout)         (None, 10, 10, 2138)      0
# _________________________________________________________________
# conv2d_395 (Conv2D)          (None, 10, 10, 10)        21390
# _________________________________________________________________
# flatten_35 (Flatten)         (None, 1000)              0
# _________________________________________________________________
# activation_35 (Activation)   (None, 1000)              0
# =================================================================
# Total params: 8,893,690
# Trainable params: 8,893,690
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 202ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 5s 5s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 36/36 [00:00<00:00, 28270.91it/s]
# [INFO] infer shape (NHWC)  :100%|█| 51/51 [00:00<00:00, 1422.02it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 356.83it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1297.34it/s]
# [INFO] generate xmodel     :100%|█| 51/51 [00:00<00:00, 879.72it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_35, with op num: 91
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 2d5266eb47274a3849f7dbe30530ca59, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"

# %%
import os
import numpy as np
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from itertools import product
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, ZeroPadding2D, Activation, Dropout
from tensorflow_model_optimization.quantization.keras import vitis_quantize
import tensorflow_model_optimization as tfmot

shape_range =range(48,220,34)

for shape_x in shape_range:
    
    shape_y = shape_x
#     X_train=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
#     Y_train=np.random.randint(0,10,size=[60,])
    X_test=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
    Y_test=np.random.randint(0,10,size=[60,])
#     X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
#     X_train /= 255.0
    X_test /= 255.0

    max_step =4
    inputs = Input(shape=(shape_x, shape_y, 1))
    for step in range(1,max_step+1):
        zeroPadding1 = ZeroPadding2D(padding=1)(inputs)
        conv1_kernel_num = int(32+step*32/max_step)
        conv1 = Conv2D(conv1_kernel_num, (3,3), padding='same', activation='relu')(zeroPadding1)
        pool1 = MaxPooling2D(pool_size=2)(conv1)

        zeroPadding2 = ZeroPadding2D(padding=1)(pool1)
        conv2_kernel_num = int(64+step*64/max_step)
        conv2 = Conv2D(conv2_kernel_num, (3,3), padding='same', activation='relu')(zeroPadding2)
        pool2 = MaxPooling2D(pool_size=2)(conv2)

        zeroPadding3 = ZeroPadding2D(padding=1)(pool2)
        conv3_kernel_num = int(128+step*128/max_step)
        conv3 = Conv2D(conv3_kernel_num, (3,3), padding='same', activation='relu')(zeroPadding3)

        zeroPadding4 = ZeroPadding2D(padding=1)(conv3)
        conv4_kernel_num = int(128+step*128/max_step)
        conv4 = Conv2D(conv4_kernel_num, (3,3), padding='same', activation='relu')(zeroPadding4)
        pool3 = MaxPooling2D(pool_size=2)(conv4)

        zeroPadding5 = ZeroPadding2D(padding=1)(pool3)
        conv5_kernel_num = int(256+step*256/max_step)
        conv5 = Conv2D(conv5_kernel_num, (3,3), padding='same', activation='relu')(zeroPadding5)

        zeroPadding6 = ZeroPadding2D(padding=1)(conv5)
        conv6_kernel_num = int(256+step*256/max_step)
        conv6 = Conv2D(conv6_kernel_num, (3,3), padding='same', activation='relu')(zeroPadding6)
        pool4 = MaxPooling2D(pool_size=2)(conv6)

        zeroPadding7 = ZeroPadding2D(padding=1)(pool4)
        conv7_kernel_num = int(256+step*256/max_step)
        conv7 = Conv2D(conv7_kernel_num, (3,3), padding='same', activation='relu')(zeroPadding7)

        zeroPadding8 = ZeroPadding2D(padding=1)(conv7)
        conv8_kernel_num = int(256+step*256/max_step)
        conv8 = Conv2D(conv8_kernel_num, (3,3), padding='same', activation='relu')(zeroPadding8)
        pool5 = MaxPooling2D(pool_size=2)(conv8)

        conv9_kernel_num = int(512+step*3584/max_step)
        conv9 = Conv2D(conv9_kernel_num, (7,7), padding='same', activation='relu')(pool5)
        drop1 = Dropout(0.5)(conv9)

        conv10_kernel_num = int(512+step*3584/max_step)
        conv10 = Conv2D(conv10_kernel_num, (1,1), padding='same', activation='relu')(pool5)
        drop2 = Dropout(0.5)(conv10)

        conv11 = Conv2D(10, (1,1))(drop2)

        flat = Flatten()(conv11)
        
        outputs = Dense(10, activation = 'softmax')(flat)

        


        model = Model(inputs=inputs, outputs=outputs)
        model.summary()
        model.save('./vgg11_h5/vgg11_{input_x}_{input_y}_{step}.h5'.format(input_x=shape_x,input_y=shape_y,step=step))
#         model.compile(optimizer='adam',
#                   loss="sparse_categorical_crossentropy", 
#                   metrics=['accuracy'])
#         history = model.fit(X_train, Y_train, epochs=1)
#         model.get_weights()[0].dtype
        quantizer = vitis_quantize.VitisQuantizer(model)
        quantized_model = quantizer.quantize_model(calib_dataset = X_test[1:8], weight_bit=8, activation_bit=8)
#         quantized_model.compile(loss='sparse_categorical_crossentropy', metrics=["accuracy"])
        quantized_model.save('quantized.h5')
        # !vai_c_tensorflow2 \
                --model ./quantized.h5 \
                --arch ./arch.json \
                --output_dir ./xmodel_vgg11 \
                --net_name deploy
        os.rename("./xmodel_vgg11/deploy.xmodel","./xmodel_vgg11/vgg11_{input_x}_{input_y}_{step}.xmodel".format(input_x=shape_x,input_y=shape_y,step=step))
# Out:
# Model: "model_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 48, 48, 1)]       0
# _________________________________________________________________
# zero_padding2d_192 (ZeroPadd (None, 50, 50, 1)         0
# _________________________________________________________________
# conv2d_264 (Conv2D)          (None, 50, 50, 40)        400
# _________________________________________________________________
# max_pooling2d_120 (MaxPoolin (None, 25, 25, 40)        0
# _________________________________________________________________
# zero_padding2d_193 (ZeroPadd (None, 27, 27, 40)        0
# _________________________________________________________________
# conv2d_265 (Conv2D)          (None, 27, 27, 80)        28880
# _________________________________________________________________
# max_pooling2d_121 (MaxPoolin (None, 13, 13, 80)        0
# _________________________________________________________________
# zero_padding2d_194 (ZeroPadd (None, 15, 15, 80)        0
# _________________________________________________________________
# conv2d_266 (Conv2D)          (None, 15, 15, 160)       115360
# _________________________________________________________________
# zero_padding2d_195 (ZeroPadd (None, 17, 17, 160)       0
# _________________________________________________________________
# conv2d_267 (Conv2D)          (None, 17, 17, 160)       230560
# _________________________________________________________________
# max_pooling2d_122 (MaxPoolin (None, 8, 8, 160)         0
# _________________________________________________________________
# zero_padding2d_196 (ZeroPadd (None, 10, 10, 160)       0
# _________________________________________________________________
# conv2d_268 (Conv2D)          (None, 10, 10, 320)       461120
# _________________________________________________________________
# zero_padding2d_197 (ZeroPadd (None, 12, 12, 320)       0
# _________________________________________________________________
# conv2d_269 (Conv2D)          (None, 12, 12, 320)       921920
# _________________________________________________________________
# max_pooling2d_123 (MaxPoolin (None, 6, 6, 320)         0
# _________________________________________________________________
# zero_padding2d_198 (ZeroPadd (None, 8, 8, 320)         0
# _________________________________________________________________
# conv2d_270 (Conv2D)          (None, 8, 8, 320)         921920
# _________________________________________________________________
# zero_padding2d_199 (ZeroPadd (None, 10, 10, 320)       0
# _________________________________________________________________
# conv2d_271 (Conv2D)          (None, 10, 10, 320)       921920
# _________________________________________________________________
# max_pooling2d_124 (MaxPoolin (None, 5, 5, 320)         0
# _________________________________________________________________
# conv2d_273 (Conv2D)          (None, 5, 5, 1408)        451968
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 5, 5, 1408)        0
# _________________________________________________________________
# conv2d_274 (Conv2D)          (None, 5, 5, 10)          14090
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 250)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 10)                2510
# =================================================================
# Total params: 4,070,648
# Trainable params: 4,070,648
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 184ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 2022-05-14 13:02:35.528280: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 1/1 [==============================] - 4s 4s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 37/37 [00:00<00:00, 12435.04it/s]
# [INFO] infer shape (NHWC)  :100%|█| 55/55 [00:00<00:00, 8768.02it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 254.05it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1164.60it/s]
# [INFO] generate xmodel     :100%|█| 55/55 [00:00<00:00, 1885.27it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_24, with op num: 97
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 70e6fb5c2878cdbae0dda433be6d5a63, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 48, 48, 1)]       0
# _________________________________________________________________
# zero_padding2d_200 (ZeroPadd (None, 50, 50, 1)         0
# _________________________________________________________________
# conv2d_275 (Conv2D)          (None, 50, 50, 48)        480
# _________________________________________________________________
# max_pooling2d_125 (MaxPoolin (None, 25, 25, 48)        0
# _________________________________________________________________
# zero_padding2d_201 (ZeroPadd (None, 27, 27, 48)        0
# _________________________________________________________________
# conv2d_276 (Conv2D)          (None, 27, 27, 96)        41568
# _________________________________________________________________
# max_pooling2d_126 (MaxPoolin (None, 13, 13, 96)        0
# _________________________________________________________________
# zero_padding2d_202 (ZeroPadd (None, 15, 15, 96)        0
# _________________________________________________________________
# conv2d_277 (Conv2D)          (None, 15, 15, 192)       166080
# _________________________________________________________________
# zero_padding2d_203 (ZeroPadd (None, 17, 17, 192)       0
# _________________________________________________________________
# conv2d_278 (Conv2D)          (None, 17, 17, 192)       331968
# _________________________________________________________________
# max_pooling2d_127 (MaxPoolin (None, 8, 8, 192)         0
# _________________________________________________________________
# zero_padding2d_204 (ZeroPadd (None, 10, 10, 192)       0
# _________________________________________________________________
# conv2d_279 (Conv2D)          (None, 10, 10, 384)       663936
# _________________________________________________________________
# zero_padding2d_205 (ZeroPadd (None, 12, 12, 384)       0
# _________________________________________________________________
# conv2d_280 (Conv2D)          (None, 12, 12, 384)       1327488
# _________________________________________________________________
# max_pooling2d_128 (MaxPoolin (None, 6, 6, 384)         0
# _________________________________________________________________
# zero_padding2d_206 (ZeroPadd (None, 8, 8, 384)         0
# _________________________________________________________________
# conv2d_281 (Conv2D)          (None, 8, 8, 384)         1327488
# _________________________________________________________________
# zero_padding2d_207 (ZeroPadd (None, 10, 10, 384)       0
# _________________________________________________________________
# conv2d_282 (Conv2D)          (None, 10, 10, 384)       1327488
# _________________________________________________________________
# max_pooling2d_129 (MaxPoolin (None, 5, 5, 384)         0
# _________________________________________________________________
# conv2d_284 (Conv2D)          (None, 5, 5, 2304)        887040
# _________________________________________________________________
# dropout_51 (Dropout)         (None, 5, 5, 2304)        0
# _________________________________________________________________
# conv2d_285 (Conv2D)          (None, 5, 5, 10)          23050
# _________________________________________________________________
# flatten_25 (Flatten)         (None, 250)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 10)                2510
# =================================================================
# Total params: 6,099,096
# Trainable params: 6,099,096
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 195ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 4s 4s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 37/37 [00:00<00:00, 28098.72it/s]
# [INFO] infer shape (NHWC)  :100%|█| 55/55 [00:00<00:00, 14337.27it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 330.44it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1243.31it/s]
# [INFO] generate xmodel     :100%|█| 55/55 [00:00<00:00, 1409.79it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_25, with op num: 97
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 4ff5c93077dd02a324a7e906b6349b31, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 48, 48, 1)]       0
# _________________________________________________________________
# zero_padding2d_208 (ZeroPadd (None, 50, 50, 1)         0
# _________________________________________________________________
# conv2d_286 (Conv2D)          (None, 50, 50, 56)        560
# _________________________________________________________________
# max_pooling2d_130 (MaxPoolin (None, 25, 25, 56)        0
# _________________________________________________________________
# zero_padding2d_209 (ZeroPadd (None, 27, 27, 56)        0
# _________________________________________________________________
# conv2d_287 (Conv2D)          (None, 27, 27, 112)       56560
# _________________________________________________________________
# max_pooling2d_131 (MaxPoolin (None, 13, 13, 112)       0
# _________________________________________________________________
# zero_padding2d_210 (ZeroPadd (None, 15, 15, 112)       0
# _________________________________________________________________
# conv2d_288 (Conv2D)          (None, 15, 15, 224)       226016
# _________________________________________________________________
# zero_padding2d_211 (ZeroPadd (None, 17, 17, 224)       0
# _________________________________________________________________
# conv2d_289 (Conv2D)          (None, 17, 17, 224)       451808
# _________________________________________________________________
# max_pooling2d_132 (MaxPoolin (None, 8, 8, 224)         0
# _________________________________________________________________
# zero_padding2d_212 (ZeroPadd (None, 10, 10, 224)       0
# _________________________________________________________________
# conv2d_290 (Conv2D)          (None, 10, 10, 448)       903616
# _________________________________________________________________
# zero_padding2d_213 (ZeroPadd (None, 12, 12, 448)       0
# _________________________________________________________________
# conv2d_291 (Conv2D)          (None, 12, 12, 448)       1806784
# _________________________________________________________________
# max_pooling2d_133 (MaxPoolin (None, 6, 6, 448)         0
# _________________________________________________________________
# zero_padding2d_214 (ZeroPadd (None, 8, 8, 448)         0
# _________________________________________________________________
# conv2d_292 (Conv2D)          (None, 8, 8, 448)         1806784
# _________________________________________________________________
# zero_padding2d_215 (ZeroPadd (None, 10, 10, 448)       0
# _________________________________________________________________
# conv2d_293 (Conv2D)          (None, 10, 10, 448)       1806784
# _________________________________________________________________
# max_pooling2d_134 (MaxPoolin (None, 5, 5, 448)         0
# _________________________________________________________________
# conv2d_295 (Conv2D)          (None, 5, 5, 3200)        1436800
# _________________________________________________________________
# dropout_53 (Dropout)         (None, 5, 5, 3200)        0
# _________________________________________________________________
# conv2d_296 (Conv2D)          (None, 5, 5, 10)          32010
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 250)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 10)                2510
# =================================================================
# Total params: 8,530,232
# Trainable params: 8,530,232
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 200ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 4s 4s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 37/37 [00:00<00:00, 28200.84it/s]
# [INFO] infer shape (NHWC)  :100%|█| 55/55 [00:00<00:00, 13406.56it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 335.41it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1232.53it/s]
# [INFO] generate xmodel     :100%|█| 55/55 [00:00<00:00, 1053.23it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_26, with op num: 97
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_296, type = conv2d-fix} has been assigned to CPU: [DPU only supports "input_channel"(3200) less than 3072].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_296_weights, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_296_bias, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 5, DPU subgraph number 2
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 795e4f6d422c0832168c58f63b92ffa2, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 48, 48, 1)]       0
# _________________________________________________________________
# zero_padding2d_216 (ZeroPadd (None, 50, 50, 1)         0
# _________________________________________________________________
# conv2d_297 (Conv2D)          (None, 50, 50, 64)        640
# _________________________________________________________________
# max_pooling2d_135 (MaxPoolin (None, 25, 25, 64)        0
# _________________________________________________________________
# zero_padding2d_217 (ZeroPadd (None, 27, 27, 64)        0
# _________________________________________________________________
# conv2d_298 (Conv2D)          (None, 27, 27, 128)       73856
# _________________________________________________________________
# max_pooling2d_136 (MaxPoolin (None, 13, 13, 128)       0
# _________________________________________________________________
# zero_padding2d_218 (ZeroPadd (None, 15, 15, 128)       0
# _________________________________________________________________
# conv2d_299 (Conv2D)          (None, 15, 15, 256)       295168
# _________________________________________________________________
# zero_padding2d_219 (ZeroPadd (None, 17, 17, 256)       0
# _________________________________________________________________
# conv2d_300 (Conv2D)          (None, 17, 17, 256)       590080
# _________________________________________________________________
# max_pooling2d_137 (MaxPoolin (None, 8, 8, 256)         0
# _________________________________________________________________
# zero_padding2d_220 (ZeroPadd (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_301 (Conv2D)          (None, 10, 10, 512)       1180160
# _________________________________________________________________
# zero_padding2d_221 (ZeroPadd (None, 12, 12, 512)       0
# _________________________________________________________________
# conv2d_302 (Conv2D)          (None, 12, 12, 512)       2359808
# _________________________________________________________________
# max_pooling2d_138 (MaxPoolin (None, 6, 6, 512)         0
# _________________________________________________________________
# zero_padding2d_222 (ZeroPadd (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_303 (Conv2D)          (None, 8, 8, 512)         2359808
# _________________________________________________________________
# zero_padding2d_223 (ZeroPadd (None, 10, 10, 512)       0
# _________________________________________________________________
# conv2d_304 (Conv2D)          (None, 10, 10, 512)       2359808
# _________________________________________________________________
# max_pooling2d_139 (MaxPoolin (None, 5, 5, 512)         0
# _________________________________________________________________
# conv2d_306 (Conv2D)          (None, 5, 5, 4096)        2101248
# _________________________________________________________________
# dropout_55 (Dropout)         (None, 5, 5, 4096)        0
# _________________________________________________________________
# conv2d_307 (Conv2D)          (None, 5, 5, 10)          40970
# _________________________________________________________________
# flatten_27 (Flatten)         (None, 250)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 10)                2510
# =================================================================
# Total params: 11,364,056
# Trainable params: 11,364,056
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 209ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 4s 4s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 37/37 [00:00<00:00, 28221.36it/s]
# [INFO] infer shape (NHWC)  :100%|█| 55/55 [00:00<00:00, 12669.53it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 331.23it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1274.48it/s]
# [INFO] generate xmodel     :100%|█| 55/55 [00:00<00:00, 611.76it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_27, with op num: 97
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_307, type = conv2d-fix} has been assigned to CPU: [DPU only supports "input_channel"(4096) less than 3072].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_307_weights, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_307_bias, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 5, DPU subgraph number 2
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 67645ed67094ddb5118d4eaff71139a3, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 82, 82, 1)]       0
# _________________________________________________________________
# zero_padding2d_224 (ZeroPadd (None, 84, 84, 1)         0
# _________________________________________________________________
# conv2d_308 (Conv2D)          (None, 84, 84, 40)        400
# _________________________________________________________________
# max_pooling2d_140 (MaxPoolin (None, 42, 42, 40)        0
# _________________________________________________________________
# zero_padding2d_225 (ZeroPadd (None, 44, 44, 40)        0
# _________________________________________________________________
# conv2d_309 (Conv2D)          (None, 44, 44, 80)        28880
# _________________________________________________________________
# max_pooling2d_141 (MaxPoolin (None, 22, 22, 80)        0
# _________________________________________________________________
# zero_padding2d_226 (ZeroPadd (None, 24, 24, 80)        0
# _________________________________________________________________
# conv2d_310 (Conv2D)          (None, 24, 24, 160)       115360
# _________________________________________________________________
# zero_padding2d_227 (ZeroPadd (None, 26, 26, 160)       0
# _________________________________________________________________
# conv2d_311 (Conv2D)          (None, 26, 26, 160)       230560
# _________________________________________________________________
# max_pooling2d_142 (MaxPoolin (None, 13, 13, 160)       0
# _________________________________________________________________
# zero_padding2d_228 (ZeroPadd (None, 15, 15, 160)       0
# _________________________________________________________________
# conv2d_312 (Conv2D)          (None, 15, 15, 320)       461120
# _________________________________________________________________
# zero_padding2d_229 (ZeroPadd (None, 17, 17, 320)       0
# _________________________________________________________________
# conv2d_313 (Conv2D)          (None, 17, 17, 320)       921920
# _________________________________________________________________
# max_pooling2d_143 (MaxPoolin (None, 8, 8, 320)         0
# _________________________________________________________________
# zero_padding2d_230 (ZeroPadd (None, 10, 10, 320)       0
# _________________________________________________________________
# conv2d_314 (Conv2D)          (None, 10, 10, 320)       921920
# _________________________________________________________________
# zero_padding2d_231 (ZeroPadd (None, 12, 12, 320)       0
# _________________________________________________________________
# conv2d_315 (Conv2D)          (None, 12, 12, 320)       921920
# _________________________________________________________________
# max_pooling2d_144 (MaxPoolin (None, 6, 6, 320)         0
# _________________________________________________________________
# conv2d_317 (Conv2D)          (None, 6, 6, 1408)        451968
# _________________________________________________________________
# dropout_57 (Dropout)         (None, 6, 6, 1408)        0
# _________________________________________________________________
# conv2d_318 (Conv2D)          (None, 6, 6, 10)          14090
# _________________________________________________________________
# flatten_28 (Flatten)         (None, 360)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 10)                3610
# =================================================================
# Total params: 4,071,748
# Trainable params: 4,071,748
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 188ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 4s 4s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 37/37 [00:00<00:00, 27312.43it/s]
# [INFO] infer shape (NHWC)  :100%|█| 55/55 [00:00<00:00, 7326.88it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 330.23it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1229.28it/s]
# [INFO] generate xmodel     :100%|█| 55/55 [00:00<00:00, 1935.58it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_28, with op num: 97
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 78db7e4e1b06d158771456c336cd2e7f, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 82, 82, 1)]       0
# _________________________________________________________________
# zero_padding2d_232 (ZeroPadd (None, 84, 84, 1)         0
# _________________________________________________________________
# conv2d_319 (Conv2D)          (None, 84, 84, 48)        480
# _________________________________________________________________
# max_pooling2d_145 (MaxPoolin (None, 42, 42, 48)        0
# _________________________________________________________________
# zero_padding2d_233 (ZeroPadd (None, 44, 44, 48)        0
# _________________________________________________________________
# conv2d_320 (Conv2D)          (None, 44, 44, 96)        41568
# _________________________________________________________________
# max_pooling2d_146 (MaxPoolin (None, 22, 22, 96)        0
# _________________________________________________________________
# zero_padding2d_234 (ZeroPadd (None, 24, 24, 96)        0
# _________________________________________________________________
# conv2d_321 (Conv2D)          (None, 24, 24, 192)       166080
# _________________________________________________________________
# zero_padding2d_235 (ZeroPadd (None, 26, 26, 192)       0
# _________________________________________________________________
# conv2d_322 (Conv2D)          (None, 26, 26, 192)       331968
# _________________________________________________________________
# max_pooling2d_147 (MaxPoolin (None, 13, 13, 192)       0
# _________________________________________________________________
# zero_padding2d_236 (ZeroPadd (None, 15, 15, 192)       0
# _________________________________________________________________
# conv2d_323 (Conv2D)          (None, 15, 15, 384)       663936
# _________________________________________________________________
# zero_padding2d_237 (ZeroPadd (None, 17, 17, 384)       0
# _________________________________________________________________
# conv2d_324 (Conv2D)          (None, 17, 17, 384)       1327488
# _________________________________________________________________
# max_pooling2d_148 (MaxPoolin (None, 8, 8, 384)         0
# _________________________________________________________________
# zero_padding2d_238 (ZeroPadd (None, 10, 10, 384)       0
# _________________________________________________________________
# conv2d_325 (Conv2D)          (None, 10, 10, 384)       1327488
# _________________________________________________________________
# zero_padding2d_239 (ZeroPadd (None, 12, 12, 384)       0
# _________________________________________________________________
# conv2d_326 (Conv2D)          (None, 12, 12, 384)       1327488
# _________________________________________________________________
# max_pooling2d_149 (MaxPoolin (None, 6, 6, 384)         0
# _________________________________________________________________
# conv2d_328 (Conv2D)          (None, 6, 6, 2304)        887040
# _________________________________________________________________
# dropout_59 (Dropout)         (None, 6, 6, 2304)        0
# _________________________________________________________________
# conv2d_329 (Conv2D)          (None, 6, 6, 10)          23050
# _________________________________________________________________
# flatten_29 (Flatten)         (None, 360)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 10)                3610
# =================================================================
# Total params: 6,100,196
# Trainable params: 6,100,196
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 197ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 4s 4s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 37/37 [00:00<00:00, 28139.48it/s]
# [INFO] infer shape (NHWC)  :100%|█| 55/55 [00:00<00:00, 6363.24it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 330.55it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1238.54it/s]
# [INFO] generate xmodel     :100%|█| 55/55 [00:00<00:00, 1379.39it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_29, with op num: 97
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is f3ef86a9425bb0597431fbc3c4597b71, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 82, 82, 1)]       0
# _________________________________________________________________
# zero_padding2d_240 (ZeroPadd (None, 84, 84, 1)         0
# _________________________________________________________________
# conv2d_330 (Conv2D)          (None, 84, 84, 56)        560
# _________________________________________________________________
# max_pooling2d_150 (MaxPoolin (None, 42, 42, 56)        0
# _________________________________________________________________
# zero_padding2d_241 (ZeroPadd (None, 44, 44, 56)        0
# _________________________________________________________________
# conv2d_331 (Conv2D)          (None, 44, 44, 112)       56560
# _________________________________________________________________
# max_pooling2d_151 (MaxPoolin (None, 22, 22, 112)       0
# _________________________________________________________________
# zero_padding2d_242 (ZeroPadd (None, 24, 24, 112)       0
# _________________________________________________________________
# conv2d_332 (Conv2D)          (None, 24, 24, 224)       226016
# _________________________________________________________________
# zero_padding2d_243 (ZeroPadd (None, 26, 26, 224)       0
# _________________________________________________________________
# conv2d_333 (Conv2D)          (None, 26, 26, 224)       451808
# _________________________________________________________________
# max_pooling2d_152 (MaxPoolin (None, 13, 13, 224)       0
# _________________________________________________________________
# zero_padding2d_244 (ZeroPadd (None, 15, 15, 224)       0
# _________________________________________________________________
# conv2d_334 (Conv2D)          (None, 15, 15, 448)       903616
# _________________________________________________________________
# zero_padding2d_245 (ZeroPadd (None, 17, 17, 448)       0
# _________________________________________________________________
# conv2d_335 (Conv2D)          (None, 17, 17, 448)       1806784
# _________________________________________________________________
# max_pooling2d_153 (MaxPoolin (None, 8, 8, 448)         0
# _________________________________________________________________
# zero_padding2d_246 (ZeroPadd (None, 10, 10, 448)       0
# _________________________________________________________________
# conv2d_336 (Conv2D)          (None, 10, 10, 448)       1806784
# _________________________________________________________________
# zero_padding2d_247 (ZeroPadd (None, 12, 12, 448)       0
# _________________________________________________________________
# conv2d_337 (Conv2D)          (None, 12, 12, 448)       1806784
# _________________________________________________________________
# max_pooling2d_154 (MaxPoolin (None, 6, 6, 448)         0
# _________________________________________________________________
# conv2d_339 (Conv2D)          (None, 6, 6, 3200)        1436800
# _________________________________________________________________
# dropout_61 (Dropout)         (None, 6, 6, 3200)        0
# _________________________________________________________________
# conv2d_340 (Conv2D)          (None, 6, 6, 10)          32010
# _________________________________________________________________
# flatten_30 (Flatten)         (None, 360)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 10)                3610
# =================================================================
# Total params: 8,531,332
# Trainable params: 8,531,332
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 203ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 4s 4s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 37/37 [00:00<00:00, 27574.49it/s]
# [INFO] infer shape (NHWC)  :100%|█| 55/55 [00:00<00:00, 5795.28it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 327.60it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1262.39it/s]
# [INFO] generate xmodel     :100%|█| 55/55 [00:00<00:00, 1047.97it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_30, with op num: 97
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_340, type = conv2d-fix} has been assigned to CPU: [DPU only supports "input_channel"(3200) less than 3072].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_340_weights, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_340_bias, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 5, DPU subgraph number 2
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is e05b981009d8def6feb9b3a57fb48672, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 82, 82, 1)]       0
# _________________________________________________________________
# zero_padding2d_248 (ZeroPadd (None, 84, 84, 1)         0
# _________________________________________________________________
# conv2d_341 (Conv2D)          (None, 84, 84, 64)        640
# _________________________________________________________________
# max_pooling2d_155 (MaxPoolin (None, 42, 42, 64)        0
# _________________________________________________________________
# zero_padding2d_249 (ZeroPadd (None, 44, 44, 64)        0
# _________________________________________________________________
# conv2d_342 (Conv2D)          (None, 44, 44, 128)       73856
# _________________________________________________________________
# max_pooling2d_156 (MaxPoolin (None, 22, 22, 128)       0
# _________________________________________________________________
# zero_padding2d_250 (ZeroPadd (None, 24, 24, 128)       0
# _________________________________________________________________
# conv2d_343 (Conv2D)          (None, 24, 24, 256)       295168
# _________________________________________________________________
# zero_padding2d_251 (ZeroPadd (None, 26, 26, 256)       0
# _________________________________________________________________
# conv2d_344 (Conv2D)          (None, 26, 26, 256)       590080
# _________________________________________________________________
# max_pooling2d_157 (MaxPoolin (None, 13, 13, 256)       0
# _________________________________________________________________
# zero_padding2d_252 (ZeroPadd (None, 15, 15, 256)       0
# ...
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 197ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 5s 5s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 37/37 [00:00<00:00, 26937.90it/s]
# [INFO] infer shape (NHWC)  :100%|█| 55/55 [00:00<00:00, 1421.88it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 319.76it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1214.51it/s]
# [INFO] generate xmodel     :100%|█| 55/55 [00:00<00:00, 1332.30it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_45, with op num: 97
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 4037405a09c98ef9936662aa3a8067f2, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_46"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        [(None, 218, 218, 1)]     0
# _________________________________________________________________
# zero_padding2d_368 (ZeroPadd (None, 220, 220, 1)       0
# _________________________________________________________________
# conv2d_506 (Conv2D)          (None, 220, 220, 56)      560
# _________________________________________________________________
# max_pooling2d_230 (MaxPoolin (None, 110, 110, 56)      0
# _________________________________________________________________
# zero_padding2d_369 (ZeroPadd (None, 112, 112, 56)      0
# _________________________________________________________________
# conv2d_507 (Conv2D)          (None, 112, 112, 112)     56560
# _________________________________________________________________
# max_pooling2d_231 (MaxPoolin (None, 56, 56, 112)       0
# _________________________________________________________________
# zero_padding2d_370 (ZeroPadd (None, 58, 58, 112)       0
# _________________________________________________________________
# conv2d_508 (Conv2D)          (None, 58, 58, 224)       226016
# _________________________________________________________________
# zero_padding2d_371 (ZeroPadd (None, 60, 60, 224)       0
# _________________________________________________________________
# conv2d_509 (Conv2D)          (None, 60, 60, 224)       451808
# _________________________________________________________________
# max_pooling2d_232 (MaxPoolin (None, 30, 30, 224)       0
# _________________________________________________________________
# zero_padding2d_372 (ZeroPadd (None, 32, 32, 224)       0
# _________________________________________________________________
# conv2d_510 (Conv2D)          (None, 32, 32, 448)       903616
# _________________________________________________________________
# zero_padding2d_373 (ZeroPadd (None, 34, 34, 448)       0
# _________________________________________________________________
# conv2d_511 (Conv2D)          (None, 34, 34, 448)       1806784
# _________________________________________________________________
# max_pooling2d_233 (MaxPoolin (None, 17, 17, 448)       0
# _________________________________________________________________
# zero_padding2d_374 (ZeroPadd (None, 19, 19, 448)       0
# _________________________________________________________________
# conv2d_512 (Conv2D)          (None, 19, 19, 448)       1806784
# _________________________________________________________________
# zero_padding2d_375 (ZeroPadd (None, 21, 21, 448)       0
# _________________________________________________________________
# conv2d_513 (Conv2D)          (None, 21, 21, 448)       1806784
# _________________________________________________________________
# max_pooling2d_234 (MaxPoolin (None, 10, 10, 448)       0
# _________________________________________________________________
# conv2d_515 (Conv2D)          (None, 10, 10, 3200)      1436800
# _________________________________________________________________
# dropout_93 (Dropout)         (None, 10, 10, 3200)      0
# _________________________________________________________________
# conv2d_516 (Conv2D)          (None, 10, 10, 10)        32010
# _________________________________________________________________
# flatten_46 (Flatten)         (None, 1000)              0
# _________________________________________________________________
# dense_46 (Dense)             (None, 10)                10010
# =================================================================
# Total params: 8,537,732
# Trainable params: 8,537,732
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 245ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 5s 5s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 37/37 [00:00<00:00, 26491.85it/s]
# [INFO] infer shape (NHWC)  :100%|█| 55/55 [00:00<00:00, 1247.39it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 319.04it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1221.40it/s]
# [INFO] generate xmodel     :100%|█| 55/55 [00:00<00:00, 1020.91it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_46, with op num: 97
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_516, type = conv2d-fix} has been assigned to CPU: [DPU only supports "input_channel"(3200) less than 3072].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_516_weights, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_516_bias, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 5, DPU subgraph number 2
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 4e495b5d796d840f8b6dddee9d38b04c, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
# Model: "model_47"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        [(None, 218, 218, 1)]     0
# _________________________________________________________________
# zero_padding2d_376 (ZeroPadd (None, 220, 220, 1)       0
# _________________________________________________________________
# conv2d_517 (Conv2D)          (None, 220, 220, 64)      640
# _________________________________________________________________
# max_pooling2d_235 (MaxPoolin (None, 110, 110, 64)      0
# _________________________________________________________________
# zero_padding2d_377 (ZeroPadd (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_518 (Conv2D)          (None, 112, 112, 128)     73856
# _________________________________________________________________
# max_pooling2d_236 (MaxPoolin (None, 56, 56, 128)       0
# _________________________________________________________________
# zero_padding2d_378 (ZeroPadd (None, 58, 58, 128)       0
# _________________________________________________________________
# conv2d_519 (Conv2D)          (None, 58, 58, 256)       295168
# _________________________________________________________________
# zero_padding2d_379 (ZeroPadd (None, 60, 60, 256)       0
# _________________________________________________________________
# conv2d_520 (Conv2D)          (None, 60, 60, 256)       590080
# _________________________________________________________________
# max_pooling2d_237 (MaxPoolin (None, 30, 30, 256)       0
# _________________________________________________________________
# zero_padding2d_380 (ZeroPadd (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_521 (Conv2D)          (None, 32, 32, 512)       1180160
# _________________________________________________________________
# zero_padding2d_381 (ZeroPadd (None, 34, 34, 512)       0
# _________________________________________________________________
# conv2d_522 (Conv2D)          (None, 34, 34, 512)       2359808
# _________________________________________________________________
# max_pooling2d_238 (MaxPoolin (None, 17, 17, 512)       0
# _________________________________________________________________
# zero_padding2d_382 (ZeroPadd (None, 19, 19, 512)       0
# _________________________________________________________________
# conv2d_523 (Conv2D)          (None, 19, 19, 512)       2359808
# _________________________________________________________________
# zero_padding2d_383 (ZeroPadd (None, 21, 21, 512)       0
# _________________________________________________________________
# conv2d_524 (Conv2D)          (None, 21, 21, 512)       2359808
# _________________________________________________________________
# max_pooling2d_239 (MaxPoolin (None, 10, 10, 512)       0
# _________________________________________________________________
# conv2d_526 (Conv2D)          (None, 10, 10, 4096)      2101248
# _________________________________________________________________
# dropout_95 (Dropout)         (None, 10, 10, 4096)      0
# _________________________________________________________________
# conv2d_527 (Conv2D)          (None, 10, 10, 10)        40970
# _________________________________________________________________
# flatten_47 (Flatten)         (None, 1000)              0
# _________________________________________________________________
# dense_47 (Dense)             (None, 10)                10010
# =================================================================
# Total params: 11,371,556
# Trainable params: 11,371,556
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 253ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 5s 5s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 37/37 [00:00<00:00, 28170.13it/s]
# [INFO] infer shape (NHWC)  :100%|█| 55/55 [00:00<00:00, 1117.83it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 323.57it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1253.72it/s]
# [INFO] generate xmodel     :100%|█| 55/55 [00:00<00:00, 627.65it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_47, with op num: 97
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_527, type = conv2d-fix} has been assigned to CPU: [DPU only supports "input_channel"(4096) less than 3072].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_527_weights, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][WARNING] xir::Op{name = quant_conv2d_527_bias, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 5, DPU subgraph number 2
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 6bb6fb96cc0694b4398ba2391011260c, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg11/md5sum.txt"
