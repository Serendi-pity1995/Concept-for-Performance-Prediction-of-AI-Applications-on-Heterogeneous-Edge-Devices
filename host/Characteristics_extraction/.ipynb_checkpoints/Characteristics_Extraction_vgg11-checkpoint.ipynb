# %%
import os
import csv
import numpy as np
import keras
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, ZeroPadding2D, Dropout, Activation
from itertools import product
from keras_flops import get_flops
def get_total_number_of_neurons(model, include_output_layer):
    '''
    Args:
        model: Keras model
        include_output_layer: A boolean parameter. Whether or not to include output layer's neurons into the calculation

    Returns: number of neurons in the given model
    '''
    num_layers = len(model.layers)
    total_num_of_neurons = 0
    for layer_index in range(num_layers):
        layer = model.layers[layer_index]
        # since we multiply layer output dimensions, initial value is set to 1.
        num_neurons_in_layer = 1
        for i in range(1, len(layer.output.shape)):
            try:
                # when it is a valid layer to count neurons, an output dimension of the layer can be convertible to int.
                num_neurons_in_layer *= int(layer.output.shape[i])
            except Exception:
                # if the output dimension of layer cannot be convertible to int,
                # just pass that layer since it is not a valid layer to count neurons
                pass
        # if num_neurons_in_layer is not still 1, it means we have a valid layer to count neurons
        if not num_neurons_in_layer == 1:
            # when it is an output layer
            if layer_index == (num_layers - 1):
                if include_output_layer:
                    total_num_of_neurons += num_neurons_in_layer
            else:  # when it is not an output layer
                total_num_of_neurons += num_neurons_in_layer
    return total_num_of_neurons
model_num = 1
input_shape_range =range(32,512,2)

with open("para_count_vgg11.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "step","number_of_layers", "FLOPs_G", "Total_params_M", "Memory_M", "total_num_of_neurons_M"],])

path = "../vgg11_h5" 
files= os.listdir(path) 
for shape_x in input_shape_range:
    shape_y = shape_x
    for step in range(1,11):
        file = "vgg11_{input_x}_{input_y}_{step}.h5".format(input_x=shape_x,input_y=shape_y,step=step)
        if file in files: 
            model_name = str(file)
            if not os.path.isdir(file): 
                model = keras.models.load_model("../vgg11_h5/{}".format(model_name))
                num_neurons = get_total_number_of_neurons(model= model, include_output_layer= True)
#                 print("total_number_of_neurons:",num_neurons/1000000,"M")
                num_neurons_M = num_neurons/10**6
                # how to compute the memory allocated by the activations of a model
                batch = 1
                shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
                else 1 for s in l.output_shape])) 
                for l in model.layers]))
                memory = (shapes_count * 4 * batch)/10**6
                print(memory)
                layers_length = len(model.layers)
                Total_params = round(model.count_params()/10 ** 6,2)
                FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
                with open("para_count_vgg11.csv","a+") as csvfile:
                    writer = csv.writer(csvfile)
                    writer.writerows([[model_num, shape_x, shape_y, step, layers_length, FLOPs, Total_params, memory, num_neurons_M],])

                    model_num = model_num + 1
# Out:
# 2022-05-16 04:16:40.448507: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-05-16 04:16:40.448522: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-05-16 04:16:41.565342: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-05-16 04:16:41.565360: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-16 04:16:41.565374: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2022-05-16 04:16:41.565504: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.061476
# 2022-05-16 04:16:42.116365: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:16:42.116630: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:16:42.138189: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.009ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# WARNING:tensorflow:From /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py:5063: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/989.25m flops)
#   model_100/conv2d_1105/Conv2D (335.97m/335.97m flops)
#   model_100/conv2d_1107/Conv2D (286.50m/286.50m flops)
#   model_100/conv2d_1106/Conv2D (165.44m/165.44m flops)
#   model_100/conv2d_1104/Conv2D (67.02m/67.02m flops)
#   model_100/conv2d_1103/Conv2D (61.33m/61.33m flops)
#   model_100/conv2d_1109/Conv2D (39.65m/39.65m flops)
#   model_100/conv2d_1102/Conv2D (16.47m/16.47m flops)
#   model_100/conv2d_1101/Conv2D (14.74m/14.74m flops)
#   model_100/conv2d_1100/Conv2D (873.94k/873.94k flops)
#   model_100/conv2d_1110/Conv2D (819.20k/819.20k flops)
#   model_100/max_pooling2d_500/MaxPool (48.55k/48.55k flops)
#   model_100/conv2d_1100/BiasAdd (48.55k/48.55k flops)
#   model_100/max_pooling2d_503/MaxPool (46.20k/46.20k flops)
#   model_100/conv2d_1105/BiasAdd (46.20k/46.20k flops)
#   model_100/conv2d_1109/BiasAdd (40.96k/40.96k flops)
#   model_100/conv2d_1107/BiasAdd (39.20k/39.20k flops)
#   model_100/max_pooling2d_504/MaxPool (30.98k/30.98k flops)
#   model_100/conv2d_1104/BiasAdd (25.86k/25.86k flops)
#   model_100/conv2d_1103/BiasAdd (24.34k/24.34k flops)
#   model_100/max_pooling2d_502/MaxPool (20.74k/20.74k flops)
#   model_100/conv2d_1106/BiasAdd (19.89k/19.89k flops)
#   model_100/conv2d_1101/BiasAdd (19.49k/19.49k flops)
#   model_100/max_pooling2d_501/MaxPool (17.50k/17.50k flops)
#   model_100/conv2d_1102/BiasAdd (16.94k/16.94k flops)
#   model_100/dense_100/MatMul (3.20k/3.20k flops)
#   model_100/conv2d_1110/BiasAdd (160/160 flops)
#   model_100/dense_100/Softmax (50/50 flops)
#   model_100/dense_100/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.397596
# 2022-05-16 04:16:42.709798: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:16:42.709869: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:16:42.711341: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.19b flops)
#   model_101/conv2d_1118/Conv2D (371.79m/371.79m flops)
#   model_101/conv2d_1116/Conv2D (302.17m/302.17m flops)
#   model_101/conv2d_1117/Conv2D (215.21m/215.21m flops)
#   model_101/conv2d_1114/Conv2D (94.87m/94.87m flops)
#   model_101/conv2d_1115/Conv2D (89.56m/89.56m flops)
#   model_101/conv2d_1120/Conv2D (40.47m/40.47m flops)
#   model_101/conv2d_1112/Conv2D (39.30m/39.30m flops)
#   model_101/conv2d_1113/Conv2D (32.46m/32.46m flops)
#   model_101/conv2d_1111/Conv2D (1.17m/1.17m flops)
#   model_101/conv2d_1121/Conv2D (793.60k/793.60k flops)
#   model_101/max_pooling2d_505/MaxPool (64.74k/64.74k flops)
#   model_101/conv2d_1111/BiasAdd (64.74k/64.74k flops)
#   model_101/max_pooling2d_508/MaxPool (48.80k/48.80k flops)
#   model_101/conv2d_1116/BiasAdd (48.80k/48.80k flops)
#   model_101/conv2d_1118/BiasAdd (41.31k/41.31k flops)
#   model_101/conv2d_1120/BiasAdd (39.68k/39.68k flops)
#   model_101/conv2d_1112/BiasAdd (38.99k/38.99k flops)
#   model_101/conv2d_1114/BiasAdd (38.19k/38.19k flops)
#   model_101/max_pooling2d_506/MaxPool (34.99k/34.99k flops)
#   model_101/max_pooling2d_509/MaxPool (32.64k/32.64k flops)
#   model_101/max_pooling2d_507/MaxPool (32.54k/32.54k flops)
#   model_101/conv2d_1117/BiasAdd (24.50k/24.50k flops)
#   model_101/conv2d_1115/BiasAdd (22.02k/22.02k flops)
#   model_101/conv2d_1113/BiasAdd (16.70k/16.70k flops)
#   model_101/dense_101/MatMul (3.20k/3.20k flops)
#   model_101/conv2d_1121/BiasAdd (160/160 flops)
#   model_101/dense_101/Softmax (50/50 flops)
#   model_101/dense_101/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.144972
# 2022-05-16 04:16:43.349714: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:16:43.349787: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:16:43.351220: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.02b flops)
#   model_102/conv2d_1129/Conv2D (376.26m/376.26m flops)
#   model_102/conv2d_1127/Conv2D (189.33m/189.33m flops)
#   model_102/conv2d_1128/Conv2D (155.03m/155.03m flops)
#   model_102/conv2d_1125/Conv2D (120.34m/120.34m flops)
#   model_102/conv2d_1126/Conv2D (80.55m/80.55m flops)
#   model_102/conv2d_1124/Conv2D (35.21m/35.21m flops)
#   model_102/conv2d_1131/Conv2D (31.31m/31.31m flops)
#   model_102/conv2d_1123/Conv2D (28.10m/28.10m flops)
#   model_102/conv2d_1122/Conv2D (957.17k/957.17k flops)
#   model_102/conv2d_1132/Conv2D (616.32k/616.32k flops)
#   model_102/max_pooling2d_510/MaxPool (53.18k/53.18k flops)
#   model_102/conv2d_1122/BiasAdd (53.18k/53.18k flops)
#   model_102/conv2d_1129/BiasAdd (41.15k/41.15k flops)
#   model_102/conv2d_1125/BiasAdd (38.87k/38.87k flops)
#   model_102/conv2d_1127/BiasAdd (34.60k/34.60k flops)
#   model_102/max_pooling2d_513/MaxPool (34.60k/34.60k flops)
#   model_102/conv2d_1123/BiasAdd (33.93k/33.93k flops)
#   model_102/max_pooling2d_512/MaxPool (33.12k/33.12k flops)
#   model_102/max_pooling2d_514/MaxPool (32.51k/32.51k flops)
#   model_102/conv2d_1131/BiasAdd (30.82k/30.82k flops)
#   model_102/max_pooling2d_511/MaxPool (30.46k/30.46k flops)
#   model_102/conv2d_1128/BiasAdd (24.89k/24.89k flops)
#   model_102/conv2d_1124/BiasAdd (20.81k/20.81k flops)
#   model_102/conv2d_1126/BiasAdd (19.46k/19.46k flops)
#   model_102/dense_102/MatMul (3.20k/3.20k flops)
#   model_102/conv2d_1132/BiasAdd (160/160 flops)
#   model_102/dense_102/Softmax (50/50 flops)
#   model_102/dense_102/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.240324
# 2022-05-16 04:16:43.763629: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:16:43.763702: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:16:43.765241: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/924.06m flops)
#   model_103/conv2d_1140/Conv2D (266.74m/266.74m flops)
#   model_103/conv2d_1138/Conv2D (235.30m/235.30m flops)
#   model_103/conv2d_1139/Conv2D (150.19m/150.19m flops)
#   model_103/conv2d_1136/Conv2D (104.94m/104.94m flops)
#   model_103/conv2d_1137/Conv2D (68.64m/68.64m flops)
#   model_103/conv2d_1142/Conv2D (40.92m/40.92m flops)
#   model_103/conv2d_1135/Conv2D (27.60m/27.60m flops)
#   model_103/conv2d_1134/Conv2D (27.14m/27.14m flops)
#   model_103/conv2d_1133/Conv2D (1.21m/1.21m flops)
#   model_103/conv2d_1143/Conv2D (885.76k/885.76k flops)
#   model_103/max_pooling2d_515/MaxPool (67.05k/67.05k flops)
#   model_103/conv2d_1133/BiasAdd (67.05k/67.05k flops)
#   model_103/conv2d_1142/BiasAdd (44.29k/44.29k flops)
#   model_103/max_pooling2d_518/MaxPool (43.00k/43.00k flops)
#   model_103/conv2d_1138/BiasAdd (43.00k/43.00k flops)
#   model_103/conv2d_1140/BiasAdd (37.42k/37.42k flops)
#   model_103/conv2d_1136/BiasAdd (33.12k/33.12k flops)
#   model_103/max_pooling2d_519/MaxPool (29.57k/29.57k flops)
#   model_103/max_pooling2d_517/MaxPool (28.22k/28.22k flops)
#   model_103/conv2d_1134/BiasAdd (25.99k/25.99k flops)
#   model_103/max_pooling2d_516/MaxPool (23.33k/23.33k flops)
#   model_103/conv2d_1135/BiasAdd (21.30k/21.30k flops)
#   model_103/conv2d_1137/BiasAdd (19.46k/19.46k flops)
#   model_103/conv2d_1139/BiasAdd (19.40k/19.40k flops)
#   model_103/dense_103/MatMul (3.20k/3.20k flops)
#   model_103/conv2d_1143/BiasAdd (160/160 flops)
#   model_103/dense_103/Softmax (50/50 flops)
#   model_103/dense_103/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.24814
# 2022-05-16 04:16:44.166015: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:16:44.166094: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:16:44.167486: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/920.43m flops)
#   model_104/conv2d_1149/Conv2D (282.59m/282.59m flops)
#   model_104/conv2d_1151/Conv2D (225.19m/225.19m flops)
#   model_104/conv2d_1150/Conv2D (143.97m/143.97m flops)
#   model_104/conv2d_1147/Conv2D (99.51m/99.51m flops)
#   model_104/conv2d_1148/Conv2D (76.23m/76.23m flops)
#   model_104/conv2d_1153/Conv2D (35.57m/35.57m flops)
#   model_104/conv2d_1145/Conv2D (28.20m/28.20m flops)
#   model_104/conv2d_1146/Conv2D (26.53m/26.53m flops)
#   model_104/conv2d_1144/Conv2D (1.29m/1.29m flops)
#   model_104/conv2d_1154/Conv2D (842.88k/842.88k flops)
#   model_104/max_pooling2d_520/MaxPool (71.67k/71.67k flops)
#   model_104/conv2d_1144/BiasAdd (71.67k/71.67k flops)
#   model_104/max_pooling2d_523/MaxPool (44.60k/44.60k flops)
#   model_104/conv2d_1149/BiasAdd (44.60k/44.60k flops)
#   model_104/conv2d_1153/BiasAdd (42.14k/42.14k flops)
#   model_104/conv2d_1151/BiasAdd (34.18k/34.18k flops)
#   model_104/conv2d_1147/BiasAdd (31.77k/31.77k flops)
#   model_104/max_pooling2d_522/MaxPool (27.07k/27.07k flops)
#   model_104/max_pooling2d_524/MaxPool (27.01k/27.01k flops)
#   model_104/conv2d_1145/BiasAdd (25.27k/25.27k flops)
#   model_104/max_pooling2d_521/MaxPool (22.68k/22.68k flops)
#   model_104/conv2d_1148/BiasAdd (22.53k/22.53k flops)
#   model_104/conv2d_1146/BiasAdd (21.05k/21.05k flops)
#   model_104/conv2d_1150/BiasAdd (17.93k/17.93k flops)
#   model_104/dense_104/MatMul (3.20k/3.20k flops)
#   model_104/conv2d_1154/BiasAdd (160/160 flops)
#   model_104/dense_104/Softmax (50/50 flops)
#   model_104/dense_104/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.136356
# 2022-05-16 04:16:44.592002: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:16:44.592091: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:16:44.593469: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.10b flops)
#   model_105/conv2d_1160/Conv2D (380.81m/380.81m flops)
#   model_105/conv2d_1162/Conv2D (300.04m/300.04m flops)
#   model_105/conv2d_1161/Conv2D (189.20m/189.20m flops)
#   model_105/conv2d_1159/Conv2D (107.00m/107.00m flops)
#   model_105/conv2d_1158/Conv2D (47.31m/47.31m flops)
#   model_105/conv2d_1164/Conv2D (44.89m/44.89m flops)
#   model_105/conv2d_1156/Conv2D (14.50m/14.50m flops)
#   model_105/conv2d_1157/Conv2D (9.72m/9.72m flops)
#   model_105/conv2d_1165/Conv2D (951.04k/951.04k flops)
#   model_105/conv2d_1155/Conv2D (749.09k/749.09k flops)
#   model_105/max_pooling2d_528/MaxPool (49.20k/49.20k flops)
#   model_105/conv2d_1160/BiasAdd (49.20k/49.20k flops)
#   model_105/conv2d_1164/BiasAdd (47.55k/47.55k flops)
#   model_105/max_pooling2d_525/MaxPool (41.62k/41.62k flops)
#   model_105/conv2d_1155/BiasAdd (41.62k/41.62k flops)
#   model_105/conv2d_1162/BiasAdd (38.23k/38.23k flops)
#   model_105/conv2d_1158/BiasAdd (36.50k/36.50k flops)
#   model_105/max_pooling2d_527/MaxPool (31.10k/31.10k flops)
#   model_105/max_pooling2d_529/MaxPool (30.21k/30.21k flops)
#   model_105/conv2d_1159/BiasAdd (27.52k/27.52k flops)
#   model_105/conv2d_1156/BiasAdd (22.38k/22.38k flops)
#   model_105/conv2d_1161/BiasAdd (21.36k/21.36k flops)
#   model_105/max_pooling2d_526/MaxPool (20.09k/20.09k flops)
#   model_105/conv2d_1157/BiasAdd (8.71k/8.71k flops)
#   model_105/dense_105/MatMul (3.20k/3.20k flops)
#   model_105/conv2d_1165/BiasAdd (160/160 flops)
#   model_105/dense_105/Softmax (50/50 flops)
#   model_105/dense_105/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.25818
# 2022-05-16 04:16:45.183073: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:16:45.183154: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:16:45.184736: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.05b flops)
#   model_106/conv2d_1173/Conv2D (363.04m/363.04m flops)
#   model_106/conv2d_1171/Conv2D (255.04m/255.04m flops)
#   model_106/conv2d_1172/Conv2D (174.82m/174.82m flops)
#   model_106/conv2d_1170/Conv2D (99.25m/99.25m flops)
#   model_106/conv2d_1169/Conv2D (69.20m/69.20m flops)
#   model_106/conv2d_1175/Conv2D (47.01m/47.01m flops)
#   model_106/conv2d_1167/Conv2D (23.86m/23.86m flops)
#   model_106/conv2d_1168/Conv2D (13.92m/13.92m flops)
#   model_106/conv2d_1166/Conv2D (1.12m/1.12m flops)
#   model_106/conv2d_1176/Conv2D (940.16k/940.16k flops)
#   model_106/max_pooling2d_530/MaxPool (62.42k/62.42k flops)
#   model_106/conv2d_1166/BiasAdd (62.42k/62.42k flops)
#   model_106/conv2d_1175/BiasAdd (47.01k/47.01k flops)
#   model_106/conv2d_1169/BiasAdd (40.90k/40.90k flops)
#   model_106/conv2d_1173/BiasAdd (40.50k/40.50k flops)
#   model_106/conv2d_1171/BiasAdd (39.80k/39.80k flops)
#   model_106/max_pooling2d_533/MaxPool (39.80k/39.80k flops)
#   model_106/max_pooling2d_532/MaxPool (34.85k/34.85k flops)
#   model_106/max_pooling2d_534/MaxPool (32.00k/32.00k flops)
#   model_106/conv2d_1167/BiasAdd (24.55k/24.55k flops)
#   model_106/conv2d_1172/BiasAdd (24.40k/24.40k flops)
#   model_106/conv2d_1170/BiasAdd (22.78k/22.78k flops)
#   model_106/max_pooling2d_531/MaxPool (22.03k/22.03k flops)
#   model_106/conv2d_1168/BiasAdd (11.37k/11.37k flops)
#   model_106/dense_106/MatMul (3.20k/3.20k flops)
#   model_106/conv2d_1176/BiasAdd (160/160 flops)
#   model_106/dense_106/Softmax (50/50 flops)
#   model_106/dense_106/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.873532
# 2022-05-16 04:16:45.651036: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:16:45.651112: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:16:45.652657: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.04b flops)
#   model_107/conv2d_1184/Conv2D (367.42m/367.42m flops)
#   model_107/conv2d_1182/Conv2D (330.75m/330.75m flops)
#   model_107/conv2d_1183/Conv2D (197.47m/197.47m flops)
#   model_107/conv2d_1181/Conv2D (65.50m/65.50m flops)
#   model_107/conv2d_1180/Conv2D (32.74m/32.74m flops)
#   model_107/conv2d_1178/Conv2D (20.79m/20.79m flops)
#   model_107/conv2d_1186/Conv2D (10.89m/10.89m flops)
#   model_107/conv2d_1179/Conv2D (10.87m/10.87m flops)
#   model_107/conv2d_1177/Conv2D (1.04m/1.04m flops)
#   model_107/conv2d_1187/Conv2D (216.96k/216.96k flops)
#   model_107/max_pooling2d_535/MaxPool (57.80k/57.80k flops)
#   model_107/conv2d_1177/BiasAdd (57.80k/57.80k flops)
#   model_107/max_pooling2d_538/MaxPool (44.60k/44.60k flops)
#   model_107/conv2d_1182/BiasAdd (44.60k/44.60k flops)
#   model_107/conv2d_1184/BiasAdd (40.66k/40.66k flops)
#   model_107/max_pooling2d_539/MaxPool (32.13k/32.13k flops)
#   model_107/conv2d_1181/BiasAdd (26.37k/26.37k flops)
#   model_107/conv2d_1183/BiasAdd (24.60k/24.60k flops)
#   model_107/conv2d_1180/BiasAdd (23.32k/23.32k flops)
#   model_107/conv2d_1178/BiasAdd (23.10k/23.10k flops)
#   model_107/max_pooling2d_536/MaxPool (20.74k/20.74k flops)
#   model_107/max_pooling2d_537/MaxPool (19.87k/19.87k flops)
#   model_107/conv2d_1186/BiasAdd (10.85k/10.85k flops)
#   model_107/conv2d_1179/BiasAdd (9.44k/9.44k flops)
#   model_107/dense_107/MatMul (3.20k/3.20k flops)
#   model_107/conv2d_1187/BiasAdd (160/160 flops)
#   model_107/dense_107/Softmax (50/50 flops)
#   model_107/dense_107/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.277356
# 2022-05-16 04:16:46.138619: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:16:46.138691: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:16:46.140235: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/979.91m flops)
#   model_108/conv2d_1195/Conv2D (310.36m/310.36m flops)
#   model_108/conv2d_1193/Conv2D (212.52m/212.52m flops)
#   model_108/conv2d_1194/Conv2D (145.25m/145.25m flops)
#   model_108/conv2d_1191/Conv2D (107.69m/107.69m flops)
#   model_108/conv2d_1192/Conv2D (85.37m/85.37m flops)
#   model_108/conv2d_1197/Conv2D (45.01m/45.01m flops)
#   model_108/conv2d_1190/Conv2D (37.24m/37.24m flops)
#   model_108/conv2d_1189/Conv2D (34.08m/34.08m flops)
#   model_108/conv2d_1188/Conv2D (957.17k/957.17k flops)
#   model_108/conv2d_1198/Conv2D (926.08k/926.08k flops)
#   model_108/max_pooling2d_540/MaxPool (53.18k/53.18k flops)
#   model_108/conv2d_1188/BiasAdd (53.18k/53.18k flops)
#   model_108/conv2d_1197/BiasAdd (46.30k/46.30k flops)
#   model_108/conv2d_1189/BiasAdd (41.15k/41.15k flops)
#   model_108/conv2d_1191/BiasAdd (39.88k/39.88k flops)
#   model_108/conv2d_1195/BiasAdd (39.37k/39.37k flops)
#   model_108/conv2d_1193/BiasAdd (37.60k/37.60k flops)
#   model_108/max_pooling2d_543/MaxPool (37.60k/37.60k flops)
#   model_108/max_pooling2d_541/MaxPool (36.94k/36.94k flops)
#   model_108/max_pooling2d_542/MaxPool (33.98k/33.98k flops)
#   model_108/max_pooling2d_544/MaxPool (31.10k/31.10k flops)
#   model_108/conv2d_1194/BiasAdd (21.46k/21.46k flops)
#   model_108/conv2d_1192/BiasAdd (20.10k/20.10k flops)
#   model_108/conv2d_1190/BiasAdd (18.15k/18.15k flops)
#   model_108/dense_108/MatMul (3.20k/3.20k flops)
#   model_108/conv2d_1198/BiasAdd (160/160 flops)
#   model_108/dense_108/Softmax (50/50 flops)
#   model_108/dense_108/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.184628
# 2022-05-16 04:16:46.516324: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:16:46.516399: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:16:46.517929: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/992.85m flops)
#   model_109/conv2d_1206/Conv2D (358.64m/358.64m flops)
#   model_109/conv2d_1204/Conv2D (208.02m/208.02m flops)
#   model_109/conv2d_1205/Conv2D (149.53m/149.53m flops)
#   model_109/conv2d_1202/Conv2D (89.98m/89.98m flops)
#   model_109/conv2d_1203/Conv2D (66.95m/66.95m flops)
#   model_109/conv2d_1201/Conv2D (45.17m/45.17m flops)
#   model_109/conv2d_1208/Conv2D (43.92m/43.92m flops)
#   model_109/conv2d_1200/Conv2D (28.54m/28.54m flops)
#   model_109/conv2d_1209/Conv2D (874.88k/874.88k flops)
#   model_109/conv2d_1199/Conv2D (749.09k/749.09k flops)
#   model_109/conv2d_1200/BiasAdd (44.04k/44.04k flops)
#   model_109/conv2d_1208/BiasAdd (43.74k/43.74k flops)
#   model_109/max_pooling2d_545/MaxPool (41.62k/41.62k flops)
#   model_109/conv2d_1199/BiasAdd (41.62k/41.62k flops)
#   model_109/conv2d_1206/BiasAdd (40.66k/40.66k flops)
#   model_109/max_pooling2d_546/MaxPool (39.53k/39.53k flops)
#   model_109/conv2d_1204/BiasAdd (34.60k/34.60k flops)
#   model_109/max_pooling2d_548/MaxPool (34.60k/34.60k flops)
#   model_109/max_pooling2d_549/MaxPool (32.13k/32.13k flops)
#   model_109/conv2d_1202/BiasAdd (29.41k/29.41k flops)
#   model_109/max_pooling2d_547/MaxPool (25.06k/25.06k flops)
#   model_109/conv2d_1205/BiasAdd (24.01k/24.01k flops)
#   model_109/conv2d_1203/BiasAdd (21.38k/21.38k flops)
#   model_109/conv2d_1201/BiasAdd (20.57k/20.57k flops)
#   model_109/dense_109/MatMul (3.20k/3.20k flops)
#   model_109/conv2d_1209/BiasAdd (160/160 flops)
#   model_109/dense_109/Softmax (50/50 flops)
#   model_109/dense_109/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 5.023044
# 2022-05-16 04:16:46.899518: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:16:46.899593: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:16:46.901029: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/2.11b flops)
#   model_110/conv2d_1215/Conv2D (682.51m/682.51m flops)
#   model_110/conv2d_1217/Conv2D (478.29m/478.29m flops)
#   model_110/conv2d_1216/Conv2D (296.56m/296.56m flops)
#   model_110/conv2d_1214/Conv2D (248.50m/248.50m flops)
#   model_110/conv2d_1213/Conv2D (199.15m/199.15m flops)
#   model_110/conv2d_1211/Conv2D (72.06m/72.06m flops)
#   model_110/conv2d_1219/Conv2D (67.30m/67.30m flops)
#   model_110/conv2d_1212/Conv2D (62.59m/62.59m flops)
#   model_110/conv2d_1210/Conv2D (2.98m/2.98m flops)
#   model_110/conv2d_1220/Conv2D (1.38m/1.38m flops)
#   model_110/max_pooling2d_550/MaxPool (165.53k/165.53k flops)
#   model_110/conv2d_1210/BiasAdd (165.53k/165.53k flops)
#   model_110/conv2d_1211/BiasAdd (105.35k/105.35k flops)
#   model_110/max_pooling2d_551/MaxPool (99.42k/99.42k flops)
#   model_110/conv2d_1213/BiasAdd (98.78k/98.78k flops)
#   model_110/max_pooling2d_552/MaxPool (89.60k/89.60k flops)
#   model_110/conv2d_1215/BiasAdd (88.59k/88.59k flops)
#   model_110/max_pooling2d_553/MaxPool (88.59k/88.59k flops)
#   model_110/conv2d_1219/BiasAdd (68.95k/68.95k flops)
#   model_110/conv2d_1214/BiasAdd (61.63k/61.63k flops)
#   model_110/conv2d_1217/BiasAdd (59.05k/59.05k flops)
#   model_110/max_pooling2d_554/MaxPool (48.80k/48.80k flops)
#   model_110/conv2d_1212/BiasAdd (40.43k/40.43k flops)
#   model_110/conv2d_1216/BiasAdd (36.45k/36.45k flops)
#   model_110/dense_110/MatMul (5.00k/5.00k flops)
#   model_110/conv2d_1220/BiasAdd (250/250 flops)
#   model_110/dense_110/Softmax (50/50 flops)
#   model_110/dense_110/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 5.342324
# 2022-05-16 04:16:47.292649: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:16:47.292725: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:16:47.294136: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/2.31b flops)
#   model_111/conv2d_1226/Conv2D (596.05m/596.05m flops)
#   model_111/conv2d_1228/Conv2D (557.64m/557.64m flops)
#   model_111/conv2d_1227/Conv2D (363.01m/363.01m flops)
#   model_111/conv2d_1224/Conv2D (305.84m/305.84m flops)
#   model_111/conv2d_1225/Conv2D (198.57m/198.57m flops)
#   model_111/conv2d_1223/Conv2D (122.94m/122.94m flops)
#   model_111/conv2d_1222/Conv2D (82.47m/82.47m flops)
#   model_111/conv2d_1230/Conv2D (77.72m/77.72m flops)
#   model_111/conv2d_1221/Conv2D (2.67m/2.67m flops)
#   model_111/conv2d_1231/Conv2D (1.53m/1.53m flops)
#   model_111/max_pooling2d_555/MaxPool (148.10k/148.10k flops)
#   model_111/conv2d_1221/BiasAdd (148.10k/148.10k flops)
#   model_111/conv2d_1222/BiasAdd (134.75k/134.75k flops)
#   model_111/max_pooling2d_556/MaxPool (127.16k/127.16k flops)
#   model_111/conv2d_1224/BiasAdd (98.78k/98.78k flops)
#   model_111/conv2d_1226/BiasAdd (96.82k/96.82k flops)
#   model_111/max_pooling2d_558/MaxPool (96.82k/96.82k flops)
#   model_111/max_pooling2d_557/MaxPool (89.60k/89.60k flops)
#   model_111/conv2d_1230/BiasAdd (76.50k/76.50k flops)
#   model_111/conv2d_1223/BiasAdd (62.09k/62.09k flops)
#   model_111/conv2d_1228/BiasAdd (61.47k/61.47k flops)
#   model_111/max_pooling2d_559/MaxPool (50.80k/50.80k flops)
#   model_111/conv2d_1225/BiasAdd (49.25k/49.25k flops)
#   model_111/conv2d_1227/BiasAdd (40.82k/40.82k flops)
#   model_111/dense_111/MatMul (5.00k/5.00k flops)
#   model_111/conv2d_1231/BiasAdd (250/250 flops)
#   model_111/dense_111/Softmax (50/50 flops)
#   model_111/dense_111/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 5.64502
# 2022-05-16 04:16:47.692144: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:16:47.692222: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:16:47.693641: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/2.05b flops)
#   model_112/conv2d_1237/Conv2D (464.69m/464.69m flops)
#   model_112/conv2d_1239/Conv2D (449.94m/449.94m flops)
#   model_112/conv2d_1235/Conv2D (397.79m/397.79m flops)
#   model_112/conv2d_1238/Conv2D (279.69m/279.69m flops)
#   model_112/conv2d_1236/Conv2D (179.20m/179.20m flops)
#   model_112/conv2d_1234/Conv2D (106.67m/106.67m flops)
#   model_112/conv2d_1233/Conv2D (97.20m/97.20m flops)
#   model_112/conv2d_1241/Conv2D (67.73m/67.73m flops)
#   model_112/conv2d_1232/Conv2D (4.55m/4.55m flops)
#   model_112/conv2d_1242/Conv2D (1.42m/1.42m flops)
#   model_112/max_pooling2d_560/MaxPool (252.65k/252.65k flops)
#   model_112/conv2d_1232/BiasAdd (252.65k/252.65k flops)
#   model_112/conv2d_1235/BiasAdd (102.31k/102.31k flops)
#   model_112/conv2d_1233/BiasAdd (93.10k/93.10k flops)
#   model_112/max_pooling2d_562/MaxPool (92.80k/92.80k flops)
#   model_112/max_pooling2d_561/MaxPool (87.86k/87.86k flops)
#   model_112/conv2d_1237/BiasAdd (86.63k/86.63k flops)
#   model_112/max_pooling2d_563/MaxPool (86.63k/86.63k flops)
#   model_112/conv2d_1234/BiasAdd (77.98k/77.98k flops)
#   model_112/conv2d_1241/BiasAdd (71.15k/71.15k flops)
#   model_112/conv2d_1239/BiasAdd (57.60k/57.60k flops)
#   model_112/max_pooling2d_564/MaxPool (47.60k/47.60k flops)
#   model_112/conv2d_1236/BiasAdd (42.91k/42.91k flops)
#   model_112/conv2d_1238/BiasAdd (35.15k/35.15k flops)
#   model_112/dense_112/MatMul (5.00k/5.00k flops)
#   model_112/conv2d_1242/BiasAdd (250/250 flops)
#   model_112/dense_112/Softmax (50/50 flops)
#   model_112/dense_112/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 4.9901
# 2022-05-16 04:16:48.073528: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:16:48.073600: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:16:48.074995: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/2.19b flops)
#   model_113/conv2d_1248/Conv2D (821.49m/821.49m flops)
#   model_113/conv2d_1250/Conv2D (493.47m/493.47m flops)
#   model_113/conv2d_1249/Conv2D (348.31m/348.31m flops)
#   model_113/conv2d_1247/Conv2D (191.60m/191.60m flops)
#   model_113/conv2d_1246/Conv2D (144.79m/144.79m flops)
#   model_113/conv2d_1244/Conv2D (82.56m/82.56m flops)
#   model_113/conv2d_1245/Conv2D (57.78m/57.78m flops)
#   model_113/conv2d_1252/Conv2D (42.21m/42.21m flops)
#   model_113/conv2d_1243/Conv2D (3.76m/3.76m flops)
#   model_113/conv2d_1253/Conv2D (883.00k/883.00k flops)
#   model_113/conv2d_1243/BiasAdd (209.09k/209.09k flops)
#   model_113/max_pooling2d_565/MaxPool (209.09k/209.09k flops)
#   model_113/conv2d_1248/BiasAdd (98.78k/98.78k flops)
#   model_113/max_pooling2d_568/MaxPool (98.78k/98.78k flops)
#   model_113/conv2d_1244/BiasAdd (95.55k/95.55k flops)
#   model_113/max_pooling2d_566/MaxPool (90.17k/90.17k flops)
#   model_113/conv2d_1246/BiasAdd (70.56k/70.56k flops)
#   model_113/conv2d_1247/BiasAdd (66.53k/66.53k flops)
#   model_113/max_pooling2d_567/MaxPool (64.00k/64.00k flops)
#   model_113/conv2d_1250/BiasAdd (57.84k/57.84k flops)
#   model_113/max_pooling2d_569/MaxPool (47.80k/47.80k flops)
#   model_113/conv2d_1252/BiasAdd (44.15k/44.15k flops)
#   model_113/conv2d_1245/BiasAdd (41.15k/41.15k flops)
#   model_113/conv2d_1249/BiasAdd (38.39k/38.39k flops)
#   model_113/dense_113/MatMul (5.00k/5.00k flops)
#   model_113/conv2d_1253/BiasAdd (250/250 flops)
#   model_113/dense_113/Softmax (50/50 flops)
#   model_113/dense_113/BiasAdd (10/10 flops)
#
# ...
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/3.93b flops)
#   model_139/conv2d_1536/Conv2D (976.34m/976.34m flops)
#   model_139/conv2d_1534/Conv2D (885.49m/885.49m flops)
#   model_139/conv2d_1535/Conv2D (489.88m/489.88m flops)
#   model_139/conv2d_1532/Conv2D (485.84m/485.84m flops)
#   model_139/conv2d_1533/Conv2D (412.47m/412.47m flops)
#   model_139/conv2d_1530/Conv2D (363.61m/363.61m flops)
#   model_139/conv2d_1531/Conv2D (210.36m/210.36m flops)
#   model_139/conv2d_1538/Conv2D (84.72m/84.72m flops)
#   model_139/conv2d_1529/Conv2D (15.21m/15.21m flops)
#   model_139/conv2d_1539/Conv2D (1.72m/1.72m flops)
#   model_139/max_pooling2d_695/MaxPool (845.00k/845.00k flops)
#   model_139/conv2d_1529/BiasAdd (845.00k/845.00k flops)
#   model_139/conv2d_1530/BiasAdd (404.01k/404.01k flops)
#   model_139/max_pooling2d_696/MaxPool (392.04k/392.04k flops)
#   model_139/conv2d_1532/BiasAdd (254.63k/254.63k flops)
#   model_139/max_pooling2d_697/MaxPool (241.06k/241.06k flops)
#   model_139/max_pooling2d_698/MaxPool (159.72k/159.72k flops)
#   model_139/conv2d_1534/BiasAdd (159.72k/159.72k flops)
#   model_139/conv2d_1531/BiasAdd (129.85k/129.85k flops)
#   model_139/conv2d_1533/BiasAdd (123.20k/123.20k flops)
#   model_139/conv2d_1536/BiasAdd (111.15k/111.15k flops)
#   model_139/max_pooling2d_699/MaxPool (96.82k/96.82k flops)
#   model_139/conv2d_1538/BiasAdd (85.75k/85.75k flops)
#   model_139/conv2d_1535/BiasAdd (82.47k/82.47k flops)
#   model_139/dense_139/MatMul (9.80k/9.80k flops)
#   model_139/conv2d_1539/BiasAdd (490/490 flops)
#   model_139/dense_139/Softmax (50/50 flops)
#   model_139/dense_139/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 23.061892
# 2022-05-16 04:17:00.157400: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:00.157473: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:00.159116: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/8.78b flops)
#   model_140/conv2d_1545/Conv2D (2.21b/2.21b flops)
#   model_140/conv2d_1543/Conv2D (2.19b/2.19b flops)
#   model_140/conv2d_1547/Conv2D (1.15b/1.15b flops)
#   model_140/conv2d_1544/Conv2D (1.09b/1.09b flops)
#   model_140/conv2d_1546/Conv2D (776.56m/776.56m flops)
#   model_140/conv2d_1542/Conv2D (773.21m/773.21m flops)
#   model_140/conv2d_1541/Conv2D (380.93m/380.93m flops)
#   model_140/conv2d_1549/Conv2D (183.50m/183.50m flops)
#   model_140/conv2d_1540/Conv2D (15.12m/15.12m flops)
#   model_140/conv2d_1550/Conv2D (3.71m/3.71m flops)
#   model_140/conv2d_1540/BiasAdd (839.81k/839.81k flops)
#   model_140/max_pooling2d_700/MaxPool (839.81k/839.81k flops)
#   model_140/conv2d_1541/BiasAdd (661.34k/661.34k flops)
#   model_140/max_pooling2d_701/MaxPool (645.50k/645.50k flops)
#   model_140/conv2d_1543/BiasAdd (502.20k/502.20k flops)
#   model_140/max_pooling2d_702/MaxPool (480.13k/480.13k flops)
#   model_140/conv2d_1542/BiasAdd (447.46k/447.46k flops)
#   model_140/conv2d_1545/BiasAdd (289.33k/289.33k flops)
#   model_140/max_pooling2d_703/MaxPool (289.33k/289.33k flops)
#   model_140/conv2d_1544/BiasAdd (244.22k/244.22k flops)
#   model_140/conv2d_1549/BiasAdd (185.73k/185.73k flops)
#   model_140/conv2d_1547/BiasAdd (142.77k/142.77k flops)
#   model_140/max_pooling2d_704/MaxPool (126.46k/126.46k flops)
#   model_140/conv2d_1546/BiasAdd (100.80k/100.80k flops)
#   model_140/dense_140/MatMul (12.80k/12.80k flops)
#   model_140/conv2d_1550/BiasAdd (640/640 flops)
#   model_140/dense_140/Softmax (50/50 flops)
#   model_140/dense_140/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 27.648148
# 2022-05-16 04:17:00.566906: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:00.566981: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:00.568561: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/8.47b flops)
#   model_141/conv2d_1554/Conv2D (2.35b/2.35b flops)
#   model_141/conv2d_1556/Conv2D (1.71b/1.71b flops)
#   model_141/conv2d_1553/Conv2D (997.53m/997.53m flops)
#   model_141/conv2d_1555/Conv2D (921.72m/921.72m flops)
#   model_141/conv2d_1552/Conv2D (848.67m/848.67m flops)
#   model_141/conv2d_1558/Conv2D (848.18m/848.18m flops)
#   model_141/conv2d_1557/Conv2D (579.60m/579.60m flops)
#   model_141/conv2d_1560/Conv2D (170.48m/170.48m flops)
#   model_141/conv2d_1551/Conv2D (27.40m/27.40m flops)
#   model_141/conv2d_1561/Conv2D (3.72m/3.72m flops)
#   model_141/conv2d_1551/BiasAdd (1.52m/1.52m flops)
#   model_141/max_pooling2d_705/MaxPool (1.52m/1.52m flops)
#   model_141/conv2d_1552/BiasAdd (812.90k/812.90k flops)
#   model_141/max_pooling2d_706/MaxPool (793.43k/793.43k flops)
#   model_141/conv2d_1554/BiasAdd (514.35k/514.35k flops)
#   model_141/max_pooling2d_707/MaxPool (491.74k/491.74k flops)
#   model_141/conv2d_1553/BiasAdd (469.65k/469.65k flops)
#   model_141/conv2d_1556/BiasAdd (271.75k/271.75k flops)
#   model_141/max_pooling2d_708/MaxPool (271.75k/271.75k flops)
#   model_141/conv2d_1555/BiasAdd (201.60k/201.60k flops)
#   model_141/conv2d_1560/BiasAdd (186.11k/186.11k flops)
#   model_141/conv2d_1558/BiasAdd (132.36k/132.36k flops)
#   model_141/max_pooling2d_709/MaxPool (117.25k/117.25k flops)
#   model_141/conv2d_1557/BiasAdd (80.10k/80.10k flops)
#   model_141/dense_141/MatMul (12.80k/12.80k flops)
#   model_141/conv2d_1561/BiasAdd (640/640 flops)
#   model_141/dense_141/Softmax (50/50 flops)
#   model_141/dense_141/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 21.22494
# 2022-05-16 04:17:00.952174: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:00.952254: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:00.953777: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/6.24b flops)
#   model_142/conv2d_1567/Conv2D (1.71b/1.71b flops)
#   model_142/conv2d_1565/Conv2D (1.30b/1.30b flops)
#   model_142/conv2d_1569/Conv2D (687.91m/687.91m flops)
#   model_142/conv2d_1564/Conv2D (673.63m/673.63m flops)
#   model_142/conv2d_1568/Conv2D (670.87m/670.87m flops)
#   model_142/conv2d_1566/Conv2D (595.37m/595.37m flops)
#   model_142/conv2d_1563/Conv2D (463.77m/463.77m flops)
#   model_142/conv2d_1571/Conv2D (105.94m/105.94m flops)
#   model_142/conv2d_1562/Conv2D (16.06m/16.06m flops)
#   model_142/conv2d_1572/Conv2D (2.79m/2.79m flops)
#   model_142/conv2d_1562/BiasAdd (892.30k/892.30k flops)
#   model_142/max_pooling2d_710/MaxPool (892.30k/892.30k flops)
#   model_142/conv2d_1563/BiasAdd (757.79k/757.79k flops)
#   model_142/max_pooling2d_711/MaxPool (739.64k/739.64k flops)
#   model_142/conv2d_1565/BiasAdd (392.85k/392.85k flops)
#   model_142/max_pooling2d_712/MaxPool (375.58k/375.58k flops)
#   model_142/conv2d_1564/BiasAdd (340.22k/340.22k flops)
#   model_142/conv2d_1567/BiasAdd (321.78k/321.78k flops)
#   model_142/max_pooling2d_713/MaxPool (321.78k/321.78k flops)
#   model_142/conv2d_1566/BiasAdd (170.50k/170.50k flops)
#   model_142/conv2d_1571/BiasAdd (139.39k/139.39k flops)
#   model_142/conv2d_1569/BiasAdd (109.82k/109.82k flops)
#   model_142/max_pooling2d_714/MaxPool (97.28k/97.28k flops)
#   model_142/conv2d_1568/BiasAdd (78.30k/78.30k flops)
#   model_142/dense_142/MatMul (12.80k/12.80k flops)
#   model_142/conv2d_1572/BiasAdd (640/640 flops)
#   model_142/dense_142/Softmax (50/50 flops)
#   model_142/dense_142/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 28.1449
# 2022-05-16 04:17:01.324804: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:01.324891: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:01.326476: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/9.58b flops)
#   model_143/conv2d_1578/Conv2D (2.43b/2.43b flops)
#   model_143/conv2d_1576/Conv2D (1.81b/1.81b flops)
#   model_143/conv2d_1580/Conv2D (1.35b/1.35b flops)
#   model_143/conv2d_1577/Conv2D (1.12b/1.12b flops)
#   model_143/conv2d_1574/Conv2D (937.95m/937.95m flops)
#   model_143/conv2d_1579/Conv2D (937.74m/937.74m flops)
#   model_143/conv2d_1575/Conv2D (820.20m/820.20m flops)
#   model_143/conv2d_1582/Conv2D (130.69m/130.69m flops)
#   model_143/conv2d_1573/Conv2D (29.29m/29.29m flops)
#   model_143/conv2d_1583/Conv2D (2.56m/2.56m flops)
#   model_143/max_pooling2d_715/MaxPool (1.63m/1.63m flops)
#   model_143/conv2d_1573/BiasAdd (1.63m/1.63m flops)
#   model_143/conv2d_1574/BiasAdd (840.46k/840.46k flops)
#   model_143/max_pooling2d_716/MaxPool (820.33k/820.33k flops)
#   model_143/conv2d_1576/BiasAdd (498.15k/498.15k flops)
#   model_143/max_pooling2d_717/MaxPool (476.26k/476.26k flops)
#   model_143/conv2d_1575/BiasAdd (373.50k/373.50k flops)
#   model_143/max_pooling2d_718/MaxPool (306.90k/306.90k flops)
#   model_143/conv2d_1578/BiasAdd (306.90k/306.90k flops)
#   model_143/conv2d_1577/BiasAdd (253.44k/253.44k flops)
#   model_143/conv2d_1580/BiasAdd (147.39k/147.39k flops)
#   model_143/max_pooling2d_719/MaxPool (130.56k/130.56k flops)
#   model_143/conv2d_1582/BiasAdd (128.13k/128.13k flops)
#   model_143/conv2d_1579/BiasAdd (114.75k/114.75k flops)
#   model_143/dense_143/MatMul (12.80k/12.80k flops)
#   model_143/conv2d_1583/BiasAdd (640/640 flops)
#   model_143/dense_143/Softmax (50/50 flops)
#   model_143/dense_143/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
