# %% [markdown]
# # Multiple Linear Regression using the Ordinary Least Squares (OLS)

# %%
from time import time
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

df = pd.read_csv("training_data.csv")
x_train = df[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]]
y_train = df['Execution_time']

valid = pd.read_csv("valid_data.csv")
x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]]
y_valid = valid['Execution_time']


df_pred = pd.read_csv("test_data_NCV.csv")
x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]] 
y_test = df_pred['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]] 
# y_test = df_pred['Execution_time']

# df = pd.read_csv("training_data.csv")
# x_train = df[["Total_number_of_FLOPs","Total_trainable_parameters"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters"]] 
# y_test = df_pred['Execution_time']

# df = pd.read_csv("training_data.csv")
# x_train = df[["Total_number_of_FLOPs"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs"]] 
# y_test = df_pred['Execution_time']


x_train = sm.add_constant(x_train)
start = time()
olsmod = sm.OLS(y_train, x_train)
olsres = olsmod.fit()
stop = time()
training_time = stop-start

print(olsres.summary())

# predict on validation data
x_valid = sm.add_constant(x_valid)
y_valid_pred = olsres.predict(x_valid)

# Calculate percentage error
per_err = (y_valid - y_valid_pred) / y_valid

# Take absolute value of the percentage error (APE)
per_err = abs(per_err)*100

# Calculate the MAPE
MAPE_valid = sum(per_err)/len(per_err)

x_test = sm.add_constant(x_test)
y_pred = olsres.predict(x_test)


# Calculate percentage error
per_err = (y_test - y_pred) / y_test

# Take absolute value of the percentage error (APE)
per_err = abs(per_err)*100

# Calculate the MAPE
MAPE_test = sum(per_err)/len(per_err)
  
# Print the MAPE value 
print(f'''
MAPE during training of OLS : { round(MAPE_valid, 2) }
MAPE during testing of OLS  : { round(MAPE_test, 2) }
training time : {training_time}

''')

index=np.argsort(y_test)

plt.figure(figsize=(12,5))
plt.plot(np.arange(len(y_test)),y_test[index],"r",label="Measured Execution Time")
plt.scatter(np.arange(len(y_pred)),y_pred[index],s=10,c="b",label="Predicted Execution Time ")
plt.legend(loc="upper left")
plt.grid()
plt.ylabel("Execution Time(ms)")
plt.title("OLS: Predicted vs. Measured Execution Time of NCV")
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Execution_time   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 1.700e+04
# Date:                Thu, 30 Jun 2022   Prob (F-statistic):               0.00
# Time:                        02:05:00   Log-Likelihood:                -817.06
# No. Observations:                 425   AIC:                             1644.
# Df Residuals:                     420   BIC:                             1664.
# Df Model:                           4
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# const                                       -0.6592      0.161     -4.085      0.000      -0.976      -0.342
# Total_number_of_FLOPs                        2.1511      0.033     65.003      0.000       2.086       2.216
# Total_trainable_parameters                   0.3718      0.007     54.307      0.000       0.358       0.385
# Total_number_of_neurons                     20.4268      5.369      3.804      0.000       9.872      30.981
# Memory_allocated_by_activation_functions    -4.9943      1.358     -3.677      0.000      -7.664      -2.325
# ==============================================================================
# Omnibus:                      210.698   Durbin-Watson:                   2.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6127.134
# Skew:                           1.507   Prob(JB):                         0.00
# Kurtosis:                      21.355   Cond. No.                     2.91e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.91e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# MAPE during training of OLS : 6.42
# MAPE during testing of OLS  : 7.39
# training time : 0.0006656646728515625

# %% [markdown]
# # Multi-Layer Perceptrons (MLP)

# %% [markdown]
# # The numerber of hidden layer: 0

# %%
from time import time
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from itertools import product
from pandas.core.frame import DataFrame
import numpy as np
import csv
import matplotlib.pyplot as plt


# train = pd.read_csv("training_data+valid_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters"]] 
# y_test = df_pred['Execution_time']



# train = pd.read_csv("training_data+valid_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]] 
# y_test = df_pred['Execution_time']



# train = pd.read_csv("training_data+valid_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]] 
# y_test = df_pred['Execution_time']


scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_valid = scaler.fit_transform(x_valid)
x_test = scaler.fit_transform(x_test)
MAPE_default=10000
MAPE_better=MAPE_default

start = time()
    
model = tf.keras.Sequential(
                            tf.keras.layers.Dense(1, input_shape = x_train.shape[1:]))

model.compile(loss = tf.losses.mean_squared_error,
             optimizer = 'sgd')
model.summary()
history = model.fit(x_train, y_train, epochs=200)
stop = time()
training_time = stop-start
y_pred = model.predict(x_test)

y_test  = np.array(y_test).reshape(-1,1)

# Calculate percentage error
per_err = (y_test - y_pred) / y_test
#print(per_err)

# Take absolute value of the percentage error (APE)
per_err = abs(per_err)*100

# Calculate the MAPE
MAPE = sum(per_err)/len(per_err)


stop = time()

MAPE = DataFrame(MAPE)  
# Print the MAPE value 
print(f"""MAPE of MLP  : {round(MAPE, 2)},  

Training time : {training_time}s
     """)

y_test_sort=np.sort(y_test,axis=0)
y_pred_sort=np.sort(y_pred,axis=0)
# plt.figure(figsize=(13,6))
# plt.plot(np.arange(len(y_test)),y_test_sort,"r",label="original execution time")
# plt.scatter(np.arange(len(y_pred)),y_pred_sort,s=10,c="b",label="prediced execution time ")
# plt.legend(loc="upper left")
# plt.grid()
# plt.xlabel("The index of the model that need to be predicted")
# plt.ylabel("execution time(ms)")
# plt.title("Multi-Layer Perceptrons Results")
# plt.show()

plt.figure(figsize=(12,5))
plt.plot(np.arange(len(y_test)),y_test_sort,"r",label="Original Execution Time")
plt.scatter(np.arange(len(y_pred)),y_pred_sort,s=10,c="b",label="Predicted Execution Time ")
plt.legend(loc="upper left")
plt.grid()
plt.ylabel("Execution Time(ms)")
plt.title("MLP: Predicted vs. Measured Execution Time of NCV")
plt.show()
# Out:
# Model: "sequential_216"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_617 (Dense)            (None, 1)                 4
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 17/17 [==============================] - 0s 597us/step - loss: 889.4939
# Epoch 2/200
# 17/17 [==============================] - 0s 576us/step - loss: 390.0440
# Epoch 3/200
# 17/17 [==============================] - 0s 537us/step - loss: 187.1532
# Epoch 4/200
# 17/17 [==============================] - 0s 517us/step - loss: 96.4847
# Epoch 5/200
# 17/17 [==============================] - 0s 473us/step - loss: 53.9056
# Epoch 6/200
# 17/17 [==============================] - 0s 567us/step - loss: 32.6670
# Epoch 7/200
# 17/17 [==============================] - 0s 502us/step - loss: 21.9777
# Epoch 8/200
# 17/17 [==============================] - 0s 502us/step - loss: 16.2876
# Epoch 9/200
# 17/17 [==============================] - 0s 495us/step - loss: 13.1313
# Epoch 10/200
# 17/17 [==============================] - 0s 546us/step - loss: 11.2816
# Epoch 11/200
# 17/17 [==============================] - 0s 515us/step - loss: 10.1262
# Epoch 12/200
# 17/17 [==============================] - 0s 505us/step - loss: 9.3814
# Epoch 13/200
# 17/17 [==============================] - 0s 483us/step - loss: 8.8645
# Epoch 14/200
# 17/17 [==============================] - 0s 530us/step - loss: 8.4758
# Epoch 15/200
# 17/17 [==============================] - 0s 504us/step - loss: 8.1852
# Epoch 16/200
# 17/17 [==============================] - 0s 541us/step - loss: 7.9508
# Epoch 17/200
# 17/17 [==============================] - 0s 702us/step - loss: 7.7720
# Epoch 18/200
# 17/17 [==============================] - 0s 682us/step - loss: 7.6112
# Epoch 19/200
# 17/17 [==============================] - 0s 666us/step - loss: 7.4872
# Epoch 20/200
# 17/17 [==============================] - 0s 716us/step - loss: 7.3843
# Epoch 21/200
# 17/17 [==============================] - 0s 689us/step - loss: 7.3036
# Epoch 22/200
# 17/17 [==============================] - 0s 706us/step - loss: 7.2300
# Epoch 23/200
# 17/17 [==============================] - 0s 685us/step - loss: 7.1722
# Epoch 24/200
# 17/17 [==============================] - 0s 700us/step - loss: 7.1261
# Epoch 25/200
# 17/17 [==============================] - 0s 670us/step - loss: 7.0859
# Epoch 26/200
# 17/17 [==============================] - 0s 657us/step - loss: 7.0491
# Epoch 27/200
# 17/17 [==============================] - 0s 698us/step - loss: 7.0302
# Epoch 28/200
# 17/17 [==============================] - 0s 671us/step - loss: 6.9963
# Epoch 29/200
# 17/17 [==============================] - 0s 695us/step - loss: 6.9866
# Epoch 30/200
# 17/17 [==============================] - 0s 737us/step - loss: 6.9651
# Epoch 31/200
# 17/17 [==============================] - 0s 775us/step - loss: 6.9521
# Epoch 32/200
# 17/17 [==============================] - 0s 774us/step - loss: 6.9405
# Epoch 33/200
# 17/17 [==============================] - 0s 716us/step - loss: 6.9313
# Epoch 34/200
# 17/17 [==============================] - 0s 759us/step - loss: 6.9278
# Epoch 35/200
# 17/17 [==============================] - 0s 773us/step - loss: 6.9186
# Epoch 36/200
# 17/17 [==============================] - 0s 749us/step - loss: 6.9153
# Epoch 37/200
# 17/17 [==============================] - 0s 760us/step - loss: 6.9085
# Epoch 38/200
# 17/17 [==============================] - 0s 752us/step - loss: 6.9009
# Epoch 39/200
# 17/17 [==============================] - 0s 737us/step - loss: 6.9005
# Epoch 40/200
# 17/17 [==============================] - 0s 747us/step - loss: 6.9026
# Epoch 41/200
# 17/17 [==============================] - 0s 757us/step - loss: 6.8968
# Epoch 42/200
# 17/17 [==============================] - 0s 754us/step - loss: 6.8946
# Epoch 43/200
# 17/17 [==============================] - 0s 731us/step - loss: 6.8987
# Epoch 44/200
# 17/17 [==============================] - 0s 781us/step - loss: 6.8957
# Epoch 45/200
# 17/17 [==============================] - 0s 828us/step - loss: 6.8891
# Epoch 46/200
# 17/17 [==============================] - 0s 771us/step - loss: 6.8959
# Epoch 47/200
# 17/17 [==============================] - 0s 801us/step - loss: 6.8958
# Epoch 48/200
# 17/17 [==============================] - 0s 732us/step - loss: 6.8975
# Epoch 49/200
# 17/17 [==============================] - 0s 712us/step - loss: 6.8957
# Epoch 50/200
# 17/17 [==============================] - 0s 697us/step - loss: 6.8887
# Epoch 51/200
# 17/17 [==============================] - 0s 765us/step - loss: 6.8940
# Epoch 52/200
# 17/17 [==============================] - 0s 730us/step - loss: 6.8893
# Epoch 53/200
# 17/17 [==============================] - 0s 730us/step - loss: 6.8857
# Epoch 54/200
# 17/17 [==============================] - 0s 719us/step - loss: 6.8941
# Epoch 55/200
# 17/17 [==============================] - 0s 775us/step - loss: 6.8910
# Epoch 56/200
# 17/17 [==============================] - 0s 716us/step - loss: 6.8917
# Epoch 57/200
# 17/17 [==============================] - 0s 783us/step - loss: 6.8875
# Epoch 58/200
# 17/17 [==============================] - 0s 743us/step - loss: 6.8946
# Epoch 59/200
# 17/17 [==============================] - 0s 761us/step - loss: 6.9002
# Epoch 60/200
# 17/17 [==============================] - 0s 758us/step - loss: 6.8910
# Epoch 61/200
# 17/17 [==============================] - 0s 750us/step - loss: 6.8861
# Epoch 62/200
# 17/17 [==============================] - 0s 756us/step - loss: 6.8889
# Epoch 63/200
# 17/17 [==============================] - 0s 718us/step - loss: 6.8851
# Epoch 64/200
# 17/17 [==============================] - 0s 796us/step - loss: 6.8902
# Epoch 65/200
# 17/17 [==============================] - 0s 710us/step - loss: 6.8955
# Epoch 66/200
# 17/17 [==============================] - 0s 758us/step - loss: 6.8921
# Epoch 67/200
# 17/17 [==============================] - 0s 736us/step - loss: 6.8903
# Epoch 68/200
# 17/17 [==============================] - 0s 749us/step - loss: 6.8892
# Epoch 69/200
# 17/17 [==============================] - 0s 778us/step - loss: 6.8974
# Epoch 70/200
# 17/17 [==============================] - 0s 782us/step - loss: 6.8868
# Epoch 71/200
# 17/17 [==============================] - 0s 693us/step - loss: 6.8931
# Epoch 72/200
# 17/17 [==============================] - 0s 742us/step - loss: 6.8885
# Epoch 73/200
# 17/17 [==============================] - 0s 705us/step - loss: 6.8947
# Epoch 74/200
# 17/17 [==============================] - 0s 760us/step - loss: 6.8878
# Epoch 75/200
# 17/17 [==============================] - 0s 783us/step - loss: 6.8955
# Epoch 76/200
# 17/17 [==============================] - 0s 765us/step - loss: 6.8928
# Epoch 77/200
# 17/17 [==============================] - 0s 791us/step - loss: 6.8893
# Epoch 78/200
# 17/17 [==============================] - 0s 724us/step - loss: 6.8881
# Epoch 79/200
# 17/17 [==============================] - 0s 772us/step - loss: 6.8874
# Epoch 80/200
# 17/17 [==============================] - 0s 743us/step - loss: 6.8888
# Epoch 81/200
# 17/17 [==============================] - 0s 766us/step - loss: 6.8889
# Epoch 82/200
# 17/17 [==============================] - 0s 703us/step - loss: 6.8858
# Epoch 83/200
# 17/17 [==============================] - 0s 758us/step - loss: 6.8958
# Epoch 84/200
# 17/17 [==============================] - 0s 749us/step - loss: 6.8897
# Epoch 85/200
# 17/17 [==============================] - 0s 699us/step - loss: 6.8922
# Epoch 86/200
# 17/17 [==============================] - 0s 749us/step - loss: 6.8899
# Epoch 87/200
# 17/17 [==============================] - 0s 768us/step - loss: 6.8965
# Epoch 88/200
# 17/17 [==============================] - 0s 780us/step - loss: 6.8859
# Epoch 89/200
# 17/17 [==============================] - 0s 780us/step - loss: 6.8904
# Epoch 90/200
# 17/17 [==============================] - 0s 712us/step - loss: 6.8903
# Epoch 91/200
# 17/17 [==============================] - 0s 722us/step - loss: 6.8871
# Epoch 92/200
# 17/17 [==============================] - 0s 749us/step - loss: 6.8883
# Epoch 93/200
# 17/17 [==============================] - 0s 784us/step - loss: 6.8902
# Epoch 94/200
# 17/17 [==============================] - 0s 760us/step - loss: 6.8873
# Epoch 95/200
# 17/17 [==============================] - 0s 700us/step - loss: 6.8918
# Epoch 96/200
# 17/17 [==============================] - 0s 721us/step - loss: 6.8924
# Epoch 97/200
# 17/17 [==============================] - 0s 714us/step - loss: 6.8901
# Epoch 98/200
# 17/17 [==============================] - 0s 775us/step - loss: 6.8836
# Epoch 99/200
# 17/17 [==============================] - 0s 747us/step - loss: 6.8928
# Epoch 100/200
# 17/17 [==============================] - 0s 771us/step - loss: 6.8928
# Epoch 101/200
# 17/17 [==============================] - 0s 771us/step - loss: 6.8937
# Epoch 102/200
# 17/17 [==============================] - 0s 732us/step - loss: 6.8922
# Epoch 103/200
# 17/17 [==============================] - 0s 760us/step - loss: 6.8879
# Epoch 104/200
# 17/17 [==============================] - 0s 670us/step - loss: 6.8844
# Epoch 105/200
# 17/17 [==============================] - 0s 753us/step - loss: 6.8870
# Epoch 106/200
# 17/17 [==============================] - 0s 756us/step - loss: 6.8865
# Epoch 107/200
# 17/17 [==============================] - 0s 768us/step - loss: 6.8916
# Epoch 108/200
# 17/17 [==============================] - 0s 723us/step - loss: 6.8885
# Epoch 109/200
# 17/17 [==============================] - 0s 775us/step - loss: 6.8913
# Epoch 110/200
# 17/17 [==============================] - 0s 684us/step - loss: 6.8864
# Epoch 111/200
# 17/17 [==============================] - 0s 766us/step - loss: 6.8948
# Epoch 112/200
# 17/17 [==============================] - 0s 767us/step - loss: 6.8921
# Epoch 113/200
# 17/17 [==============================] - 0s 768us/step - loss: 6.8872
# Epoch 114/200
# 17/17 [==============================] - 0s 822us/step - loss: 6.9007
# Epoch 115/200
# 17/17 [==============================] - 0s 770us/step - loss: 6.8897
# Epoch 116/200
# 17/17 [==============================] - 0s 792us/step - loss: 6.8875
# Epoch 117/200
# 17/17 [==============================] - 0s 711us/step - loss: 6.8943
# Epoch 118/200
# 17/17 [==============================] - 0s 773us/step - loss: 6.8888
# Epoch 119/200
# 17/17 [==============================] - 0s 719us/step - loss: 6.8941
# Epoch 120/200
# 17/17 [==============================] - 0s 777us/step - loss: 6.8868
# Epoch 121/200
# 17/17 [==============================] - 0s 751us/step - loss: 6.8918
# Epoch 122/200
# 17/17 [==============================] - 0s 730us/step - loss: 6.8877
# Epoch 123/200
# 17/17 [==============================] - 0s 729us/step - loss: 6.8841
# Epoch 124/200
# 17/17 [==============================] - 0s 773us/step - loss: 6.8878
# Epoch 125/200
# 17/17 [==============================] - 0s 774us/step - loss: 6.8946
# Epoch 126/200
# 17/17 [==============================] - 0s 796us/step - loss: 6.8912
# Epoch 127/200
# 17/17 [==============================] - 0s 767us/step - loss: 6.8882
# Epoch 128/200
# 17/17 [==============================] - 0s 741us/step - loss: 6.8870
# Epoch 129/200
# 17/17 [==============================] - 0s 700us/step - loss: 6.8947
# Epoch 130/200
# 17/17 [==============================] - 0s 784us/step - loss: 6.8913
# Epoch 131/200
# 17/17 [==============================] - 0s 736us/step - loss: 6.8948
# Epoch 132/200
# 17/17 [==============================] - 0s 751us/step - loss: 6.8891
# Epoch 133/200
# 17/17 [==============================] - 0s 725us/step - loss: 6.8871
# Epoch 134/200
# 17/17 [==============================] - 0s 787us/step - loss: 6.8891
# Epoch 135/200
# 17/17 [==============================] - 0s 773us/step - loss: 6.8882
# Epoch 136/200
# 17/17 [==============================] - 0s 778us/step - loss: 6.8938
# Epoch 137/200
# 17/17 [==============================] - 0s 729us/step - loss: 6.8909
# Epoch 138/200
# 17/17 [==============================] - 0s 766us/step - loss: 6.8908
# Epoch 139/200
# 17/17 [==============================] - 0s 748us/step - loss: 6.8895
# Epoch 140/200
# 17/17 [==============================] - 0s 775us/step - loss: 6.8933
# Epoch 141/200
# 17/17 [==============================] - 0s 702us/step - loss: 6.8937
# Epoch 142/200
# 17/17 [==============================] - 0s 735us/step - loss: 6.8856
# Epoch 143/200
# 17/17 [==============================] - 0s 733us/step - loss: 6.8879
# Epoch 144/200
# 17/17 [==============================] - 0s 781us/step - loss: 6.8869
# Epoch 145/200
# 17/17 [==============================] - 0s 770us/step - loss: 6.8935
# Epoch 146/200
# 17/17 [==============================] - 0s 734us/step - loss: 6.8842
# Epoch 147/200
# 17/17 [==============================] - 0s 759us/step - loss: 6.8869
# Epoch 148/200
# 17/17 [==============================] - 0s 784us/step - loss: 6.8920
# Epoch 149/200
# 17/17 [==============================] - 0s 781us/step - loss: 6.8897
# Epoch 150/200
# 17/17 [==============================] - 0s 740us/step - loss: 6.8855
# Epoch 151/200
# 17/17 [==============================] - 0s 773us/step - loss: 6.8894
# Epoch 152/200
# 17/17 [==============================] - 0s 702us/step - loss: 6.8965
# Epoch 153/200
# 17/17 [==============================] - 0s 750us/step - loss: 6.8870
# Epoch 154/200
# 17/17 [==============================] - 0s 749us/step - loss: 6.8865
# Epoch 155/200
# 17/17 [==============================] - 0s 720us/step - loss: 6.8894
# Epoch 156/200
# 17/17 [==============================] - 0s 773us/step - loss: 6.8884
# Epoch 157/200
# 17/17 [==============================] - 0s 765us/step - loss: 6.8912
# Epoch 158/200
# 17/17 [==============================] - 0s 753us/step - loss: 6.8998
# Epoch 159/200
# 17/17 [==============================] - 0s 764us/step - loss: 6.8934
# Epoch 160/200
# 17/17 [==============================] - 0s 779us/step - loss: 6.8977
# Epoch 161/200
# 17/17 [==============================] - 0s 774us/step - loss: 6.9003
# Epoch 162/200
# 17/17 [==============================] - 0s 743us/step - loss: 6.8916
# Epoch 163/200
# 17/17 [==============================] - 0s 746us/step - loss: 6.8887
# Epoch 164/200
# 17/17 [==============================] - 0s 747us/step - loss: 6.8883
# Epoch 165/200
# 17/17 [==============================] - 0s 730us/step - loss: 6.8929
# Epoch 166/200
# 17/17 [==============================] - 0s 713us/step - loss: 6.8896
# Epoch 167/200
# 17/17 [==============================] - 0s 753us/step - loss: 6.8892
# Epoch 168/200
# 17/17 [==============================] - 0s 758us/step - loss: 6.8898
# Epoch 169/200
# 17/17 [==============================] - 0s 746us/step - loss: 6.8907
# Epoch 170/200
# 17/17 [==============================] - 0s 692us/step - loss: 6.8893
# Epoch 171/200
# 17/17 [==============================] - 0s 743us/step - loss: 6.8923
# Epoch 172/200
# 17/17 [==============================] - 0s 753us/step - loss: 6.8893
# Epoch 173/200
# 17/17 [==============================] - 0s 704us/step - loss: 6.8878
# Epoch 174/200
# 17/17 [==============================] - 0s 781us/step - loss: 6.8897
# Epoch 175/200
# 17/17 [==============================] - 0s 694us/step - loss: 6.8921
# Epoch 176/200
# 17/17 [==============================] - 0s 753us/step - loss: 6.8947
# Epoch 177/200
# 17/17 [==============================] - 0s 764us/step - loss: 6.8950
# Epoch 178/200
# 17/17 [==============================] - 0s 705us/step - loss: 6.8906
# Epoch 179/200
# 17/17 [==============================] - 0s 749us/step - loss: 6.8988
# Epoch 180/200
# 17/17 [==============================] - 0s 732us/step - loss: 6.8974
# Epoch 181/200
# 17/17 [==============================] - 0s 766us/step - loss: 6.8885
# Epoch 182/200
# 17/17 [==============================] - 0s 758us/step - loss: 6.8893
# Epoch 183/200
# 17/17 [==============================] - 0s 730us/step - loss: 6.8855
# Epoch 184/200
# 17/17 [==============================] - 0s 703us/step - loss: 6.8934
# Epoch 185/200
# 17/17 [==============================] - 0s 770us/step - loss: 6.8894
# Epoch 186/200
# 17/17 [==============================] - 0s 744us/step - loss: 6.8914
# Epoch 187/200
# 17/17 [==============================] - 0s 756us/step - loss: 6.8900
# Epoch 188/200
# 17/17 [==============================] - 0s 768us/step - loss: 6.8932
# Epoch 189/200
# 17/17 [==============================] - 0s 759us/step - loss: 6.8905
# Epoch 190/200
# 17/17 [==============================] - 0s 749us/step - loss: 6.8981
# Epoch 191/200
# 17/17 [==============================] - 0s 789us/step - loss: 6.8900
# Epoch 192/200
# 17/17 [==============================] - 0s 749us/step - loss: 6.8885
# Epoch 193/200
# 17/17 [==============================] - 0s 789us/step - loss: 6.8946
# Epoch 194/200
# 17/17 [==============================] - 0s 777us/step - loss: 6.8910
# Epoch 195/200
# 17/17 [==============================] - 0s 767us/step - loss: 6.8978
# Epoch 196/200
# 17/17 [==============================] - 0s 718us/step - loss: 6.8971
# Epoch 197/200
# 17/17 [==============================] - 0s 764us/step - loss: 6.8927
# Epoch 198/200
# 17/17 [==============================] - 0s 770us/step - loss: 6.8933
# Epoch 199/200
# 17/17 [==============================] - 0s 761us/step - loss: 6.8927
# Epoch 200/200
# 17/17 [==============================] - 0s 741us/step - loss: 6.8923
# MAPE of MLP  :        0
# 0  42.99,
#
# Training time : 2.929119825363159s

# %% [markdown]
# # The numerber of hidden layer: 1

# %%
from time import time
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from itertools import product
from pandas.core.frame import DataFrame
import numpy as np
import csv
import matplotlib.pyplot as plt


# train = pd.read_csv("training_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters"]] 
# y_test = df_pred['Execution_time']



train = pd.read_csv("training_data.csv")
x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]]
y_train = train['Execution_time']

valid = pd.read_csv("valid_data.csv")
x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]]
y_valid = valid['Execution_time']

df_pred = pd.read_csv("test_data_NCV.csv")
x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]] 
y_test = df_pred['Execution_time']



# train = pd.read_csv("training_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]] 
# y_test = df_pred['Execution_time']



scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_valid = scaler.fit_transform(x_valid)
x_test = scaler.fit_transform(x_test)
MAPE_default=10000
MAPE_better=MAPE_default
range_neuron_first_layer =range(4,12,1)
start = time()
for num_neuron_first_layer in range_neuron_first_layer:
    
    model = tf.keras.Sequential([tf.keras.layers.Dense(num_neuron_first_layer, activation = 'sigmoid', input_shape = x_train.shape[1:]),
                                 
                                tf.keras.layers.Dense(1)])

    model.compile(loss = tf.losses.mean_squared_error,
                 optimizer = 'sgd')
    history = model.fit(x_train, y_train, epochs=200)

    y_valid_current = model.predict(x_valid)

    y_valid  = np.array(y_valid).reshape(-1,1)

    # Calculate percentage error
    per_err = (y_valid - y_valid_current) / y_valid

    # Take absolute value of the percentage error (APE)
    per_err = abs(per_err)*100

    # Calculate the MAPE
    MAPE = sum(per_err)/len(per_err)

    if ( MAPE < MAPE_better ):
        better_num_neuron_first_layer = num_neuron_first_layer
        MAPE_better = MAPE
stop = time()
tunning_time = stop-start        
start = time()
model = tf.keras.Sequential([tf.keras.layers.Dense(num_neuron_first_layer, activation = 'sigmoid', input_shape = x_train.shape[1:]),
                                 
                                tf.keras.layers.Dense(1)])
model.compile(loss = tf.losses.mean_squared_error,
                 optimizer = 'sgd')
history = model.fit(x_train, y_train, epochs=200)
stop = time()
training_time = stop-start 

y_pred = model.predict(x_valid)

y_test  = np.array(y_valid).reshape(-1,1)
per_err = (y_test - y_pred) / y_test
per_err = abs(per_err)*100
MAPE = sum(per_err)/len(per_err)

MAPE = DataFrame(MAPE)  
# Print the MAPE value 
print(f"""MAPE of MLP  :" , {round(MAPE, 2)}
lowest MAPE in training process:" ,{MAPE_better}
the number of neurons of fist layer :{ better_num_neuron_first_layer },
Tunning time : {tunning_time}s,
Training time : {training_time}s
     """)

y_test_sort=np.sort(y_test,axis=0)
y_pred_sort=np.sort(y_pred,axis=0)
plt.figure(figsize=(12,5))
plt.plot(np.arange(len(y_test)),y_test_sort,"r",label="Original Execution Time")
plt.scatter(np.arange(len(y_pred)),y_pred_sort,s=10,c="b",label="Predicted Execution Time ")
plt.legend(loc="upper left")
plt.grid()
plt.ylabel("Execution Time(ms)")
plt.title("MLP: Predicted vs. Measured Execution Time of NCV")
plt.show()
# Out:
# Epoch 1/200
# 14/14 [==============================] - 0s 568us/step - loss: 863.4219
# Epoch 2/200
# 14/14 [==============================] - 0s 650us/step - loss: 437.1268
# Epoch 3/200
# 14/14 [==============================] - 0s 565us/step - loss: 255.0977
# Epoch 4/200
# 14/14 [==============================] - 0s 525us/step - loss: 165.8320
# Epoch 5/200
# 14/14 [==============================] - 0s 500us/step - loss: 119.4108
# Epoch 6/200
# 14/14 [==============================] - 0s 513us/step - loss: 93.8998
# Epoch 7/200
# 14/14 [==============================] - 0s 486us/step - loss: 76.1358
# Epoch 8/200
# 14/14 [==============================] - 0s 557us/step - loss: 65.8433
# Epoch 9/200
# 14/14 [==============================] - 0s 542us/step - loss: 57.4819
# Epoch 10/200
# 14/14 [==============================] - 0s 531us/step - loss: 51.5425
# Epoch 11/200
# 14/14 [==============================] - 0s 557us/step - loss: 46.8407
# Epoch 12/200
# 14/14 [==============================] - 0s 541us/step - loss: 42.7098
# Epoch 13/200
# 14/14 [==============================] - 0s 523us/step - loss: 38.8939
# Epoch 14/200
# 14/14 [==============================] - 0s 574us/step - loss: 36.0429
# Epoch 15/200
# 14/14 [==============================] - 0s 546us/step - loss: 33.7457
# Epoch 16/200
# 14/14 [==============================] - 0s 557us/step - loss: 31.3755
# Epoch 17/200
# 14/14 [==============================] - 0s 573us/step - loss: 29.4230
# Epoch 18/200
# 14/14 [==============================] - 0s 600us/step - loss: 27.5756
# Epoch 19/200
# 14/14 [==============================] - 0s 560us/step - loss: 25.7832
# Epoch 20/200
# 14/14 [==============================] - 0s 605us/step - loss: 24.2048
# Epoch 21/200
# 14/14 [==============================] - 0s 589us/step - loss: 22.8006
# Epoch 22/200
# 14/14 [==============================] - 0s 580us/step - loss: 21.4195
# Epoch 23/200
# 14/14 [==============================] - 0s 581us/step - loss: 20.0392
# Epoch 24/200
# 14/14 [==============================] - 0s 583us/step - loss: 18.8032
# Epoch 25/200
# 14/14 [==============================] - 0s 545us/step - loss: 17.6252
# Epoch 26/200
# 14/14 [==============================] - 0s 538us/step - loss: 17.0466
# Epoch 27/200
# 14/14 [==============================] - 0s 570us/step - loss: 15.9944
# Epoch 28/200
# 14/14 [==============================] - 0s 579us/step - loss: 15.0122
# Epoch 29/200
# 14/14 [==============================] - 0s 556us/step - loss: 14.3799
# Epoch 30/200
# 14/14 [==============================] - 0s 613us/step - loss: 13.3544
# Epoch 31/200
# 14/14 [==============================] - 0s 565us/step - loss: 12.7313
# Epoch 32/200
# 14/14 [==============================] - 0s 593us/step - loss: 12.1826
# Epoch 33/200
# 14/14 [==============================] - 0s 600us/step - loss: 11.7158
# Epoch 34/200
# 14/14 [==============================] - 0s 608us/step - loss: 11.1312
# Epoch 35/200
# 14/14 [==============================] - 0s 592us/step - loss: 10.7182
# Epoch 36/200
# 14/14 [==============================] - 0s 562us/step - loss: 10.3610
# Epoch 37/200
# 14/14 [==============================] - 0s 558us/step - loss: 10.3126
# Epoch 38/200
# 14/14 [==============================] - 0s 603us/step - loss: 9.6160
# Epoch 39/200
# 14/14 [==============================] - 0s 603us/step - loss: 9.2463
# Epoch 40/200
# 14/14 [==============================] - 0s 613us/step - loss: 9.0968
# Epoch 41/200
# 14/14 [==============================] - 0s 592us/step - loss: 8.7700
# Epoch 42/200
# 14/14 [==============================] - 0s 644us/step - loss: 8.5325
# Epoch 43/200
# 14/14 [==============================] - 0s 687us/step - loss: 8.2389
# Epoch 44/200
# 14/14 [==============================] - 0s 708us/step - loss: 8.0608
# Epoch 45/200
# 14/14 [==============================] - 0s 707us/step - loss: 7.8014
# Epoch 46/200
# 14/14 [==============================] - 0s 716us/step - loss: 7.6372
# Epoch 47/200
# 14/14 [==============================] - 0s 705us/step - loss: 7.9325
# Epoch 48/200
# 14/14 [==============================] - 0s 745us/step - loss: 7.3092
# Epoch 49/200
# 14/14 [==============================] - 0s 709us/step - loss: 7.1995
# Epoch 50/200
# 14/14 [==============================] - 0s 685us/step - loss: 6.9771
# Epoch 51/200
# 14/14 [==============================] - 0s 705us/step - loss: 6.7593
# Epoch 52/200
# 14/14 [==============================] - 0s 733us/step - loss: 6.6020
# Epoch 53/200
# 14/14 [==============================] - 0s 687us/step - loss: 6.4929
# Epoch 54/200
# 14/14 [==============================] - 0s 723us/step - loss: 6.4125
# Epoch 55/200
# 14/14 [==============================] - 0s 693us/step - loss: 6.1911
# Epoch 56/200
# 14/14 [==============================] - 0s 702us/step - loss: 6.1051
# Epoch 57/200
# 14/14 [==============================] - 0s 730us/step - loss: 6.0062
# Epoch 58/200
# 14/14 [==============================] - 0s 696us/step - loss: 5.8623
# Epoch 59/200
# 14/14 [==============================] - 0s 725us/step - loss: 5.8635
# Epoch 60/200
# 14/14 [==============================] - 0s 676us/step - loss: 5.7604
# Epoch 61/200
# 14/14 [==============================] - 0s 695us/step - loss: 5.6427
# Epoch 62/200
# 14/14 [==============================] - 0s 688us/step - loss: 5.5343
# Epoch 63/200
# 14/14 [==============================] - 0s 707us/step - loss: 5.4608
# Epoch 64/200
# 14/14 [==============================] - 0s 704us/step - loss: 5.4555
# Epoch 65/200
# 14/14 [==============================] - 0s 705us/step - loss: 5.3779
# Epoch 66/200
# 14/14 [==============================] - 0s 719us/step - loss: 5.3266
# Epoch 67/200
# 14/14 [==============================] - 0s 709us/step - loss: 5.1157
# Epoch 68/200
# 14/14 [==============================] - 0s 712us/step - loss: 4.9324
# Epoch 69/200
# 14/14 [==============================] - 0s 737us/step - loss: 5.1267
# Epoch 70/200
# 14/14 [==============================] - 0s 721us/step - loss: 5.6696
# Epoch 71/200
# 14/14 [==============================] - 0s 694us/step - loss: 4.9924
# Epoch 72/200
# 14/14 [==============================] - 0s 715us/step - loss: 4.8364
# Epoch 73/200
# 14/14 [==============================] - 0s 694us/step - loss: 4.8402
# Epoch 74/200
# 14/14 [==============================] - 0s 738us/step - loss: 5.1018
# Epoch 75/200
# 14/14 [==============================] - 0s 667us/step - loss: 4.7302
# Epoch 76/200
# 14/14 [==============================] - 0s 700us/step - loss: 4.6683
# Epoch 77/200
# 14/14 [==============================] - 0s 719us/step - loss: 4.7058
# Epoch 78/200
# 14/14 [==============================] - 0s 732us/step - loss: 4.5640
# Epoch 79/200
# 14/14 [==============================] - 0s 734us/step - loss: 4.5352
# Epoch 80/200
# 14/14 [==============================] - 0s 687us/step - loss: 4.6504
# Epoch 81/200
# 14/14 [==============================] - 0s 668us/step - loss: 4.5000
# Epoch 82/200
# 14/14 [==============================] - 0s 713us/step - loss: 4.6434
# Epoch 83/200
# 14/14 [==============================] - 0s 746us/step - loss: 4.4306
# Epoch 84/200
# 14/14 [==============================] - 0s 794us/step - loss: 4.3887
# Epoch 85/200
# 14/14 [==============================] - 0s 731us/step - loss: 4.4219
# Epoch 86/200
# 14/14 [==============================] - 0s 709us/step - loss: 4.3412
# Epoch 87/200
# 14/14 [==============================] - 0s 723us/step - loss: 4.3315
# Epoch 88/200
# 14/14 [==============================] - 0s 699us/step - loss: 4.3218
# Epoch 89/200
# 14/14 [==============================] - 0s 743us/step - loss: 4.2648
# Epoch 90/200
# 14/14 [==============================] - 0s 684us/step - loss: 4.0696
# Epoch 91/200
# 14/14 [==============================] - 0s 670us/step - loss: 4.1078
# Epoch 92/200
# 14/14 [==============================] - 0s 691us/step - loss: 4.1684
# Epoch 93/200
# 14/14 [==============================] - 0s 673us/step - loss: 4.2122
# Epoch 94/200
# 14/14 [==============================] - 0s 667us/step - loss: 4.0556
# Epoch 95/200
# 14/14 [==============================] - 0s 742us/step - loss: 4.2516
# Epoch 96/200
# 14/14 [==============================] - 0s 727us/step - loss: 4.0900
# Epoch 97/200
# 14/14 [==============================] - 0s 728us/step - loss: 4.0501
# Epoch 98/200
# 14/14 [==============================] - 0s 720us/step - loss: 4.0169
# Epoch 99/200
# 14/14 [==============================] - 0s 726us/step - loss: 3.8728
# Epoch 100/200
# 14/14 [==============================] - 0s 700us/step - loss: 4.0124
# Epoch 101/200
# 14/14 [==============================] - 0s 696us/step - loss: 3.8810
# Epoch 102/200
# 14/14 [==============================] - 0s 650us/step - loss: 3.9441
# Epoch 103/200
# 14/14 [==============================] - 0s 696us/step - loss: 3.7962
# Epoch 104/200
# 14/14 [==============================] - 0s 721us/step - loss: 3.8463
# Epoch 105/200
# 14/14 [==============================] - 0s 693us/step - loss: 3.8366
# Epoch 106/200
# 14/14 [==============================] - 0s 734us/step - loss: 3.7642
# Epoch 107/200
# 14/14 [==============================] - 0s 742us/step - loss: 3.7655
# Epoch 108/200
# 14/14 [==============================] - 0s 738us/step - loss: 3.6985
# Epoch 109/200
# 14/14 [==============================] - 0s 717us/step - loss: 3.6985
# Epoch 110/200
# 14/14 [==============================] - 0s 712us/step - loss: 3.7254
# Epoch 111/200
# 14/14 [==============================] - 0s 679us/step - loss: 3.7697
# Epoch 112/200
# 14/14 [==============================] - 0s 714us/step - loss: 3.6211
# Epoch 113/200
# 14/14 [==============================] - 0s 670us/step - loss: 4.0918
# Epoch 114/200
# 14/14 [==============================] - 0s 691us/step - loss: 3.7020
# Epoch 115/200
# 14/14 [==============================] - 0s 681us/step - loss: 3.5432
# Epoch 116/200
# 14/14 [==============================] - 0s 761us/step - loss: 3.5775
# Epoch 117/200
# 14/14 [==============================] - 0s 722us/step - loss: 3.5394
# Epoch 118/200
# 14/14 [==============================] - 0s 716us/step - loss: 3.5296
# Epoch 119/200
# 14/14 [==============================] - 0s 705us/step - loss: 3.5058
# Epoch 120/200
# 14/14 [==============================] - 0s 691us/step - loss: 3.6112
# Epoch 121/200
# 14/14 [==============================] - 0s 725us/step - loss: 3.4953
# Epoch 122/200
# 14/14 [==============================] - 0s 714us/step - loss: 3.4750
# Epoch 123/200
# 14/14 [==============================] - 0s 657us/step - loss: 3.4977
# Epoch 124/200
# 14/14 [==============================] - 0s 711us/step - loss: 3.5276
# Epoch 125/200
# 14/14 [==============================] - 0s 705us/step - loss: 3.4671
# Epoch 126/200
# 14/14 [==============================] - 0s 710us/step - loss: 3.4596
# Epoch 127/200
# 14/14 [==============================] - 0s 711us/step - loss: 3.3718
# Epoch 128/200
# 14/14 [==============================] - 0s 710us/step - loss: 3.4634
# Epoch 129/200
# 14/14 [==============================] - 0s 729us/step - loss: 3.4169
# Epoch 130/200
# 14/14 [==============================] - 0s 685us/step - loss: 3.4576
# Epoch 131/200
# 14/14 [==============================] - 0s 697us/step - loss: 3.4052
# Epoch 132/200
# 14/14 [==============================] - 0s 728us/step - loss: 3.3761
# Epoch 133/200
# 14/14 [==============================] - 0s 669us/step - loss: 3.4046
# Epoch 134/200
# 14/14 [==============================] - 0s 730us/step - loss: 3.3129
# Epoch 135/200
# 14/14 [==============================] - 0s 713us/step - loss: 3.3184
# Epoch 136/200
# 14/14 [==============================] - 0s 707us/step - loss: 3.3737
# Epoch 137/200
# 14/14 [==============================] - 0s 734us/step - loss: 3.3090
# Epoch 138/200
# 14/14 [==============================] - 0s 721us/step - loss: 3.3039
# Epoch 139/200
# 14/14 [==============================] - 0s 681us/step - loss: 3.3107
# Epoch 140/200
# 14/14 [==============================] - 0s 733us/step - loss: 3.3389
# Epoch 141/200
# 14/14 [==============================] - 0s 699us/step - loss: 3.2077
# Epoch 142/200
# 14/14 [==============================] - 0s 772us/step - loss: 3.2563
# Epoch 143/200
# 14/14 [==============================] - 0s 727us/step - loss: 3.4325
# Epoch 144/200
# 14/14 [==============================] - 0s 725us/step - loss: 3.1796
# Epoch 145/200
# 14/14 [==============================] - 0s 704us/step - loss: 3.2741
# Epoch 146/200
# 14/14 [==============================] - 0s 769us/step - loss: 3.2493
# Epoch 147/200
# 14/14 [==============================] - 0s 733us/step - loss: 3.2661
# Epoch 148/200
# 14/14 [==============================] - 0s 703us/step - loss: 3.1396
# Epoch 149/200
# 14/14 [==============================] - 0s 665us/step - loss: 3.2705
# Epoch 150/200
# 14/14 [==============================] - 0s 708us/step - loss: 3.1780
# Epoch 151/200
# 14/14 [==============================] - 0s 725us/step - loss: 3.1262
# Epoch 152/200
# 14/14 [==============================] - 0s 657us/step - loss: 3.1329
# Epoch 153/200
# 14/14 [==============================] - 0s 720us/step - loss: 3.1017
# Epoch 154/200
# 14/14 [==============================] - 0s 690us/step - loss: 3.1358
# Epoch 155/200
# 14/14 [==============================] - 0s 698us/step - loss: 3.1142
# Epoch 156/200
# 14/14 [==============================] - 0s 713us/step - loss: 3.1958
# Epoch 157/200
# 14/14 [==============================] - 0s 700us/step - loss: 3.0633
# Epoch 158/200
# 14/14 [==============================] - 0s 714us/step - loss: 3.0806
# Epoch 159/200
# 14/14 [==============================] - 0s 682us/step - loss: 3.3213
# Epoch 160/200
# 14/14 [==============================] - 0s 696us/step - loss: 3.0380
# Epoch 161/200
# 14/14 [==============================] - 0s 748us/step - loss: 3.1557
# Epoch 162/200
# 14/14 [==============================] - 0s 731us/step - loss: 3.1827
# Epoch 163/200
# 14/14 [==============================] - 0s 735us/step - loss: 3.1348
# Epoch 164/200
# 14/14 [==============================] - 0s 710us/step - loss: 3.0288
# Epoch 165/200
# 14/14 [==============================] - 0s 681us/step - loss: 3.0210
# Epoch 166/200
# 14/14 [==============================] - 0s 695us/step - loss: 3.0145
# Epoch 167/200
# 14/14 [==============================] - 0s 701us/step - loss: 3.0022
# Epoch 168/200
# 14/14 [==============================] - 0s 684us/step - loss: 3.0979
# Epoch 169/200
# 14/14 [==============================] - 0s 692us/step - loss: 3.0846
# Epoch 170/200
# 14/14 [==============================] - 0s 711us/step - loss: 3.0475
# Epoch 171/200
# 14/14 [==============================] - 0s 794us/step - loss: 3.0288
# Epoch 172/200
# 14/14 [==============================] - 0s 716us/step - loss: 3.0637
# Epoch 173/200
# 14/14 [==============================] - 0s 719us/step - loss: 2.9821
# Epoch 174/200
# 14/14 [==============================] - 0s 707us/step - loss: 3.0443
# Epoch 175/200
# 14/14 [==============================] - 0s 724us/step - loss: 2.9679
# Epoch 176/200
# 14/14 [==============================] - 0s 736us/step - loss: 2.9973
# Epoch 177/200
# 14/14 [==============================] - 0s 726us/step - loss: 3.4578
# Epoch 178/200
# 14/14 [==============================] - 0s 698us/step - loss: 2.9912
# Epoch 179/200
# 14/14 [==============================] - 0s 693us/step - loss: 2.9482
# Epoch 180/200
# 14/14 [==============================] - 0s 716us/step - loss: 3.0288
# Epoch 181/200
# 14/14 [==============================] - 0s 722us/step - loss: 2.9683
# Epoch 182/200
# 14/14 [==============================] - 0s 827us/step - loss: 2.9829
# Epoch 183/200
# 14/14 [==============================] - 0s 732us/step - loss: 2.9167
# Epoch 184/200
# 14/14 [==============================] - 0s 680us/step - loss: 2.9063
# Epoch 185/200
# 14/14 [==============================] - 0s 734us/step - loss: 2.9477
# Epoch 186/200
# 14/14 [==============================] - 0s 666us/step - loss: 2.9614
# Epoch 187/200
# 14/14 [==============================] - 0s 715us/step - loss: 3.0406
# Epoch 188/200
# 14/14 [==============================] - 0s 729us/step - loss: 2.9080
# Epoch 189/200
# 14/14 [==============================] - 0s 706us/step - loss: 2.9249
# Epoch 190/200
# 14/14 [==============================] - 0s 737us/step - loss: 2.9235
# Epoch 191/200
# 14/14 [==============================] - 0s 703us/step - loss: 3.0421
# Epoch 192/200
# 14/14 [==============================] - 0s 667us/step - loss: 2.9532
# Epoch 193/200
# 14/14 [==============================] - 0s 692us/step - loss: 2.9285
# Epoch 194/200
# 14/14 [==============================] - 0s 713us/step - loss: 3.3280
# Epoch 195/200
# 14/14 [==============================] - 0s 742us/step - loss: 2.9683
# Epoch 196/200
# 14/14 [==============================] - 0s 718us/step - loss: 3.3723
# Epoch 197/200
# 14/14 [==============================] - 0s 689us/step - loss: 2.9149
# Epoch 198/200
# 14/14 [==============================] - 0s 668us/step - loss: 2.8504
# Epoch 199/200
# 14/14 [==============================] - 0s 714us/step - loss: 2.9661
# Epoch 200/200
# 14/14 [==============================] - 0s 714us/step - loss: 2.8505
# Epoch 1/200
# 14/14 [==============================] - 0s 578us/step - loss: 695.0894
# Epoch 2/200
# 14/14 [==============================] - 0s 617us/step - loss: 253.5269
# Epoch 3/200
# 14/14 [==============================] - 0s 520us/step - loss: 139.5360
# Epoch 4/200
# 14/14 [==============================] - 0s 523us/step - loss: 96.6505
# Epoch 5/200
# 14/14 [==============================] - 0s 522us/step - loss: 73.2330
# Epoch 6/200
# 14/14 [==============================] - 0s 524us/step - loss: 57.4537
# Epoch 7/200
# 14/14 [==============================] - 0s 501us/step - loss: 47.4678
# Epoch 8/200
# 14/14 [==============================] - 0s 542us/step - loss: 40.5145
# Epoch 9/200
# 14/14 [==============================] - 0s 548us/step - loss: 35.8172
# Epoch 10/200
# 14/14 [==============================] - 0s 517us/step - loss: 31.7107
# Epoch 11/200
# 14/14 [==============================] - 0s 537us/step - loss: 28.8251
# Epoch 12/200
# 14/14 [==============================] - 0s 550us/step - loss: 26.4750
# Epoch 13/200
# 14/14 [==============================] - 0s 561us/step - loss: 24.4456
# Epoch 14/200
# 14/14 [==============================] - 0s 533us/step - loss: 22.7929
# Epoch 15/200
# 14/14 [==============================] - 0s 563us/step - loss: 21.3865
# Epoch 16/200
# 14/14 [==============================] - 0s 530us/step - loss: 20.1642
# Epoch 17/200
# 14/14 [==============================] - 0s 568us/step - loss: 18.9848
# Epoch 18/200
# 14/14 [==============================] - 0s 750us/step - loss: 17.9508
# Epoch 19/200
# 14/14 [==============================] - 0s 624us/step - loss: 17.0324
# Epoch 20/200
# 14/14 [==============================] - 0s 677us/step - loss: 16.0881
# Epoch 21/200
# 14/14 [==============================] - 0s 645us/step - loss: 15.3544
# Epoch 22/200
# 14/14 [==============================] - 0s 614us/step - loss: 14.6686
# Epoch 23/200
# 14/14 [==============================] - 0s 691us/step - loss: 13.9099
# Epoch 24/200
# 14/14 [==============================] - 0s 653us/step - loss: 13.1388
# Epoch 25/200
# 14/14 [==============================] - 0s 649us/step - loss: 12.5400
# Epoch 26/200
# 14/14 [==============================] - 0s 645us/step - loss: 11.8552
# Epoch 27/200
# 14/14 [==============================] - 0s 683us/step - loss: 11.2369
# Epoch 28/200
# 14/14 [==============================] - 0s 594us/step - loss: 10.9606
# Epoch 29/200
# 14/14 [==============================] - 0s 618us/step - loss: 10.1160
# Epoch 30/200
# 14/14 [==============================] - 0s 662us/step - loss: 9.7259
# Epoch 31/200
# 14/14 [==============================] - 0s 679us/step - loss: 9.2072
# Epoch 32/200
# 14/14 [==============================] - 0s 634us/step - loss: 8.7415
# Epoch 33/200
# 14/14 [==============================] - 0s 665us/step - loss: 8.4123
# Epoch 34/200
# 14/14 [==============================] - 0s 601us/step - loss: 8.0695
# Epoch 35/200
# 14/14 [==============================] - 0s 615us/step - loss: 7.7761
# Epoch 36/200
# 14/14 [==============================] - 0s 655us/step - loss: 7.3706
# Epoch 37/200
# 14/14 [==============================] - 0s 630us/step - loss: 7.1699
# Epoch 38/200
# 14/14 [==============================] - 0s 658us/step - loss: 6.8671
# Epoch 39/200
# 14/14 [==============================] - 0s 638us/step - loss: 6.6415
# Epoch 40/200
# 14/14 [==============================] - 0s 650us/step - loss: 6.4139
# Epoch 41/200
# 14/14 [==============================] - 0s 661us/step - loss: 6.2255
# Epoch 42/200
# 14/14 [==============================] - 0s 624us/step - loss: 6.1283
# Epoch 43/200
# 14/14 [==============================] - 0s 635us/step - loss: 6.0500
# Epoch 44/200
# 14/14 [==============================] - 0s 678us/step - loss: 5.8711
# Epoch 45/200
# 14/14 [==============================] - 0s 655us/step - loss: 5.6340
# Epoch 46/200
# 14/14 [==============================] - 0s 658us/step - loss: 5.6750
# Epoch 47/200
# 14/14 [==============================] - 0s 599us/step - loss: 5.6992
# Epoch 48/200
# 14/14 [==============================] - 0s 664us/step - loss: 5.3788
# Epoch 49/200
# 14/14 [==============================] - 0s 622us/step - loss: 5.3086
# Epoch 50/200
# 14/14 [==============================] - 0s 663us/step - loss: 5.2895
# Epoch 51/200
# 14/14 [==============================] - 0s 658us/step - loss: 5.1394
# Epoch 52/200
# 14/14 [==============================] - 0s 650us/step - loss: 5.1429
# Epoch 53/200
# 14/14 [==============================] - 0s 648us/step - loss: 4.9391
# Epoch 54/200
# 14/14 [==============================] - 0s 648us/step - loss: 5.0245
# Epoch 55/200
# 14/14 [==============================] - 0s 639us/step - loss: 4.7791
# Epoch 56/200
# 14/14 [==============================] - 0s 638us/step - loss: 4.8121
# Epoch 57/200
# 14/14 [==============================] - 0s 613us/step - loss: 4.7699
# Epoch 58/200
# 14/14 [==============================] - 0s 647us/step - loss: 4.6693
# Epoch 59/200
# 14/14 [==============================] - 0s 648us/step - loss: 4.7370
# Epoch 60/200
# 14/14 [==============================] - 0s 635us/step - loss: 4.7662
# Epoch 61/200
# 14/14 [==============================] - 0s 660us/step - loss: 4.5975
# Epoch 62/200
# 14/14 [==============================] - 0s 652us/step - loss: 4.4957
# Epoch 63/200
# 14/14 [==============================] - 0s 671us/step - loss: 4.5134
# Epoch 64/200
# 14/14 [==============================] - 0s 656us/step - loss: 4.5270
# Epoch 65/200
# 14/14 [==============================] - 0s 653us/step - loss: 4.3626
# Epoch 66/200
# 14/14 [==============================] - 0s 653us/step - loss: 4.3592
# Epoch 67/200
# 14/14 [==============================] - 0s 622us/step - loss: 4.3866
# Epoch 68/200
# 14/14 [==============================] - 0s 617us/step - loss: 4.2879
# Epoch 69/200
# 14/14 [==============================] - 0s 625us/step - loss: 4.2261
# Epoch 70/200
# 14/14 [==============================] - 0s 644us/step - loss: 4.1684
# Epoch 71/200
# 14/14 [==============================] - 0s 625us/step - loss: 4.2291
# Epoch 72/200
# 14/14 [==============================] - 0s 636us/step - loss: 4.1041
# Epoch 73/200
# 14/14 [==============================] - 0s 639us/step - loss: 4.1872
# Epoch 74/200
# 14/14 [==============================] - 0s 681us/step - loss: 4.0833
# Epoch 75/200
# 14/14 [==============================] - 0s 640us/step - loss: 4.0531
# Epoch 76/200
# 14/14 [==============================] - 0s 698us/step - loss: 3.9711
# Epoch 77/200
# 14/14 [==============================] - 0s 683us/step - loss: 3.9496
# Epoch 78/200
# 14/14 [==============================] - 0s 646us/step - loss: 3.9450
# Epoch 79/200
# 14/14 [==============================] - 0s 663us/step - loss: 3.9417
# Epoch 80/200
# 14/14 [==============================] - 0s 632us/step - loss: 4.0598
# Epoch 81/200
# 14/14 [==============================] - 0s 654us/step - loss: 3.9606
# Epoch 82/200
# 14/14 [==============================] - 0s 642us/step - loss: 3.8448
# Epoch 83/200
# 14/14 [==============================] - 0s 644us/step - loss: 3.9782
# Epoch 84/200
# 14/14 [==============================] - 0s 659us/step - loss: 3.7313
# Epoch 85/200
# 14/14 [==============================] - 0s 643us/step - loss: 3.7411
# Epoch 86/200
# 14/14 [==============================] - 0s 687us/step - loss: 3.8417
# Epoch 87/200
# 14/14 [==============================] - 0s 689us/step - loss: 3.7643
# Epoch 88/200
# 14/14 [==============================] - 0s 653us/step - loss: 3.6998
# Epoch 89/200
# 14/14 [==============================] - 0s 622us/step - loss: 3.6762
# Epoch 90/200
# 14/14 [==============================] - 0s 626us/step - loss: 3.7182
# Epoch 91/200
# 14/14 [==============================] - 0s 650us/step - loss: 3.6945
# Epoch 92/200
# 14/14 [==============================] - 0s 679us/step - loss: 3.6493
# Epoch 93/200
# 14/14 [==============================] - 0s 680us/step - loss: 3.6777
# Epoch 94/200
# 14/14 [==============================] - 0s 643us/step - loss: 3.6524
# Epoch 95/200
# 14/14 [==============================] - 0s 620us/step - loss: 3.5494
# Epoch 96/200
# 14/14 [==============================] - 0s 631us/step - loss: 3.5969
# Epoch 97/200
# 14/14 [==============================] - 0s 620us/step - loss: 3.5309
# Epoch 98/200
# 14/14 [==============================] - 0s 664us/step - loss: 3.5030
# Epoch 99/200
# 14/14 [==============================] - 0s 619us/step - loss: 3.6863
# Epoch 100/200
# 14/14 [==============================] - 0s 648us/step - loss: 3.5081
# Epoch 101/200
# 14/14 [==============================] - 0s 626us/step - loss: 3.4696
# Epoch 102/200
# 14/14 [==============================] - 0s 668us/step - loss: 3.4848
# Epoch 103/200
# 14/14 [==============================] - 0s 649us/step - loss: 3.4259
# Epoch 104/200
# 14/14 [==============================] - 0s 688us/step - loss: 3.4408
# Epoch 105/200
# 14/14 [==============================] - 0s 638us/step - loss: 3.4859
# Epoch 106/200
# 14/14 [==============================] - 0s 645us/step - loss: 3.4305
# Epoch 107/200
# 14/14 [==============================] - 0s 632us/step - loss: 3.3912
# Epoch 108/200
# 14/14 [==============================] - 0s 640us/step - loss: 3.3875
# Epoch 109/200
# 14/14 [==============================] - 0s 638us/step - loss: 3.3613
# Epoch 110/200
# 14/14 [==============================] - 0s 671us/step - loss: 3.3010
# Epoch 111/200
# 14/14 [==============================] - 0s 638us/step - loss: 3.3665
# Epoch 112/200
# 14/14 [==============================] - 0s 680us/step - loss: 3.3619
# Epoch 113/200
# 14/14 [==============================] - 0s 621us/step - loss: 3.4426
# Epoch 114/200
# 14/14 [==============================] - 0s 649us/step - loss: 3.3546
# Epoch 115/200
# 14/14 [==============================] - 0s 665us/step - loss: 3.2281
# Epoch 116/200
# 14/14 [==============================] - 0s 646us/step - loss: 3.4130
# Epoch 117/200
# 14/14 [==============================] - 0s 625us/step - loss: 3.2647
# Epoch 118/200
# 14/14 [==============================] - 0s 619us/step - loss: 3.2023
# Epoch 119/200
# 14/14 [==============================] - 0s 667us/step - loss: 3.3097
# Epoch 120/200
# 14/14 [==============================] - 0s 638us/step - loss: 3.2545
# Epoch 121/200
# 14/14 [==============================] - 0s 671us/step - loss: 3.2182
# Epoch 122/200
# 14/14 [==============================] - 0s 668us/step - loss: 3.1997
# Epoch 123/200
# 14/14 [==============================] - 0s 636us/step - loss: 3.2746
# Epoch 124/200
# 14/14 [==============================] - 0s 641us/step - loss: 3.2080
# Epoch 125/200
# 14/14 [==============================] - 0s 652us/step - loss: 3.1478
# Epoch 126/200
# 14/14 [==============================] - 0s 667us/step - loss: 3.1501
# Epoch 127/200
# 14/14 [==============================] - 0s 623us/step - loss: 3.0712
# Epoch 128/200
# 14/14 [==============================] - 0s 626us/step - loss: 3.2405
# Epoch 129/200
# 14/14 [==============================] - 0s 637us/step - loss: 3.1971
# Epoch 130/200
# 14/14 [==============================] - 0s 657us/step - loss: 3.2123
# Epoch 131/200
# 14/14 [==============================] - 0s 673us/step - loss: 3.1592
# Epoch 132/200
# 14/14 [==============================] - 0s 679us/step - loss: 3.1079
# Epoch 133/200
# 14/14 [==============================] - 0s 750us/step - loss: 3.1613
# Epoch 134/200
# 14/14 [==============================] - 0s 669us/step - loss: 3.1075
# Epoch 135/200
# 14/14 [==============================] - 0s 635us/step - loss: 3.1060
# Epoch 136/200
# 14/14 [==============================] - 0s 631us/step - loss: 3.0647
# Epoch 137/200
# 14/14 [==============================] - 0s 658us/step - loss: 3.1614
# Epoch 138/200
# 14/14 [==============================] - 0s 663us/step - loss: 3.1122
# Epoch 139/200
# 14/14 [==============================] - 0s 631us/step - loss: 3.0357
# Epoch 140/200
# 14/14 [==============================] - 0s 645us/step - loss: 3.0539
# Epoch 141/200
# 14/14 [==============================] - 0s 634us/step - loss: 3.1406
# Epoch 142/200
# 14/14 [==============================] - 0s 620us/step - loss: 2.9688
# Epoch 143/200
# 14/14 [==============================] - 0s 658us/step - loss: 3.1690
# Epoch 144/200
# 14/14 [==============================] - 0s 639us/step - loss: 3.0096
# Epoch 145/200
# 14/14 [==============================] - 0s 649us/step - loss: 2.9952
# Epoch 146/200
# 14/14 [==============================] - 0s 681us/step - loss: 3.0099
# Epoch 147/200
# 14/14 [==============================] - 0s 659us/step - loss: 2.9960
# Epoch 148/200
# 14/14 [==============================] - 0s 636us/step - loss: 2.9770
# Epoch 149/200
# 14/14 [==============================] - 0s 638us/step - loss: 2.9486
# Epoch 150/200
# 14/14 [==============================] - 0s 684us/step - loss: 2.9712
# Epoch 151/200
# 14/14 [==============================] - 0s 751us/step - loss: 2.9842
# Epoch 152/200
# 14/14 [==============================] - 0s 619us/step - loss: 2.9801
# Epoch 153/200
# 14/14 [==============================] - 0s 632us/step - loss: 2.9844
# Epoch 154/200
# 14/14 [==============================] - 0s 620us/step - loss: 3.0174
# Epoch 155/200
# 14/14 [==============================] - 0s 625us/step - loss: 2.9331
# Epoch 156/200
# 14/14 [==============================] - 0s 656us/step - loss: 2.9542
# Epoch 157/200
# 14/14 [==============================] - 0s 692us/step - loss: 2.9250
# Epoch 158/200
# 14/14 [==============================] - 0s 704us/step - loss: 2.9007
# Epoch 159/200
# 14/14 [==============================] - 0s 646us/step - loss: 2.9294
# Epoch 160/200
# 14/14 [==============================] - 0s 633us/step - loss: 2.9136
# Epoch 161/200
# 14/14 [==============================] - 0s 611us/step - loss: 2.9749
# Epoch 162/200
# 14/14 [==============================] - 0s 629us/step - loss: 2.8412
# Epoch 163/200
# 14/14 [==============================] - 0s 685us/step - loss: 3.0358
# Epoch 164/200
# 14/14 [==============================] - 0s 634us/step - loss: 2.9154
# Epoch 165/200
# 14/14 [==============================] - 0s 643us/step - loss: 2.8934
# Epoch 166/200
# 14/14 [==============================] - 0s 654us/step - loss: 2.8982
# Epoch 167/200
# 14/14 [==============================] - 0s 616us/step - loss: 2.9357
# Epoch 168/200
# 14/14 [==============================] - 0s 656us/step - loss: 2.8836
# Epoch 169/200
# 14/14 [==============================] - 0s 624us/step - loss: 2.8956
# Epoch 170/200
# 14/14 [==============================] - 0s 648us/step - loss: 2.8554
# Epoch 171/200
# 14/14 [==============================] - 0s 701us/step - loss: 2.8815
# Epoch 172/200
# 14/14 [==============================] - 0s 665us/step - loss: 2.8153
# Epoch 173/200
# 14/14 [==============================] - 0s 617us/step - loss: 2.8215
# Epoch 174/200
# 14/14 [==============================] - 0s 675us/step - loss: 2.9517
# Epoch 175/200
# 14/14 [==============================] - 0s 654us/step - loss: 2.8205
# Epoch 176/200
# 14/14 [==============================] - 0s 685us/step - loss: 2.8474
# Epoch 177/200
# 14/14 [==============================] - 0s 672us/step - loss: 2.8120
# Epoch 178/200
# 14/14 [==============================] - 0s 662us/step - loss: 2.8861
# Epoch 179/200
# 14/14 [==============================] - 0s 666us/step - loss: 2.7839
# Epoch 180/200
# 14/14 [==============================] - 0s 616us/step - loss: 2.8962
# Epoch 181/200
# 14/14 [==============================] - 0s 688us/step - loss: 2.8144
# Epoch 182/200
# 14/14 [==============================] - 0s 692us/step - loss: 2.9554
# Epoch 183/200
# 14/14 [==============================] - 0s 652us/step - loss: 2.8149
# Epoch 184/200
# 14/14 [==============================] - 0s 646us/step - loss: 2.8453
# Epoch 185/200
# 14/14 [==============================] - 0s 699us/step - loss: 2.8845
# Epoch 186/200
# 14/14 [==============================] - 0s 765us/step - loss: 2.8211
# Epoch 187/200
# 14/14 [==============================] - 0s 827us/step - loss: 2.7869
# Epoch 188/200
# 14/14 [==============================] - 0s 781us/step - loss: 2.8135
# Epoch 189/200
# 14/14 [==============================] - 0s 861us/step - loss: 2.7915
# Epoch 190/200
# 14/14 [==============================] - 0s 804us/step - loss: 2.7701
# Epoch 191/200
# 14/14 [==============================] - 0s 757us/step - loss: 2.7573
# Epoch 192/200
# 14/14 [==============================] - 0s 788us/step - loss: 2.8335
# Epoch 193/200
# 14/14 [==============================] - 0s 766us/step - loss: 2.7686
# Epoch 194/200
# 14/14 [==============================] - 0s 808us/step - loss: 2.7320
# Epoch 195/200
# 14/14 [==============================] - 0s 806us/step - loss: 2.7942
# Epoch 196/200
# 14/14 [==============================] - 0s 853us/step - loss: 2.7275
# Epoch 197/200
# 14/14 [==============================] - 0s 803us/step - loss: 2.8197
# Epoch 198/200
# 14/14 [==============================] - 0s 815us/step - loss: 2.7209
# Epoch 199/200
# 14/14 [==============================] - 0s 768us/step - loss: 2.7221
# Epoch 200/200
# 14/14 [==============================] - 0s 786us/step - loss: 2.7911
# Epoch 1/200
# 14/14 [==============================] - 0s 624us/step - loss: 865.4957
# Epoch 2/200
# 14/14 [==============================] - 0s 598us/step - loss: 289.8671
# Epoch 3/200
# 14/14 [==============================] - 0s 556us/step - loss: 143.0674
# Epoch 4/200
# 14/14 [==============================] - 0s 521us/step - loss: 96.1179
# Epoch 5/200
# 14/14 [==============================] - 0s 527us/step - loss: 70.8854
# Epoch 6/200
# 14/14 [==============================] - 0s 549us/step - loss: 55.6090
# Epoch 7/200
# 14/14 [==============================] - 0s 552us/step - loss: 45.8388
# Epoch 8/200
# 14/14 [==============================] - 0s 549us/step - loss: 38.8997
# Epoch 9/200
# 14/14 [==============================] - 0s 517us/step - loss: 34.3169
# Epoch 10/200
# 14/14 [==============================] - 0s 555us/step - loss: 29.8144
# Epoch 11/200
# 14/14 [==============================] - 0s 535us/step - loss: 26.7666
# Epoch 12/200
# 14/14 [==============================] - 0s 552us/step - loss: 24.2409
# Epoch 13/200
# 14/14 [==============================] - 0s 504us/step - loss: 22.6219
# Epoch 14/200
# 14/14 [==============================] - 0s 548us/step - loss: 21.0768
# Epoch 15/200
# 14/14 [==============================] - 0s 532us/step - loss: 19.6530
# Epoch 16/200
# 14/14 [==============================] - 0s 563us/step - loss: 18.5610
# Epoch 17/200
# 14/14 [==============================] - 0s 505us/step - loss: 17.6045
# Epoch 18/200
# 14/14 [==============================] - 0s 522us/step - loss: 16.6602
# Epoch 19/200
# 14/14 [==============================] - 0s 533us/step - loss: 15.9085
# Epoch 20/200
# 14/14 [==============================] - 0s 571us/step - loss: 15.0996
# Epoch 21/200
# 14/14 [==============================] - 0s 551us/step - loss: 14.3243
# Epoch 22/200
# 14/14 [==============================] - 0s 558us/step - loss: 13.6900
# Epoch 23/200
# 14/14 [==============================] - 0s 540us/step - loss: 13.0526
# Epoch 24/200
# 14/14 [==============================] - 0s 585us/step - loss: 12.4390
# Epoch 25/200
# 14/14 [==============================] - 0s 519us/step - loss: 11.9466
# Epoch 26/200
# 14/14 [==============================] - 0s 572us/step - loss: 11.4070
# Epoch 27/200
# 14/14 [==============================] - 0s 578us/step - loss: 10.6744
# Epoch 28/200
# 14/14 [==============================] - 0s 580us/step - loss: 10.4320
# Epoch 29/200
# 14/14 [==============================] - 0s 566us/step - loss: 9.8257
# Epoch 30/200
# 14/14 [==============================] - 0s 616us/step - loss: 9.6950
# Epoch 31/200
# 14/14 [==============================] - 0s 647us/step - loss: 9.1697
# Epoch 32/200
# 14/14 [==============================] - 0s 729us/step - loss: 8.7876
# Epoch 33/200
# 14/14 [==============================] - 0s 663us/step - loss: 8.4222
# Epoch 34/200
# 14/14 [==============================] - 0s 629us/step - loss: 8.0135
# Epoch 35/200
# 14/14 [==============================] - 0s 646us/step - loss: 7.6954
# Epoch 36/200
# 14/14 [==============================] - 0s 764us/step - loss: 7.4167
# Epoch 37/200
# 14/14 [==============================] - 0s 678us/step - loss: 7.2425
# Epoch 38/200
# 14/14 [==============================] - 0s 702us/step - loss: 6.9864
# Epoch 39/200
# 14/14 [==============================] - 0s 758us/step - loss: 6.7019
# Epoch 40/200
# 14/14 [==============================] - 0s 806us/step - loss: 6.5853
# Epoch 41/200
# 14/14 [==============================] - 0s 849us/step - loss: 6.2587
# Epoch 42/200
# 14/14 [==============================] - 0s 787us/step - loss: 6.0769
# Epoch 43/200
# 14/14 [==============================] - 0s 818us/step - loss: 5.9169
# Epoch 44/200
# 14/14 [==============================] - 0s 851us/step - loss: 5.7678
# Epoch 45/200
# 14/14 [==============================] - 0s 813us/step - loss: 5.6120
# Epoch 46/200
# 14/14 [==============================] - 0s 797us/step - loss: 5.5053
# Epoch 47/200
# 14/14 [==============================] - 0s 839us/step - loss: 5.3621
# Epoch 48/200
# 14/14 [==============================] - 0s 771us/step - loss: 5.2197
# Epoch 49/200
# 14/14 [==============================] - 0s 786us/step - loss: 5.1133
# Epoch 50/200
# 14/14 [==============================] - 0s 769us/step - loss: 5.0106
# Epoch 51/200
# 14/14 [==============================] - 0s 745us/step - loss: 4.9352
# Epoch 52/200
# 14/14 [==============================] - 0s 832us/step - loss: 4.7979
# Epoch 53/200
# 14/14 [==============================] - 0s 744us/step - loss: 4.7021
# Epoch 54/200
# 14/14 [==============================] - 0s 809us/step - loss: 4.6453
# Epoch 55/200
# 14/14 [==============================] - 0s 773us/step - loss: 4.5271
# Epoch 56/200
# 14/14 [==============================] - 0s 804us/step - loss: 4.5529
# Epoch 57/200
# 14/14 [==============================] - 0s 770us/step - loss: 4.4257
# Epoch 58/200
# 14/14 [==============================] - 0s 778us/step - loss: 4.3482
# Epoch 59/200
# 14/14 [==============================] - 0s 830us/step - loss: 4.3207
# Epoch 60/200
# 14/14 [==============================] - 0s 823us/step - loss: 4.1946
# Epoch 61/200
# 14/14 [==============================] - 0s 821us/step - loss: 4.2241
# Epoch 62/200
# 14/14 [==============================] - 0s 806us/step - loss: 4.1412
# Epoch 63/200
# 14/14 [==============================] - 0s 761us/step - loss: 4.0525
# Epoch 64/200
# 14/14 [==============================] - 0s 807us/step - loss: 4.4341
# Epoch 65/200
# 14/14 [==============================] - 0s 796us/step - loss: 3.9859
# Epoch 66/200
# 14/14 [==============================] - 0s 815us/step - loss: 3.9176
# Epoch 67/200
# 14/14 [==============================] - 0s 770us/step - loss: 3.9454
# Epoch 68/200
# 14/14 [==============================] - 0s 809us/step - loss: 3.9467
# Epoch 69/200
# 14/14 [==============================] - 0s 774us/step - loss: 3.9036
# Epoch 70/200
# 14/14 [==============================] - 0s 785us/step - loss: 3.8162
# Epoch 71/200
# 14/14 [==============================] - 0s 779us/step - loss: 3.8009
# Epoch 72/200
# 14/14 [==============================] - 0s 805us/step - loss: 3.7234
# Epoch 73/200
# 14/14 [==============================] - 0s 779us/step - loss: 3.7825
# Epoch 74/200
# 14/14 [==============================] - 0s 822us/step - loss: 3.7268
# Epoch 75/200
# 14/14 [==============================] - 0s 809us/step - loss: 3.6190
# Epoch 76/200
# 14/14 [==============================] - 0s 764us/step - loss: 3.6727
# Epoch 77/200
# 14/14 [==============================] - 0s 815us/step - loss: 3.5977
# Epoch 78/200
# 14/14 [==============================] - 0s 821us/step - loss: 3.5801
# Epoch 79/200
# 14/14 [==============================] - 0s 776us/step - loss: 3.5580
# Epoch 80/200
# 14/14 [==============================] - 0s 815us/step - loss: 3.6493
# Epoch 81/200
# 14/14 [==============================] - 0s 806us/step - loss: 3.5434
# Epoch 82/200
# 14/14 [==============================] - 0s 802us/step - loss: 3.4881
# Epoch 83/200
# 14/14 [==============================] - 0s 753us/step - loss: 3.5462
# Epoch 84/200
# 14/14 [==============================] - 0s 759us/step - loss: 3.4583
# Epoch 85/200
# 14/14 [==============================] - 0s 801us/step - loss: 3.4292
# Epoch 86/200
# 14/14 [==============================] - 0s 880us/step - loss: 3.4760
# Epoch 87/200
# 14/14 [==============================] - 0s 829us/step - loss: 3.5638
# Epoch 88/200
# 14/14 [==============================] - 0s 761us/step - loss: 3.3891
# Epoch 89/200
# 14/14 [==============================] - 0s 777us/step - loss: 3.3916
# Epoch 90/200
# 14/14 [==============================] - 0s 760us/step - loss: 3.3737
# Epoch 91/200
# 14/14 [==============================] - 0s 835us/step - loss: 3.3080
# Epoch 92/200
# 14/14 [==============================] - 0s 837us/step - loss: 3.3766
# Epoch 93/200
# 14/14 [==============================] - 0s 812us/step - loss: 3.3679
# Epoch 94/200
# 14/14 [==============================] - 0s 793us/step - loss: 3.3208
# Epoch 95/200
# 14/14 [==============================] - 0s 821us/step - loss: 3.3320
# Epoch 96/200
# 14/14 [==============================] - 0s 788us/step - loss: 3.2595
# Epoch 97/200
# 14/14 [==============================] - 0s 784us/step - loss: 3.1687
# Epoch 98/200
# 14/14 [==============================] - 0s 768us/step - loss: 3.1967
# Epoch 99/200
# 14/14 [==============================] - 0s 791us/step - loss: 3.2321
# Epoch 100/200
# 14/14 [==============================] - 0s 777us/step - loss: 3.2296
# Epoch 101/200
# 14/14 [==============================] - 0s 807us/step - loss: 3.2596
# Epoch 102/200
# 14/14 [==============================] - 0s 776us/step - loss: 3.2057
# Epoch 103/200
# 14/14 [==============================] - 0s 772us/step - loss: 3.1092
# Epoch 104/200
# 14/14 [==============================] - 0s 808us/step - loss: 3.1787
# Epoch 105/200
# 14/14 [==============================] - 0s 768us/step - loss: 3.1412
# Epoch 106/200
# 14/14 [==============================] - 0s 779us/step - loss: 3.1934
# Epoch 107/200
# 14/14 [==============================] - 0s 805us/step - loss: 3.1062
# Epoch 108/200
# 14/14 [==============================] - 0s 775us/step - loss: 3.1743
# Epoch 109/200
# 14/14 [==============================] - 0s 852us/step - loss: 3.0705
# Epoch 110/200
# 14/14 [==============================] - 0s 787us/step - loss: 3.4356
# Epoch 111/200
# 14/14 [==============================] - 0s 800us/step - loss: 3.0621
# Epoch 112/200
# 14/14 [==============================] - 0s 784us/step - loss: 3.1501
# Epoch 113/200
# 14/14 [==============================] - 0s 788us/step - loss: 3.0922
# Epoch 114/200
# 14/14 [==============================] - 0s 782us/step - loss: 3.0199
# Epoch 115/200
# 14/14 [==============================] - 0s 767us/step - loss: 3.0733
# Epoch 116/200
# 14/14 [==============================] - 0s 837us/step - loss: 3.0207
# Epoch 117/200
# 14/14 [==============================] - 0s 785us/step - loss: 3.0084
# Epoch 118/200
# 14/14 [==============================] - 0s 756us/step - loss: 3.0598
# Epoch 119/200
# 14/14 [==============================] - 0s 821us/step - loss: 2.9768
# Epoch 120/200
# 14/14 [==============================] - 0s 779us/step - loss: 3.0354
# Epoch 121/200
# 14/14 [==============================] - 0s 804us/step - loss: 3.0333
# Epoch 122/200
# 14/14 [==============================] - 0s 811us/step - loss: 3.0299
# Epoch 123/200
# 14/14 [==============================] - 0s 813us/step - loss: 3.0430
# Epoch 124/200
# 14/14 [==============================] - 0s 787us/step - loss: 3.0595
# Epoch 125/200
# 14/14 [==============================] - 0s 754us/step - loss: 3.0074
# Epoch 126/200
# 14/14 [==============================] - 0s 766us/step - loss: 3.0533
# Epoch 127/200
# 14/14 [==============================] - 0s 822us/step - loss: 3.0115
# Epoch 128/200
# 14/14 [==============================] - 0s 826us/step - loss: 2.9864
# Epoch 129/200
# 14/14 [==============================] - 0s 781us/step - loss: 2.9261
# Epoch 130/200
# 14/14 [==============================] - 0s 754us/step - loss: 2.9904
# Epoch 131/200
# 14/14 [==============================] - 0s 796us/step - loss: 2.9461
# Epoch 132/200
# 14/14 [==============================] - 0s 805us/step - loss: 2.8850
# Epoch 133/200
# 14/14 [==============================] - 0s 823us/step - loss: 2.9268
# Epoch 134/200
# 14/14 [==============================] - 0s 759us/step - loss: 2.8641
# Epoch 135/200
# 14/14 [==============================] - 0s 776us/step - loss: 2.8995
# Epoch 136/200
# 14/14 [==============================] - 0s 796us/step - loss: 2.8474
# Epoch 137/200
# 14/14 [==============================] - 0s 762us/step - loss: 2.8278
# Epoch 138/200
# 14/14 [==============================] - 0s 756us/step - loss: 2.8746
# Epoch 139/200
# 14/14 [==============================] - 0s 789us/step - loss: 2.8657
# Epoch 140/200
# 14/14 [==============================] - 0s 773us/step - loss: 2.8636
# Epoch 141/200
# 14/14 [==============================] - 0s 838us/step - loss: 2.8640
# Epoch 142/200
# 14/14 [==============================] - 0s 768us/step - loss: 2.8999
# Epoch 143/200
# 14/14 [==============================] - 0s 803us/step - loss: 2.8620
# Epoch 144/200
# 14/14 [==============================] - 0s 787us/step - loss: 2.8304
# Epoch 145/200
# 14/14 [==============================] - 0s 756us/step - loss: 2.8363
# Epoch 146/200
# 14/14 [==============================] - 0s 788us/step - loss: 2.8885
# Epoch 147/200
# 14/14 [==============================] - 0s 795us/step - loss: 2.7947
# Epoch 148/200
# 14/14 [==============================] - 0s 804us/step - loss: 2.8301
# Epoch 149/200
# 14/14 [==============================] - 0s 803us/step - loss: 2.8756
# Epoch 150/200
# 14/14 [==============================] - 0s 790us/step - loss: 2.7628
# Epoch 151/200
# 14/14 [==============================] - 0s 906us/step - loss: 2.8553
# Epoch 152/200
# 14/14 [==============================] - 0s 807us/step - loss: 2.8912
# Epoch 153/200
# 14/14 [==============================] - 0s 797us/step - loss: 3.2533
# Epoch 154/200
# 14/14 [==============================] - 0s 782us/step - loss: 2.7062
# Epoch 155/200
# 14/14 [==============================] - 0s 771us/step - loss: 2.8473
# Epoch 156/200
# 14/14 [==============================] - 0s 776us/step - loss: 3.1634
# Epoch 157/200
# 14/14 [==============================] - 0s 780us/step - loss: 2.8344
# Epoch 158/200
# 14/14 [==============================] - 0s 794us/step - loss: 2.8674
# Epoch 159/200
# 14/14 [==============================] - 0s 806us/step - loss: 2.7674
# Epoch 160/200
# 14/14 [==============================] - 0s 814us/step - loss: 2.7555
# Epoch 161/200
# 14/14 [==============================] - 0s 767us/step - loss: 2.8239
# Epoch 162/200
# 14/14 [==============================] - 0s 743us/step - loss: 2.8254
# Epoch 163/200
# 14/14 [==============================] - 0s 766us/step - loss: 2.7388
# Epoch 164/200
# 14/14 [==============================] - 0s 781us/step - loss: 2.7925
# Epoch 165/200
# 14/14 [==============================] - 0s 784us/step - loss: 2.7789
# Epoch 166/200
# 14/14 [==============================] - 0s 825us/step - loss: 2.7264
# Epoch 167/200
# 14/14 [==============================] - 0s 803us/step - loss: 2.7835
# Epoch 168/200
# 14/14 [==============================] - 0s 821us/step - loss: 2.7781
# Epoch 169/200
# 14/14 [==============================] - 0s 788us/step - loss: 2.7733
# Epoch 170/200
# 14/14 [==============================] - 0s 804us/step - loss: 2.7606
# Epoch 171/200
# 14/14 [==============================] - 0s 724us/step - loss: 2.7517
# Epoch 172/200
# 14/14 [==============================] - 0s 763us/step - loss: 2.7551
# Epoch 173/200
# 14/14 [==============================] - 0s 783us/step - loss: 2.7184
# Epoch 174/200
# 14/14 [==============================] - 0s 794us/step - loss: 2.7394
# ...
# Epoch 12/200
# 14/14 [==============================] - 0s 562us/step - loss: 13.8214
# Epoch 13/200
# 14/14 [==============================] - 0s 540us/step - loss: 12.7791
# Epoch 14/200
# 14/14 [==============================] - 0s 558us/step - loss: 12.0639
# Epoch 15/200
# 14/14 [==============================] - 0s 546us/step - loss: 11.4266
# Epoch 16/200
# 14/14 [==============================] - 0s 501us/step - loss: 10.8193
# Epoch 17/200
# 14/14 [==============================] - 0s 522us/step - loss: 10.3773
# Epoch 18/200
# 14/14 [==============================] - 0s 540us/step - loss: 9.9168
# Epoch 19/200
# 14/14 [==============================] - 0s 557us/step - loss: 9.5689
# Epoch 20/200
# 14/14 [==============================] - 0s 536us/step - loss: 9.2710
# Epoch 21/200
# 14/14 [==============================] - 0s 584us/step - loss: 8.9253
# Epoch 22/200
# 14/14 [==============================] - 0s 554us/step - loss: 8.6539
# Epoch 23/200
# 14/14 [==============================] - 0s 541us/step - loss: 8.3771
# Epoch 24/200
# 14/14 [==============================] - 0s 533us/step - loss: 8.1221
# Epoch 25/200
# 14/14 [==============================] - 0s 553us/step - loss: 7.9506
# Epoch 26/200
# 14/14 [==============================] - 0s 546us/step - loss: 7.7066
# Epoch 27/200
# 14/14 [==============================] - 0s 548us/step - loss: 7.5252
# Epoch 28/200
# 14/14 [==============================] - 0s 625us/step - loss: 7.5785
# Epoch 29/200
# 14/14 [==============================] - 0s 531us/step - loss: 7.1782
# Epoch 30/200
# 14/14 [==============================] - 0s 548us/step - loss: 6.9872
# Epoch 31/200
# 14/14 [==============================] - 0s 513us/step - loss: 6.8213
# Epoch 32/200
# 14/14 [==============================] - 0s 546us/step - loss: 6.6803
# Epoch 33/200
# 14/14 [==============================] - 0s 537us/step - loss: 6.5498
# Epoch 34/200
# 14/14 [==============================] - 0s 561us/step - loss: 6.2747
# Epoch 35/200
# 14/14 [==============================] - 0s 544us/step - loss: 6.2911
# Epoch 36/200
# 14/14 [==============================] - 0s 555us/step - loss: 6.0330
# Epoch 37/200
# 14/14 [==============================] - 0s 532us/step - loss: 5.9297
# Epoch 38/200
# 14/14 [==============================] - 0s 549us/step - loss: 5.6951
# Epoch 39/200
# 14/14 [==============================] - 0s 537us/step - loss: 5.6140
# Epoch 40/200
# 14/14 [==============================] - 0s 508us/step - loss: 5.3752
# Epoch 41/200
# 14/14 [==============================] - 0s 527us/step - loss: 5.3536
# Epoch 42/200
# 14/14 [==============================] - 0s 549us/step - loss: 5.2415
# Epoch 43/200
# 14/14 [==============================] - 0s 527us/step - loss: 5.1561
# Epoch 44/200
# 14/14 [==============================] - 0s 533us/step - loss: 5.0248
# Epoch 45/200
# 14/14 [==============================] - 0s 506us/step - loss: 4.9104
# Epoch 46/200
# 14/14 [==============================] - 0s 543us/step - loss: 4.7837
# Epoch 47/200
# 14/14 [==============================] - 0s 520us/step - loss: 4.7209
# Epoch 48/200
# 14/14 [==============================] - 0s 574us/step - loss: 4.6205
# Epoch 49/200
# 14/14 [==============================] - 0s 505us/step - loss: 4.4594
# Epoch 50/200
# 14/14 [==============================] - 0s 545us/step - loss: 4.3201
# Epoch 51/200
# 14/14 [==============================] - 0s 548us/step - loss: 4.3548
# Epoch 52/200
# 14/14 [==============================] - 0s 558us/step - loss: 4.2159
# Epoch 53/200
# 14/14 [==============================] - 0s 543us/step - loss: 4.1193
# Epoch 54/200
# 14/14 [==============================] - 0s 575us/step - loss: 4.0397
# Epoch 55/200
# 14/14 [==============================] - 0s 630us/step - loss: 3.9659
# Epoch 56/200
# 14/14 [==============================] - 0s 585us/step - loss: 3.9420
# Epoch 57/200
# 14/14 [==============================] - 0s 633us/step - loss: 3.8029
# Epoch 58/200
# 14/14 [==============================] - 0s 563us/step - loss: 3.7186
# Epoch 59/200
# 14/14 [==============================] - 0s 621us/step - loss: 3.7331
# Epoch 60/200
# 14/14 [==============================] - 0s 614us/step - loss: 3.6336
# Epoch 61/200
# 14/14 [==============================] - 0s 575us/step - loss: 3.5663
# Epoch 62/200
# 14/14 [==============================] - 0s 588us/step - loss: 3.5149
# Epoch 63/200
# 14/14 [==============================] - 0s 700us/step - loss: 3.4160
# Epoch 64/200
# 14/14 [==============================] - 0s 732us/step - loss: 3.4722
# Epoch 65/200
# 14/14 [==============================] - 0s 729us/step - loss: 3.4553
# Epoch 66/200
# 14/14 [==============================] - 0s 734us/step - loss: 3.2072
# Epoch 67/200
# 14/14 [==============================] - 0s 761us/step - loss: 3.3502
# Epoch 68/200
# 14/14 [==============================] - 0s 707us/step - loss: 3.2653
# Epoch 69/200
# 14/14 [==============================] - 0s 729us/step - loss: 3.2526
# Epoch 70/200
# 14/14 [==============================] - 0s 770us/step - loss: 3.1885
# Epoch 71/200
# 14/14 [==============================] - 0s 716us/step - loss: 3.2336
# Epoch 72/200
# 14/14 [==============================] - 0s 734us/step - loss: 3.1591
# Epoch 73/200
# 14/14 [==============================] - 0s 703us/step - loss: 3.1606
# Epoch 74/200
# 14/14 [==============================] - 0s 745us/step - loss: 3.1127
# Epoch 75/200
# 14/14 [==============================] - 0s 691us/step - loss: 3.1756
# Epoch 76/200
# 14/14 [==============================] - 0s 717us/step - loss: 3.0205
# Epoch 77/200
# 14/14 [==============================] - 0s 726us/step - loss: 2.9945
# Epoch 78/200
# 14/14 [==============================] - 0s 686us/step - loss: 2.9861
# Epoch 79/200
# 14/14 [==============================] - 0s 743us/step - loss: 2.9558
# Epoch 80/200
# 14/14 [==============================] - 0s 728us/step - loss: 2.9229
# Epoch 81/200
# 14/14 [==============================] - 0s 732us/step - loss: 2.8785
# Epoch 82/200
# 14/14 [==============================] - 0s 647us/step - loss: 2.8434
# Epoch 83/200
# 14/14 [==============================] - 0s 707us/step - loss: 2.8747
# Epoch 84/200
# 14/14 [==============================] - 0s 691us/step - loss: 2.8944
# Epoch 85/200
# 14/14 [==============================] - 0s 731us/step - loss: 2.8771
# Epoch 86/200
# 14/14 [==============================] - 0s 743us/step - loss: 2.8388
# Epoch 87/200
# 14/14 [==============================] - 0s 711us/step - loss: 3.0046
# Epoch 88/200
# 14/14 [==============================] - 0s 730us/step - loss: 2.8267
# Epoch 89/200
# 14/14 [==============================] - 0s 684us/step - loss: 2.9090
# Epoch 90/200
# 14/14 [==============================] - 0s 660us/step - loss: 2.8142
# Epoch 91/200
# 14/14 [==============================] - 0s 717us/step - loss: 2.7671
# Epoch 92/200
# 14/14 [==============================] - 0s 730us/step - loss: 2.8333
# Epoch 93/200
# 14/14 [==============================] - 0s 690us/step - loss: 2.7471
# Epoch 94/200
# 14/14 [==============================] - 0s 748us/step - loss: 2.8082
# Epoch 95/200
# 14/14 [==============================] - 0s 687us/step - loss: 2.7521
# Epoch 96/200
# 14/14 [==============================] - 0s 709us/step - loss: 2.7409
# Epoch 97/200
# 14/14 [==============================] - 0s 749us/step - loss: 2.7313
# Epoch 98/200
# 14/14 [==============================] - 0s 744us/step - loss: 2.7114
# Epoch 99/200
# 14/14 [==============================] - 0s 739us/step - loss: 2.6760
# Epoch 100/200
# 14/14 [==============================] - 0s 773us/step - loss: 2.7098
# Epoch 101/200
# 14/14 [==============================] - 0s 724us/step - loss: 2.7773
# Epoch 102/200
# 14/14 [==============================] - 0s 735us/step - loss: 2.6826
# Epoch 103/200
# 14/14 [==============================] - 0s 697us/step - loss: 2.7431
# Epoch 104/200
# 14/14 [==============================] - 0s 690us/step - loss: 2.6416
# Epoch 105/200
# 14/14 [==============================] - 0s 710us/step - loss: 2.7331
# Epoch 106/200
# 14/14 [==============================] - 0s 694us/step - loss: 2.6719
# Epoch 107/200
# 14/14 [==============================] - 0s 705us/step - loss: 2.6537
# Epoch 108/200
# 14/14 [==============================] - 0s 722us/step - loss: 2.7826
# Epoch 109/200
# 14/14 [==============================] - 0s 729us/step - loss: 2.7022
# Epoch 110/200
# 14/14 [==============================] - 0s 720us/step - loss: 2.6382
# Epoch 111/200
# 14/14 [==============================] - 0s 691us/step - loss: 2.6174
# Epoch 112/200
# 14/14 [==============================] - 0s 688us/step - loss: 2.6459
# Epoch 113/200
# 14/14 [==============================] - 0s 676us/step - loss: 2.6048
# Epoch 114/200
# 14/14 [==============================] - 0s 731us/step - loss: 2.6570
# Epoch 115/200
# 14/14 [==============================] - 0s 706us/step - loss: 2.5831
# Epoch 116/200
# 14/14 [==============================] - 0s 721us/step - loss: 2.6459
# Epoch 117/200
# 14/14 [==============================] - 0s 710us/step - loss: 2.6798
# Epoch 118/200
# 14/14 [==============================] - 0s 696us/step - loss: 2.6280
# Epoch 119/200
# 14/14 [==============================] - 0s 708us/step - loss: 2.5848
# Epoch 120/200
# 14/14 [==============================] - 0s 689us/step - loss: 2.6578
# Epoch 121/200
# 14/14 [==============================] - 0s 736us/step - loss: 2.5508
# Epoch 122/200
# 14/14 [==============================] - 0s 700us/step - loss: 2.5869
# Epoch 123/200
# 14/14 [==============================] - 0s 755us/step - loss: 2.6498
# Epoch 124/200
# 14/14 [==============================] - 0s 672us/step - loss: 2.6136
# Epoch 125/200
# 14/14 [==============================] - 0s 693us/step - loss: 2.5672
# Epoch 126/200
# 14/14 [==============================] - 0s 719us/step - loss: 2.6216
# Epoch 127/200
# 14/14 [==============================] - 0s 730us/step - loss: 2.5816
# Epoch 128/200
# 14/14 [==============================] - 0s 690us/step - loss: 2.5976
# Epoch 129/200
# 14/14 [==============================] - 0s 702us/step - loss: 2.5455
# Epoch 130/200
# 14/14 [==============================] - 0s 726us/step - loss: 2.5296
# Epoch 131/200
# 14/14 [==============================] - 0s 707us/step - loss: 2.5486
# Epoch 132/200
# 14/14 [==============================] - 0s 750us/step - loss: 2.5012
# Epoch 133/200
# 14/14 [==============================] - 0s 712us/step - loss: 2.5899
# Epoch 134/200
# 14/14 [==============================] - 0s 697us/step - loss: 2.5497
# Epoch 135/200
# 14/14 [==============================] - 0s 699us/step - loss: 2.4921
# Epoch 136/200
# 14/14 [==============================] - 0s 672us/step - loss: 2.5086
# Epoch 137/200
# 14/14 [==============================] - 0s 730us/step - loss: 2.4738
# Epoch 138/200
# 14/14 [==============================] - 0s 674us/step - loss: 2.5315
# Epoch 139/200
# 14/14 [==============================] - 0s 709us/step - loss: 2.4885
# Epoch 140/200
# 14/14 [==============================] - 0s 701us/step - loss: 2.5472
# Epoch 141/200
# 14/14 [==============================] - 0s 676us/step - loss: 2.4997
# Epoch 142/200
# 14/14 [==============================] - 0s 697us/step - loss: 2.5013
# Epoch 143/200
# 14/14 [==============================] - 0s 713us/step - loss: 2.4969
# Epoch 144/200
# 14/14 [==============================] - 0s 729us/step - loss: 2.5283
# Epoch 145/200
# 14/14 [==============================] - 0s 740us/step - loss: 2.5450
# Epoch 146/200
# 14/14 [==============================] - 0s 725us/step - loss: 2.5220
# Epoch 147/200
# 14/14 [==============================] - 0s 701us/step - loss: 2.4904
# Epoch 148/200
# 14/14 [==============================] - 0s 698us/step - loss: 2.5528
# Epoch 149/200
# 14/14 [==============================] - 0s 683us/step - loss: 2.5363
# Epoch 150/200
# 14/14 [==============================] - 0s 683us/step - loss: 2.5063
# Epoch 151/200
# 14/14 [==============================] - 0s 699us/step - loss: 2.5129
# Epoch 152/200
# 14/14 [==============================] - 0s 668us/step - loss: 2.5397
# Epoch 153/200
# 14/14 [==============================] - 0s 758us/step - loss: 2.5374
# Epoch 154/200
# 14/14 [==============================] - 0s 713us/step - loss: 2.4327
# Epoch 155/200
# 14/14 [==============================] - 0s 715us/step - loss: 2.4442
# Epoch 156/200
# 14/14 [==============================] - 0s 719us/step - loss: 2.4661
# Epoch 157/200
# 14/14 [==============================] - 0s 729us/step - loss: 2.4274
# Epoch 158/200
# 14/14 [==============================] - 0s 696us/step - loss: 2.5293
# Epoch 159/200
# 14/14 [==============================] - 0s 721us/step - loss: 2.5239
# Epoch 160/200
# 14/14 [==============================] - 0s 698us/step - loss: 2.4983
# Epoch 161/200
# 14/14 [==============================] - 0s 718us/step - loss: 2.4955
# Epoch 162/200
# 14/14 [==============================] - 0s 768us/step - loss: 2.4827
# Epoch 163/200
# 14/14 [==============================] - 0s 704us/step - loss: 2.4617
# Epoch 164/200
# 14/14 [==============================] - 0s 746us/step - loss: 2.5141
# Epoch 165/200
# 14/14 [==============================] - 0s 774us/step - loss: 2.6529
# Epoch 166/200
# 14/14 [==============================] - 0s 721us/step - loss: 2.5365
# Epoch 167/200
# 14/14 [==============================] - 0s 726us/step - loss: 2.8785
# Epoch 168/200
# 14/14 [==============================] - 0s 693us/step - loss: 2.4831
# Epoch 169/200
# 14/14 [==============================] - 0s 729us/step - loss: 2.4527
# Epoch 170/200
# 14/14 [==============================] - 0s 815us/step - loss: 2.4480
# Epoch 171/200
# 14/14 [==============================] - 0s 706us/step - loss: 2.4812
# Epoch 172/200
# 14/14 [==============================] - 0s 683us/step - loss: 2.4524
# Epoch 173/200
# 14/14 [==============================] - 0s 682us/step - loss: 2.4158
# Epoch 174/200
# 14/14 [==============================] - 0s 667us/step - loss: 2.4766
# Epoch 175/200
# 14/14 [==============================] - 0s 696us/step - loss: 2.4551
# Epoch 176/200
# 14/14 [==============================] - 0s 704us/step - loss: 2.4431
# Epoch 177/200
# 14/14 [==============================] - 0s 719us/step - loss: 2.4222
# Epoch 178/200
# 14/14 [==============================] - 0s 750us/step - loss: 2.4068
# Epoch 179/200
# 14/14 [==============================] - 0s 796us/step - loss: 2.4374
# Epoch 180/200
# 14/14 [==============================] - 0s 800us/step - loss: 2.4311
# Epoch 181/200
# 14/14 [==============================] - 0s 809us/step - loss: 2.4733
# Epoch 182/200
# 14/14 [==============================] - 0s 795us/step - loss: 2.4595
# Epoch 183/200
# 14/14 [==============================] - 0s 801us/step - loss: 2.4162
# Epoch 184/200
# 14/14 [==============================] - 0s 797us/step - loss: 2.4373
# Epoch 185/200
# 14/14 [==============================] - 0s 794us/step - loss: 2.4559
# Epoch 186/200
# 14/14 [==============================] - 0s 781us/step - loss: 2.4455
# Epoch 187/200
# 14/14 [==============================] - 0s 764us/step - loss: 2.3735
# Epoch 188/200
# 14/14 [==============================] - 0s 805us/step - loss: 2.4882
# Epoch 189/200
# 14/14 [==============================] - 0s 783us/step - loss: 2.3715
# Epoch 190/200
# 14/14 [==============================] - 0s 798us/step - loss: 2.3889
# Epoch 191/200
# 14/14 [==============================] - 0s 822us/step - loss: 2.4381
# Epoch 192/200
# 14/14 [==============================] - 0s 801us/step - loss: 2.4182
# Epoch 193/200
# 14/14 [==============================] - 0s 795us/step - loss: 2.3609
# Epoch 194/200
# 14/14 [==============================] - 0s 762us/step - loss: 2.4144
# Epoch 195/200
# 14/14 [==============================] - 0s 785us/step - loss: 2.4123
# Epoch 196/200
# 14/14 [==============================] - 0s 785us/step - loss: 2.3723
# Epoch 197/200
# 14/14 [==============================] - 0s 713us/step - loss: 2.3820
# Epoch 198/200
# 14/14 [==============================] - 0s 783us/step - loss: 2.4184
# Epoch 199/200
# 14/14 [==============================] - 0s 814us/step - loss: 2.3706
# Epoch 200/200
# 14/14 [==============================] - 0s 795us/step - loss: 2.3334
# MAPE of MLP  :" ,        0
# 0  16.98
# lowest MAPE in training process:" ,[16.25941014]
# the number of neurons of fist layer :7,
# Tunning time : 20.098750829696655s,
# Training time : 2.322615146636963s

# %% [markdown]
# # The numerber of hidden layer: 2

# %%
from time import time
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from itertools import product
from pandas.core.frame import DataFrame
import numpy as np
import csv
import matplotlib.pyplot as plt


train = pd.read_csv("training_data.csv")
x_train = train[["Total_number_of_FLOPs"]]
y_train = train['Execution_time']

valid = pd.read_csv("valid_data.csv")
x_valid = valid[["Total_number_of_FLOPs"]]
y_valid = valid['Execution_time']

df_pred = pd.read_csv("test_data_NCV.csv")
x_test = df_pred[["Total_number_of_FLOPs"]] 
y_test = df_pred['Execution_time']

# train = pd.read_csv("training_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters"]] 
# y_test = df_pred['Execution_time']



# train = pd.read_csv("training_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]] 
# y_test = df_pred['Execution_time']



# train = pd.read_csv("training_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]] 
# y_test = df_pred['Execution_time']


scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_valid = scaler.fit_transform(x_valid)
x_test = scaler.fit_transform(x_test)
MAPE_default=10000
MAPE_better=MAPE_default
range_neuron_first_layer =range(6,12,1)
range_neuron_second_layer =range(6,12,1)
start = time()
for num_neuron_first_layer, num_neuron_second_layer in product(range_neuron_first_layer,range_neuron_second_layer):
    
    model = tf.keras.Sequential([tf.keras.layers.Dense(num_neuron_first_layer, activation = 'relu', input_shape = x_train.shape[1:]),
                                 tf.keras.layers.Dense(num_neuron_second_layer, activation = 'sigmoid'),
                                tf.keras.layers.Dense(1)])

    model.compile(loss = tf.losses.mean_squared_error,
                 optimizer = 'sgd')

    history = model.fit(x_train, y_train, epochs=200)

    y_valid_current = model.predict(x_valid)

    y_valid  = np.array(y_valid).reshape(-1,1)

    # Calculate percentage error
    per_err = (y_valid - y_valid_current) / y_valid
    #print(per_err)

    # Take absolute value of the percentage error (APE)
    per_err = abs(per_err)*100

    # Calculate the MAPE
    MAPE = sum(per_err)/len(per_err)

    if ( MAPE < MAPE_better ):
        better_num_neuron_first_layer = num_neuron_first_layer
        better_num_neuron_second_layer = num_neuron_second_layer
        MAPE_better = MAPE

stop = time()
tunning_time = stop-start  
start = time()
model = tf.keras.Sequential([tf.keras.layers.Dense(better_num_neuron_first_layer, activation = 'sigmoid', input_shape = x_train.shape[1:]),
                             tf.keras.layers.Dense(better_num_neuron_second_layer, activation = 'sigmoid'),
                            tf.keras.layers.Dense(1)])
model.compile(loss = tf.losses.mean_squared_error,
                 optimizer = 'sgd')
history = model.fit(x_train, y_train, epochs=200)
training_time = stop-start
y_pred = model.predict(x_valid)

y_test  = np.array(y_valid).reshape(-1,1)
per_err = (y_test - y_pred) / y_test
per_err = abs(per_err)*100
MAPE = sum(per_err)/len(per_err)

MAPE = DataFrame(MAPE)  
# Print the MAPE value 

print(f"""MAPE of MLP  : {round(MAPE, 2)} 
 lowest MAPE in training process:" ,{MAPE_better}
the number of neurons of fist layer : { better_num_neuron_first_layer }
the number of neurons of second layer : { better_num_neuron_second_layer }
Tunning time : {tunning_time}s,
Training time : {training_time}s
     """)

y_test_sort=np.sort(y_test,axis=0)
y_pred_sort=np.sort(y_pred,axis=0)
plt.figure(figsize=(12,5))
plt.plot(np.arange(len(y_test)),y_test_sort,"r",label="Measured Execution Time")
plt.scatter(np.arange(len(y_pred)),y_pred_sort,s=10,c="b",label="Predicted Execution Time ")
plt.legend(loc="upper left")
plt.grid()
plt.ylabel("Execution Time(ms)")
plt.title("MLP: Predicted vs. Measured Execution Time of NCV")
plt.show()
# Out:
# 2022-06-18 09:23:47.533599: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-06-18 09:23:47.533613: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-06-18 09:23:48.492833: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-06-18 09:23:48.492863: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-18 09:23:48.492877: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2022-06-18 09:23:48.493040: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-18 09:23:48.544347: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 14/14 [==============================] - 0s 651us/step - loss: 826.0125
# Epoch 2/200
# 14/14 [==============================] - 0s 535us/step - loss: 339.7314
# Epoch 3/200
# 14/14 [==============================] - 0s 514us/step - loss: 167.9946
# Epoch 4/200
# 14/14 [==============================] - 0s 546us/step - loss: 152.0789
# Epoch 5/200
# 14/14 [==============================] - 0s 505us/step - loss: 101.0587
# Epoch 6/200
# 14/14 [==============================] - 0s 498us/step - loss: 82.0245
# Epoch 7/200
# 14/14 [==============================] - 0s 534us/step - loss: 70.0287
# Epoch 8/200
# 14/14 [==============================] - 0s 541us/step - loss: 63.3801
# Epoch 9/200
# 14/14 [==============================] - 0s 567us/step - loss: 59.4017
# Epoch 10/200
# 14/14 [==============================] - 0s 534us/step - loss: 56.7375
# Epoch 11/200
# 14/14 [==============================] - 0s 541us/step - loss: 53.4328
# Epoch 12/200
# 14/14 [==============================] - 0s 581us/step - loss: 51.1308
# Epoch 13/200
# 14/14 [==============================] - 0s 543us/step - loss: 49.4318
# Epoch 14/200
# 14/14 [==============================] - 0s 527us/step - loss: 47.6816
# Epoch 15/200
# 14/14 [==============================] - 0s 558us/step - loss: 44.5759
# Epoch 16/200
# 14/14 [==============================] - 0s 518us/step - loss: 45.8148
# Epoch 17/200
# 14/14 [==============================] - 0s 542us/step - loss: 42.6932
# Epoch 18/200
# 14/14 [==============================] - 0s 567us/step - loss: 46.0799
# Epoch 19/200
# 14/14 [==============================] - 0s 526us/step - loss: 43.6221
# Epoch 20/200
# 14/14 [==============================] - 0s 525us/step - loss: 44.1588
# Epoch 21/200
# 14/14 [==============================] - 0s 532us/step - loss: 41.0335
# Epoch 22/200
# 14/14 [==============================] - 0s 537us/step - loss: 38.5366
# Epoch 23/200
# 14/14 [==============================] - 0s 535us/step - loss: 46.7748
# Epoch 24/200
# 14/14 [==============================] - 0s 560us/step - loss: 42.4383
# Epoch 25/200
# 14/14 [==============================] - 0s 581us/step - loss: 38.9820
# Epoch 26/200
# 14/14 [==============================] - 0s 596us/step - loss: 37.5250
# Epoch 27/200
# 14/14 [==============================] - 0s 574us/step - loss: 37.7242
# Epoch 28/200
# 14/14 [==============================] - 0s 617us/step - loss: 35.4687
# Epoch 29/200
# 14/14 [==============================] - 0s 574us/step - loss: 37.4004
# Epoch 30/200
# 14/14 [==============================] - 0s 587us/step - loss: 36.7998
# Epoch 31/200
# 14/14 [==============================] - 0s 603us/step - loss: 36.2037
# Epoch 32/200
# 14/14 [==============================] - 0s 623us/step - loss: 34.8846
# Epoch 33/200
# 14/14 [==============================] - 0s 613us/step - loss: 34.7440
# Epoch 34/200
# 14/14 [==============================] - 0s 576us/step - loss: 33.8140
# Epoch 35/200
# 14/14 [==============================] - 0s 544us/step - loss: 35.2621
# Epoch 36/200
# 14/14 [==============================] - 0s 595us/step - loss: 36.3469
# Epoch 37/200
# 14/14 [==============================] - 0s 611us/step - loss: 37.8313
# Epoch 38/200
# 14/14 [==============================] - 0s 588us/step - loss: 32.6290
# Epoch 39/200
# 14/14 [==============================] - 0s 560us/step - loss: 31.6781
# Epoch 40/200
# 14/14 [==============================] - 0s 628us/step - loss: 39.0536
# Epoch 41/200
# 14/14 [==============================] - 0s 628us/step - loss: 33.0055
# Epoch 42/200
# 14/14 [==============================] - 0s 630us/step - loss: 34.0782
# Epoch 43/200
# 14/14 [==============================] - 0s 590us/step - loss: 35.1200
# Epoch 44/200
# 14/14 [==============================] - 0s 548us/step - loss: 32.7808
# Epoch 45/200
# 14/14 [==============================] - 0s 605us/step - loss: 31.6552
# Epoch 46/200
# 14/14 [==============================] - 0s 584us/step - loss: 31.8031
# Epoch 47/200
# 14/14 [==============================] - 0s 573us/step - loss: 31.8906
# Epoch 48/200
# 14/14 [==============================] - 0s 615us/step - loss: 32.1336
# Epoch 49/200
# 14/14 [==============================] - 0s 598us/step - loss: 36.1521
# Epoch 50/200
# 14/14 [==============================] - 0s 585us/step - loss: 31.3256
# Epoch 51/200
# 14/14 [==============================] - 0s 591us/step - loss: 30.7959
# Epoch 52/200
# 14/14 [==============================] - 0s 595us/step - loss: 33.3395
# Epoch 53/200
# 14/14 [==============================] - 0s 587us/step - loss: 35.8298
# Epoch 54/200
# 14/14 [==============================] - 0s 565us/step - loss: 32.0475
# Epoch 55/200
# 14/14 [==============================] - 0s 597us/step - loss: 31.5992
# Epoch 56/200
# 14/14 [==============================] - 0s 597us/step - loss: 33.1869
# Epoch 57/200
# 14/14 [==============================] - 0s 565us/step - loss: 32.5687
# Epoch 58/200
# 14/14 [==============================] - 0s 588us/step - loss: 30.7669
# Epoch 59/200
# 14/14 [==============================] - 0s 586us/step - loss: 32.4180
# Epoch 60/200
# 14/14 [==============================] - 0s 565us/step - loss: 32.1432
# Epoch 61/200
# 14/14 [==============================] - 0s 598us/step - loss: 31.1310
# Epoch 62/200
# 14/14 [==============================] - 0s 604us/step - loss: 32.3536
# Epoch 63/200
# 14/14 [==============================] - 0s 597us/step - loss: 32.0207
# Epoch 64/200
# 14/14 [==============================] - 0s 583us/step - loss: 36.4150
# Epoch 65/200
# 14/14 [==============================] - 0s 636us/step - loss: 30.8509
# Epoch 66/200
# 14/14 [==============================] - 0s 635us/step - loss: 31.1726
# Epoch 67/200
# 14/14 [==============================] - 0s 607us/step - loss: 30.7137
# Epoch 68/200
# 14/14 [==============================] - 0s 642us/step - loss: 32.1876
# Epoch 69/200
# 14/14 [==============================] - 0s 608us/step - loss: 30.3753
# Epoch 70/200
# 14/14 [==============================] - 0s 607us/step - loss: 33.4171
# Epoch 71/200
# 14/14 [==============================] - 0s 592us/step - loss: 30.1789
# Epoch 72/200
# 14/14 [==============================] - 0s 610us/step - loss: 31.6921
# Epoch 73/200
# 14/14 [==============================] - 0s 585us/step - loss: 32.2097
# Epoch 74/200
# 14/14 [==============================] - 0s 568us/step - loss: 32.9705
# Epoch 75/200
# 14/14 [==============================] - 0s 624us/step - loss: 30.9026
# Epoch 76/200
# 14/14 [==============================] - 0s 616us/step - loss: 32.7508
# Epoch 77/200
# 14/14 [==============================] - 0s 608us/step - loss: 31.3280
# Epoch 78/200
# 14/14 [==============================] - 0s 592us/step - loss: 32.8843
# Epoch 79/200
# 14/14 [==============================] - 0s 629us/step - loss: 29.8124
# Epoch 80/200
# 14/14 [==============================] - 0s 614us/step - loss: 30.4755
# Epoch 81/200
# 14/14 [==============================] - 0s 615us/step - loss: 29.9405
# Epoch 82/200
# 14/14 [==============================] - 0s 562us/step - loss: 32.8157
# Epoch 83/200
# 14/14 [==============================] - 0s 602us/step - loss: 32.1049
# Epoch 84/200
# 14/14 [==============================] - 0s 643us/step - loss: 31.7991
# Epoch 85/200
# 14/14 [==============================] - 0s 562us/step - loss: 30.8344
# Epoch 86/200
# 14/14 [==============================] - 0s 567us/step - loss: 31.5157
# Epoch 87/200
# 14/14 [==============================] - 0s 647us/step - loss: 30.4490
# Epoch 88/200
# 14/14 [==============================] - 0s 573us/step - loss: 30.2194
# Epoch 89/200
# 14/14 [==============================] - 0s 614us/step - loss: 30.0506
# Epoch 90/200
# 14/14 [==============================] - 0s 619us/step - loss: 30.8431
# Epoch 91/200
# 14/14 [==============================] - 0s 590us/step - loss: 30.9386
# Epoch 92/200
# 14/14 [==============================] - 0s 622us/step - loss: 30.3903
# Epoch 93/200
# 14/14 [==============================] - 0s 574us/step - loss: 29.4073
# Epoch 94/200
# 14/14 [==============================] - 0s 591us/step - loss: 31.8097
# Epoch 95/200
# 14/14 [==============================] - 0s 597us/step - loss: 34.2103
# Epoch 96/200
# 14/14 [==============================] - 0s 636us/step - loss: 33.4249
# Epoch 97/200
# 14/14 [==============================] - 0s 598us/step - loss: 30.4796
# Epoch 98/200
# 14/14 [==============================] - 0s 618us/step - loss: 29.5100
# Epoch 99/200
# 14/14 [==============================] - 0s 596us/step - loss: 30.4513
# Epoch 100/200
# 14/14 [==============================] - 0s 618us/step - loss: 47.1871
# Epoch 101/200
# 14/14 [==============================] - 0s 611us/step - loss: 37.7024
# Epoch 102/200
# 14/14 [==============================] - 0s 586us/step - loss: 36.0229
# Epoch 103/200
# 14/14 [==============================] - 0s 627us/step - loss: 34.7299
# Epoch 104/200
# 14/14 [==============================] - 0s 710us/step - loss: 35.5714
# Epoch 105/200
# 14/14 [==============================] - 0s 725us/step - loss: 32.8975
# Epoch 106/200
# 14/14 [==============================] - 0s 719us/step - loss: 30.2524
# Epoch 107/200
# 14/14 [==============================] - 0s 727us/step - loss: 30.0333
# Epoch 108/200
# 14/14 [==============================] - 0s 712us/step - loss: 31.1105
# Epoch 109/200
# 14/14 [==============================] - 0s 733us/step - loss: 31.2903
# Epoch 110/200
# 14/14 [==============================] - 0s 716us/step - loss: 32.0318
# Epoch 111/200
# 14/14 [==============================] - 0s 746us/step - loss: 31.2669
# Epoch 112/200
# 14/14 [==============================] - 0s 708us/step - loss: 29.6960
# Epoch 113/200
# 14/14 [==============================] - 0s 714us/step - loss: 30.1040
# Epoch 114/200
# 14/14 [==============================] - 0s 722us/step - loss: 31.3689
# Epoch 115/200
# 14/14 [==============================] - 0s 719us/step - loss: 31.5189
# Epoch 116/200
# 14/14 [==============================] - 0s 798us/step - loss: 30.8636
# Epoch 117/200
# 14/14 [==============================] - 0s 712us/step - loss: 32.1922
# Epoch 118/200
# 14/14 [==============================] - 0s 732us/step - loss: 30.1835
# Epoch 119/200
# 14/14 [==============================] - 0s 712us/step - loss: 29.1163
# Epoch 120/200
# 14/14 [==============================] - 0s 740us/step - loss: 35.5287
# Epoch 121/200
# 14/14 [==============================] - 0s 681us/step - loss: 32.5321
# Epoch 122/200
# 14/14 [==============================] - 0s 749us/step - loss: 29.4473
# Epoch 123/200
# 14/14 [==============================] - 0s 734us/step - loss: 39.2884
# Epoch 124/200
# 14/14 [==============================] - 0s 717us/step - loss: 30.2923
# Epoch 125/200
# 14/14 [==============================] - 0s 684us/step - loss: 30.8061
# Epoch 126/200
# 14/14 [==============================] - 0s 729us/step - loss: 30.9806
# Epoch 127/200
# 14/14 [==============================] - 0s 737us/step - loss: 30.1784
# Epoch 128/200
# 14/14 [==============================] - 0s 707us/step - loss: 30.2287
# Epoch 129/200
# 14/14 [==============================] - 0s 715us/step - loss: 35.6977
# Epoch 130/200
# 14/14 [==============================] - 0s 706us/step - loss: 30.4592
# Epoch 131/200
# 14/14 [==============================] - 0s 679us/step - loss: 32.7179
# Epoch 132/200
# 14/14 [==============================] - 0s 716us/step - loss: 31.2664
# Epoch 133/200
# 14/14 [==============================] - 0s 722us/step - loss: 30.5866
# Epoch 134/200
# 14/14 [==============================] - 0s 661us/step - loss: 31.6130
# Epoch 135/200
# 14/14 [==============================] - 0s 694us/step - loss: 28.9506
# Epoch 136/200
# 14/14 [==============================] - 0s 749us/step - loss: 31.4298
# Epoch 137/200
# 14/14 [==============================] - 0s 721us/step - loss: 29.2639
# Epoch 138/200
# 14/14 [==============================] - 0s 701us/step - loss: 29.6213
# Epoch 139/200
# 14/14 [==============================] - 0s 716us/step - loss: 30.8288
# Epoch 140/200
# 14/14 [==============================] - 0s 753us/step - loss: 29.8887
# Epoch 141/200
# 14/14 [==============================] - 0s 738us/step - loss: 29.5532
# Epoch 142/200
# 14/14 [==============================] - 0s 753us/step - loss: 29.8846
# Epoch 143/200
# 14/14 [==============================] - 0s 727us/step - loss: 29.7841
# Epoch 144/200
# 14/14 [==============================] - 0s 734us/step - loss: 30.0400
# Epoch 145/200
# 14/14 [==============================] - 0s 710us/step - loss: 29.5409
# Epoch 146/200
# 14/14 [==============================] - 0s 682us/step - loss: 29.8141
# Epoch 147/200
# 14/14 [==============================] - 0s 751us/step - loss: 28.8214
# Epoch 148/200
# 14/14 [==============================] - 0s 721us/step - loss: 31.2516
# Epoch 149/200
# 14/14 [==============================] - 0s 720us/step - loss: 29.7490
# Epoch 150/200
# 14/14 [==============================] - 0s 686us/step - loss: 30.4819
# Epoch 151/200
# 14/14 [==============================] - 0s 690us/step - loss: 29.0434
# Epoch 152/200
# 14/14 [==============================] - 0s 671us/step - loss: 29.0935
# Epoch 153/200
# 14/14 [==============================] - 0s 715us/step - loss: 31.1401
# Epoch 154/200
# 14/14 [==============================] - 0s 711us/step - loss: 29.8377
# Epoch 155/200
# 14/14 [==============================] - 0s 700us/step - loss: 30.2503
# Epoch 156/200
# 14/14 [==============================] - 0s 729us/step - loss: 29.3333
# Epoch 157/200
# 14/14 [==============================] - 0s 734us/step - loss: 31.0306
# Epoch 158/200
# 14/14 [==============================] - 0s 692us/step - loss: 29.9738
# Epoch 159/200
# 14/14 [==============================] - 0s 694us/step - loss: 29.5291
# Epoch 160/200
# 14/14 [==============================] - 0s 730us/step - loss: 29.4164
# Epoch 161/200
# 14/14 [==============================] - 0s 705us/step - loss: 29.6067
# Epoch 162/200
# 14/14 [==============================] - 0s 753us/step - loss: 29.8809
# Epoch 163/200
# 14/14 [==============================] - 0s 726us/step - loss: 29.4564
# Epoch 164/200
# 14/14 [==============================] - 0s 733us/step - loss: 30.6837
# Epoch 165/200
# 14/14 [==============================] - 0s 697us/step - loss: 30.0709
# Epoch 166/200
# 14/14 [==============================] - 0s 713us/step - loss: 30.2274
# Epoch 167/200
# 14/14 [==============================] - 0s 676us/step - loss: 30.7634
# Epoch 168/200
# 14/14 [==============================] - 0s 711us/step - loss: 29.1568
# Epoch 169/200
# 14/14 [==============================] - 0s 666us/step - loss: 29.6617
# Epoch 170/200
# 14/14 [==============================] - 0s 715us/step - loss: 30.1904
# Epoch 171/200
# 14/14 [==============================] - 0s 714us/step - loss: 29.0896
# Epoch 172/200
# 14/14 [==============================] - 0s 745us/step - loss: 29.2175
# Epoch 173/200
# 14/14 [==============================] - 0s 715us/step - loss: 28.9683
# Epoch 174/200
# 14/14 [==============================] - 0s 708us/step - loss: 29.8011
# Epoch 175/200
# 14/14 [==============================] - 0s 768us/step - loss: 29.5650
# Epoch 176/200
# 14/14 [==============================] - 0s 694us/step - loss: 29.5554
# Epoch 177/200
# 14/14 [==============================] - 0s 731us/step - loss: 30.0504
# Epoch 178/200
# 14/14 [==============================] - 0s 757us/step - loss: 30.5722
# Epoch 179/200
# 14/14 [==============================] - 0s 709us/step - loss: 30.9735
# Epoch 180/200
# 14/14 [==============================] - 0s 695us/step - loss: 30.1229
# Epoch 181/200
# 14/14 [==============================] - 0s 725us/step - loss: 28.6863
# Epoch 182/200
# 14/14 [==============================] - 0s 684us/step - loss: 29.1202
# Epoch 183/200
# 14/14 [==============================] - 0s 734us/step - loss: 30.6457
# Epoch 184/200
# 14/14 [==============================] - 0s 726us/step - loss: 29.9643
# Epoch 185/200
# 14/14 [==============================] - 0s 722us/step - loss: 30.0072
# Epoch 186/200
# 14/14 [==============================] - 0s 712us/step - loss: 30.6885
# Epoch 187/200
# 14/14 [==============================] - 0s 717us/step - loss: 30.0613
# Epoch 188/200
# 14/14 [==============================] - 0s 723us/step - loss: 29.8377
# Epoch 189/200
# 14/14 [==============================] - 0s 712us/step - loss: 29.8086
# Epoch 190/200
# 14/14 [==============================] - 0s 742us/step - loss: 30.1077
# Epoch 191/200
# 14/14 [==============================] - 0s 712us/step - loss: 30.1099
# Epoch 192/200
# 14/14 [==============================] - 0s 763us/step - loss: 30.2992
# Epoch 193/200
# 14/14 [==============================] - 0s 660us/step - loss: 30.6181
# Epoch 194/200
# 14/14 [==============================] - 0s 670us/step - loss: 29.8600
# Epoch 195/200
# 14/14 [==============================] - 0s 685us/step - loss: 28.8927
# Epoch 196/200
# 14/14 [==============================] - 0s 715us/step - loss: 29.8011
# Epoch 197/200
# 14/14 [==============================] - 0s 722us/step - loss: 29.9039
# Epoch 198/200
# 14/14 [==============================] - 0s 708us/step - loss: 30.2724
# Epoch 199/200
# 14/14 [==============================] - 0s 698us/step - loss: 30.6968
# Epoch 200/200
# 14/14 [==============================] - 0s 731us/step - loss: 29.6795
# Epoch 1/200
# 14/14 [==============================] - 0s 653us/step - loss: 734.8538
# Epoch 2/200
# 14/14 [==============================] - 0s 565us/step - loss: 252.7547
# Epoch 3/200
# 14/14 [==============================] - 0s 582us/step - loss: 136.5249
# Epoch 4/200
# 14/14 [==============================] - 0s 531us/step - loss: 100.3398
# Epoch 5/200
# 14/14 [==============================] - 0s 525us/step - loss: 81.5116
# Epoch 6/200
# 14/14 [==============================] - 0s 565us/step - loss: 67.5572
# Epoch 7/200
# 14/14 [==============================] - 0s 572us/step - loss: 58.5945
# Epoch 8/200
# 14/14 [==============================] - 0s 551us/step - loss: 60.9639
# Epoch 9/200
# 14/14 [==============================] - 0s 574us/step - loss: 52.1347
# Epoch 10/200
# 14/14 [==============================] - 0s 558us/step - loss: 61.5060
# Epoch 11/200
# 14/14 [==============================] - 0s 539us/step - loss: 66.1892
# Epoch 12/200
# 14/14 [==============================] - 0s 564us/step - loss: 50.7374
# Epoch 13/200
# 14/14 [==============================] - 0s 544us/step - loss: 45.6139
# Epoch 14/200
# 14/14 [==============================] - 0s 570us/step - loss: 42.1942
# Epoch 15/200
# 14/14 [==============================] - 0s 497us/step - loss: 41.9248
# Epoch 16/200
# 14/14 [==============================] - 0s 546us/step - loss: 41.8164
# Epoch 17/200
# 14/14 [==============================] - 0s 526us/step - loss: 45.2168
# Epoch 18/200
# 14/14 [==============================] - 0s 545us/step - loss: 42.3908
# Epoch 19/200
# 14/14 [==============================] - 0s 557us/step - loss: 40.8038
# Epoch 20/200
# 14/14 [==============================] - 0s 556us/step - loss: 37.9421
# Epoch 21/200
# 14/14 [==============================] - 0s 529us/step - loss: 41.8263
# Epoch 22/200
# 14/14 [==============================] - 0s 660us/step - loss: 37.3969
# Epoch 23/200
# 14/14 [==============================] - 0s 647us/step - loss: 38.0142
# Epoch 24/200
# 14/14 [==============================] - 0s 629us/step - loss: 38.9071
# Epoch 25/200
# 14/14 [==============================] - 0s 627us/step - loss: 35.0518
# Epoch 26/200
# 14/14 [==============================] - 0s 646us/step - loss: 43.6223
# Epoch 27/200
# 14/14 [==============================] - 0s 692us/step - loss: 34.9650
# Epoch 28/200
# 14/14 [==============================] - 0s 719us/step - loss: 35.1720
# Epoch 29/200
# 14/14 [==============================] - 0s 692us/step - loss: 38.3388
# Epoch 30/200
# 14/14 [==============================] - 0s 655us/step - loss: 33.6424
# Epoch 31/200
# 14/14 [==============================] - 0s 634us/step - loss: 37.6566
# Epoch 32/200
# 14/14 [==============================] - 0s 672us/step - loss: 36.2669
# Epoch 33/200
# 14/14 [==============================] - 0s 658us/step - loss: 36.9911
# Epoch 34/200
# 14/14 [==============================] - 0s 636us/step - loss: 34.8919
# Epoch 35/200
# 14/14 [==============================] - 0s 667us/step - loss: 37.9247
# Epoch 36/200
# 14/14 [==============================] - 0s 618us/step - loss: 44.2379
# Epoch 37/200
# 14/14 [==============================] - 0s 641us/step - loss: 32.6129
# Epoch 38/200
# 14/14 [==============================] - 0s 628us/step - loss: 33.7122
# Epoch 39/200
# 14/14 [==============================] - 0s 634us/step - loss: 36.3251
# Epoch 40/200
# 14/14 [==============================] - 0s 646us/step - loss: 34.4333
# Epoch 41/200
# 14/14 [==============================] - 0s 664us/step - loss: 36.1560
# Epoch 42/200
# 14/14 [==============================] - 0s 605us/step - loss: 38.0191
# Epoch 43/200
# 14/14 [==============================] - 0s 696us/step - loss: 33.9397
# Epoch 44/200
# 14/14 [==============================] - 0s 613us/step - loss: 33.4208
# Epoch 45/200
# 14/14 [==============================] - 0s 636us/step - loss: 36.1369
# Epoch 46/200
# 14/14 [==============================] - 0s 668us/step - loss: 33.4710
# Epoch 47/200
# 14/14 [==============================] - 0s 629us/step - loss: 40.0634
# Epoch 48/200
# 14/14 [==============================] - 0s 647us/step - loss: 43.8544
# Epoch 49/200
# 14/14 [==============================] - 0s 658us/step - loss: 33.5707
# Epoch 50/200
# 14/14 [==============================] - 0s 636us/step - loss: 31.2121
# Epoch 51/200
# 14/14 [==============================] - 0s 657us/step - loss: 33.3614
# Epoch 52/200
# 14/14 [==============================] - 0s 654us/step - loss: 32.1087
# Epoch 53/200
# 14/14 [==============================] - 0s 643us/step - loss: 33.8452
# Epoch 54/200
# 14/14 [==============================] - 0s 661us/step - loss: 40.6840
# Epoch 55/200
# 14/14 [==============================] - 0s 624us/step - loss: 33.4440
# Epoch 56/200
# 14/14 [==============================] - 0s 640us/step - loss: 33.7166
# Epoch 57/200
# 14/14 [==============================] - 0s 659us/step - loss: 33.4904
# Epoch 58/200
# 14/14 [==============================] - 0s 691us/step - loss: 32.8356
# Epoch 59/200
# 14/14 [==============================] - 0s 646us/step - loss: 31.7154
# Epoch 60/200
# 14/14 [==============================] - 0s 670us/step - loss: 31.1844
# Epoch 61/200
# 14/14 [==============================] - 0s 619us/step - loss: 35.7766
# Epoch 62/200
# 14/14 [==============================] - 0s 666us/step - loss: 30.6847
# Epoch 63/200
# 14/14 [==============================] - 0s 632us/step - loss: 33.1497
# Epoch 64/200
# 14/14 [==============================] - 0s 692us/step - loss: 32.8390
# Epoch 65/200
# 14/14 [==============================] - 0s 646us/step - loss: 34.5807
# Epoch 66/200
# 14/14 [==============================] - 0s 659us/step - loss: 33.1311
# Epoch 67/200
# 14/14 [==============================] - 0s 669us/step - loss: 32.7424
# Epoch 68/200
# 14/14 [==============================] - 0s 704us/step - loss: 32.5144
# Epoch 69/200
# 14/14 [==============================] - 0s 773us/step - loss: 33.9238
# Epoch 70/200
# 14/14 [==============================] - 0s 774us/step - loss: 31.8100
# Epoch 71/200
# 14/14 [==============================] - 0s 731us/step - loss: 32.1807
# Epoch 72/200
# 14/14 [==============================] - 0s 726us/step - loss: 31.1473
# Epoch 73/200
# 14/14 [==============================] - 0s 775us/step - loss: 33.8031
# Epoch 74/200
# 14/14 [==============================] - 0s 689us/step - loss: 34.2636
# Epoch 75/200
# 14/14 [==============================] - 0s 744us/step - loss: 37.3586
# Epoch 76/200
# 14/14 [==============================] - 0s 751us/step - loss: 32.8074
# Epoch 77/200
# 14/14 [==============================] - 0s 716us/step - loss: 32.3718
# Epoch 78/200
# 14/14 [==============================] - 0s 708us/step - loss: 31.8151
# Epoch 79/200
# 14/14 [==============================] - 0s 718us/step - loss: 36.7205
# Epoch 80/200
# 14/14 [==============================] - 0s 731us/step - loss: 34.3599
# Epoch 81/200
# 14/14 [==============================] - 0s 726us/step - loss: 35.6776
# Epoch 82/200
# 14/14 [==============================] - 0s 757us/step - loss: 31.7111
# Epoch 83/200
# 14/14 [==============================] - 0s 698us/step - loss: 33.5757
# Epoch 84/200
# 14/14 [==============================] - 0s 737us/step - loss: 32.7267
# Epoch 85/200
# 14/14 [==============================] - 0s 763us/step - loss: 33.1370
# Epoch 86/200
# 14/14 [==============================] - 0s 764us/step - loss: 35.3632
# Epoch 87/200
# 14/14 [==============================] - 0s 697us/step - loss: 34.6284
# Epoch 88/200
# 14/14 [==============================] - 0s 691us/step - loss: 30.5911
# Epoch 89/200
# 14/14 [==============================] - 0s 702us/step - loss: 33.9004
# Epoch 90/200
# 14/14 [==============================] - 0s 723us/step - loss: 33.2869
# Epoch 91/200
# 14/14 [==============================] - 0s 735us/step - loss: 33.5678
# Epoch 92/200
# 14/14 [==============================] - 0s 695us/step - loss: 33.9410
# Epoch 93/200
# 14/14 [==============================] - 0s 707us/step - loss: 32.3538
# Epoch 94/200
# 14/14 [==============================] - 0s 711us/step - loss: 32.2422
# Epoch 95/200
# 14/14 [==============================] - 0s 722us/step - loss: 31.1876
# Epoch 96/200
# 14/14 [==============================] - 0s 743us/step - loss: 34.4442
# Epoch 97/200
# 14/14 [==============================] - 0s 710us/step - loss: 32.9786
# Epoch 98/200
# 14/14 [==============================] - 0s 688us/step - loss: 32.9684
# Epoch 99/200
# 14/14 [==============================] - 0s 714us/step - loss: 34.1207
# Epoch 100/200
# 14/14 [==============================] - 0s 685us/step - loss: 31.3018
# Epoch 101/200
# 14/14 [==============================] - 0s 738us/step - loss: 32.8776
# Epoch 102/200
# 14/14 [==============================] - 0s 723us/step - loss: 32.6460
# Epoch 103/200
# 14/14 [==============================] - 0s 689us/step - loss: 32.3690
# Epoch 104/200
# 14/14 [==============================] - 0s 720us/step - loss: 30.4591
# Epoch 105/200
# 14/14 [==============================] - 0s 748us/step - loss: 32.5098
# Epoch 106/200
# 14/14 [==============================] - 0s 731us/step - loss: 32.3574
# Epoch 107/200
# 14/14 [==============================] - 0s 720us/step - loss: 33.2571
# Epoch 108/200
# 14/14 [==============================] - 0s 725us/step - loss: 36.4321
# Epoch 109/200
# 14/14 [==============================] - 0s 727us/step - loss: 32.7979
# Epoch 110/200
# 14/14 [==============================] - 0s 711us/step - loss: 33.2712
# Epoch 111/200
# 14/14 [==============================] - 0s 701us/step - loss: 35.0113
# Epoch 112/200
# 14/14 [==============================] - 0s 697us/step - loss: 30.1215
# Epoch 113/200
# 14/14 [==============================] - 0s 704us/step - loss: 35.2458
# Epoch 114/200
# 14/14 [==============================] - 0s 689us/step - loss: 31.7845
# Epoch 115/200
# 14/14 [==============================] - 0s 727us/step - loss: 31.2782
# Epoch 116/200
# 14/14 [==============================] - 0s 735us/step - loss: 36.4569
# Epoch 117/200
# 14/14 [==============================] - 0s 748us/step - loss: 35.2195
# Epoch 118/200
# 14/14 [==============================] - 0s 729us/step - loss: 32.0112
# Epoch 119/200
# 14/14 [==============================] - 0s 707us/step - loss: 34.1500
# Epoch 120/200
# 14/14 [==============================] - 0s 757us/step - loss: 30.8038
# Epoch 121/200
# 14/14 [==============================] - 0s 700us/step - loss: 33.5521
# Epoch 122/200
# 14/14 [==============================] - 0s 702us/step - loss: 33.4762
# Epoch 123/200
# 14/14 [==============================] - 0s 772us/step - loss: 33.3591
# Epoch 124/200
# 14/14 [==============================] - 0s 696us/step - loss: 34.3718
# Epoch 125/200
# 14/14 [==============================] - 0s 678us/step - loss: 31.3490
# Epoch 126/200
# 14/14 [==============================] - 0s 742us/step - loss: 35.0278
# Epoch 127/200
# 14/14 [==============================] - 0s 710us/step - loss: 32.7430
# Epoch 128/200
# 14/14 [==============================] - 0s 673us/step - loss: 32.7209
# Epoch 129/200
# 14/14 [==============================] - 0s 706us/step - loss: 32.0895
# Epoch 130/200
# 14/14 [==============================] - 0s 751us/step - loss: 31.8831
# Epoch 131/200
# 14/14 [==============================] - 0s 704us/step - loss: 31.5392
# Epoch 132/200
# 14/14 [==============================] - 0s 700us/step - loss: 40.6413
# Epoch 133/200
# 14/14 [==============================] - 0s 684us/step - loss: 34.2470
# Epoch 134/200
# 14/14 [==============================] - 0s 701us/step - loss: 31.4850
# Epoch 135/200
# 14/14 [==============================] - 0s 765us/step - loss: 33.7549
# Epoch 136/200
# 14/14 [==============================] - 0s 726us/step - loss: 33.4783
# Epoch 137/200
# 14/14 [==============================] - 0s 711us/step - loss: 31.0080
# Epoch 138/200
# 14/14 [==============================] - 0s 695us/step - loss: 33.3026
# Epoch 139/200
# 14/14 [==============================] - 0s 726us/step - loss: 32.4450
# Epoch 140/200
# 14/14 [==============================] - 0s 718us/step - loss: 32.0146
# Epoch 141/200
# 14/14 [==============================] - 0s 674us/step - loss: 29.6881
# Epoch 142/200
# 14/14 [==============================] - 0s 691us/step - loss: 33.1050
# Epoch 143/200
# 14/14 [==============================] - 0s 697us/step - loss: 31.6551
# Epoch 144/200
# 14/14 [==============================] - 0s 802us/step - loss: 31.4791
# Epoch 145/200
# 14/14 [==============================] - 0s 698us/step - loss: 31.7698
# Epoch 146/200
# 14/14 [==============================] - 0s 759us/step - loss: 33.4056
# Epoch 147/200
# 14/14 [==============================] - 0s 684us/step - loss: 32.9168
# Epoch 148/200
# 14/14 [==============================] - 0s 742us/step - loss: 33.3801
# Epoch 149/200
# 14/14 [==============================] - 0s 742us/step - loss: 34.4997
# Epoch 150/200
# 14/14 [==============================] - 0s 719us/step - loss: 30.3230
# Epoch 151/200
# 14/14 [==============================] - 0s 686us/step - loss: 30.0787
# Epoch 152/200
# 14/14 [==============================] - 0s 731us/step - loss: 31.2781
# Epoch 153/200
# 14/14 [==============================] - 0s 725us/step - loss: 30.9848
# Epoch 154/200
# 14/14 [==============================] - 0s 732us/step - loss: 31.6970
# Epoch 155/200
# 14/14 [==============================] - 0s 682us/step - loss: 32.7135
# Epoch 156/200
# 14/14 [==============================] - 0s 687us/step - loss: 31.1765
# Epoch 157/200
# 14/14 [==============================] - 0s 726us/step - loss: 30.7149
# Epoch 158/200
# 14/14 [==============================] - 0s 737us/step - loss: 33.2317
# Epoch 159/200
# 14/14 [==============================] - 0s 724us/step - loss: 31.0451
# Epoch 160/200
# 14/14 [==============================] - 0s 726us/step - loss: 31.5878
# Epoch 161/200
# 14/14 [==============================] - 0s 697us/step - loss: 30.7367
# Epoch 162/200
# 14/14 [==============================] - 0s 712us/step - loss: 31.6238
# Epoch 163/200
# 14/14 [==============================] - 0s 695us/step - loss: 35.9635
# Epoch 164/200
# 14/14 [==============================] - 0s 720us/step - loss: 30.9598
# Epoch 165/200
# 14/14 [==============================] - 0s 681us/step - loss: 32.7046
# Epoch 166/200
# 14/14 [==============================] - 0s 712us/step - loss: 35.9342
# Epoch 167/200
# 14/14 [==============================] - 0s 677us/step - loss: 33.8508
# Epoch 168/200
# 14/14 [==============================] - 0s 728us/step - loss: 31.2002
# Epoch 169/200
# 14/14 [==============================] - 0s 706us/step - loss: 33.4429
# Epoch 170/200
# 14/14 [==============================] - 0s 727us/step - loss: 31.9571
# Epoch 171/200
# 14/14 [==============================] - 0s 685us/step - loss: 36.5157
# Epoch 172/200
# 14/14 [==============================] - 0s 716us/step - loss: 31.8488
# Epoch 173/200
# 14/14 [==============================] - 0s 700us/step - loss: 32.6708
# Epoch 174/200
# 14/14 [==============================] - 0s 749us/step - loss: 33.2994
# Epoch 175/200
# 14/14 [==============================] - 0s 695us/step - loss: 31.6536
# Epoch 176/200
# 14/14 [==============================] - 0s 696us/step - loss: 33.5088
# Epoch 177/200
# 14/14 [==============================] - 0s 724us/step - loss: 32.5558
# Epoch 178/200
# 14/14 [==============================] - 0s 739us/step - loss: 31.1272
# Epoch 179/200
# 14/14 [==============================] - 0s 713us/step - loss: 31.2206
# Epoch 180/200
# 14/14 [==============================] - 0s 752us/step - loss: 34.9612
# Epoch 181/200
# 14/14 [==============================] - 0s 743us/step - loss: 31.8767
# Epoch 182/200
# 14/14 [==============================] - 0s 729us/step - loss: 32.0266
# Epoch 183/200
# 14/14 [==============================] - 0s 694us/step - loss: 32.4829
# Epoch 184/200
# 14/14 [==============================] - 0s 672us/step - loss: 31.2023
# Epoch 185/200
# 14/14 [==============================] - 0s 733us/step - loss: 32.3995
# Epoch 186/200
# 14/14 [==============================] - 0s 703us/step - loss: 31.3314
# Epoch 187/200
# 14/14 [==============================] - 0s 760us/step - loss: 32.5765
# Epoch 188/200
# 14/14 [==============================] - 0s 696us/step - loss: 32.1216
# Epoch 189/200
# 14/14 [==============================] - 0s 710us/step - loss: 32.4318
# Epoch 190/200
# 14/14 [==============================] - 0s 668us/step - loss: 31.0494
# Epoch 191/200
# 14/14 [==============================] - 0s 660us/step - loss: 33.7808
# Epoch 192/200
# 14/14 [==============================] - 0s 734us/step - loss: 32.6446
# Epoch 193/200
# 14/14 [==============================] - 0s 723us/step - loss: 31.9294
# Epoch 194/200
# 14/14 [==============================] - 0s 702us/step - loss: 31.0739
# Epoch 195/200
# 14/14 [==============================] - 0s 695us/step - loss: 32.3342
# Epoch 196/200
# 14/14 [==============================] - 0s 721us/step - loss: 32.0977
# Epoch 197/200
# 14/14 [==============================] - 0s 747us/step - loss: 31.6733
# Epoch 198/200
# 14/14 [==============================] - 0s 692us/step - loss: 32.8037
# Epoch 199/200
# 14/14 [==============================] - 0s 743us/step - loss: 30.6396
# Epoch 200/200
# 14/14 [==============================] - 0s 755us/step - loss: 31.2843
# Epoch 1/200
# 14/14 [==============================] - 0s 619us/step - loss: 707.2562
# Epoch 2/200
# 14/14 [==============================] - 0s 597us/step - loss: 260.5164
# Epoch 3/200
# 14/14 [==============================] - 0s 534us/step - loss: 132.9991
# Epoch 4/200
# 14/14 [==============================] - 0s 537us/step - loss: 109.9601
# Epoch 5/200
# 14/14 [==============================] - 0s 522us/step - loss: 82.5434
# Epoch 6/200
# 14/14 [==============================] - 0s 542us/step - loss: 67.3539
# Epoch 7/200
# 14/14 [==============================] - 0s 507us/step - loss: 59.0484
# Epoch 8/200
# 14/14 [==============================] - 0s 534us/step - loss: 62.2951
# Epoch 9/200
# 14/14 [==============================] - 0s 542us/step - loss: 63.9285
# Epoch 10/200
# 14/14 [==============================] - 0s 550us/step - loss: 62.4422
# Epoch 11/200
# 14/14 [==============================] - 0s 577us/step - loss: 48.4474
# Epoch 12/200
# 14/14 [==============================] - 0s 545us/step - loss: 46.0685
# Epoch 13/200
# 14/14 [==============================] - 0s 549us/step - loss: 54.5607
# Epoch 14/200
# 14/14 [==============================] - 0s 538us/step - loss: 43.8617
# Epoch 15/200
# 14/14 [==============================] - 0s 553us/step - loss: 37.4134
# Epoch 16/200
# 14/14 [==============================] - 0s 556us/step - loss: 43.5349
# Epoch 17/200
# 14/14 [==============================] - 0s 560us/step - loss: 38.2896
# Epoch 18/200
# 14/14 [==============================] - 0s 546us/step - loss: 39.6387
# Epoch 19/200
# 14/14 [==============================] - 0s 523us/step - loss: 39.1037
# Epoch 20/200
# 14/14 [==============================] - 0s 527us/step - loss: 42.0533
# Epoch 21/200
# 14/14 [==============================] - 0s 575us/step - loss: 42.8522
# Epoch 22/200
# 14/14 [==============================] - 0s 555us/step - loss: 40.8118
# Epoch 23/200
# 14/14 [==============================] - 0s 539us/step - loss: 36.3188
# Epoch 24/200
# 14/14 [==============================] - 0s 535us/step - loss: 39.2731
# Epoch 25/200
# 14/14 [==============================] - 0s 578us/step - loss: 36.5326
# Epoch 26/200
# 14/14 [==============================] - 0s 568us/step - loss: 36.8004
# Epoch 27/200
# 14/14 [==============================] - 0s 618us/step - loss: 34.4427
# Epoch 28/200
# 14/14 [==============================] - 0s 582us/step - loss: 34.2545
# Epoch 29/200
# 14/14 [==============================] - 0s 615us/step - loss: 35.4136
# Epoch 30/200
# 14/14 [==============================] - 0s 591us/step - loss: 38.5573
# Epoch 31/200
# 14/14 [==============================] - 0s 578us/step - loss: 38.8898
# Epoch 32/200
# 14/14 [==============================] - 0s 599us/step - loss: 32.5818
# Epoch 33/200
# 14/14 [==============================] - 0s 593us/step - loss: 32.3627
# Epoch 34/200
# 14/14 [==============================] - 0s 603us/step - loss: 32.5126
# Epoch 35/200
# 14/14 [==============================] - 0s 555us/step - loss: 33.3641
# Epoch 36/200
# 14/14 [==============================] - 0s 583us/step - loss: 36.8124
# Epoch 37/200
# 14/14 [==============================] - 0s 589us/step - loss: 32.3151
# Epoch 38/200
# 14/14 [==============================] - 0s 618us/step - loss: 36.2991
# Epoch 39/200
# 14/14 [==============================] - 0s 623us/step - loss: 43.1931
# Epoch 40/200
# 14/14 [==============================] - 0s 607us/step - loss: 32.4234
# Epoch 41/200
# 14/14 [==============================] - 0s 604us/step - loss: 34.5929
# Epoch 42/200
# 14/14 [==============================] - 0s 586us/step - loss: 33.1475
# Epoch 43/200
# 14/14 [==============================] - 0s 565us/step - loss: 32.3098
# Epoch 44/200
# 14/14 [==============================] - 0s 595us/step - loss: 35.1504
# Epoch 45/200
# 14/14 [==============================] - 0s 595us/step - loss: 31.8741
# Epoch 46/200
# 14/14 [==============================] - 0s 599us/step - loss: 34.8130
# Epoch 47/200
# 14/14 [==============================] - 0s 651us/step - loss: 33.6059
# Epoch 48/200
# 14/14 [==============================] - 0s 608us/step - loss: 31.1724
# Epoch 49/200
# 14/14 [==============================] - 0s 571us/step - loss: 35.0417
# Epoch 50/200
# 14/14 [==============================] - 0s 602us/step - loss: 31.9119
# Epoch 51/200
# 14/14 [==============================] - 0s 589us/step - loss: 32.1780
# Epoch 52/200
# 14/14 [==============================] - 0s 598us/step - loss: 34.3437
# Epoch 53/200
# 14/14 [==============================] - 0s 610us/step - loss: 34.5707
# Epoch 54/200
# 14/14 [==============================] - 0s 618us/step - loss: 32.6736
# Epoch 55/200
# 14/14 [==============================] - 0s 600us/step - loss: 44.0446
# Epoch 56/200
# 14/14 [==============================] - 0s 580us/step - loss: 34.1682
# Epoch 57/200
# 14/14 [==============================] - 0s 586us/step - loss: 32.2258
# Epoch 58/200
# 14/14 [==============================] - 0s 606us/step - loss: 32.9788
# Epoch 59/200
# 14/14 [==============================] - 0s 582us/step - loss: 39.7966
# Epoch 60/200
# 14/14 [==============================] - 0s 615us/step - loss: 36.4097
# Epoch 61/200
# 14/14 [==============================] - 0s 610us/step - loss: 31.6650
# Epoch 62/200
# 14/14 [==============================] - 0s 594us/step - loss: 33.1499
# Epoch 63/200
# 14/14 [==============================] - 0s 606us/step - loss: 32.5190
# Epoch 64/200
# 14/14 [==============================] - 0s 613us/step - loss: 33.1776
# Epoch 65/200
# 14/14 [==============================] - 0s 564us/step - loss: 31.9687
# Epoch 66/200
# 14/14 [==============================] - 0s 585us/step - loss: 32.3275
# Epoch 67/200
# 14/14 [==============================] - 0s 665us/step - loss: 32.8171
# Epoch 68/200
# 14/14 [==============================] - 0s 621us/step - loss: 35.7767
# Epoch 69/200
# 14/14 [==============================] - 0s 636us/step - loss: 31.5233
# Epoch 70/200
# 14/14 [==============================] - 0s 636us/step - loss: 38.2472
# Epoch 71/200
# 14/14 [==============================] - 0s 577us/step - loss: 30.6937
# Epoch 72/200
# 14/14 [==============================] - 0s 592us/step - loss: 32.2387
# Epoch 73/200
# 14/14 [==============================] - 0s 602us/step - loss: 30.6902
# Epoch 74/200
# 14/14 [==============================] - 0s 598us/step - loss: 32.5981
# Epoch 75/200
# 14/14 [==============================] - 0s 623us/step - loss: 31.8466
# Epoch 76/200
# 14/14 [==============================] - 0s 614us/step - loss: 30.5294
# Epoch 77/200
# 14/14 [==============================] - 0s 642us/step - loss: 32.4137
# Epoch 78/200
# 14/14 [==============================] - 0s 591us/step - loss: 33.3072
# Epoch 79/200
# 14/14 [==============================] - 0s 581us/step - loss: 32.8903
# Epoch 80/200
# 14/14 [==============================] - 0s 563us/step - loss: 30.8809
# Epoch 81/200
# 14/14 [==============================] - 0s 589us/step - loss: 30.1364
# Epoch 82/200
# 14/14 [==============================] - 0s 603us/step - loss: 32.0673
# Epoch 83/200
# 14/14 [==============================] - 0s 599us/step - loss: 34.5891
# Epoch 84/200
# 14/14 [==============================] - 0s 629us/step - loss: 32.4819
# Epoch 85/200
# 14/14 [==============================] - 0s 603us/step - loss: 34.2744
# Epoch 86/200
# 14/14 [==============================] - 0s 595us/step - loss: 31.3945
# Epoch 87/200
# 14/14 [==============================] - 0s 598us/step - loss: 33.6784
# Epoch 88/200
# 14/14 [==============================] - 0s 623us/step - loss: 32.8749
# Epoch 89/200
# 14/14 [==============================] - 0s 652us/step - loss: 31.8539
# Epoch 90/200
# 14/14 [==============================] - 0s 675us/step - loss: 33.6555
# Epoch 91/200
# 14/14 [==============================] - 0s 674us/step - loss: 32.5981
# Epoch 92/200
# 14/14 [==============================] - 0s 658us/step - loss: 34.4198
# Epoch 93/200
# 14/14 [==============================] - 0s 655us/step - loss: 32.7416
# Epoch 94/200
# 14/14 [==============================] - 0s 631us/step - loss: 32.6345
# Epoch 95/200
# 14/14 [==============================] - 0s 660us/step - loss: 31.0855
# Epoch 96/200
# 14/14 [==============================] - 0s 654us/step - loss: 31.7419
# Epoch 97/200
# 14/14 [==============================] - 0s 655us/step - loss: 33.8027
# Epoch 98/200
# 14/14 [==============================] - 0s 654us/step - loss: 30.2918
# Epoch 99/200
# 14/14 [==============================] - 0s 640us/step - loss: 33.3499
# Epoch 100/200
# 14/14 [==============================] - 0s 664us/step - loss: 30.8766
# Epoch 101/200
# 14/14 [==============================] - 0s 662us/step - loss: 31.4629
# Epoch 102/200
# 14/14 [==============================] - 0s 625us/step - loss: 34.6576
# Epoch 103/200
# 14/14 [==============================] - 0s 661us/step - loss: 30.8565
# Epoch 104/200
# 14/14 [==============================] - 0s 649us/step - loss: 34.7793
# Epoch 105/200
# 14/14 [==============================] - 0s 644us/step - loss: 32.4470
# Epoch 106/200
# 14/14 [==============================] - 0s 651us/step - loss: 32.4928
# Epoch 107/200
# 14/14 [==============================] - 0s 674us/step - loss: 31.7794
# Epoch 108/200
# 14/14 [==============================] - 0s 639us/step - loss: 30.3507
# Epoch 109/200
# 14/14 [==============================] - 0s 684us/step - loss: 30.5027
# Epoch 110/200
# 14/14 [==============================] - 0s 772us/step - loss: 33.0682
# Epoch 111/200
# 14/14 [==============================] - 0s 675us/step - loss: 31.2218
# Epoch 112/200
# 14/14 [==============================] - 0s 650us/step - loss: 30.0988
# Epoch 113/200
# 14/14 [==============================] - 0s 650us/step - loss: 32.8341
# Epoch 114/200
# 14/14 [==============================] - 0s 676us/step - loss: 30.4947
# Epoch 115/200
# 14/14 [==============================] - 0s 649us/step - loss: 35.1605
# Epoch 116/200
# 14/14 [==============================] - 0s 665us/step - loss: 32.3211
# Epoch 117/200
# 14/14 [==============================] - 0s 612us/step - loss: 33.3419
# Epoch 118/200
# 14/14 [==============================] - 0s 714us/step - loss: 34.7929
# Epoch 119/200
# 14/14 [==============================] - 0s 662us/step - loss: 30.7379
# Epoch 120/200
# 14/14 [==============================] - 0s 661us/step - loss: 30.8285
# Epoch 121/200
# 14/14 [==============================] - 0s 715us/step - loss: 31.5203
# Epoch 122/200
# 14/14 [==============================] - 0s 684us/step - loss: 33.5282
# Epoch 123/200
# 14/14 [==============================] - 0s 653us/step - loss: 29.9827
# Epoch 124/200
# 14/14 [==============================] - 0s 648us/step - loss: 32.5882
# Epoch 125/200
# 14/14 [==============================] - 0s 694us/step - loss: 32.3070
# Epoch 126/200
# 14/14 [==============================] - 0s 642us/step - loss: 30.1722
# Epoch 127/200
# 14/14 [==============================] - 0s 649us/step - loss: 31.6048
# Epoch 128/200
# 14/14 [==============================] - 0s 667us/step - loss: 30.8411
# Epoch 129/200
# 14/14 [==============================] - 0s 657us/step - loss: 30.2003
# Epoch 130/200
# 14/14 [==============================] - 0s 668us/step - loss: 30.5095
# Epoch 131/200
# 14/14 [==============================] - 0s 719us/step - loss: 36.0958
# Epoch 132/200
# 14/14 [==============================] - 0s 644us/step - loss: 30.4986
# Epoch 133/200
# 14/14 [==============================] - 0s 636us/step - loss: 30.8887
# Epoch 134/200
# 14/14 [==============================] - 0s 652us/step - loss: 30.5669
# Epoch 135/200
# 14/14 [==============================] - 0s 694us/step - loss: 30.8424
# Epoch 136/200
# 14/14 [==============================] - 0s 657us/step - loss: 30.4203
# Epoch 137/200
# 14/14 [==============================] - 0s 680us/step - loss: 33.6521
# Epoch 138/200
# 14/14 [==============================] - 0s 644us/step - loss: 32.7265
# Epoch 139/200
# 14/14 [==============================] - 0s 684us/step - loss: 30.3352
# Epoch 140/200
# 14/14 [==============================] - 0s 650us/step - loss: 32.0413
# Epoch 141/200
# 14/14 [==============================] - 0s 648us/step - loss: 32.0094
# Epoch 142/200
# 14/14 [==============================] - 0s 644us/step - loss: 30.5224
# Epoch 143/200
# 14/14 [==============================] - 0s 699us/step - loss: 30.9113
# Epoch 144/200
# 14/14 [==============================] - 0s 713us/step - loss: 30.6548
# Epoch 145/200
# 14/14 [==============================] - 0s 647us/step - loss: 31.8830
# Epoch 146/200
# 14/14 [==============================] - 0s 647us/step - loss: 30.8096
# Epoch 147/200
# 14/14 [==============================] - 0s 645us/step - loss: 30.7433
# Epoch 148/200
# 14/14 [==============================] - 0s 658us/step - loss: 32.0797
# Epoch 149/200
# ...
# Epoch 15/200
# 14/14 [==============================] - 0s 684us/step - loss: 48.8115
# Epoch 16/200
# 14/14 [==============================] - 0s 736us/step - loss: 49.0719
# Epoch 17/200
# 14/14 [==============================] - 0s 747us/step - loss: 48.0935
# Epoch 18/200
# 14/14 [==============================] - 0s 721us/step - loss: 44.2971
# Epoch 19/200
# 14/14 [==============================] - 0s 762us/step - loss: 43.9863
# Epoch 20/200
# 14/14 [==============================] - 0s 751us/step - loss: 41.0600
# Epoch 21/200
# 14/14 [==============================] - 0s 736us/step - loss: 39.1319
# Epoch 22/200
# 14/14 [==============================] - 0s 794us/step - loss: 40.3816
# Epoch 23/200
# 14/14 [==============================] - 0s 688us/step - loss: 37.0010
# Epoch 24/200
# 14/14 [==============================] - 0s 724us/step - loss: 38.6545
# Epoch 25/200
# 14/14 [==============================] - 0s 714us/step - loss: 35.5466
# Epoch 26/200
# 14/14 [==============================] - 0s 765us/step - loss: 37.9176
# Epoch 27/200
# 14/14 [==============================] - 0s 731us/step - loss: 38.1537
# Epoch 28/200
# 14/14 [==============================] - 0s 749us/step - loss: 36.4052
# Epoch 29/200
# 14/14 [==============================] - 0s 705us/step - loss: 35.9331
# Epoch 30/200
# 14/14 [==============================] - 0s 692us/step - loss: 34.6167
# Epoch 31/200
# 14/14 [==============================] - 0s 739us/step - loss: 35.8061
# Epoch 32/200
# 14/14 [==============================] - 0s 732us/step - loss: 36.5709
# Epoch 33/200
# 14/14 [==============================] - 0s 747us/step - loss: 34.6399
# Epoch 34/200
# 14/14 [==============================] - 0s 704us/step - loss: 34.3917
# Epoch 35/200
# 14/14 [==============================] - 0s 760us/step - loss: 33.6533
# Epoch 36/200
# 14/14 [==============================] - 0s 736us/step - loss: 35.3989
# Epoch 37/200
# 14/14 [==============================] - 0s 718us/step - loss: 39.3450
# Epoch 38/200
# 14/14 [==============================] - 0s 740us/step - loss: 32.8843
# Epoch 39/200
# 14/14 [==============================] - 0s 738us/step - loss: 31.7263
# Epoch 40/200
# 14/14 [==============================] - 0s 711us/step - loss: 32.6185
# Epoch 41/200
# 14/14 [==============================] - 0s 710us/step - loss: 33.0763
# Epoch 42/200
# 14/14 [==============================] - 0s 743us/step - loss: 32.2595
# Epoch 43/200
# 14/14 [==============================] - 0s 732us/step - loss: 33.6150
# Epoch 44/200
# 14/14 [==============================] - 0s 744us/step - loss: 33.9921
# Epoch 45/200
# 14/14 [==============================] - 0s 778us/step - loss: 31.9019
# Epoch 46/200
# 14/14 [==============================] - 0s 742us/step - loss: 33.1464
# Epoch 47/200
# 14/14 [==============================] - 0s 713us/step - loss: 31.5703
# Epoch 48/200
# 14/14 [==============================] - 0s 767us/step - loss: 33.5249
# Epoch 49/200
# 14/14 [==============================] - 0s 830us/step - loss: 32.2542
# Epoch 50/200
# 14/14 [==============================] - 0s 754us/step - loss: 32.6580
# Epoch 51/200
# 14/14 [==============================] - 0s 718us/step - loss: 30.3195
# Epoch 52/200
# 14/14 [==============================] - 0s 744us/step - loss: 30.9103
# Epoch 53/200
# 14/14 [==============================] - 0s 679us/step - loss: 30.6705
# Epoch 54/200
# 14/14 [==============================] - 0s 704us/step - loss: 30.6842
# Epoch 55/200
# 14/14 [==============================] - 0s 733us/step - loss: 31.2268
# Epoch 56/200
# 14/14 [==============================] - 0s 731us/step - loss: 30.0920
# Epoch 57/200
# 14/14 [==============================] - 0s 705us/step - loss: 31.2414
# Epoch 58/200
# 14/14 [==============================] - 0s 777us/step - loss: 33.3955
# Epoch 59/200
# 14/14 [==============================] - 0s 769us/step - loss: 31.9004
# Epoch 60/200
# 14/14 [==============================] - 0s 740us/step - loss: 30.7726
# Epoch 61/200
# 14/14 [==============================] - 0s 697us/step - loss: 30.6785
# Epoch 62/200
# 14/14 [==============================] - 0s 699us/step - loss: 32.1759
# Epoch 63/200
# 14/14 [==============================] - 0s 706us/step - loss: 30.0343
# Epoch 64/200
# 14/14 [==============================] - 0s 714us/step - loss: 30.4742
# Epoch 65/200
# 14/14 [==============================] - 0s 716us/step - loss: 30.9049
# Epoch 66/200
# 14/14 [==============================] - 0s 700us/step - loss: 30.4895
# Epoch 67/200
# 14/14 [==============================] - 0s 739us/step - loss: 31.2730
# Epoch 68/200
# 14/14 [==============================] - 0s 717us/step - loss: 31.2871
# Epoch 69/200
# 14/14 [==============================] - 0s 730us/step - loss: 30.3823
# Epoch 70/200
# 14/14 [==============================] - 0s 701us/step - loss: 29.8214
# Epoch 71/200
# 14/14 [==============================] - 0s 711us/step - loss: 31.0091
# Epoch 72/200
# 14/14 [==============================] - 0s 729us/step - loss: 30.6261
# Epoch 73/200
# 14/14 [==============================] - 0s 734us/step - loss: 30.6972
# Epoch 74/200
# 14/14 [==============================] - 0s 768us/step - loss: 29.1507
# Epoch 75/200
# 14/14 [==============================] - 0s 715us/step - loss: 33.9297
# Epoch 76/200
# 14/14 [==============================] - 0s 743us/step - loss: 30.5408
# Epoch 77/200
# 14/14 [==============================] - 0s 722us/step - loss: 29.5327
# Epoch 78/200
# 14/14 [==============================] - 0s 671us/step - loss: 28.6784
# Epoch 79/200
# 14/14 [==============================] - 0s 719us/step - loss: 28.9536
# Epoch 80/200
# 14/14 [==============================] - 0s 696us/step - loss: 29.4376
# Epoch 81/200
# 14/14 [==============================] - 0s 733us/step - loss: 29.3334
# Epoch 82/200
# 14/14 [==============================] - 0s 777us/step - loss: 30.1225
# Epoch 83/200
# 14/14 [==============================] - 0s 767us/step - loss: 29.6997
# Epoch 84/200
# 14/14 [==============================] - 0s 697us/step - loss: 29.6516
# Epoch 85/200
# 14/14 [==============================] - 0s 771us/step - loss: 28.7666
# Epoch 86/200
# 14/14 [==============================] - 0s 754us/step - loss: 28.8591
# Epoch 87/200
# 14/14 [==============================] - 0s 717us/step - loss: 29.4471
# Epoch 88/200
# 14/14 [==============================] - 0s 775us/step - loss: 28.7609
# Epoch 89/200
# 14/14 [==============================] - 0s 747us/step - loss: 28.6579
# Epoch 90/200
# 14/14 [==============================] - 0s 765us/step - loss: 30.9282
# Epoch 91/200
# 14/14 [==============================] - 0s 768us/step - loss: 28.6535
# Epoch 92/200
# 14/14 [==============================] - 0s 732us/step - loss: 28.6864
# Epoch 93/200
# 14/14 [==============================] - 0s 697us/step - loss: 28.6031
# Epoch 94/200
# 14/14 [==============================] - 0s 732us/step - loss: 29.2478
# Epoch 95/200
# 14/14 [==============================] - 0s 736us/step - loss: 30.3939
# Epoch 96/200
# 14/14 [==============================] - 0s 734us/step - loss: 28.5249
# Epoch 97/200
# 14/14 [==============================] - 0s 727us/step - loss: 29.2770
# Epoch 98/200
# 14/14 [==============================] - 0s 724us/step - loss: 29.7495
# Epoch 99/200
# 14/14 [==============================] - 0s 801us/step - loss: 28.7501
# Epoch 100/200
# 14/14 [==============================] - 0s 766us/step - loss: 28.6545
# Epoch 101/200
# 14/14 [==============================] - 0s 730us/step - loss: 30.2044
# Epoch 102/200
# 14/14 [==============================] - 0s 664us/step - loss: 29.6034
# Epoch 103/200
# 14/14 [==============================] - 0s 709us/step - loss: 28.9018
# Epoch 104/200
# 14/14 [==============================] - 0s 727us/step - loss: 28.1512
# Epoch 105/200
# 14/14 [==============================] - 0s 757us/step - loss: 28.9444
# Epoch 106/200
# 14/14 [==============================] - 0s 773us/step - loss: 28.3521
# Epoch 107/200
# 14/14 [==============================] - 0s 755us/step - loss: 29.0574
# Epoch 108/200
# 14/14 [==============================] - 0s 738us/step - loss: 28.4848
# Epoch 109/200
# 14/14 [==============================] - 0s 696us/step - loss: 29.3049
# Epoch 110/200
# 14/14 [==============================] - 0s 732us/step - loss: 28.3091
# Epoch 111/200
# 14/14 [==============================] - 0s 776us/step - loss: 29.4593
# Epoch 112/200
# 14/14 [==============================] - 0s 734us/step - loss: 28.8311
# Epoch 113/200
# 14/14 [==============================] - 0s 679us/step - loss: 28.9986
# Epoch 114/200
# 14/14 [==============================] - 0s 733us/step - loss: 28.5919
# Epoch 115/200
# 14/14 [==============================] - 0s 719us/step - loss: 28.6183
# Epoch 116/200
# 14/14 [==============================] - 0s 723us/step - loss: 28.2867
# Epoch 117/200
# 14/14 [==============================] - 0s 743us/step - loss: 28.2110
# Epoch 118/200
# 14/14 [==============================] - 0s 729us/step - loss: 28.7752
# Epoch 119/200
# 14/14 [==============================] - 0s 705us/step - loss: 29.4005
# Epoch 120/200
# 14/14 [==============================] - 0s 749us/step - loss: 28.2884
# Epoch 121/200
# 14/14 [==============================] - 0s 734us/step - loss: 28.9229
# Epoch 122/200
# 14/14 [==============================] - 0s 735us/step - loss: 29.1302
# Epoch 123/200
# 14/14 [==============================] - 0s 744us/step - loss: 29.1051
# Epoch 124/200
# 14/14 [==============================] - 0s 718us/step - loss: 28.5029
# Epoch 125/200
# 14/14 [==============================] - 0s 727us/step - loss: 28.0269
# Epoch 126/200
# 14/14 [==============================] - 0s 762us/step - loss: 28.8741
# Epoch 127/200
# 14/14 [==============================] - 0s 735us/step - loss: 28.3252
# Epoch 128/200
# 14/14 [==============================] - 0s 759us/step - loss: 28.4596
# Epoch 129/200
# 14/14 [==============================] - 0s 712us/step - loss: 28.7317
# Epoch 130/200
# 14/14 [==============================] - 0s 696us/step - loss: 28.5414
# Epoch 131/200
# 14/14 [==============================] - 0s 749us/step - loss: 28.3397
# Epoch 132/200
# 14/14 [==============================] - 0s 745us/step - loss: 28.7698
# Epoch 133/200
# 14/14 [==============================] - 0s 733us/step - loss: 28.3960
# Epoch 134/200
# 14/14 [==============================] - 0s 737us/step - loss: 29.5680
# Epoch 135/200
# 14/14 [==============================] - 0s 761us/step - loss: 28.6504
# Epoch 136/200
# 14/14 [==============================] - 0s 734us/step - loss: 28.9411
# Epoch 137/200
# 14/14 [==============================] - 0s 763us/step - loss: 28.8335
# Epoch 138/200
# 14/14 [==============================] - 0s 768us/step - loss: 28.4202
# Epoch 139/200
# 14/14 [==============================] - 0s 742us/step - loss: 29.0083
# Epoch 140/200
# 14/14 [==============================] - 0s 719us/step - loss: 29.6445
# Epoch 141/200
# 14/14 [==============================] - 0s 709us/step - loss: 29.3224
# Epoch 142/200
# 14/14 [==============================] - 0s 756us/step - loss: 29.4786
# Epoch 143/200
# 14/14 [==============================] - 0s 773us/step - loss: 28.2487
# Epoch 144/200
# 14/14 [==============================] - 0s 719us/step - loss: 28.3689
# Epoch 145/200
# 14/14 [==============================] - 0s 711us/step - loss: 28.2249
# Epoch 146/200
# 14/14 [==============================] - 0s 731us/step - loss: 28.4581
# Epoch 147/200
# 14/14 [==============================] - 0s 765us/step - loss: 29.3189
# Epoch 148/200
# 14/14 [==============================] - 0s 745us/step - loss: 28.6402
# Epoch 149/200
# 14/14 [==============================] - 0s 708us/step - loss: 29.1309
# Epoch 150/200
# 14/14 [==============================] - 0s 750us/step - loss: 29.5383
# Epoch 151/200
# 14/14 [==============================] - 0s 726us/step - loss: 29.0937
# Epoch 152/200
# 14/14 [==============================] - 0s 714us/step - loss: 28.9614
# Epoch 153/200
# 14/14 [==============================] - 0s 722us/step - loss: 28.5623
# Epoch 154/200
# 14/14 [==============================] - 0s 733us/step - loss: 28.9642
# Epoch 155/200
# 14/14 [==============================] - 0s 845us/step - loss: 28.7558
# Epoch 156/200
# 14/14 [==============================] - 0s 655us/step - loss: 28.9772
# Epoch 157/200
# 14/14 [==============================] - 0s 707us/step - loss: 29.4949
# Epoch 158/200
# 14/14 [==============================] - 0s 699us/step - loss: 29.2628
# Epoch 159/200
# 14/14 [==============================] - 0s 693us/step - loss: 28.0565
# Epoch 160/200
# 14/14 [==============================] - 0s 749us/step - loss: 28.0860
# Epoch 161/200
# 14/14 [==============================] - 0s 722us/step - loss: 28.0705
# Epoch 162/200
# 14/14 [==============================] - 0s 717us/step - loss: 28.1203
# Epoch 163/200
# 14/14 [==============================] - 0s 737us/step - loss: 28.3439
# Epoch 164/200
# 14/14 [==============================] - 0s 723us/step - loss: 29.0026
# Epoch 165/200
# 14/14 [==============================] - 0s 711us/step - loss: 29.4749
# Epoch 166/200
# 14/14 [==============================] - 0s 720us/step - loss: 28.8287
# Epoch 167/200
# 14/14 [==============================] - 0s 727us/step - loss: 29.4409
# Epoch 168/200
# 14/14 [==============================] - 0s 758us/step - loss: 28.6376
# Epoch 169/200
# 14/14 [==============================] - 0s 805us/step - loss: 28.0377
# Epoch 170/200
# 14/14 [==============================] - 0s 745us/step - loss: 28.0286
# Epoch 171/200
# 14/14 [==============================] - 0s 730us/step - loss: 29.3091
# Epoch 172/200
# 14/14 [==============================] - 0s 738us/step - loss: 28.4273
# Epoch 173/200
# 14/14 [==============================] - 0s 738us/step - loss: 28.5949
# Epoch 174/200
# 14/14 [==============================] - 0s 734us/step - loss: 28.1697
# Epoch 175/200
# 14/14 [==============================] - 0s 704us/step - loss: 29.4155
# Epoch 176/200
# 14/14 [==============================] - 0s 712us/step - loss: 28.4438
# Epoch 177/200
# 14/14 [==============================] - 0s 708us/step - loss: 28.8973
# Epoch 178/200
# 14/14 [==============================] - 0s 711us/step - loss: 28.3867
# Epoch 179/200
# 14/14 [==============================] - 0s 702us/step - loss: 28.9967
# Epoch 180/200
# 14/14 [==============================] - 0s 745us/step - loss: 27.6856
# Epoch 181/200
# 14/14 [==============================] - 0s 702us/step - loss: 28.6840
# Epoch 182/200
# 14/14 [==============================] - 0s 726us/step - loss: 28.2055
# Epoch 183/200
# 14/14 [==============================] - 0s 708us/step - loss: 28.7460
# Epoch 184/200
# 14/14 [==============================] - 0s 754us/step - loss: 28.4792
# Epoch 185/200
# 14/14 [==============================] - 0s 694us/step - loss: 28.1286
# Epoch 186/200
# 14/14 [==============================] - 0s 709us/step - loss: 28.2170
# Epoch 187/200
# 14/14 [==============================] - 0s 743us/step - loss: 29.0962
# Epoch 188/200
# 14/14 [==============================] - 0s 701us/step - loss: 29.0163
# Epoch 189/200
# 14/14 [==============================] - 0s 748us/step - loss: 27.7322
# Epoch 190/200
# 14/14 [==============================] - 0s 711us/step - loss: 28.4380
# Epoch 191/200
# 14/14 [==============================] - 0s 743us/step - loss: 28.0700
# Epoch 192/200
# 14/14 [==============================] - 0s 713us/step - loss: 28.4221
# Epoch 193/200
# 14/14 [==============================] - 0s 699us/step - loss: 28.2419
# Epoch 194/200
# 14/14 [==============================] - 0s 735us/step - loss: 28.2256
# Epoch 195/200
# 14/14 [==============================] - 0s 726us/step - loss: 28.5926
# Epoch 196/200
# 14/14 [==============================] - 0s 698us/step - loss: 28.5563
# Epoch 197/200
# 14/14 [==============================] - 0s 712us/step - loss: 28.6573
# Epoch 198/200
# 14/14 [==============================] - 0s 691us/step - loss: 29.1594
# Epoch 199/200
# 14/14 [==============================] - 0s 711us/step - loss: 28.1659
# Epoch 200/200
# 14/14 [==============================] - 0s 715us/step - loss: 28.5013
# MAPE of MLP  :        0
# 0  21.54
#  lowest MAPE in training process:" ,[21.68626316]
# the number of neurons of fist layer : 9
# the number of neurons of second layer : 11
# Tunning time : 89.6288857460022s,
# Training time : -5.602836608886719e-05s

# %% [markdown]
# # Random Forest (RF)

# %%
from time import time
import numpy as np # for array operations
import pandas as pd # for working with DataFrames
from itertools import product
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt # for data visualization
# %matplotlib inline

# scikit-learn modules
from sklearn.model_selection import train_test_split # for splitting the data
from sklearn.metrics import mean_squared_error # for calculating the cost function
from sklearn.ensemble import RandomForestRegressor # for building the model


train = pd.read_csv("training_data.csv")
x_train = train[["Total_number_of_FLOPs"]]
y_train = train['Execution_time']

valid = pd.read_csv("valid_data.csv")
x_valid = valid[["Total_number_of_FLOPs"]]
y_valid = valid['Execution_time']

df_pred = pd.read_csv("test_data_NCV.csv")
x_test = df_pred[["Total_number_of_FLOPs"]] 
y_test = df_pred['Execution_time']

# train = pd.read_csv("training_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters"]] 
# y_test = df_pred['Execution_time']




# train = pd.read_csv("training_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]] 
# y_test = df_pred['Execution_time']



# train = pd.read_csv("training_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]] 
# y_test = df_pred['Execution_time']



# df = pd.read_csv("training_data.csv")
# train, valid = train_test_split(df, test_size=0.2)
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters","Memory_allocated_by_activation_functions","Total_number_of_neurons","Input_image_size","Number_of_layers"]]
# y_train = train['Execution_time']

# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters","Memory_allocated_by_activation_functions","Total_number_of_neurons","Input_image_size","Number_of_layers"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("model_result_AlexNet_for_feature_importance.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters","Memory_allocated_by_activation_functions","Total_number_of_neurons","Input_image_size","Number_of_layers"]] 
# y_test = df_pred['Execution_time']

MAPE_default=10000
MAPE_better=MAPE_default
start = time()

range_n_estimators =range(4,100,4)
range_min_samples_leaf =range(1,10,2)
start = time()
for value_n_estimators, value_min_samples_leaf in product(range_n_estimators, range_min_samples_leaf):
    # Initializing the Random Forest Regression model with 50 decision trees
    model = RandomForestRegressor(n_estimators = value_n_estimators, random_state = 0, max_features = "auto", min_samples_leaf = value_min_samples_leaf)

    # Fitting the Random Forest Regression model to the data
    model.fit(x_train, y_train) 

    # Predicting the target values of the validation set
    y_valid_current = model.predict(x_valid)

    # Calculate percentage error
    per_err = (y_valid - y_valid_current) / y_valid

    # Take absolute value of the percentage error (APE)
    per_err = abs(per_err)*100

    # Calculate the MAPE
    MAPE = sum(per_err)/len(per_err)


    if ( MAPE < MAPE_better ):
        better_n_estimators = value_n_estimators
        better_min_samples_leaf = value_min_samples_leaf
        MAPE_better = MAPE
        print(f'''        
        The current MAPE of Random Forest  : { round(MAPE, 2) }, 
        the number of estimator :{ better_n_estimators }
        min_samples_leaf : {better_min_samples_leaf} 

        ''')
stop = time()
tunning_time = stop-start  
start = time()        
# Initializing the Random Forest Regression model with 50 decision trees
model = RandomForestRegressor(n_estimators = better_n_estimators, random_state = 0, max_features = "auto", min_samples_leaf = better_min_samples_leaf)

# Fitting the Random Forest Regression model to the data
model.fit(x_train, y_train) 
stop = time()
training_time = stop-start  
# Predicting the target values of the test set
y_pred = model.predict(x_test)

# Calculate percentage error
per_err = (y_test - y_pred) / y_test

# Take absolute value of the percentage error (APE)
per_err = abs(per_err)*100

# Calculate the MAPE
MAPE = sum(per_err)/len(per_err)        
        
        
        
print(f'''        
The MAPE of Random Forest  : { round(MAPE, 2) }, 
the number of estimator :{ better_n_estimators }
min_samples_leaf : {better_min_samples_leaf} 
Tunning time : {tunning_time}s,
Training time : {training_time}s

''')
# plt.barh(x_train.columns, model.feature_importances_)
sorted_idx = model.feature_importances_.argsort()
plt.barh(x_train.columns[sorted_idx], model.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
index=np.argsort(y_test)

plt.figure(figsize=(12,5))
plt.plot(np.arange(len(y_test)),y_test[index],"r",label="Measured Execution Time")
plt.scatter(np.arange(len(y_pred)),y_pred[index],s=10,c="b",label="Predicted Execution Time ")
plt.legend(loc="upper left")
plt.grid()
plt.ylabel("Execution Time(ms)")
plt.title("RM: Predicted vs. Measured Execution Time of NCV")
plt.show()
# Out:
#
#         The current MAPE of Random Forest  : 25.66,
#         the number of estimator :4
#         min_samples_leaf : 1
#
#
#
#         The current MAPE of Random Forest  : 22.65,
#         the number of estimator :4
#         min_samples_leaf : 3
#
#
#
#         The current MAPE of Random Forest  : 20.15,
#         the number of estimator :4
#         min_samples_leaf : 5
#
#
#
#         The current MAPE of Random Forest  : 20.12,
#         the number of estimator :4
#         min_samples_leaf : 7
#
#
#
# The MAPE of Random Forest  : 23.54,
# the number of estimator :4
# min_samples_leaf : 7
# Tunning time : 6.424968719482422s,
# Training time : 0.0052165985107421875s

# %% [markdown]
# # Support Vector Regression (SVR)

# %%
from time import time
import pandas as pd # for data manipulation
import numpy as np # for data manipulation
from sklearn.model_selection import train_test_split
from itertools import product
# Sklearn
from sklearn.linear_model import LinearRegression # for building a linear regression model
from sklearn.svm import SVR # for building SVR model
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt # for data visualization
# %matplotlib inline

train = pd.read_csv("training_data.csv")
x_train = train[["Total_number_of_FLOPs"]]
y_train = train['Execution_time']

valid = pd.read_csv("valid_data.csv")
x_valid = valid[["Total_number_of_FLOPs"]]
y_valid = valid['Execution_time']

df_pred = pd.read_csv("test_data_NCV.csv")
x_test = df_pred[["Total_number_of_FLOPs"]] 
y_test = df_pred['Execution_time']

# train = pd.read_csv("training_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters"]] 
# y_test = df_pred['Execution_time']




# train = pd.read_csv("training_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]] 
# y_test = df_pred['Execution_time']



# train = pd.read_csv("training_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]] 
# y_test = df_pred['Execution_time']


# ----------- Model fitting -----------

# model1 = LinearRegression()
# lr = model1.fit(x_train, y_train)
MAPE_default=10000
MAPE_better=MAPE_default
range_C =range(1,100,4)
range_epsilon =np.arange(0.01,0.3,0.04)
start = time()
for value_C, value_epsilon in product(range_C,range_epsilon):
    
    model2 = SVR(kernel='rbf', C=value_C, epsilon=value_epsilon) # set kernel and hyperparameters
    
    svr = model2.fit(x_train, y_train)

    # Predicting the target values of the test set
    y_valid_current = model2.predict(x_valid)

    # Calculate percentage error
    per_err = (y_valid - y_valid_current) / y_valid

    # Take absolute value of the percentage error (APE)
    per_err = abs(per_err)*100

    # Calculate the MAPE
    MAPE = sum(per_err)/len(per_err)

    # Print the MAPE value 
#     print(f'''
#     MAPE of Random Forest  : { round(MAPE, 2) }

#     ''')
    if ( MAPE < MAPE_better ):
        better_C = value_C
        better_epsilon = value_epsilon
        MAPE_better = MAPE
        print("The lowest MAPE of SVR",MAPE_better)
        
stop = time()
tunning_time = stop-start  
start = time()
model2 = SVR(kernel='rbf', C=better_C, epsilon=better_epsilon) # set kernel and hyperparameters

svr = model2.fit(x_train, y_train)

stop = time()
training_time = stop-start  

# Predicting the target values of the test set
y_pred = model2.predict(x_test)

# Calculate percentage error
per_err = (y_test - y_pred) / y_test

# Take absolute value of the percentage error (APE)
per_err = abs(per_err)*100

# Calculate the MAPE
MAPE = sum(per_err)/len(per_err)        
        
        
        
print(f'''        
The MAPE of SVR  : { round(MAPE, 2) }, the value of hyperparameters :C = {better_C}, epsilon = {better_epsilon},
Tunning time : {tunning_time}s,
Training time : {training_time}s

''')




index=np.argsort(y_test)

plt.figure(figsize=(12,5))
plt.plot(np.arange(len(y_test)),y_test[index],"r",label="Measured Execution Time")
plt.scatter(np.arange(len(y_pred)),y_pred[index],s=10,c="b",label="Predicted Execution Time ")
plt.legend(loc="upper left")
plt.grid()
plt.ylabel("Execution Time(ms)")
plt.title("SVR: Predicted vs. Measured Execution Time of NCV")
plt.show()


# plt.figure(figsize=(12,5))
# plt.plot(np.arange(len(y_test)),y_test[index],"r",label="original y")
# plt.scatter(np.arange(len(y_lr)),y_lr[index],s=3,c="b",label="prediction")
# plt.legend(loc="upper left")
# plt.grid()
# plt.xlabel("index")
# plt.ylabel("y")
# plt.title(":")
# plt.show()
# Out:
# The lowest MAPE of SVR 24.47876474106196
# The lowest MAPE of SVR 24.336042083090906
# The lowest MAPE of SVR 24.261464194340785
# The lowest MAPE of SVR 24.101291506606895
# The lowest MAPE of SVR 23.934594646374904
# The lowest MAPE of SVR 23.767055109334837
# The lowest MAPE of SVR 23.60328165834784
# The lowest MAPE of SVR 18.39999219468511
# The lowest MAPE of SVR 18.070038493995565
# The lowest MAPE of SVR 17.978019167362365
# The lowest MAPE of SVR 17.92508991748772
# The lowest MAPE of SVR 17.916931262970337
# The lowest MAPE of SVR 17.899148409743123
# The lowest MAPE of SVR 17.772975010934648
# The lowest MAPE of SVR 17.67339754309683
# The lowest MAPE of SVR 17.643026722579933
# The lowest MAPE of SVR 17.63479407447093
# The lowest MAPE of SVR 17.570969276264364
# The lowest MAPE of SVR 17.53028194862638
# The lowest MAPE of SVR 17.518759428528767
#
# The MAPE of SVR  : 18.62, the value of hyperparameters :C = 37, epsilon = 0.09,
# Tunning time : 2.759722948074341s,
# Training time : 0.011444091796875s

# %% [markdown]
# # eXtreme Gradient Boosting (XGBoost)

# %%
from time import time
import xgboost as xgb
import pandas as pd # for data manipulation
from itertools import product
from sklearn.model_selection import train_test_split
import numpy as np # for data manipulation
import matplotlib.pyplot as plt # for data visualization
# %matplotlib inline


train = pd.read_csv("training_data.csv")
x_train = train[["Total_number_of_FLOPs"]]
y_train = train['Execution_time']

valid = pd.read_csv("valid_data.csv")
x_valid = valid[["Total_number_of_FLOPs"]]
y_valid = valid['Execution_time']

df_pred = pd.read_csv("test_data_NCV.csv")
x_test = df_pred[["Total_number_of_FLOPs"]] 
y_test = df_pred['Execution_time']

# train = pd.read_csv("training_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters"]] 
# y_test = df_pred['Execution_time']




# train = pd.read_csv("training_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons"]] 
# y_test = df_pred['Execution_time']


# train = pd.read_csv("training_data.csv")
# x_train = train[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]]
# y_train = train['Execution_time']

# valid = pd.read_csv("valid_data.csv")
# x_valid = valid[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]]
# y_valid = valid['Execution_time']

# df_pred = pd.read_csv("test_data_NCV.csv")
# x_test = df_pred[["Total_number_of_FLOPs","Total_trainable_parameters","Total_number_of_neurons","Memory_allocated_by_activation_functions"]] 
# y_test = df_pred['Execution_time']

MAPE_default=10000
MAPE_better=MAPE_default
range_colsample_bytree = np.arange(0.5,0.9,0.1)
range_learning_rate = np.arange(0.1,0.26,0.05)
range_max_depth = range(3,12,1)
range_n_estimators = range(2,60,4)
start = time()
for value_colsample_bytree, value_learning_rate, value_max_depth, value_n_estimators in product(range_colsample_bytree,range_learning_rate,range_max_depth,range_n_estimators):


    xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = value_colsample_bytree, learning_rate =value_learning_rate,
                    max_depth = value_max_depth, n_estimators = value_n_estimators)
    xg_reg.fit(x_train,y_train)

    y_valid_current = xg_reg.predict(x_valid)
    # Calculate percentage error
    per_err = (y_valid - y_valid_current) / y_valid

    # Take absolute value of the percentage error (APE)
    per_err = abs(per_err)*100


    # Calculate the MAPE
    MAPE = sum(per_err)/len(per_err)


    if ( MAPE < MAPE_better ):
        better_colsample_bytree = value_colsample_bytree
        better_learning_rate = value_learning_rate
        better_max_depth = value_max_depth
        better_n_estimators = value_n_estimators
        MAPE_better = MAPE

                
        print(f'''        
        The lowest MAPE of XGBoost  : { round(MAPE_better, 2) }
        the value of hyperparameters :
        colsample_bytree = {better_colsample_bytree}
        learning_rate = {better_learning_rate}
        max_depth = {better_max_depth}
        n_estimators = {better_n_estimators}

        ''')
stop = time()
tunning_time = stop-start  
start = time()        
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = better_colsample_bytree, learning_rate =better_learning_rate,
                max_depth = better_max_depth, n_estimators = better_n_estimators)
xg_reg.fit(x_train,y_train)
stop = time()
training_time = stop-start 
y_pred = xg_reg.predict(x_test)
# Calculate percentage error
per_err = (y_test - y_pred) / y_test

# Take absolute value of the percentage error (APE)
per_err = abs(per_err)*100


# Calculate the MAPE
MAPE = sum(per_err)/len(per_err)
print(f'''        
The MAPE of XGBoost  : { round(MAPE, 2) }
the value of hyperparameters :
colsample_bytree = {better_colsample_bytree}
learning_rate = {better_learning_rate}
max_depth = {better_max_depth}
n_estimators = {better_n_estimators}
Tunning time : {tunning_time}s,
Training time : {training_time}s

''')
index=np.argsort(y_test)

plt.figure(figsize=(12,5))
plt.plot(np.arange(len(y_test)),y_test[index],"r",label="Measured Execution Time")
plt.scatter(np.arange(len(y_pred)),y_pred[index],s=10,c="b",label="Predicted Execution Time ")
plt.legend(loc="upper left")
plt.grid()
plt.ylabel("Execution Time(ms)")
plt.title("XGBoost: Predicted vs. Measured Execution Time of NCV")
plt.show()
# Out:
#
#         The lowest MAPE of XGBoost  : 76.36
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.1
#         max_depth = 3
#         n_estimators = 2
#
#
#
#         The lowest MAPE of XGBoost  : 46.88
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.1
#         max_depth = 3
#         n_estimators = 6
#
#
#
#         The lowest MAPE of XGBoost  : 30.56
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.1
#         max_depth = 3
#         n_estimators = 10
#
#
#
#         The lowest MAPE of XGBoost  : 22.78
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.1
#         max_depth = 3
#         n_estimators = 14
#
#
#
#         The lowest MAPE of XGBoost  : 19.69
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.1
#         max_depth = 3
#         n_estimators = 18
#
#
#
#         The lowest MAPE of XGBoost  : 19.08
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.1
#         max_depth = 3
#         n_estimators = 22
#
#
#
#         The lowest MAPE of XGBoost  : 19.07
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.15000000000000002
#         max_depth = 3
#         n_estimators = 14
#
#
#
#         The lowest MAPE of XGBoost  : 19.05
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.20000000000000004
#         max_depth = 3
#         n_estimators = 10
#
#
#
# The MAPE of XGBoost  : 20.8
# the value of hyperparameters :
# colsample_bytree = 0.5
# learning_rate = 0.20000000000000004
# max_depth = 3
# n_estimators = 10
# Tunning time : 148.19240260124207s,
# Training time : 0.026014328002929688s
