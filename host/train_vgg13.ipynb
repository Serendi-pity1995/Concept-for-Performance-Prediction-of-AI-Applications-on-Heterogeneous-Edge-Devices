# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from itertools import product
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, ZeroPadding2D, Activation, Dropout
from tensorflow_model_optimization.quantization.keras import vitis_quantize


shape_range =range((48,220,34)

for shape_x in shape_range:
    
    shape_y = shape_x
    X_train=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
    Y_train=np.random.randint(0,10,size=[60,])
    X_test=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
    Y_test=np.random.randint(0,10,size=[60,])
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
    X_train /= 255.0
    X_test /= 255.0


    inputs = Input(shape=(shape_x, shape_y, 1))

    conv1 = Conv2D(64, (3,3), padding='same', activation='relu')(inputs)
    conv2 = Conv2D(64, (3,3), padding='same', activation='relu')(conv1)
    pool1 = MaxPooling2D(pool_size=2)(conv2)
    
    conv3 = Conv2D(128, (3,3), padding='same', activation='relu')(pool1)
    conv4 = Conv2D(128, (3,3), padding='same', activation='relu')(conv3)
    pool2 = MaxPooling2D(pool_size=2)(conv4)
    
    conv5 = Conv2D(256, (3,3), padding='same', activation='relu')(pool2)
    conv6 = Conv2D(256, (3,3), padding='same', activation='relu')(conv5)
    pool3 = MaxPooling2D(pool_size=2)(conv6)

    conv7 = Conv2D(512, (3,3), padding='same', activation='relu')(pool3)
    conv8 = Conv2D(512, (3,3), padding='same', activation='relu')(conv7)
    pool4 = MaxPooling2D(pool_size=2)(conv8)

    conv9 = Conv2D(512, (3,3), padding='same', activation='relu')(pool4)
    conv10 = Conv2D(512, (3,3), padding='same', activation='relu')(conv9)
    pool5 = MaxPooling2D(pool_size=2)(conv10)
    
    flat = Flatten()(pool5)
    fc1 = Dense(4096, activation='relu')(flat)
    drop1 = Dropout(0.5)(fc1)
    fc2 = Dense(4096, activation='relu')(drop1)
    drop2 = Dropout(0.5)(fc2)

    outputs = Dense(10, activation='softmax')(drop2)



    model = Model(inputs=inputs, outputs=outputs)
    model.summary()
    model.compile(optimizer='adam',
              loss="sparse_categorical_crossentropy", 
              metrics=['accuracy'])
    history = model.fit(X_train, Y_train, epochs=1)
    model.get_weights()[0].dtype
    quantizer = vitis_quantize.VitisQuantizer(model)
    quantized_model = quantizer.quantize_model(calib_dataset = X_test[1:8], weight_bit=8, activation_bit=8)
    quantized_model.compile(loss='sparse_categorical_crossentropy', metrics=["accuracy"])
    quantized_model.save('quantized.h5')
    # !vai_c_tensorflow2 \
            --model ./quantized.h5 \
            --arch ./arch.json \
            --output_dir ./xmodel_vgg13 \
            --net_name deploy
    os.rename("./xmodel_vgg13/deploy.xmodel","./xmodel_vgg13/vgg13_{input_x}_{input_y}.xmodel".format(input_x=shape_x,input_y=shape_y))
# Out:
# 2022-04-03 08:02:43.309324: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-04-03 08:02:43.309355: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-04-03 08:02:44.930222: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-04-03 08:02:44.930260: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-03 08:02:44.930278: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2022-04-03 08:02:44.930417: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 352, 352, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 352, 352, 64)      640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 352, 352, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 176, 176, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 176, 176, 128)     73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 176, 176, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 88, 88, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 88, 88, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 88, 88, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 44, 44, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 44, 44, 512)       1180160
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 44, 44, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 22, 22, 512)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 22, 22, 512)       2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 22, 22, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 11, 11, 512)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 61952)             0
# _________________________________________________________________
# dense (Dense)                (None, 3072)              190319616
# _________________________________________________________________
# dropout (Dropout)            (None, 3072)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3072)              9440256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3072)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                30730
# =================================================================
# Total params: 209,194,442
# Trainable params: 209,194,442
# Non-trainable params: 0
# _________________________________________________________________
# 2022-04-03 08:02:45.667781: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1552/1790609127.py in <module>
#      61               loss="sparse_categorical_crossentropy",
#      62               metrics=['accuracy'])
# ---> 63     history = model.fit(X_train, Y_train, epochs=1)
#      64     model.get_weights()[0].dtype
#      65     quantizer = vitis_quantize.VitisQuantizer(model)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     948         # Lifting succeeded, so variables are initialized and we can run the
#     949         # stateless function.
# --> 950         return self._stateless_fn(*args, **kwds)
#     951     else:
#     952       _, _, _, filtered_flat_args = \
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
# -> 3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#    3042   @property
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1962       # No tape is watching; skip to running the function.
#    1963       return self._build_call_outputs(self._inference_function.call(
# -> 1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#    1966         args,
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from itertools import product
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, ZeroPadding2D, Activation, Dropout
from tensorflow_model_optimization.quantization.keras import vitis_quantize


shape_range =range(144,240,16)

for shape_x in shape_range:
    
    shape_y = shape_x
#     X_train=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
#     Y_train=np.random.randint(0,10,size=[60,])
    X_test=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
    Y_test=np.random.randint(0,10,size=[60,])
#     X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
#     X_train /= 255.0
    X_test /= 255.0


    inputs = Input(shape=(shape_x, shape_y, 1))
    for step in range(1,11):
        conv1_kernel_num = random.randrange(32,64,2)
        conv1 = Conv2D(conv1_kernel_num, (3,3), padding='same', activation='relu')(inputs)
        conv2_kernel_num = random.randrange(conv1_kernel_num,64,2)
        conv2 = Conv2D(64, (3,3), padding='same', activation='relu')(conv1)
        pool1 = MaxPooling2D(pool_size=2)(conv2)

        conv3_kernel_num = random.randrange(conv2_kernel_num,128,2)
        conv3 = Conv2D(conv3_kernel_num, (3,3), padding='same', activation='relu')(pool1)
        conv4_kernel_num = random.randrange(conv3_kernel_num,128,2)
        conv4 = Conv2D(conv4_kernel_num, (3,3), padding='same', activation='relu')(conv3)
        pool2 = MaxPooling2D(pool_size=2)(conv4)
        

        conv5_kernel_num = random.randrange(conv4_kernel_num,256,2)
        conv5 = Conv2D(conv5_kernel_num, (3,3), padding='same', activation='relu')(pool2)
        conv6_kernel_num = random.randrange(conv5_kernel_num,256,2)
        conv6 = Conv2D(conv6_kernel_num, (3,3), padding='same', activation='relu')(conv5)
        pool3 = MaxPooling2D(pool_size=2)(conv6)
        
        conv7_kernel_num = random.randrange(conv6_kernel_num,512,2)
        conv7 = Conv2D(conv7_kernel_num, (3,3), padding='same', activation='relu')(pool3)
        conv8_kernel_num = random.randrange(conv7_kernel_num,512,2)
        conv8 = Conv2D(conv8_kernel_num, (3,3), padding='same', activation='relu')(conv7)
        pool4 = MaxPooling2D(pool_size=2)(conv8)

        conv9_kernel_num = random.randrange(conv8_kernel_num,512,2)
        conv9 = Conv2D(conv9_kernel_num, (3,3), padding='same', activation='relu')(pool4)
        conv10_kernel_num = random.randrange(conv9_kernel_num,512,2)
        conv10 = Conv2D(conv10_kernel_num, (3,3), padding='same', activation='relu')(conv9)
        pool5 = MaxPooling2D(pool_size=2)(conv10)

        flat = Flatten()(pool5)
        Dense1_neuron_num = random.randrange(1072,3072,32)
        fc1 = Dense(Dense1_neuron_num, activation='relu')(flat)
        drop1 = Dropout(0.5)(fc1)
        Dense2_neuron_num = random.randrange(1072,Dense1_neuron_num+1,32)
        fc2 = Dense(Dense2_neuron_num, activation='relu')(drop1)
        drop2 = Dropout(0.5)(fc2)

        outputs = Dense(10, activation='softmax')(drop2)


        model = Model(inputs=inputs, outputs=outputs)
        model.summary()
        model.save('./vgg13_h5/vgg13_{input_x}_{input_y}_{step}.h5'.format(input_x=shape_x,input_y=shape_y,step=step))
#         model.compile(optimizer='adam',
#                   loss="sparse_categorical_crossentropy", 
#                   metrics=['accuracy'])
#         history = model.fit(X_train, Y_train, epochs=1)
#         model.get_weights()[0].dtype
        quantizer = vitis_quantize.VitisQuantizer(model)
        quantized_model = quantizer.quantize_model(calib_dataset = X_test[1:8], weight_bit=8, activation_bit=8)
#         quantized_model.compile(loss='sparse_categorical_crossentropy', metrics=["accuracy"])
        quantized_model.save('quantized.h5')
        # !vai_c_tensorflow2 \
                --model ./quantized.h5 \
                --arch ./arch.json \
                --output_dir ./xmodel_vgg13 \
                --net_name deploy
        os.rename("./xmodel_vgg13/deploy.xmodel","./xmodel_vgg13/vgg13_{input_x}_{input_y}_{step}.xmodel".format(input_x=shape_x,input_y=shape_y,step=step))
# Out:
# Model: "model_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 144, 144, 1)]     0
# _________________________________________________________________
# conv2d_400 (Conv2D)          (None, 144, 144, 40)      400
# _________________________________________________________________
# conv2d_401 (Conv2D)          (None, 144, 144, 64)      23104
# _________________________________________________________________
# max_pooling2d_200 (MaxPoolin (None, 72, 72, 64)        0
# _________________________________________________________________
# conv2d_402 (Conv2D)          (None, 72, 72, 108)       62316
# _________________________________________________________________
# conv2d_403 (Conv2D)          (None, 72, 72, 110)       107030
# _________________________________________________________________
# max_pooling2d_201 (MaxPoolin (None, 36, 36, 110)       0
# _________________________________________________________________
# conv2d_404 (Conv2D)          (None, 36, 36, 168)       166488
# _________________________________________________________________
# conv2d_405 (Conv2D)          (None, 36, 36, 224)       338912
# _________________________________________________________________
# max_pooling2d_202 (MaxPoolin (None, 18, 18, 224)       0
# _________________________________________________________________
# conv2d_406 (Conv2D)          (None, 18, 18, 336)       677712
# _________________________________________________________________
# conv2d_407 (Conv2D)          (None, 18, 18, 364)       1101100
# _________________________________________________________________
# max_pooling2d_203 (MaxPoolin (None, 9, 9, 364)         0
# _________________________________________________________________
# conv2d_408 (Conv2D)          (None, 9, 9, 502)         1645054
# _________________________________________________________________
# conv2d_409 (Conv2D)          (None, 9, 9, 508)         2295652
# _________________________________________________________________
# max_pooling2d_204 (MaxPoolin (None, 4, 4, 508)         0
# _________________________________________________________________
# flatten_40 (Flatten)         (None, 8128)              0
# _________________________________________________________________
# dense_120 (Dense)            (None, 2800)              22761200
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 2800)              0
# _________________________________________________________________
# dense_121 (Dense)            (None, 2384)              6677584
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 2384)              0
# _________________________________________________________________
# dense_122 (Dense)            (None, 10)                23850
# =================================================================
# Total params: 35,880,402
# Trainable params: 35,880,402
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 3s 378ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 5s 5s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 34/34 [00:00<00:00, 25547.53it/s]
# [INFO] infer shape (NHWC)  :100%|█| 58/58 [00:00<00:00, 744.81it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 301.79it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1154.18it/s]
# [INFO] generate xmodel     :100%|█| 58/58 [00:01<00:00, 33.40it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_40, with op num: 104
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 47100d20eed6da7b77a21400394c5f73, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/md5sum.txt"
# Model: "model_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 144, 144, 1)]     0
# _________________________________________________________________
# conv2d_410 (Conv2D)          (None, 144, 144, 52)      520
# _________________________________________________________________
# conv2d_411 (Conv2D)          (None, 144, 144, 64)      30016
# _________________________________________________________________
# max_pooling2d_205 (MaxPoolin (None, 72, 72, 64)        0
# _________________________________________________________________
# conv2d_412 (Conv2D)          (None, 72, 72, 68)        39236
# _________________________________________________________________
# conv2d_413 (Conv2D)          (None, 72, 72, 122)       74786
# _________________________________________________________________
# max_pooling2d_206 (MaxPoolin (None, 36, 36, 122)       0
# _________________________________________________________________
# conv2d_414 (Conv2D)          (None, 36, 36, 218)       239582
# _________________________________________________________________
# conv2d_415 (Conv2D)          (None, 36, 36, 242)       475046
# _________________________________________________________________
# max_pooling2d_207 (MaxPoolin (None, 18, 18, 242)       0
# _________________________________________________________________
# conv2d_416 (Conv2D)          (None, 18, 18, 318)       692922
# _________________________________________________________________
# conv2d_417 (Conv2D)          (None, 18, 18, 356)       1019228
# _________________________________________________________________
# max_pooling2d_208 (MaxPoolin (None, 9, 9, 356)         0
# _________________________________________________________________
# conv2d_418 (Conv2D)          (None, 9, 9, 378)         1211490
# _________________________________________________________________
# conv2d_419 (Conv2D)          (None, 9, 9, 508)         1728724
# _________________________________________________________________
# max_pooling2d_209 (MaxPoolin (None, 4, 4, 508)         0
# _________________________________________________________________
# flatten_41 (Flatten)         (None, 8128)              0
# _________________________________________________________________
# dense_123 (Dense)            (None, 2352)              19119408
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 2352)              0
# _________________________________________________________________
# dense_124 (Dense)            (None, 1744)              4103632
# _________________________________________________________________
# dropout_83 (Dropout)         (None, 1744)              0
# _________________________________________________________________
# dense_125 (Dense)            (None, 10)                17450
# =================================================================
# Total params: 28,752,040
# Trainable params: 28,752,040
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 3s 343ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 5s 5s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 34/34 [00:00<00:00, 26253.01it/s]
# [INFO] infer shape (NHWC)  :100%|█| 58/58 [00:00<00:00, 1017.43it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 303.41it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1168.98it/s]
# [INFO] generate xmodel     :100%|█| 58/58 [00:01<00:00, 42.19it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_41, with op num: 104
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 2bfe9a79f4c960d4f1548b8c64045f84, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/md5sum.txt"
# Model: "model_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 144, 144, 1)]     0
# _________________________________________________________________
# conv2d_420 (Conv2D)          (None, 144, 144, 62)      620
# _________________________________________________________________
# conv2d_421 (Conv2D)          (None, 144, 144, 64)      35776
# _________________________________________________________________
# max_pooling2d_210 (MaxPoolin (None, 72, 72, 64)        0
# _________________________________________________________________
# conv2d_422 (Conv2D)          (None, 72, 72, 116)       66932
# _________________________________________________________________
# conv2d_423 (Conv2D)          (None, 72, 72, 120)       125400
# _________________________________________________________________
# max_pooling2d_211 (MaxPoolin (None, 36, 36, 120)       0
# _________________________________________________________________
# conv2d_424 (Conv2D)          (None, 36, 36, 150)       162150
# _________________________________________________________________
# conv2d_425 (Conv2D)          (None, 36, 36, 218)       294518
# _________________________________________________________________
# max_pooling2d_212 (MaxPoolin (None, 18, 18, 218)       0
# _________________________________________________________________
# conv2d_426 (Conv2D)          (None, 18, 18, 390)       765570
# _________________________________________________________________
# conv2d_427 (Conv2D)          (None, 18, 18, 464)       1629104
# _________________________________________________________________
# max_pooling2d_213 (MaxPoolin (None, 9, 9, 464)         0
# _________________________________________________________________
# conv2d_428 (Conv2D)          (None, 9, 9, 510)         2130270
# _________________________________________________________________
# conv2d_429 (Conv2D)          (None, 9, 9, 510)         2341410
# _________________________________________________________________
# max_pooling2d_214 (MaxPoolin (None, 4, 4, 510)         0
# _________________________________________________________________
# flatten_42 (Flatten)         (None, 8160)              0
# _________________________________________________________________
# dense_126 (Dense)            (None, 2192)              17888912
# _________________________________________________________________
# dropout_84 (Dropout)         (None, 2192)              0
# _________________________________________________________________
# dense_127 (Dense)            (None, 1904)              4175472
# _________________________________________________________________
# dropout_85 (Dropout)         (None, 1904)              0
# _________________________________________________________________
# dense_128 (Dense)            (None, 10)                19050
# =================================================================
# Total params: 29,635,184
# Trainable params: 29,635,184
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 3s 356ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 5s 5s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 34/34 [00:00<00:00, 25501.85it/s]
# [INFO] infer shape (NHWC)  :100%|█| 58/58 [00:00<00:00, 993.50it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 297.55it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1142.40it/s]
# [INFO] generate xmodel     :100%|█| 58/58 [00:01<00:00, 43.72it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_42, with op num: 104
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 14ea247047ff6c18897f41ff9e9c61cb, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/md5sum.txt"
# Model: "model_43"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 144, 144, 1)]     0
# _________________________________________________________________
# conv2d_430 (Conv2D)          (None, 144, 144, 48)      480
# _________________________________________________________________
# conv2d_431 (Conv2D)          (None, 144, 144, 64)      27712
# _________________________________________________________________
# max_pooling2d_215 (MaxPoolin (None, 72, 72, 64)        0
# _________________________________________________________________
# conv2d_432 (Conv2D)          (None, 72, 72, 114)       65778
# _________________________________________________________________
# conv2d_433 (Conv2D)          (None, 72, 72, 122)       125294
# _________________________________________________________________
# max_pooling2d_216 (MaxPoolin (None, 36, 36, 122)       0
# _________________________________________________________________
# conv2d_434 (Conv2D)          (None, 36, 36, 162)       178038
# _________________________________________________________________
# conv2d_435 (Conv2D)          (None, 36, 36, 252)       367668
# _________________________________________________________________
# max_pooling2d_217 (MaxPoolin (None, 18, 18, 252)       0
# _________________________________________________________________
# conv2d_436 (Conv2D)          (None, 18, 18, 472)       1070968
# _________________________________________________________________
# conv2d_437 (Conv2D)          (None, 18, 18, 484)       2056516
# _________________________________________________________________
# max_pooling2d_218 (MaxPoolin (None, 9, 9, 484)         0
# _________________________________________________________________
# conv2d_438 (Conv2D)          (None, 9, 9, 502)         2187214
# _________________________________________________________________
# conv2d_439 (Conv2D)          (None, 9, 9, 506)         2286614
# _________________________________________________________________
# max_pooling2d_219 (MaxPoolin (None, 4, 4, 506)         0
# _________________________________________________________________
# flatten_43 (Flatten)         (None, 8096)              0
# _________________________________________________________________
# dense_129 (Dense)            (None, 2544)              20598768
# _________________________________________________________________
# dropout_86 (Dropout)         (None, 2544)              0
# _________________________________________________________________
# dense_130 (Dense)            (None, 1104)              2809680
# _________________________________________________________________
# dropout_87 (Dropout)         (None, 1104)              0
# _________________________________________________________________
# dense_131 (Dense)            (None, 10)                11050
# =================================================================
# Total params: 31,785,780
# Trainable params: 31,785,780
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 3s 329ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 5s 5s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 34/34 [00:00<00:00, 25862.59it/s]
# [INFO] infer shape (NHWC)  :100%|█| 58/58 [00:00<00:00, 711.52it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 300.19it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1156.41it/s]
# [INFO] generate xmodel     :100%|█| 58/58 [00:01<00:00, 40.87it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_43, with op num: 104
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 0c469064a051e5896c9817f9476f60d8, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/md5sum.txt"
# Model: "model_44"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 144, 144, 1)]     0
# _________________________________________________________________
# conv2d_440 (Conv2D)          (None, 144, 144, 52)      520
# _________________________________________________________________
# conv2d_441 (Conv2D)          (None, 144, 144, 64)      30016
# _________________________________________________________________
# max_pooling2d_220 (MaxPoolin (None, 72, 72, 64)        0
# _________________________________________________________________
# conv2d_442 (Conv2D)          (None, 72, 72, 62)        35774
# _________________________________________________________________
# conv2d_443 (Conv2D)          (None, 72, 72, 96)        53664
# _________________________________________________________________
# max_pooling2d_221 (MaxPoolin (None, 36, 36, 96)        0
# _________________________________________________________________
# conv2d_444 (Conv2D)          (None, 36, 36, 186)       160890
# _________________________________________________________________
# conv2d_445 (Conv2D)          (None, 36, 36, 210)       351750
# _________________________________________________________________
# max_pooling2d_222 (MaxPoolin (None, 18, 18, 210)       0
# _________________________________________________________________
# conv2d_446 (Conv2D)          (None, 18, 18, 430)       813130
# _________________________________________________________________
# conv2d_447 (Conv2D)          (None, 18, 18, 434)       1680014
# _________________________________________________________________
# max_pooling2d_223 (MaxPoolin (None, 9, 9, 434)         0
# _________________________________________________________________
# conv2d_448 (Conv2D)          (None, 9, 9, 488)         1906616
# _________________________________________________________________
# conv2d_449 (Conv2D)          (None, 9, 9, 498)         2187714
# _________________________________________________________________
# max_pooling2d_224 (MaxPoolin (None, 4, 4, 498)         0
# _________________________________________________________________
# flatten_44 (Flatten)         (None, 7968)              0
# _________________________________________________________________
# dense_132 (Dense)            (None, 1776)              14152944
# _________________________________________________________________
# dropout_88 (Dropout)         (None, 1776)              0
# _________________________________________________________________
# dense_133 (Dense)            (None, 1488)              2644176
# _________________________________________________________________
# dropout_89 (Dropout)         (None, 1488)              0
# _________________________________________________________________
# dense_134 (Dense)            (None, 10)                14890
# =================================================================
# Total params: 24,032,098
# Trainable params: 24,032,098
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 3s 279ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 5s 5s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 34/34 [00:00<00:00, 26932.26it/s]
# [INFO] infer shape (NHWC)  :100%|█| 58/58 [00:00<00:00, 1242.29it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 291.23it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1170.29it/s]
# [INFO] generate xmodel     :100%|█| 58/58 [00:01<00:00, 56.03it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_44, with op num: 104
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 4b46d9a21096bd306632f2619d667771, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/md5sum.txt"
# Model: "model_45"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 144, 144, 1)]     0
# _________________________________________________________________
# conv2d_450 (Conv2D)          (None, 144, 144, 42)      420
# _________________________________________________________________
# conv2d_451 (Conv2D)          (None, 144, 144, 64)      24256
# _________________________________________________________________
# max_pooling2d_225 (MaxPoolin (None, 72, 72, 64)        0
# _________________________________________________________________
# conv2d_452 (Conv2D)          (None, 72, 72, 60)        34620
# _________________________________________________________________
# conv2d_453 (Conv2D)          (None, 72, 72, 104)       56264
# _________________________________________________________________
# max_pooling2d_226 (MaxPoolin (None, 36, 36, 104)       0
# _________________________________________________________________
# conv2d_454 (Conv2D)          (None, 36, 36, 144)       134928
# _________________________________________________________________
# conv2d_455 (Conv2D)          (None, 36, 36, 172)       223084
# _________________________________________________________________
# max_pooling2d_227 (MaxPoolin (None, 18, 18, 172)       0
# _________________________________________________________________
# conv2d_456 (Conv2D)          (None, 18, 18, 496)       768304
# _________________________________________________________________
# conv2d_457 (Conv2D)          (None, 18, 18, 506)       2259290
# _________________________________________________________________
# max_pooling2d_228 (MaxPoolin (None, 9, 9, 506)         0
# _________________________________________________________________
# conv2d_458 (Conv2D)          (None, 9, 9, 508)         2313940
# _________________________________________________________________
# conv2d_459 (Conv2D)          (None, 9, 9, 510)         2332230
# _________________________________________________________________
# max_pooling2d_229 (MaxPoolin (None, 4, 4, 510)         0
# _________________________________________________________________
# flatten_45 (Flatten)         (None, 8160)              0
# _________________________________________________________________
# dense_135 (Dense)            (None, 2512)              20500432
# _________________________________________________________________
# dropout_90 (Dropout)         (None, 2512)              0
# _________________________________________________________________
# dense_136 (Dense)            (None, 1616)              4061008
# _________________________________________________________________
# dropout_91 (Dropout)         (None, 1616)              0
# _________________________________________________________________
# dense_137 (Dense)            (None, 10)                16170
# =================================================================
# Total params: 32,724,946
# Trainable params: 32,724,946
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 3s 328ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 5s 5s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 34/34 [00:00<00:00, 27121.78it/s]
# [INFO] infer shape (NHWC)  :100%|█| 58/58 [00:00<00:00, 1002.32it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 303.57it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1172.90it/s]
# [INFO] generate xmodel     :100%|█| 58/58 [00:01<00:00, 37.99it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_45, with op num: 104
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is cc983202155beb615a3391f15f7d4261, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/md5sum.txt"
# Model: "model_46"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 144, 144, 1)]     0
# _________________________________________________________________
# conv2d_460 (Conv2D)          (None, 144, 144, 50)      500
# _________________________________________________________________
# conv2d_461 (Conv2D)          (None, 144, 144, 64)      28864
# _________________________________________________________________
# max_pooling2d_230 (MaxPoolin (None, 72, 72, 64)        0
# _________________________________________________________________
# conv2d_462 (Conv2D)          (None, 72, 72, 76)        43852
# _________________________________________________________________
# conv2d_463 (Conv2D)          (None, 72, 72, 92)        63020
# _________________________________________________________________
# max_pooling2d_231 (MaxPoolin (None, 36, 36, 92)        0
# _________________________________________________________________
# conv2d_464 (Conv2D)          (None, 36, 36, 224)       185696
# _________________________________________________________________
# conv2d_465 (Conv2D)          (None, 36, 36, 248)       500216
# _________________________________________________________________
# max_pooling2d_232 (MaxPoolin (None, 18, 18, 248)       0
# _________________________________________________________________
# conv2d_466 (Conv2D)          (None, 18, 18, 358)       799414
# _________________________________________________________________
# conv2d_467 (Conv2D)          (None, 18, 18, 410)       1321430
# _________________________________________________________________
# max_pooling2d_233 (MaxPoolin (None, 9, 9, 410)         0
# _________________________________________________________________
# conv2d_468 (Conv2D)          (None, 9, 9, 502)         1852882
# _________________________________________________________________
# conv2d_469 (Conv2D)          (None, 9, 9, 508)         2295652
# _________________________________________________________________
# max_pooling2d_234 (MaxPoolin (None, 4, 4, 508)         0
# _________________________________________________________________
# flatten_46 (Flatten)         (None, 8128)              0
# _________________________________________________________________
# dense_138 (Dense)            (None, 2768)              22501072
# _________________________________________________________________
# dropout_92 (Dropout)         (None, 2768)              0
# _________________________________________________________________
# dense_139 (Dense)            (None, 1488)              4120272
# _________________________________________________________________
# dropout_93 (Dropout)         (None, 1488)              0
# _________________________________________________________________
# dense_140 (Dense)            (None, 10)                14890
# =================================================================
# Total params: 33,727,760
# Trainable params: 33,727,760
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 3s 331ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 6s 6s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 34/34 [00:00<00:00, 26615.59it/s]
# [INFO] infer shape (NHWC)  :100%|█| 58/58 [00:00<00:00, 916.04it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 301.25it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1158.81it/s]
# [INFO] generate xmodel     :100%|█| 58/58 [00:01<00:00, 36.53it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_46, with op num: 104
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 44e73281f770811a8487fe7593d1bcf0, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/md5sum.txt"
# Model: "model_47"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 144, 144, 1)]     0
# _________________________________________________________________
# conv2d_470 (Conv2D)          (None, 144, 144, 40)      400
# _________________________________________________________________
# conv2d_471 (Conv2D)          (None, 144, 144, 64)      23104
# _________________________________________________________________
# max_pooling2d_235 (MaxPoolin (None, 72, 72, 64)        0
# _________________________________________________________________
# conv2d_472 (Conv2D)          (None, 72, 72, 62)        35774
# _________________________________________________________________
# conv2d_473 (Conv2D)          (None, 72, 72, 90)        50310
# _________________________________________________________________
# max_pooling2d_236 (MaxPoolin (None, 36, 36, 90)        0
# _________________________________________________________________
# conv2d_474 (Conv2D)          (None, 36, 36, 170)       137870
# _________________________________________________________________
# conv2d_475 (Conv2D)          (None, 36, 36, 210)       321510
# _________________________________________________________________
# max_pooling2d_237 (MaxPoolin (None, 18, 18, 210)       0
# _________________________________________________________________
# conv2d_476 (Conv2D)          (None, 18, 18, 334)       631594
# _________________________________________________________________
# conv2d_477 (Conv2D)          (None, 18, 18, 444)       1335108
# _________________________________________________________________
# max_pooling2d_238 (MaxPoolin (None, 9, 9, 444)         0
# _________________________________________________________________
# conv2d_478 (Conv2D)          (None, 9, 9, 458)         1830626
# _________________________________________________________________
# conv2d_479 (Conv2D)          (None, 9, 9, 488)         2012024
# _________________________________________________________________
# max_pooling2d_239 (MaxPoolin (None, 4, 4, 488)         0
# _________________________________________________________________
# flatten_47 (Flatten)         (None, 7808)              0
# _________________________________________________________________
# dense_141 (Dense)            (None, 1936)              15118224
# _________________________________________________________________
# dropout_94 (Dropout)         (None, 1936)              0
# _________________________________________________________________
# dense_142 (Dense)            (None, 1744)              3378128
# _________________________________________________________________
# dropout_95 (Dropout)         (None, 1744)              0
# _________________________________________________________________
# dense_143 (Dense)            (None, 10)                17450
# =================================================================
# Total params: 24,892,122
# Trainable params: 24,892,122
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 3s 338ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 5s 5s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 34/34 [00:00<00:00, 26815.78it/s]
# [INFO] infer shape (NHWC)  :100%|█| 58/58 [00:00<00:00, 1178.26it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 297.48it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1154.34it/s]
# [INFO] generate xmodel     :100%|█| 58/58 [00:01<00:00, 52.13it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_47, with op num: 104
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 6d20bd5ab50edb589120af8081f11366, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/md5sum.txt"
# Model: "model_48"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 144, 144, 1)]     0
# _________________________________________________________________
# conv2d_480 (Conv2D)          (None, 144, 144, 32)      320
# _________________________________________________________________
# conv2d_481 (Conv2D)          (None, 144, 144, 64)      18496
# _________________________________________________________________
# max_pooling2d_240 (MaxPoolin (None, 72, 72, 64)        0
# _________________________________________________________________
# conv2d_482 (Conv2D)          (None, 72, 72, 122)       70394
# _________________________________________________________________
# conv2d_483 (Conv2D)          (None, 72, 72, 122)       134078
# _________________________________________________________________
# max_pooling2d_241 (MaxPoolin (None, 36, 36, 122)       0
# _________________________________________________________________
# conv2d_484 (Conv2D)          (None, 36, 36, 212)       232988
# _________________________________________________________________
# conv2d_485 (Conv2D)          (None, 36, 36, 244)       465796
# _________________________________________________________________
# max_pooling2d_242 (MaxPoolin (None, 18, 18, 244)       0
# _________________________________________________________________
# conv2d_486 (Conv2D)          (None, 18, 18, 442)       971074
# _________________________________________________________________
# conv2d_487 (Conv2D)          (None, 18, 18, 496)       1973584
# _________________________________________________________________
# max_pooling2d_243 (MaxPoolin (None, 9, 9, 496)         0
# _________________________________________________________________
# conv2d_488 (Conv2D)          (None, 9, 9, 502)         2241430
# _________________________________________________________________
# conv2d_489 (Conv2D)          (None, 9, 9, 504)         2277576
# _________________________________________________________________
# max_pooling2d_244 (MaxPoolin (None, 4, 4, 504)         0
# _________________________________________________________________
# flatten_48 (Flatten)         (None, 8064)              0
# ...
# flatten_97 (Flatten)         (None, 23912)             0
# _________________________________________________________________
# dense_291 (Dense)            (None, 3056)              73078128
# _________________________________________________________________
# dropout_194 (Dropout)        (None, 3056)              0
# _________________________________________________________________
# dense_292 (Dense)            (None, 3056)              9342192
# _________________________________________________________________
# dropout_195 (Dropout)        (None, 3056)              0
# _________________________________________________________________
# dense_293 (Dense)            (None, 10)                30570
# =================================================================
# Total params: 88,765,634
# Trainable params: 88,765,634
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 5s 601ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 7s 7s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 34/34 [00:00<00:00, 25593.38it/s]
# [INFO] infer shape (NHWC)  :100%|█| 58/58 [00:00<00:00, 346.49it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 300.65it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1138.52it/s]
# [INFO] generate xmodel     :100%|█| 58/58 [00:05<00:00, 11.26it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_97, with op num: 104
# [UNILOG][INFO] Begin to compile...
# [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 30b52da8c64ec95c8a5345f5c81e2fce, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/md5sum.txt"
# Model: "model_98"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 224, 224, 1)]     0
# _________________________________________________________________
# conv2d_980 (Conv2D)          (None, 224, 224, 40)      400
# _________________________________________________________________
# conv2d_981 (Conv2D)          (None, 224, 224, 64)      23104
# _________________________________________________________________
# max_pooling2d_490 (MaxPoolin (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_982 (Conv2D)          (None, 112, 112, 84)      48468
# _________________________________________________________________
# conv2d_983 (Conv2D)          (None, 112, 112, 106)     80242
# _________________________________________________________________
# max_pooling2d_491 (MaxPoolin (None, 56, 56, 106)       0
# _________________________________________________________________
# conv2d_984 (Conv2D)          (None, 56, 56, 178)       169990
# _________________________________________________________________
# conv2d_985 (Conv2D)          (None, 56, 56, 240)       384720
# _________________________________________________________________
# max_pooling2d_492 (MaxPoolin (None, 28, 28, 240)       0
# _________________________________________________________________
# conv2d_986 (Conv2D)          (None, 28, 28, 374)       808214
# _________________________________________________________________
# conv2d_987 (Conv2D)          (None, 28, 28, 478)       1609426
# _________________________________________________________________
# max_pooling2d_493 (MaxPoolin (None, 14, 14, 478)       0
# _________________________________________________________________
# conv2d_988 (Conv2D)          (None, 14, 14, 490)       2108470
# _________________________________________________________________
# conv2d_989 (Conv2D)          (None, 14, 14, 500)       2205500
# _________________________________________________________________
# max_pooling2d_494 (MaxPoolin (None, 7, 7, 500)         0
# _________________________________________________________________
# flatten_98 (Flatten)         (None, 24500)             0
# _________________________________________________________________
# dense_294 (Dense)            (None, 1328)              32537328
# _________________________________________________________________
# dropout_196 (Dropout)        (None, 1328)              0
# _________________________________________________________________
# dense_295 (Dense)            (None, 1296)              1722384
# _________________________________________________________________
# dropout_197 (Dropout)        (None, 1296)              0
# _________________________________________________________________
# dense_296 (Dense)            (None, 10)                12970
# =================================================================
# Total params: 41,711,216
# Trainable params: 41,711,216
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 4s 409ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 8s 8s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 34/34 [00:00<00:00, 25529.24it/s]
# [INFO] infer shape (NHWC)  :100%|█| 58/58 [00:00<00:00, 572.32it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 299.01it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1149.60it/s]
# [INFO] generate xmodel     :100%|█| 58/58 [00:02<00:00, 26.87it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_98, with op num: 104
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = quant_dense_294(TransferMatMulToConv2d), type = conv2d-fix} has been assigned to CPU: [Weights(1328, 7, 7, 500) is too large to be loaded into parameter buffer. "kernel_h * kernel_w * input_channel" is supposed to be less equal than 24576].
# [UNILOG][WARNING] xir::Op{name = quant_dense_294_const_const(reshaped), type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][WARNING] xir::Op{name = quant_dense_294_bias, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 5, DPU subgraph number 2
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 2c3cbc6a05a2b24953745596e853a4d1, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/md5sum.txt"
# Model: "model_99"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 224, 224, 1)]     0
# _________________________________________________________________
# conv2d_990 (Conv2D)          (None, 224, 224, 54)      540
# _________________________________________________________________
# conv2d_991 (Conv2D)          (None, 224, 224, 64)      31168
# _________________________________________________________________
# max_pooling2d_495 (MaxPoolin (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_992 (Conv2D)          (None, 112, 112, 98)      56546
# _________________________________________________________________
# conv2d_993 (Conv2D)          (None, 112, 112, 106)     93598
# _________________________________________________________________
# max_pooling2d_496 (MaxPoolin (None, 56, 56, 106)       0
# _________________________________________________________________
# conv2d_994 (Conv2D)          (None, 56, 56, 178)       169990
# _________________________________________________________________
# conv2d_995 (Conv2D)          (None, 56, 56, 178)       285334
# _________________________________________________________________
# max_pooling2d_497 (MaxPoolin (None, 28, 28, 178)       0
# _________________________________________________________________
# conv2d_996 (Conv2D)          (None, 28, 28, 438)       702114
# _________________________________________________________________
# conv2d_997 (Conv2D)          (None, 28, 28, 470)       1853210
# _________________________________________________________________
# max_pooling2d_498 (MaxPoolin (None, 14, 14, 470)       0
# _________________________________________________________________
# conv2d_998 (Conv2D)          (None, 14, 14, 496)       2098576
# _________________________________________________________________
# conv2d_999 (Conv2D)          (None, 14, 14, 498)       2223570
# _________________________________________________________________
# max_pooling2d_499 (MaxPoolin (None, 7, 7, 498)         0
# _________________________________________________________________
# flatten_99 (Flatten)         (None, 24402)             0
# _________________________________________________________________
# dense_297 (Dense)            (None, 2128)              51929584
# _________________________________________________________________
# dropout_198 (Dropout)        (None, 2128)              0
# _________________________________________________________________
# dense_298 (Dense)            (None, 1104)              2350416
# _________________________________________________________________
# dropout_199 (Dropout)        (None, 1104)              0
# _________________________________________________________________
# dense_299 (Dense)            (None, 10)                11050
# =================================================================
# Total params: 61,805,696
# Trainable params: 61,805,696
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 5s 502ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 1/1 [==============================] - 7s 7s/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quantize Adjustment...
# [VAI INFO] Post-Quantize Adjustment Done.
# [VAI INFO] Quantization Finished.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# **************************************************
# * VITIS_AI Compilation - Xilinx Inc.
# **************************************************
# [INFO] Namespace(batchsize=1, inputs_shape=None, layout='NHWC', model_files=['./quantized.h5'], model_type='tensorflow2', named_inputs_shape=None, out_filename='/tmp/deploy_org.xmodel', proto=None)
# [INFO] tensorflow2 model: /workspace/DPU-PYNQ/host/quantized.h5
# [INFO] keras version: 2.6.0
# [INFO] Tensorflow Keras model type: functional
# [INFO] parse raw model     :100%|█| 34/34 [00:00<00:00, 25630.18it/s]
# [INFO] infer shape (NHWC)  :100%|█| 58/58 [00:00<00:00, 448.43it/s]
# [INFO] perform level-0 opt :100%|█| 2/2 [00:00<00:00, 298.44it/s]
# [INFO] perform level-1 opt :100%|█| 2/2 [00:00<00:00, 1142.08it/s]
# [INFO] generate xmodel     :100%|█| 58/58 [00:03<00:00, 17.17it/s]
# [INFO] dump xmodel: /tmp/deploy_org.xmodel
# [UNILOG][INFO] Compile mode: dpu
# [UNILOG][INFO] Debug mode: function
# [UNILOG][INFO] Target architecture: DPUCZDX8G_ISA0_B2304_MAX_BG2
# [UNILOG][INFO] Graph name: model_99, with op num: 104
# [UNILOG][INFO] Begin to compile...
# [UNILOG][WARNING] xir::Op{name = quant_dense_297(TransferMatMulToConv2d), type = conv2d-fix} has been assigned to CPU: [Weights(2128, 7, 7, 498) is too large to be loaded into parameter buffer. "kernel_h * kernel_w * input_channel" is supposed to be less equal than 24576].
# [UNILOG][WARNING] xir::Op{name = quant_dense_297_const_const(reshaped), type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][WARNING] xir::Op{name = quant_dense_297_bias, type = const-fix} has been assigned to CPU: [Has no fanout or at least one fanout is out of DPU subgraph.].
# [UNILOG][INFO] Total device subgraph number 5, DPU subgraph number 2
# [UNILOG][INFO] Compile done.
# [UNILOG][INFO] The meta json is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/meta.json"
# [UNILOG][INFO] The compiled xmodel is saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/deploy.xmodel"
# [UNILOG][INFO] The compiled xmodel's md5sum is 7bc3d35b2c983d2d17932f6c471bf40f, and has been saved to "/workspace/DPU-PYNQ/host/./xmodel_vgg13/md5sum.txt"
