# %% [markdown]
# # Multiple Linear Regression using the Ordinary Least Squares (OLS)

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt


# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]] 
# y_test = df_pred['Execution_time']

df = pd.read_csv("model_result.csv")
x_train = df[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M"]]
y_train = df['Execution_time']

df_pred = pd.read_csv("model_result_NCV.csv")
x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M"]]
y_test = df_pred['Execution_time']


# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M"]]
# y_test = df_pred['Execution_time']

# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M"]]
# y_test = df_pred['Execution_time']

x_train = sm.add_constant(x_train)
olsmod = sm.OLS(y_train, x_train)
olsres = olsmod.fit()
print(olsres.summary())
x_test = sm.add_constant(x_test)
y_pred = olsres.predict(x_test)


print(y_pred)
# Calculate percentage error
per_err = (y_test - y_pred) / y_test
print(per_err)
# Take absolute value of the percentage error (APE)
per_err = abs(per_err)*100

# Calculate the MAPE
MAPE = sum(per_err)/len(per_err)
  
# Print the MAPE value 
print(f'''
MAPE of OLS  : { round(MAPE, 2) }

''')
index=np.argsort(y_test)

plt.figure(figsize=(12,5))
plt.plot(np.arange(len(y_test)),y_test[index],"r",label="original execution time")
plt.scatter(np.arange(len(y_pred)),y_pred[index],s=10,c="b",label="prediced execution time ")
plt.legend(loc="upper left")
plt.grid()
plt.xlabel("The index of the model that need to be predicted")
plt.ylabel("execution time(ms)")
plt.title("OLS Regression Results")
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Execution_time   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.986
# Method:                 Least Squares   F-statistic:                     9553.
# Date:                Wed, 18 May 2022   Prob (F-statistic):               0.00
# Time:                        16:02:47   Log-Likelihood:                -1261.7
# No. Observations:                 532   AIC:                             2533.
# Df Residuals:                     527   BIC:                             2555.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.7484      0.226     -3.318      0.001      -1.192      -0.305
# FLOPs_G                    2.2111      0.046     47.597      0.000       2.120       2.302
# Total_params_M             0.3695      0.009     40.138      0.000       0.351       0.388
# Memory_M                  -6.7150      1.962     -3.423      0.001     -10.569      -2.861
# total_num_of_neurons_M    27.2298      7.756      3.511      0.000      11.993      42.467
# ==============================================================================
# Omnibus:                      956.896   Durbin-Watson:                   1.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           889988.093
# Skew:                          11.263   Prob(JB):                         0.00
# Kurtosis:                     202.104   Cond. No.                     3.02e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.02e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 0       3.062579
# 1       4.734597
# 2       6.698103
# 3       8.953099
# 4       5.428195
#          ...
# 128    30.232695
# 129    35.811328
# 130    39.902311
# 131    45.803253
# 132    52.451072
# Length: 133, dtype: float64
# 0      0.144746
# 1     -0.019169
# 2     -0.018558
# 3     -0.070354
# 4      0.092317
#          ...
# 128   -0.065066
# 129   -0.017801
# 130    0.006276
# 131    0.017720
# 132    0.046387
# Length: 133, dtype: float64
#
# MAPE of OLS  : 7.68

# %% [markdown]
# # Multi-Layer Perceptrons (MLP)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import pandas as pd
from pandas.core.frame import DataFrame
import numpy as np
import csv
import matplotlib.pyplot as plt


# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]] 
# y_test = df_pred['Execution_time']

# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M"]]
# y_test = df_pred['Execution_time']


# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M"]]
# y_test = df_pred['Execution_time']

df = pd.read_csv("model_result.csv")
x_train = df[["FLOPs_G","Total_params_M"]]
y_train = df['Execution_time']

df_pred = pd.read_csv("model_result_NCV.csv")
x_test = df_pred[["FLOPs_G","Total_params_M"]]
y_test = df_pred['Execution_time']



# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]] 
# y_test = df_pred['Execution_time']

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)

x_test = scaler.fit_transform(x_test)

model = tf.keras.Sequential([tf.keras.layers.Dense(10, activation = 'relu', input_shape = x_train.shape[1:]),
                             tf.keras.layers.Dense(5, activation = 'sigmoid'),
                            tf.keras.layers.Dense(1)])

model.compile(loss = tf.losses.mean_squared_error,
             optimizer = 'sgd')
model.summary()
history = model.fit(x_train, y_train, epochs=1000)

y_pred = model.predict(x_test)

y_test = np.array(y_test).reshape(-1,1)

# Calculate percentage error
per_err = (y_test - y_pred) / y_test
#print(per_err)

# Take absolute value of the percentage error (APE)
per_err = abs(per_err)*100

# Calculate the MAPE
MAPE = sum(per_err)/len(per_err)
MAPE = DataFrame(MAPE)  
# Print the MAPE value 
print("MAPE of MLP  :" , round(MAPE, 2) )

y_test_sort=np.sort(y_test,axis=0)
y_pred_sort=np.sort(y_pred,axis=0)
plt.figure(figsize=(13,6))
plt.plot(np.arange(len(y_test)),y_test_sort,"r",label="original execution time")
plt.scatter(np.arange(len(y_pred)),y_pred_sort,s=10,c="b",label="prediced execution time ")
plt.legend(loc="upper left")
plt.grid()
plt.xlabel("The index of the model that need to be predicted")
plt.ylabel("execution time(ms)")
plt.title("Multi-Layer Perceptrons Results")
plt.show()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_34 (Dense)             (None, 10)                30
# _________________________________________________________________
# dense_35 (Dense)             (None, 5)                 55
# _________________________________________________________________
# dense_36 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 91
# Trainable params: 91
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 17/17 [==============================] - 0s 644us/step - loss: 800.9052
# Epoch 2/1000
# 17/17 [==============================] - 0s 562us/step - loss: 278.0504
# Epoch 3/1000
# 17/17 [==============================] - 0s 546us/step - loss: 144.0174
# Epoch 4/1000
# 17/17 [==============================] - 0s 518us/step - loss: 98.9793
# Epoch 5/1000
# 17/17 [==============================] - 0s 531us/step - loss: 75.4995
# Epoch 6/1000
# 17/17 [==============================] - 0s 549us/step - loss: 62.9919
# Epoch 7/1000
# 17/17 [==============================] - 0s 577us/step - loss: 50.6025
# Epoch 8/1000
# 17/17 [==============================] - 0s 557us/step - loss: 44.8779
# Epoch 9/1000
# 17/17 [==============================] - 0s 558us/step - loss: 39.8115
# Epoch 10/1000
# 17/17 [==============================] - 0s 557us/step - loss: 35.0785
# Epoch 11/1000
# 17/17 [==============================] - 0s 676us/step - loss: 34.8949
# Epoch 12/1000
# 17/17 [==============================] - 0s 721us/step - loss: 32.6837
# Epoch 13/1000
# 17/17 [==============================] - 0s 736us/step - loss: 29.0335
# Epoch 14/1000
# 17/17 [==============================] - 0s 728us/step - loss: 31.3615
# Epoch 15/1000
# 17/17 [==============================] - 0s 719us/step - loss: 27.6302
# Epoch 16/1000
# 17/17 [==============================] - 0s 787us/step - loss: 30.3980
# Epoch 17/1000
# 17/17 [==============================] - 0s 902us/step - loss: 27.7955
# Epoch 18/1000
# 17/17 [==============================] - 0s 911us/step - loss: 26.4381
# Epoch 19/1000
# 17/17 [==============================] - 0s 927us/step - loss: 24.6368
# Epoch 20/1000
df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]] 
# y_test = df_pred['Execution_time']

df = pd.read_csv("model_result.csv")
x_train = df[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M"]]
y_train = df['Execution_time']

df_pred = pd.read_csv("model_result_NCV.csv")
x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M"]]
y_test = df_pred['Execution_time']


# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M"]]
# y_test = df_pred['Execution_time']

# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M"]]
# y_test = df_pred['Execution_time']



# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]] 
# y_test = df_pred['Execution_time']
MAPE_default=10000
MAPE_better=MAPE_default
for num_estimators in range(1,150,2):

    # Initializing the Random Forest Regression model with 50 decision trees
    model = RandomForestRegressor(n_estimators = num_estimators, random_state = 0)

    # Fitting the Random Forest Regression model to the data
    model.fit(x_train, y_train) 

    # Predicting the target values of the test set
    y_pred_current = model.predict(x_test)

    # Calculate percentage error
    per_err = (y_test - y_pred_current) / y_test

    # Take absolute value of the percentage error (APE)
    per_err = abs(per_err)*100

    # Calculate the MAPE
    MAPE = sum(per_err)/len(per_err)

    # Print the MAPE value 
#     print(f'''
#     MAPE of Random Forest  : { round(MAPE, 2) }

#     ''')
    if ( MAPE < MAPE_better ):
        better_num_estimators = num_estimators
        MAPE_better = MAPE
        y_pred = y_pred_current
        
print(f'''        
The lowest MAPE of Random Forest  : { round(MAPE_better, 2) }, the number of estimator :{ better_num_estimators }

''')
# plt.barh(x_train.columns, model.feature_importances_)
sorted_idx = model.feature_importances_.argsort()
plt.barh(x_train.columns[sorted_idx], model.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
index=np.argsort(y_test)

plt.figure(figsize=(12,5))
plt.plot(np.arange(len(y_test)),y_test[index],"r",label="original execution time")
plt.scatter(np.arange(len(y_pred)),y_pred[index],s=10,c="b",label="prediced execution time ")
plt.legend(loc="upper left")
plt.grid()
plt.xlabel("The index of the model that need to be predicted")
plt.ylabel("execution time(ms)")
plt.title("Random Forest Results")
plt.show()
# Out:
#
# The lowest MAPE of Random Forest  : 5.66, the number of estimator :137

# %% [markdown]
# # Support Vector Regression (SVR)

# %%
import pandas as pd # for data manipulation
import numpy as np # for data manipulation

from itertools import product
# Sklearn
from sklearn.linear_model import LinearRegression # for building a linear regression model
from sklearn.svm import SVR # for building SVR model
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt # for data visualization
# %matplotlib inline


# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]] 
# y_test = df_pred['Execution_time']

df = pd.read_csv("model_result.csv")
x_train = df[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M"]]
y_train = df['Execution_time']

df_pred = pd.read_csv("model_result_NCV.csv")
x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M"]]
y_test = df_pred['Execution_time']


# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M"]]
# y_test = df_pred['Execution_time']

# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M"]]
# y_test = df_pred['Execution_time']
# ----------- Model fitting -----------

# model1 = LinearRegression()
# lr = model1.fit(x_train, y_train)
MAPE_default=10000
MAPE_better=MAPE_default
range_C =range(1,400,2)
range_epsilon =range(1,10,1)
for value_C, value_epsilon in product(range_C,range_epsilon):
    model2 = SVR(kernel='rbf', C=value_C, epsilon=value_epsilon) # set kernel and hyperparameters
    svr = model2.fit(x_train, y_train)

    # y_lr = model1.predict(x_test)
    y_pred_current = model2.predict(x_test)


    # # Calculate percentage error
    # per_err = (y_test - y_lr) / y_test

    # # Take absolute value of the percentage error (APE)
    # per_err = abs(per_err)*100


    # # Calculate the MAPE
    # MAPE = sum(per_err)/len(per_err)

    # # Print the MAPE value 
    # print(f'''
    # MAPE of Linear Regression   : { round(MAPE, 2) }

    # ''')


    # Calculate percentage error
    per_err = (y_test - y_pred_current) / y_test

    # Take absolute value of the percentage error (APE)
    per_err = abs(per_err)*100


    # Calculate the MAPE
    MAPE = sum(per_err)/len(per_err)

    # Print the MAPE value 
    print(f'''
    MAPE of SVR  : { round(MAPE, 2) }

    ''')

    if ( MAPE < MAPE_better ):
        better_C = value_C
        better_epsilon = value_epsilon
        MAPE_better = MAPE
        y_pred = y_pred_current
        
        
print(f'''        
The lowest MAPE of SVR  : { round(MAPE_better, 2) }, the value of hyperparameters :C = {better_C}, epsilon = {better_epsilon}

''')
index=np.argsort(y_test)

plt.figure(figsize=(12,5))
plt.plot(np.arange(len(y_test)),y_test[index],"r",label="original execution time")
plt.scatter(np.arange(len(y_pred)),y_pred[index],s=10,c="b",label="prediced execution time ")
plt.legend(loc="upper left")
plt.grid()
plt.xlabel("The index of the model that need to be predicted")
plt.ylabel("execution time(ms)")
plt.title("Support Vector Regression Results")
plt.show()


# plt.figure(figsize=(12,5))
# plt.plot(np.arange(len(y_test)),y_test[index],"r",label="original y")
# plt.scatter(np.arange(len(y_lr)),y_lr[index],s=3,c="b",label="prediction")
# plt.legend(loc="upper left")
# plt.grid()
# plt.xlabel("index")
# plt.ylabel("y")
# plt.title(":")
# plt.show()
# Out:
#     MAPE of SVR  : 17.18
#
#
# 17.18176261006862
#
#     MAPE of SVR  : 19.6
#
#
#
#     MAPE of SVR  : 23.21
#
#
#
#     MAPE of SVR  : 28.27
#
#
#
#     MAPE of SVR  : 33.67
#
#
#
#     MAPE of SVR  : 40.0
#
#
#
#     MAPE of SVR  : 46.31
#
#
#
#     MAPE of SVR  : 53.54
#
#
#
#     MAPE of SVR  : 60.42
#
#
#
#     MAPE of SVR  : 9.58
#
#
# 9.579242918833003
#
#     MAPE of SVR  : 13.18
#
#
#
#     MAPE of SVR  : 18.14
#
#
#
#     MAPE of SVR  : 22.74
#
#
#
#     MAPE of SVR  : 28.99
#
#
#
#     MAPE of SVR  : 35.3
#
#
#
#     MAPE of SVR  : 41.74
#
#
#
#     MAPE of SVR  : 48.75
#
#
#
#     MAPE of SVR  : 56.29
#
#
#
#     MAPE of SVR  : 8.47
#
#
# 8.471703115359272
#
#     MAPE of SVR  : 12.32
#
#
#
#     MAPE of SVR  : 16.52
#
#
#
#     MAPE of SVR  : 21.82
#
#
#
#     MAPE of SVR  : 27.91
#
#
#
#     MAPE of SVR  : 34.19
#
#
#
#     MAPE of SVR  : 40.22
#
#
#
#     MAPE of SVR  : 46.46
#
#
#
#     MAPE of SVR  : 53.93
#
#
#
#     MAPE of SVR  : 8.11
#
#
# 8.109031394217265
#
#     MAPE of SVR  : 11.74
#
#
#
#     MAPE of SVR  : 16.04
#
#
#
#     MAPE of SVR  : 21.18
#
#
#
#     MAPE of SVR  : 27.17
#
#
#
#     MAPE of SVR  : 33.21
#
#
#
#     MAPE of SVR  : 39.06
#
#
#
#     MAPE of SVR  : 45.11
#
#
#
#     MAPE of SVR  : 52.34
#
#
#
#     MAPE of SVR  : 7.87
#
#
# 7.866684645707868
#
#     MAPE of SVR  : 11.36
#
#
#
#     MAPE of SVR  : 15.5
#
#
#
#     MAPE of SVR  : 20.92
#
#
#
#     MAPE of SVR  : 26.96
#
#
#
#     MAPE of SVR  : 32.58
#
#
#
#     MAPE of SVR  : 38.4
#
#
#
#     MAPE of SVR  : 45.05
#
#
#
#     MAPE of SVR  : 51.14
#
#
#
#     MAPE of SVR  : 7.74
#
#
# 7.7409299945087975
#
#     MAPE of SVR  : 11.29
#
#
#
#     MAPE of SVR  : 15.31
#
#
#
#     MAPE of SVR  : 20.38
#
#
#
#     MAPE of SVR  : 26.18
#
#
#
#     MAPE of SVR  : 32.07
#
#
#
#     MAPE of SVR  : 37.7
#
#
#
#     MAPE of SVR  : 43.78
#
#
#
#     MAPE of SVR  : 49.56
#
#
#
#     MAPE of SVR  : 7.68
#
#
# 7.678166668311111
#
#     MAPE of SVR  : 11.05
#
#
#
#     MAPE of SVR  : 15.26
#
#
#
#     MAPE of SVR  : 20.28
#
#
#
#     MAPE of SVR  : 26.19
#
#
#
#     MAPE of SVR  : 31.63
#
#
#
#     MAPE of SVR  : 36.58
#
#
#
#     MAPE of SVR  : 41.19
#
#
#
#     MAPE of SVR  : 46.99
#
#
#
#     MAPE of SVR  : 7.55
#
#
# 7.5489077645563665
#
#     MAPE of SVR  : 10.95
#
#
#
#     MAPE of SVR  : 15.04
#
#
#
#     MAPE of SVR  : 20.31
#
#
#
#     MAPE of SVR  : 26.02
#
#
#
#     MAPE of SVR  : 29.15
#
#
#
#     MAPE of SVR  : 34.82
#
#
#
#     MAPE of SVR  : 40.35
#
#
#
#     MAPE of SVR  : 46.6
#
#
#
#     MAPE of SVR  : 7.38
#
#
# 7.381355348708591
#
#     MAPE of SVR  : 10.83
#
#
#
#     MAPE of SVR  : 14.64
#
#
#
#     MAPE of SVR  : 20.31
#
#
#
#     MAPE of SVR  : 23.96
#
#
#
#     MAPE of SVR  : 28.85
#
#
#
#     MAPE of SVR  : 34.28
#
#
#
#     MAPE of SVR  : 40.12
#
#
#
#     MAPE of SVR  : 46.55
#
#
#
#     MAPE of SVR  : 7.3
#
#
# 7.3019929333432705
#
#     MAPE of SVR  : 10.77
#
#
#
#     MAPE of SVR  : 14.39
#
#
#
#     MAPE of SVR  : 18.29
#
#
#
#     MAPE of SVR  : 23.52
#
#
#
#     MAPE of SVR  : 28.68
#
#
#
#     MAPE of SVR  : 34.14
#
#
#
#     MAPE of SVR  : 40.03
#
#
#
#     MAPE of SVR  : 46.44
#
#
#
#     MAPE of SVR  : 7.24
#
#
# 7.241070110085382
#
#     MAPE of SVR  : 10.76
#
#
#
#     MAPE of SVR  : 13.67
#
#
#
#     MAPE of SVR  : 18.33
#
#
#
#     MAPE of SVR  : 23.39
#
#
#
#     MAPE of SVR  : 28.61
#
#
#
#     MAPE of SVR  : 34.06
#
#
#
#     MAPE of SVR  : 39.97
#
#
#
#     MAPE of SVR  : 46.18
#
#
#
#     MAPE of SVR  : 7.16
#
#
# 7.164155718980542
#
#     MAPE of SVR  : 10.68
#
#
#
#     MAPE of SVR  : 13.65
#
#
#
#     MAPE of SVR  : 18.32
#
#
#
#     MAPE of SVR  : 23.27
#
#
#
#     MAPE of SVR  : 28.54
#
#
#
#     MAPE of SVR  : 34.01
#
#
#
#     MAPE of SVR  : 39.8
#
#
#
#     MAPE of SVR  : 45.86
#
#
#
#     MAPE of SVR  : 7.09
#
#
# 7.090094495486532
#
#     MAPE of SVR  : 10.53
#
#
#
#     MAPE of SVR  : 13.66
#
#
#
#     MAPE of SVR  : 18.19
#
#
#
#     MAPE of SVR  : 23.15
#
#
#
#     MAPE of SVR  : 28.4
#
#
#
#     MAPE of SVR  : 33.92
#
#
#
#     MAPE of SVR  : 39.54
#
#
#
#     MAPE of SVR  : 44.82
#
#
#
#     MAPE of SVR  : 7.03
#
#
# 7.033260965187969
#
#     MAPE of SVR  : 10.5
#
#
#
#     MAPE of SVR  : 13.61
#
#
#
#     MAPE of SVR  : 18.13
#
#
#
#     MAPE of SVR  : 23.05
#
#
#
#     MAPE of SVR  : 28.33
#
#
#
#     MAPE of SVR  : 33.01
#
#
#
#     MAPE of SVR  : 38.45
#
#
#
#     MAPE of SVR  : 44.64
#
#
#
#     MAPE of SVR  : 7.02
#
#
# 7.018412863177421
#
#     MAPE of SVR  : 10.47
#
#
#
#     MAPE of SVR  : 13.53
#
#
#
#     MAPE of SVR  : 18.06
#
#
#
#     MAPE of SVR  : 22.95
#
#
#
#     MAPE of SVR  : 27.93
#
#
#
#     MAPE of SVR  : 32.6
#
#
#
#     MAPE of SVR  : 38.31
#
#
#
#     MAPE of SVR  : 44.52
#
#
#
#     MAPE of SVR  : 7.01
#
#
# 7.007348455792897
#
#     MAPE of SVR  : 10.44
#
#
#
#     MAPE of SVR  : 13.52
#
#
#
#     MAPE of SVR  : 18.02
#
#
#
#     MAPE of SVR  : 22.91
#
#
#
#     MAPE of SVR  : 27.08
#
#
#
#     MAPE of SVR  : 32.46
#
#
#
#     MAPE of SVR  : 38.22
#
#
#
#     MAPE of SVR  : 44.42
#
#
#
#     MAPE of SVR  : 6.99
#
#
# 6.985262807135247
#
#     MAPE of SVR  : 10.42
#
#
#
#     MAPE of SVR  : 13.49
#
#
#
#     MAPE of SVR  : 18.02
#
#
#
#     MAPE of SVR  : 22.32
#
#
#
#     MAPE of SVR  : 27.08
#
#
#
#     MAPE of SVR  : 32.37
#
#
#
#     MAPE of SVR  : 38.17
#
#
#
#     MAPE of SVR  : 44.32
#
#
#
#     MAPE of SVR  : 6.95
#
#
# 6.952270451310519
#
#     MAPE of SVR  : 10.38
#
#
#
#     MAPE of SVR  : 13.34
#
#
#
#     MAPE of SVR  : 18.01
#
#
#
#     MAPE of SVR  : 21.88
#
#
#
#     MAPE of SVR  : 27.03
#
#
#
#     MAPE of SVR  : 32.31
#
#
#
#     MAPE of SVR  : 38.08
#
#
#
#     MAPE of SVR  : 44.33
#
#
#
#     MAPE of SVR  : 6.9
#
#
# 6.895238795478165
#
#     MAPE of SVR  : 10.3
#
#
#
#     MAPE of SVR  : 13.22
#
#
#
#     MAPE of SVR  : 18.05
#
#
#
#     MAPE of SVR  : 21.91
#
#
#
#     MAPE of SVR  : 27.0
#
#
#
#     MAPE of SVR  : 32.17
#
#
#
#     MAPE of SVR  : 38.03
#
#
#
#     MAPE of SVR  : 44.35
#
#
#
#     MAPE of SVR  : 6.9
#
#
#
#     MAPE of SVR  : 10.0
#
#
#
#     MAPE of SVR  : 13.21
#
#
#
#     MAPE of SVR  : 17.83
#
#
#
#     MAPE of SVR  : 21.91
#
#
#
#     MAPE of SVR  : 26.95
#
#
#
#     MAPE of SVR  : 32.06
#
#
#
#     MAPE of SVR  : 38.0
#
#
#
#     MAPE of SVR  : 44.37
#
#
#
#     MAPE of SVR  : 6.87
#
#
# 6.871535009332593
#
#     MAPE of SVR  : 9.91
#
#
#
#     MAPE of SVR  : 13.19
#
#
#
#     MAPE of SVR  : 17.27
#
#
#
#     MAPE of SVR  : 21.86
#
#
#
#     MAPE of SVR  : 26.92
#
#
#
#     MAPE of SVR  : 32.04
#
#
#
#     MAPE of SVR  : 38.0
#
#
#
#     MAPE of SVR  : 44.38
#
#
#
#     MAPE of SVR  : 6.79
#
#
# 6.788282944979143
#
#     MAPE of SVR  : 9.98
#
#
#
#     MAPE of SVR  : 13.18
#
#
#
#     MAPE of SVR  : 17.32
#
#
#
#     MAPE of SVR  : 21.84
#
#
#
#     MAPE of SVR  : 26.91
#
#
#
#     MAPE of SVR  : 32.04
#
#
#
#     MAPE of SVR  : 38.0
#
#
#
#     MAPE of SVR  : 44.38
#
#
#
#     MAPE of SVR  : 6.78
#
#
# 6.775240587549934
#
#     MAPE of SVR  : 10.0
#
#
#
#     MAPE of SVR  : 13.14
#
#
#
#     MAPE of SVR  : 17.35
#
#
#
#     MAPE of SVR  : 21.84
#
#
#
#     MAPE of SVR  : 26.93
#
#
#
#     MAPE of SVR  : 32.04
#
#
#
#     MAPE of SVR  : 37.99
#
#
#
#     MAPE of SVR  : 44.38
#
#
#
#     MAPE of SVR  : 6.75
#
#
# 6.749415362346317
#
#     MAPE of SVR  : 10.0
#
#
#
#     MAPE of SVR  : 12.51
#
#
#
#     MAPE of SVR  : 17.36
#
#
#
#     MAPE of SVR  : 21.85
#
#
#
#     MAPE of SVR  : 26.93
#
#
#
#     MAPE of SVR  : 32.04
#
#
#
#     MAPE of SVR  : 37.99
#
#
#
#     MAPE of SVR  : 44.39
#
#
#
#     MAPE of SVR  : 6.73
#
#
# 6.734660591841495
#
#     MAPE of SVR  : 10.0
#
#
#
#     MAPE of SVR  : 12.46
#
#
#
#     MAPE of SVR  : 17.37
#
#
#
#     MAPE of SVR  : 21.85
#
#
#
#     MAPE of SVR  : 26.94
#
#
#
#     MAPE of SVR  : 32.05
#
#
#
#     MAPE of SVR  : 37.99
#
#
#
#     MAPE of SVR  : 44.39
#
#
#
#     MAPE of SVR  : 6.72
#
#
# 6.723715754675751
#
#     MAPE of SVR  : 10.0
#
#
#
#     MAPE of SVR  : 12.42
#
#
#
#     MAPE of SVR  : 17.39
#
#
#
#     MAPE of SVR  : 21.86
#
#
#
#     MAPE of SVR  : 26.94
#
#
#
#     MAPE of SVR  : 32.06
#
#
#
#     MAPE of SVR  : 37.99
#
#
#
#     MAPE of SVR  : 44.39
#
#
#
#     MAPE of SVR  : 6.71
#
#
# 6.71264178219464
#
#     MAPE of SVR  : 10.04
#
#
#
#     MAPE of SVR  : 12.42
#
#
#
#     MAPE of SVR  : 17.37
#
#
#
#     MAPE of SVR  : 21.86
#
#
#
#     MAPE of SVR  : 26.95
#
#
#
#     MAPE of SVR  : 32.07
#
#
#
#     MAPE of SVR  : 37.99
#
#
#
#     MAPE of SVR  : 44.4
#
#
#
#     MAPE of SVR  : 6.7
#
#
# 6.702289358621713
#
#     MAPE of SVR  : 10.07
#
#
#
#     MAPE of SVR  : 12.41
#
#
#
#     MAPE of SVR  : 17.36
#
#
#
#     MAPE of SVR  : 21.87
#
#
#
#     MAPE of SVR  : 26.95
#
#
#
#     MAPE of SVR  : 32.08
#
#
#
#     MAPE of SVR  : 37.99
#
#
#
#     MAPE of SVR  : 44.4
#
#
#
#     MAPE of SVR  : 6.69
#
#
# 6.689515735713928
#
#     MAPE of SVR  : 10.09
#
#
#
#     MAPE of SVR  : 12.41
#
#
#
#     MAPE of SVR  : 17.35
#
#
#
#     MAPE of SVR  : 21.89
#
#
#
#     MAPE of SVR  : 26.96
#
#
#
#     MAPE of SVR  : 32.13
#
#
#
#     MAPE of SVR  : 37.99
#
#
#
#     MAPE of SVR  : 44.4
#
#
#
#     MAPE of SVR  : 6.68
#
#
# 6.681824465046469
#
#     MAPE of SVR  : 10.11
#
#
#
#     MAPE of SVR  : 12.41
#     MAPE of SVR  : 17.33
#
#
#
#     MAPE of SVR  : 21.92
#
#
#
#     MAPE of SVR  : 26.96
#
#
#
#     MAPE of SVR  : 32.18
#
#
#
#     MAPE of SVR  : 38.0
#
#
#
#     MAPE of SVR  : 44.41
#
#
#
#     MAPE of SVR  : 6.67
#
#
# 6.669843477271158
#
#     MAPE of SVR  : 10.12
#
#
#
#     MAPE of SVR  : 12.39
#
#
#
#     MAPE of SVR  : 17.31
#
#
#
#     MAPE of SVR  : 21.94
#
#
#
#     MAPE of SVR  : 26.97
#
#
#
#     MAPE of SVR  : 32.23
#
#
#
#     MAPE of SVR  : 38.0
#
#
#
#     MAPE of SVR  : 44.41
#
#
#
#     MAPE of SVR  : 6.66
#
#
# 6.657842844481876
#
#     MAPE of SVR  : 10.13
#
#
#
#     MAPE of SVR  : 12.38
#
#
#
#     MAPE of SVR  : 17.28
#
#
#
#     MAPE of SVR  : 21.93
#
#
#
#     MAPE of SVR  : 26.97
#
#
#
#     MAPE of SVR  : 32.24
#
#
#
#     MAPE of SVR  : 38.01
#
#
#
#     MAPE of SVR  : 44.41
#
#
#
#     MAPE of SVR  : 6.65
#
#
# 6.646431818543475
#
#     MAPE of SVR  : 10.14
#
#
#
#     MAPE of SVR  : 12.36
#
#
#
#     MAPE of SVR  : 17.25
#
#
#
#     MAPE of SVR  : 21.91
#
#
#
#     MAPE of SVR  : 26.98
#
#
#
#     MAPE of SVR  : 32.25
#
#
#
#     MAPE of SVR  : 38.02
#
#
#
#     MAPE of SVR  : 44.42
#
#
#
#     MAPE of SVR  : 6.64
#
#
# 6.636545040189685
#
#     MAPE of SVR  : 10.15
#
#
#
#     MAPE of SVR  : 12.36
#
#
#
#     MAPE of SVR  : 17.22
#
#
#
#     MAPE of SVR  : 21.88
#
#
#
#     MAPE of SVR  : 26.99
#
#
#
#     MAPE of SVR  : 32.25
#
#
#
#     MAPE of SVR  : 38.02
#
#
#
#     MAPE of SVR  : 44.42
#
#
#
#     MAPE of SVR  : 6.63
#
#
# 6.634067019740847
#
#     MAPE of SVR  : 10.16
#
#
#
#     MAPE of SVR  : 12.36
#
#
#
#     MAPE of SVR  : 17.21
#
#
#
#     MAPE of SVR  : 21.85
#
#
#
#     MAPE of SVR  : 27.0
#
#
#
#     MAPE of SVR  : 32.26
#
#
#
#     MAPE of SVR  : 38.02
#
#
#
#     MAPE of SVR  : 44.43
#
#
#
#     MAPE of SVR  : 6.63
#
#
# 6.630810356582671
#
#     MAPE of SVR  : 10.17
#
#
#
#     MAPE of SVR  : 12.35
#
#
#
#     MAPE of SVR  : 17.24
#
#
#
#     MAPE of SVR  : 21.87
#
#
#
#     MAPE of SVR  : 27.0
#
#
#
#     MAPE of SVR  : 32.27
#
#
#
#     MAPE of SVR  : 38.02
#
#
#
#     MAPE of SVR  : 44.43
#
#
#
#     MAPE of SVR  : 6.59
#
#
# 6.594989174976158
#
#     MAPE of SVR  : 10.17
#
#
#
#     MAPE of SVR  : 12.35
#
#
#
#     MAPE of SVR  : 17.27
#
#
#
#     MAPE of SVR  : 21.89
#
#
#
#     MAPE of SVR  : 27.01
#
#
#
#     MAPE of SVR  : 32.27
#
#
#
#     MAPE of SVR  : 38.02
#
#
#
#     MAPE of SVR  : 44.44
#
#
#
#     MAPE of SVR  : 6.58
#
#
# 6.584482304903484
#
#     MAPE of SVR  : 10.16
#
#
#
#     MAPE of SVR  : 12.36
#
#
#
#     MAPE of SVR  : 17.3
#
#
#
#     MAPE of SVR  : 21.91
#
#
#
#     MAPE of SVR  : 27.01
#
#
#
#     MAPE of SVR  : 32.28
#
#
#
#     MAPE of SVR  : 38.02
#
#
#
#     MAPE of SVR  : 44.45
#
#
#
#     MAPE of SVR  : 6.57
#
#
# 6.567039074169209
#
#     MAPE of SVR  : 10.15
#
#
#
#     MAPE of SVR  : 12.36
#
#
#
#     MAPE of SVR  : 17.33
#
#
#
#     MAPE of SVR  : 21.93
#
#
#
#     MAPE of SVR  : 27.02
#
#
#
#     MAPE of SVR  : 32.28
#
#
#
#     MAPE of SVR  : 38.01
#
#
#
#     MAPE of SVR  : 44.45
#
#
#
#     MAPE of SVR  : 6.55
#
#
# 6.550527511608266
#
#     MAPE of SVR  : 10.14
#
#
#
#     MAPE of SVR  : 12.37
#
#
#
#     MAPE of SVR  : 17.35
#
#
#
#     MAPE of SVR  : 21.95
#
#
#
#     MAPE of SVR  : 27.03
#
#
#
#     MAPE of SVR  : 32.29
#
#
#
#     MAPE of SVR  : 38.0
#
#
#
#     MAPE of SVR  : 44.47
#
#
#
#     MAPE of SVR  : 6.54
#
#
# 6.536531109882498
#
#     MAPE of SVR  : 10.02
#
#
#
#     MAPE of SVR  : 12.38
#
#
#
#     MAPE of SVR  : 17.37
#
#
#
#     MAPE of SVR  : 21.98
#
#
#
#     MAPE of SVR  : 27.03
#
#
#
#     MAPE of SVR  : 32.29
#
#
#
#     MAPE of SVR  : 38.0
#
#
#
#     MAPE of SVR  : 44.49
#
#
#
#     MAPE of SVR  : 6.51
#
#
# 6.513820217459398
#
#     MAPE of SVR  : 9.96
#
#
#
#     MAPE of SVR  : 12.4
#
#
#
#     MAPE of SVR  : 17.4
#
#
#
#     MAPE of SVR  : 22.0
#
#
#
#     MAPE of SVR  : 27.04
#
#
#
#     MAPE of SVR  : 32.29
#
#
#
#     MAPE of SVR  : 37.99
#
#
#
#     MAPE of SVR  : 44.54
#
#
#
#     MAPE of SVR  : 6.5
#
#
# 6.502767711883767
#
#     MAPE of SVR  : 9.89
#
#
#
#     MAPE of SVR  : 12.42
#
#
#
#     MAPE of SVR  : 17.42
#
#
#
#     MAPE of SVR  : 22.02
#
#
#
#     MAPE of SVR  : 27.04
#
#
#
#     MAPE of SVR  : 32.29
#
#
#
#     MAPE of SVR  : 37.99
#
#
#
#     MAPE of SVR  : 44.59
#
#
#
#     MAPE of SVR  : 6.49
#
#
# 6.491985955082351
#
#     MAPE of SVR  : 9.82
#
#
#
#     MAPE of SVR  : 12.45
#
#
#
#     MAPE of SVR  : 17.44
#
#
#
#     MAPE of SVR  : 22.04
#
#
#
#     MAPE of SVR  : 27.04
#
#
#
#     MAPE of SVR  : 32.3
#
#
#
#     MAPE of SVR  : 37.99
#
#
#
#     MAPE of SVR  : 44.62
#
#
#
#     MAPE of SVR  : 6.47
#
#
# 6.4703005864002785
#
#     MAPE of SVR  : 9.76
#
#
#
#     MAPE of SVR  : 12.47
#
#
#
#     MAPE of SVR  : 17.46
#
#
#
#     MAPE of SVR  : 22.06
#
#
#
#     MAPE of SVR  : 27.04
#
#
#
#     MAPE of SVR  : 32.31
#
#
#
#     MAPE of SVR  : 37.98
#
#
#
#     MAPE of SVR  : 44.64
#
#
#
#     MAPE of SVR  : 6.45
#
#
# 6.454998125540051
#
#     MAPE of SVR  : 9.63
#
#
#
#     MAPE of SVR  : 12.48
#
#
#
#     MAPE of SVR  : 17.48
#
#
#
#     MAPE of SVR  : 22.08
#
#
#
#     MAPE of SVR  : 27.04
#
#
#
#     MAPE of SVR  : 32.31
#
#
#
#     MAPE of SVR  : 37.98
#
#
#
#     MAPE of SVR  : 44.67
#
#
#
#     MAPE of SVR  : 6.45
#
#
# 6.449347111245671
#
#     MAPE of SVR  : 9.63
#
#
#
#     MAPE of SVR  : 12.49
#
#
#
#     MAPE of SVR  : 17.51
#
#
#
#     MAPE of SVR  : 22.1
#
#
#
#     MAPE of SVR  : 27.04
#
#
#
#     MAPE of SVR  : 32.32
#
#
#
#     MAPE of SVR  : 37.97
#
#
#
#     MAPE of SVR  : 44.69
#
#
#
#     MAPE of SVR  : 6.44
#
#
# 6.442207251022997
#
#     MAPE of SVR  : 9.62
#
#
#
#     MAPE of SVR  : 12.51
#
#
#
#     MAPE of SVR  : 17.53
#
#
#
#     MAPE of SVR  : 22.13
#
#
#
#     MAPE of SVR  : 27.04
#
#
#
#     MAPE of SVR  : 32.33
#
#
#
#     MAPE of SVR  : 37.97
#
#
#
#     MAPE of SVR  : 44.72
#
#
#
#     MAPE of SVR  : 6.44
#
#
# 6.435924251001086
#
#     MAPE of SVR  : 9.61
#
#
#
#     MAPE of SVR  : 12.53
#
#
#
#     MAPE of SVR  : 17.55
#
#
#
#     MAPE of SVR  : 22.15
#
#
#
#     MAPE of SVR  : 27.04
#
#
#
#     MAPE of SVR  : 32.34
#
#
#
#     MAPE of SVR  : 37.97
#
#
#
#     MAPE of SVR  : 44.74
#
#
#
#     MAPE of SVR  : 6.43
#
#
# 6.4338460532289945
#
#     MAPE of SVR  : 9.61
#
#
#
#     MAPE of SVR  : 12.55
#
#
#
#     MAPE of SVR  : 17.58
#
#
#
#     MAPE of SVR  : 22.17
#
#
#
#     MAPE of SVR  : 27.04
#
#
#
#     MAPE of SVR  : 32.35
#
#
#
#     MAPE of SVR  : 37.97
#
#
#
#     MAPE of SVR  : 44.77
#
#
#
#     MAPE of SVR  : 6.43
#
#
# 6.430788561751718
#
#     MAPE of SVR  : 9.6
#
#
#
#     MAPE of SVR  : 12.56
#
#
#
#     MAPE of SVR  : 17.6
#
#
#
#     MAPE of SVR  : 22.2
#
#
#
#     MAPE of SVR  : 27.04
#
#
#
#     MAPE of SVR  : 32.36
#
#
#
#     MAPE of SVR  : 37.97
#
#
#
#     MAPE of SVR  : 44.8
#
#
#
#     MAPE of SVR  : 6.43
#
#
# 6.428676802464166
#
#     MAPE of SVR  : 9.6
#
#
#
#     MAPE of SVR  : 12.58
#
#
#
#     MAPE of SVR  : 17.63
#
#
#
#     MAPE of SVR  : 22.22
#
#
#
#     MAPE of SVR  : 27.04
#
#
#
#     MAPE of SVR  : 32.37
#
#
#
#     MAPE of SVR  : 37.97
#
#
#
#     MAPE of SVR  : 44.82
#
#
#
#     MAPE of SVR  : 6.43
#
#
# 6.426407817271379
#
#     MAPE of SVR  : 9.59
#
#
#
#     MAPE of SVR  : 12.59
#
#
#
#     MAPE of SVR  : 17.64
#
#
#
#     MAPE of SVR  : 22.25
#
#
#
#     MAPE of SVR  : 27.03
#
#
#
#     MAPE of SVR  : 32.39
#
#
#
#     MAPE of SVR  : 37.97
#
#
#
#     MAPE of SVR  : 44.85
#
#
#
#     MAPE of SVR  : 6.42
#
#
# 6.423280215364821
#
#     MAPE of SVR  : 9.58
#
#
#
#     MAPE of SVR  : 12.61
#
#
#
#     MAPE of SVR  : 17.65
#
#
#
#     MAPE of SVR  : 22.29
#
#
#
#     MAPE of SVR  : 27.03
#
#
#
#     MAPE of SVR  : 32.4
#
#
#
#     MAPE of SVR  : 37.97
#
#
#
#     MAPE of SVR  : 44.87
#
#
#
#     MAPE of SVR  : 6.42
#
#
# 6.420994504164195
#
#     MAPE of SVR  : 9.57
#
#
#
#     MAPE of SVR  : 12.62
#
#
#
#     MAPE of SVR  : 17.66
#
#
#
#     MAPE of SVR  : 22.31
#
#
#
#     MAPE of SVR  : 27.03
#
#
#
#     MAPE of SVR  : 32.41
#
#
#
#     MAPE of SVR  : 37.97
#
#
#
#     MAPE of SVR  : 44.9
#
#
#
#     MAPE of SVR  : 6.42
#
#
# 6.4208937560060235
#
#     MAPE of SVR  : 9.55
#
#
#
#     MAPE of SVR  : 12.64
#
#
#
#     MAPE of SVR  : 17.67
#
#
#
#     MAPE of SVR  : 22.32
#
#
#
#     MAPE of SVR  : 27.03
#
#
#
#     MAPE of SVR  : 32.42
#
#
#
#     MAPE of SVR  : 37.97
#
#
#
#     MAPE of SVR  : 44.93
#
#
#
#     MAPE of SVR  : 6.42
#
#
# 6.4205119325718165
#
#     MAPE of SVR  : 9.54
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.67
#
#
#
#     MAPE of SVR  : 22.33
#
#
#
#     MAPE of SVR  : 27.02
#
#
#
#     MAPE of SVR  : 32.42
#
#
#
#     MAPE of SVR  : 37.98
#
#
#
#     MAPE of SVR  : 44.95
#
#
#
#     MAPE of SVR  : 6.42
#
#
#
#     MAPE of SVR  : 9.54
#
#
#
#     MAPE of SVR  : 12.66
#
#
#
#     MAPE of SVR  : 17.67
#
#
#
#     MAPE of SVR  : 22.34
#
#
#
#     MAPE of SVR  : 27.02
#
#
#
#     MAPE of SVR  : 32.43
#
#
#
#     MAPE of SVR  : 37.98
#     MAPE of SVR  : 44.97
#
#
#
#     MAPE of SVR  : 6.42
#
#
# 6.417296064789378
#
#     MAPE of SVR  : 9.54
#
#
#
#     MAPE of SVR  : 12.68
#
#
#
#     MAPE of SVR  : 17.67
#
#
#
#     MAPE of SVR  : 22.35
#
#
#
#     MAPE of SVR  : 27.02
#
#
#
#     MAPE of SVR  : 32.43
#
#
#
#     MAPE of SVR  : 37.99
#
#
#
#     MAPE of SVR  : 45.0
#
#
#
#     MAPE of SVR  : 6.41
#
#
# 6.410666046988115
#
#     MAPE of SVR  : 9.53
#
#
#
#     MAPE of SVR  : 12.69
#
#
#
#     MAPE of SVR  : 17.66
#
#
#
#     MAPE of SVR  : 22.35
#
#
#
#     MAPE of SVR  : 27.02
#
#
#
#     MAPE of SVR  : 32.44
#
#
#
#     MAPE of SVR  : 37.99
#
#
#
#     MAPE of SVR  : 45.02
#
#
#
#     MAPE of SVR  : 6.4
#
#
# 6.402996981257306
#
#     MAPE of SVR  : 9.53
#
#
#
#     MAPE of SVR  : 12.7
#
#
#
#     MAPE of SVR  : 17.66
#
#
#
#     MAPE of SVR  : 22.36
#
#
#
#     MAPE of SVR  : 27.02
#
#
#
#     MAPE of SVR  : 32.44
#
#
#
#     MAPE of SVR  : 38.0
#
#
#
#     MAPE of SVR  : 45.05
#
#
#
#     MAPE of SVR  : 6.4
#
#
# 6.397694734780823
#
#     MAPE of SVR  : 9.53
#
#
#
#     MAPE of SVR  : 12.72
#
#
#
#     MAPE of SVR  : 17.65
#
#
#
#     MAPE of SVR  : 22.37
#
#
#
#     MAPE of SVR  : 27.02
#
#
#
#     MAPE of SVR  : 32.45
#
#
#
#     MAPE of SVR  : 38.01
#
#
#
#     MAPE of SVR  : 45.08
#
#
#
#     MAPE of SVR  : 6.39
#
#
# 6.39314087421819
#
#     MAPE of SVR  : 9.53
#
#
#
#     MAPE of SVR  : 12.73
#
#
#
#     MAPE of SVR  : 17.64
#
#
#
#     MAPE of SVR  : 22.37
#
#
#
#     MAPE of SVR  : 27.02
#
#
#
#     MAPE of SVR  : 32.45
#
#
#
#     MAPE of SVR  : 38.02
#
#
#
#     MAPE of SVR  : 45.1
#
#
#
#     MAPE of SVR  : 6.38
#
#
# 6.382598622163832
#
#     MAPE of SVR  : 9.53
#
#
#
#     MAPE of SVR  : 12.75
#
#
#
#     MAPE of SVR  : 17.64
#
#
#
#     MAPE of SVR  : 22.38
#
#
#
#     MAPE of SVR  : 27.02
#
#
#
#     MAPE of SVR  : 32.45
#
#
#
#     MAPE of SVR  : 38.03
#
#
#
#     MAPE of SVR  : 45.13
#
#
#
#     MAPE of SVR  : 6.37
#
#
# 6.373345425405945
#
#     MAPE of SVR  : 9.53
#
#
#
#     MAPE of SVR  : 12.76
#
#
#
#     MAPE of SVR  : 17.63
#
#
#
#     MAPE of SVR  : 22.39
#
#
#
#     MAPE of SVR  : 27.02
#
#
#
#     MAPE of SVR  : 32.46
#
#
#
#     MAPE of SVR  : 38.04
#
#
#
#     MAPE of SVR  : 45.16
#
#
#
#     MAPE of SVR  : 6.36
#
#
# 6.364185225199343
#
#     MAPE of SVR  : 9.52
#
#
#
#     MAPE of SVR  : 12.77
#
#
#
#     MAPE of SVR  : 17.63
#
#
#
#     MAPE of SVR  : 22.4
#
#
#
#     MAPE of SVR  : 27.03
#
#
#
#     MAPE of SVR  : 32.47
#
#
#
#     MAPE of SVR  : 38.05
#
#
#
#     MAPE of SVR  : 45.18
#
#
#
#     MAPE of SVR  : 6.36
#
#
# 6.356103218503176
#
#     MAPE of SVR  : 9.52
#
#
#
#     MAPE of SVR  : 12.79
#
#
#
#     MAPE of SVR  : 17.62
#
#
#
#     MAPE of SVR  : 22.4
#
#
#
#     MAPE of SVR  : 27.03
#
#
#
#     MAPE of SVR  : 32.47
#
#
#
#     MAPE of SVR  : 38.06
#
#
#
#     MAPE of SVR  : 45.21
#
#
#
#     MAPE of SVR  : 6.35
#
#
# 6.346369990920467
#
#     MAPE of SVR  : 9.52
#
#
#
#     MAPE of SVR  : 12.8
#
#
#
#     MAPE of SVR  : 17.62
#
#
#
#     MAPE of SVR  : 22.41
#
#
#
#     MAPE of SVR  : 27.03
#
#
#
#     MAPE of SVR  : 32.48
#
#
#
#     MAPE of SVR  : 38.07
#
#
#
#     MAPE of SVR  : 45.24
#
#
#
#     MAPE of SVR  : 6.34
#
#
# 6.338035302327624
#
#     MAPE of SVR  : 9.52
#
#
#
#     MAPE of SVR  : 12.81
#
#
#
#     MAPE of SVR  : 17.62
#
#
#
#     MAPE of SVR  : 22.42
#
#
#
#     MAPE of SVR  : 27.03
#
#
#
#     MAPE of SVR  : 32.48
#
#
#
#     MAPE of SVR  : 38.08
#
#
#
#     MAPE of SVR  : 45.26
#
#
#
#     MAPE of SVR  : 6.34
#
#
# 6.335331516942138
#
#     MAPE of SVR  : 9.52
#
#
#
#     MAPE of SVR  : 12.82
#
#
#
#     MAPE of SVR  : 17.61
#
#
#
#     MAPE of SVR  : 22.43
#
#
#
#     MAPE of SVR  : 27.04
#
#
#
#     MAPE of SVR  : 32.48
#
#
#
#     MAPE of SVR  : 38.09
#
#
#
#     MAPE of SVR  : 45.29
#
#
#
#     MAPE of SVR  : 6.33
#
#
# 6.33391630594625
#
#     MAPE of SVR  : 9.52
#
#
#
#     MAPE of SVR  : 12.84
#
#
#
#     MAPE of SVR  : 17.61
#
#
#
#     MAPE of SVR  : 22.43
#
#
#
#     MAPE of SVR  : 27.04
#
#
#
#     MAPE of SVR  : 32.49
#
#
#
#     MAPE of SVR  : 38.1
#
#
#
#     MAPE of SVR  : 45.32
#
#
#
#     MAPE of SVR  : 6.33
#
#
# 6.333340370506445
#
#     MAPE of SVR  : 9.52
#
#
#
#     MAPE of SVR  : 12.86
#
#
#
#     MAPE of SVR  : 17.6
#
#
#
#     MAPE of SVR  : 22.44
#
#
#
#     MAPE of SVR  : 27.04
#
#
#
#     MAPE of SVR  : 32.49
#
#
#
#     MAPE of SVR  : 38.12
#
#
#
#     MAPE of SVR  : 45.35
#
#
#
#     MAPE of SVR  : 6.33
#
#
# 6.3329816001895045
#
#     MAPE of SVR  : 9.52
#
#
#
#     MAPE of SVR  : 12.87
#
#
#
#     MAPE of SVR  : 17.6
#
#
#
#     MAPE of SVR  : 22.45
#
#
#
#     MAPE of SVR  : 27.05
#
#
#
#     MAPE of SVR  : 32.5
#
#
#
#     MAPE of SVR  : 38.13
#
#
#
#     MAPE of SVR  : 45.38
#
#
#
#     MAPE of SVR  : 6.33
#
#
#
#     MAPE of SVR  : 9.52
#
#
#
#     MAPE of SVR  : 12.87
#
#
#
#     MAPE of SVR  : 17.61
#
#
#
#     MAPE of SVR  : 22.46
#
#
#
#     MAPE of SVR  : 27.05
#
#
#
#     MAPE of SVR  : 32.5
#
#
#
#     MAPE of SVR  : 38.14
#
#
#
#     MAPE of SVR  : 45.41
#
#
#
#     MAPE of SVR  : 6.33
#
#
# 6.331481492472167
#
#     MAPE of SVR  : 9.52
#
#
#
#     MAPE of SVR  : 12.88
#
#
#
#     MAPE of SVR  : 17.62
#
#
#
#     MAPE of SVR  : 22.47
#
#
#
#     MAPE of SVR  : 27.05
#
#
#
#     MAPE of SVR  : 32.5
#
#
#
#     MAPE of SVR  : 38.15
#
#
#
#     MAPE of SVR  : 45.44
#
#
#
#     MAPE of SVR  : 6.33
#
#
# 6.326755754666519
#
#     MAPE of SVR  : 9.52
#
#
#
#     MAPE of SVR  : 12.87
#
#
#
#     MAPE of SVR  : 17.63
#
#
#
#     MAPE of SVR  : 22.47
#
#
#
#     MAPE of SVR  : 27.06
#
#
#
#     MAPE of SVR  : 32.51
#
#
#
#     MAPE of SVR  : 38.17
#
#
#
#     MAPE of SVR  : 45.47
#
#
#
#     MAPE of SVR  : 6.32
#
#
# 6.322341148625297
#
#     MAPE of SVR  : 9.52
#
#
#
#     MAPE of SVR  : 12.87
#
#
#
#     MAPE of SVR  : 17.64
#
#
#
#     MAPE of SVR  : 22.48
#
#
#
#     MAPE of SVR  : 27.06
#
#
#
#     MAPE of SVR  : 32.51
#
#
#
#     MAPE of SVR  : 38.18
#
#
#
#     MAPE of SVR  : 45.5
#
#
#
#     MAPE of SVR  : 6.32
#
#
# 6.31883361113592
#
#     MAPE of SVR  : 9.52
#
#
#
#     MAPE of SVR  : 12.86
#
#
#
#     MAPE of SVR  : 17.65
#
#
#
#     MAPE of SVR  : 22.49
#
#
#
#     MAPE of SVR  : 27.06
#
#
#
#     MAPE of SVR  : 32.52
#
#
#
#     MAPE of SVR  : 38.19
#
#
#
#     MAPE of SVR  : 45.53
#
#
#
#     MAPE of SVR  : 6.31
#
#
# 6.314888735117013
#
#     MAPE of SVR  : 9.52
#
#
#
#     MAPE of SVR  : 12.85
#
#
#
#     MAPE of SVR  : 17.64
#
#
#
#     MAPE of SVR  : 22.5
#
#
#
#     MAPE of SVR  : 27.06
#
#
#
#     MAPE of SVR  : 32.53
#
#
#
#     MAPE of SVR  : 38.21
#
#
#
#     MAPE of SVR  : 45.57
#
#
#
#     MAPE of SVR  : 6.31
#
#
# 6.311203106884618
#
#     MAPE of SVR  : 9.51
#
#
#
#     MAPE of SVR  : 12.84
#
#
#
#     MAPE of SVR  : 17.64
#
#
#
#     MAPE of SVR  : 22.51
#
#
#
#     MAPE of SVR  : 27.07
#
#
#
#     MAPE of SVR  : 32.53
#
#
#
#     MAPE of SVR  : 38.22
#
#
#
#     MAPE of SVR  : 45.6
#
#
#
#     MAPE of SVR  : 6.31
#
#
# 6.307065915778011
#
#     MAPE of SVR  : 9.51
#
#
#
#     MAPE of SVR  : 12.83
#
#
#
#     MAPE of SVR  : 17.63
#
#
#
#     MAPE of SVR  : 22.51
#
#
#
#     MAPE of SVR  : 27.07
#
#
#
#     MAPE of SVR  : 32.54
#
#
#
#     MAPE of SVR  : 38.24
#
#
#
#     MAPE of SVR  : 45.63
#
#
#
#     MAPE of SVR  : 6.3
#
#
# 6.301579990218218
#
#     MAPE of SVR  : 9.51
#
#
#
#     MAPE of SVR  : 12.83
#
#
#
#     MAPE of SVR  : 17.61
#
#
#
#     MAPE of SVR  : 22.51
#
#
#
#     MAPE of SVR  : 27.07
#
#
#
#     MAPE of SVR  : 32.54
#
#
#
#     MAPE of SVR  : 38.26
#
#
#
#     MAPE of SVR  : 45.67
#
#
#
#     MAPE of SVR  : 6.3
#
#
# 6.29735085876436
#
#     MAPE of SVR  : 9.51
#
#
#
#     MAPE of SVR  : 12.82
#
#
#
#     MAPE of SVR  : 17.61
#
#
#
#     MAPE of SVR  : 22.5
#
#
#
#     MAPE of SVR  : 27.07
#
#
#
#     MAPE of SVR  : 32.55
#
#
#
#     MAPE of SVR  : 38.28
#
#
#
#     MAPE of SVR  : 45.7
#
#
#
#     MAPE of SVR  : 6.29
#
#
# 6.292644654625503
#
#     MAPE of SVR  : 9.5
#
#
#
#     MAPE of SVR  : 12.82
#
#
#
#     MAPE of SVR  : 17.6
#
#
#
#     MAPE of SVR  : 22.5
#
#
#
#     MAPE of SVR  : 27.08
#
#
#
#     MAPE of SVR  : 32.56
#
#
#
#     MAPE of SVR  : 38.3
#
#
#
#     MAPE of SVR  : 45.73
#
#
#
#     MAPE of SVR  : 6.29
#
#
# 6.288388902683188
#
#     MAPE of SVR  : 9.5
#
#
#
#     MAPE of SVR  : 12.81
#
#
#
#     MAPE of SVR  : 17.59
#
#
#
#     MAPE of SVR  : 22.49
#
#
#
#     MAPE of SVR  : 27.08
#
#
#
#     MAPE of SVR  : 32.56
#
#
#
#     MAPE of SVR  : 38.32
#
#
#
#     MAPE of SVR  : 45.77
#
#
#
#     MAPE of SVR  : 6.28
#
#
# 6.282260994572209
#
#     MAPE of SVR  : 9.5
#
#
#
#     MAPE of SVR  : 12.81
#     MAPE of SVR  : 17.59
#
#
#
#     MAPE of SVR  : 22.49
#
#
#
#     MAPE of SVR  : 27.08
#
#
#
#     MAPE of SVR  : 32.57
#
#
#
#     MAPE of SVR  : 38.33
#
#
#
#     MAPE of SVR  : 45.79
#
#
#
#     MAPE of SVR  : 6.28
#
#
# 6.278217088803002
#
#     MAPE of SVR  : 9.5
#
#
#
#     MAPE of SVR  : 12.8
#
#
#
#     MAPE of SVR  : 17.58
#
#
#
#     MAPE of SVR  : 22.48
#
#
#
#     MAPE of SVR  : 27.09
#
#
#
#     MAPE of SVR  : 32.58
#
#
#
#     MAPE of SVR  : 38.34
#
#
#
#     MAPE of SVR  : 45.78
#
#
#
#     MAPE of SVR  : 6.27
#
#
# 6.27437636532619
#
#     MAPE of SVR  : 9.5
#
#
#
#     MAPE of SVR  : 12.8
#
#
#
#     MAPE of SVR  : 17.58
#
#
#
#     MAPE of SVR  : 22.47
#
#
#
#     MAPE of SVR  : 27.09
#
#
#
#     MAPE of SVR  : 32.58
#
#
#
#     MAPE of SVR  : 38.34
#
#
#
#     MAPE of SVR  : 45.78
#
#
#
#     MAPE of SVR  : 6.27
#
#
# 6.271612785862186
#
#     MAPE of SVR  : 9.5
#
#
#
#     MAPE of SVR  : 12.79
#
#
#
#     MAPE of SVR  : 17.58
#
#
#
#     MAPE of SVR  : 22.47
#
#
#
#     MAPE of SVR  : 27.09
#
#
#
#     MAPE of SVR  : 32.59
#
#
#
#     MAPE of SVR  : 38.34
#
#
#
#     MAPE of SVR  : 45.78
#
#
#
#     MAPE of SVR  : 6.27
#
#
# 6.269455024778754
#
#     MAPE of SVR  : 9.5
#
#
#
#     MAPE of SVR  : 12.79
#
#
#
#     MAPE of SVR  : 17.57
#
#
#
#     MAPE of SVR  : 22.46
#
#
#
#     MAPE of SVR  : 27.1
#
#
#
#     MAPE of SVR  : 32.59
#
#
#
#     MAPE of SVR  : 38.34
#
#
#
#     MAPE of SVR  : 45.77
#
#
#
#     MAPE of SVR  : 6.27
#
#
# 6.2678665921092005
#
#     MAPE of SVR  : 9.5
#
#
#
#     MAPE of SVR  : 12.78
#
#
#
#     MAPE of SVR  : 17.58
#
#
#
#     MAPE of SVR  : 22.46
#
#
#
#     MAPE of SVR  : 27.1
#
#
#
#     MAPE of SVR  : 32.59
#
#
#
#     MAPE of SVR  : 38.34
#
#
#
#     MAPE of SVR  : 45.77
#
#
#
#     MAPE of SVR  : 6.27
#
#
# 6.265762469116558
#
#     MAPE of SVR  : 9.49
#
#
#
#     MAPE of SVR  : 12.78
#
#
#
#     MAPE of SVR  : 17.58
#
#
#
#     MAPE of SVR  : 22.45
#
#
#
#     MAPE of SVR  : 27.1
#
#
#
#     MAPE of SVR  : 32.59
#
#
#
#     MAPE of SVR  : 38.35
#
#
#
#     MAPE of SVR  : 45.77
#
#
#
#     MAPE of SVR  : 6.26
#
#
# 6.262857802891744
#
#     MAPE of SVR  : 9.48
#
#
#
#     MAPE of SVR  : 12.78
#
#
#
#     MAPE of SVR  : 17.58
#
#
#
#     MAPE of SVR  : 22.45
#
#
#
#     MAPE of SVR  : 27.1
#
#
#
#     MAPE of SVR  : 32.59
#
#
#
#     MAPE of SVR  : 38.35
#
#
#
#     MAPE of SVR  : 45.77
#
#
#
#     MAPE of SVR  : 6.25
#
#
# 6.254995557775689
#
#     MAPE of SVR  : 9.47
#
#
#
#     MAPE of SVR  : 12.77
#
#
#
#     MAPE of SVR  : 17.58
#
#
#
#     MAPE of SVR  : 22.44
#
#
#
#     MAPE of SVR  : 27.11
#
#
#
#     MAPE of SVR  : 32.59
#
#
#
#     MAPE of SVR  : 38.35
#
#
#
#     MAPE of SVR  : 45.77
#
#
#
#     MAPE of SVR  : 6.25
#
#
# 6.249306841555245
#
#     MAPE of SVR  : 9.47
#
#
#
#     MAPE of SVR  : 12.76
#
#
#
#     MAPE of SVR  : 17.57
#
#
#
#     MAPE of SVR  : 22.44
#
#
#
#     MAPE of SVR  : 27.11
#
#
#
#     MAPE of SVR  : 32.6
#
#
#
#     MAPE of SVR  : 38.35
#
#
#
#     MAPE of SVR  : 45.77
#
#
#
#     MAPE of SVR  : 6.25
#
#
# 6.245809080232666
#
#     MAPE of SVR  : 9.46
#
#
#
#     MAPE of SVR  : 12.75
#
#
#
#     MAPE of SVR  : 17.57
#
#
#
#     MAPE of SVR  : 22.44
#
#
#
#     MAPE of SVR  : 27.11
#
#
#
#     MAPE of SVR  : 32.6
#
#
#
#     MAPE of SVR  : 38.35
#
#
#
#     MAPE of SVR  : 45.77
#
#
#
#     MAPE of SVR  : 6.24
#
#
# 6.244426381943088
#
#     MAPE of SVR  : 9.46
#
#
#
#     MAPE of SVR  : 12.74
#
#
#
#     MAPE of SVR  : 17.57
#
#
#
#     MAPE of SVR  : 22.44
#
#
#
#     MAPE of SVR  : 27.12
#
#
#
#     MAPE of SVR  : 32.6
#
#
#
#     MAPE of SVR  : 38.35
#
#
#
#     MAPE of SVR  : 45.77
#
#
#
#     MAPE of SVR  : 6.24
#
#
# 6.243587988483996
#
#     MAPE of SVR  : 9.46
#
#
#
#     MAPE of SVR  : 12.74
#
#
#
#     MAPE of SVR  : 17.57
#
#
#
#     MAPE of SVR  : 22.44
#
#
#
#     MAPE of SVR  : 27.12
#
#
#
#     MAPE of SVR  : 32.6
#
#
#
#     MAPE of SVR  : 38.36
#
#
#
#     MAPE of SVR  : 45.77
#
#
#
#     MAPE of SVR  : 6.24
#
#
# 6.24200194437284
#
#     MAPE of SVR  : 9.46
#
#
#
#     MAPE of SVR  : 12.73
#
#
#
#     MAPE of SVR  : 17.57
#
#
#
#     MAPE of SVR  : 22.44
#
#
#
#     MAPE of SVR  : 27.12
#
#
#
#     MAPE of SVR  : 32.6
#
#
#
#     MAPE of SVR  : 38.36
#
#
#
#     MAPE of SVR  : 45.77
#
#
#
#     MAPE of SVR  : 6.24
#
#
# 6.240744656019351
#
#     MAPE of SVR  : 9.45
#
#
#
#     MAPE of SVR  : 12.72
#
#
#
#     MAPE of SVR  : 17.56
#
#
#
#     MAPE of SVR  : 22.43
#
#
#
#     MAPE of SVR  : 27.13
#
#
#
#     MAPE of SVR  : 32.6
#
#
#
#     MAPE of SVR  : 38.36
#
#
#
#     MAPE of SVR  : 45.77
#
#
#
#     MAPE of SVR  : 6.24
#
#
# 6.239344541532766
#
#     MAPE of SVR  : 9.45
#
#
#
#     MAPE of SVR  : 12.72
#
#
#
#     MAPE of SVR  : 17.56
#
#
#
#     MAPE of SVR  : 22.44
#
#
#
#     MAPE of SVR  : 27.13
#
#
#
#     MAPE of SVR  : 32.6
#
#
#
#     MAPE of SVR  : 38.37
#
#
#
#     MAPE of SVR  : 45.76
#
#
#
#     MAPE of SVR  : 6.24
#
#
# 6.236658606390586
#
#     MAPE of SVR  : 9.45
#
#
#
#     MAPE of SVR  : 12.71
#
#
#
#     MAPE of SVR  : 17.56
#
#
#
#     MAPE of SVR  : 22.44
#
#
#
#     MAPE of SVR  : 27.13
#
#
#
#     MAPE of SVR  : 32.6
#
#
#
#     MAPE of SVR  : 38.37
#
#
#
#     MAPE of SVR  : 45.76
#
#
#
#     MAPE of SVR  : 6.23
#
#
# 6.2323178228338625
#
#     MAPE of SVR  : 9.45
#
#
#
#     MAPE of SVR  : 12.7
#
#
#
#     MAPE of SVR  : 17.56
#
#
#
#     MAPE of SVR  : 22.43
#
#
#
#     MAPE of SVR  : 27.14
#
#
#
#     MAPE of SVR  : 32.61
#
#
#
#     MAPE of SVR  : 38.37
#
#
#
#     MAPE of SVR  : 45.76
#
#
#
#     MAPE of SVR  : 6.23
#
#
# 6.228444605973793
#
#     MAPE of SVR  : 9.45
#
#
#
#     MAPE of SVR  : 12.69
#
#
#
#     MAPE of SVR  : 17.55
#
#
#
#     MAPE of SVR  : 22.44
#
#
#
#     MAPE of SVR  : 27.14
#
#
#
#     MAPE of SVR  : 32.6
#
#
#
#     MAPE of SVR  : 38.38
#
#
#
#     MAPE of SVR  : 45.76
#
#
#
#     MAPE of SVR  : 6.23
#
#
# 6.226805891942766
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.69
#
#
#
#     MAPE of SVR  : 17.55
#
#
#
#     MAPE of SVR  : 22.44
#
#
#
#     MAPE of SVR  : 27.15
#
#
#
#     MAPE of SVR  : 32.6
#
#
#
#     MAPE of SVR  : 38.38
#
#
#
#     MAPE of SVR  : 45.76
#
#
#
#     MAPE of SVR  : 6.22
#
#
# 6.224322720225359
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.68
#
#
#
#     MAPE of SVR  : 17.55
#
#
#
#     MAPE of SVR  : 22.44
#
#
#
#     MAPE of SVR  : 27.15
#
#
#
#     MAPE of SVR  : 32.61
#
#
#
#     MAPE of SVR  : 38.39
#
#
#
#     MAPE of SVR  : 45.76
#
#
#
#     MAPE of SVR  : 6.22
#
#
# 6.221734719629934
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.68
#
#
#
#     MAPE of SVR  : 17.55
#
#
#
#     MAPE of SVR  : 22.44
#
#
#
#     MAPE of SVR  : 27.15
#
#
#
#     MAPE of SVR  : 32.61
#
#
#
#     MAPE of SVR  : 38.39
#
#
#
#     MAPE of SVR  : 45.76
#
#
#
#     MAPE of SVR  : 6.22
#
#
# 6.218559531184914
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.67
#
#
#
#     MAPE of SVR  : 17.54
#
#
#
#     MAPE of SVR  : 22.45
#
#
#
#     MAPE of SVR  : 27.16
#
#
#
#     MAPE of SVR  : 32.61
#
#
#
#     MAPE of SVR  : 38.4
#
#
#
#     MAPE of SVR  : 45.76
#
#
#
#     MAPE of SVR  : 6.21
#
#
# 6.214894733348823
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.66
#
#
#
#     MAPE of SVR  : 17.54
#
#
#
#     MAPE of SVR  : 22.45
#
#
#
#     MAPE of SVR  : 27.16
#
#
#
#     MAPE of SVR  : 32.61
#
#
#
#     MAPE of SVR  : 38.4
#
#
#
#     MAPE of SVR  : 45.76
#
#
#
#     MAPE of SVR  : 6.21
#
#
# 6.211328218900381
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.66
#
#
#
#     MAPE of SVR  : 17.54
#
#
#
#     MAPE of SVR  : 22.45
#
#
#
#     MAPE of SVR  : 27.17
#
#
#
#     MAPE of SVR  : 32.62
#
#
#
#     MAPE of SVR  : 38.41
#
#
#
#     MAPE of SVR  : 45.75
#
#
#
#     MAPE of SVR  : 6.21
#
#
# 6.207925466476558
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.54
#
#
#
#     MAPE of SVR  : 22.45
#
#
#
#     MAPE of SVR  : 27.17
#
#
#
#     MAPE of SVR  : 32.63
#
#
#
#     MAPE of SVR  : 38.41
#
#
#
#     MAPE of SVR  : 45.76
#
#
#
#     MAPE of SVR  : 6.2
#
#
# 6.2049408768699
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.54
#
#
#
#     MAPE of SVR  : 22.45
#
#
#
#     MAPE of SVR  : 27.17
#
#
#
#     MAPE of SVR  : 32.63
#
#
#
#     MAPE of SVR  : 38.41
#
#
#
#     MAPE of SVR  : 45.75
#
#
#
#     MAPE of SVR  : 6.2
#
#
# 6.202014359755766
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.54
#
#
#
#     MAPE of SVR  : 22.45
#
#
#
#     MAPE of SVR  : 27.18
#
#
#
#     MAPE of SVR  : 32.64
#
#
#
#     MAPE of SVR  : 38.42
#
#
#
#     MAPE of SVR  : 45.75
#
#
#
#     MAPE of SVR  : 6.2
#
#
# 6.197185092059691
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.55
#
#
#
#     MAPE of SVR  : 22.46
#     MAPE of SVR  : 27.18
#
#
#
#     MAPE of SVR  : 32.65
#
#
#
#     MAPE of SVR  : 38.42
#
#
#
#     MAPE of SVR  : 45.75
#
#
#
#     MAPE of SVR  : 6.19
#
#
# 6.19280020079143
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.55
#
#
#
#     MAPE of SVR  : 22.46
#
#
#
#     MAPE of SVR  : 27.19
#
#
#
#     MAPE of SVR  : 32.66
#
#
#
#     MAPE of SVR  : 38.43
#
#
#
#     MAPE of SVR  : 45.75
#
#
#
#     MAPE of SVR  : 6.19
#
#
# 6.188019796384128
#
#     MAPE of SVR  : 9.43
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.55
#
#
#
#     MAPE of SVR  : 22.46
#
#
#
#     MAPE of SVR  : 27.19
#
#
#
#     MAPE of SVR  : 32.67
#
#
#
#     MAPE of SVR  : 38.43
#
#
#
#     MAPE of SVR  : 45.74
#
#
#
#     MAPE of SVR  : 6.18
#
#
# 6.182396543362628
#
#     MAPE of SVR  : 9.43
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.56
#
#
#
#     MAPE of SVR  : 22.46
#
#
#
#     MAPE of SVR  : 27.19
#
#
#
#     MAPE of SVR  : 32.68
#
#
#
#     MAPE of SVR  : 38.44
#
#
#
#     MAPE of SVR  : 45.74
#
#
#
#     MAPE of SVR  : 6.18
#
#
# 6.177192519275899
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.56
#
#
#
#     MAPE of SVR  : 22.46
#
#
#
#     MAPE of SVR  : 27.2
#
#
#
#     MAPE of SVR  : 32.68
#
#
#
#     MAPE of SVR  : 38.44
#
#
#
#     MAPE of SVR  : 45.74
#
#
#
#     MAPE of SVR  : 6.17
#
#
# 6.172273002943099
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.57
#
#
#
#     MAPE of SVR  : 22.46
#
#
#
#     MAPE of SVR  : 27.2
#
#
#
#     MAPE of SVR  : 32.68
#
#
#
#     MAPE of SVR  : 38.44
#
#
#
#     MAPE of SVR  : 45.74
#
#
#
#     MAPE of SVR  : 6.17
#
#
# 6.167344318916209
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.58
#
#
#
#     MAPE of SVR  : 22.47
#
#
#
#     MAPE of SVR  : 27.21
#
#
#
#     MAPE of SVR  : 32.69
#
#
#
#     MAPE of SVR  : 38.44
#
#
#
#     MAPE of SVR  : 45.73
#
#
#
#     MAPE of SVR  : 6.16
#
#
# 6.161763763166677
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.58
#
#
#
#     MAPE of SVR  : 22.47
#
#
#
#     MAPE of SVR  : 27.21
#
#
#
#     MAPE of SVR  : 32.69
#
#
#
#     MAPE of SVR  : 38.44
#
#
#
#     MAPE of SVR  : 45.73
#
#
#
#     MAPE of SVR  : 6.16
#
#
# 6.158575855642881
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.59
#
#
#
#     MAPE of SVR  : 22.47
#
#
#
#     MAPE of SVR  : 27.21
#
#
#
#     MAPE of SVR  : 32.69
#
#
#
#     MAPE of SVR  : 38.44
#
#
#
#     MAPE of SVR  : 45.73
#
#
#
#     MAPE of SVR  : 6.16
#
#
# 6.1573914980752
#
#     MAPE of SVR  : 9.44
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.59
#
#
#
#     MAPE of SVR  : 22.47
#
#
#
#     MAPE of SVR  : 27.21
#
#
#
#     MAPE of SVR  : 32.69
#
#
#
#     MAPE of SVR  : 38.44
#
#
#
#     MAPE of SVR  : 45.73
#
#
#
#     MAPE of SVR  : 6.16
#
#
# 6.156756897573881
#
#     MAPE of SVR  : 9.43
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.6
#
#
#
#     MAPE of SVR  : 22.48
#
#
#
#     MAPE of SVR  : 27.21
#
#
#
#     MAPE of SVR  : 32.7
#
#
#
#     MAPE of SVR  : 38.44
#
#
#
#     MAPE of SVR  : 45.74
#
#
#
#     MAPE of SVR  : 6.16
#
#
# 6.156402995019115
#
#     MAPE of SVR  : 9.43
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.6
#
#
#
#     MAPE of SVR  : 22.48
#
#
#
#     MAPE of SVR  : 27.21
#
#
#
#     MAPE of SVR  : 32.7
#
#
#
#     MAPE of SVR  : 38.44
#
#
#
#     MAPE of SVR  : 45.75
#
#
#
#     MAPE of SVR  : 6.16
#
#
# 6.156024036904428
#
#     MAPE of SVR  : 9.43
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.61
#
#
#
#     MAPE of SVR  : 22.48
#
#
#
#     MAPE of SVR  : 27.21
#
#
#
#     MAPE of SVR  : 32.7
#
#
#
#     MAPE of SVR  : 38.44
#
#
#
#     MAPE of SVR  : 45.76
#
#
#
#     MAPE of SVR  : 6.15
#
#
# 6.154762067704224
#
#     MAPE of SVR  : 9.43
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.61
#
#
#
#     MAPE of SVR  : 22.48
#
#
#
#     MAPE of SVR  : 27.21
#
#
#
#     MAPE of SVR  : 32.7
#
#
#
#     MAPE of SVR  : 38.44
#
#
#
#     MAPE of SVR  : 45.77
#
#
#
#     MAPE of SVR  : 6.16
#
#
#
#     MAPE of SVR  : 9.43
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.62
#
#
#
#     MAPE of SVR  : 22.48
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.71
#
#
#
#     MAPE of SVR  : 38.45
#
#
#
#     MAPE of SVR  : 45.79
#
#
#
#     MAPE of SVR  : 6.15
#
#
#
#     MAPE of SVR  : 9.43
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.62
#
#
#
#     MAPE of SVR  : 22.48
#
#
#
#     MAPE of SVR  : 27.21
#
#
#
#     MAPE of SVR  : 32.71
#
#
#
#     MAPE of SVR  : 38.45
#
#
#
#     MAPE of SVR  : 45.8
#
#
#
#     MAPE of SVR  : 6.16
#
#
#
#     MAPE of SVR  : 9.43
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.63
#
#
#
#     MAPE of SVR  : 22.49
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.71
#
#
#
#     MAPE of SVR  : 38.44
#
#
#
#     MAPE of SVR  : 45.79
#
#
#
#     MAPE of SVR  : 6.15
#
#
#
#     MAPE of SVR  : 9.43
#
#
#
#     MAPE of SVR  : 12.66
#
#
#
#     MAPE of SVR  : 17.63
#
#
#
#     MAPE of SVR  : 22.49
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.7
#
#
#
#     MAPE of SVR  : 38.44
#
#
#
#     MAPE of SVR  : 45.77
#
#
#
#     MAPE of SVR  : 6.15
#
#
# 6.154501100144219
#
#     MAPE of SVR  : 9.43
#
#
#
#     MAPE of SVR  : 12.67
#
#
#
#     MAPE of SVR  : 17.64
#
#
#
#     MAPE of SVR  : 22.49
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.7
#
#
#
#     MAPE of SVR  : 38.43
#
#
#
#     MAPE of SVR  : 45.74
#
#
#
#     MAPE of SVR  : 6.15
#
#
# 6.1524088337385345
#
#     MAPE of SVR  : 9.43
#
#
#
#     MAPE of SVR  : 12.67
#
#
#
#     MAPE of SVR  : 17.64
#
#
#
#     MAPE of SVR  : 22.49
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.7
#
#
#
#     MAPE of SVR  : 38.42
#
#
#
#     MAPE of SVR  : 45.72
#
#
#
#     MAPE of SVR  : 6.14
#
#
# 6.142751436042671
#
#     MAPE of SVR  : 9.43
#
#
#
#     MAPE of SVR  : 12.68
#
#
#
#     MAPE of SVR  : 17.65
#
#
#
#     MAPE of SVR  : 22.49
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.69
#
#
#
#     MAPE of SVR  : 38.41
#
#
#
#     MAPE of SVR  : 45.7
#
#
#
#     MAPE of SVR  : 6.13
#
#
# 6.132467951468521
#
#     MAPE of SVR  : 9.43
#
#
#
#     MAPE of SVR  : 12.68
#
#
#
#     MAPE of SVR  : 17.65
#
#
#
#     MAPE of SVR  : 22.5
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.69
#
#
#
#     MAPE of SVR  : 38.41
#
#
#
#     MAPE of SVR  : 45.68
#
#
#
#     MAPE of SVR  : 6.12
#
#
# 6.122970594603496
#
#     MAPE of SVR  : 9.43
#
#
#
#     MAPE of SVR  : 12.69
#
#
#
#     MAPE of SVR  : 17.66
#
#
#
#     MAPE of SVR  : 22.5
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.69
#
#
#
#     MAPE of SVR  : 38.4
#
#
#
#     MAPE of SVR  : 45.65
#
#
#
#     MAPE of SVR  : 6.12
#
#
# 6.115213146422734
#
#     MAPE of SVR  : 9.43
#
#
#
#     MAPE of SVR  : 12.69
#
#
#
#     MAPE of SVR  : 17.66
#
#
#
#     MAPE of SVR  : 22.5
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.69
#
#
#
#     MAPE of SVR  : 38.39
#
#
#
#     MAPE of SVR  : 45.63
#
#
#
#     MAPE of SVR  : 6.11
#
#
# 6.107576731590415
#
#     MAPE of SVR  : 9.42
#
#
#
#     MAPE of SVR  : 12.68
#
#
#
#     MAPE of SVR  : 17.67
#
#
#
#     MAPE of SVR  : 22.5
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.68
#
#
#
#     MAPE of SVR  : 38.39
#
#
#
#     MAPE of SVR  : 45.6
#
#
#
#     MAPE of SVR  : 6.11
#
#
#
#     MAPE of SVR  : 9.42
#
#
#
#     MAPE of SVR  : 12.68
#
#
#
#     MAPE of SVR  : 17.68
#
#
#
#     MAPE of SVR  : 22.5
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.68
#
#
#
#     MAPE of SVR  : 38.39
#
#
#
#     MAPE of SVR  : 45.58
#
#
#
#     MAPE of SVR  : 6.11
#
#
#
#     MAPE of SVR  : 9.42
#
#
#
#     MAPE of SVR  : 12.68
#
#
#
#     MAPE of SVR  : 17.69
#
#
#
#     MAPE of SVR  : 22.5
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.68
#
#
#
#     MAPE of SVR  : 38.38
#
#
#
#     MAPE of SVR  : 45.55
#
#
#
#     MAPE of SVR  : 6.11
#
#
#
#     MAPE of SVR  : 9.42
#
#
#
#     MAPE of SVR  : 12.68
#
#
#
#     MAPE of SVR  : 17.7
#
#
#
#     MAPE of SVR  : 22.51
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.67
#
#
#
#     MAPE of SVR  : 38.38
#
#
#
#     MAPE of SVR  : 45.53
#
#
#
#     MAPE of SVR  : 6.11
#
#
#
#     MAPE of SVR  : 9.42
#
#
#
#     MAPE of SVR  : 12.67
#
#
#
#     MAPE of SVR  : 17.71
#
#
#
#     MAPE of SVR  : 22.51
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.67
#
#
#
#     MAPE of SVR  : 38.38
#
#
#
#     MAPE of SVR  : 45.5
#
#
#
#     MAPE of SVR  : 6.11
#
#
#
#     MAPE of SVR  : 9.41
#
#
#
#     MAPE of SVR  : 12.67
#
#
#
#     MAPE of SVR  : 17.72
#
#
#
#     MAPE of SVR  : 22.51
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.67
#
#
#
#     MAPE of SVR  : 38.37
#
#
#
#     MAPE of SVR  : 45.49
#
#
#
#     MAPE of SVR  : 6.11
#
#
#
#     MAPE of SVR  : 9.41
#     MAPE of SVR  : 12.67
#
#
#
#     MAPE of SVR  : 17.73
#
#
#
#     MAPE of SVR  : 22.51
#
#
#
#     MAPE of SVR  : 27.21
#
#
#
#     MAPE of SVR  : 32.67
#
#
#
#     MAPE of SVR  : 38.37
#
#
#
#     MAPE of SVR  : 45.49
#
#
#
#     MAPE of SVR  : 6.11
#
#
# 6.105897586944638
#
#     MAPE of SVR  : 9.41
#
#
#
#     MAPE of SVR  : 12.67
#
#
#
#     MAPE of SVR  : 17.74
#
#
#
#     MAPE of SVR  : 22.51
#
#
#
#     MAPE of SVR  : 27.21
#
#
#
#     MAPE of SVR  : 32.66
#
#
#
#     MAPE of SVR  : 38.37
#
#
#
#     MAPE of SVR  : 45.49
#
#
#
#     MAPE of SVR  : 6.1
#
#
# 6.1031751980839655
#
#     MAPE of SVR  : 9.41
#
#
#
#     MAPE of SVR  : 12.67
#
#
#
#     MAPE of SVR  : 17.75
#
#
#
#     MAPE of SVR  : 22.52
#
#
#
#     MAPE of SVR  : 27.2
#
#
#
#     MAPE of SVR  : 32.66
#
#
#
#     MAPE of SVR  : 38.36
#
#
#
#     MAPE of SVR  : 45.48
#
#
#
#     MAPE of SVR  : 6.1
#
#
# 6.101054276583464
#
#     MAPE of SVR  : 9.4
#
#
#
#     MAPE of SVR  : 12.67
#
#
#
#     MAPE of SVR  : 17.76
#
#
#
#     MAPE of SVR  : 22.52
#
#
#
#     MAPE of SVR  : 27.19
#
#
#
#     MAPE of SVR  : 32.66
#
#
#
#     MAPE of SVR  : 38.36
#
#
#
#     MAPE of SVR  : 45.48
#
#
#
#     MAPE of SVR  : 6.1
#
#
# 6.098522044258052
#
#     MAPE of SVR  : 9.4
#
#
#
#     MAPE of SVR  : 12.67
#
#
#
#     MAPE of SVR  : 17.77
#
#
#
#     MAPE of SVR  : 22.52
#
#
#
#     MAPE of SVR  : 27.19
#
#
#
#     MAPE of SVR  : 32.66
#
#
#
#     MAPE of SVR  : 38.36
#
#
#
#     MAPE of SVR  : 45.48
#
#
#
#     MAPE of SVR  : 6.1
#
#
# 6.096832654735348
#
#     MAPE of SVR  : 9.4
#
#
#
#     MAPE of SVR  : 12.67
#
#
#
#     MAPE of SVR  : 17.77
#
#
#
#     MAPE of SVR  : 22.52
#
#
#
#     MAPE of SVR  : 27.18
#
#
#
#     MAPE of SVR  : 32.65
#
#
#
#     MAPE of SVR  : 38.35
#
#
#
#     MAPE of SVR  : 45.47
#
#
#
#     MAPE of SVR  : 6.1
#
#
# 6.0951447486494
#
#     MAPE of SVR  : 9.4
#
#
#
#     MAPE of SVR  : 12.66
#
#
#
#     MAPE of SVR  : 17.78
#
#
#
#     MAPE of SVR  : 22.52
#
#
#
#     MAPE of SVR  : 27.18
#
#
#
#     MAPE of SVR  : 32.65
#
#
#
#     MAPE of SVR  : 38.35
#
#
#
#     MAPE of SVR  : 45.47
#
#
#
#     MAPE of SVR  : 6.09
#
#
# 6.093271668262336
#
#     MAPE of SVR  : 9.4
#
#
#
#     MAPE of SVR  : 12.66
#
#
#
#     MAPE of SVR  : 17.8
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.18
#
#
#
#     MAPE of SVR  : 32.65
#
#
#
#     MAPE of SVR  : 38.35
#
#
#
#     MAPE of SVR  : 45.47
#
#
#
#     MAPE of SVR  : 6.09
#
#
# 6.0924611758941385
#
#     MAPE of SVR  : 9.39
#
#
#
#     MAPE of SVR  : 12.66
#
#
#
#     MAPE of SVR  : 17.81
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.17
#
#
#
#     MAPE of SVR  : 32.64
#
#
#
#     MAPE of SVR  : 38.34
#
#
#
#     MAPE of SVR  : 45.46
#
#
#
#     MAPE of SVR  : 6.09
#
#
# 6.08971794285567
#
#     MAPE of SVR  : 9.39
#
#
#
#     MAPE of SVR  : 12.66
#
#
#
#     MAPE of SVR  : 17.82
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.17
#
#
#
#     MAPE of SVR  : 32.64
#
#
#
#     MAPE of SVR  : 38.34
#
#
#
#     MAPE of SVR  : 45.46
#
#
#
#     MAPE of SVR  : 6.09
#
#
# 6.0880729378506695
#
#     MAPE of SVR  : 9.39
#
#
#
#     MAPE of SVR  : 12.66
#
#
#
#     MAPE of SVR  : 17.82
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.16
#
#
#
#     MAPE of SVR  : 32.64
#
#
#
#     MAPE of SVR  : 38.34
#
#
#
#     MAPE of SVR  : 45.46
#
#
#
#     MAPE of SVR  : 6.09
#
#
# 6.087157421781309
#
#     MAPE of SVR  : 9.39
#
#
#
#     MAPE of SVR  : 12.66
#
#
#
#     MAPE of SVR  : 17.84
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.16
#
#
#
#     MAPE of SVR  : 32.63
#
#
#
#     MAPE of SVR  : 38.34
#
#
#
#     MAPE of SVR  : 45.46
#
#
#
#     MAPE of SVR  : 6.09
#
#
# 6.086780577959697
#
#     MAPE of SVR  : 9.39
#
#
#
#     MAPE of SVR  : 12.66
#
#
#
#     MAPE of SVR  : 17.84
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.15
#
#
#
#     MAPE of SVR  : 32.63
#
#
#
#     MAPE of SVR  : 38.35
#
#
#
#     MAPE of SVR  : 45.46
#
#
#
#     MAPE of SVR  : 6.09
#
#
# 6.085646677251838
#
#     MAPE of SVR  : 9.39
#
#
#
#     MAPE of SVR  : 12.66
#
#
#
#     MAPE of SVR  : 17.85
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.15
#
#
#
#     MAPE of SVR  : 32.63
#
#
#
#     MAPE of SVR  : 38.35
#
#
#
#     MAPE of SVR  : 45.46
#
#
#
#     MAPE of SVR  : 6.08
#
#
# 6.083927441611615
#
#     MAPE of SVR  : 9.39
#
#
#
#     MAPE of SVR  : 12.66
#
#
#
#     MAPE of SVR  : 17.86
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.14
#
#
#
#     MAPE of SVR  : 32.62
#
#
#
#     MAPE of SVR  : 38.37
#
#
#
#     MAPE of SVR  : 45.47
#
#
#
#     MAPE of SVR  : 6.08
#
#
# 6.083566457584051
#
#     MAPE of SVR  : 9.39
#
#
#
#     MAPE of SVR  : 12.66
#
#
#
#     MAPE of SVR  : 17.87
#
#
#
#     MAPE of SVR  : 22.54
#
#
#
#     MAPE of SVR  : 27.14
#
#
#
#     MAPE of SVR  : 32.62
#
#
#
#     MAPE of SVR  : 38.37
#
#
#
#     MAPE of SVR  : 45.47
#
#
#
#     MAPE of SVR  : 6.08
#
#
# 6.082291257769445
#
#     MAPE of SVR  : 9.39
#
#
#
#     MAPE of SVR  : 12.66
#
#
#
#     MAPE of SVR  : 17.88
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.13
#
#
#
#     MAPE of SVR  : 32.62
#
#
#
#     MAPE of SVR  : 38.38
#
#
#
#     MAPE of SVR  : 45.48
#
#
#
#     MAPE of SVR  : 6.08
#
#
# 6.081752559529325
#
#     MAPE of SVR  : 9.38
#
#
#
#     MAPE of SVR  : 12.66
#
#
#
#     MAPE of SVR  : 17.89
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.13
#
#
#
#     MAPE of SVR  : 32.62
#
#
#
#     MAPE of SVR  : 38.4
#
#
#
#     MAPE of SVR  : 45.48
#
#
#
#     MAPE of SVR  : 6.08
#
#
# 6.081269250895374
#
#     MAPE of SVR  : 9.38
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.9
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.12
#
#
#
#     MAPE of SVR  : 32.61
#
#
#
#     MAPE of SVR  : 38.41
#
#
#
#     MAPE of SVR  : 45.48
#
#
#
#     MAPE of SVR  : 6.08
#
#
# 6.0803894499283375
#
#     MAPE of SVR  : 9.38
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.91
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.12
#
#
#
#     MAPE of SVR  : 32.61
#
#
#
#     MAPE of SVR  : 38.42
#
#
#
#     MAPE of SVR  : 45.49
#
#
#
#     MAPE of SVR  : 6.08
#
#
# 6.07993474233316
#
#     MAPE of SVR  : 9.38
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.92
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.12
#
#
#
#     MAPE of SVR  : 32.61
#
#
#
#     MAPE of SVR  : 38.43
#
#
#
#     MAPE of SVR  : 45.49
#
#
#
#     MAPE of SVR  : 6.08
#
#
# 6.079011530535547
#
#     MAPE of SVR  : 9.38
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.93
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.12
#
#
#
#     MAPE of SVR  : 32.61
#
#
#
#     MAPE of SVR  : 38.44
#
#
#
#     MAPE of SVR  : 45.5
#
#
#
#     MAPE of SVR  : 6.08
#
#
# 6.0786850379456885
#
#     MAPE of SVR  : 9.38
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.94
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.12
#
#
#
#     MAPE of SVR  : 32.6
#
#
#
#     MAPE of SVR  : 38.45
#
#
#
#     MAPE of SVR  : 45.5
#
#
#
#     MAPE of SVR  : 6.08
#
#
# 6.077735177328434
#
#     MAPE of SVR  : 9.38
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.95
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.13
#
#
#
#     MAPE of SVR  : 32.6
#
#
#
#     MAPE of SVR  : 38.46
#
#
#
#     MAPE of SVR  : 45.5
#
#
#
#     MAPE of SVR  : 6.08
#
#
# 6.075527277376683
#
#     MAPE of SVR  : 9.38
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.96
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.14
#
#
#
#     MAPE of SVR  : 32.6
#
#
#
#     MAPE of SVR  : 38.47
#
#
#
#     MAPE of SVR  : 45.51
#
#
#
#     MAPE of SVR  : 6.07
#
#
# 6.070344554383458
#
#     MAPE of SVR  : 9.37
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.97
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.14
#
#
#
#     MAPE of SVR  : 32.59
#
#
#
#     MAPE of SVR  : 38.49
#
#
#
#     MAPE of SVR  : 45.52
#
#
#
#     MAPE of SVR  : 6.06
#
#
# 6.064928106912278
#
#     MAPE of SVR  : 9.37
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.98
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.15
#
#
#
#     MAPE of SVR  : 32.59
#
#
#
#     MAPE of SVR  : 38.5
#
#
#
#     MAPE of SVR  : 45.52
#
#
#
#     MAPE of SVR  : 6.06
#
#
# 6.05939221696388
#
#     MAPE of SVR  : 9.37
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 17.99
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.16
#
#
#
#     MAPE of SVR  : 32.59
#
#
#
#     MAPE of SVR  : 38.51
#
#
#
#     MAPE of SVR  : 45.53
#
#
#
#     MAPE of SVR  : 6.05
#
#
# 6.054071420717253
#
#     MAPE of SVR  : 9.37
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 18.0
#
#
#
#     MAPE of SVR  : 22.53
#
#
#
#     MAPE of SVR  : 27.16
#
#
#
#     MAPE of SVR  : 32.59
#
#
#
#     MAPE of SVR  : 38.53
#
#
#
#     MAPE of SVR  : 45.53
#
#
#
#     MAPE of SVR  : 6.05
#
#
# 6.049237446797589
#     MAPE of SVR  : 9.36
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 18.01
#
#
#
#     MAPE of SVR  : 22.54
#
#
#
#     MAPE of SVR  : 27.17
#
#
#
#     MAPE of SVR  : 32.58
#
#
#
#     MAPE of SVR  : 38.54
#
#
#
#     MAPE of SVR  : 45.54
#
#
#
#     MAPE of SVR  : 6.04
#
#
# 6.043887840321649
#
#     MAPE of SVR  : 9.36
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 18.02
#
#
#
#     MAPE of SVR  : 22.55
#
#
#
#     MAPE of SVR  : 27.18
#
#
#
#     MAPE of SVR  : 32.58
#
#
#
#     MAPE of SVR  : 38.56
#
#
#
#     MAPE of SVR  : 45.54
#
#
#
#     MAPE of SVR  : 6.04
#
#
# 6.038625906668534
#
#     MAPE of SVR  : 9.36
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 18.03
#
#
#
#     MAPE of SVR  : 22.55
#
#
#
#     MAPE of SVR  : 27.19
#
#
#
#     MAPE of SVR  : 32.58
#
#
#
#     MAPE of SVR  : 38.57
#
#
#
#     MAPE of SVR  : 45.55
#
#
#
#     MAPE of SVR  : 6.03
#
#
# 6.033855768187926
#
#     MAPE of SVR  : 9.36
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 18.04
#
#
#
#     MAPE of SVR  : 22.56
#
#
#
#     MAPE of SVR  : 27.19
#
#
#
#     MAPE of SVR  : 32.57
#
#
#
#     MAPE of SVR  : 38.58
#
#
#
#     MAPE of SVR  : 45.56
#
#
#
#     MAPE of SVR  : 6.03
#
#
# 6.027753139897965
#
#     MAPE of SVR  : 9.36
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 18.05
#
#
#
#     MAPE of SVR  : 22.57
#
#
#
#     MAPE of SVR  : 27.2
#
#
#
#     MAPE of SVR  : 32.57
#
#
#
#     MAPE of SVR  : 38.6
#
#
#
#     MAPE of SVR  : 45.56
#
#
#
#     MAPE of SVR  : 6.02
#
#
# 6.023575838972681
#
#     MAPE of SVR  : 9.36
#
#
#
#     MAPE of SVR  : 12.65
#
#
#
#     MAPE of SVR  : 18.06
#
#
#
#     MAPE of SVR  : 22.57
#
#
#
#     MAPE of SVR  : 27.21
#
#
#
#     MAPE of SVR  : 32.57
#
#
#
#     MAPE of SVR  : 38.61
#
#
#
#     MAPE of SVR  : 45.57
#
#
#
#     MAPE of SVR  : 6.02
#
#
# 6.017946586064211
#
#     MAPE of SVR  : 9.36
#
#
#
#     MAPE of SVR  : 12.64
#
#
#
#     MAPE of SVR  : 18.07
#
#
#
#     MAPE of SVR  : 22.58
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.56
#
#
#
#     MAPE of SVR  : 38.63
#
#
#
#     MAPE of SVR  : 45.57
#
#
#
#     MAPE of SVR  : 6.01
#
#
# 6.011506795527323
#
#     MAPE of SVR  : 9.36
#
#
#
#     MAPE of SVR  : 12.64
#
#
#
#     MAPE of SVR  : 18.08
#
#
#
#     MAPE of SVR  : 22.59
#
#
#
#     MAPE of SVR  : 27.22
#
#
#
#     MAPE of SVR  : 32.56
#
#
#
#     MAPE of SVR  : 38.65
#
#
#
#     MAPE of SVR  : 45.58
#
#
#
#     MAPE of SVR  : 6.01
#
#
# 6.010919932905128
#
#     MAPE of SVR  : 9.36
#
#
#
#     MAPE of SVR  : 12.64
#
#
#
#     MAPE of SVR  : 18.09
#
#
#
#     MAPE of SVR  : 22.59
#
#
#
#     MAPE of SVR  : 27.23
#
#
#
#     MAPE of SVR  : 32.56
#
#
#
#     MAPE of SVR  : 38.66
#
#
#
#     MAPE of SVR  : 45.58
#
#
#
#     MAPE of SVR  : 6.01
#
#
# 6.0088371413748485
#
#     MAPE of SVR  : 9.36
#
#
#
#     MAPE of SVR  : 12.64
#
#
#
#     MAPE of SVR  : 18.09
#
#
#
#     MAPE of SVR  : 22.6
#
#
#
#     MAPE of SVR  : 27.23
#
#
#
#     MAPE of SVR  : 32.56
#
#
#
#     MAPE of SVR  : 38.68
#
#
#
#     MAPE of SVR  : 45.59
#
#
#
#     MAPE of SVR  : 6.01
#
#
# 6.0085178172090306
#
#     MAPE of SVR  : 9.36
#
#
#
#     MAPE of SVR  : 12.64
#
#
#
#     MAPE of SVR  : 18.1
#
#
#
#     MAPE of SVR  : 22.6
#
#
#
#     MAPE of SVR  : 27.24
#
#
#
#     MAPE of SVR  : 32.55
#
#
#
#     MAPE of SVR  : 38.69
#
#
#
#     MAPE of SVR  : 45.6
#
#
#
#     MAPE of SVR  : 6.01
#
#
#
#     MAPE of SVR  : 9.35
#
#
#
#     MAPE of SVR  : 12.64
#
#
#
#     MAPE of SVR  : 18.1
#
#
#
#     MAPE of SVR  : 22.61
#
#
#
#     MAPE of SVR  : 27.25
#
#
#
#     MAPE of SVR  : 32.55
#
#
#
#     MAPE of SVR  : 38.71
#
#
#
#     MAPE of SVR  : 45.58
#
#
#
#     MAPE of SVR  : 6.01
#
#
#
#     MAPE of SVR  : 9.35
#
#
#
#     MAPE of SVR  : 12.64
#
#
#
#     MAPE of SVR  : 18.11
#
#
#
#     MAPE of SVR  : 22.61
#
#
#
#     MAPE of SVR  : 27.26
#
#
#
#     MAPE of SVR  : 32.55
#
#
#
#     MAPE of SVR  : 38.72
#
#
#
#     MAPE of SVR  : 45.56
#
#
#
#     MAPE of SVR  : 6.02
#
#
#
#     MAPE of SVR  : 9.35
#
#
#
#     MAPE of SVR  : 12.64
#
#
#
#     MAPE of SVR  : 18.13
#
#
#
#     MAPE of SVR  : 22.62
#
#
#
#     MAPE of SVR  : 27.26
#
#
#
#     MAPE of SVR  : 32.55
#
#
#
#     MAPE of SVR  : 38.74
#
#
#
#     MAPE of SVR  : 45.53
#
#
#
#     MAPE of SVR  : 6.02
#
#
#
#     MAPE of SVR  : 9.35
#
#
#
#     MAPE of SVR  : 12.64
#
#
#
#     MAPE of SVR  : 18.14
#
#
#
#     MAPE of SVR  : 22.62
#
#
#
#     MAPE of SVR  : 27.27
#
#
#
#     MAPE of SVR  : 32.54
#
#
#
#     MAPE of SVR  : 38.75
#
#
#
#     MAPE of SVR  : 45.51
#
#
#
#     MAPE of SVR  : 6.02
#
#
#
#     MAPE of SVR  : 9.35
#
#
#
#     MAPE of SVR  : 12.63
#
#
#
#     MAPE of SVR  : 18.15
#
#
#
#     MAPE of SVR  : 22.63
#
#
#
#     MAPE of SVR  : 27.28
#
#
#
#     MAPE of SVR  : 32.54
#
#
#
#     MAPE of SVR  : 38.77
#
#
#
#     MAPE of SVR  : 45.49
#
#
#
#     MAPE of SVR  : 6.02
#
#
#
#     MAPE of SVR  : 9.35
#
#
#
#     MAPE of SVR  : 12.63
#
#
#
#     MAPE of SVR  : 18.16
#
#
#
#     MAPE of SVR  : 22.64
#
#
#
#     MAPE of SVR  : 27.28
#
#
#
#     MAPE of SVR  : 32.54
#
#
#
#     MAPE of SVR  : 38.79
#
#
#
#     MAPE of SVR  : 45.46
#
#
#
#     MAPE of SVR  : 6.02
#
#
#
#     MAPE of SVR  : 9.35
#
#
#
#     MAPE of SVR  : 12.63
#
#
#
#     MAPE of SVR  : 18.17
#
#
#
#     MAPE of SVR  : 22.64
#
#
#
#     MAPE of SVR  : 27.29
#
#
#
#     MAPE of SVR  : 32.53
#
#
#
#     MAPE of SVR  : 38.8
#
#
#
#     MAPE of SVR  : 45.45
#
#
#
#     MAPE of SVR  : 6.02
#
#
#
#     MAPE of SVR  : 9.35
#
#
#
#     MAPE of SVR  : 12.63
#
#
#
#     MAPE of SVR  : 18.18
#
#
#
#     MAPE of SVR  : 22.65
#
#
#
#     MAPE of SVR  : 27.3
#
#
#
#     MAPE of SVR  : 32.53
#
#
#
#     MAPE of SVR  : 38.82
#
#
#
#     MAPE of SVR  : 45.42
#
#
#
#     MAPE of SVR  : 6.02
#
#
#
#     MAPE of SVR  : 9.35
#
#
#
#     MAPE of SVR  : 12.63
#
#
#
#     MAPE of SVR  : 18.19
#
#
#
#     MAPE of SVR  : 22.65
#
#
#
#     MAPE of SVR  : 27.31
#
#
#
#     MAPE of SVR  : 32.53
#
#
#
#     MAPE of SVR  : 38.83
#
#
#
#     MAPE of SVR  : 45.4
#
#
#
#     MAPE of SVR  : 6.02
#
#
#
#     MAPE of SVR  : 9.35
#
#
#
#     MAPE of SVR  : 12.63
#
#
#
#     MAPE of SVR  : 18.2
#
#
#
#     MAPE of SVR  : 22.66
#
#
#
#     MAPE of SVR  : 27.31
#
#
#
#     MAPE of SVR  : 32.52
#
#
#
#     MAPE of SVR  : 38.85
#
#
#
#     MAPE of SVR  : 45.38
#
#
#
#     MAPE of SVR  : 6.02
#
#
#
#     MAPE of SVR  : 9.35
#
#
#
#     MAPE of SVR  : 12.63
#
#
#
#     MAPE of SVR  : 18.22
#
#
#
#     MAPE of SVR  : 22.66
#
#
#
#     MAPE of SVR  : 27.32
#
#
#
#     MAPE of SVR  : 32.52
#
#
#
#     MAPE of SVR  : 38.85
#
#
#
#     MAPE of SVR  : 45.36
#
#
#
#     MAPE of SVR  : 6.02
#
#
#
#     MAPE of SVR  : 9.35
#
#
#
#     MAPE of SVR  : 12.62
#
#
#
#     MAPE of SVR  : 18.23
#
#
#
#     MAPE of SVR  : 22.67
#
#
#
#     MAPE of SVR  : 27.33
#
#
#
#     MAPE of SVR  : 32.52
#
#
#
#     MAPE of SVR  : 38.84
#
#
#
#     MAPE of SVR  : 45.34
#
#
#
#     MAPE of SVR  : 6.02
#
#
#
#     MAPE of SVR  : 9.35
#
#
#
#     MAPE of SVR  : 12.62
#
#
#
#     MAPE of SVR  : 18.24
#
#
#
#     MAPE of SVR  : 22.67
#
#
#
#     MAPE of SVR  : 27.33
#
#
#
#     MAPE of SVR  : 32.52
#
#
#
#     MAPE of SVR  : 38.83
#
#
#
#     MAPE of SVR  : 45.32
#
#
#
#     MAPE of SVR  : 6.02
#
#
#
#     MAPE of SVR  : 9.34
#
#
#
#     MAPE of SVR  : 12.62
#
#
#
#     MAPE of SVR  : 18.25
#
#
#
#     MAPE of SVR  : 22.68
#
#
#
#     MAPE of SVR  : 27.34
#
#
#
#     MAPE of SVR  : 32.52
#
#
#
#     MAPE of SVR  : 38.82
#
#
#
#     MAPE of SVR  : 45.29
#
#
#
#     MAPE of SVR  : 6.02
#
#
#
#     MAPE of SVR  : 9.34
#
#
#
#     MAPE of SVR  : 12.62
#
#
#
#     MAPE of SVR  : 18.26
#
#
#
#     MAPE of SVR  : 22.69
#
#
#
#     MAPE of SVR  : 27.35
#
#
#
#     MAPE of SVR  : 32.52
#
#
#
#     MAPE of SVR  : 38.81
#
#
#
#     MAPE of SVR  : 45.28
#
#
#
#     MAPE of SVR  : 6.02
#
#
#
#     MAPE of SVR  : 9.34
#
#
#
#     MAPE of SVR  : 12.62
#
#
#
#     MAPE of SVR  : 18.28
#
#
#
#     MAPE of SVR  : 22.69
#
#
#
#     MAPE of SVR  : 27.35
#
#
#
#     MAPE of SVR  : 32.51
#
#
#
#     MAPE of SVR  : 38.8
#
#
#
#     MAPE of SVR  : 45.25
#
#
#
#     MAPE of SVR  : 6.02
#
#
#
#     MAPE of SVR  : 9.33
#
#
#
#     MAPE of SVR  : 12.62
#
#
#
#     MAPE of SVR  : 18.29
#
#
#
#     MAPE of SVR  : 22.7
#
#
#
#     MAPE of SVR  : 27.36
#
#
#
#     MAPE of SVR  : 32.51
#
#
#
#     MAPE of SVR  : 38.79
#
#
#
#     MAPE of SVR  : 45.23
#
#
#
# The lowest MAPE of SVR  : 6.01, the value of hyperparameters :C = 365, epsilon = 1

# %% [markdown]
# # eXtreme Gradient Boosting (XGBoost)

# %%
import xgboost as xgb
import pandas as pd # for data manipulation
from itertools import product
import numpy as np # for data manipulation
import matplotlib.pyplot as plt # for data visualization
# %matplotlib inline


# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]] 
# y_test = df_pred['Execution_time']

# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M"]]
# y_test = df_pred['Execution_time']


# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M"]]
# y_test = df_pred['Execution_time']

df = pd.read_csv("model_result.csv")
x_train = df[["FLOPs_G","Total_params_M"]]
y_train = df['Execution_time']

df_pred = pd.read_csv("model_result_NCV.csv")
x_test = df_pred[["FLOPs_G","Total_params_M"]]
y_test = df_pred['Execution_time']



# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]] 
# y_test = df_pred['Execution_time']
MAPE_default=10000
MAPE_better=MAPE_default
range_colsample_bytree = np.arange(0.5,1.0,0.1)
range_learning_rate = np.arange(0.1,0.35,0.05)
range_max_depth = range(3,11,1)
range_n_estimators = range(2,54,4)
for value_colsample_bytree, value_learning_rate, value_max_depth, value_n_estimators in product(range_colsample_bytree,range_learning_rate,range_max_depth,range_n_estimators):


    xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = value_colsample_bytree, learning_rate =value_learning_rate,
                    max_depth = value_max_depth, n_estimators = value_n_estimators)
    xg_reg.fit(x_train,y_train)

    y_pred_current = xg_reg.predict(x_test)
    # Calculate percentage error
    per_err = (y_test - y_pred_current) / y_test

    # Take absolute value of the percentage error (APE)
    per_err = abs(per_err)*100


    # Calculate the MAPE
    MAPE = sum(per_err)/len(per_err)


    if ( MAPE < MAPE_better ):
        better_colsample_bytree = value_colsample_bytree
        better_learning_rate = value_learning_rate
        better_max_depth = value_max_depth
        better_n_estimators = value_n_estimators
        MAPE_better = MAPE
        y_pred = y_pred_current
                
        print(f'''        
        The lowest MAPE of XGBoost  : { round(MAPE_better, 2) }
        the value of hyperparameters :
        colsample_bytree = {better_colsample_bytree}
        learning_rate = {better_learning_rate}
        max_depth = {better_max_depth}
        n_estimators = {better_n_estimators}

        ''')
index=np.argsort(y_test)

plt.figure(figsize=(12,5))
plt.plot(np.arange(len(y_test)),y_test[index],"r",label="original execution time")
plt.scatter(np.arange(len(y_pred)),y_pred[index],s=10,c="b",label="prediced execution time ")
plt.legend(loc="upper left")
plt.grid()
plt.xlabel("The index of the model that need to be predicted")
plt.ylabel("execution time(ms)")
plt.title("XGBoost Results")
plt.show()
# Out:
#
#         The lowest MAPE of XGBoost  : 75.27
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.1
#         max_depth = 3
#         n_estimators = 2
#
#
#
#         The lowest MAPE of XGBoost  : 41.71
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.1
#         max_depth = 3
#         n_estimators = 6
#
#
#
#         The lowest MAPE of XGBoost  : 25.6
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.1
#         max_depth = 3
#         n_estimators = 10
#
#
#
#         The lowest MAPE of XGBoost  : 20.0
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.1
#         max_depth = 3
#         n_estimators = 14
#
#
#
#         The lowest MAPE of XGBoost  : 18.63
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.1
#         max_depth = 3
#         n_estimators = 18
#
#
#
#         The lowest MAPE of XGBoost  : 18.35
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.1
#         max_depth = 3
#         n_estimators = 22
#
#
#
#         The lowest MAPE of XGBoost  : 17.8
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.1
#         max_depth = 3
#         n_estimators = 26
#
#
#
#         The lowest MAPE of XGBoost  : 17.33
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.1
#         max_depth = 3
#         n_estimators = 34
#
#
#
#         The lowest MAPE of XGBoost  : 16.88
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.1
#         max_depth = 3
#         n_estimators = 42
#
#
#
#         The lowest MAPE of XGBoost  : 16.59
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.1
#         max_depth = 3
#         n_estimators = 46
#
#
#
#         The lowest MAPE of XGBoost  : 16.38
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.15000000000000002
#         max_depth = 3
#         n_estimators = 26
#
#
#
#         The lowest MAPE of XGBoost  : 16.27
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.20000000000000004
#         max_depth = 3
#         n_estimators = 18
#
#
#
#         The lowest MAPE of XGBoost  : 16.27
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.20000000000000004
#         max_depth = 3
#         n_estimators = 22
#
#
#
#         The lowest MAPE of XGBoost  : 16.11
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.20000000000000004
#         max_depth = 3
#         n_estimators = 26
#
#
#
#         The lowest MAPE of XGBoost  : 16.1
#         the value of hyperparameters :
#         colsample_bytree = 0.5
#         learning_rate = 0.20000000000000004
#         max_depth = 3
#         n_estimators = 34

# %%
print(better_alpha)

# %%
import xgboost as xgb
import pandas as pd # for data manipulation
import numpy as np # for data manipulation
from matplotlib import pyplot
import matplotlib.pyplot as plt # for data visualization
# %matplotlib inline


# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]] 
# y_test = df_pred['Execution_time']

# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M"]]
# y_test = df_pred['Execution_time']


# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M"]]
# y_test = df_pred['Execution_time']

df = pd.read_csv("model_result.csv")
x_train = df[["FLOPs_G","Total_params_M"]]
y_train = df['Execution_time']

df_pred = pd.read_csv("model_result_NCV.csv")
x_test = df_pred[["FLOPs_G","Total_params_M"]]
y_test = df_pred['Execution_time']



# df = pd.read_csv("model_result.csv")
# x_train = df[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]]
# y_train = df['Execution_time']

# df_pred = pd.read_csv("model_result_NCV.csv")
# x_test = df_pred[["FLOPs_G","Total_params_M","Memory_M","total_num_of_neurons_M","input_horizontal","number_of_layers"]] 
# y_test = df_pred['Execution_time']

xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.9, learning_rate = 0.9,
               max_depth = 9, alpha = 11, n_estimators = 47)

xg_reg.fit(x_train,y_train)

y_pred = xg_reg.predict(x_test)
# Calculate percentage error
per_err = (y_test - y_pred) / y_test

# Take absolute value of the percentage error (APE)
per_err = abs(per_err)*100


# Calculate the MAPE
MAPE = sum(per_err)/len(per_err)

# Print the MAPE value 
print(f'''
MAPE of XGBoost  : { round(MAPE, 2) }

''')
print(x_train.columns)
print(xg_reg.feature_importances_)
plt.barh(x_train.columns, xg_reg.feature_importances_)

pyplot.show()
index=np.argsort(y_test)

plt.figure(figsize=(12,5))
plt.plot(np.arange(len(y_test)),y_test[index],"r",label="original execution time")
plt.scatter(np.arange(len(y_pred)),y_pred[index],s=10,c="b",label="prediced execution time ")
plt.legend(loc="upper left")
plt.grid()
plt.xlabel("The index of the model that need to be predicted")
plt.ylabel("execution time(ms)")
plt.title("XGBoost Results")
plt.show()
# Out:
# [16:37:41] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
#
# MAPE of XGBoost  : 19.65
#
#
# Index(['FLOPs_G', 'Total_params_M'], dtype='object')
# [0.9705726  0.02942746]

# %%
import xgboost as xgb
import pandas as pd # for data manipulation
import numpy as np # for data manipulation
import matplotlib.pyplot as plt # for data visualization
# %matplotlib inline

df = pd.read_csv("2_variables.csv")
x1 = df["FLOPs_G"].values.tolist()
x2 = df["Memory_M"].values.tolist()
# x3 = df["Total_params_M"].values.tolist()
y = df['Execution_time'].values.tolist()
x_train =np.array(list(zip(x1,x2)))
print(x_train.shape)
y_train = np.array(y)
df_pred = pd.read_csv("pred_2_variables.csv")
x1_pred = df_pred["FLOPs_G"].values.tolist()
x2_pred = df_pred["Memory_M"].values.tolist()
x_test =np.array(list(zip(x1_pred,x2_pred)))
y_pred = df_pred['Execution_time'].values.tolist()

y_test = np.array(y_pred)

xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 20, n_estimators = 10)


xg_reg.fit(x_train,y_train)

y_pred = xg_reg.predict(x_test)
print(y_pred)
index=np.argsort(y_test)

plt.figure(figsize=(12,5))
plt.plot(np.arange(len(y_test)),y_test[index],"r",label="original y")
plt.scatter(np.arange(len(y_pred)),y_pred[index],s=3,c="b",label="prediction")
plt.legend(loc="upper left")
plt.grid()
plt.xlabel("index")
plt.ylabel("y")
plt.show()
