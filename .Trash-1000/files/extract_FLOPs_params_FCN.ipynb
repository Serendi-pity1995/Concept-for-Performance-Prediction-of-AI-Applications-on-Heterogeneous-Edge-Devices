# %%
import os
import csv
import numpy as np
import tensorflow as tf
import keras

from itertools import product
from keras_flops import get_flops


model_num = 1
input_shape_range =range(32,512,32)

with open("para_count_FCN.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "step", "number of layers", "FLOPs", "Total_params", "Memory"],])
path = "../FCN_h5" #文件夹目录
files= os.listdir(path) #得到文件夹下的所有文件名称

for shape_x in input_shape_range:
    shape_y = shape_x
    for step in range(1,11):
        file = "UNet_{input_x}_{input_y}_{step}.h5".format(input_x=shape_x,input_y=shape_y,step=step)
        if file in files: #遍历文件夹
            model_name = str(file)
            if not os.path.isdir(file): #判断是否是文件夹，不是文件夹才打开
                model = keras.models.load_model("../FCN_h5/{}".format(model_name))

                # how to compute the memory allocated by the activations of a model
                batch = 1
                shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
                else 1 for s in l.output_shape])) 
                for l in model.layers]))
                memory = (shapes_count * 4 * batch)/10**6
                print(memory)
                layers_length = len(model.layers)
                Total_params = round(model.count_params()/10 ** 6,2)
                FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
                with open("para_count_FCN.csv","a+") as csvfile:
                    writer = csv.writer(csvfile)
                    writer.writerows([[model_num, shape_x, shape_y, step, layers_length, FLOPs, Total_params, memory],])

                    model_num = model_num + 1
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-04-30 08:13:40.724321: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-04-30 08:13:40.724350: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-30 08:13:40.724375: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2022-04-30 08:13:40.724575: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 6.461572
# WARNING:tensorflow:From /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py:5063: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/126.20m flops)
#   fcn_segment/conv_4/Conv2D (30.36m/30.36m flops)
#   fcn_segment/conv_2/Conv2D (28.04m/28.04m flops)
#   fcn_segment/conv_3/Conv2D (25.88m/25.88m flops)
#   fcn_segment/conv_7/Conv2D (20.24m/20.24m flops)
#   fcn_segment/conv_5/Conv2D (13.28m/13.28m flops)
#   fcn_segment/conv_1/Conv2D (4.31m/4.31m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (3.32m/3.32m flops)
#   fcn_segment/conv_1/BiasAdd (239.62k/239.62k flops)
#   fcn_segment/max_pool_1/MaxPool (239.62k/239.62k flops)
#   fcn_segment/conv_2/BiasAdd (59.90k/59.90k flops)
#   fcn_segment/max_pool_2/MaxPool (59.90k/59.90k flops)
#   fcn_segment/conv_3/BiasAdd (55.30k/55.30k flops)
#   fcn_segment/max_pool_3/MaxPool (55.30k/55.30k flops)
#   fcn_segment/conv_4/BiasAdd (17.57k/17.57k flops)
#   fcn_segment/max_pool_4/MaxPool (17.57k/17.57k flops)
#   fcn_segment/conv_7/BiasAdd (9.22k/9.22k flops)
#   fcn_segment/conv_5/BiasAdd (6.05k/6.05k flops)
#   fcn_segment/max_pool_5/MaxPool (6.05k/6.05k flops)
#   fcn_segment/upsamping_6/BiasAdd (4.39k/4.39k flops)
#   fcn_segment/add_16/add (4.39k/4.39k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-04-30 08:13:41.172697: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:13:41.172866: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:13:41.193944: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.007ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
#
# 2022-04-30 08:13:41.359336: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:13:41.359413: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:13:41.360776: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 6.461572
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/126.20m flops)
#   fcn_segment/conv_4/Conv2D (30.36m/30.36m flops)
#   fcn_segment/conv_2/Conv2D (28.04m/28.04m flops)
#   fcn_segment/conv_3/Conv2D (25.88m/25.88m flops)
#   fcn_segment/conv_7/Conv2D (20.24m/20.24m flops)
#   fcn_segment/conv_5/Conv2D (13.28m/13.28m flops)
#   fcn_segment/conv_1/Conv2D (4.31m/4.31m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (3.32m/3.32m flops)
#   fcn_segment/conv_1/BiasAdd (239.62k/239.62k flops)
#   fcn_segment/max_pool_1/MaxPool (239.62k/239.62k flops)
#   fcn_segment/conv_2/BiasAdd (59.90k/59.90k flops)
#   fcn_segment/max_pool_2/MaxPool (59.90k/59.90k flops)
#   fcn_segment/conv_3/BiasAdd (55.30k/55.30k flops)
#   fcn_segment/max_pool_3/MaxPool (55.30k/55.30k flops)
#   fcn_segment/conv_4/BiasAdd (17.57k/17.57k flops)
#   fcn_segment/max_pool_4/MaxPool (17.57k/17.57k flops)
#   fcn_segment/conv_7/BiasAdd (9.22k/9.22k flops)
#   fcn_segment/conv_5/BiasAdd (6.05k/6.05k flops)
#   fcn_segment/max_pool_5/MaxPool (6.05k/6.05k flops)
#   fcn_segment/upsamping_6/BiasAdd (4.39k/4.39k flops)
#   fcn_segment/add_16/add (4.39k/4.39k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 6.461572
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/126.20m flops)
#   fcn_segment/conv_4/Conv2D (30.36m/30.36m flops)
#   fcn_segment/conv_2/Conv2D (28.04m/28.04m flops)
#   fcn_segment/conv_3/Conv2D (25.88m/25.88m flops)
#   fcn_segment/conv_7/Conv2D (20.24m/20.24m flops)
#   fcn_segment/conv_5/Conv2D (13.28m/13.28m flops)
#   fcn_segment/conv_1/Conv2D (4.31m/4.31m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (3.32m/3.32m flops)
#   fcn_segment/conv_1/BiasAdd (239.62k/239.62k flops)
#   fcn_segment/max_pool_1/MaxPool (239.62k/239.62k flops)
#   fcn_segment/conv_2/BiasAdd (59.90k/59.90k flops)
#   fcn_segment/max_pool_2/MaxPool (59.90k/59.90k flops)
#   fcn_segment/conv_3/BiasAdd (55.30k/55.30k flops)
#   fcn_segment/max_pool_3/MaxPool (55.30k/55.30k flops)
#   fcn_segment/conv_4/BiasAdd (17.57k/17.57k flops)
#   fcn_segment/max_pool_4/MaxPool (17.57k/17.57k flops)
#   fcn_segment/conv_7/BiasAdd (9.22k/9.22k flops)
#   fcn_segment/conv_5/BiasAdd (6.05k/6.05k flops)
#   fcn_segment/max_pool_5/MaxPool (6.05k/6.05k flops)
#   fcn_segment/upsamping_6/BiasAdd (4.39k/4.39k flops)
#   fcn_segment/add_16/add (4.39k/4.39k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 6.461572
# 2022-04-30 08:13:41.526109: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:13:41.526197: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:13:41.527472: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
#
# 2022-04-30 08:13:41.691288: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:13:41.691376: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:13:41.692768: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/126.20m flops)
#   fcn_segment/conv_4/Conv2D (30.36m/30.36m flops)
#   fcn_segment/conv_2/Conv2D (28.04m/28.04m flops)
#   fcn_segment/conv_3/Conv2D (25.88m/25.88m flops)
#   fcn_segment/conv_7/Conv2D (20.24m/20.24m flops)
#   fcn_segment/conv_5/Conv2D (13.28m/13.28m flops)
#   fcn_segment/conv_1/Conv2D (4.31m/4.31m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (3.32m/3.32m flops)
#   fcn_segment/conv_1/BiasAdd (239.62k/239.62k flops)
#   fcn_segment/max_pool_1/MaxPool (239.62k/239.62k flops)
#   fcn_segment/conv_2/BiasAdd (59.90k/59.90k flops)
#   fcn_segment/max_pool_2/MaxPool (59.90k/59.90k flops)
#   fcn_segment/conv_3/BiasAdd (55.30k/55.30k flops)
#   fcn_segment/max_pool_3/MaxPool (55.30k/55.30k flops)
#   fcn_segment/conv_4/BiasAdd (17.57k/17.57k flops)
#   fcn_segment/max_pool_4/MaxPool (17.57k/17.57k flops)
#   fcn_segment/conv_7/BiasAdd (9.22k/9.22k flops)
#   fcn_segment/conv_5/BiasAdd (6.05k/6.05k flops)
#   fcn_segment/max_pool_5/MaxPool (6.05k/6.05k flops)
#   fcn_segment/upsamping_6/BiasAdd (4.39k/4.39k flops)
#   fcn_segment/add_16/add (4.39k/4.39k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 6.461572
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/126.20m flops)
#   fcn_segment/conv_4/Conv2D (30.36m/30.36m flops)
#   fcn_segment/conv_2/Conv2D (28.04m/28.04m flops)
#   fcn_segment/conv_3/Conv2D (25.88m/25.88m flops)
#   fcn_segment/conv_7/Conv2D (20.24m/20.24m flops)
#   fcn_segment/conv_5/Conv2D (13.28m/13.28m flops)
#   fcn_segment/conv_1/Conv2D (4.31m/4.31m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (3.32m/3.32m flops)
#   fcn_segment/conv_1/BiasAdd (239.62k/239.62k flops)
#   fcn_segment/max_pool_1/MaxPool (239.62k/239.62k flops)
#   fcn_segment/conv_2/BiasAdd (59.90k/59.90k flops)
#   fcn_segment/max_pool_2/MaxPool (59.90k/59.90k flops)
#   fcn_segment/conv_3/BiasAdd (55.30k/55.30k flops)
#   fcn_segment/max_pool_3/MaxPool (55.30k/55.30k flops)
#   fcn_segment/conv_4/BiasAdd (17.57k/17.57k flops)
#   fcn_segment/max_pool_4/MaxPool (17.57k/17.57k flops)
#   fcn_segment/conv_7/BiasAdd (9.22k/9.22k flops)
#   fcn_segment/conv_5/BiasAdd (6.05k/6.05k flops)
#   fcn_segment/max_pool_5/MaxPool (6.05k/6.05k flops)
#   fcn_segment/upsamping_6/BiasAdd (4.39k/4.39k flops)
#   fcn_segment/add_16/add (4.39k/4.39k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 6.461572
# 2022-04-30 08:13:41.861993: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:13:41.862066: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:13:41.863447: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
#
# 2022-04-30 08:13:42.028389: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:13:42.028459: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:13:42.029779: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/126.20m flops)
#   fcn_segment/conv_4/Conv2D (30.36m/30.36m flops)
#   fcn_segment/conv_2/Conv2D (28.04m/28.04m flops)
#   fcn_segment/conv_3/Conv2D (25.88m/25.88m flops)
#   fcn_segment/conv_7/Conv2D (20.24m/20.24m flops)
#   fcn_segment/conv_5/Conv2D (13.28m/13.28m flops)
#   fcn_segment/conv_1/Conv2D (4.31m/4.31m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (3.32m/3.32m flops)
#   fcn_segment/conv_1/BiasAdd (239.62k/239.62k flops)
#   fcn_segment/max_pool_1/MaxPool (239.62k/239.62k flops)
#   fcn_segment/conv_2/BiasAdd (59.90k/59.90k flops)
#   fcn_segment/max_pool_2/MaxPool (59.90k/59.90k flops)
#   fcn_segment/conv_3/BiasAdd (55.30k/55.30k flops)
#   fcn_segment/max_pool_3/MaxPool (55.30k/55.30k flops)
#   fcn_segment/conv_4/BiasAdd (17.57k/17.57k flops)
#   fcn_segment/max_pool_4/MaxPool (17.57k/17.57k flops)
#   fcn_segment/conv_7/BiasAdd (9.22k/9.22k flops)
#   fcn_segment/conv_5/BiasAdd (6.05k/6.05k flops)
#   fcn_segment/max_pool_5/MaxPool (6.05k/6.05k flops)
#   fcn_segment/upsamping_6/BiasAdd (4.39k/4.39k flops)
#   fcn_segment/add_16/add (4.39k/4.39k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 6.461572
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/126.20m flops)
#   fcn_segment/conv_4/Conv2D (30.36m/30.36m flops)
#   fcn_segment/conv_2/Conv2D (28.04m/28.04m flops)
#   fcn_segment/conv_3/Conv2D (25.88m/25.88m flops)
#   fcn_segment/conv_7/Conv2D (20.24m/20.24m flops)
#   fcn_segment/conv_5/Conv2D (13.28m/13.28m flops)
#   fcn_segment/conv_1/Conv2D (4.31m/4.31m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (3.32m/3.32m flops)
#   fcn_segment/conv_1/BiasAdd (239.62k/239.62k flops)
#   fcn_segment/max_pool_1/MaxPool (239.62k/239.62k flops)
#   fcn_segment/conv_2/BiasAdd (59.90k/59.90k flops)
#   fcn_segment/max_pool_2/MaxPool (59.90k/59.90k flops)
#   fcn_segment/conv_3/BiasAdd (55.30k/55.30k flops)
#   fcn_segment/max_pool_3/MaxPool (55.30k/55.30k flops)
#   fcn_segment/conv_4/BiasAdd (17.57k/17.57k flops)
#   fcn_segment/max_pool_4/MaxPool (17.57k/17.57k flops)
#   fcn_segment/conv_7/BiasAdd (9.22k/9.22k flops)
#   fcn_segment/conv_5/BiasAdd (6.05k/6.05k flops)
#   fcn_segment/max_pool_5/MaxPool (6.05k/6.05k flops)
#   fcn_segment/upsamping_6/BiasAdd (4.39k/4.39k flops)
#   fcn_segment/add_16/add (4.39k/4.39k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 6.461572
# 2022-04-30 08:13:42.195360: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:13:42.195444: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:13:42.196730: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
#
# 2022-04-30 08:13:42.356638: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:13:42.356713: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:13:42.358020: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/126.20m flops)
#   fcn_segment/conv_4/Conv2D (30.36m/30.36m flops)
#   fcn_segment/conv_2/Conv2D (28.04m/28.04m flops)
#   fcn_segment/conv_3/Conv2D (25.88m/25.88m flops)
#   fcn_segment/conv_7/Conv2D (20.24m/20.24m flops)
#   fcn_segment/conv_5/Conv2D (13.28m/13.28m flops)
#   fcn_segment/conv_1/Conv2D (4.31m/4.31m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (3.32m/3.32m flops)
#   fcn_segment/conv_1/BiasAdd (239.62k/239.62k flops)
#   fcn_segment/max_pool_1/MaxPool (239.62k/239.62k flops)
#   fcn_segment/conv_2/BiasAdd (59.90k/59.90k flops)
#   fcn_segment/max_pool_2/MaxPool (59.90k/59.90k flops)
#   fcn_segment/conv_3/BiasAdd (55.30k/55.30k flops)
#   fcn_segment/max_pool_3/MaxPool (55.30k/55.30k flops)
#   fcn_segment/conv_4/BiasAdd (17.57k/17.57k flops)
#   fcn_segment/max_pool_4/MaxPool (17.57k/17.57k flops)
#   fcn_segment/conv_7/BiasAdd (9.22k/9.22k flops)
#   fcn_segment/conv_5/BiasAdd (6.05k/6.05k flops)
#   fcn_segment/max_pool_5/MaxPool (6.05k/6.05k flops)
#   fcn_segment/upsamping_6/BiasAdd (4.39k/4.39k flops)
#   fcn_segment/add_16/add (4.39k/4.39k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 6.461572
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/126.20m flops)
#   fcn_segment/conv_4/Conv2D (30.36m/30.36m flops)
#   fcn_segment/conv_2/Conv2D (28.04m/28.04m flops)
#   fcn_segment/conv_3/Conv2D (25.88m/25.88m flops)
#   fcn_segment/conv_7/Conv2D (20.24m/20.24m flops)
#   fcn_segment/conv_5/Conv2D (13.28m/13.28m flops)
#   fcn_segment/conv_1/Conv2D (4.31m/4.31m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (3.32m/3.32m flops)
#   fcn_segment/conv_1/BiasAdd (239.62k/239.62k flops)
#   fcn_segment/max_pool_1/MaxPool (239.62k/239.62k flops)
#   fcn_segment/conv_2/BiasAdd (59.90k/59.90k flops)
#   fcn_segment/max_pool_2/MaxPool (59.90k/59.90k flops)
#   fcn_segment/conv_3/BiasAdd (55.30k/55.30k flops)
#   fcn_segment/max_pool_3/MaxPool (55.30k/55.30k flops)
#   fcn_segment/conv_4/BiasAdd (17.57k/17.57k flops)
#   fcn_segment/max_pool_4/MaxPool (17.57k/17.57k flops)
#   fcn_segment/conv_7/BiasAdd (9.22k/9.22k flops)
#   fcn_segment/conv_5/BiasAdd (6.05k/6.05k flops)
#   fcn_segment/max_pool_5/MaxPool (6.05k/6.05k flops)
#   fcn_segment/upsamping_6/BiasAdd (4.39k/4.39k flops)
#   fcn_segment/add_16/add (4.39k/4.39k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 6.461572
# 2022-04-30 08:13:42.527925: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:13:42.528008: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:13:42.529306: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
#
# 2022-04-30 08:13:42.698164: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:13:42.698237: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:13:42.699555: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/126.20m flops)
#   fcn_segment/conv_4/Conv2D (30.36m/30.36m flops)
#   fcn_segment/conv_2/Conv2D (28.04m/28.04m flops)
#   fcn_segment/conv_3/Conv2D (25.88m/25.88m flops)
#   fcn_segment/conv_7/Conv2D (20.24m/20.24m flops)
#   fcn_segment/conv_5/Conv2D (13.28m/13.28m flops)
#   fcn_segment/conv_1/Conv2D (4.31m/4.31m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (3.32m/3.32m flops)
#   fcn_segment/conv_1/BiasAdd (239.62k/239.62k flops)
#   fcn_segment/max_pool_1/MaxPool (239.62k/239.62k flops)
#   fcn_segment/conv_2/BiasAdd (59.90k/59.90k flops)
#   fcn_segment/max_pool_2/MaxPool (59.90k/59.90k flops)
#   fcn_segment/conv_3/BiasAdd (55.30k/55.30k flops)
#   fcn_segment/max_pool_3/MaxPool (55.30k/55.30k flops)
#   fcn_segment/conv_4/BiasAdd (17.57k/17.57k flops)
#   fcn_segment/max_pool_4/MaxPool (17.57k/17.57k flops)
#   fcn_segment/conv_7/BiasAdd (9.22k/9.22k flops)
#   fcn_segment/conv_5/BiasAdd (6.05k/6.05k flops)
#   fcn_segment/max_pool_5/MaxPool (6.05k/6.05k flops)
#   fcn_segment/upsamping_6/BiasAdd (4.39k/4.39k flops)
#   fcn_segment/add_16/add (4.39k/4.39k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 15.26234
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/348.35m flops)
#   fcn_segment/conv_2/Conv2D (79.63m/79.63m flops)
#   fcn_segment/conv_4/Conv2D (68.94m/68.94m flops)
#   fcn_segment/conv_5/Conv2D (64.63m/64.63m flops)
#   fcn_segment/conv_3/Conv2D (58.39m/58.39m flops)
#   fcn_segment/conv_7/Conv2D (50.14m/50.14m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (16.16m/16.16m flops)
#   fcn_segment/conv_1/Conv2D (8.85m/8.85m flops)
#   fcn_segment/conv_1/BiasAdd (491.52k/491.52k flops)
#   fcn_segment/max_pool_1/MaxPool (491.52k/491.52k flops)
#   fcn_segment/conv_2/BiasAdd (147.46k/147.46k flops)
#   fcn_segment/max_pool_2/MaxPool (147.46k/147.46k flops)
#   fcn_segment/conv_3/BiasAdd (90.11k/90.11k flops)
#   fcn_segment/max_pool_3/MaxPool (90.11k/90.11k flops)
#   fcn_segment/conv_4/BiasAdd (43.52k/43.52k flops)
#   fcn_segment/max_pool_4/MaxPool (43.52k/43.52k flops)
#   fcn_segment/conv_5/BiasAdd (21.12k/21.12k flops)
#   fcn_segment/max_pool_5/MaxPool (21.12k/21.12k flops)
#   fcn_segment/conv_7/BiasAdd (16.38k/16.38k flops)
#   fcn_segment/upsamping_6/BiasAdd (10.88k/10.88k flops)
#   fcn_segment/add_17/add (10.88k/10.88k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 15.26234
# 2022-04-30 08:13:42.873429: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:13:42.873501: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:13:42.874818: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/348.35m flops)
#   fcn_segment/conv_2/Conv2D (79.63m/79.63m flops)
#   fcn_segment/conv_4/Conv2D (68.94m/68.94m flops)
#   fcn_segment/conv_5/Conv2D (64.63m/64.63m flops)
#   fcn_segment/conv_3/Conv2D (58.39m/58.39m flops)
#   fcn_segment/conv_7/Conv2D (50.14m/50.14m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (16.16m/16.16m flops)
#   fcn_segment/conv_1/Conv2D (8.85m/8.85m flops)
#   fcn_segment/conv_1/BiasAdd (491.52k/491.52k flops)
#   fcn_segment/max_pool_1/MaxPool (491.52k/491.52k flops)
#   fcn_segment/conv_2/BiasAdd (147.46k/147.46k flops)
#   fcn_segment/max_pool_2/MaxPool (147.46k/147.46k flops)
#   fcn_segment/conv_3/BiasAdd (90.11k/90.11k flops)
#   fcn_segment/max_pool_3/MaxPool (90.11k/90.11k flops)
#   fcn_segment/conv_4/BiasAdd (43.52k/43.52k flops)
#   fcn_segment/max_pool_4/MaxPool (43.52k/43.52k flops)
#   fcn_segment/conv_5/BiasAdd (21.12k/21.12k flops)
#   fcn_segment/max_pool_5/MaxPool (21.12k/21.12k flops)
#   fcn_segment/conv_7/BiasAdd (16.38k/16.38k flops)
#   fcn_segment/upsamping_6/BiasAdd (10.88k/10.88k flops)
#   fcn_segment/add_17/add (10.88k/10.88k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 15.26234
# 2022-04-30 08:13:43.078218: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:13:43.078302: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:13:43.079639: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/348.35m flops)
#   fcn_segment/conv_2/Conv2D (79.63m/79.63m flops)
#   fcn_segment/conv_4/Conv2D (68.94m/68.94m flops)
#   fcn_segment/conv_5/Conv2D (64.63m/64.63m flops)
#   fcn_segment/conv_3/Conv2D (58.39m/58.39m flops)
#   fcn_segment/conv_7/Conv2D (50.14m/50.14m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (16.16m/16.16m flops)
#   fcn_segment/conv_1/Conv2D (8.85m/8.85m flops)
#   fcn_segment/conv_1/BiasAdd (491.52k/491.52k flops)
#   fcn_segment/max_pool_1/MaxPool (491.52k/491.52k flops)
#   fcn_segment/conv_2/BiasAdd (147.46k/147.46k flops)
#   fcn_segment/max_pool_2/MaxPool (147.46k/147.46k flops)
#   fcn_segment/conv_3/BiasAdd (90.11k/90.11k flops)
#   fcn_segment/max_pool_3/MaxPool (90.11k/90.11k flops)
#   fcn_segment/conv_4/BiasAdd (43.52k/43.52k flops)
#   fcn_segment/max_pool_4/MaxPool (43.52k/43.52k flops)
#   fcn_segment/conv_5/BiasAdd (21.12k/21.12k flops)
#   fcn_segment/max_pool_5/MaxPool (21.12k/21.12k flops)
#   fcn_segment/conv_7/BiasAdd (16.38k/16.38k flops)
#   fcn_segment/upsamping_6/BiasAdd (10.88k/10.88k flops)
#   fcn_segment/add_17/add (10.88k/10.88k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 15.26234
# 2022-04-30 08:13:43.283364: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:13:43.283437: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:13:43.284797: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
#
# 2022-04-30 08:13:43.472415: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:13:43.472496: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:13:43.473799: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/348.35m flops)
#   fcn_segment/conv_2/Conv2D (79.63m/79.63m flops)
#   fcn_segment/conv_4/Conv2D (68.94m/68.94m flops)
#   fcn_segment/conv_5/Conv2D (64.63m/64.63m flops)
#   fcn_segment/conv_3/Conv2D (58.39m/58.39m flops)
#   fcn_segment/conv_7/Conv2D (50.14m/50.14m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (16.16m/16.16m flops)
#   fcn_segment/conv_1/Conv2D (8.85m/8.85m flops)
#   fcn_segment/conv_1/BiasAdd (491.52k/491.52k flops)
#   fcn_segment/max_pool_1/MaxPool (491.52k/491.52k flops)
#   fcn_segment/conv_2/BiasAdd (147.46k/147.46k flops)
#   fcn_segment/max_pool_2/MaxPool (147.46k/147.46k flops)
#   fcn_segment/conv_3/BiasAdd (90.11k/90.11k flops)
#   fcn_segment/max_pool_3/MaxPool (90.11k/90.11k flops)
#   fcn_segment/conv_4/BiasAdd (43.52k/43.52k flops)
#   fcn_segment/max_pool_4/MaxPool (43.52k/43.52k flops)
#   fcn_segment/conv_5/BiasAdd (21.12k/21.12k flops)
#   fcn_segment/max_pool_5/MaxPool (21.12k/21.12k flops)
#   fcn_segment/conv_7/BiasAdd (16.38k/16.38k flops)
#   fcn_segment/upsamping_6/BiasAdd (10.88k/10.88k flops)
#   fcn_segment/add_17/add (10.88k/10.88k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 15.26234
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/348.35m flops)
#   fcn_segment/conv_2/Conv2D (79.63m/79.63m flops)
#   fcn_segment/conv_4/Conv2D (68.94m/68.94m flops)
#   fcn_segment/conv_5/Conv2D (64.63m/64.63m flops)
#   fcn_segment/conv_3/Conv2D (58.39m/58.39m flops)
#   fcn_segment/conv_7/Conv2D (50.14m/50.14m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (16.16m/16.16m flops)
#   fcn_segment/conv_1/Conv2D (8.85m/8.85m flops)
#   fcn_segment/conv_1/BiasAdd (491.52k/491.52k flops)
#   fcn_segment/max_pool_1/MaxPool (491.52k/491.52k flops)
#   fcn_segment/conv_2/BiasAdd (147.46k/147.46k flops)
#   fcn_segment/max_pool_2/MaxPool (147.46k/147.46k flops)
#   fcn_segment/conv_3/BiasAdd (90.11k/90.11k flops)
#   fcn_segment/max_pool_3/MaxPool (90.11k/90.11k flops)
#   fcn_segment/conv_4/BiasAdd (43.52k/43.52k flops)
#   fcn_segment/max_pool_4/MaxPool (43.52k/43.52k flops)
#   fcn_segment/conv_5/BiasAdd (21.12k/21.12k flops)
#   fcn_segment/max_pool_5/MaxPool (21.12k/21.12k flops)
#   fcn_segment/conv_7/BiasAdd (16.38k/16.38k flops)
#   fcn_segment/upsamping_6/BiasAdd (10.88k/10.88k flops)
#   fcn_segment/add_17/add (10.88k/10.88k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 15.26234
# 2022-04-30 08:13:43.668106: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:13:43.668186: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:13:43.669513: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
#
# 2022-04-30 08:13:43.855952: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:13:43.856030: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:13:43.857406: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/348.35m flops)
#   fcn_segment/conv_2/Conv2D (79.63m/79.63m flops)
#   fcn_segment/conv_4/Conv2D (68.94m/68.94m flops)
#   fcn_segment/conv_5/Conv2D (64.63m/64.63m flops)
#   fcn_segment/conv_3/Conv2D (58.39m/58.39m flops)
#   fcn_segment/conv_7/Conv2D (50.14m/50.14m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (16.16m/16.16m flops)
#   fcn_segment/conv_1/Conv2D (8.85m/8.85m flops)
#   fcn_segment/conv_1/BiasAdd (491.52k/491.52k flops)
#   fcn_segment/max_pool_1/MaxPool (491.52k/491.52k flops)
#   fcn_segment/conv_2/BiasAdd (147.46k/147.46k flops)
#   fcn_segment/max_pool_2/MaxPool (147.46k/147.46k flops)
#   fcn_segment/conv_3/BiasAdd (90.11k/90.11k flops)
#   fcn_segment/max_pool_3/MaxPool (90.11k/90.11k flops)
#   fcn_segment/conv_4/BiasAdd (43.52k/43.52k flops)
#   fcn_segment/max_pool_4/MaxPool (43.52k/43.52k flops)
#   fcn_segment/conv_5/BiasAdd (21.12k/21.12k flops)
#   fcn_segment/max_pool_5/MaxPool (21.12k/21.12k flops)
#   fcn_segment/conv_7/BiasAdd (16.38k/16.38k flops)
#   fcn_segment/upsamping_6/BiasAdd (10.88k/10.88k flops)
#   fcn_segment/add_17/add (10.88k/10.88k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 15.26234
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# ...
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/3.33b flops)
#   fcn_segment/conv_5/Conv2D (1.23b/1.23b flops)
#   fcn_segment/conv_7/Conv2D (666.61m/666.61m flops)
#   fcn_segment/conv_4/Conv2D (437.46m/437.46m flops)
#   fcn_segment/conv_2/Conv2D (392.49m/392.49m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (307.27m/307.27m flops)
#   fcn_segment/conv_3/Conv2D (228.95m/228.95m flops)
#   fcn_segment/conv_1/Conv2D (56.07m/56.07m flops)
#   fcn_segment/conv_1/BiasAdd (3.12m/3.12m flops)
#   fcn_segment/max_pool_1/MaxPool (3.12m/3.12m flops)
#   fcn_segment/conv_2/BiasAdd (1.21m/1.21m flops)
#   fcn_segment/max_pool_2/MaxPool (1.21m/1.21m flops)
#   fcn_segment/conv_4/BiasAdd (578.66k/578.66k flops)
#   fcn_segment/max_pool_4/MaxPool (578.66k/578.66k flops)
#   fcn_segment/conv_3/BiasAdd (454.27k/454.27k flops)
#   fcn_segment/max_pool_3/MaxPool (454.27k/454.27k flops)
#   fcn_segment/conv_5/BiasAdd (319.07k/319.07k flops)
#   fcn_segment/max_pool_5/MaxPool (319.07k/319.07k flops)
#   fcn_segment/conv_7/BiasAdd (173.06k/173.06k flops)
#   fcn_segment/upsamping_6/BiasAdd (144.66k/144.66k flops)
#   fcn_segment/add_26/add (144.66k/144.66k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 178.377476
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/3.33b flops)
#   fcn_segment/conv_5/Conv2D (1.23b/1.23b flops)
#   fcn_segment/conv_7/Conv2D (666.61m/666.61m flops)
#   fcn_segment/conv_4/Conv2D (437.46m/437.46m flops)
#   fcn_segment/conv_2/Conv2D (392.49m/392.49m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (307.27m/307.27m flops)
#   fcn_segment/conv_3/Conv2D (228.95m/228.95m flops)
#   fcn_segment/conv_1/Conv2D (56.07m/56.07m flops)
#   fcn_segment/conv_1/BiasAdd (3.12m/3.12m flops)
#   fcn_segment/max_pool_1/MaxPool (3.12m/3.12m flops)
#   fcn_segment/conv_2/BiasAdd (1.21m/1.21m flops)
#   fcn_segment/max_pool_2/MaxPool (1.21m/1.21m flops)
#   fcn_segment/conv_4/BiasAdd (578.66k/578.66k flops)
#   fcn_segment/max_pool_4/MaxPool (578.66k/578.66k flops)
#   fcn_segment/conv_3/BiasAdd (454.27k/454.27k flops)
#   fcn_segment/max_pool_3/MaxPool (454.27k/454.27k flops)
#   fcn_segment/conv_5/BiasAdd (319.07k/319.07k flops)
#   fcn_segment/max_pool_5/MaxPool (319.07k/319.07k flops)
#   fcn_segment/conv_7/BiasAdd (173.06k/173.06k flops)
#   fcn_segment/upsamping_6/BiasAdd (144.66k/144.66k flops)
#   fcn_segment/add_26/add (144.66k/144.66k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 178.377476
# 2022-04-30 08:14:00.510963: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:14:00.511037: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:14:00.512650: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
#
# 2022-04-30 08:14:00.709314: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:14:00.709390: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:14:00.710948: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/3.33b flops)
#   fcn_segment/conv_5/Conv2D (1.23b/1.23b flops)
#   fcn_segment/conv_7/Conv2D (666.61m/666.61m flops)
#   fcn_segment/conv_4/Conv2D (437.46m/437.46m flops)
#   fcn_segment/conv_2/Conv2D (392.49m/392.49m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (307.27m/307.27m flops)
#   fcn_segment/conv_3/Conv2D (228.95m/228.95m flops)
#   fcn_segment/conv_1/Conv2D (56.07m/56.07m flops)
#   fcn_segment/conv_1/BiasAdd (3.12m/3.12m flops)
#   fcn_segment/max_pool_1/MaxPool (3.12m/3.12m flops)
#   fcn_segment/conv_2/BiasAdd (1.21m/1.21m flops)
#   fcn_segment/max_pool_2/MaxPool (1.21m/1.21m flops)
#   fcn_segment/conv_4/BiasAdd (578.66k/578.66k flops)
#   fcn_segment/max_pool_4/MaxPool (578.66k/578.66k flops)
#   fcn_segment/conv_3/BiasAdd (454.27k/454.27k flops)
#   fcn_segment/max_pool_3/MaxPool (454.27k/454.27k flops)
#   fcn_segment/conv_5/BiasAdd (319.07k/319.07k flops)
#   fcn_segment/max_pool_5/MaxPool (319.07k/319.07k flops)
#   fcn_segment/conv_7/BiasAdd (173.06k/173.06k flops)
#   fcn_segment/upsamping_6/BiasAdd (144.66k/144.66k flops)
#   fcn_segment/add_26/add (144.66k/144.66k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 178.377476
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/3.33b flops)
#   fcn_segment/conv_5/Conv2D (1.23b/1.23b flops)
#   fcn_segment/conv_7/Conv2D (666.61m/666.61m flops)
#   fcn_segment/conv_4/Conv2D (437.46m/437.46m flops)
#   fcn_segment/conv_2/Conv2D (392.49m/392.49m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (307.27m/307.27m flops)
#   fcn_segment/conv_3/Conv2D (228.95m/228.95m flops)
#   fcn_segment/conv_1/Conv2D (56.07m/56.07m flops)
#   fcn_segment/conv_1/BiasAdd (3.12m/3.12m flops)
#   fcn_segment/max_pool_1/MaxPool (3.12m/3.12m flops)
#   fcn_segment/conv_2/BiasAdd (1.21m/1.21m flops)
#   fcn_segment/max_pool_2/MaxPool (1.21m/1.21m flops)
#   fcn_segment/conv_4/BiasAdd (578.66k/578.66k flops)
#   fcn_segment/max_pool_4/MaxPool (578.66k/578.66k flops)
#   fcn_segment/conv_3/BiasAdd (454.27k/454.27k flops)
#   fcn_segment/max_pool_3/MaxPool (454.27k/454.27k flops)
#   fcn_segment/conv_5/BiasAdd (319.07k/319.07k flops)
#   fcn_segment/max_pool_5/MaxPool (319.07k/319.07k flops)
#   fcn_segment/conv_7/BiasAdd (173.06k/173.06k flops)
#   fcn_segment/upsamping_6/BiasAdd (144.66k/144.66k flops)
#   fcn_segment/add_26/add (144.66k/144.66k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 178.377476
# 2022-04-30 08:14:00.906916: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:14:00.906992: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:14:00.908637: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
#
# 2022-04-30 08:14:01.103307: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:14:01.103385: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:14:01.105009: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/3.33b flops)
#   fcn_segment/conv_5/Conv2D (1.23b/1.23b flops)
#   fcn_segment/conv_7/Conv2D (666.61m/666.61m flops)
#   fcn_segment/conv_4/Conv2D (437.46m/437.46m flops)
#   fcn_segment/conv_2/Conv2D (392.49m/392.49m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (307.27m/307.27m flops)
#   fcn_segment/conv_3/Conv2D (228.95m/228.95m flops)
#   fcn_segment/conv_1/Conv2D (56.07m/56.07m flops)
#   fcn_segment/conv_1/BiasAdd (3.12m/3.12m flops)
#   fcn_segment/max_pool_1/MaxPool (3.12m/3.12m flops)
#   fcn_segment/conv_2/BiasAdd (1.21m/1.21m flops)
#   fcn_segment/max_pool_2/MaxPool (1.21m/1.21m flops)
#   fcn_segment/conv_4/BiasAdd (578.66k/578.66k flops)
#   fcn_segment/max_pool_4/MaxPool (578.66k/578.66k flops)
#   fcn_segment/conv_3/BiasAdd (454.27k/454.27k flops)
#   fcn_segment/max_pool_3/MaxPool (454.27k/454.27k flops)
#   fcn_segment/conv_5/BiasAdd (319.07k/319.07k flops)
#   fcn_segment/max_pool_5/MaxPool (319.07k/319.07k flops)
#   fcn_segment/conv_7/BiasAdd (173.06k/173.06k flops)
#   fcn_segment/upsamping_6/BiasAdd (144.66k/144.66k flops)
#   fcn_segment/add_26/add (144.66k/144.66k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 178.377476
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/3.33b flops)
#   fcn_segment/conv_5/Conv2D (1.23b/1.23b flops)
#   fcn_segment/conv_7/Conv2D (666.61m/666.61m flops)
#   fcn_segment/conv_4/Conv2D (437.46m/437.46m flops)
#   fcn_segment/conv_2/Conv2D (392.49m/392.49m flops)
#   fcn_segment/upsamping_6/conv2d_transpose (307.27m/307.27m flops)
#   fcn_segment/conv_3/Conv2D (228.95m/228.95m flops)
#   fcn_segment/conv_1/Conv2D (56.07m/56.07m flops)
#   fcn_segment/conv_1/BiasAdd (3.12m/3.12m flops)
#   fcn_segment/max_pool_1/MaxPool (3.12m/3.12m flops)
#   fcn_segment/conv_2/BiasAdd (1.21m/1.21m flops)
#   fcn_segment/max_pool_2/MaxPool (1.21m/1.21m flops)
#   fcn_segment/conv_4/BiasAdd (578.66k/578.66k flops)
#   fcn_segment/max_pool_4/MaxPool (578.66k/578.66k flops)
#   fcn_segment/conv_3/BiasAdd (454.27k/454.27k flops)
#   fcn_segment/max_pool_3/MaxPool (454.27k/454.27k flops)
#   fcn_segment/conv_5/BiasAdd (319.07k/319.07k flops)
#   fcn_segment/max_pool_5/MaxPool (319.07k/319.07k flops)
#   fcn_segment/conv_7/BiasAdd (173.06k/173.06k flops)
#   fcn_segment/upsamping_6/BiasAdd (144.66k/144.66k flops)
#   fcn_segment/add_26/add (144.66k/144.66k flops)
#   fcn_segment/upsamping_7/mul (2/2 flops)
#
# ======================End of Report==========================
# 2022-04-30 08:14:01.303493: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-30 08:14:01.303571: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-30 08:14:01.305149: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
