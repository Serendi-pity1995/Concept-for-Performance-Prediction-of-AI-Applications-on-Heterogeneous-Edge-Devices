# %%
from keras.layers import *
from keras.models import Model
from keras import optimizers
import numpy as np
from tensorflow_model_optimization.quantization.keras import vitis_quantize
import os
from keras import backend as K


shape_range =range(96,512,32)
for shape_x in shape_range:
    shape_y = shape_x
    X_train=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
    Y_train=np.random.randint(0,10,size=[60,])
    X_test=np.random.randint(0,255,size=[60,shape_x,shape_y,1])
    Y_test=np.random.randint(0,10,size=[60,])
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
    X_train /= 255.0
    X_test /= 255.0
    
    inputs = tf.keras.Input(shape=(shape_x,shape_y,1))
    x = tf.keras.layers.Conv2D(32, (3,3), activation='relu')(inputs)
    x = tf.keras.layers.MaxPooling2D((2,2))(x)
    x = tf.keras.layers.Conv2D(32, (3,3), activation='relu')(x)
    x = tf.keras.layers.MaxPooling2D((2,2))(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(1024, activation='relu')(x)
    x = tf.keras.layers.Dense(512, activation='relu')(x)
    x = tf.keras.layers.Dense(256, activation='relu')(x)
    outputs = tf.keras.layers.Dense(10, activation='softmax')(x)
    
    model = tf.keras.Model(inputs=inputs, outputs=outputs, name='mnist_classifier')
    model.summary()
    
    #model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    #history = model.fit(X_train, Y_train, epochs=1)
    quantizer = vitis_quantize.VitisQuantizer(model)
    quantized_model = quantizer.quantize_model(calib_dataset = X_test[1:10], weight_bit=8, activation_bit=8)
    quantized_model.compile(loss='sparse_categorical_crossentropy', metrics=["accuracy"])
    quantized_model.save('quantized.h5')
    # !vai_c_tensorflow2 \
    --model ./quantized.h5 \
    --arch ./arch.json \
    --output_dir ./xmodel_simple \
    --net_name deploy
    os.rename("./xmodel_simple/deploy.xmodel","./xmodel_simple/simple_{shape_x}_{shape_y}.xmodel".format(shape_x=shape_x,shape_y=shape_y))
# Out:
# Model: "mnist_classifier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_14 (InputLayer)        [(None, 96, 96, 1)]       0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 94, 94, 32)        320
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 47, 47, 32)        0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 45, 45, 32)        9248
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 22, 22, 32)        0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 15488)             0
# _________________________________________________________________
# dense_50 (Dense)             (None, 1024)              15860736
# _________________________________________________________________
# dense_51 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_52 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_53 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 16,529,002
# Trainable params: 16,529,002
# Non-trainable params: 0
# _________________________________________________________________
# [VAI INFO] Update custom_layer_type: []
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 2s 201ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1230/854817503.py in <module>
#      37     #history = model.fit(X_train, Y_train, epochs=1)
#      38     quantizer = vitis_quantize.VitisQuantizer(model)
# ---> 39     quantized_model = quantizer.quantize_model(calib_dataset = X_test[1:10], weight_bit=8, activation_bit=8)
#      40     quantized_model.compile(loss='sparse_categorical_crossentropy', metrics=["accuracy"])
#      41     quantized_model.save('quantized.h5')
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/vitis_quantize.py in quantize_model(self, loss, metrics, calib_dataset, calib_batch_size, calib_steps, eval_dataset, verbose, add_shape_info, input_shape, configs, **kwargs)
#     576       else:
#     577         self._calibrate_without_loss(calib_dataset, calib_batch_size,
# --> 578                                      calib_steps)
#     579
#     580         # Post-quantize adjustment (Only for 8bit)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/vitis_quantize.py in _calibrate_without_loss(self, calib_dataset, calib_batch_size, calib_steps)
#     273     logger.info("Start Quantize Calibration...")
#     274     collector = self._run_model_with_collector(self._qcb_model, calib_dataset,
# --> 275                                                calib_batch_size, calib_steps)
#     276
#     277     #  Create quantize calibration evaluation model
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/vitis_quantize.py in _run_model_with_collector(self, model, dataset, batch_size, steps)
#     217         verbose=1,
#     218         steps=steps,
# --> 219         callbacks=[collector])
#     220     return collector
#     221
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1749           for step in data_handler.steps():
#    1750             callbacks.on_predict_batch_begin(step)
# -> 1751             tmp_batch_outputs = self.predict_function(iterator)
#    1752             if data_handler.should_sync:
#    1753               context.async_wait()
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     931       # This is the first call of __call__, so we have to initialize.
#     932       initializers = []
# --> 933       self._initialize(args, kwds, add_initializers_to=initializers)
#     934     finally:
#     935       # At this point we know that the initialization is complete (or less
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     758     self._concrete_stateful_fn = (
#     759         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 760             *args, **kwds))
#     761
#     762     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3064       args, kwargs = None, None
#    3065     with self._lock:
# -> 3066       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3067     return graph_function
#    3068
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3461
#    3462           self._function_cache.missed.add(call_context_key)
# -> 3463           graph_function = self._create_graph_function(args, kwargs)
#    3464           self._function_cache.primary[cache_key] = graph_function
#    3465
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3306             arg_names=arg_names,
#    3307             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3308             capture_by_value=self._capture_by_value),
#    3309         self._function_attributes,
#    3310         function_spec=self.function_spec,
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1005         _, original_func = tf_decorator.unwrap(python_func)
#    1006
# -> 1007       func_outputs = python_func(*func_args, **func_kwargs)
#    1008
#    1009       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     666         # the function a weak reference to itself to avoid a reference cycle.
#     667         with OptionalXlaContext(compile_with_xla):
# --> 668           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     669         return out
#     670
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     988                     recursive=True,
#     989                     optional_features=autograph_options,
# --> 990                     user_requested=True,
#     991                 ))
#     992           except Exception as e:  # pylint:disable=broad-except
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     380
#     381   if not options.user_requested and conversion.is_allowlisted(f):
# --> 382     return _call_unconverted(f, args, kwargs, options)
#     383
#     384   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     462   if kwargs is not None:
#     463     return f(*args, **kwargs)
# --> 464   return f(*args)
#     465
#     466
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/training.py in step_function(model, iterator)
#    1574
#    1575       data = next(iterator)
# -> 1576       outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1577       outputs = reduce_per_replica(
#    1578           outputs, self.distribute_strategy, reduction='concat')
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1284       fn = autograph.tf_convert(
#    1285           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1286       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1287
#    1288   def reduce(self, reduce_op, value, axis):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2847       kwargs = {}
#    2848     with self._container_strategy().scope():
# -> 2849       return self._call_for_each_replica(fn, args, kwargs)
#    2850
#    2851   def _call_for_each_replica(self, fn, args, kwargs):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    3630   def _call_for_each_replica(self, fn, args, kwargs):
#    3631     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3632       return fn(*args, **kwargs)
#    3633
#    3634   def _reduce_to(self, reduce_op, value, destinations, options):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     690       try:
#     691         with conversion_ctx:
# --> 692           return converted_call(f, args, kwargs, options=options)
#     693       except Exception as e:  # pylint:disable=broad-except
#     694         if hasattr(e, 'ag_error_metadata'):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     380
#     381   if not options.user_requested and conversion.is_allowlisted(f):
# --> 382     return _call_unconverted(f, args, kwargs, options)
#     383
#     384   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     461
#     462   if kwargs is not None:
# --> 463     return f(*args, **kwargs)
#     464   return f(*args)
#     465
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/training.py in run_step(data)
#    1567
#    1568       def run_step(data):
# -> 1569         outputs = model.predict_step(data)
#    1570         # Ensure counter is updated only if `test_step` succeeds.
#    1571         with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/training.py in predict_step(self, data)
#    1535     data = data_adapter.expand_1d(data)
#    1536     x, _, _ = data_adapter.unpack_x_y_sample_weight(data)
# -> 1537     return self(x, training=False)
#    1538
#    1539   def make_predict_function(self, force=False):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/functional.py in call(self, inputs, training, mask)
#     413     """
#     414     return self._run_internal_graph(
# --> 415         inputs, training=training, mask=mask)
#     416
#     417   def compute_output_shape(self, input_shape):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     548
#     549         args, kwargs = node.map_arguments(tensor_dict)
# --> 550         outputs = node.layer(*args, **kwargs)
#     551
#     552         # Update tensor_dict.
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     690       try:
#     691         with conversion_ctx:
# --> 692           return converted_call(f, args, kwargs, options=options)
#     693       except Exception as e:  # pylint:disable=broad-except
#     694         if hasattr(e, 'ag_error_metadata'):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_wrapper.py in tf__call(self, inputs, training)
#      73                     outputs = ag__.converted_call(ag__.ld(self).layer.call, (ag__.ld(inputs),), None, fscope)
#      74                 outputs = ag__.Undefined('outputs')
# ---> 75                 ag__.if_stmt(('training' in ag__.ld(args)), if_body_1, else_body_1, get_state_3, set_state_3, ('outputs',), 1)
#      76
#      77                 def get_state_6():
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1172     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1173   else:
# -> 1174     _py_if_stmt(cond, body, orelse)
#    1175
#    1176
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1225 def _py_if_stmt(cond, body, orelse):
#    1226   """Overload of if_stmt that executes a Python if statement."""
# -> 1227   return body() if cond else orelse()
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_wrapper.py in else_body_1()
#      71                 def else_body_1():
#      72                     nonlocal outputs
# ---> 73                     outputs = ag__.converted_call(ag__.ld(self).layer.call, (ag__.ld(inputs),), None, fscope)
#      74                 outputs = ag__.Undefined('outputs')
#      75                 ag__.if_stmt(('training' in ag__.ld(args)), if_body_1, else_body_1, get_state_3, set_state_3, ('outputs',), 1)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     334   if conversion.is_in_allowlist_cache(f, options):
#     335     logging.log(2, 'Allowlisted %s: from cache', f)
# --> 336     return _call_unconverted(f, args, kwargs, options, False)
#     337
#     338   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     462   if kwargs is not None:
#     463     return f(*args, **kwargs)
# --> 464   return f(*args)
#     465
#     466
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/layers/core.py in call(self, inputs)
#    1241
#    1242     if self.activation is not None:
# -> 1243       outputs = self.activation(outputs)
#    1244     return outputs
#    1245
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_aware_activation.py in __call__(self, inputs, *args, **kwargs)
#     209                             self._post_activation_vars),
#     210           make_quantizer_fn(self.quantizer, x, False, self.mode,
# --> 211                             self._post_activation_vars))
#     212
#     213     return x
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/utils/common_utils.py in smart_cond(pred, true_fn, false_fn, name)
#     114         pred, true_fn=true_fn, false_fn=false_fn, name=name)
#     115   return smart_module.smart_cond(
# --> 116       pred, true_fn=true_fn, false_fn=false_fn, name=name)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/framework/smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      56       return true_fn()
#      57     else:
# ---> 58       return false_fn()
#      59   else:
#      60     return control_flow_ops.cond(pred, true_fn=true_fn, false_fn=false_fn,
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_aware_activation.py in quantizer_fn()
#     188
#     189       def quantizer_fn():
# --> 190         return quantizer(x, training, mode, weights=quantizer_vars)
#     191
#     192       return quantizer_fn
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantizers.py in __call__(self, inputs, is_training, mode, weights, **kwargs)
#     379         symmetry=self.symmetry,
#     380         per_channel=self.per_channel,
# --> 381         channel_axis=self.channel_axis)
#     382
#     383   def get_config(self):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_ops.py in LastValueQuantPosQuantize(inputs, quant_pos_var, min_var, max_var, bit_width, method, round_mode, mode, is_training, symmetry, per_channel, channel_axis, name_scope)
#    1085       else:
#    1086         if symmetry:
# -> 1087           return quantize_kernel(inputs, assign_quantize_pos, bit_width)
#    1088         else:
#    1089           return quantize_kernel(inputs, assign_quantize_pos, assign_min,
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/ops/custom_gradient.py in __call__(self, *a, **k)
#     307
#     308   def __call__(self, *a, **k):
# --> 309     return self._d(self._f, a, k)
#     310
#     311
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/ops/custom_gradient.py in decorated(wrapped, args, kwargs)
#     263       return _eager_mode_decorator(wrapped, args, kwargs)
#     264     else:
# --> 265       return _graph_mode_decorator(wrapped, args, kwargs)
#     266
#     267   return tf_decorator.make_decorator(f, decorated(f))  # pylint: disable=no-value-for-parameter
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/ops/custom_gradient.py in _graph_mode_decorator(f, args, kwargs)
#     380   ])
#     381   with tape_lib.VariableWatcher() as variable_watcher:
# --> 382     result, grad_fn = f(*args)
#     383
#     384   args = nest.flatten(args)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/quantization/keras/vitis/common/vitis_quantize_ops.py in fake_quantize_with_quantize_pos_dpu_sym(inputs, quantize_pos, bit_width)
#     500
#     501   with tf.name_scope("FakeQuantizeWithQuantizePosDpuSym"):
# --> 502     bit_width = tf.cast(bit_width, dtype=tf.float32, name="bit_width")
#     503     bound = tf.math.pow(2.0, bit_width - 1)
#     504     q_min = tf.math.negative(bound, name="q_min")
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py in cast(x, dtype, name)
#     988       x = ops.convert_to_tensor(x, name="x")
#     989       if x.dtype.base_dtype != base_type:
# --> 990         x = gen_math_ops.cast(x, base_type, name=name)
#     991     if x.dtype.is_complex and base_type.is_floating:
#     992       logging.warn("Casting complex to real discards imaginary part.")
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/ops/gen_math_ops.py in cast(x, DstT, Truncate, name)
#    1955   Truncate = _execute.make_bool(Truncate, "Truncate")
#    1956   _, _, _op, _outputs = _op_def_library._apply_op_helper(
# -> 1957         "Cast", x=x, DstT=DstT, Truncate=Truncate, name=name)
#    1958   _result = _outputs[:]
#    1959   if _execute.must_record_gradient():
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     748       op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     749                                  name=scope, input_types=input_types,
# --> 750                                  attrs=attr_protos, op_def=op_def)
#     751
#     752     # `outputs` is returned as a separate return value so that the output
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     599     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     600         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
# --> 601         compute_device)
#     602
#     603   def capture(self, tensor, name=None, shape=None):
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3567           input_types=input_types,
#    3568           original_op=self._default_original_op,
# -> 3569           op_def=op_def)
#    3570       self._create_op_helper(ret, compute_device=compute_device)
#    3571     return ret
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2040         op_def = self._graph._get_op_def(node_def.op)
#    2041       self._c_op = _create_c_op(self._graph, node_def, inputs,
# -> 2042                                 control_input_ops, op_def)
#    2043       name = compat.as_str(node_def.name)
#    2044
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1878
#    1879   try:
# -> 1880     c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1881   except errors.InvalidArgumentError as e:
#    1882     # Convert to ValueError for backwards compatibility.
#
# KeyboardInterrupt:
