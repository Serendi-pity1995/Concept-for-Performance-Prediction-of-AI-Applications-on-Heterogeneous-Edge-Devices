# %%
import os
import csv
import numpy as np
import tensorflow as tf
import keras
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, ZeroPadding2D, Dropout, Activation
from itertools import product
from keras_flops import get_flops

def get_total_number_of_neurons(model, include_output_layer):
    '''
    Args:
        model: Keras model
        include_output_layer: A boolean parameter. Whether or not to include output layer's neurons into the calculation

    Returns: number of neurons in the given model
    '''
    num_layers = len(model.layers)
    total_num_of_neurons = 0
    for layer_index in range(num_layers):
        layer = model.layers[layer_index]
        # since we multiply layer output dimensions, initial value is set to 1.
        num_neurons_in_layer = 1
        for i in range(1, len(layer.output.shape)):
            try:
                # when it is a valid layer to count neurons, an output dimension of the layer can be convertible to int.
                num_neurons_in_layer *= int(layer.output.shape[i])
            except Exception:
                # if the output dimension of layer cannot be convertible to int,
                # just pass that layer since it is not a valid layer to count neurons
                pass
        # if num_neurons_in_layer is not still 1, it means we have a valid layer to count neurons
        if not num_neurons_in_layer == 1:
            # when it is an output layer
            if layer_index == (num_layers - 1):
                if include_output_layer:
                    total_num_of_neurons += num_neurons_in_layer
            else:  # when it is not an output layer
                total_num_of_neurons += num_neurons_in_layer
    return total_num_of_neurons

model_num = 1
input_shape_range =range(32,512,2)

with open("para_count_vgg13.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "step","number_of_layers", "FLOPs_G", "Total_params_M", "Memory_M", "total_num_of_neurons_M"],])
path = "../vgg13_h5" 
files= os.listdir(path) 

for shape_x in input_shape_range:
    shape_y = shape_x
    for step in range(1,11):
        file = "vgg13_{input_x}_{input_y}_{step}.h5".format(input_x=shape_x,input_y=shape_y,step=step)
        if file in files: 
            model_name = str(file)
            if not os.path.isdir(file): 
                model = keras.models.load_model("../vgg13_h5/{}".format(model_name))
                num_neurons = get_total_number_of_neurons(model= model, include_output_layer= True)
                num_neurons_M = num_neurons/10**6
                # how to compute the memory allocated by the activations of a model
                batch = 1
                shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
                else 1 for s in l.output_shape])) 
                for l in model.layers]))
                memory = (shapes_count * 4 * batch)/10**6
                print(memory)
                layers_length = len(model.layers)
                Total_params = round(model.count_params()/10 ** 6,2)
                FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
                with open("para_count_vgg13.csv","a+") as csvfile:
                    writer = csv.writer(csvfile)
                    writer.writerows([[model_num, shape_x, shape_y, step, layers_length, FLOPs, Total_params, memory, num_neurons_M],])

                    model_num = model_num + 1
# Out:
# 2022-05-16 04:17:26.767789: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-05-16 04:17:26.767807: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-05-16 04:17:27.879093: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-05-16 04:17:27.879110: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-16 04:17:27.879123: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2022-05-16 04:17:27.879252: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 0.858396
# 2022-05-16 04:17:28.459909: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:28.460012: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:28.481686: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.007ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# WARNING:tensorflow:From /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py:5063: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/237.36m flops)
#   model/conv2d_1/Conv2D (37.75m/37.75m flops)
#   model/conv2d_7/Conv2D (37.30m/37.30m flops)
#   model/conv2d_5/Conv2D (36.77m/36.77m flops)
#   model/conv2d_3/Conv2D (28.33m/28.33m flops)
#   model/conv2d_4/Conv2D (20.51m/20.51m flops)
#   model/conv2d_6/Conv2D (19.15m/19.15m flops)
#   model/conv2d_9/Conv2D (18.00m/18.00m flops)
#   model/conv2d_2/Conv2D (17.10m/17.10m flops)
#   model/conv2d_8/Conv2D (13.16m/13.16m flops)
#   model/dense_1/MatMul (6.31m/6.31m flops)
#   model/dense/MatMul (2.06m/2.06m flops)
#   model/conv2d/Conv2D (589.82k/589.82k flops)
#   model/conv2d_1/BiasAdd (65.54k/65.54k flops)
#   model/max_pooling2d/MaxPool (65.54k/65.54k flops)
#   model/conv2d/BiasAdd (32.77k/32.77k flops)
#   model/dense_2/MatMul (31.04k/31.04k flops)
#   model/conv2d_3/BiasAdd (27.14k/27.14k flops)
#   model/max_pooling2d_1/MaxPool (27.14k/27.14k flops)
#   model/conv2d_2/BiasAdd (14.85k/14.85k flops)
#   model/conv2d_5/BiasAdd (12.16k/12.16k flops)
#   model/max_pooling2d_2/MaxPool (12.16k/12.16k flops)
#   model/conv2d_4/BiasAdd (10.75k/10.75k flops)
#   model/conv2d_7/BiasAdd (5.92k/5.92k flops)
#   model/max_pooling2d_3/MaxPool (5.92k/5.92k flops)
#   model/conv2d_6/BiasAdd (5.60k/5.60k flops)
#   model/dense/BiasAdd (2.03k/2.03k flops)
#   model/max_pooling2d_4/MaxPool (2.02k/2.02k flops)
#   model/conv2d_9/BiasAdd (2.02k/2.02k flops)
#   model/conv2d_8/BiasAdd (1.98k/1.98k flops)
#   model/dense_1/BiasAdd (1.55k/1.55k flops)
#   model/dense_2/Softmax (50/50 flops)
#   model/dense_2/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.982876
# 2022-05-16 04:17:29.269956: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:29.270030: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:29.271348: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/361.45m flops)
#   model_1/conv2d_15/Conv2D (65.18m/65.18m flops)
#   model_1/conv2d_17/Conv2D (59.38m/59.38m flops)
#   model_1/conv2d_13/Conv2D (55.74m/55.74m flops)
#   model_1/conv2d_11/Conv2D (40.11m/40.11m flops)
#   model_1/conv2d_12/Conv2D (31.85m/31.85m flops)
#   model_1/conv2d_16/Conv2D (30.18m/30.18m flops)
#   model_1/conv2d_14/Conv2D (29.68m/29.68m flops)
#   model_1/conv2d_19/Conv2D (17.35m/17.35m flops)
#   model_1/conv2d_18/Conv2D (16.87m/16.87m flops)
#   model_1/dense_4/MatMul (11.67m/11.67m flops)
#   model_1/dense_3/MatMul (2.44m/2.44m flops)
#   model_1/conv2d_10/Conv2D (626.69k/626.69k flops)
#   model_1/max_pooling2d_5/MaxPool (65.54k/65.54k flops)
#   model_1/conv2d_11/BiasAdd (65.54k/65.54k flops)
#   model_1/dense_5/MatMul (47.68k/47.68k flops)
#   model_1/conv2d_10/BiasAdd (34.82k/34.82k flops)
#   model_1/conv2d_13/BiasAdd (28.67k/28.67k flops)
#   model_1/max_pooling2d_6/MaxPool (28.67k/28.67k flops)
#   model_1/conv2d_12/BiasAdd (27.65k/27.65k flops)
#   model_1/conv2d_15/BiasAdd (15.74k/15.74k flops)
#   model_1/max_pooling2d_7/MaxPool (15.74k/15.74k flops)
#   model_1/conv2d_14/BiasAdd (14.72k/14.72k flops)
#   model_1/conv2d_17/BiasAdd (7.74k/7.74k flops)
#   model_1/max_pooling2d_8/MaxPool (7.74k/7.74k flops)
#   model_1/conv2d_16/BiasAdd (6.82k/6.82k flops)
#   model_1/dense_3/BiasAdd (2.45k/2.45k flops)
#   model_1/dense_4/BiasAdd (2.38k/2.38k flops)
#   model_1/max_pooling2d_9/MaxPool (1.99k/1.99k flops)
#   model_1/conv2d_19/BiasAdd (1.99k/1.99k flops)
#   model_1/conv2d_18/BiasAdd (1.94k/1.94k flops)
#   model_1/dense_5/Softmax (50/50 flops)
#   model_1/dense_5/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.004988
# 2022-05-16 04:17:30.272504: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:30.272574: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:30.273907: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/350.75m flops)
#   model_2/conv2d_27/Conv2D (69.66m/69.66m flops)
#   model_2/conv2d_23/Conv2D (66.36m/66.36m flops)
#   model_2/conv2d_21/Conv2D (51.90m/51.90m flops)
#   model_2/conv2d_22/Conv2D (35.39m/35.39m flops)
#   model_2/conv2d_25/Conv2D (33.87m/33.87m flops)
#   model_2/conv2d_26/Conv2D (28.91m/28.91m flops)
#   model_2/conv2d_24/Conv2D (19.35m/19.35m flops)
#   model_2/conv2d_29/Conv2D (18.58m/18.58m flops)
#   model_2/conv2d_28/Conv2D (18.43m/18.43m flops)
#   model_2/dense_7/MatMul (5.21m/5.21m flops)
#   model_2/dense_6/MatMul (1.91m/1.91m flops)
#   model_2/conv2d_20/Conv2D (811.01k/811.01k flops)
#   model_2/conv2d_21/BiasAdd (65.54k/65.54k flops)
#   model_2/max_pooling2d_10/MaxPool (65.54k/65.54k flops)
#   model_2/conv2d_20/BiasAdd (45.06k/45.06k flops)
#   model_2/conv2d_23/BiasAdd (30.72k/30.72k flops)
#   model_2/conv2d_22/BiasAdd (30.72k/30.72k flops)
#   model_2/max_pooling2d_11/MaxPool (30.72k/30.72k flops)
#   model_2/dense_8/MatMul (27.84k/27.84k flops)
#   model_2/conv2d_25/BiasAdd (13.44k/13.44k flops)
#   model_2/max_pooling2d_12/MaxPool (13.44k/13.44k flops)
#   model_2/conv2d_24/BiasAdd (8.96k/8.96k flops)
#   model_2/conv2d_27/BiasAdd (8.10k/8.10k flops)
#   model_2/max_pooling2d_13/MaxPool (8.10k/8.10k flops)
#   model_2/conv2d_26/BiasAdd (7.65k/7.65k flops)
#   model_2/max_pooling2d_14/MaxPool (2.04k/2.04k flops)
#   model_2/conv2d_29/BiasAdd (2.04k/2.04k flops)
#   model_2/conv2d_28/BiasAdd (2.02k/2.02k flops)
#   model_2/dense_6/BiasAdd (1.87k/1.87k flops)
#   model_2/dense_7/BiasAdd (1.39k/1.39k flops)
#   model_2/dense_8/Softmax (50/50 flops)
#   model_2/dense_8/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.99654
# 2022-05-16 04:17:31.071010: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:31.071084: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:31.072444: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/345.74m flops)
#   model_3/conv2d_35/Conv2D (66.85m/66.85m flops)
#   model_3/conv2d_37/Conv2D (59.63m/59.63m flops)
#   model_3/conv2d_31/Conv2D (56.62m/56.62m flops)
#   model_3/conv2d_33/Conv2D (35.28m/35.28m flops)
#   model_3/conv2d_34/Conv2D (31.27m/31.27m flops)
#   model_3/conv2d_36/Conv2D (29.00m/29.00m flops)
#   model_3/conv2d_32/Conv2D (19.46m/19.46m flops)
#   model_3/conv2d_39/Conv2D (18.73m/18.73m flops)
#   model_3/conv2d_38/Conv2D (18.73m/18.73m flops)
#   model_3/dense_10/MatMul (6.74m/6.74m flops)
#   model_3/dense_9/MatMul (2.17m/2.17m flops)
#   model_3/conv2d_30/Conv2D (884.74k/884.74k flops)
#   model_3/conv2d_31/BiasAdd (65.54k/65.54k flops)
#   model_3/max_pooling2d_15/MaxPool (65.54k/65.54k flops)
#   model_3/conv2d_30/BiasAdd (49.15k/49.15k flops)
#   model_3/dense_11/MatMul (31.68k/31.68k flops)
#   model_3/conv2d_33/BiasAdd (29.70k/29.70k flops)
#   model_3/max_pooling2d_16/MaxPool (29.70k/29.70k flops)
#   model_3/conv2d_32/BiasAdd (16.90k/16.90k flops)
#   model_3/conv2d_35/BiasAdd (15.87k/15.87k flops)
#   model_3/max_pooling2d_17/MaxPool (15.87k/15.87k flops)
#   model_3/conv2d_34/BiasAdd (14.98k/14.98k flops)
#   model_3/conv2d_37/BiasAdd (8.16k/8.16k flops)
#   model_3/max_pooling2d_18/MaxPool (8.16k/8.16k flops)
#   model_3/conv2d_36/BiasAdd (6.50k/6.50k flops)
#   model_3/dense_9/BiasAdd (2.13k/2.13k flops)
#   model_3/max_pooling2d_19/MaxPool (2.04k/2.04k flops)
#   model_3/conv2d_39/BiasAdd (2.04k/2.04k flops)
#   model_3/conv2d_38/BiasAdd (2.04k/2.04k flops)
#   model_3/dense_10/BiasAdd (1.58k/1.58k flops)
#   model_3/dense_11/Softmax (50/50 flops)
#   model_3/dense_11/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.850076
# 2022-05-16 04:17:31.767860: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 29099008 exceeds 10% of free system memory.
# 2022-05-16 04:17:31.775519: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 29099008 exceeds 10% of free system memory.
# 2022-05-16 04:17:31.778727: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 29099008 exceeds 10% of free system memory.
# 2022-05-16 04:17:31.837922: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 29099008 exceeds 10% of free system memory.
# 2022-05-16 04:17:31.893189: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:31.893260: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:31.894806: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/232.69m flops)
#   model_4/conv2d_41/Conv2D (42.47m/42.47m flops)
#   model_4/conv2d_45/Conv2D (38.22m/38.22m flops)
#   model_4/conv2d_47/Conv2D (33.91m/33.91m flops)
#   model_4/conv2d_43/Conv2D (20.07m/20.07m flops)
#   model_4/conv2d_42/Conv2D (19.46m/19.46m flops)
#   model_4/conv2d_49/Conv2D (16.80m/16.80m flops)
#   model_4/conv2d_46/Conv2D (15.97m/15.97m flops)
#   model_4/conv2d_48/Conv2D (15.41m/15.41m flops)
#   model_4/dense_13/MatMul (14.55m/14.55m flops)
#   model_4/conv2d_44/Conv2D (12.01m/12.01m flops)
#   model_4/dense_12/MatMul (2.81m/2.81m flops)
#   model_4/conv2d_40/Conv2D (663.55k/663.55k flops)
#   model_4/max_pooling2d_20/MaxPool (65.54k/65.54k flops)
#   model_4/conv2d_41/BiasAdd (65.54k/65.54k flops)
#   model_4/dense_14/MatMul (50.24k/50.24k flops)
#   model_4/conv2d_40/BiasAdd (36.86k/36.86k flops)
#   model_4/conv2d_43/BiasAdd (16.90k/16.90k flops)
#   model_4/conv2d_42/BiasAdd (16.90k/16.90k flops)
#   model_4/max_pooling2d_21/MaxPool (16.90k/16.90k flops)
#   model_4/conv2d_45/BiasAdd (13.44k/13.44k flops)
#   model_4/max_pooling2d_22/MaxPool (13.44k/13.44k flops)
#   model_4/conv2d_44/BiasAdd (10.11k/10.11k flops)
#   model_4/conv2d_47/BiasAdd (7.14k/7.14k flops)
#   model_4/max_pooling2d_23/MaxPool (7.14k/7.14k flops)
#   model_4/conv2d_46/BiasAdd (4.22k/4.22k flops)
#   model_4/dense_12/BiasAdd (2.90k/2.90k flops)
#   model_4/dense_13/BiasAdd (2.51k/2.51k flops)
#   model_4/max_pooling2d_24/MaxPool (1.94k/1.94k flops)
#   model_4/conv2d_49/BiasAdd (1.94k/1.94k flops)
#   model_4/conv2d_48/BiasAdd (1.92k/1.92k flops)
#   model_4/dense_14/Softmax (50/50 flops)
#   model_4/dense_14/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.96182
# 2022-05-16 04:17:32.852156: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:32.852233: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:32.853595: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/309.41m flops)
#   model_5/conv2d_53/Conv2D (67.35m/67.35m flops)
#   model_5/conv2d_55/Conv2D (50.31m/50.31m flops)
#   model_5/conv2d_51/Conv2D (40.11m/40.11m flops)
#   model_5/conv2d_52/Conv2D (34.21m/34.21m flops)
#   model_5/conv2d_57/Conv2D (31.68m/31.68m flops)
#   model_5/conv2d_54/Conv2D (29.90m/29.90m flops)
#   model_5/conv2d_59/Conv2D (18.73m/18.73m flops)
#   model_5/conv2d_58/Conv2D (18.36m/18.36m flops)
#   model_5/conv2d_56/Conv2D (13.43m/13.43m flops)
#   model_5/dense_16/MatMul (3.03m/3.03m flops)
#   model_5/dense_15/MatMul (1.32m/1.32m flops)
#   model_5/conv2d_50/Conv2D (626.69k/626.69k flops)
#   model_5/conv2d_51/BiasAdd (65.54k/65.54k flops)
#   model_5/max_pooling2d_25/MaxPool (65.54k/65.54k flops)
#   model_5/conv2d_50/BiasAdd (34.82k/34.82k flops)
#   model_5/conv2d_53/BiasAdd (32.26k/32.26k flops)
#   model_5/max_pooling2d_26/MaxPool (32.26k/32.26k flops)
#   model_5/conv2d_52/BiasAdd (29.70k/29.70k flops)
#   model_5/dense_17/MatMul (23.36k/23.36k flops)
#   model_5/conv2d_55/BiasAdd (13.57k/13.57k flops)
#   model_5/max_pooling2d_27/MaxPool (13.57k/13.57k flops)
#   model_5/conv2d_54/BiasAdd (13.18k/13.18k flops)
#   model_5/conv2d_57/BiasAdd (8.00k/8.00k flops)
#   model_5/max_pooling2d_28/MaxPool (8.00k/8.00k flops)
#   model_5/conv2d_56/BiasAdd (3.52k/3.52k flops)
#   model_5/max_pooling2d_29/MaxPool (2.04k/2.04k flops)
#   model_5/conv2d_59/BiasAdd (2.04k/2.04k flops)
#   model_5/conv2d_58/BiasAdd (2.04k/2.04k flops)
#   model_5/dense_15/BiasAdd (1.30k/1.30k flops)
#   model_5/dense_16/BiasAdd (1.17k/1.17k flops)
#   model_5/dense_17/Softmax (50/50 flops)
#   model_5/dense_17/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.072044
# 2022-05-16 04:17:33.406372: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:33.406449: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:33.407901: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/405.22m flops)
#   model_6/conv2d_63/Conv2D (73.16m/73.16m flops)
#   model_6/conv2d_65/Conv2D (64.09m/64.09m flops)
#   model_6/conv2d_67/Conv2D (62.54m/62.54m flops)
#   model_6/conv2d_61/Conv2D (58.98m/58.98m flops)
#   model_6/conv2d_62/Conv2D (37.16m/37.16m flops)
#   model_6/conv2d_64/Conv2D (33.09m/33.09m flops)
#   model_6/conv2d_66/Conv2D (32.61m/32.61m flops)
#   model_6/conv2d_69/Conv2D (18.51m/18.51m flops)
#   model_6/conv2d_68/Conv2D (17.05m/17.05m flops)
#   model_6/dense_19/MatMul (4.99m/4.99m flops)
#   model_6/dense_18/MatMul (1.74m/1.74m flops)
#   model_6/conv2d_60/Conv2D (921.60k/921.60k flops)
#   model_6/conv2d_61/BiasAdd (65.54k/65.54k flops)
#   model_6/max_pooling2d_30/MaxPool (65.54k/65.54k flops)
#   model_6/conv2d_60/BiasAdd (51.20k/51.20k flops)
#   model_6/conv2d_63/BiasAdd (32.26k/32.26k flops)
#   model_6/conv2d_62/BiasAdd (32.26k/32.26k flops)
#   model_6/max_pooling2d_31/MaxPool (32.26k/32.26k flops)
#   model_6/dense_20/MatMul (29.12k/29.12k flops)
#   model_6/conv2d_65/BiasAdd (15.62k/15.62k flops)
#   model_6/max_pooling2d_32/MaxPool (15.62k/15.62k flops)
#   model_6/conv2d_64/BiasAdd (14.59k/14.59k flops)
#   model_6/conv2d_67/BiasAdd (7.49k/7.49k flops)
#   model_6/max_pooling2d_33/MaxPool (7.49k/7.49k flops)
#   model_6/conv2d_66/BiasAdd (7.42k/7.42k flops)
#   model_6/max_pooling2d_34/MaxPool (2.03k/2.03k flops)
#   model_6/conv2d_69/BiasAdd (2.03k/2.03k flops)
#   model_6/conv2d_68/BiasAdd (2.02k/2.02k flops)
#   model_6/dense_18/BiasAdd (1.71k/1.71k flops)
#   model_6/dense_19/BiasAdd (1.46k/1.46k flops)
#   model_6/dense_20/Softmax (50/50 flops)
#   model_6/dense_20/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.936444
# 2022-05-16 04:17:34.167269: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:34.167341: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:34.168725: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/299.28m flops)
#   model_7/conv2d_73/Conv2D (72.00m/72.00m flops)
#   model_7/conv2d_77/Conv2D (44.83m/44.83m flops)
#   model_7/conv2d_71/Conv2D (37.75m/37.75m flops)
#   model_7/conv2d_72/Conv2D (36.57m/36.57m flops)
#   model_7/conv2d_75/Conv2D (29.12m/29.12m flops)
#   model_7/conv2d_74/Conv2D (22.93m/22.93m flops)
#   model_7/conv2d_79/Conv2D (18.73m/18.73m flops)
#   model_7/conv2d_78/Conv2D (17.11m/17.11m flops)
#   model_7/conv2d_76/Conv2D (15.39m/15.39m flops)
#   model_7/dense_22/MatMul (2.73m/2.73m flops)
#   model_7/dense_21/MatMul (1.19m/1.19m flops)
#   model_7/conv2d_70/Conv2D (589.82k/589.82k flops)
#   model_7/conv2d_71/BiasAdd (65.54k/65.54k flops)
#   model_7/max_pooling2d_35/MaxPool (65.54k/65.54k flops)
#   model_7/conv2d_70/BiasAdd (32.77k/32.77k flops)
#   model_7/conv2d_73/BiasAdd (32.26k/32.26k flops)
#   model_7/max_pooling2d_36/MaxPool (32.26k/32.26k flops)
#   model_7/conv2d_72/BiasAdd (31.74k/31.74k flops)
#   model_7/dense_23/MatMul (23.36k/23.36k flops)
#   model_7/conv2d_75/BiasAdd (10.24k/10.24k flops)
#   model_7/max_pooling2d_37/MaxPool (10.24k/10.24k flops)
#   model_7/conv2d_74/BiasAdd (10.11k/10.11k flops)
#   model_7/conv2d_77/BiasAdd (7.46k/7.46k flops)
#   model_7/max_pooling2d_38/MaxPool (7.46k/7.46k flops)
#   model_7/conv2d_76/BiasAdd (5.34k/5.34k flops)
#   model_7/max_pooling2d_39/MaxPool (2.04k/2.04k flops)
#   model_7/conv2d_79/BiasAdd (2.04k/2.04k flops)
#   model_7/conv2d_78/BiasAdd (2.04k/2.04k flops)
#   model_7/dense_22/BiasAdd (1.17k/1.17k flops)
#   model_7/dense_21/BiasAdd (1.17k/1.17k flops)
#   model_7/dense_23/Softmax (50/50 flops)
#   model_7/dense_23/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.947484
# 2022-05-16 04:17:34.754611: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:34.754684: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:34.756047: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/313.59m flops)
#   model_8/conv2d_85/Conv2D (53.63m/53.63m flops)
#   model_8/conv2d_87/Conv2D (48.52m/48.52m flops)
#   model_8/conv2d_83/Conv2D (46.08m/46.08m flops)
#   model_8/conv2d_81/Conv2D (42.47m/42.47m flops)
#   model_8/conv2d_82/Conv2D (29.49m/29.49m flops)
#   model_8/conv2d_86/Conv2D (25.38m/25.38m flops)
#   model_8/conv2d_84/Conv2D (23.73m/23.73m flops)
#   model_8/conv2d_89/Conv2D (15.41m/15.41m flops)
#   model_8/conv2d_88/Conv2D (13.81m/13.81m flops)
#   model_8/dense_25/MatMul (11.67m/11.67m flops)
#   model_8/dense_24/MatMul (2.36m/2.36m flops)
#   model_8/conv2d_80/Conv2D (663.55k/663.55k flops)
#   model_8/max_pooling2d_40/MaxPool (65.54k/65.54k flops)
#   model_8/conv2d_81/BiasAdd (65.54k/65.54k flops)
#   model_8/dense_26/MatMul (47.68k/47.68k flops)
#   model_8/conv2d_80/BiasAdd (36.86k/36.86k flops)
#   model_8/conv2d_83/BiasAdd (25.60k/25.60k flops)
#   model_8/conv2d_82/BiasAdd (25.60k/25.60k flops)
#   model_8/max_pooling2d_41/MaxPool (25.60k/25.60k flops)
#   model_8/conv2d_85/BiasAdd (14.46k/14.46k flops)
#   model_8/max_pooling2d_42/MaxPool (14.46k/14.46k flops)
#   model_8/conv2d_84/BiasAdd (13.18k/13.18k flops)
#   model_8/conv2d_87/BiasAdd (6.91k/6.91k flops)
#   model_8/max_pooling2d_43/MaxPool (6.91k/6.91k flops)
#   model_8/conv2d_86/BiasAdd (6.24k/6.24k flops)
#   model_8/dense_24/BiasAdd (2.45k/2.45k flops)
#   model_8/dense_25/BiasAdd (2.38k/2.38k flops)
#   model_8/max_pooling2d_44/MaxPool (1.93k/1.93k flops)
#   model_8/conv2d_89/BiasAdd (1.93k/1.93k flops)
#   model_8/conv2d_88/BiasAdd (1.78k/1.78k flops)
#   model_8/dense_26/Softmax (50/50 flops)
#   model_8/dense_26/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.039532
# 2022-05-16 04:17:35.562678: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 29611008 exceeds 10% of free system memory.
# 2022-05-16 04:17:35.678078: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:35.678147: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:35.679533: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/339.57m flops)
#   model_9/conv2d_93/Conv2D (70.85m/70.85m flops)
#   model_9/conv2d_95/Conv2D (57.76m/57.76m flops)
#   model_9/conv2d_91/Conv2D (54.26m/54.26m flops)
#   model_9/conv2d_92/Conv2D (36.57m/36.57m flops)
#   model_9/conv2d_94/Conv2D (31.14m/31.14m flops)
#   model_9/conv2d_97/Conv2D (29.13m/29.13m flops)
#   model_9/conv2d_96/Conv2D (17.09m/17.09m flops)
#   model_9/dense_28/MatMul (14.81m/14.81m flops)
#   model_9/conv2d_99/Conv2D (12.46m/12.46m flops)
#   model_9/conv2d_98/Conv2D (11.74m/11.74m flops)
#   model_9/dense_27/MatMul (2.52m/2.52m flops)
#   model_9/conv2d_90/Conv2D (847.87k/847.87k flops)
#   model_9/max_pooling2d_45/MaxPool (65.54k/65.54k flops)
#   model_9/conv2d_91/BiasAdd (65.54k/65.54k flops)
#   model_9/dense_29/MatMul (48.96k/48.96k flops)
#   model_9/conv2d_90/BiasAdd (47.10k/47.10k flops)
#   model_9/conv2d_93/BiasAdd (31.74k/31.74k flops)
#   model_9/conv2d_92/BiasAdd (31.74k/31.74k flops)
#   model_9/max_pooling2d_46/MaxPool (31.74k/31.74k flops)
#   model_9/conv2d_95/BiasAdd (14.72k/14.72k flops)
#   model_9/max_pooling2d_47/MaxPool (14.72k/14.72k flops)
#   model_9/conv2d_94/BiasAdd (13.95k/13.95k flops)
#   model_9/conv2d_97/BiasAdd (6.27k/6.27k flops)
#   model_9/max_pooling2d_48/MaxPool (6.27k/6.27k flops)
#   model_9/conv2d_96/BiasAdd (4.13k/4.13k flops)
#   model_9/dense_27/BiasAdd (3.02k/3.02k flops)
#   model_9/dense_28/BiasAdd (2.45k/2.45k flops)
#   model_9/max_pooling2d_49/MaxPool (1.66k/1.66k flops)
#   model_9/conv2d_99/BiasAdd (1.66k/1.66k flops)
#   model_9/conv2d_98/BiasAdd (1.66k/1.66k flops)
#   model_9/dense_29/Softmax (50/50 flops)
#   model_9/dense_29/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 3.098732
# 2022-05-16 04:17:36.674551: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:36.674627: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:36.676242: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/843.07m flops)
#   model_10/conv2d_105/Conv2D (213.15m/213.15m flops)
#   model_10/conv2d_101/Conv2D (160.43m/160.43m flops)
#   model_10/conv2d_107/Conv2D (119.35m/119.35m flops)
#   model_10/conv2d_106/Conv2D (80.47m/80.47m flops)
#   model_10/conv2d_109/Conv2D (67.70m/67.70m flops)
#   model_10/conv2d_102/Conv2D (51.90m/51.90m flops)
#   model_10/conv2d_108/Conv2D (47.58m/47.58m flops)
#   model_10/conv2d_104/Conv2D (45.16m/45.16m flops)
#   model_10/conv2d_103/Conv2D (40.55m/40.55m flops)
#   model_10/dense_30/MatMul (8.22m/8.22m flops)
#   model_10/dense_31/MatMul (4.95m/4.95m flops)
#   model_10/conv2d_100/Conv2D (2.51m/2.51m flops)
#   model_10/conv2d_101/BiasAdd (262.14k/262.14k flops)
#   model_10/max_pooling2d_50/MaxPool (262.14k/262.14k flops)
#   model_10/conv2d_100/BiasAdd (139.26k/139.26k flops)
#   model_10/conv2d_105/BiasAdd (60.42k/60.42k flops)
#   model_10/max_pooling2d_52/MaxPool (60.42k/60.42k flops)
#   model_10/conv2d_103/BiasAdd (51.20k/51.20k flops)
#   model_10/max_pooling2d_51/MaxPool (51.20k/51.20k flops)
#   model_10/conv2d_104/BiasAdd (50.18k/50.18k flops)
#   model_10/conv2d_102/BiasAdd (45.06k/45.06k flops)
#   model_10/dense_32/MatMul (24.00k/24.00k flops)
#   model_10/conv2d_107/BiasAdd (22.40k/22.40k flops)
#   model_10/max_pooling2d_53/MaxPool (22.40k/22.40k flops)
#   model_10/conv2d_106/BiasAdd (18.94k/18.94k flops)
#   model_10/max_pooling2d_54/MaxPool (7.97k/7.97k flops)
#   model_10/conv2d_109/BiasAdd (7.97k/7.97k flops)
#   model_10/conv2d_108/BiasAdd (7.55k/7.55k flops)
#   model_10/dense_30/BiasAdd (2.06k/2.06k flops)
#   model_10/dense_31/BiasAdd (1.20k/1.20k flops)
#   model_10/dense_32/Softmax (50/50 flops)
#   model_10/dense_32/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 4.155372
# 2022-05-16 04:17:37.148589: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:37.148664: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:37.150174: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.39b flops)
#   model_11/conv2d_111/Conv2D (273.68m/273.68m flops)
#   model_11/conv2d_113/Conv2D (248.02m/248.02m flops)
#   model_11/conv2d_115/Conv2D (195.64m/195.64m flops)
#   model_11/conv2d_117/Conv2D (194.57m/194.57m flops)
#   model_11/conv2d_112/Conv2D (136.84m/136.84m flops)
#   model_11/conv2d_116/Conv2D (114.12m/114.12m flops)
#   model_11/conv2d_114/Conv2D (93.01m/93.01m flops)
#   model_11/conv2d_119/Conv2D (65.23m/65.23m flops)
#   model_11/conv2d_118/Conv2D (55.83m/55.83m flops)
#   model_11/dense_33/MatMul (5.41m/5.41m flops)
#   model_11/conv2d_110/Conv2D (4.28m/4.28m flops)
#   model_11/dense_34/MatMul (3.52m/3.52m flops)
#   model_11/conv2d_111/BiasAdd (262.14k/262.14k flops)
#   model_11/max_pooling2d_55/MaxPool (262.14k/262.14k flops)
#   model_11/conv2d_110/BiasAdd (237.57k/237.57k flops)
#   model_11/conv2d_113/BiasAdd (118.78k/118.78k flops)
#   model_11/conv2d_112/BiasAdd (118.78k/118.78k flops)
#   model_11/max_pooling2d_56/MaxPool (118.78k/118.78k flops)
#   model_11/conv2d_115/BiasAdd (62.46k/62.46k flops)
#   model_11/max_pooling2d_57/MaxPool (62.46k/62.46k flops)
#   model_11/conv2d_114/BiasAdd (44.54k/44.54k flops)
#   model_11/conv2d_117/BiasAdd (26.62k/26.62k flops)
#   model_11/max_pooling2d_58/MaxPool (26.62k/26.62k flops)
#   model_11/conv2d_116/BiasAdd (25.98k/25.98k flops)
#   model_11/dense_35/MatMul (25.28k/25.28k flops)
#   model_11/max_pooling2d_59/MaxPool (7.78k/7.78k flops)
#   model_11/conv2d_119/BiasAdd (7.78k/7.78k flops)
#   model_11/conv2d_118/BiasAdd (7.46k/7.46k flops)
#   model_11/dense_33/BiasAdd (1.39k/1.39k flops)
#   model_11/dense_34/BiasAdd (1.26k/1.26k flops)
#   model_11/dense_35/Softmax (50/50 flops)
#   model_11/dense_35/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 4.201388
# 2022-05-16 04:17:37.607788: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:37.607862: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:37.609431: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.35b flops)
#   model_12/conv2d_123/Conv2D (283.41m/283.41m flops)
#   model_12/conv2d_121/Conv2D (273.68m/273.68m flops)
#   model_12/conv2d_125/Conv2D (209.65m/209.65m flops)
#   model_12/conv2d_122/Conv2D (146.28m/146.28m flops)
#   model_12/conv2d_127/Conv2D (134.49m/134.49m flops)
#   model_12/conv2d_124/Conv2D (107.42m/107.42m flops)
#   model_12/conv2d_126/Conv2D (78.62m/78.62m flops)
#   model_12/conv2d_129/Conv2D (54.98m/54.98m flops)
#   model_12/conv2d_128/Conv2D (51.27m/51.27m flops)
#   model_12/dense_36/MatMul (4.94m/4.94m flops)
#   model_12/conv2d_120/Conv2D (4.28m/4.28m flops)
#   model_12/dense_37/MatMul (3.25m/3.25m flops)
#   model_12/conv2d_121/BiasAdd (262.14k/262.14k flops)
#   model_12/max_pooling2d_60/MaxPool (262.14k/262.14k flops)
#   model_12/conv2d_120/BiasAdd (237.57k/237.57k flops)
#   model_12/conv2d_123/BiasAdd (126.98k/126.98k flops)
#   model_12/conv2d_122/BiasAdd (126.98k/126.98k flops)
#   model_12/max_pooling2d_61/MaxPool (126.98k/126.98k flops)
#   model_12/conv2d_125/BiasAdd (61.95k/61.95k flops)
#   model_12/max_pooling2d_62/MaxPool (61.95k/61.95k flops)
#   model_12/conv2d_124/BiasAdd (48.13k/48.13k flops)
#   model_12/conv2d_127/BiasAdd (26.50k/26.50k flops)
#   model_12/max_pooling2d_63/MaxPool (26.50k/26.50k flops)
#   model_12/dense_38/MatMul (23.36k/23.36k flops)
#   model_12/conv2d_126/BiasAdd (18.05k/18.05k flops)
#   model_12/max_pooling2d_64/MaxPool (7.10k/7.10k flops)
#   model_12/conv2d_129/BiasAdd (7.10k/7.10k flops)
#   model_12/conv2d_128/BiasAdd (6.88k/6.88k flops)
#   model_12/dense_36/BiasAdd (1.39k/1.39k flops)
#   model_12/dense_37/BiasAdd (1.17k/1.17k flops)
#   model_12/dense_38/Softmax (50/50 flops)
#   model_12/dense_38/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 3.296364
# 2022-05-16 04:17:38.073884: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:17:38.073969: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:17:38.075488: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# ...
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/15.82b flops)
#   model_95/conv2d_951/Conv2D (3.01b/3.01b flops)
#   model_95/conv2d_957/Conv2D (2.94b/2.94b flops)
#   model_95/conv2d_955/Conv2D (2.44b/2.44b flops)
#   model_95/conv2d_953/Conv2D (1.85b/1.85b flops)
#   model_95/conv2d_954/Conv2D (1.30b/1.30b flops)
#   model_95/conv2d_956/Conv2D (1.28b/1.28b flops)
#   model_95/conv2d_952/Conv2D (1.04b/1.04b flops)
#   model_95/conv2d_959/Conv2D (874.96m/874.96m flops)
#   model_95/conv2d_958/Conv2D (864.42m/864.42m flops)
#   model_95/dense_285/MatMul (138.21m/138.21m flops)
#   model_95/conv2d_950/Conv2D (46.96m/46.96m flops)
#   model_95/dense_286/MatMul (13.68m/13.68m flops)
#   model_95/max_pooling2d_475/MaxPool (3.21m/3.21m flops)
#   model_95/conv2d_951/BiasAdd (3.21m/3.21m flops)
#   model_95/conv2d_950/BiasAdd (2.61m/2.61m flops)
#   model_95/conv2d_953/BiasAdd (1.43m/1.43m flops)
#   model_95/max_pooling2d_476/MaxPool (1.43m/1.43m flops)
#   model_95/conv2d_952/BiasAdd (903.17k/903.17k flops)
#   model_95/conv2d_955/BiasAdd (671.10k/671.10k flops)
#   model_95/max_pooling2d_477/MaxPool (671.10k/671.10k flops)
#   model_95/conv2d_954/BiasAdd (633.47k/633.47k flops)
#   model_95/conv2d_957/BiasAdd (385.73k/385.73k flops)
#   model_95/max_pooling2d_478/MaxPool (385.73k/385.73k flops)
#   model_95/conv2d_956/BiasAdd (332.42k/332.42k flops)
#   model_95/max_pooling2d_479/MaxPool (97.61k/97.61k flops)
#   model_95/conv2d_959/BiasAdd (97.61k/97.61k flops)
#   model_95/conv2d_958/BiasAdd (97.61k/97.61k flops)
#   model_95/dense_287/MatMul (48.32k/48.32k flops)
#   model_95/dense_285/BiasAdd (2.83k/2.83k flops)
#   model_95/dense_286/BiasAdd (2.42k/2.42k flops)
#   model_95/dense_287/Softmax (50/50 flops)
#   model_95/dense_287/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 47.83254
# 2022-05-16 04:21:04.246395: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:21:04.246469: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:21:04.248304: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.006ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/17.58b flops)
#   model_96/conv2d_965/Conv2D (3.33b/3.33b flops)
#   model_96/conv2d_963/Conv2D (3.30b/3.30b flops)
#   model_96/conv2d_967/Conv2D (2.44b/2.44b flops)
#   model_96/conv2d_961/Conv2D (2.08b/2.08b flops)
#   model_96/conv2d_962/Conv2D (1.71b/1.71b flops)
#   model_96/conv2d_964/Conv2D (1.65b/1.65b flops)
#   model_96/conv2d_966/Conv2D (1.31b/1.31b flops)
#   model_96/conv2d_969/Conv2D (843.62m/843.62m flops)
#   model_96/conv2d_968/Conv2D (805.74m/805.74m flops)
#   model_96/dense_288/MatMul (60.70m/60.70m flops)
#   model_96/conv2d_960/Conv2D (32.51m/32.51m flops)
#   model_96/max_pooling2d_480/MaxPool (3.21m/3.21m flops)
#   model_96/conv2d_961/BiasAdd (3.21m/3.21m flops)
#   model_96/dense_289/MatMul (2.71m/2.71m flops)
#   model_96/conv2d_960/BiasAdd (1.81m/1.81m flops)
#   model_96/conv2d_963/BiasAdd (1.56m/1.56m flops)
#   model_96/max_pooling2d_481/MaxPool (1.56m/1.56m flops)
#   model_96/conv2d_962/BiasAdd (1.48m/1.48m flops)
#   model_96/conv2d_965/BiasAdd (784.00k/784.00k flops)
#   model_96/max_pooling2d_482/MaxPool (784.00k/784.00k flops)
#   model_96/conv2d_964/BiasAdd (740.10k/740.10k flops)
#   model_96/conv2d_967/BiasAdd (366.91k/366.91k flops)
#   model_96/max_pooling2d_483/MaxPool (366.91k/366.91k flops)
#   model_96/conv2d_966/BiasAdd (290.08k/290.08k flops)
#   model_96/max_pooling2d_484/MaxPool (96.04k/96.04k flops)
#   model_96/conv2d_969/BiasAdd (96.04k/96.04k flops)
#   model_96/conv2d_968/BiasAdd (95.65k/95.65k flops)
#   model_96/dense_290/MatMul (21.44k/21.44k flops)
#   model_96/dense_288/BiasAdd (1.26k/1.26k flops)
#   model_96/dense_289/BiasAdd (1.07k/1.07k flops)
#   model_96/dense_290/Softmax (50/50 flops)
#   model_96/dense_290/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 39.862028
# 2022-05-16 04:21:07.313989: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:21:07.314063: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:21:07.315684: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/10.73b flops)
#   model_97/conv2d_977/Conv2D (2.24b/2.24b flops)
#   model_97/conv2d_971/Conv2D (1.97b/1.97b flops)
#   model_97/conv2d_975/Conv2D (1.23b/1.23b flops)
#   model_97/conv2d_973/Conv2D (1.15b/1.15b flops)
#   model_97/conv2d_976/Conv2D (1.12b/1.12b flops)
#   model_97/conv2d_972/Conv2D (838.14m/838.14m flops)
#   model_97/conv2d_979/Conv2D (778.19m/778.19m flops)
#   model_97/conv2d_978/Conv2D (711.22m/711.22m flops)
#   model_97/conv2d_974/Conv2D (486.81m/486.81m flops)
#   model_97/dense_291/MatMul (146.15m/146.15m flops)
#   model_97/conv2d_970/Conv2D (30.71m/30.71m flops)
#   model_97/dense_292/MatMul (18.68m/18.68m flops)
#   model_97/max_pooling2d_485/MaxPool (3.21m/3.21m flops)
#   model_97/conv2d_971/BiasAdd (3.21m/3.21m flops)
#   model_97/conv2d_970/BiasAdd (1.71m/1.71m flops)
#   model_97/conv2d_973/BiasAdd (1.10m/1.10m flops)
#   model_97/max_pooling2d_486/MaxPool (1.10m/1.10m flops)
#   model_97/conv2d_972/BiasAdd (727.55k/727.55k flops)
#   model_97/conv2d_975/BiasAdd (696.19k/696.19k flops)
#   model_97/max_pooling2d_487/MaxPool (696.19k/696.19k flops)
#   model_97/conv2d_977/BiasAdd (349.66k/349.66k flops)
#   model_97/max_pooling2d_488/MaxPool (349.66k/349.66k flops)
#   model_97/conv2d_974/BiasAdd (307.33k/307.33k flops)
#   model_97/conv2d_976/BiasAdd (279.10k/279.10k flops)
#   model_97/max_pooling2d_489/MaxPool (95.65k/95.65k flops)
#   model_97/conv2d_979/BiasAdd (95.65k/95.65k flops)
#   model_97/conv2d_978/BiasAdd (88.59k/88.59k flops)
#   model_97/dense_293/MatMul (61.12k/61.12k flops)
#   model_97/dense_292/BiasAdd (3.06k/3.06k flops)
#   model_97/dense_291/BiasAdd (3.06k/3.06k flops)
#   model_97/dense_293/Softmax (50/50 flops)
#   model_97/dense_293/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 44.983436
# 2022-05-16 04:21:13.475523: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:21:13.475597: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:21:13.477295: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/14.61b flops)
#   model_98/conv2d_987/Conv2D (2.52b/2.52b flops)
#   model_98/conv2d_985/Conv2D (2.41b/2.41b flops)
#   model_98/conv2d_981/Conv2D (2.31b/2.31b flops)
#   model_98/conv2d_983/Conv2D (2.01b/2.01b flops)
#   model_98/conv2d_986/Conv2D (1.27b/1.27b flops)
#   model_98/conv2d_982/Conv2D (1.21b/1.21b flops)
#   model_98/conv2d_984/Conv2D (1.07b/1.07b flops)
#   model_98/conv2d_989/Conv2D (864.36m/864.36m flops)
#   model_98/conv2d_988/Conv2D (826.33m/826.33m flops)
#   model_98/dense_294/MatMul (65.07m/65.07m flops)
#   model_98/conv2d_980/Conv2D (36.13m/36.13m flops)
#   model_98/dense_295/MatMul (3.44m/3.44m flops)
#   model_98/max_pooling2d_490/MaxPool (3.21m/3.21m flops)
#   model_98/conv2d_981/BiasAdd (3.21m/3.21m flops)
#   model_98/conv2d_980/BiasAdd (2.01m/2.01m flops)
#   model_98/conv2d_983/BiasAdd (1.33m/1.33m flops)
#   model_98/max_pooling2d_491/MaxPool (1.33m/1.33m flops)
#   model_98/conv2d_982/BiasAdd (1.05m/1.05m flops)
#   model_98/conv2d_985/BiasAdd (752.64k/752.64k flops)
#   model_98/max_pooling2d_492/MaxPool (752.64k/752.64k flops)
#   model_98/conv2d_984/BiasAdd (558.21k/558.21k flops)
#   model_98/conv2d_987/BiasAdd (374.75k/374.75k flops)
#   model_98/max_pooling2d_493/MaxPool (374.75k/374.75k flops)
#   model_98/conv2d_986/BiasAdd (293.22k/293.22k flops)
#   model_98/max_pooling2d_494/MaxPool (98.00k/98.00k flops)
#   model_98/conv2d_989/BiasAdd (98.00k/98.00k flops)
#   model_98/conv2d_988/BiasAdd (96.04k/96.04k flops)
#   model_98/dense_296/MatMul (25.92k/25.92k flops)
#   model_98/dense_294/BiasAdd (1.33k/1.33k flops)
#   model_98/dense_295/BiasAdd (1.30k/1.30k flops)
#   model_98/dense_296/Softmax (50/50 flops)
#   model_98/dense_296/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 47.700156
# 2022-05-16 04:21:16.578517: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:21:16.578592: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:21:16.580216: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/15.61b flops)
#   model_99/conv2d_991/Conv2D (3.12b/3.12b flops)
#   model_99/conv2d_997/Conv2D (2.91b/2.91b flops)
#   model_99/conv2d_993/Conv2D (2.35b/2.35b flops)
#   model_99/conv2d_995/Conv2D (1.79b/1.79b flops)
#   model_99/conv2d_992/Conv2D (1.42b/1.42b flops)
#   model_99/conv2d_996/Conv2D (1.10b/1.10b flops)
#   model_99/conv2d_994/Conv2D (1.07b/1.07b flops)
#   model_99/conv2d_999/Conv2D (871.44m/871.44m flops)
#   model_99/conv2d_998/Conv2D (822.45m/822.45m flops)
#   model_99/dense_297/MatMul (103.85m/103.85m flops)
#   model_99/conv2d_990/Conv2D (48.77m/48.77m flops)
#   model_99/dense_298/MatMul (4.70m/4.70m flops)
#   model_99/max_pooling2d_495/MaxPool (3.21m/3.21m flops)
#   model_99/conv2d_991/BiasAdd (3.21m/3.21m flops)
#   model_99/conv2d_990/BiasAdd (2.71m/2.71m flops)
#   model_99/conv2d_993/BiasAdd (1.33m/1.33m flops)
#   model_99/max_pooling2d_496/MaxPool (1.33m/1.33m flops)
#   model_99/conv2d_992/BiasAdd (1.23m/1.23m flops)
#   model_99/conv2d_995/BiasAdd (558.21k/558.21k flops)
#   model_99/conv2d_994/BiasAdd (558.21k/558.21k flops)
#   model_99/max_pooling2d_497/MaxPool (558.21k/558.21k flops)
#   model_99/conv2d_997/BiasAdd (368.48k/368.48k flops)
#   model_99/max_pooling2d_498/MaxPool (368.48k/368.48k flops)
#   model_99/conv2d_996/BiasAdd (343.39k/343.39k flops)
#   model_99/max_pooling2d_499/MaxPool (97.61k/97.61k flops)
#   model_99/conv2d_999/BiasAdd (97.61k/97.61k flops)
#   model_99/conv2d_998/BiasAdd (97.22k/97.22k flops)
#   model_99/dense_299/MatMul (22.08k/22.08k flops)
#   model_99/dense_297/BiasAdd (2.13k/2.13k flops)
#   model_99/dense_298/BiasAdd (1.10k/1.10k flops)
#   model_99/dense_299/Softmax (50/50 flops)
#   model_99/dense_299/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
