# %%
import os
import csv
import numpy as np
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from itertools import product
from keras_flops import get_flops
print("TensorFlow version:", tf.__version__)

model_num = 1
input_horizontal =range(32,512,32)
input_vertical =range(32,512,32)
with open("para_count_vgg16.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "FLOPs", "Total_params"],])
          
for input_x, input_y in product(input_horizontal, input_vertical):



    inputs = Input(shape=(input_x, input_y, 1))

    # 卷积层和最大池化层
    conv1 = Conv2D(64, (3,3), padding='same', activation='relu')(inputs)
    conv2 = Conv2D(64, (3,3), padding='same', activation='relu')(conv1)
    pool1 = MaxPooling2D(pool_size=2)(conv2)

    conv3 = Conv2D(128, (3,3), padding='same', activation='relu')(pool1)
    conv4 = Conv2D(128, (3,3), padding='same', activation='relu')(conv3)
    pool2 = MaxPooling2D(pool_size=2)(conv4)

    conv5 = Conv2D(256, (3,3), padding='same', activation='relu')(pool2)
    conv6 = Conv2D(256, (3,3), padding='same', activation='relu')(conv5)
    conv7 = Conv2D(256, (3,3), padding='same', activation='relu')(conv6)
    pool3 = MaxPooling2D(pool_size=2)(conv7)

    conv8 = Conv2D(512, (3,3), padding='same', activation='relu')(pool3)
    conv9 = Conv2D(512, (3,3), padding='same', activation='relu')(conv8)
    conv10 = Conv2D(512, (3,3), padding='same', activation='relu')(conv9)
    pool4 = MaxPooling2D(pool_size=2)(conv10)

    conv11 = Conv2D(512, (3,3), padding='same', activation='relu')(pool4)
    conv12 = Conv2D(512, (3,3), padding='same', activation='relu')(conv11)
    conv13 = Conv2D(256, (3,3), padding='same', activation='relu')(conv12)
    pool5 = MaxPooling2D(pool_size=2)(conv13)

    # 扁平层
    flat = Flatten()(pool5)

    # 全联接层
    fc1 = Dense(4096, activation='relu')(flat)
    fc2 = Dense(4096, activation='relu')(fc1)

    # 输出层
    outputs = Dense(10, activation='softmax')(fc2)


    model = Model(inputs=inputs, outputs=outputs)

    
    Total_params = round(model.count_params()/10 ** 6,2)
    FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
    with open("para_count_vgg16.csv","a+") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerows([[model_num, input_x, input_y, FLOPs, Total_params],])

        model_num = model_num + 1
# Out:
# 2022-04-02 04:13:27.512510: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-04-02 04:13:27.512541: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# TensorFlow version: 2.6.0
# 1.259564
# 2022-04-02 04:13:28.539733: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-04-02 04:13:28.539750: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-02 04:13:28.539764: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2022-04-02 04:13:28.539890: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.486316
# 3.713068
# 4.93982
# 6.166572
# 7.393324
# 8.620076
# 9.846828
# 11.07358
# 12.300332
# 13.527084
# 14.753836
# 15.980588
# 17.20734
# 18.434092
# 2.486316
# 4.93982
# 7.393324
# 9.846828
# 12.300332
# 14.753836
# 17.20734
# 19.660844
# 22.114348
# 24.567852
# 27.021356
# 29.47486
# 31.928364
# 34.381868
# 36.835372
# 3.713068
# 7.393324
# 11.07358
# 14.753836
# 18.434092
# 22.114348
# 25.794604
# 29.47486
# 33.155116
# 36.835372
# 40.515628
# 44.195884
# 47.87614
# 51.556396
# 55.236652
# 4.93982
# 9.846828
# 14.753836
# 19.660844
# 24.567852
# 29.47486
# 34.381868
# 39.288876
# 44.195884
# 49.102892
# 54.0099
# 58.916908
# 63.823916
# 68.730924
# 73.637932
# 6.166572
# 12.300332
# 18.434092
# 24.567852
# 30.701612
# 36.835372
# 42.969132
# 49.102892
# 55.236652
# 61.370412
# 67.504172
# 73.637932
# 79.771692
# 85.905452
# 92.039212
# 7.393324
# 14.753836
# 22.114348
# 29.47486
# 36.835372
# 44.195884
# 51.556396
# 58.916908
# 66.27742
# 73.637932
# 80.998444
# 88.358956
# 95.719468
# 103.07998
# 110.440492
# 8.620076
# 17.20734
# 25.794604
# 34.381868
# 42.969132
# 51.556396
# 60.14366
# 68.730924
# 77.318188
# 85.905452
# 94.492716
# 103.07998
# 111.667244
# 120.254508
# 128.841772
# 9.846828
# 19.660844
# 29.47486
# 39.288876
# 49.102892
# 58.916908
# 68.730924
# 78.54494
# 88.358956
# 98.172972
# 107.986988
# 117.801004
# 127.61502
# 137.429036
# 147.243052
# 11.07358
# 22.114348
# 33.155116
# 44.195884
# 55.236652
# 66.27742
# 77.318188
# 88.358956
# 99.399724
# 110.440492
# 121.48126
# 132.522028
# 143.562796
# 154.603564
# 165.644332
# 12.300332
# 24.567852
# 36.835372
# 49.102892
# 61.370412
# 73.637932
# 85.905452
# 98.172972
# 110.440492
# 122.708012
# 134.975532
# 147.243052
# 159.510572
# 171.778092
# 184.045612
# 13.527084
# 27.021356
# 40.515628
# 54.0099
# 67.504172
# 80.998444
# 94.492716
# 107.986988
# 121.48126
# 134.975532
# 148.469804
# 161.964076
# 175.458348
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_350/860500545.py in <module>
#      42
#      43     conv11 = Conv2D(512, (3,3), padding='same', activation='relu')(pool4)
# ---> 44     conv12 = Conv2D(512, (3,3), padding='same', activation='relu')(conv11)
#      45     conv13 = Conv2D(256, (3,3), padding='same', activation='relu')(conv12)
#      46     pool5 = MaxPooling2D(pool_size=2)(conv13)
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     975     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#     976       return self._functional_construction_call(inputs, args, kwargs,
# --> 977                                                 input_list)
#     978
#     979     # Maintains info about the `Layer.call` stack.
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1126       # Node connectivity does not special-case the first argument.
#    1127       outputs = self._set_connectivity_metadata((inputs,) + args, kwargs,
# -> 1128                                                 outputs)
#    1129       return outputs
#    1130
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/base_layer.py in _set_connectivity_metadata(self, args, kwargs, outputs)
#    2589     # `_outbound_nodes` of the layers that produced the inputs to this
#    2590     # layer call.
# -> 2591     node_module.Node(self, call_args=args, call_kwargs=kwargs, outputs=outputs)
#    2592     return outputs
#    2593
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/node.py in __init__(self, layer, call_args, call_kwargs, outputs)
#      94
#      95     # Wire up Node to Layers.
# ---> 96     self.layer._inbound_nodes.append(self)
#      97     for kt in self.keras_inputs:
#      98       inbound_layer = kt._keras_history.layer
#
# /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/keras/engine/base_layer.py in _inbound_nodes(self)
#    2255   ##############################################################################
#    2256
# -> 2257   @property
#    2258   def _inbound_nodes(self):
#    2259     return self._inbound_nodes_value
#
# KeyboardInterrupt:

# %%
import os
import csv
import numpy as np
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from itertools import product
from keras_flops import get_flops
print("TensorFlow version:", tf.__version__)

model_num = 1
input_shape_range =range(32,512,32)

with open("para_count_vgg16.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "FLOPs", "Total_params", "Memory"],])
          
for input_x in input_shape_range:
    input_y = input_x
    inputs = Input(shape=(input_x, input_y, 1))

    # 卷积层和最大池化层
    conv1 = Conv2D(64, (3,3), padding='same', activation='relu')(inputs)
    conv2 = Conv2D(64, (3,3), padding='same', activation='relu')(conv1)
    pool1 = MaxPooling2D(pool_size=2)(conv2)

    conv3 = Conv2D(128, (3,3), padding='same', activation='relu')(pool1)
    conv4 = Conv2D(128, (3,3), padding='same', activation='relu')(conv3)
    pool2 = MaxPooling2D(pool_size=2)(conv4)

    conv5 = Conv2D(256, (3,3), padding='same', activation='relu')(pool2)
    conv6 = Conv2D(256, (3,3), padding='same', activation='relu')(conv5)
    conv7 = Conv2D(256, (3,3), padding='same', activation='relu')(conv6)
    pool3 = MaxPooling2D(pool_size=2)(conv7)

    conv8 = Conv2D(512, (3,3), padding='same', activation='relu')(pool3)
    conv9 = Conv2D(512, (3,3), padding='same', activation='relu')(conv8)
    conv10 = Conv2D(512, (3,3), padding='same', activation='relu')(conv9)
    pool4 = MaxPooling2D(pool_size=2)(conv10)

    conv11 = Conv2D(512, (3,3), padding='same', activation='relu')(pool4)
    conv12 = Conv2D(512, (3,3), padding='same', activation='relu')(conv11)
    conv13 = Conv2D(256, (3,3), padding='same', activation='relu')(conv12)
    pool5 = MaxPooling2D(pool_size=2)(conv13)

    # 扁平层
    flat = Flatten()(pool5)

    # 全联接层
    fc1 = Dense(4096, activation='relu')(flat)
    fc2 = Dense(4096, activation='relu')(fc1)

    # 输出层
    outputs = Dense(10, activation='softmax')(fc2)


    model = Model(inputs=inputs, outputs=outputs)
    # how to compute the memory allocated by the activations of a model
    batch = 1
    shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
    else 1 for s in l.output_shape])) 
    for l in model.layers]))
    memory = (shapes_count * 4 * batch)/10**6
    print(memory)
    
    Total_params = round(model.count_params()/10 ** 6,2)
    FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
    with open("para_count_vgg16.csv","a+") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerows([[model_num, input_x, input_y, FLOPs, Total_params, memory],])

        model_num = model_num + 1
# Out:
# TensorFlow version: 2.6.0
# 1.259564
# 4.93982
# 11.07358
# 19.660844
# 30.701612
# 44.195884
# 60.14366
# 78.54494
# 99.399724
# 122.708012
# 148.469804
# 176.6851
# 207.3539
# 240.476204
# 276.052012

# %%
import os
import csv
import numpy as np
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from itertools import product
from keras_flops import get_flops
import keras

model_num = 1
input_shape_range =range(32,512,32)

with open("para_count_vgg16.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical","step","number of layers","FLOPs", "Total_params", "Memory"],])
          
path = "../vgg16_h5" #文件夹目录
files= os.listdir(path) #得到文件夹下的所有文件名称
print(files)
for shape_x in input_shape_range:
    shape_y = shape_x
    for step in range(1,11):
        file = "vgg16_{input_x}_{input_y}_{step}.h5".format(input_x=shape_x,input_y=shape_y,step=step)
        if file in files: #遍历文件夹
            model_name = str(file)
            if not os.path.isdir(file): #判断是否是文件夹，不是文件夹才打开
                model = keras.models.load_model("../vgg16_h5/{}".format(model_name))
                # how to compute the memory allocated by the activations of a model
                batch = 1
                shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
                else 1 for s in l.output_shape])) 
                for l in model.layers]))
                memory = (shapes_count * 4 * batch)/10**6
                print(memory)
                layers_length = len(model.layers)
                Total_params = round(model.count_params()/10 ** 6,2)
                FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
                with open("para_count_vgg16.csv","a+") as csvfile:
                    writer = csv.writer(csvfile)
                    writer.writerows([[model_num, shape_x, shape_y, step, layers_length, FLOPs, Total_params, memory],])

                    model_num = model_num + 1
# Out:
# 2022-04-12 09:47:08.417567: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-04-12 09:47:08.417603: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ['vgg16_224_224_7.h5', 'vgg16_128_128_7.h5', 'vgg16_96_96_8.h5', 'vgg16_96_96_3.h5', 'vgg16_288_288_4.h5', 'vgg16_32_32_1.h5', 'vgg16_192_192_9.h5', 'vgg16_288_288_5.h5', 'vgg16_64_64_9.h5', 'vgg16_160_160_7.h5', 'vgg16_256_256_1.h5', 'vgg16_288_288_3.h5', 'vgg16_64_64_2.h5', 'vgg16_320_320_2.h5', 'vgg16_288_288_9.h5', 'vgg16_256_256_8.h5', 'vgg16_256_256_7.h5', 'vgg16_224_224_2.h5', 'vgg16_32_32_8.h5', 'vgg16_288_288_6.h5', 'vgg16_160_160_1.h5', 'vgg16_128_128_9.h5', 'vgg16_64_64_10.h5', 'vgg16_96_96_5.h5', 'vgg16_288_288_7.h5', 'vgg16_256_256_10.h5', 'vgg16_96_96_4.h5', 'vgg16_32_32_5.h5', 'vgg16_32_32_4.h5', 'vgg16_288_288_8.h5', 'vgg16_288_288_10.h5', 'vgg16_288_288_1.h5', 'vgg16_160_160_5.h5', 'vgg16_192_192_10.h5', 'vgg16_128_128_2.h5', 'vgg16_96_96_1.h5', 'vgg16_96_96_2.h5', 'vgg16_224_224_6.h5', 'vgg16_256_256_3.h5', 'vgg16_320_320_1.h5', 'vgg16_192_192_1.h5', 'vgg16_128_128_1.h5', 'vgg16_224_224_3.h5', 'vgg16_192_192_5.h5', 'vgg16_32_32_10.h5', 'vgg16_64_64_3.h5', 'vgg16_160_160_9.h5', 'vgg16_224_224_5.h5', 'vgg16_128_128_8.h5', 'vgg16_160_160_6.h5', 'vgg16_256_256_5.h5', 'vgg16_288_288_2.h5', 'vgg16_160_160_10.h5', 'vgg16_224_224_4.h5', 'vgg16_32_32_9.h5', 'vgg16_64_64_5.h5', 'vgg16_160_160_4.h5', 'vgg16_96_96_7.h5', 'vgg16_160_160_2.h5', 'vgg16_128_128_5.h5', 'vgg16_224_224_10.h5', 'vgg16_192_192_3.h5', 'vgg16_32_32_2.h5', 'vgg16_224_224_9.h5', 'vgg16_256_256_2.h5', 'vgg16_64_64_6.h5', 'vgg16_192_192_2.h5', 'vgg16_192_192_8.h5', 'vgg16_224_224_1.h5', 'vgg16_256_256_6.h5', 'vgg16_224_224_8.h5', 'vgg16_64_64_4.h5', 'vgg16_192_192_4.h5', 'vgg16_96_96_9.h5', 'vgg16_320_320_3.h5', 'vgg16_160_160_8.h5', 'vgg16_32_32_6.h5', 'vgg16_32_32_7.h5', 'vgg16_192_192_7.h5', 'vgg16_64_64_7.h5', 'vgg16_192_192_6.h5', 'vgg16_256_256_9.h5', 'vgg16_128_128_4.h5', 'vgg16_32_32_3.h5', 'vgg16_256_256_4.h5', 'vgg16_128_128_6.h5', 'vgg16_96_96_6.h5', 'vgg16_64_64_8.h5', 'vgg16_64_64_1.h5', 'vgg16_160_160_3.h5', 'vgg16_128_128_10.h5', 'vgg16_128_128_3.h5', 'vgg16_96_96_10.h5']
# 2022-04-12 09:47:09.788024: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-04-12 09:47:09.788042: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-12 09:47:09.788057: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2022-04-12 09:47:09.788197: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.986204
# 2022-04-12 09:47:10.516138: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-12 09:47:10.516246: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-12 09:47:10.540634: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.013ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# WARNING:tensorflow:From /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py:5063: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/436.72m flops)
#   model/conv2d_6/Conv2D (73.15m/73.15m flops)
#   model/conv2d_5/Conv2D (65.09m/65.09m flops)
#   model/conv2d_3/Conv2D (53.29m/53.29m flops)
#   model/conv2d_9/Conv2D (43.14m/43.14m flops)
#   model/conv2d_1/Conv2D (34.50m/34.50m flops)
#   model/conv2d_4/Conv2D (30.72m/30.72m flops)
#   model/conv2d_8/Conv2D (30.53m/30.53m flops)
#   model/conv2d_2/Conv2D (23.48m/23.48m flops)
#   model/conv2d_7/Conv2D (22.68m/22.68m flops)
#   model/conv2d_12/Conv2D (18.73m/18.73m flops)
#   model/conv2d_11/Conv2D (17.99m/17.99m flops)
#   model/conv2d_10/Conv2D (15.45m/15.45m flops)
#   model/dense_1/MatMul (4.88m/4.88m flops)
#   model/dense/MatMul (2.07m/2.07m flops)
#   model/conv2d/Conv2D (663.55k/663.55k flops)
#   model/conv2d_1/BiasAdd (53.25k/53.25k flops)
#   model/max_pooling2d/MaxPool (53.25k/53.25k flops)
#   model/conv2d/BiasAdd (36.86k/36.86k flops)
#   model/conv2d_3/BiasAdd (30.21k/30.21k flops)
#   model/max_pooling2d_1/MaxPool (30.21k/30.21k flops)
#   model/conv2d_2/BiasAdd (25.09k/25.09k flops)
#   model/dense_2/MatMul (24.00k/24.00k flops)
#   model/conv2d_6/BiasAdd (16.26k/16.26k flops)
#   model/max_pooling2d_2/MaxPool (16.26k/16.26k flops)
#   model/conv2d_5/BiasAdd (16.00k/16.00k flops)
#   model/conv2d_4/BiasAdd (14.46k/14.46k flops)
#   model/max_pooling2d_3/MaxPool (7.01k/7.01k flops)
#   model/conv2d_9/BiasAdd (7.01k/7.01k flops)
#   model/conv2d_8/BiasAdd (5.47k/5.47k flops)
#   model/conv2d_7/BiasAdd (4.96k/4.96k flops)
#   model/max_pooling2d_4/MaxPool (2.04k/2.04k flops)
#   model/conv2d_11/BiasAdd (2.04k/2.04k flops)
#   model/conv2d_12/BiasAdd (2.04k/2.04k flops)
#   model/dense/BiasAdd (2.03k/2.03k flops)
#   model/conv2d_10/BiasAdd (1.96k/1.96k flops)
#   model/dense_1/BiasAdd (1.20k/1.20k flops)
#   model/dense_2/Softmax (50/50 flops)
#   model/dense_2/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.01718
# 2022-04-12 09:47:11.768050: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-12 09:47:11.768140: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-12 09:47:11.778335: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.012ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/446.53m flops)
#   model_1/conv2d_19/Conv2D (63.08m/63.08m flops)
#   model_1/conv2d_22/Conv2D (60.37m/60.37m flops)
#   model_1/conv2d_21/Conv2D (56.00m/56.00m flops)
#   model_1/conv2d_14/Conv2D (51.76m/51.76m flops)
#   model_1/conv2d_18/Conv2D (43.13m/43.13m flops)
#   model_1/conv2d_16/Conv2D (36.42m/36.42m flops)
#   model_1/conv2d_20/Conv2D (29.38m/29.38m flops)
#   model_1/conv2d_17/Conv2D (19.17m/19.17m flops)
#   model_1/conv2d_15/Conv2D (18.91m/18.91m flops)
#   model_1/conv2d_25/Conv2D (18.43m/18.43m flops)
#   model_1/conv2d_24/Conv2D (18.22m/18.22m flops)
#   model_1/conv2d_23/Conv2D (16.92m/16.92m flops)
#   model_1/dense_4/MatMul (10.73m/10.73m flops)
#   model_1/dense_3/MatMul (2.67m/2.67m flops)
#   model_1/conv2d_13/Conv2D (958.46k/958.46k flops)
#   model_1/conv2d_14/BiasAdd (55.30k/55.30k flops)
#   model_1/max_pooling2d_5/MaxPool (55.30k/55.30k flops)
#   model_1/conv2d_13/BiasAdd (53.25k/53.25k flops)
#   model_1/dense_5/MatMul (40.64k/40.64k flops)
#   model_1/conv2d_16/BiasAdd (26.62k/26.62k flops)
#   model_1/max_pooling2d_6/MaxPool (26.62k/26.62k flops)
#   model_1/conv2d_15/BiasAdd (19.46k/19.46k flops)
#   model_1/conv2d_19/BiasAdd (14.98k/14.98k flops)
#   model_1/conv2d_18/BiasAdd (14.98k/14.98k flops)
#   model_1/max_pooling2d_7/MaxPool (14.98k/14.98k flops)
#   model_1/conv2d_17/BiasAdd (10.24k/10.24k flops)
#   model_1/conv2d_22/BiasAdd (7.52k/7.52k flops)
#   model_1/max_pooling2d_8/MaxPool (7.52k/7.52k flops)
#   model_1/conv2d_21/BiasAdd (7.14k/7.14k flops)
#   model_1/conv2d_20/BiasAdd (6.98k/6.98k flops)
#   model_1/dense_3/BiasAdd (2.64k/2.64k flops)
#   model_1/dense_4/BiasAdd (2.03k/2.03k flops)
#   model_1/conv2d_25/BiasAdd (2.02k/2.02k flops)
#   model_1/conv2d_24/BiasAdd (2.02k/2.02k flops)
#   model_1/max_pooling2d_9/MaxPool (2.02k/2.02k flops)
#   model_1/conv2d_23/BiasAdd (2.00k/2.00k flops)
#   model_1/dense_5/Softmax (50/50 flops)
#   model_1/dense_5/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.9747
# 2022-04-12 09:47:13.341748: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-12 09:47:13.341827: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-12 09:47:13.343370: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/426.07m flops)
#   model_2/conv2d_35/Conv2D (65.35m/65.35m flops)
#   model_2/conv2d_32/Conv2D (56.17m/56.17m flops)
#   model_2/conv2d_29/Conv2D (51.78m/51.78m flops)
#   model_2/conv2d_34/Conv2D (42.44m/42.44m flops)
#   model_2/conv2d_31/Conv2D (38.10m/38.10m flops)
#   model_2/conv2d_27/Conv2D (35.09m/35.09m flops)
#   model_2/conv2d_28/Conv2D (27.35m/27.35m flops)
#   model_2/conv2d_33/Conv2D (21.59m/21.59m flops)
#   model_2/conv2d_30/Conv2D (19.05m/19.05m flops)
#   model_2/conv2d_38/Conv2D (18.58m/18.58m flops)
#   model_2/conv2d_37/Conv2D (18.43m/18.43m flops)
#   model_2/conv2d_36/Conv2D (18.22m/18.22m flops)
#   model_2/dense_7/MatMul (10.30m/10.30m flops)
#   model_2/dense_6/MatMul (2.62m/2.62m flops)
#   model_2/conv2d_26/Conv2D (626.69k/626.69k flops)
#   model_2/conv2d_27/BiasAdd (57.34k/57.34k flops)
#   model_2/max_pooling2d_10/MaxPool (57.34k/57.34k flops)
#   model_2/dense_8/MatMul (40.00k/40.00k flops)
#   model_2/conv2d_26/BiasAdd (34.82k/34.82k flops)
#   model_2/conv2d_29/BiasAdd (27.14k/27.14k flops)
#   model_2/max_pooling2d_11/MaxPool (27.14k/27.14k flops)
#   model_2/conv2d_28/BiasAdd (27.14k/27.14k flops)
#   model_2/conv2d_32/BiasAdd (14.72k/14.72k flops)
#   model_2/max_pooling2d_12/MaxPool (14.72k/14.72k flops)
#   model_2/conv2d_31/BiasAdd (13.57k/13.57k flops)
#   model_2/conv2d_30/BiasAdd (9.98k/9.98k flops)
#   model_2/conv2d_35/BiasAdd (8.03k/8.03k flops)
#   model_2/max_pooling2d_13/MaxPool (8.03k/8.03k flops)
#   model_2/conv2d_34/BiasAdd (7.23k/7.23k flops)
#   model_2/conv2d_33/BiasAdd (5.22k/5.22k flops)
#   model_2/dense_6/BiasAdd (2.58k/2.58k flops)
#   model_2/conv2d_38/BiasAdd (2.03k/2.03k flops)
#   model_2/conv2d_37/BiasAdd (2.03k/2.03k flops)
#   model_2/max_pooling2d_14/MaxPool (2.03k/2.03k flops)
#   model_2/conv2d_36/BiasAdd (2.02k/2.02k flops)
#   model_2/dense_7/BiasAdd (2.00k/2.00k flops)
#   model_2/dense_8/Softmax (50/50 flops)
#   model_2/dense_8/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.940732
# 2022-04-12 09:47:14.721820: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-12 09:47:14.721932: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-12 09:47:14.724819: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.011ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/320.78m flops)
#   model_3/conv2d_40/Conv2D (55.74m/55.74m flops)
#   model_3/conv2d_45/Conv2D (43.36m/43.36m flops)
#   model_3/conv2d_48/Conv2D (37.26m/37.26m flops)
#   model_3/conv2d_44/Conv2D (32.18m/32.18m flops)
#   model_3/conv2d_47/Conv2D (25.86m/25.86m flops)
#   model_3/conv2d_42/Conv2D (24.77m/24.77m flops)
#   model_3/conv2d_51/Conv2D (17.92m/17.92m flops)
#   model_3/conv2d_41/Conv2D (16.52m/16.52m flops)
#   model_3/conv2d_46/Conv2D (15.98m/15.98m flops)
#   model_3/conv2d_50/Conv2D (15.94m/15.94m flops)
#   model_3/conv2d_43/Conv2D (13.93m/13.93m flops)
#   model_3/conv2d_49/Conv2D (13.35m/13.35m flops)
#   model_3/dense_10/MatMul (4.77m/4.77m flops)
#   model_3/dense_9/MatMul (1.86m/1.86m flops)
#   model_3/conv2d_39/Conv2D (995.33k/995.33k flops)
#   model_3/conv2d_40/BiasAdd (57.34k/57.34k flops)
#   model_3/max_pooling2d_15/MaxPool (57.34k/57.34k flops)
#   model_3/conv2d_39/BiasAdd (55.30k/55.30k flops)
#   model_3/dense_11/MatMul (25.92k/25.92k flops)
#   model_3/conv2d_42/BiasAdd (21.50k/21.50k flops)
#   model_3/max_pooling2d_16/MaxPool (21.50k/21.50k flops)
#   model_3/conv2d_41/BiasAdd (16.38k/16.38k flops)
#   model_3/conv2d_45/BiasAdd (12.42k/12.42k flops)
#   model_3/conv2d_44/BiasAdd (12.42k/12.42k flops)
#   model_3/max_pooling2d_17/MaxPool (12.42k/12.42k flops)
#   model_3/conv2d_43/BiasAdd (9.22k/9.22k flops)
#   model_3/conv2d_48/BiasAdd (6.59k/6.59k flops)
#   model_3/max_pooling2d_18/MaxPool (6.59k/6.59k flops)
#   model_3/conv2d_47/BiasAdd (5.02k/5.02k flops)
#   model_3/conv2d_46/BiasAdd (4.58k/4.58k flops)
#   model_3/max_pooling2d_19/MaxPool (2.02k/2.02k flops)
#   model_3/conv2d_51/BiasAdd (2.02k/2.02k flops)
#   model_3/conv2d_50/BiasAdd (1.97k/1.97k flops)
#   model_3/dense_9/BiasAdd (1.84k/1.84k flops)
#   model_3/conv2d_49/BiasAdd (1.80k/1.80k flops)
#   model_3/dense_10/BiasAdd (1.30k/1.30k flops)
#   model_3/dense_11/Softmax (50/50 flops)
#   model_3/dense_11/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.997788
# 2022-04-12 09:47:15.767528: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-12 09:47:15.767608: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-12 09:47:15.769173: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/502.44m flops)
#   model_4/conv2d_61/Conv2D (74.91m/74.91m flops)
#   model_4/conv2d_60/Conv2D (70.50m/70.50m flops)
#   model_4/conv2d_58/Conv2D (65.24m/65.24m flops)
#   model_4/conv2d_57/Conv2D (57.15m/57.15m flops)
#   model_4/conv2d_55/Conv2D (46.45m/46.45m flops)
#   model_4/conv2d_53/Conv2D (35.02m/35.02m flops)
#   model_4/conv2d_59/Conv2D (33.45m/33.45m flops)
#   model_4/conv2d_56/Conv2D (30.77m/30.77m flops)
#   model_4/conv2d_64/Conv2D (18.73m/18.73m flops)
#   model_4/conv2d_63/Conv2D (18.73m/18.73m flops)
#   model_4/conv2d_62/Conv2D (18.73m/18.73m flops)
#   model_4/conv2d_54/Conv2D (18.43m/18.43m flops)
#   model_4/dense_13/MatMul (10.66m/10.66m flops)
#   model_4/dense_12/MatMul (2.59m/2.59m flops)
#   model_4/conv2d_52/Conv2D (700.42k/700.42k flops)
#   model_4/conv2d_53/BiasAdd (51.20k/51.20k flops)
#   model_4/max_pooling2d_20/MaxPool (51.20k/51.20k flops)
#   model_4/dense_14/MatMul (41.92k/41.92k flops)
#   model_4/conv2d_52/BiasAdd (38.91k/38.91k flops)
#   model_4/conv2d_55/BiasAdd (32.26k/32.26k flops)
#   model_4/max_pooling2d_21/MaxPool (32.26k/32.26k flops)
#   model_4/conv2d_54/BiasAdd (20.48k/20.48k flops)
#   model_4/conv2d_58/BiasAdd (15.49k/15.49k flops)
#   model_4/max_pooling2d_22/MaxPool (15.49k/15.49k flops)
#   model_4/conv2d_57/BiasAdd (14.98k/14.98k flops)
#   model_4/conv2d_56/BiasAdd (13.57k/13.57k flops)
#   model_4/conv2d_60/BiasAdd (8.16k/8.16k flops)
#   model_4/conv2d_61/BiasAdd (8.16k/8.16k flops)
#   model_4/max_pooling2d_23/MaxPool (8.16k/8.16k flops)
#   model_4/conv2d_59/BiasAdd (7.68k/7.68k flops)
#   model_4/dense_12/BiasAdd (2.54k/2.54k flops)
#   model_4/dense_13/BiasAdd (2.10k/2.10k flops)
#   model_4/conv2d_64/BiasAdd (2.04k/2.04k flops)
#   model_4/conv2d_63/BiasAdd (2.04k/2.04k flops)
#   model_4/conv2d_62/BiasAdd (2.04k/2.04k flops)
#   model_4/max_pooling2d_24/MaxPool (2.04k/2.04k flops)
#   model_4/dense_14/Softmax (50/50 flops)
#   model_4/dense_14/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.763372
# 2022-04-12 09:47:17.312082: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-12 09:47:17.312165: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-12 09:47:17.313897: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.009ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/311.92m flops)
#   model_5/conv2d_74/Conv2D (58.57m/58.57m flops)
#   model_5/conv2d_73/Conv2D (48.04m/48.04m flops)
#   model_5/conv2d_71/Conv2D (30.23m/30.23m flops)
#   model_5/conv2d_68/Conv2D (26.76m/26.76m flops)
#   model_5/conv2d_70/Conv2D (23.51m/23.51m flops)
#   model_5/conv2d_66/Conv2D (22.41m/22.41m flops)
#   model_5/conv2d_77/Conv2D (18.22m/18.22m flops)
#   model_5/conv2d_72/Conv2D (17.45m/17.45m flops)
#   model_5/conv2d_76/Conv2D (17.13m/17.13m flops)
#   model_5/conv2d_75/Conv2D (15.56m/15.56m flops)
#   model_5/conv2d_69/Conv2D (12.77m/12.77m flops)
#   model_5/conv2d_67/Conv2D (11.56m/11.56m flops)
#   model_5/dense_16/MatMul (6.17m/6.17m flops)
#   model_5/dense_15/MatMul (2.66m/2.66m flops)
#   model_5/conv2d_65/Conv2D (589.82k/589.82k flops)
#   model_5/conv2d_66/BiasAdd (38.91k/38.91k flops)
#   model_5/max_pooling2d_25/MaxPool (38.91k/38.91k flops)
#   model_5/conv2d_65/BiasAdd (32.77k/32.77k flops)
#   model_5/dense_17/MatMul (23.36k/23.36k flops)
#   model_5/conv2d_68/BiasAdd (22.53k/22.53k flops)
#   model_5/max_pooling2d_26/MaxPool (22.53k/22.53k flops)
#   model_5/conv2d_67/BiasAdd (16.90k/16.90k flops)
#   model_5/conv2d_71/BiasAdd (10.37k/10.37k flops)
#   model_5/conv2d_70/BiasAdd (10.37k/10.37k flops)
#   model_5/max_pooling2d_27/MaxPool (10.37k/10.37k flops)
#   model_5/conv2d_69/BiasAdd (8.06k/8.06k flops)
#   model_5/conv2d_74/BiasAdd (7.30k/7.30k flops)
#   model_5/max_pooling2d_28/MaxPool (7.30k/7.30k flops)
#   model_5/conv2d_73/BiasAdd (7.14k/7.14k flops)
#   model_5/conv2d_72/BiasAdd (5.98k/5.98k flops)
#   model_5/dense_15/BiasAdd (2.64k/2.64k flops)
#   model_5/conv2d_77/BiasAdd (2.02k/2.02k flops)
#   model_5/max_pooling2d_29/MaxPool (2.02k/2.02k flops)
#   model_5/conv2d_76/BiasAdd (2.01k/2.01k flops)
#   model_5/conv2d_75/BiasAdd (1.90k/1.90k flops)
#   model_5/dense_16/BiasAdd (1.17k/1.17k flops)
#   model_5/dense_17/Softmax (50/50 flops)
#   model_5/dense_17/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.91782
# 2022-04-12 09:47:18.679650: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-12 09:47:18.679788: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-12 09:47:18.681653: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.007ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/420.27m flops)
#   model_6/conv2d_87/Conv2D (72.29m/72.29m flops)
#   model_6/conv2d_86/Conv2D (68.84m/68.84m flops)
#   model_6/conv2d_84/Conv2D (51.84m/51.84m flops)
#   model_6/conv2d_79/Conv2D (38.34m/38.34m flops)
#   model_6/conv2d_85/Conv2D (34.56m/34.56m flops)
#   model_6/conv2d_83/Conv2D (29.03m/29.03m flops)
#   model_6/conv2d_81/Conv2D (24.33m/24.33m flops)
#   model_6/conv2d_90/Conv2D (18.73m/18.73m flops)
#   model_6/conv2d_89/Conv2D (18.73m/18.73m flops)
#   model_6/conv2d_88/Conv2D (18.51m/18.51m flops)
#   model_6/conv2d_80/Conv2D (14.38m/14.38m flops)
#   model_6/conv2d_82/Conv2D (14.19m/14.19m flops)
#   model_6/dense_19/MatMul (12.41m/12.41m flops)
#   model_6/dense_18/MatMul (3.02m/3.02m flops)
#   model_6/conv2d_78/Conv2D (737.28k/737.28k flops)
#   model_6/conv2d_79/BiasAdd (53.25k/53.25k flops)
#   model_6/max_pooling2d_30/MaxPool (53.25k/53.25k flops)
#   model_6/dense_20/MatMul (41.92k/41.92k flops)
#   model_6/conv2d_78/BiasAdd (40.96k/40.96k flops)
#   model_6/conv2d_81/BiasAdd (22.53k/22.53k flops)
#   model_6/max_pooling2d_31/MaxPool (22.53k/22.53k flops)
#   model_6/conv2d_84/BiasAdd (16.00k/16.00k flops)
#   model_6/max_pooling2d_32/MaxPool (16.00k/16.00k flops)
#   model_6/conv2d_80/BiasAdd (15.36k/15.36k flops)
#   model_6/conv2d_83/BiasAdd (11.52k/11.52k flops)
#   model_6/conv2d_82/BiasAdd (8.96k/8.96k flops)
#   model_6/conv2d_87/BiasAdd (8.06k/8.06k flops)
#   model_6/max_pooling2d_33/MaxPool (8.06k/8.06k flops)
#   model_6/conv2d_86/BiasAdd (7.97k/7.97k flops)
#   model_6/conv2d_85/BiasAdd (7.68k/7.68k flops)
#   model_6/dense_18/BiasAdd (2.96k/2.96k flops)
#   model_6/dense_19/BiasAdd (2.10k/2.10k flops)
#   model_6/conv2d_90/BiasAdd (2.04k/2.04k flops)
#   model_6/conv2d_89/BiasAdd (2.04k/2.04k flops)
#   model_6/conv2d_88/BiasAdd (2.04k/2.04k flops)
#   model_6/max_pooling2d_34/MaxPool (2.04k/2.04k flops)
#   model_6/dense_20/Softmax (50/50 flops)
#   model_6/dense_20/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.096988
# 2022-04-12 09:47:20.362790: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-12 09:47:20.362927: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-12 09:47:20.364939: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.016ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/461.04m flops)
#   model_7/conv2d_97/Conv2D (64.61m/64.61m flops)
#   model_7/conv2d_92/Conv2D (62.01m/62.01m flops)
#   model_7/conv2d_100/Conv2D (56.76m/56.76m flops)
#   model_7/conv2d_94/Conv2D (52.20m/52.20m flops)
#   model_7/conv2d_96/Conv2D (48.85m/48.85m flops)
#   model_7/conv2d_99/Conv2D (43.45m/43.45m flops)
#   model_7/conv2d_93/Conv2D (25.66m/25.66m flops)
#   model_7/conv2d_95/Conv2D (25.28m/25.28m flops)
#   model_7/conv2d_98/Conv2D (24.51m/24.51m flops)
#   model_7/conv2d_103/Conv2D (17.01m/17.01m flops)
#   model_7/conv2d_102/Conv2D (15.82m/15.82m flops)
#   model_7/conv2d_101/Conv2D (14.71m/14.71m flops)
#   model_7/dense_22/MatMul (6.00m/6.00m flops)
#   model_7/dense_21/MatMul (2.72m/2.72m flops)
#   model_7/conv2d_91/Conv2D (1.07m/1.07m flops)
#   model_7/max_pooling2d_35/MaxPool (59.39k/59.39k flops)
#   model_7/conv2d_91/BiasAdd (59.39k/59.39k flops)
#   model_7/conv2d_92/BiasAdd (59.39k/59.39k flops)
#   model_7/conv2d_94/BiasAdd (30.21k/30.21k flops)
#   model_7/max_pooling2d_36/MaxPool (30.21k/30.21k flops)
#   model_7/conv2d_93/BiasAdd (24.58k/24.58k flops)
#   model_7/dense_23/MatMul (21.44k/21.44k flops)
#   model_7/conv2d_97/BiasAdd (15.74k/15.74k flops)
#   model_7/max_pooling2d_37/MaxPool (15.74k/15.74k flops)
#   model_7/conv2d_96/BiasAdd (14.59k/14.59k flops)
#   model_7/conv2d_95/BiasAdd (11.90k/11.90k flops)
#   model_7/conv2d_100/BiasAdd (7.23k/7.23k flops)
#   model_7/max_pooling2d_38/MaxPool (7.23k/7.23k flops)
#   model_7/conv2d_99/BiasAdd (6.98k/6.98k flops)
#   model_7/conv2d_98/BiasAdd (5.54k/5.54k flops)
#   model_7/dense_21/BiasAdd (2.80k/2.80k flops)
#   model_7/max_pooling2d_39/MaxPool (1.94k/1.94k flops)
#   model_7/conv2d_103/BiasAdd (1.94k/1.94k flops)
#   model_7/conv2d_102/BiasAdd (1.94k/1.94k flops)
#   model_7/conv2d_101/BiasAdd (1.81k/1.81k flops)
#   model_7/dense_22/BiasAdd (1.07k/1.07k flops)
#   model_7/dense_23/Softmax (50/50 flops)
#   model_7/dense_23/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.945852
# 2022-04-12 09:47:21.372907: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-12 09:47:21.373058: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-12 09:47:21.374966: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.008ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/364.82m flops)
#   model_8/conv2d_113/Conv2D (57.54m/57.54m flops)
#   model_8/conv2d_112/Conv2D (47.78m/47.78m flops)
#   model_8/conv2d_105/Conv2D (47.04m/47.04m flops)
#   model_8/conv2d_110/Conv2D (44.24m/44.24m flops)
#   model_8/conv2d_107/Conv2D (28.00m/28.00m flops)
#   model_8/conv2d_111/Conv2D (25.71m/25.71m flops)
#   model_8/conv2d_109/Conv2D (23.59m/23.59m flops)
#   model_8/conv2d_116/Conv2D (18.00m/18.00m flops)
#   model_8/conv2d_115/Conv2D (17.71m/17.71m flops)
#   model_8/conv2d_106/Conv2D (16.57m/16.57m flops)
#   model_8/conv2d_114/Conv2D (15.93m/15.93m flops)
#   model_8/conv2d_108/Conv2D (14.45m/14.45m flops)
#   model_8/dense_25/MatMul (5.24m/5.24m flops)
#   model_8/dense_24/MatMul (1.85m/1.85m flops)
#   model_8/conv2d_104/Conv2D (811.01k/811.01k flops)
#   model_8/conv2d_105/BiasAdd (59.39k/59.39k flops)
#   model_8/max_pooling2d_40/MaxPool (59.39k/59.39k flops)
#   model_8/conv2d_104/BiasAdd (45.06k/45.06k flops)
#   model_8/dense_26/MatMul (28.48k/28.48k flops)
#   model_8/conv2d_107/BiasAdd (25.09k/25.09k flops)
#   model_8/max_pooling2d_41/MaxPool (25.09k/25.09k flops)
#   model_8/conv2d_106/BiasAdd (15.87k/15.87k flops)
#   model_8/conv2d_110/BiasAdd (15.36k/15.36k flops)
#   model_8/max_pooling2d_42/MaxPool (15.36k/15.36k flops)
#   model_8/conv2d_109/BiasAdd (10.24k/10.24k flops)
#   model_8/conv2d_108/BiasAdd (8.19k/8.19k flops)
#   model_8/conv2d_113/BiasAdd (7.17k/7.17k flops)
#   model_8/max_pooling2d_43/MaxPool (7.17k/7.17k flops)
#   model_8/conv2d_112/BiasAdd (7.14k/7.14k flops)
#   model_8/conv2d_111/BiasAdd (5.95k/5.95k flops)
#   model_8/max_pooling2d_44/MaxPool (2.01k/2.01k flops)
#   model_8/conv2d_116/BiasAdd (2.01k/2.01k flops)
#   model_8/conv2d_115/BiasAdd (1.99k/1.99k flops)
#   model_8/conv2d_114/BiasAdd (1.98k/1.98k flops)
#   model_8/dense_24/BiasAdd (1.84k/1.84k flops)
#   model_8/dense_25/BiasAdd (1.42k/1.42k flops)
#   model_8/dense_26/Softmax (50/50 flops)
#   model_8/dense_26/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.954716
# 2022-04-12 09:47:22.797866: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-12 09:47:22.797946: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-12 09:47:22.799594: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/393.30m flops)
#   model_9/conv2d_123/Conv2D (63.07m/63.07m flops)
#   model_9/conv2d_126/Conv2D (51.92m/51.92m flops)
#   model_9/conv2d_118/Conv2D (41.29m/41.29m flops)
#   model_9/conv2d_122/Conv2D (38.49m/38.49m flops)
#   model_9/conv2d_125/Conv2D (37.74m/37.74m flops)
#   model_9/conv2d_120/Conv2D (32.26m/32.26m flops)
#   model_9/conv2d_124/Conv2D (24.60m/24.60m flops)
#   model_9/conv2d_129/Conv2D (18.73m/18.73m flops)
#   model_9/conv2d_128/Conv2D (18.73m/18.73m flops)
#   model_9/conv2d_127/Conv2D (18.29m/18.29m flops)
#   model_9/conv2d_119/Conv2D (18.06m/18.06m flops)
#   model_9/conv2d_121/Conv2D (16.59m/16.59m flops)
#   model_9/dense_28/MatMul (9.97m/9.97m flops)
#   model_9/dense_27/MatMul (2.46m/2.46m flops)
#   model_9/conv2d_117/Conv2D (737.28k/737.28k flops)
#   model_9/conv2d_118/BiasAdd (57.34k/57.34k flops)
#   model_9/max_pooling2d_45/MaxPool (57.34k/57.34k flops)
#   model_9/dense_29/MatMul (41.28k/41.28k flops)
#   model_9/conv2d_117/BiasAdd (40.96k/40.96k flops)
#   model_9/conv2d_120/BiasAdd (25.60k/25.60k flops)
#   model_9/max_pooling2d_46/MaxPool (25.60k/25.60k flops)
#   model_9/conv2d_119/BiasAdd (17.92k/17.92k flops)
#   model_9/conv2d_123/BiasAdd (15.10k/15.10k flops)
#   model_9/max_pooling2d_47/MaxPool (15.10k/15.10k flops)
#   model_9/conv2d_122/BiasAdd (14.85k/14.85k flops)
#   model_9/conv2d_121/BiasAdd (9.22k/9.22k flops)
#   model_9/conv2d_126/BiasAdd (7.97k/7.97k flops)
#   model_9/max_pooling2d_48/MaxPool (7.97k/7.97k flops)
#   model_9/conv2d_125/BiasAdd (5.79k/5.79k flops)
#   model_9/conv2d_124/BiasAdd (5.79k/5.79k flops)
#   model_9/dense_27/BiasAdd (2.42k/2.42k flops)
#   model_9/dense_28/BiasAdd (2.06k/2.06k flops)
#   model_9/conv2d_129/BiasAdd (2.04k/2.04k flops)
#   model_9/conv2d_128/BiasAdd (2.04k/2.04k flops)
#   model_9/conv2d_127/BiasAdd (2.04k/2.04k flops)
#   model_9/max_pooling2d_49/MaxPool (2.04k/2.04k flops)
#   model_9/dense_29/Softmax (50/50 flops)
#   model_9/dense_29/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 3.42366
# 2022-04-12 09:47:23.940503: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-12 09:47:23.940579: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-12 09:47:23.942344: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.009ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.71b flops)
#   model_10/conv2d_136/Conv2D (292.63m/292.63m flops)
#   model_10/conv2d_135/Conv2D (271.72m/271.72m flops)
#   model_10/conv2d_139/Conv2D (253.81m/253.81m flops)
#   model_10/conv2d_138/Conv2D (183.94m/183.94m flops)
#   model_10/conv2d_133/Conv2D (121.65m/121.65m flops)
#   model_10/conv2d_134/Conv2D (107.83m/107.83m flops)
#   model_10/conv2d_137/Conv2D (103.93m/103.93m flops)
#   model_10/conv2d_131/Conv2D (95.55m/95.55m flops)
#   model_10/conv2d_142/Conv2D (73.74m/73.74m flops)
#   model_10/conv2d_141/Conv2D (72.58m/72.58m flops)
#   model_10/conv2d_140/Conv2D (71.14m/71.14m flops)
#   model_10/conv2d_132/Conv2D (43.79m/43.79m flops)
#   model_10/dense_30/MatMul (9.43m/9.43m flops)
#   model_10/dense_31/MatMul (8.98m/8.98m flops)
#   model_10/conv2d_130/Conv2D (2.65m/2.65m flops)
#   model_10/conv2d_131/BiasAdd (147.46k/147.46k flops)
#   model_10/max_pooling2d_50/MaxPool (147.46k/147.46k flops)
#   model_10/conv2d_130/BiasAdd (147.46k/147.46k flops)
#   model_10/conv2d_133/BiasAdd (102.40k/102.40k flops)
#   model_10/max_pooling2d_51/MaxPool (102.40k/102.40k flops)
#   model_10/conv2d_132/BiasAdd (67.58k/67.58k flops)
#   model_10/conv2d_136/BiasAdd (64.51k/64.51k flops)
#   model_10/conv2d_135/BiasAdd (64.51k/64.51k flops)
#   model_10/max_pooling2d_52/MaxPool (64.51k/64.51k flops)
#   model_10/conv2d_134/BiasAdd (59.90k/59.90k flops)
#   model_10/dense_32/MatMul (38.72k/38.72k flops)
#   model_10/conv2d_139/BiasAdd (31.62k/31.62k flops)
#   model_10/max_pooling2d_53/MaxPool (31.62k/31.62k flops)
#   model_10/conv2d_138/BiasAdd (28.54k/28.54k flops)
#   model_10/conv2d_137/BiasAdd (22.91k/22.91k flops)
#   model_10/max_pooling2d_54/MaxPool (8.13k/8.13k flops)
#   model_10/conv2d_142/BiasAdd (8.13k/8.13k flops)
#   model_10/conv2d_141/BiasAdd (8.06k/8.06k flops)
#   model_10/conv2d_140/BiasAdd (8.00k/8.00k flops)
#   model_10/dense_30/BiasAdd (2.32k/2.32k flops)
#   model_10/dense_31/BiasAdd (1.94k/1.94k flops)
#   model_10/dense_32/Softmax (50/50 flops)
#   model_10/dense_32/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 3.627052
# 2022-04-12 09:47:25.078539: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-12 09:47:25.078620: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-12 09:47:25.080198: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.47b flops)
#   model_11/conv2d_149/Conv2D (285.59m/285.59m flops)
#   model_11/conv2d_148/Conv2D (182.15m/182.15m flops)
#   model_11/conv2d_152/Conv2D (178.00m/178.00m flops)
#   model_11/conv2d_144/Conv2D (153.35m/153.35m flops)
#   model_11/conv2d_151/Conv2D (133.90m/133.90m flops)
#   model_11/conv2d_150/Conv2D (97.73m/97.73m flops)
#   model_11/conv2d_146/Conv2D (95.85m/95.85m flops)
#   model_11/conv2d_147/Conv2D (74.65m/74.65m flops)
#   model_11/conv2d_155/Conv2D (73.15m/73.15m flops)
#   model_11/conv2d_154/Conv2D (71.14m/71.14m flops)
#   model_11/conv2d_153/Conv2D (63.17m/63.17m flops)
#   model_11/conv2d_145/Conv2D (49.84m/49.84m flops)
#   model_11/dense_33/MatMul (6.96m/6.96m flops)
#   model_11/dense_34/MatMul (4.22m/4.22m flops)
#   model_11/conv2d_143/Conv2D (2.95m/2.95m flops)
#   model_11/conv2d_144/BiasAdd (212.99k/212.99k flops)
#   model_11/max_pooling2d_55/MaxPool (212.99k/212.99k flops)
#   model_11/conv2d_143/BiasAdd (163.84k/163.84k flops)
#   model_11/conv2d_146/BiasAdd (102.40k/102.40k flops)
#   model_11/max_pooling2d_56/MaxPool (102.40k/102.40k flops)
#   model_11/conv2d_149/BiasAdd (65.02k/65.02k flops)
#   model_11/max_pooling2d_57/MaxPool (65.02k/65.02k flops)
#   model_11/conv2d_148/BiasAdd (62.46k/62.46k flops)
#   model_11/conv2d_145/BiasAdd (53.25k/53.25k flops)
#   model_11/conv2d_147/BiasAdd (41.47k/41.47k flops)
#   model_11/conv2d_152/BiasAdd (28.42k/28.42k flops)
#   model_11/max_pooling2d_58/MaxPool (28.42k/28.42k flops)
#   model_11/dense_35/MatMul (24.64k/24.64k flops)
#   model_11/conv2d_151/BiasAdd (22.27k/22.27k flops)
#   model_11/conv2d_150/BiasAdd (21.38k/21.38k flops)
#   model_11/max_pooling2d_59/MaxPool (8.13k/8.13k flops)
#   model_11/conv2d_155/BiasAdd (8.13k/8.13k flops)
#   model_11/conv2d_154/BiasAdd (8.00k/8.00k flops)
#   model_11/conv2d_153/BiasAdd (7.90k/7.90k flops)
#   model_11/dense_33/BiasAdd (1.71k/1.71k flops)
#   model_11/dense_34/BiasAdd (1.23k/1.23k flops)
#   model_11/dense_35/Softmax (50/50 flops)
#   model_11/dense_35/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# ...
#   model_123/max_pooling2d_623/MaxPool (640.22k/640.22k flops)
#   model_123/conv2d_1621/BiasAdd (640.22k/640.22k flops)
#   model_123/conv2d_1620/BiasAdd (603.94k/603.94k flops)
#   model_123/conv2d_1619/BiasAdd (324.00k/324.00k flops)
#   model_123/conv2d_1623/BiasAdd (165.24k/165.24k flops)
#   model_123/conv2d_1622/BiasAdd (163.30k/163.30k flops)
#   model_123/max_pooling2d_624/MaxPool (57.02k/57.02k flops)
#   model_123/conv2d_1624/BiasAdd (57.02k/57.02k flops)
#   model_123/dense_372/MatMul (48.32k/48.32k flops)
#   model_123/dense_370/BiasAdd (2.58k/2.58k flops)
#   model_123/dense_371/BiasAdd (2.42k/2.42k flops)
#   model_123/dense_372/Softmax (50/50 flops)
#   model_123/dense_372/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 75.455292
# 2022-04-12 09:50:31.127139: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-12 09:50:31.127212: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-12 09:50:31.129109: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.008ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/23.52b flops)
#   model_124/conv2d_1628/Conv2D (4.07b/4.07b flops)
#   model_124/conv2d_1626/Conv2D (3.68b/3.68b flops)
#   model_124/conv2d_1631/Conv2D (2.84b/2.84b flops)
#   model_124/conv2d_1634/Conv2D (2.14b/2.14b flops)
#   model_124/conv2d_1630/Conv2D (2.07b/2.07b flops)
#   model_124/conv2d_1627/Conv2D (1.96b/1.96b flops)
#   model_124/conv2d_1629/Conv2D (1.58b/1.58b flops)
#   model_124/conv2d_1636/Conv2D (1.37b/1.37b flops)
#   model_124/conv2d_1633/Conv2D (1.11b/1.11b flops)
#   model_124/conv2d_1635/Conv2D (1.08b/1.08b flops)
#   model_124/conv2d_1632/Conv2D (961.11m/961.11m flops)
#   model_124/conv2d_1637/Conv2D (503.65m/503.65m flops)
#   model_124/conv2d_1625/Conv2D (65.69m/65.69m flops)
#   model_124/dense_373/MatMul (62.13m/62.13m flops)
#   model_124/dense_374/MatMul (8.30m/8.30m flops)
#   model_124/conv2d_1626/BiasAdd (4.64m/4.64m flops)
#   model_124/max_pooling2d_625/MaxPool (4.64m/4.64m flops)
#   model_124/conv2d_1625/BiasAdd (3.65m/3.65m flops)
#   model_124/conv2d_1628/BiasAdd (2.41m/2.41m flops)
#   model_124/max_pooling2d_626/MaxPool (2.41m/2.41m flops)
#   model_124/conv2d_1627/BiasAdd (1.95m/1.95m flops)
#   model_124/conv2d_1631/BiasAdd (1.04m/1.04m flops)
#   model_124/max_pooling2d_627/MaxPool (1.04m/1.04m flops)
#   model_124/conv2d_1630/BiasAdd (787.97k/787.97k flops)
#   model_124/conv2d_1629/BiasAdd (756.86k/756.86k flops)
#   model_124/conv2d_1634/BiasAdd (515.81k/515.81k flops)
#   model_124/max_pooling2d_628/MaxPool (515.81k/515.81k flops)
#   model_124/conv2d_1633/BiasAdd (298.08k/298.08k flops)
#   model_124/conv2d_1632/BiasAdd (266.98k/266.98k flops)
#   model_124/conv2d_1636/BiasAdd (164.59k/164.59k flops)
#   model_124/conv2d_1635/BiasAdd (150.34k/150.34k flops)
#   model_124/conv2d_1637/BiasAdd (55.08k/55.08k flops)
#   model_124/max_pooling2d_629/MaxPool (55.08k/55.08k flops)
#   model_124/dense_375/MatMul (36.80k/36.80k flops)
#   model_124/dense_373/BiasAdd (2.26k/2.26k flops)
#   model_124/dense_374/BiasAdd (1.84k/1.84k flops)
#   model_124/dense_375/Softmax (50/50 flops)
#   model_124/dense_375/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 95.67902
# 2022-04-12 09:50:34.673023: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-12 09:50:34.673148: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-12 09:50:34.675102: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.009ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/42.48b flops)
#   model_125/conv2d_1647/Conv2D (7.23b/7.23b flops)
#   model_125/conv2d_1646/Conv2D (6.11b/6.11b flops)
#   model_125/conv2d_1644/Conv2D (5.24b/5.24b flops)
#   model_125/conv2d_1641/Conv2D (4.69b/4.69b flops)
#   model_125/conv2d_1639/Conv2D (4.03b/4.03b flops)
#   model_125/conv2d_1643/Conv2D (3.39b/3.39b flops)
#   model_125/conv2d_1645/Conv2D (2.83b/2.83b flops)
#   model_125/conv2d_1640/Conv2D (2.30b/2.30b flops)
#   model_125/conv2d_1649/Conv2D (1.84b/1.84b flops)
#   model_125/conv2d_1642/Conv2D (1.83b/1.83b flops)
#   model_125/conv2d_1648/Conv2D (1.83b/1.83b flops)
#   model_125/conv2d_1650/Conv2D (918.09m/918.09m flops)
#   model_125/dense_376/MatMul (133.06m/133.06m flops)
#   model_125/conv2d_1638/Conv2D (77.41m/77.41m flops)
#   model_125/dense_377/MatMul (10.05m/10.05m flops)
#   model_125/max_pooling2d_630/MaxPool (5.32m/5.32m flops)
#   model_125/conv2d_1639/BiasAdd (5.32m/5.32m flops)
#   model_125/conv2d_1638/BiasAdd (4.30m/4.30m flops)
#   model_125/max_pooling2d_631/MaxPool (2.71m/2.71m flops)
#   model_125/conv2d_1641/BiasAdd (2.71m/2.71m flops)
#   model_125/conv2d_1640/BiasAdd (2.46m/2.46m flops)
#   model_125/max_pooling2d_632/MaxPool (1.48m/1.48m flops)
#   model_125/conv2d_1644/BiasAdd (1.48m/1.48m flops)
#   model_125/conv2d_1643/BiasAdd (1.25m/1.25m flops)
#   model_125/conv2d_1642/BiasAdd (960.00k/960.00k flops)
#   model_125/max_pooling2d_633/MaxPool (803.20k/803.20k flops)
#   model_125/conv2d_1647/BiasAdd (803.20k/803.20k flops)
#   model_125/conv2d_1646/BiasAdd (800.00k/800.00k flops)
#   model_125/conv2d_1645/BiasAdd (678.40k/678.40k flops)
#   model_125/conv2d_1648/BiasAdd (202.40k/202.40k flops)
#   model_125/conv2d_1649/BiasAdd (202.40k/202.40k flops)
#   model_125/max_pooling2d_634/MaxPool (100.80k/100.80k flops)
#   model_125/conv2d_1650/BiasAdd (100.80k/100.80k flops)
#   model_125/dense_378/MatMul (38.08k/38.08k flops)
#   model_125/dense_376/BiasAdd (2.64k/2.64k flops)
#   model_125/dense_377/BiasAdd (1.90k/1.90k flops)
#   model_125/dense_378/Softmax (50/50 flops)
#   model_125/dense_378/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 105.74302
# 2022-04-12 09:50:40.980042: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-12 09:50:40.980132: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-12 09:50:40.982915: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.019ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/40.34b flops)
#   model_126/conv2d_1657/Conv2D (7.20b/7.20b flops)
#   model_126/conv2d_1652/Conv2D (7.09b/7.09b flops)
#   model_126/conv2d_1656/Conv2D (6.29b/6.29b flops)
#   model_126/conv2d_1660/Conv2D (3.57b/3.57b flops)
#   model_126/conv2d_1654/Conv2D (3.23b/3.23b flops)
#   model_126/conv2d_1659/Conv2D (2.67b/2.67b flops)
#   model_126/conv2d_1655/Conv2D (2.28b/2.28b flops)
#   model_126/conv2d_1653/Conv2D (2.23b/2.23b flops)
#   model_126/conv2d_1658/Conv2D (2.12b/2.12b flops)
#   model_126/conv2d_1662/Conv2D (1.37b/1.37b flops)
#   model_126/conv2d_1661/Conv2D (1.11b/1.11b flops)
#   model_126/conv2d_1663/Conv2D (874.54m/874.54m flops)
#   model_126/dense_379/MatMul (137.89m/137.89m flops)
#   model_126/conv2d_1651/Conv2D (114.28m/114.28m flops)
#   model_126/dense_380/MatMul (9.89m/9.89m flops)
#   model_126/max_pooling2d_635/MaxPool (6.35m/6.35m flops)
#   model_126/conv2d_1651/BiasAdd (6.35m/6.35m flops)
#   model_126/conv2d_1652/BiasAdd (6.35m/6.35m flops)
#   model_126/max_pooling2d_636/MaxPool (2.30m/2.30m flops)
#   model_126/conv2d_1654/BiasAdd (2.30m/2.30m flops)
#   model_126/conv2d_1653/BiasAdd (2.00m/2.00m flops)
#   model_126/max_pooling2d_637/MaxPool (1.61m/1.61m flops)
#   model_126/conv2d_1657/BiasAdd (1.61m/1.61m flops)
#   model_126/conv2d_1656/BiasAdd (1.59m/1.59m flops)
#   model_126/conv2d_1655/BiasAdd (1.41m/1.41m flops)
#   model_126/max_pooling2d_638/MaxPool (624.00k/624.00k flops)
#   model_126/conv2d_1660/BiasAdd (624.00k/624.00k flops)
#   model_126/conv2d_1659/BiasAdd (508.80k/508.80k flops)
#   model_126/conv2d_1658/BiasAdd (467.20k/467.20k flops)
#   model_126/conv2d_1662/BiasAdd (192.80k/192.80k flops)
#   model_126/conv2d_1661/BiasAdd (158.40k/158.40k flops)
#   model_126/max_pooling2d_639/MaxPool (100.80k/100.80k flops)
#   model_126/conv2d_1663/BiasAdd (100.80k/100.80k flops)
#   model_126/dense_381/MatMul (36.16k/36.16k flops)
#   model_126/dense_379/BiasAdd (2.74k/2.74k flops)
#   model_126/dense_380/BiasAdd (1.81k/1.81k flops)
#   model_126/dense_381/Softmax (50/50 flops)
#   model_126/dense_381/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 93.637356
# 2022-04-12 09:50:47.250563: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-12 09:50:47.250688: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-12 09:50:47.252641: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.007ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/39.32b flops)
#   model_127/conv2d_1673/Conv2D (7.11b/7.11b flops)
#   model_127/conv2d_1670/Conv2D (5.78b/5.78b flops)
#   model_127/conv2d_1669/Conv2D (4.50b/4.50b flops)
#   model_127/conv2d_1667/Conv2D (3.91b/3.91b flops)
#   model_127/conv2d_1665/Conv2D (3.87b/3.87b flops)
#   model_127/conv2d_1672/Conv2D (3.86b/3.86b flops)
#   model_127/conv2d_1668/Conv2D (2.39b/2.39b flops)
#   model_127/conv2d_1675/Conv2D (1.81b/1.81b flops)
#   model_127/conv2d_1674/Conv2D (1.80b/1.80b flops)
#   model_127/conv2d_1671/Conv2D (1.76b/1.76b flops)
#   model_127/conv2d_1666/Conv2D (1.66b/1.66b flops)
#   model_127/conv2d_1676/Conv2D (643.36m/643.36m flops)
#   model_127/dense_382/MatMul (98.54m/98.54m flops)
#   model_127/conv2d_1664/Conv2D (77.41m/77.41m flops)
#   model_127/dense_383/MatMul (7.53m/7.53m flops)
#   model_127/max_pooling2d_640/MaxPool (5.12m/5.12m flops)
#   model_127/conv2d_1665/BiasAdd (5.12m/5.12m flops)
#   model_127/conv2d_1664/BiasAdd (4.30m/4.30m flops)
#   model_127/max_pooling2d_641/MaxPool (3.02m/3.02m flops)
#   model_127/conv2d_1667/BiasAdd (3.02m/3.02m flops)
#   model_127/conv2d_1666/BiasAdd (1.84m/1.84m flops)
#   model_127/max_pooling2d_642/MaxPool (1.45m/1.45m flops)
#   model_127/conv2d_1670/BiasAdd (1.45m/1.45m flops)
#   model_127/conv2d_1669/BiasAdd (1.42m/1.42m flops)
#   model_127/conv2d_1668/BiasAdd (1.13m/1.13m flops)
#   model_127/max_pooling2d_643/MaxPool (796.80k/796.80k flops)
#   model_127/conv2d_1673/BiasAdd (796.80k/796.80k flops)
#   model_127/conv2d_1672/BiasAdd (793.60k/793.60k flops)
#   model_127/conv2d_1671/BiasAdd (432.00k/432.00k flops)
#   model_127/conv2d_1674/BiasAdd (200.80k/200.80k flops)
#   model_127/conv2d_1675/BiasAdd (200.80k/200.80k flops)
#   model_127/max_pooling2d_644/MaxPool (71.20k/71.20k flops)
#   model_127/conv2d_1676/BiasAdd (71.20k/71.20k flops)
#   model_127/dense_384/MatMul (27.20k/27.20k flops)
#   model_127/dense_382/BiasAdd (2.77k/2.77k flops)
#   model_127/dense_383/BiasAdd (1.36k/1.36k flops)
#   model_127/dense_384/Softmax (50/50 flops)
#   model_127/dense_384/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
