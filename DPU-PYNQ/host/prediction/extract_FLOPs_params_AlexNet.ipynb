# %%
import os
import csv
import numpy as np
import tensorflow as tf
import keras
from keras.models import Model
from keras_flops import get_flops
from itertools import product

def get_total_number_of_neurons(model, include_output_layer):
    '''
    Args:
        model: Keras model
        include_output_layer: A boolean parameter. Whether or not to include output layer's neurons into the calculation

    Returns: number of neurons in the given model
    '''
    num_layers = len(model.layers)
    total_num_of_neurons = 0
    for layer_index in range(num_layers):
        layer = model.layers[layer_index]
        # since we multiply layer output dimensions, initial value is set to 1.
        num_neurons_in_layer = 1
        for i in range(1, len(layer.output.shape)):
            try:
                # when it is a valid layer to count neurons, an output dimension of the layer can be convertible to int.
                num_neurons_in_layer *= int(layer.output.shape[i])
            except Exception:
                # if the output dimension of layer cannot be convertible to int,
                # just pass that layer since it is not a valid layer to count neurons
                pass
        # if num_neurons_in_layer is not still 1, it means we have a valid layer to count neurons
        if not num_neurons_in_layer == 1:
            # when it is an output layer
            if layer_index == (num_layers - 1):
                if include_output_layer:
                    total_num_of_neurons += num_neurons_in_layer
            else:  # when it is not an output layer
                total_num_of_neurons += num_neurons_in_layer
    return total_num_of_neurons


with open("para_count_AlexNet.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "step","number_of_layers", "FLOPs_G", "Total_params_M", "Memory_M", "total_num_of_neurons_M"],])

path = "../AlexNet_h5" #文件夹目录
files= os.listdir(path) #得到文件夹下的所有文件名称
model_num = 1
input_shape_range =range(512,550,2)

for shape_x in input_shape_range:
    shape_y = shape_x
    for step in range(1,11):
        file = "AlexNet_{input_x}_{input_y}_{step}.h5".format(input_x=shape_x,input_y=shape_y,step=step)
        if file in files: #遍历文件夹
            model_name = str(file)
            if not os.path.isdir(file): #判断是否是文件夹，不是文件夹才打开
                model = keras.models.load_model("../AlexNet_h5/{}".format(model_name))
                num_neurons = get_total_number_of_neurons(model= model, include_output_layer= True)
                num_neurons_M = num_neurons/10**6    
                # how to compute the memory allocated by the activations of a model
                batch = 1
                shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
                else 1 for s in l.output_shape])) 
                for l in model.layers]))
                memory = (shapes_count * 4 * batch)/10**6
                print(memory)
                layers_length = len(model.layers)
                Total_params = round(model.count_params()/10 ** 6,2)
                FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
                with open("para_count_AlexNet.csv","a+") as csvfile:
                    writer = csv.writer(csvfile)
                    writer.writerows([[model_num, shape_x, shape_y, step, layers_length, FLOPs, Total_params, memory, num_neurons_M],])

                    model_num = model_num + 1
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 13.127084
# 2022-05-16 13:13:42.037123: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 13:13:42.037211: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 13:13:42.039051: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/5.81b flops)
#   model_90/conv2d_451/Conv2D (2.23b/2.23b flops)
#   model_90/conv2d_453/Conv2D (1.53b/1.53b flops)
#   model_90/conv2d_452/Conv2D (859.74m/859.74m flops)
#   model_90/conv2d_454/Conv2D (796.21m/796.21m flops)
#   model_90/conv2d_450/Conv2D (276.62m/276.62m flops)
#   model_90/dense_270/MatMul (104.34m/104.34m flops)
#   model_90/dense_271/MatMul (12.98m/12.98m flops)
#   model_90/max_pooling2d_270/MaxPool (2.49m/2.49m flops)
#   model_90/max_pooling2d_271/MaxPool (1.30m/1.30m flops)
#   model_90/conv2d_450/BiasAdd (1.14m/1.14m flops)
#   model_90/conv2d_451/BiasAdd (618.98k/618.98k flops)
#   model_90/batch_normalization_270/FusedBatchNormV3 (553.97k/553.97k flops)
#   model_90/batch_normalization_271/FusedBatchNormV3 (289.62k/289.62k flops)
#   model_90/conv2d_452/BiasAdd (259.58k/259.58k flops)
#   model_90/conv2d_453/BiasAdd (221.18k/221.18k flops)
#   model_90/max_pooling2d_272/MaxPool (214.20k/214.20k flops)
#   model_90/conv2d_454/BiasAdd (115.19k/115.19k flops)
#   model_90/dense_272/MatMul (59.20k/59.20k flops)
#   model_90/batch_normalization_272/FusedBatchNormV3 (49.03k/49.03k flops)
#   model_90/dense_271/BiasAdd (2.96k/2.96k flops)
#   model_90/dense_270/BiasAdd (2.19k/2.19k flops)
#   model_90/dense_272/Softmax (50/50 flops)
#   model_90/dense_272/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 14.23342
# 2022-05-16 13:13:46.389372: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 13:13:46.389449: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 13:13:46.391301: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/6.17b flops)
#   model_91/conv2d_456/Conv2D (2.57b/2.57b flops)
#   model_91/conv2d_458/Conv2D (1.53b/1.53b flops)
#   model_91/conv2d_457/Conv2D (850.40m/850.40m flops)
#   model_91/conv2d_459/Conv2D (829.66m/829.66m flops)
#   model_91/conv2d_455/Conv2D (322.73m/322.73m flops)
#   model_91/dense_273/MatMul (54.76m/54.76m flops)
#   model_91/dense_274/MatMul (4.35m/4.35m flops)
#   model_91/max_pooling2d_273/MaxPool (2.91m/2.91m flops)
#   model_91/conv2d_455/BiasAdd (1.33m/1.33m flops)
#   model_91/max_pooling2d_274/MaxPool (1.28m/1.28m flops)
#   model_91/batch_normalization_273/FusedBatchNormV3 (646.30k/646.30k flops)
#   model_91/conv2d_456/BiasAdd (612.25k/612.25k flops)
#   model_91/batch_normalization_274/FusedBatchNormV3 (286.47k/286.47k flops)
#   model_91/conv2d_457/BiasAdd (259.58k/259.58k flops)
#   model_91/max_pooling2d_275/MaxPool (223.20k/223.20k flops)
#   model_91/conv2d_458/BiasAdd (221.18k/221.18k flops)
#   model_91/conv2d_459/BiasAdd (120.03k/120.03k flops)
#   model_91/batch_normalization_275/FusedBatchNormV3 (51.09k/51.09k flops)
#   model_91/dense_275/MatMul (39.36k/39.36k flops)
#   model_91/dense_274/BiasAdd (1.97k/1.97k flops)
#   model_91/dense_273/BiasAdd (1.10k/1.10k flops)
#   model_91/dense_275/Softmax (50/50 flops)
#   model_91/dense_275/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 14.756236
# 2022-05-16 13:13:48.940599: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 13:13:48.940675: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 13:13:48.942474: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/6.65b flops)
#   model_92/conv2d_461/Conv2D (3.08b/3.08b flops)
#   model_92/conv2d_463/Conv2D (1.53b/1.53b flops)
#   model_92/conv2d_462/Conv2D (1.02b/1.02b flops)
#   model_92/conv2d_464/Conv2D (615.56m/615.56m flops)
#   model_92/conv2d_460/Conv2D (322.73m/322.73m flops)
#   model_92/dense_276/MatMul (63.00m/63.00m flops)
#   model_92/dense_277/MatMul (10.35m/10.35m flops)
#   model_92/max_pooling2d_276/MaxPool (2.91m/2.91m flops)
#   model_92/max_pooling2d_277/MaxPool (1.54m/1.54m flops)
#   model_92/conv2d_460/BiasAdd (1.33m/1.33m flops)
#   model_92/conv2d_461/BiasAdd (733.35k/733.35k flops)
#   model_92/batch_normalization_276/FusedBatchNormV3 (646.30k/646.30k flops)
#   model_92/batch_normalization_277/FusedBatchNormV3 (343.13k/343.13k flops)
#   model_92/conv2d_462/BiasAdd (259.58k/259.58k flops)
#   model_92/conv2d_463/BiasAdd (221.18k/221.18k flops)
#   model_92/max_pooling2d_278/MaxPool (165.60k/165.60k flops)
#   model_92/conv2d_464/BiasAdd (89.06k/89.06k flops)
#   model_92/dense_278/MatMul (60.48k/60.48k flops)
#   model_92/batch_normalization_278/FusedBatchNormV3 (37.90k/37.90k flops)
#   model_92/dense_277/BiasAdd (3.02k/3.02k flops)
#   model_92/dense_276/BiasAdd (1.71k/1.71k flops)
#   model_92/dense_278/Softmax (50/50 flops)
#   model_92/dense_278/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 15.110796
# 2022-05-16 13:13:51.711343: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 13:13:51.711420: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 13:13:51.713186: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/6.65b flops)
#   model_93/conv2d_466/Conv2D (3.27b/3.27b flops)
#   model_93/conv2d_468/Conv2D (1.53b/1.53b flops)
#   model_93/conv2d_467/Conv2D (1.01b/1.01b flops)
#   model_93/conv2d_469/Conv2D (441.59m/441.59m flops)
#   model_93/conv2d_465/Conv2D (345.78m/345.78m flops)
#   model_93/dense_279/MatMul (35.90m/35.90m flops)
#   model_93/dense_280/MatMul (6.31m/6.31m flops)
#   model_93/max_pooling2d_279/MaxPool (3.11m/3.11m flops)
#   model_93/max_pooling2d_280/MaxPool (1.52m/1.52m flops)
#   model_93/conv2d_465/BiasAdd (1.43m/1.43m flops)
#   model_93/conv2d_466/BiasAdd (726.62k/726.62k flops)
#   model_93/batch_normalization_279/FusedBatchNormV3 (692.46k/692.46k flops)
#   model_93/batch_normalization_280/FusedBatchNormV3 (339.98k/339.98k flops)
#   model_93/conv2d_467/BiasAdd (259.58k/259.58k flops)
#   model_93/conv2d_468/BiasAdd (221.18k/221.18k flops)
#   model_93/max_pooling2d_281/MaxPool (118.80k/118.80k flops)
#   model_93/conv2d_469/BiasAdd (63.89k/63.89k flops)
#   model_93/dense_281/MatMul (46.40k/46.40k flops)
#   model_93/batch_normalization_281/FusedBatchNormV3 (27.19k/27.19k flops)
#   model_93/dense_280/BiasAdd (2.32k/2.32k flops)
#   model_93/dense_279/BiasAdd (1.36k/1.36k flops)
#   model_93/dense_281/Softmax (50/50 flops)
#   model_93/dense_281/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 13.517164
# 2022-05-16 13:13:53.522546: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 13:13:53.522628: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 13:13:53.524377: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/5.85b flops)
#   model_94/conv2d_471/Conv2D (2.56b/2.56b flops)
#   model_94/conv2d_473/Conv2D (1.53b/1.53b flops)
#   model_94/conv2d_472/Conv2D (934.50m/934.50m flops)
#   model_94/conv2d_474/Conv2D (488.43m/488.43m flops)
#   model_94/conv2d_470/Conv2D (291.99m/291.99m flops)
#   model_94/dense_282/MatMul (37.84m/37.84m flops)
#   model_94/dense_283/MatMul (5.43m/5.43m flops)
#   model_94/max_pooling2d_282/MaxPool (2.63m/2.63m flops)
#   model_94/max_pooling2d_283/MaxPool (1.41m/1.41m flops)
#   model_94/conv2d_470/BiasAdd (1.21m/1.21m flops)
#   model_94/conv2d_471/BiasAdd (672.80k/672.80k flops)
#   model_94/batch_normalization_282/FusedBatchNormV3 (584.74k/584.74k flops)
#   model_94/batch_normalization_283/FusedBatchNormV3 (314.80k/314.80k flops)
#   model_94/conv2d_472/BiasAdd (259.58k/259.58k flops)
#   model_94/conv2d_473/BiasAdd (221.18k/221.18k flops)
#   model_94/max_pooling2d_284/MaxPool (131.40k/131.40k flops)
#   model_94/conv2d_474/BiasAdd (70.66k/70.66k flops)
#   model_94/dense_284/MatMul (41.92k/41.92k flops)
#   model_94/batch_normalization_284/FusedBatchNormV3 (30.08k/30.08k flops)
#   model_94/dense_283/BiasAdd (2.10k/2.10k flops)
#   model_94/dense_282/BiasAdd (1.30k/1.30k flops)
#   model_94/dense_284/Softmax (50/50 flops)
#   model_94/dense_284/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 14.95966
# 2022-05-16 13:13:55.450428: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 13:13:55.450500: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 13:13:55.452249: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/6.30b flops)
#   model_95/conv2d_476/Conv2D (2.88b/2.88b flops)
#   model_95/conv2d_478/Conv2D (1.53b/1.53b flops)
#   model_95/conv2d_477/Conv2D (850.40m/850.40m flops)
#   model_95/conv2d_479/Conv2D (588.79m/588.79m flops)
#   model_95/conv2d_475/Conv2D (361.15m/361.15m flops)
#   model_95/dense_285/MatMul (72.65m/72.65m flops)
#   model_95/dense_286/MatMul (9.05m/9.05m flops)
#   model_95/max_pooling2d_285/MaxPool (3.25m/3.25m flops)
#   model_95/conv2d_475/BiasAdd (1.49m/1.49m flops)
#   model_95/max_pooling2d_286/MaxPool (1.28m/1.28m flops)
#   model_95/batch_normalization_285/FusedBatchNormV3 (723.24k/723.24k flops)
#   model_95/conv2d_476/BiasAdd (612.25k/612.25k flops)
#   model_95/batch_normalization_286/FusedBatchNormV3 (286.47k/286.47k flops)
#   model_95/conv2d_477/BiasAdd (259.58k/259.58k flops)
#   model_95/conv2d_478/BiasAdd (221.18k/221.18k flops)
#   model_95/max_pooling2d_287/MaxPool (158.40k/158.40k flops)
#   model_95/conv2d_479/BiasAdd (85.18k/85.18k flops)
#   model_95/dense_287/MatMul (43.84k/43.84k flops)
#   model_95/batch_normalization_287/FusedBatchNormV3 (36.26k/36.26k flops)
#   model_95/dense_286/BiasAdd (2.19k/2.19k flops)
#   model_95/dense_285/BiasAdd (2.06k/2.06k flops)
#   model_95/dense_287/Softmax (50/50 flops)
#   model_95/dense_287/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 14.277484
# 2022-05-16 13:13:58.608735: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 13:13:58.608813: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 13:13:58.610551: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/6.51b flops)
#   model_96/conv2d_481/Conv2D (2.86b/2.86b flops)
#   model_96/conv2d_483/Conv2D (1.53b/1.53b flops)
#   model_96/conv2d_482/Conv2D (1.02b/1.02b flops)
#   model_96/conv2d_484/Conv2D (722.61m/722.61m flops)
#   model_96/conv2d_480/Conv2D (299.68m/299.68m flops)
#   model_96/dense_288/MatMul (65.66m/65.66m flops)
#   model_96/dense_289/MatMul (4.62m/4.62m flops)
#   model_96/max_pooling2d_288/MaxPool (2.70m/2.70m flops)
#   model_96/max_pooling2d_289/MaxPool (1.54m/1.54m flops)
#   model_96/conv2d_480/BiasAdd (1.24m/1.24m flops)
#   model_96/conv2d_481/BiasAdd (733.35k/733.35k flops)
#   model_96/batch_normalization_288/FusedBatchNormV3 (600.13k/600.13k flops)
#   model_96/batch_normalization_289/FusedBatchNormV3 (343.13k/343.13k flops)
#   model_96/conv2d_482/BiasAdd (259.58k/259.58k flops)
#   model_96/conv2d_483/BiasAdd (221.18k/221.18k flops)
#   model_96/max_pooling2d_290/MaxPool (194.40k/194.40k flops)
#   model_96/conv2d_484/BiasAdd (104.54k/104.54k flops)
#   model_96/batch_normalization_290/FusedBatchNormV3 (44.50k/44.50k flops)
#   model_96/dense_290/MatMul (30.40k/30.40k flops)
#   model_96/dense_289/BiasAdd (1.52k/1.52k flops)
#   model_96/dense_288/BiasAdd (1.52k/1.52k flops)
#   model_96/dense_290/Softmax (50/50 flops)
#   model_96/dense_290/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 13.737356
# 2022-05-16 13:14:01.410022: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 13:14:01.410136: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 13:14:01.411844: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/6.30b flops)
#   model_97/conv2d_486/Conv2D (2.78b/2.78b flops)
#   model_97/conv2d_488/Conv2D (1.53b/1.53b flops)
#   model_97/conv2d_487/Conv2D (1.10b/1.10b flops)
#   model_97/conv2d_489/Conv2D (568.72m/568.72m flops)
#   model_97/conv2d_485/Conv2D (268.94m/268.94m flops)
#   model_97/dense_291/MatMul (38.62m/38.62m flops)
#   model_97/dense_292/MatMul (5.20m/5.20m flops)
#   model_97/max_pooling2d_291/MaxPool (2.42m/2.42m flops)
#   model_97/max_pooling2d_292/MaxPool (1.67m/1.67m flops)
#   model_97/conv2d_485/BiasAdd (1.11m/1.11m flops)
#   model_97/conv2d_486/BiasAdd (793.90k/793.90k flops)
#   model_97/batch_normalization_291/FusedBatchNormV3 (538.58k/538.58k flops)
#   model_97/batch_normalization_292/FusedBatchNormV3 (371.46k/371.46k flops)
#   model_97/conv2d_487/BiasAdd (259.58k/259.58k flops)
#   model_97/conv2d_488/BiasAdd (221.18k/221.18k flops)
#   model_97/max_pooling2d_293/MaxPool (153.00k/153.00k flops)
#   model_97/conv2d_489/BiasAdd (82.28k/82.28k flops)
#   model_97/dense_293/MatMul (45.76k/45.76k flops)
#   model_97/batch_normalization_293/FusedBatchNormV3 (35.02k/35.02k flops)
#   model_97/dense_292/BiasAdd (2.29k/2.29k flops)
#   model_97/dense_291/BiasAdd (1.14k/1.14k flops)
#   model_97/dense_293/Softmax (50/50 flops)
#   model_97/dense_293/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 13.41326
# 2022-05-16 13:14:03.413870: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 13:14:03.413986: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 13:14:03.415658: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/5.66b flops)
#   model_98/conv2d_491/Conv2D (2.13b/2.13b flops)
#   model_98/conv2d_493/Conv2D (1.53b/1.53b flops)
#   model_98/conv2d_494/Conv2D (849.73m/849.73m flops)
#   model_98/conv2d_492/Conv2D (738.26m/738.26m flops)
#   model_98/conv2d_490/Conv2D (307.36m/307.36m flops)
#   model_98/dense_294/MatMul (90.22m/90.22m flops)
#   model_98/dense_295/MatMul (9.72m/9.72m flops)
#   model_98/max_pooling2d_294/MaxPool (2.77m/2.77m flops)
#   model_98/conv2d_490/BiasAdd (1.27m/1.27m flops)
#   model_98/max_pooling2d_295/MaxPool (1.11m/1.11m flops)
#   model_98/batch_normalization_294/FusedBatchNormV3 (615.52k/615.52k flops)
#   model_98/conv2d_491/BiasAdd (531.51k/531.51k flops)
#   model_98/conv2d_492/BiasAdd (259.58k/259.58k flops)
#   model_98/batch_normalization_295/FusedBatchNormV3 (248.69k/248.69k flops)
#   model_98/max_pooling2d_296/MaxPool (228.60k/228.60k flops)
#   model_98/conv2d_493/BiasAdd (221.18k/221.18k flops)
#   model_98/conv2d_494/BiasAdd (122.94k/122.94k flops)
#   model_98/dense_296/MatMul (54.72k/54.72k flops)
#   model_98/batch_normalization_296/FusedBatchNormV3 (52.32k/52.32k flops)
#   model_98/dense_295/BiasAdd (2.74k/2.74k flops)
#   model_98/dense_294/BiasAdd (1.78k/1.78k flops)
#   model_98/dense_296/Softmax (50/50 flops)
#   model_98/dense_296/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 13.698796
# 2022-05-16 13:14:07.486811: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 13:14:07.486935: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 13:14:07.488930: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/5.43b flops)
#   model_99/conv2d_496/Conv2D (2.07b/2.07b flops)
#   model_99/conv2d_498/Conv2D (1.53b/1.53b flops)
#   model_99/conv2d_499/Conv2D (729.30m/729.30m flops)
#   model_99/conv2d_497/Conv2D (654.15m/654.15m flops)
#   model_99/conv2d_495/Conv2D (338.10m/338.10m flops)
#   model_99/dense_297/MatMul (91.39m/91.39m flops)
#   model_99/dense_298/MatMul (9.86m/9.86m flops)
#   model_99/max_pooling2d_297/MaxPool (3.04m/3.04m flops)
#   model_99/conv2d_495/BiasAdd (1.40m/1.40m flops)
#   model_99/max_pooling2d_298/MaxPool (987.84k/987.84k flops)
#   model_99/batch_normalization_297/FusedBatchNormV3 (677.07k/677.07k flops)
#   model_99/conv2d_496/BiasAdd (470.96k/470.96k flops)
#   model_99/conv2d_497/BiasAdd (259.58k/259.58k flops)
#   model_99/conv2d_498/BiasAdd (221.18k/221.18k flops)
#   model_99/batch_normalization_298/FusedBatchNormV3 (220.36k/220.36k flops)
#   model_99/max_pooling2d_299/MaxPool (196.20k/196.20k flops)
#   model_99/conv2d_499/BiasAdd (105.51k/105.51k flops)
#   model_99/dense_299/MatMul (47.04k/47.04k flops)
#   model_99/batch_normalization_299/FusedBatchNormV3 (44.91k/44.91k flops)
#   model_99/dense_298/BiasAdd (2.35k/2.35k flops)
#   model_99/dense_297/BiasAdd (2.10k/2.10k flops)
#   model_99/dense_299/Softmax (50/50 flops)
#   model_99/dense_299/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
