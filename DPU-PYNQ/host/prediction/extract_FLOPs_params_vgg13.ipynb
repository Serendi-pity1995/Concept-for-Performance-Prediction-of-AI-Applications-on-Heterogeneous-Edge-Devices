# %%
import os
import csv
import numpy as np
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, ZeroPadding2D, Dropout, Activation
from itertools import product
from keras_flops import get_flops


model_num = 1
input_shape_range =range(32,160,32)

with open("para_count_vgg13.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "FLOPs", "Total_params", "Memory"],])
          
for shape_x in input_shape_range:
    
    shape_y = shape_x

    inputs = Input(shape=(shape_x, shape_y, 1))

    conv1 = Conv2D(64, (3,3), padding='same', activation='relu')(inputs)
    conv2 = Conv2D(64, (3,3), padding='same', activation='relu')(conv1)
    pool1 = MaxPooling2D(pool_size=2)(conv2)
    
    conv3 = Conv2D(128, (3,3), padding='same', activation='relu')(pool1)
    conv4 = Conv2D(128, (3,3), padding='same', activation='relu')(conv3)
    pool2 = MaxPooling2D(pool_size=2)(conv4)
    
    conv5 = Conv2D(256, (3,3), padding='same', activation='relu')(pool2)
    conv6 = Conv2D(256, (3,3), padding='same', activation='relu')(conv5)
    pool3 = MaxPooling2D(pool_size=2)(conv6)

    conv7 = Conv2D(512, (3,3), padding='same', activation='relu')(pool3)
    conv8 = Conv2D(512, (3,3), padding='same', activation='relu')(conv7)
    pool4 = MaxPooling2D(pool_size=2)(conv8)

    conv9 = Conv2D(512, (3,3), padding='same', activation='relu')(pool4)
    conv10 = Conv2D(512, (3,3), padding='same', activation='relu')(conv9)
    pool5 = MaxPooling2D(pool_size=2)(conv10)
    
    flat = Flatten()(pool5)
    fc1 = Dense(3072, activation='relu')(flat)
    drop1 = Dropout(0.5)(fc1)
    fc2 = Dense(3072, activation='relu')(drop1)
    drop2 = Dropout(0.5)(fc2)

    outputs = Dense(10, activation='softmax')(drop2)


    model = Model(inputs=inputs, outputs=outputs)
    # how to compute the memory allocated by the activations of a model
    batch = 1
    shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
    else 1 for s in l.output_shape])) 
    for l in model.layers]))
    memory = (shapes_count * 4 * batch)/10**6
    print(memory)
    
    Total_params = round(model.count_params()/10 ** 6,2)
    FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
    with open("para_count_vgg13.csv","a+") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerows([[model_num, shape_x, shape_y, FLOPs, Total_params, memory],])

        model_num = model_num + 1
# Out:
# 2022-04-12 08:50:40.728647: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-04-12 08:50:40.728664: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_4836/3167290778.py in <module>
#       6 from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, ZeroPadding2D, Dropout, Activation
#       7 from itertools import product
# ----> 8 from keras_flops import get_flops
#       9
#      10
#
# ModuleNotFoundError: No module named 'keras_flops'

# %%
import os
import csv
import numpy as np
import tensorflow as tf
import keras
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, ZeroPadding2D, Dropout, Activation
from itertools import product
from keras_flops import get_flops


model_num = 1
input_shape_range =range(32,512,32)

with open("para_count_vgg13.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "step", "number of layers", "FLOPs", "Total_params", "Memory"],])
path = "../vgg13_h5" #文件夹目录
files= os.listdir(path) #得到文件夹下的所有文件名称

for shape_x in input_shape_range:
    shape_y = shape_x
    for step in range(1,11):
        file = "vgg13_{input_x}_{input_y}_{step}.h5".format(input_x=shape_x,input_y=shape_y,step=step)
        if file in files: #遍历文件夹
            model_name = str(file)
            if not os.path.isdir(file): #判断是否是文件夹，不是文件夹才打开
                model = keras.models.load_model("../vgg13_h5/{}".format(model_name))

                # how to compute the memory allocated by the activations of a model
                batch = 1
                shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
                else 1 for s in l.output_shape])) 
                for l in model.layers]))
                memory = (shapes_count * 4 * batch)/10**6
                print(memory)
                layers_length = len(model.layers)
                Total_params = round(model.count_params()/10 ** 6,2)
                FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
                with open("para_count_vgg13.csv","a+") as csvfile:
                    writer = csv.writer(csvfile)
                    writer.writerows([[model_num, shape_x, shape_y, step, layers_length, FLOPs, Total_params, memory],])

                    model_num = model_num + 1
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-04-13 05:46:29.441115: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-04-13 05:46:29.441134: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-13 05:46:29.441150: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2022-04-13 05:46:29.441293: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 0.965692
# 2022-04-13 05:46:30.001594: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:46:30.001728: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:46:30.026464: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.02ms.
#   function_optimizer: function_optimizer did nothing. time = 0.003ms.
# WARNING:tensorflow:From /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py:5063: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/260.07m flops)
#   model/conv2d_1/Conv2D (66.06m/66.06m flops)
#   model/conv2d_3/Conv2D (32.74m/32.74m flops)
#   model/conv2d_7/Conv2D (32.09m/32.09m flops)
#   model/conv2d_5/Conv2D (28.82m/28.82m flops)
#   model/conv2d_2/Conv2D (21.82m/21.82m flops)
#   model/conv2d_6/Conv2D (19.03m/19.03m flops)
#   model/conv2d_9/Conv2D (18.73m/18.73m flops)
#   model/conv2d_8/Conv2D (14.61m/14.61m flops)
#   model/conv2d_4/Conv2D (11.72m/11.72m flops)
#   model/dense_1/MatMul (10.10m/10.10m flops)
#   model/dense/MatMul (2.95m/2.95m flops)
#   model/conv2d/Conv2D (1.03m/1.03m flops)
#   model/conv2d_1/BiasAdd (65.54k/65.54k flops)
#   model/max_pooling2d/MaxPool (65.54k/65.54k flops)
#   model/conv2d/BiasAdd (57.34k/57.34k flops)
#   model/dense_2/MatMul (34.88k/34.88k flops)
#   model/conv2d_3/BiasAdd (24.58k/24.58k flops)
#   model/max_pooling2d_1/MaxPool (24.58k/24.58k flops)
#   model/conv2d_2/BiasAdd (18.94k/18.94k flops)
#   model/conv2d_5/BiasAdd (15.10k/15.10k flops)
#   model/max_pooling2d_2/MaxPool (15.10k/15.10k flops)
#   model/conv2d_4/BiasAdd (6.78k/6.78k flops)
#   model/conv2d_7/BiasAdd (6.37k/6.37k flops)
#   model/max_pooling2d_3/MaxPool (6.37k/6.37k flops)
#   model/conv2d_6/BiasAdd (4.48k/4.48k flops)
#   model/dense/BiasAdd (2.90k/2.90k flops)
#   model/max_pooling2d_4/MaxPool (2.04k/2.04k flops)
#   model/conv2d_9/BiasAdd (2.04k/2.04k flops)
#   model/conv2d_8/BiasAdd (2.04k/2.04k flops)
#   model/dense_1/BiasAdd (1.74k/1.74k flops)
#   model/dense_2/Softmax (50/50 flops)
#   model/dense_2/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.917116
# 2022-04-13 05:46:30.894558: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:46:30.894667: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:46:30.896002: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/283.34m flops)
#   model_1/conv2d_17/Conv2D (54.59m/54.59m flops)
#   model_1/conv2d_11/Conv2D (44.83m/44.83m flops)
#   model_1/conv2d_13/Conv2D (35.67m/35.67m flops)
#   model_1/conv2d_15/Conv2D (33.68m/33.68m flops)
#   model_1/conv2d_16/Conv2D (28.30m/28.30m flops)
#   model_1/conv2d_12/Conv2D (25.36m/25.36m flops)
#   model_1/conv2d_19/Conv2D (17.86m/17.86m flops)
#   model_1/conv2d_18/Conv2D (17.29m/17.29m flops)
#   model_1/conv2d_14/Conv2D (12.03m/12.03m flops)
#   model_1/dense_4/MatMul (10.05m/10.05m flops)
#   model_1/dense_3/MatMul (2.65m/2.65m flops)
#   model_1/conv2d_10/Conv2D (700.42k/700.42k flops)
#   model_1/conv2d_11/BiasAdd (65.54k/65.54k flops)
#   model_1/max_pooling2d_5/MaxPool (65.54k/65.54k flops)
#   model_1/conv2d_10/BiasAdd (38.91k/38.91k flops)
#   model_1/dense_5/MatMul (38.08k/38.08k flops)
#   model_1/conv2d_13/BiasAdd (23.04k/23.04k flops)
#   model_1/max_pooling2d_6/MaxPool (23.04k/23.04k flops)
#   model_1/conv2d_12/BiasAdd (22.02k/22.02k flops)
#   model_1/conv2d_15/BiasAdd (16.13k/16.13k flops)
#   model_1/max_pooling2d_7/MaxPool (16.13k/16.13k flops)
#   model_1/conv2d_17/BiasAdd (7.78k/7.78k flops)
#   model_1/max_pooling2d_8/MaxPool (7.78k/7.78k flops)
#   model_1/conv2d_14/BiasAdd (7.42k/7.42k flops)
#   model_1/conv2d_16/BiasAdd (6.24k/6.24k flops)
#   model_1/dense_3/BiasAdd (2.64k/2.64k flops)
#   model_1/max_pooling2d_9/MaxPool (2.01k/2.01k flops)
#   model_1/conv2d_19/BiasAdd (2.01k/2.01k flops)
#   model_1/conv2d_18/BiasAdd (1.98k/1.98k flops)
#   model_1/dense_4/BiasAdd (1.90k/1.90k flops)
#   model_1/dense_5/Softmax (50/50 flops)
#   model_1/dense_5/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.96862
# 2022-04-13 05:46:31.746365: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:46:31.746439: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:46:31.747801: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/278.48m flops)
#   model_2/conv2d_21/Conv2D (61.34m/61.34m flops)
#   model_2/conv2d_25/Conv2D (51.29m/51.29m flops)
#   model_2/conv2d_23/Conv2D (35.09m/35.09m flops)
#   model_2/conv2d_27/Conv2D (30.85m/30.85m flops)
#   model_2/conv2d_24/Conv2D (27.10m/27.10m flops)
#   model_2/conv2d_22/Conv2D (20.05m/20.05m flops)
#   model_2/conv2d_29/Conv2D (16.06m/16.06m flops)
#   model_2/conv2d_26/Conv2D (15.87m/15.87m flops)
#   model_2/conv2d_28/Conv2D (13.23m/13.23m flops)
#   model_2/dense_7/MatMul (4.29m/4.29m flops)
#   model_2/dense_6/MatMul (2.00m/2.00m flops)
#   model_2/conv2d_20/Conv2D (958.46k/958.46k flops)
#   model_2/conv2d_21/BiasAdd (65.54k/65.54k flops)
#   model_2/max_pooling2d_10/MaxPool (65.54k/65.54k flops)
#   model_2/conv2d_20/BiasAdd (53.25k/53.25k flops)
#   model_2/conv2d_23/BiasAdd (28.67k/28.67k flops)
#   model_2/max_pooling2d_11/MaxPool (28.67k/28.67k flops)
#   model_2/dense_8/MatMul (21.44k/21.44k flops)
#   model_2/conv2d_22/BiasAdd (17.41k/17.41k flops)
#   model_2/conv2d_25/BiasAdd (13.57k/13.57k flops)
#   model_2/max_pooling2d_12/MaxPool (13.57k/13.57k flops)
#   model_2/conv2d_24/BiasAdd (13.44k/13.44k flops)
#   model_2/conv2d_27/BiasAdd (6.59k/6.59k flops)
#   model_2/max_pooling2d_13/MaxPool (6.59k/6.59k flops)
#   model_2/conv2d_26/BiasAdd (4.16k/4.16k flops)
#   model_2/max_pooling2d_14/MaxPool (2.00k/2.00k flops)
#   model_2/dense_6/BiasAdd (2.00k/2.00k flops)
#   model_2/conv2d_29/BiasAdd (2.00k/2.00k flops)
#   model_2/conv2d_28/BiasAdd (1.78k/1.78k flops)
#   model_2/dense_7/BiasAdd (1.07k/1.07k flops)
#   model_2/dense_8/Softmax (50/50 flops)
#   model_2/dense_8/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.080348
# 2022-04-13 05:46:32.397343: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:46:32.397452: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:46:32.398891: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/358.01m flops)
#   model_3/conv2d_35/Conv2D (73.16m/73.16m flops)
#   model_3/conv2d_31/Conv2D (73.14m/73.14m flops)
#   model_3/conv2d_33/Conv2D (52.72m/52.72m flops)
#   model_3/conv2d_34/Conv2D (31.93m/31.93m flops)
#   model_3/conv2d_37/Conv2D (30.69m/30.69m flops)
#   model_3/conv2d_32/Conv2D (30.67m/30.67m flops)
#   model_3/conv2d_36/Conv2D (22.35m/22.35m flops)
#   model_3/conv2d_39/Conv2D (15.96m/15.96m flops)
#   model_3/dense_10/MatMul (12.17m/12.17m flops)
#   model_3/conv2d_38/Conv2D (10.91m/10.91m flops)
#   model_3/dense_9/MatMul (2.77m/2.77m flops)
#   model_3/conv2d_30/Conv2D (1.14m/1.14m flops)
#   model_3/max_pooling2d_15/MaxPool (65.54k/65.54k flops)
#   model_3/conv2d_31/BiasAdd (65.54k/65.54k flops)
#   model_3/conv2d_30/BiasAdd (63.49k/63.49k flops)
#   model_3/dense_11/MatMul (44.48k/44.48k flops)
#   model_3/conv2d_33/BiasAdd (28.16k/28.16k flops)
#   model_3/max_pooling2d_16/MaxPool (28.16k/28.16k flops)
#   model_3/conv2d_32/BiasAdd (26.62k/26.62k flops)
#   model_3/conv2d_35/BiasAdd (16.13k/16.13k flops)
#   model_3/conv2d_34/BiasAdd (16.13k/16.13k flops)
#   model_3/max_pooling2d_17/MaxPool (16.13k/16.13k flops)
#   model_3/conv2d_37/BiasAdd (5.54k/5.54k flops)
#   model_3/max_pooling2d_18/MaxPool (5.54k/5.54k flops)
#   model_3/conv2d_36/BiasAdd (4.93k/4.93k flops)
#   model_3/dense_9/BiasAdd (2.74k/2.74k flops)
#   model_3/dense_10/BiasAdd (2.22k/2.22k flops)
#   model_3/max_pooling2d_19/MaxPool (2.02k/2.02k flops)
#   model_3/conv2d_39/BiasAdd (2.02k/2.02k flops)
#   model_3/conv2d_38/BiasAdd (1.75k/1.75k flops)
#   model_3/dense_11/Softmax (50/50 flops)
#   model_3/dense_11/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.027356
# 2022-04-13 05:46:33.267565: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:46:33.267639: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:46:33.269014: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/313.11m flops)
#   model_4/conv2d_41/Conv2D (66.06m/66.06m flops)
#   model_4/conv2d_43/Conv2D (60.72m/60.72m flops)
#   model_4/conv2d_45/Conv2D (40.55m/40.55m flops)
#   model_4/conv2d_47/Conv2D (34.27m/34.27m flops)
#   model_4/conv2d_42/Conv2D (31.85m/31.85m flops)
#   model_4/conv2d_44/Conv2D (24.74m/24.74m flops)
#   model_4/conv2d_46/Conv2D (17.05m/17.05m flops)
#   model_4/conv2d_49/Conv2D (16.92m/16.92m flops)
#   model_4/conv2d_48/Conv2D (13.55m/13.55m flops)
#   model_4/dense_13/MatMul (4.40m/4.40m flops)
#   model_4/dense_12/MatMul (1.62m/1.62m flops)
#   model_4/conv2d_40/Conv2D (1.03m/1.03m flops)
#   model_4/conv2d_41/BiasAdd (65.54k/65.54k flops)
#   model_4/max_pooling2d_20/MaxPool (65.54k/65.54k flops)
#   model_4/conv2d_40/BiasAdd (57.34k/57.34k flops)
#   model_4/conv2d_43/BiasAdd (31.23k/31.23k flops)
#   model_4/max_pooling2d_21/MaxPool (31.23k/31.23k flops)
#   model_4/conv2d_42/BiasAdd (27.65k/27.65k flops)
#   model_4/dense_14/MatMul (27.20k/27.20k flops)
#   model_4/conv2d_45/BiasAdd (12.80k/12.80k flops)
#   model_4/max_pooling2d_22/MaxPool (12.80k/12.80k flops)
#   model_4/conv2d_44/BiasAdd (11.26k/11.26k flops)
#   model_4/conv2d_47/BiasAdd (6.43k/6.43k flops)
#   model_4/max_pooling2d_23/MaxPool (6.43k/6.43k flops)
#   model_4/conv2d_46/BiasAdd (4.74k/4.74k flops)
#   model_4/max_pooling2d_24/MaxPool (2.01k/2.01k flops)
#   model_4/conv2d_49/BiasAdd (2.01k/2.01k flops)
#   model_4/conv2d_48/BiasAdd (1.87k/1.87k flops)
#   model_4/dense_12/BiasAdd (1.62k/1.62k flops)
#   model_4/dense_13/BiasAdd (1.36k/1.36k flops)
#   model_4/dense_14/Softmax (50/50 flops)
#   model_4/dense_14/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.017212
# 2022-04-13 05:46:33.877139: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:46:33.877209: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:46:33.878626: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/316.81m flops)
#   model_5/conv2d_51/Conv2D (70.78m/70.78m flops)
#   model_5/conv2d_57/Conv2D (56.18m/56.18m flops)
#   model_5/conv2d_53/Conv2D (45.16m/45.16m flops)
#   model_5/conv2d_55/Conv2D (30.99m/30.99m flops)
#   model_5/conv2d_52/Conv2D (28.90m/28.90m flops)
#   model_5/conv2d_56/Conv2D (25.21m/25.21m flops)
#   model_5/conv2d_59/Conv2D (18.65m/18.65m flops)
#   model_5/conv2d_58/Conv2D (18.58m/18.58m flops)
#   model_5/conv2d_54/Conv2D (13.59m/13.59m flops)
#   model_5/dense_16/MatMul (5.53m/5.53m flops)
#   model_5/dense_15/MatMul (1.75m/1.75m flops)
#   model_5/conv2d_50/Conv2D (1.11m/1.11m flops)
#   model_5/conv2d_51/BiasAdd (65.54k/65.54k flops)
#   model_5/max_pooling2d_25/MaxPool (65.54k/65.54k flops)
#   model_5/conv2d_50/BiasAdd (61.44k/61.44k flops)
#   model_5/dense_17/MatMul (32.32k/32.32k flops)
#   model_5/conv2d_53/BiasAdd (25.60k/25.60k flops)
#   model_5/max_pooling2d_26/MaxPool (25.60k/25.60k flops)
#   model_5/conv2d_52/BiasAdd (25.09k/25.09k flops)
#   model_5/conv2d_55/BiasAdd (14.59k/14.59k flops)
#   model_5/max_pooling2d_27/MaxPool (14.59k/14.59k flops)
#   model_5/conv2d_57/BiasAdd (8.13k/8.13k flops)
#   model_5/max_pooling2d_28/MaxPool (8.13k/8.13k flops)
#   model_5/conv2d_54/BiasAdd (7.55k/7.55k flops)
#   model_5/conv2d_56/BiasAdd (6.14k/6.14k flops)
#   model_5/max_pooling2d_29/MaxPool (2.04k/2.04k flops)
#   model_5/conv2d_59/BiasAdd (2.04k/2.04k flops)
#   model_5/conv2d_58/BiasAdd (2.03k/2.03k flops)
#   model_5/dense_15/BiasAdd (1.71k/1.71k flops)
#   model_5/dense_16/BiasAdd (1.62k/1.62k flops)
#   model_5/dense_17/Softmax (50/50 flops)
#   model_5/dense_17/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.010316
# 2022-04-13 05:46:34.637009: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:46:34.637081: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:46:34.638483: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/305.49m flops)
#   model_6/conv2d_61/Conv2D (66.06m/66.06m flops)
#   model_6/conv2d_67/Conv2D (49.44m/49.44m flops)
#   model_6/conv2d_63/Conv2D (42.41m/42.41m flops)
#   model_6/conv2d_65/Conv2D (32.72m/32.72m flops)
#   model_6/conv2d_62/Conv2D (23.00m/23.00m flops)
#   model_6/conv2d_66/Conv2D (19.70m/19.70m flops)
#   model_6/conv2d_64/Conv2D (19.30m/19.30m flops)
#   model_6/conv2d_69/Conv2D (18.36m/18.36m flops)
#   model_6/conv2d_68/Conv2D (18.14m/18.14m flops)
#   model_6/dense_19/MatMul (12.05m/12.05m flops)
#   model_6/dense_18/MatMul (2.88m/2.88m flops)
#   model_6/conv2d_60/Conv2D (1.03m/1.03m flops)
#   model_6/max_pooling2d_30/MaxPool (65.54k/65.54k flops)
#   model_6/conv2d_61/BiasAdd (65.54k/65.54k flops)
#   model_6/conv2d_60/BiasAdd (57.34k/57.34k flops)
#   model_6/dense_20/MatMul (42.56k/42.56k flops)
#   model_6/conv2d_63/BiasAdd (30.21k/30.21k flops)
#   model_6/max_pooling2d_31/MaxPool (30.21k/30.21k flops)
#   model_6/conv2d_62/BiasAdd (19.97k/19.97k flops)
#   model_6/conv2d_65/BiasAdd (12.80k/12.80k flops)
#   model_6/max_pooling2d_32/MaxPool (12.80k/12.80k flops)
#   model_6/conv2d_64/BiasAdd (9.09k/9.09k flops)
#   model_6/conv2d_67/BiasAdd (8.03k/8.03k flops)
#   model_6/max_pooling2d_33/MaxPool (8.03k/8.03k flops)
#   model_6/conv2d_66/BiasAdd (5.47k/5.47k flops)
#   model_6/dense_18/BiasAdd (2.83k/2.83k flops)
#   model_6/dense_19/BiasAdd (2.13k/2.13k flops)
#   model_6/max_pooling2d_34/MaxPool (2.03k/2.03k flops)
#   model_6/conv2d_69/BiasAdd (2.03k/2.03k flops)
#   model_6/conv2d_68/BiasAdd (2.01k/2.01k flops)
#   model_6/dense_20/Softmax (50/50 flops)
#   model_6/dense_20/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.875148
# 2022-04-13 05:46:35.573186: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:46:35.573255: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:46:35.574695: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/260.98m flops)
#   model_7/conv2d_77/Conv2D (55.62m/55.62m flops)
#   model_7/conv2d_71/Conv2D (44.83m/44.83m flops)
#   model_7/conv2d_75/Conv2D (29.23m/29.23m flops)
#   model_7/conv2d_73/Conv2D (28.02m/28.02m flops)
#   model_7/conv2d_76/Conv2D (24.20m/24.20m flops)
#   model_7/conv2d_72/Conv2D (22.41m/22.41m flops)
#   model_7/conv2d_79/Conv2D (18.36m/18.36m flops)
#   model_7/conv2d_78/Conv2D (17.28m/17.28m flops)
#   model_7/conv2d_74/Conv2D (11.24m/11.24m flops)
#   model_7/dense_22/MatMul (6.57m/6.57m flops)
#   model_7/dense_21/MatMul (2.19m/2.19m flops)
#   model_7/conv2d_70/Conv2D (700.42k/700.42k flops)
#   model_7/conv2d_71/BiasAdd (65.54k/65.54k flops)
#   model_7/max_pooling2d_35/MaxPool (65.54k/65.54k flops)
#   model_7/conv2d_70/BiasAdd (38.91k/38.91k flops)
#   model_7/dense_23/MatMul (30.40k/30.40k flops)
#   model_7/conv2d_73/BiasAdd (20.48k/20.48k flops)
#   model_7/max_pooling2d_36/MaxPool (20.48k/20.48k flops)
#   model_7/conv2d_72/BiasAdd (19.46k/19.46k flops)
#   model_7/conv2d_75/BiasAdd (13.31k/13.31k flops)
#   model_7/max_pooling2d_37/MaxPool (13.31k/13.31k flops)
#   model_7/conv2d_74/BiasAdd (7.81k/7.81k flops)
#   model_7/conv2d_77/BiasAdd (7.65k/7.65k flops)
#   model_7/max_pooling2d_38/MaxPool (7.65k/7.65k flops)
#   model_7/conv2d_76/BiasAdd (6.46k/6.46k flops)
#   model_7/dense_21/BiasAdd (2.16k/2.16k flops)
#   model_7/max_pooling2d_39/MaxPool (2.03k/2.03k flops)
#   model_7/conv2d_79/BiasAdd (2.03k/2.03k flops)
#   model_7/conv2d_78/BiasAdd (2.01k/2.01k flops)
#   model_7/dense_22/BiasAdd (1.52k/1.52k flops)
#   model_7/dense_23/Softmax (50/50 flops)
#   model_7/dense_23/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.066748
# 2022-04-13 05:46:36.277490: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:46:36.277563: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:46:36.278982: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/334.01m flops)
#   model_8/conv2d_83/Conv2D (69.67m/69.67m flops)
#   model_8/conv2d_81/Conv2D (68.42m/68.42m flops)
#   model_8/conv2d_85/Conv2D (53.25m/53.25m flops)
#   model_8/conv2d_82/Conv2D (35.39m/35.39m flops)
#   model_8/conv2d_87/Conv2D (27.15m/27.15m flops)
#   model_8/conv2d_84/Conv2D (26.42m/26.42m flops)
#   model_8/conv2d_86/Conv2D (20.04m/20.04m flops)
#   model_8/conv2d_89/Conv2D (14.68m/14.68m flops)
#   model_8/conv2d_88/Conv2D (10.65m/10.65m flops)
#   model_8/dense_25/MatMul (5.33m/5.33m flops)
#   model_8/dense_24/MatMul (1.56m/1.56m flops)
#   model_8/conv2d_80/Conv2D (1.07m/1.07m flops)
#   model_8/conv2d_81/BiasAdd (65.54k/65.54k flops)
#   model_8/max_pooling2d_40/MaxPool (65.54k/65.54k flops)
#   model_8/conv2d_80/BiasAdd (59.39k/59.39k flops)
#   model_8/dense_26/MatMul (32.32k/32.32k flops)
#   model_8/conv2d_83/BiasAdd (32.26k/32.26k flops)
#   model_8/max_pooling2d_41/MaxPool (32.26k/32.26k flops)
#   model_8/conv2d_82/BiasAdd (30.72k/30.72k flops)
#   model_8/conv2d_85/BiasAdd (16.26k/16.26k flops)
#   model_8/max_pooling2d_42/MaxPool (16.26k/16.26k flops)
#   model_8/conv2d_84/BiasAdd (11.65k/11.65k flops)
#   model_8/conv2d_87/BiasAdd (5.50k/5.50k flops)
#   model_8/max_pooling2d_43/MaxPool (5.50k/5.50k flops)
#   model_8/conv2d_86/BiasAdd (4.38k/4.38k flops)
#   model_8/max_pooling2d_44/MaxPool (1.90k/1.90k flops)
#   model_8/conv2d_89/BiasAdd (1.90k/1.90k flops)
#   model_8/conv2d_88/BiasAdd (1.72k/1.72k flops)
#   model_8/dense_24/BiasAdd (1.65k/1.65k flops)
#   model_8/dense_25/BiasAdd (1.62k/1.62k flops)
#   model_8/dense_26/Softmax (50/50 flops)
#   model_8/dense_26/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.048188
# 2022-04-13 05:46:36.910723: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:46:36.910797: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:46:36.912210: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/368.12m flops)
#   model_9/conv2d_95/Conv2D (68.51m/68.51m flops)
#   model_9/conv2d_91/Conv2D (66.06m/66.06m flops)
#   model_9/conv2d_97/Conv2D (53.50m/53.50m flops)
#   model_9/conv2d_93/Conv2D (47.04m/47.04m flops)
#   model_9/conv2d_94/Conv2D (31.54m/31.54m flops)
#   model_9/conv2d_96/Conv2D (31.06m/31.06m flops)
#   model_9/conv2d_92/Conv2D (25.95m/25.95m flops)
#   model_9/conv2d_99/Conv2D (18.73m/18.73m flops)
#   model_9/conv2d_98/Conv2D (15.94m/15.94m flops)
#   model_9/dense_28/MatMul (6.54m/6.54m flops)
#   model_9/dense_27/MatMul (1.84m/1.84m flops)
#   model_9/conv2d_90/Conv2D (1.03m/1.03m flops)
#   model_9/conv2d_91/BiasAdd (65.54k/65.54k flops)
#   model_9/max_pooling2d_45/MaxPool (65.54k/65.54k flops)
#   model_9/conv2d_90/BiasAdd (57.34k/57.34k flops)
#   model_9/dense_29/MatMul (36.16k/36.16k flops)
#   model_9/conv2d_93/BiasAdd (29.70k/29.70k flops)
#   model_9/max_pooling2d_46/MaxPool (29.70k/29.70k flops)
#   model_9/conv2d_92/BiasAdd (22.53k/22.53k flops)
#   model_9/conv2d_95/BiasAdd (16.13k/16.13k flops)
#   model_9/max_pooling2d_47/MaxPool (16.13k/16.13k flops)
#   model_9/conv2d_94/BiasAdd (15.10k/15.10k flops)
#   model_9/conv2d_97/BiasAdd (6.94k/6.94k flops)
#   model_9/max_pooling2d_48/MaxPool (6.94k/6.94k flops)
#   model_9/conv2d_96/BiasAdd (6.85k/6.85k flops)
#   model_9/max_pooling2d_49/MaxPool (2.04k/2.04k flops)
#   model_9/conv2d_99/BiasAdd (2.04k/2.04k flops)
#   model_9/conv2d_98/BiasAdd (2.04k/2.04k flops)
#   model_9/dense_28/BiasAdd (1.81k/1.81k flops)
#   model_9/dense_27/BiasAdd (1.81k/1.81k flops)
#   model_9/dense_29/Softmax (50/50 flops)
#   model_9/dense_29/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 3.443948
# 2022-04-13 05:46:37.697962: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:46:37.698046: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:46:37.699418: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/873.22m flops)
#   model_10/conv2d_101/Conv2D (179.31m/179.31m flops)
#   model_10/conv2d_103/Conv2D (155.71m/155.71m flops)
#   model_10/conv2d_105/Conv2D (149.23m/149.23m flops)
#   model_10/conv2d_102/Conv2D (103.81m/103.81m flops)
#   model_10/conv2d_104/Conv2D (77.86m/77.86m flops)
#   model_10/conv2d_107/Conv2D (69.89m/69.89m flops)
#   model_10/conv2d_109/Conv2D (50.60m/50.60m flops)
#   model_10/conv2d_106/Conv2D (40.70m/40.70m flops)
#   model_10/conv2d_108/Conv2D (31.85m/31.85m flops)
#   model_10/dense_30/MatMul (6.62m/6.62m flops)
#   model_10/dense_31/MatMul (3.64m/3.64m flops)
#   model_10/conv2d_100/Conv2D (2.80m/2.80m flops)
#   model_10/conv2d_101/BiasAdd (262.14k/262.14k flops)
#   model_10/max_pooling2d_50/MaxPool (262.14k/262.14k flops)
#   model_10/conv2d_100/BiasAdd (155.65k/155.65k flops)
#   model_10/conv2d_103/BiasAdd (98.30k/98.30k flops)
#   model_10/max_pooling2d_51/MaxPool (98.30k/98.30k flops)
#   model_10/conv2d_102/BiasAdd (90.11k/90.11k flops)
#   model_10/conv2d_105/BiasAdd (47.10k/47.10k flops)
#   model_10/max_pooling2d_52/MaxPool (47.10k/47.10k flops)
#   model_10/conv2d_104/BiasAdd (45.06k/45.06k flops)
#   model_10/dense_32/MatMul (22.08k/22.08k flops)
#   model_10/conv2d_107/BiasAdd (20.22k/20.22k flops)
#   model_10/max_pooling2d_53/MaxPool (20.22k/20.22k flops)
#   model_10/conv2d_106/BiasAdd (12.29k/12.29k flops)
#   model_10/max_pooling2d_54/MaxPool (8.03k/8.03k flops)
#   model_10/conv2d_109/BiasAdd (8.03k/8.03k flops)
#   model_10/conv2d_108/BiasAdd (5.60k/5.60k flops)
#   model_10/dense_30/BiasAdd (1.65k/1.65k flops)
#   model_10/dense_31/BiasAdd (1.10k/1.10k flops)
#   model_10/dense_32/Softmax (50/50 flops)
#   model_10/dense_32/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 3.356588
# 2022-04-13 05:46:38.431738: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:46:38.431860: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:46:38.433402: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/903.68m flops)
#   model_11/conv2d_115/Conv2D (179.16m/179.16m flops)
#   model_11/conv2d_111/Conv2D (150.99m/150.99m flops)
#   model_11/conv2d_113/Conv2D (116.56m/116.56m flops)
#   model_11/conv2d_117/Conv2D (114.69m/114.69m flops)
#   model_11/conv2d_114/Conv2D (84.60m/84.60m flops)
#   model_11/conv2d_112/Conv2D (73.14m/73.14m flops)
#   model_11/conv2d_116/Conv2D (65.19m/65.19m flops)
#   model_11/conv2d_119/Conv2D (57.28m/57.28m flops)
#   model_11/conv2d_118/Conv2D (48.15m/48.15m flops)
#   model_11/dense_33/MatMul (5.73m/5.73m flops)
#   model_11/dense_34/MatMul (4.61m/4.61m flops)
#   model_11/conv2d_110/Conv2D (2.36m/2.36m flops)
#   model_11/conv2d_111/BiasAdd (262.14k/262.14k flops)
#   model_11/max_pooling2d_55/MaxPool (262.14k/262.14k flops)
#   model_11/conv2d_110/BiasAdd (131.07k/131.07k flops)
#   model_11/conv2d_113/BiasAdd (104.45k/104.45k flops)
#   model_11/max_pooling2d_56/MaxPool (104.45k/104.45k flops)
#   model_11/conv2d_112/BiasAdd (63.49k/63.49k flops)
#   model_11/conv2d_115/BiasAdd (55.30k/55.30k flops)
#   model_11/max_pooling2d_57/MaxPool (55.30k/55.30k flops)
#   model_11/conv2d_114/BiasAdd (46.08k/46.08k flops)
#   model_11/dense_35/MatMul (29.12k/29.12k flops)
#   model_11/conv2d_117/BiasAdd (24.32k/24.32k flops)
#   model_11/max_pooling2d_58/MaxPool (24.32k/24.32k flops)
#   model_11/conv2d_116/BiasAdd (16.77k/16.77k flops)
#   model_11/max_pooling2d_59/MaxPool (7.23k/7.23k flops)
#   model_11/conv2d_119/BiasAdd (7.23k/7.23k flops)
#   model_11/conv2d_118/BiasAdd (7.04k/7.04k flops)
#   model_11/dense_33/BiasAdd (1.58k/1.58k flops)
#   model_11/dense_34/BiasAdd (1.46k/1.46k flops)
#   model_11/dense_35/Softmax (50/50 flops)
#   model_11/dense_35/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 4.05534
# 2022-04-13 05:46:38.887135: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:46:38.887206: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:46:38.888711: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.25b flops)
#   model_12/conv2d_121/Conv2D (264.24m/264.24m flops)
#   model_12/conv2d_123/Conv2D (260.55m/260.55m flops)
#   model_12/conv2d_127/Conv2D (153.28m/153.28m flops)
#   model_12/conv2d_122/Conv2D (134.48m/134.48m flops)
#   model_12/conv2d_125/Conv2D (128.88m/128.88m flops)
#   model_12/conv2d_124/Conv2D (86.85m/86.85m flops)
#   model_12/conv2d_126/Conv2D (65.29m/65.29m flops)
#   model_12/conv2d_129/Conv2D (65.25m/65.25m flops)
#   model_12/conv2d_128/Conv2D (58.72m/58.72m flops)
#   model_12/dense_37/MatMul (12.81m/12.81m flops)
#   model_12/dense_36/MatMul (10.75m/10.75m flops)
#   model_12/conv2d_120/Conv2D (4.13m/4.13m flops)
#   model_12/conv2d_121/BiasAdd (262.14k/262.14k flops)
#   model_12/max_pooling2d_60/MaxPool (262.14k/262.14k flops)
#   model_12/conv2d_120/BiasAdd (229.38k/229.38k flops)
#   model_12/conv2d_123/BiasAdd (126.98k/126.98k flops)
#   model_12/max_pooling2d_61/MaxPool (126.98k/126.98k flops)
#   model_12/conv2d_122/BiasAdd (116.74k/116.74k flops)
#   model_12/conv2d_125/BiasAdd (47.10k/47.10k flops)
#   model_12/max_pooling2d_62/MaxPool (47.10k/47.10k flops)
#   model_12/dense_38/MatMul (45.76k/45.76k flops)
#   model_12/conv2d_124/BiasAdd (38.91k/38.91k flops)
#   model_12/conv2d_127/BiasAdd (27.65k/27.65k flops)
#   model_12/max_pooling2d_63/MaxPool (27.65k/27.65k flops)
#   model_12/conv2d_126/BiasAdd (19.71k/19.71k flops)
#   model_12/max_pooling2d_64/MaxPool (7.68k/7.68k flops)
#   model_12/conv2d_129/BiasAdd (7.68k/7.68k flops)
#   model_12/conv2d_128/BiasAdd (7.55k/7.55k flops)
#   model_12/dense_36/BiasAdd (2.80k/2.80k flops)
#   model_12/dense_37/BiasAdd (2.29k/2.29k flops)
#   model_12/dense_38/Softmax (50/50 flops)
#   model_12/dense_38/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 3.681708
# 2022-04-13 05:46:39.832946: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:46:39.833023: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:46:39.834546: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.03b flops)
#   model_13/conv2d_131/Conv2D (207.62m/207.62m flops)
#   model_13/conv2d_133/Conv2D (195.08m/195.08m flops)
#   model_13/conv2d_135/Conv2D (151.73m/151.73m flops)
#   model_13/conv2d_132/Conv2D (115.61m/115.61m flops)
#   model_13/conv2d_137/Conv2D (101.74m/101.74m flops)
#   model_13/conv2d_134/Conv2D (83.61m/83.61m flops)
#   model_13/conv2d_136/Conv2D (60.06m/60.06m flops)
#   model_13/conv2d_139/Conv2D (56.61m/56.61m flops)
#   model_13/conv2d_138/Conv2D (40.16m/40.16m flops)
#   model_13/dense_39/MatMul (6.65m/6.65m flops)
#   model_13/dense_40/MatMul (5.51m/5.51m flops)
#   model_13/conv2d_130/Conv2D (3.24m/3.24m flops)
#   model_13/conv2d_131/BiasAdd (262.14k/262.14k flops)
#   model_13/max_pooling2d_65/MaxPool (262.14k/262.14k flops)
#   model_13/conv2d_130/BiasAdd (180.22k/180.22k flops)
#   model_13/conv2d_133/BiasAdd (110.59k/110.59k flops)
#   model_13/max_pooling2d_66/MaxPool (110.59k/110.59k flops)
#   model_13/conv2d_132/BiasAdd (100.35k/100.35k flops)
#   model_13/conv2d_135/BiasAdd (50.18k/50.18k flops)
# ...
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/13.38b flops)
#   model_55/conv2d_553/Conv2D (2.47b/2.47b flops)
#   model_55/conv2d_557/Conv2D (2.44b/2.44b flops)
#   model_55/conv2d_551/Conv2D (2.12b/2.12b flops)
#   model_55/conv2d_555/Conv2D (1.63b/1.63b flops)
#   model_55/conv2d_552/Conv2D (1.27b/1.27b flops)
#   model_55/conv2d_556/Conv2D (1.20b/1.20b flops)
#   model_55/conv2d_554/Conv2D (833.09m/833.09m flops)
#   model_55/conv2d_559/Conv2D (650.57m/650.57m flops)
#   model_55/conv2d_558/Conv2D (632.50m/632.50m flops)
#   model_55/dense_165/MatMul (78.38m/78.38m flops)
#   model_55/conv2d_550/Conv2D (33.18m/33.18m flops)
#   model_55/dense_166/MatMul (7.81m/7.81m flops)
#   model_55/max_pooling2d_275/MaxPool (2.36m/2.36m flops)
#   model_55/conv2d_551/BiasAdd (2.36m/2.36m flops)
#   model_55/conv2d_550/BiasAdd (1.84m/1.84m flops)
#   model_55/conv2d_553/BiasAdd (1.14m/1.14m flops)
#   model_55/max_pooling2d_276/MaxPool (1.14m/1.14m flops)
#   model_55/conv2d_552/BiasAdd (1.11m/1.11m flops)
#   model_55/conv2d_555/BiasAdd (557.57k/557.57k flops)
#   model_55/max_pooling2d_277/MaxPool (557.57k/557.57k flops)
#   model_55/conv2d_554/BiasAdd (373.25k/373.25k flops)
#   model_55/conv2d_557/BiasAdd (282.24k/282.24k flops)
#   model_55/max_pooling2d_278/MaxPool (282.24k/282.24k flops)
#   model_55/conv2d_556/BiasAdd (276.48k/276.48k flops)
#   model_55/max_pooling2d_279/MaxPool (72.58k/72.58k flops)
#   model_55/conv2d_559/BiasAdd (72.58k/72.58k flops)
#   model_55/conv2d_558/BiasAdd (71.71k/71.71k flops)
#   model_55/dense_167/MatMul (36.16k/36.16k flops)
#   model_55/dense_165/BiasAdd (2.16k/2.16k flops)
#   model_55/dense_166/BiasAdd (1.81k/1.81k flops)
#   model_55/dense_167/Softmax (50/50 flops)
#   model_55/dense_167/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 34.556908
# 2022-04-13 05:47:57.511325: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:57.511412: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:57.512925: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/10.90b flops)
#   model_56/conv2d_561/Conv2D (2.38b/2.38b flops)
#   model_56/conv2d_567/Conv2D (1.85b/1.85b flops)
#   model_56/conv2d_565/Conv2D (1.56b/1.56b flops)
#   model_56/conv2d_563/Conv2D (1.28b/1.28b flops)
#   model_56/conv2d_562/Conv2D (891.81m/891.81m flops)
#   model_56/conv2d_566/Conv2D (824.80m/824.80m flops)
#   model_56/conv2d_569/Conv2D (663.65m/663.65m flops)
#   model_56/conv2d_568/Conv2D (663.65m/663.65m flops)
#   model_56/conv2d_564/Conv2D (633.36m/633.36m flops)
#   model_56/dense_168/MatMul (99.68m/99.68m flops)
#   model_56/conv2d_560/Conv2D (37.16m/37.16m flops)
#   model_56/dense_169/MatMul (10.07m/10.07m flops)
#   model_56/max_pooling2d_280/MaxPool (2.36m/2.36m flops)
#   model_56/conv2d_561/BiasAdd (2.36m/2.36m flops)
#   model_56/conv2d_560/BiasAdd (2.06m/2.06m flops)
#   model_56/conv2d_563/BiasAdd (847.87k/847.87k flops)
#   model_56/max_pooling2d_281/MaxPool (847.87k/847.87k flops)
#   model_56/conv2d_562/BiasAdd (774.14k/774.14k flops)
#   model_56/conv2d_565/BiasAdd (520.70k/520.70k flops)
#   model_56/max_pooling2d_282/MaxPool (520.70k/520.70k flops)
#   model_56/conv2d_564/BiasAdd (382.46k/382.46k flops)
#   model_56/conv2d_567/BiasAdd (291.46k/291.46k flops)
#   model_56/max_pooling2d_283/MaxPool (291.46k/291.46k flops)
#   model_56/conv2d_566/BiasAdd (202.75k/202.75k flops)
#   model_56/max_pooling2d_284/MaxPool (72.86k/72.86k flops)
#   model_56/conv2d_569/BiasAdd (72.86k/72.86k flops)
#   model_56/conv2d_568/BiasAdd (72.86k/72.86k flops)
#   model_56/dense_170/MatMul (36.80k/36.80k flops)
#   model_56/dense_168/BiasAdd (2.74k/2.74k flops)
#   model_56/dense_169/BiasAdd (1.84k/1.84k flops)
#   model_56/dense_170/Softmax (50/50 flops)
#   model_56/dense_170/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 32.125868
# 2022-04-13 05:48:02.314870: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:48:02.314966: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:48:02.329362: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.031ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/9.36b flops)
#   model_57/conv2d_571/Conv2D (2.46b/2.46b flops)
#   model_57/conv2d_577/Conv2D (2.43b/2.43b flops)
#   model_57/conv2d_576/Conv2D (843.04m/843.04m flops)
#   model_57/conv2d_573/Conv2D (769.72m/769.72m flops)
#   model_57/conv2d_579/Conv2D (645.35m/645.35m flops)
#   model_57/conv2d_578/Conv2D (619.74m/619.74m flops)
#   model_57/conv2d_572/Conv2D (615.78m/615.78m flops)
#   model_57/conv2d_575/Conv2D (571.32m/571.32m flops)
#   model_57/conv2d_574/Conv2D (272.06m/272.06m flops)
#   model_57/dense_171/MatMul (73.74m/73.74m flops)
#   model_57/conv2d_570/Conv2D (38.49m/38.49m flops)
#   model_57/dense_172/MatMul (8.13m/8.13m flops)
#   model_57/max_pooling2d_285/MaxPool (2.36m/2.36m flops)
#   model_57/conv2d_571/BiasAdd (2.36m/2.36m flops)
#   model_57/conv2d_570/BiasAdd (2.14m/2.14m flops)
#   model_57/conv2d_573/BiasAdd (737.28k/737.28k flops)
#   model_57/max_pooling2d_286/MaxPool (737.28k/737.28k flops)
#   model_57/conv2d_572/BiasAdd (534.53k/534.53k flops)
#   model_57/conv2d_575/BiasAdd (387.07k/387.07k flops)
#   model_57/max_pooling2d_287/MaxPool (387.07k/387.07k flops)
#   model_57/conv2d_576/BiasAdd (278.78k/278.78k flops)
#   model_57/conv2d_577/BiasAdd (278.78k/278.78k flops)
#   model_57/max_pooling2d_288/MaxPool (278.78k/278.78k flops)
#   model_57/conv2d_574/BiasAdd (188.93k/188.93k flops)
#   model_57/max_pooling2d_289/MaxPool (72.58k/72.58k flops)
#   model_57/conv2d_579/BiasAdd (72.58k/72.58k flops)
#   model_57/conv2d_578/BiasAdd (71.14k/71.14k flops)
#   model_57/dense_173/MatMul (40.00k/40.00k flops)
#   model_57/dense_171/BiasAdd (2.03k/2.03k flops)
#   model_57/dense_172/BiasAdd (2.00k/2.00k flops)
#   model_57/dense_173/Softmax (50/50 flops)
#   model_57/dense_173/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 30.533036
# 2022-04-13 05:48:06.249669: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:48:06.249759: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:48:06.251193: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/8.97b flops)
#   model_58/conv2d_585/Conv2D (1.93b/1.93b flops)
#   model_58/conv2d_581/Conv2D (1.36b/1.36b flops)
#   model_58/conv2d_587/Conv2D (1.29b/1.29b flops)
#   model_58/conv2d_583/Conv2D (1.05b/1.05b flops)
#   model_58/conv2d_584/Conv2D (905.25m/905.25m flops)
#   model_58/conv2d_586/Conv2D (727.79m/727.79m flops)
#   model_58/conv2d_582/Conv2D (658.24m/658.24m flops)
#   model_58/conv2d_589/Conv2D (510.62m/510.62m flops)
#   model_58/conv2d_588/Conv2D (394.20m/394.20m flops)
#   model_58/dense_174/MatMul (99.65m/99.65m flops)
#   model_58/conv2d_580/Conv2D (21.23m/21.23m flops)
#   model_58/dense_175/MatMul (9.65m/9.65m flops)
#   model_58/max_pooling2d_290/MaxPool (2.36m/2.36m flops)
#   model_58/conv2d_581/BiasAdd (2.36m/2.36m flops)
#   model_58/conv2d_580/BiasAdd (1.18m/1.18m flops)
#   model_58/conv2d_583/BiasAdd (940.03k/940.03k flops)
#   model_58/max_pooling2d_291/MaxPool (940.03k/940.03k flops)
#   model_58/conv2d_582/BiasAdd (571.39k/571.39k flops)
#   model_58/conv2d_585/BiasAdd (502.27k/502.27k flops)
#   model_58/max_pooling2d_292/MaxPool (502.27k/502.27k flops)
#   model_58/conv2d_584/BiasAdd (493.06k/493.06k flops)
#   model_58/conv2d_587/BiasAdd (222.34k/222.34k flops)
#   model_58/max_pooling2d_293/MaxPool (222.34k/222.34k flops)
#   model_58/conv2d_586/BiasAdd (185.47k/185.47k flops)
#   model_58/max_pooling2d_294/MaxPool (72.00k/72.00k flops)
#   model_58/conv2d_589/BiasAdd (72.00k/72.00k flops)
#   model_58/conv2d_588/BiasAdd (56.74k/56.74k flops)
#   model_58/dense_176/MatMul (34.88k/34.88k flops)
#   model_58/dense_174/BiasAdd (2.77k/2.77k flops)
#   model_58/dense_175/BiasAdd (1.74k/1.74k flops)
#   model_58/dense_176/Softmax (50/50 flops)
#   model_58/dense_176/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 37.775788
# 2022-04-13 05:48:10.885732: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:48:10.885830: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:48:10.887369: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.006ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/12.18b flops)
#   model_59/conv2d_591/Conv2D (2.63b/2.63b flops)
#   model_59/conv2d_595/Conv2D (2.28b/2.28b flops)
#   model_59/conv2d_593/Conv2D (2.10b/2.10b flops)
#   model_59/conv2d_597/Conv2D (1.14b/1.14b flops)
#   model_59/conv2d_594/Conv2D (1.12b/1.12b flops)
#   model_59/conv2d_592/Conv2D (1.08b/1.08b flops)
#   model_59/conv2d_596/Conv2D (762.92m/762.92m flops)
#   model_59/conv2d_599/Conv2D (544.32m/544.32m flops)
#   model_59/conv2d_598/Conv2D (409.33m/409.33m flops)
#   model_59/dense_177/MatMul (54.72m/54.72m flops)
#   model_59/conv2d_590/Conv2D (41.14m/41.14m flops)
#   model_59/dense_178/MatMul (3.45m/3.45m flops)
#   model_59/max_pooling2d_295/MaxPool (2.36m/2.36m flops)
#   model_59/conv2d_591/BiasAdd (2.36m/2.36m flops)
#   model_59/conv2d_590/BiasAdd (2.29m/2.29m flops)
#   model_59/conv2d_593/BiasAdd (1.14m/1.14m flops)
#   model_59/max_pooling2d_296/MaxPool (1.14m/1.14m flops)
#   model_59/conv2d_592/BiasAdd (940.03k/940.03k flops)
#   model_59/conv2d_595/BiasAdd (580.61k/580.61k flops)
#   model_59/max_pooling2d_297/MaxPool (580.61k/580.61k flops)
#   model_59/conv2d_594/BiasAdd (502.27k/502.27k flops)
#   model_59/conv2d_597/BiasAdd (216.58k/216.58k flops)
#   model_59/max_pooling2d_298/MaxPool (216.58k/216.58k flops)
#   model_59/conv2d_596/BiasAdd (168.19k/168.19k flops)
#   model_59/max_pooling2d_299/MaxPool (72.00k/72.00k flops)
#   model_59/conv2d_599/BiasAdd (72.00k/72.00k flops)
#   model_59/conv2d_598/BiasAdd (60.48k/60.48k flops)
#   model_59/dense_179/MatMul (22.72k/22.72k flops)
#   model_59/dense_177/BiasAdd (1.52k/1.52k flops)
#   model_59/dense_178/BiasAdd (1.14k/1.14k flops)
#   model_59/dense_179/Softmax (50/50 flops)
#   model_59/dense_179/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
