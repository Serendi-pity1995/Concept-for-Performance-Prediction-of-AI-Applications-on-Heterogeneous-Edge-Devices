# %%
import os
import csv
import numpy as np
import tensorflow as tf
from itertools import product
from tensorflow_model_optimization.quantization.keras import vitis_quantize
import cv2
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D
from keras.models import Model, load_model
from keras.initializers import glorot_uniform

from keras.utils.vis_utils import model_to_dot
import keras.backend as K

from keras_flops import get_flops


def identity_block(X, f, filters, stage, block):
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    # Retrieve Filters
    F1, F2, F3 = filters

    # Save the input value. We'll need this later to add back to the main path. 
    X_shortcut = X

    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    # Second component of main path
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X
def convolutional_block(X, f, filters, stage, block, s = 2):
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    # First component of main path 
    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    # Second component of main path
    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path
    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    
    ##### SHORTCUT PATH ####
    X_shortcut = Conv2D(F3, (1, 1), strides = (s,s), name = conv_name_base + '1', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X
def ResNet50(input_shape = (64, 64, 3), classes = 2):   
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')

    # Stage 3
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    # Stage 4
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    # Stage 5
    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], stage = 5, block='a', s = 2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    # AVGPOOL.
    X = AveragePooling2D((2, 2), name='avg_pool')(X)

    # output layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)
    
    # Create model
    model = Model(inputs = X_input, outputs = X, name='ResNet50')

    return model

model_num = 1
input_horizontal =range(64,256,32)
input_vertical =range(64,256,32)
with open("para_count_resnet50.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "FLOPs", "Total_params"],])
for input_x, input_y in product(input_horizontal, input_vertical):

    model = ResNet50(input_shape = (input_x, input_y, 3), classes = 2)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    Total_params = round(model.count_params()/10 ** 6,2)
    FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
    with open("para_count_resnet50.csv","a+") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerows([[model_num, input_x, input_y, FLOPs, Total_params],])

        model_num = model_num + 1
# Out:
# 2022-03-05 09:18:32.319176: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-03-05 09:18:32.319208: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-03-05 09:18:33.454174: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/cv2/../../lib64:/opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-03-05 09:18:33.454206: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-05 09:18:33.454220: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2022-03-05 09:18:33.454356: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-05 09:18:34.896520: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-03-05 09:18:34.896684: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-03-05 09:18:34.926517: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.009ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# WARNING:tensorflow:From /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py:5063: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/619.53m flops)
#   ResNet50/conv1/Conv2D (19.27m/19.27m flops)
#   ResNet50/res4e_branch2b/Conv2D (18.87m/18.87m flops)
#   ResNet50/res4b_branch2b/Conv2D (18.87m/18.87m flops)
#   ResNet50/res4a_branch2b/Conv2D (18.87m/18.87m flops)
#   ResNet50/res4c_branch2b/Conv2D (18.87m/18.87m flops)
#   ResNet50/res4d_branch2b/Conv2D (18.87m/18.87m flops)
#   ResNet50/res3d_branch2b/Conv2D (18.87m/18.87m flops)
#   ResNet50/res3c_branch2b/Conv2D (18.87m/18.87m flops)
#   ResNet50/res4f_branch2b/Conv2D (18.87m/18.87m flops)
#   ResNet50/res5a_branch2b/Conv2D (18.87m/18.87m flops)
#   ResNet50/res3a_branch2b/Conv2D (18.87m/18.87m flops)
#   ResNet50/res5c_branch2b/Conv2D (18.87m/18.87m flops)
#   ResNet50/res3b_branch2b/Conv2D (18.87m/18.87m flops)
#   ResNet50/res5b_branch2b/Conv2D (18.87m/18.87m flops)
#   ResNet50/res5a_branch1/Conv2D (16.78m/16.78m flops)
#   ResNet50/res4a_branch1/Conv2D (16.78m/16.78m flops)
#   ResNet50/res3a_branch1/Conv2D (16.78m/16.78m flops)
#   ResNet50/res2a_branch2b/Conv2D (16.59m/16.59m flops)
#   ResNet50/res2c_branch2b/Conv2D (16.59m/16.59m flops)
#   ResNet50/res2b_branch2b/Conv2D (16.59m/16.59m flops)
#   ResNet50/res3d_branch2a/Conv2D (8.39m/8.39m flops)
#   ResNet50/res4c_branch2a/Conv2D (8.39m/8.39m flops)
#   ResNet50/res3b_branch2a/Conv2D (8.39m/8.39m flops)
#   ResNet50/res3d_branch2c/Conv2D (8.39m/8.39m flops)
#   ResNet50/res3c_branch2c/Conv2D (8.39m/8.39m flops)
#   ResNet50/res3a_branch2c/Conv2D (8.39m/8.39m flops)
#   ResNet50/res3b_branch2c/Conv2D (8.39m/8.39m flops)
#   ResNet50/res4a_branch2c/Conv2D (8.39m/8.39m flops)
#   ResNet50/res4b_branch2a/Conv2D (8.39m/8.39m flops)
#   ResNet50/res3c_branch2a/Conv2D (8.39m/8.39m flops)
#   ResNet50/res4b_branch2c/Conv2D (8.39m/8.39m flops)
#   ResNet50/res5c_branch2c/Conv2D (8.39m/8.39m flops)
#   ResNet50/res5c_branch2a/Conv2D (8.39m/8.39m flops)
#   ResNet50/res5b_branch2c/Conv2D (8.39m/8.39m flops)
#   ResNet50/res5b_branch2a/Conv2D (8.39m/8.39m flops)
#   ResNet50/res5a_branch2c/Conv2D (8.39m/8.39m flops)
#   ResNet50/res4f_branch2c/Conv2D (8.39m/8.39m flops)
#   ResNet50/res4f_branch2a/Conv2D (8.39m/8.39m flops)
#   ResNet50/res4e_branch2c/Conv2D (8.39m/8.39m flops)
#   ResNet50/res4e_branch2a/Conv2D (8.39m/8.39m flops)
#   ResNet50/res4d_branch2c/Conv2D (8.39m/8.39m flops)
#   ResNet50/res4d_branch2a/Conv2D (8.39m/8.39m flops)
#   ResNet50/res4c_branch2c/Conv2D (8.39m/8.39m flops)
#   ResNet50/res2a_branch1/Conv2D (7.37m/7.37m flops)
#   ResNet50/res2c_branch2c/Conv2D (7.37m/7.37m flops)
#   ResNet50/res2a_branch2c/Conv2D (7.37m/7.37m flops)
#   ResNet50/res2c_branch2a/Conv2D (7.37m/7.37m flops)
#   ResNet50/res2b_branch2a/Conv2D (7.37m/7.37m flops)
#   ResNet50/res2b_branch2c/Conv2D (7.37m/7.37m flops)
#   ResNet50/res4a_branch2a/Conv2D (4.19m/4.19m flops)
#   ResNet50/res5a_branch2a/Conv2D (4.19m/4.19m flops)
#   ResNet50/res3a_branch2a/Conv2D (4.19m/4.19m flops)
#   ResNet50/res2a_branch2a/Conv2D (1.84m/1.84m flops)
#   ResNet50/bn_conv1/FusedBatchNormV3 (131.46k/131.46k flops)
#   ResNet50/max_pooling2d/MaxPool (129.60k/129.60k flops)
#   ResNet50/bn2b_branch2c/FusedBatchNormV3 (116.74k/116.74k flops)
#   ResNet50/bn2a_branch1/FusedBatchNormV3 (116.74k/116.74k flops)
#   ResNet50/bn2a_branch2c/FusedBatchNormV3 (116.74k/116.74k flops)
#   ResNet50/bn2c_branch2c/FusedBatchNormV3 (116.74k/116.74k flops)
#   ResNet50/bn3a_branch1/FusedBatchNormV3 (68.61k/68.61k flops)
#   ResNet50/bn3a_branch2c/FusedBatchNormV3 (68.61k/68.61k flops)
#   ResNet50/bn3b_branch2c/FusedBatchNormV3 (68.61k/68.61k flops)
#   ResNet50/bn3c_branch2c/FusedBatchNormV3 (68.61k/68.61k flops)
#   ResNet50/bn3d_branch2c/FusedBatchNormV3 (68.61k/68.61k flops)
#   ResNet50/conv1/BiasAdd (65.54k/65.54k flops)
#   ResNet50/res2b_branch2c/BiasAdd (57.60k/57.60k flops)
#   ResNet50/res2a_branch2c/BiasAdd (57.60k/57.60k flops)
#   ResNet50/add_1/add (57.60k/57.60k flops)
#   ResNet50/res2a_branch1/BiasAdd (57.60k/57.60k flops)
#   ResNet50/res2c_branch2c/BiasAdd (57.60k/57.60k flops)
#   ResNet50/add/add (57.60k/57.60k flops)
#   ResNet50/add_2/add (57.60k/57.60k flops)
#   ResNet50/bn4b_branch2c/FusedBatchNormV3 (38.91k/38.91k flops)
#   ResNet50/bn4a_branch2c/FusedBatchNormV3 (38.91k/38.91k flops)
#   ResNet50/bn4c_branch2c/FusedBatchNormV3 (38.91k/38.91k flops)
#   ResNet50/bn4a_branch1/FusedBatchNormV3 (38.91k/38.91k flops)
#   ResNet50/bn4d_branch2c/FusedBatchNormV3 (38.91k/38.91k flops)
#   ResNet50/bn4e_branch2c/FusedBatchNormV3 (38.91k/38.91k flops)
#   ResNet50/bn4f_branch2c/FusedBatchNormV3 (38.91k/38.91k flops)
#   ResNet50/add_3/add (32.77k/32.77k flops)
#   ResNet50/res3d_branch2c/BiasAdd (32.77k/32.77k flops)
#   ResNet50/add_5/add (32.77k/32.77k flops)
#   ResNet50/res3a_branch1/BiasAdd (32.77k/32.77k flops)
#   ResNet50/res3c_branch2c/BiasAdd (32.77k/32.77k flops)
#   ResNet50/add_4/add (32.77k/32.77k flops)
#   ResNet50/add_6/add (32.77k/32.77k flops)
#   ResNet50/res3a_branch2c/BiasAdd (32.77k/32.77k flops)
#   ResNet50/res3b_branch2c/BiasAdd (32.77k/32.77k flops)
#   ResNet50/bn2a_branch2a/FusedBatchNormV3 (29.18k/29.18k flops)
#   ResNet50/bn2a_branch2b/FusedBatchNormV3 (29.18k/29.18k flops)
#   ResNet50/bn2c_branch2b/FusedBatchNormV3 (29.18k/29.18k flops)
#   ResNet50/bn2c_branch2a/FusedBatchNormV3 (29.18k/29.18k flops)
#   ResNet50/bn2b_branch2b/FusedBatchNormV3 (29.18k/29.18k flops)
#   ResNet50/bn2b_branch2a/FusedBatchNormV3 (29.18k/29.18k flops)
#   ResNet50/bn5a_branch1/FusedBatchNormV3 (28.67k/28.67k flops)
#   ResNet50/bn5c_branch2c/FusedBatchNormV3 (28.67k/28.67k flops)
#   ResNet50/bn5b_branch2c/FusedBatchNormV3 (28.67k/28.67k flops)
#   ResNet50/bn5a_branch2c/FusedBatchNormV3 (28.67k/28.67k flops)
#   ResNet50/bn3c_branch2b/FusedBatchNormV3 (17.15k/17.15k flops)
#   ResNet50/bn3d_branch2b/FusedBatchNormV3 (17.15k/17.15k flops)
#   ResNet50/bn3d_branch2a/FusedBatchNormV3 (17.15k/17.15k flops)
#   ResNet50/bn3c_branch2a/FusedBatchNormV3 (17.15k/17.15k flops)
#   ResNet50/bn3b_branch2b/FusedBatchNormV3 (17.15k/17.15k flops)
#   ResNet50/bn3b_branch2a/FusedBatchNormV3 (17.15k/17.15k flops)
#   ResNet50/bn3a_branch2b/FusedBatchNormV3 (17.15k/17.15k flops)
#   ResNet50/bn3a_branch2a/FusedBatchNormV3 (17.15k/17.15k flops)
#   ResNet50/add_10/add (16.38k/16.38k flops)
#   ResNet50/add_11/add (16.38k/16.38k flops)
#   ResNet50/add_12/add (16.38k/16.38k flops)
#   ResNet50/res4f_branch2c/BiasAdd (16.38k/16.38k flops)
#   ResNet50/add_7/add (16.38k/16.38k flops)
#   ResNet50/add_8/add (16.38k/16.38k flops)
#   ResNet50/res4e_branch2c/BiasAdd (16.38k/16.38k flops)
#   ResNet50/add_9/add (16.38k/16.38k flops)
#   ResNet50/res4a_branch2c/BiasAdd (16.38k/16.38k flops)
#   ResNet50/res4d_branch2c/BiasAdd (16.38k/16.38k flops)
#   ResNet50/res4c_branch2c/BiasAdd (16.38k/16.38k flops)
#   ResNet50/res4a_branch1/BiasAdd (16.38k/16.38k flops)
#   ResNet50/res4b_branch2c/BiasAdd (16.38k/16.38k flops)
#   ResNet50/res2c_branch2b/BiasAdd (14.40k/14.40k flops)
#   ResNet50/res2c_branch2a/BiasAdd (14.40k/14.40k flops)
#   ResNet50/res2b_branch2b/BiasAdd (14.40k/14.40k flops)
#   ResNet50/res2b_branch2a/BiasAdd (14.40k/14.40k flops)
#   ResNet50/res2a_branch2b/BiasAdd (14.40k/14.40k flops)
#   ResNet50/res2a_branch2a/BiasAdd (14.40k/14.40k flops)
#   ResNet50/bn4f_branch2b/FusedBatchNormV3 (9.73k/9.73k flops)
#   ResNet50/bn4f_branch2a/FusedBatchNormV3 (9.73k/9.73k flops)
#   ResNet50/bn4c_branch2a/FusedBatchNormV3 (9.73k/9.73k flops)
#   ResNet50/bn4e_branch2b/FusedBatchNormV3 (9.73k/9.73k flops)
#   ResNet50/bn4a_branch2a/FusedBatchNormV3 (9.73k/9.73k flops)
#   ResNet50/bn4a_branch2b/FusedBatchNormV3 (9.73k/9.73k flops)
#   ResNet50/bn4d_branch2a/FusedBatchNormV3 (9.73k/9.73k flops)
#   ResNet50/bn4b_branch2b/FusedBatchNormV3 (9.73k/9.73k flops)
#   ResNet50/bn4c_branch2b/FusedBatchNormV3 (9.73k/9.73k flops)
#   ResNet50/bn4d_branch2b/FusedBatchNormV3 (9.73k/9.73k flops)
#   ResNet50/bn4e_branch2a/FusedBatchNormV3 (9.73k/9.73k flops)
#   ResNet50/bn4b_branch2a/FusedBatchNormV3 (9.73k/9.73k flops)
#   ResNet50/res3c_branch2b/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res3c_branch2a/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res3a_branch2b/BiasAdd (8.19k/8.19k flops)
#   ResNet50/avg_pool/AvgPool (8.19k/8.19k flops)
#   ResNet50/res5a_branch1/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res3d_branch2a/BiasAdd (8.19k/8.19k flops)
#   ResNet50/add_15/add (8.19k/8.19k flops)
#   ResNet50/fc2/MatMul (8.19k/8.19k flops)
#   ResNet50/res5a_branch2c/BiasAdd (8.19k/8.19k flops)
#   ResNet50/add_14/add (8.19k/8.19k flops)
#   ResNet50/res3d_branch2b/BiasAdd (8.19k/8.19k flops)
#   ResNet50/add_13/add (8.19k/8.19k flops)
#   ResNet50/res5b_branch2c/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res3a_branch2a/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res3b_branch2a/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res3b_branch2b/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res5c_branch2c/BiasAdd (8.19k/8.19k flops)
#   ResNet50/bn5c_branch2b/FusedBatchNormV3 (7.17k/7.17k flops)
#   ResNet50/bn5c_branch2a/FusedBatchNormV3 (7.17k/7.17k flops)
#   ResNet50/bn5b_branch2b/FusedBatchNormV3 (7.17k/7.17k flops)
#   ResNet50/bn5b_branch2a/FusedBatchNormV3 (7.17k/7.17k flops)
#   ResNet50/bn5a_branch2a/FusedBatchNormV3 (7.17k/7.17k flops)
#   ResNet50/bn5a_branch2b/FusedBatchNormV3 (7.17k/7.17k flops)
#   ResNet50/res4f_branch2a/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res4a_branch2b/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res4b_branch2a/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res4a_branch2a/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res4b_branch2b/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res4c_branch2a/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res4c_branch2b/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res4d_branch2a/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res4d_branch2b/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res4e_branch2a/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res4e_branch2b/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res4f_branch2b/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res5b_branch2a/BiasAdd (2.05k/2.05k flops)
#   ResNet50/res5b_branch2b/BiasAdd (2.05k/2.05k flops)
#   ResNet50/res5a_branch2b/BiasAdd (2.05k/2.05k flops)
#   ResNet50/res5a_branch2a/BiasAdd (2.05k/2.05k flops)
#   ResNet50/res5c_branch2a/BiasAdd (2.05k/2.05k flops)
#   ResNet50/res5c_branch2b/BiasAdd (2.05k/2.05k flops)
#   ResNet50/fc2/Softmax (10/10 flops)
#   ResNet50/fc2/BiasAdd (2/2 flops)
#
# ======================End of Report==========================
# 2022-03-05 09:18:37.662032: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-03-05 09:18:37.662151: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-03-05 09:18:37.669050: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.006ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/932.44m flops)
#   ResNet50/conv1/Conv2D (28.90m/28.90m flops)
#   ResNet50/res4e_branch2b/Conv2D (28.31m/28.31m flops)
#   ResNet50/res4b_branch2b/Conv2D (28.31m/28.31m flops)
#   ResNet50/res4a_branch2b/Conv2D (28.31m/28.31m flops)
#   ResNet50/res4c_branch2b/Conv2D (28.31m/28.31m flops)
#   ResNet50/res4d_branch2b/Conv2D (28.31m/28.31m flops)
#   ResNet50/res3d_branch2b/Conv2D (28.31m/28.31m flops)
#   ResNet50/res3c_branch2b/Conv2D (28.31m/28.31m flops)
#   ResNet50/res4f_branch2b/Conv2D (28.31m/28.31m flops)
#   ResNet50/res5a_branch2b/Conv2D (28.31m/28.31m flops)
#   ResNet50/res3a_branch2b/Conv2D (28.31m/28.31m flops)
#   ResNet50/res3b_branch2b/Conv2D (28.31m/28.31m flops)
#   ResNet50/res5c_branch2b/Conv2D (28.31m/28.31m flops)
#   ResNet50/res5b_branch2b/Conv2D (28.31m/28.31m flops)
#   ResNet50/res2b_branch2b/Conv2D (25.44m/25.44m flops)
#   ResNet50/res2c_branch2b/Conv2D (25.44m/25.44m flops)
#   ResNet50/res2a_branch2b/Conv2D (25.44m/25.44m flops)
#   ResNet50/res5a_branch1/Conv2D (25.17m/25.17m flops)
#   ResNet50/res4a_branch1/Conv2D (25.17m/25.17m flops)
#   ResNet50/res3a_branch1/Conv2D (25.17m/25.17m flops)
#   ResNet50/res3b_branch2a/Conv2D (12.58m/12.58m flops)
#   ResNet50/res3d_branch2c/Conv2D (12.58m/12.58m flops)
#   ResNet50/res3d_branch2a/Conv2D (12.58m/12.58m flops)
#   ResNet50/res4c_branch2a/Conv2D (12.58m/12.58m flops)
#   ResNet50/res3a_branch2c/Conv2D (12.58m/12.58m flops)
#   ResNet50/res3c_branch2c/Conv2D (12.58m/12.58m flops)
#   ResNet50/res4a_branch2c/Conv2D (12.58m/12.58m flops)
#   ResNet50/res3b_branch2c/Conv2D (12.58m/12.58m flops)
#   ResNet50/res4b_branch2a/Conv2D (12.58m/12.58m flops)
#   ResNet50/res3c_branch2a/Conv2D (12.58m/12.58m flops)
#   ResNet50/res4b_branch2c/Conv2D (12.58m/12.58m flops)
#   ResNet50/res5c_branch2c/Conv2D (12.58m/12.58m flops)
#   ResNet50/res5c_branch2a/Conv2D (12.58m/12.58m flops)
#   ResNet50/res5b_branch2c/Conv2D (12.58m/12.58m flops)
#   ResNet50/res5b_branch2a/Conv2D (12.58m/12.58m flops)
#   ResNet50/res5a_branch2c/Conv2D (12.58m/12.58m flops)
#   ResNet50/res4f_branch2c/Conv2D (12.58m/12.58m flops)
#   ResNet50/res4f_branch2a/Conv2D (12.58m/12.58m flops)
#   ResNet50/res4e_branch2c/Conv2D (12.58m/12.58m flops)
#   ResNet50/res4e_branch2a/Conv2D (12.58m/12.58m flops)
#   ResNet50/res4d_branch2c/Conv2D (12.58m/12.58m flops)
#   ResNet50/res4d_branch2a/Conv2D (12.58m/12.58m flops)
#   ResNet50/res4c_branch2c/Conv2D (12.58m/12.58m flops)
#   ResNet50/res2a_branch1/Conv2D (11.30m/11.30m flops)
#   ResNet50/res2c_branch2c/Conv2D (11.30m/11.30m flops)
#   ResNet50/res2a_branch2c/Conv2D (11.30m/11.30m flops)
#   ResNet50/res2c_branch2a/Conv2D (11.30m/11.30m flops)
#   ResNet50/res2b_branch2a/Conv2D (11.30m/11.30m flops)
#   ResNet50/res2b_branch2c/Conv2D (11.30m/11.30m flops)
#   ResNet50/res4a_branch2a/Conv2D (6.29m/6.29m flops)
#   ResNet50/res5a_branch2a/Conv2D (6.29m/6.29m flops)
#   ResNet50/res3a_branch2a/Conv2D (6.29m/6.29m flops)
#   ResNet50/res2a_branch2a/Conv2D (2.83m/2.83m flops)
#   ResNet50/max_pooling2d_1/MaxPool (198.72k/198.72k flops)
#   ResNet50/bn_conv1/FusedBatchNormV3 (196.99k/196.99k flops)
#   ResNet50/bn2b_branch2c/FusedBatchNormV3 (178.18k/178.18k flops)
#   ResNet50/bn2a_branch1/FusedBatchNormV3 (178.18k/178.18k flops)
#   ResNet50/bn2a_branch2c/FusedBatchNormV3 (178.18k/178.18k flops)
#   ResNet50/bn2c_branch2c/FusedBatchNormV3 (178.18k/178.18k flops)
#   ResNet50/bn3a_branch1/FusedBatchNormV3 (101.38k/101.38k flops)
#   ResNet50/bn3a_branch2c/FusedBatchNormV3 (101.38k/101.38k flops)
#   ResNet50/bn3b_branch2c/FusedBatchNormV3 (101.38k/101.38k flops)
#   ResNet50/bn3c_branch2c/FusedBatchNormV3 (101.38k/101.38k flops)
#   ResNet50/bn3d_branch2c/FusedBatchNormV3 (101.38k/101.38k flops)
#   ResNet50/conv1/BiasAdd (98.30k/98.30k flops)
#   ResNet50/res2b_branch2c/BiasAdd (88.32k/88.32k flops)
#   ResNet50/res2a_branch2c/BiasAdd (88.32k/88.32k flops)
#   ResNet50/add_17/add (88.32k/88.32k flops)
#   ResNet50/res2a_branch1/BiasAdd (88.32k/88.32k flops)
#   ResNet50/res2c_branch2c/BiasAdd (88.32k/88.32k flops)
#   ResNet50/add_16/add (88.32k/88.32k flops)
#   ResNet50/add_18/add (88.32k/88.32k flops)
#   ResNet50/bn4b_branch2c/FusedBatchNormV3 (55.30k/55.30k flops)
#   ResNet50/bn4a_branch2c/FusedBatchNormV3 (55.30k/55.30k flops)
#   ResNet50/bn4c_branch2c/FusedBatchNormV3 (55.30k/55.30k flops)
#   ResNet50/bn4a_branch1/FusedBatchNormV3 (55.30k/55.30k flops)
#   ResNet50/bn4d_branch2c/FusedBatchNormV3 (55.30k/55.30k flops)
#   ResNet50/bn4e_branch2c/FusedBatchNormV3 (55.30k/55.30k flops)
#   ResNet50/bn4f_branch2c/FusedBatchNormV3 (55.30k/55.30k flops)
#   ResNet50/add_19/add (49.15k/49.15k flops)
#   ResNet50/res3d_branch2c/BiasAdd (49.15k/49.15k flops)
#   ResNet50/add_21/add (49.15k/49.15k flops)
#   ResNet50/res3a_branch1/BiasAdd (49.15k/49.15k flops)
#   ResNet50/res3c_branch2c/BiasAdd (49.15k/49.15k flops)
#   ResNet50/add_20/add (49.15k/49.15k flops)
#   ResNet50/add_22/add (49.15k/49.15k flops)
#   ResNet50/res3a_branch2c/BiasAdd (49.15k/49.15k flops)
#   ResNet50/res3b_branch2c/BiasAdd (49.15k/49.15k flops)
#   ResNet50/bn2a_branch2a/FusedBatchNormV3 (44.54k/44.54k flops)
#   ResNet50/bn2a_branch2b/FusedBatchNormV3 (44.54k/44.54k flops)
#   ResNet50/bn2c_branch2b/FusedBatchNormV3 (44.54k/44.54k flops)
#   ResNet50/bn2c_branch2a/FusedBatchNormV3 (44.54k/44.54k flops)
#   ResNet50/bn2b_branch2b/FusedBatchNormV3 (44.54k/44.54k flops)
#   ResNet50/bn2b_branch2a/FusedBatchNormV3 (44.54k/44.54k flops)
#   ResNet50/bn5a_branch1/FusedBatchNormV3 (36.86k/36.86k flops)
#   ResNet50/bn5c_branch2c/FusedBatchNormV3 (36.86k/36.86k flops)
#   ResNet50/bn5b_branch2c/FusedBatchNormV3 (36.86k/36.86k flops)
#   ResNet50/bn5a_branch2c/FusedBatchNormV3 (36.86k/36.86k flops)
#   ResNet50/bn3c_branch2b/FusedBatchNormV3 (25.34k/25.34k flops)
#   ResNet50/bn3d_branch2b/FusedBatchNormV3 (25.34k/25.34k flops)
#   ResNet50/bn3d_branch2a/FusedBatchNormV3 (25.34k/25.34k flops)
#   ResNet50/bn3c_branch2a/FusedBatchNormV3 (25.34k/25.34k flops)
#   ResNet50/bn3b_branch2b/FusedBatchNormV3 (25.34k/25.34k flops)
#   ResNet50/bn3b_branch2a/FusedBatchNormV3 (25.34k/25.34k flops)
#   ResNet50/bn3a_branch2b/FusedBatchNormV3 (25.34k/25.34k flops)
#   ResNet50/bn3a_branch2a/FusedBatchNormV3 (25.34k/25.34k flops)
#   ResNet50/add_23/add (24.58k/24.58k flops)
#   ResNet50/add_24/add (24.58k/24.58k flops)
#   ResNet50/add_25/add (24.58k/24.58k flops)
#   ResNet50/add_26/add (24.58k/24.58k flops)
#   ResNet50/add_27/add (24.58k/24.58k flops)
#   ResNet50/res4f_branch2c/BiasAdd (24.58k/24.58k flops)
#   ResNet50/add_28/add (24.58k/24.58k flops)
#   ResNet50/res4e_branch2c/BiasAdd (24.58k/24.58k flops)
#   ResNet50/res4a_branch2c/BiasAdd (24.58k/24.58k flops)
#   ResNet50/res4d_branch2c/BiasAdd (24.58k/24.58k flops)
#   ResNet50/res4c_branch2c/BiasAdd (24.58k/24.58k flops)
#   ResNet50/res4a_branch1/BiasAdd (24.58k/24.58k flops)
#   ResNet50/res4b_branch2c/BiasAdd (24.58k/24.58k flops)
#   ResNet50/res2c_branch2b/BiasAdd (22.08k/22.08k flops)
#   ResNet50/res2c_branch2a/BiasAdd (22.08k/22.08k flops)
#   ResNet50/res2b_branch2b/BiasAdd (22.08k/22.08k flops)
#   ResNet50/res2b_branch2a/BiasAdd (22.08k/22.08k flops)
#   ResNet50/res2a_branch2b/BiasAdd (22.08k/22.08k flops)
#   ResNet50/res2a_branch2a/BiasAdd (22.08k/22.08k flops)
#   ResNet50/bn4f_branch2b/FusedBatchNormV3 (13.82k/13.82k flops)
#   ResNet50/bn4f_branch2a/FusedBatchNormV3 (13.82k/13.82k flops)
#   ResNet50/bn4c_branch2a/FusedBatchNormV3 (13.82k/13.82k flops)
#   ResNet50/bn4e_branch2b/FusedBatchNormV3 (13.82k/13.82k flops)
#   ResNet50/bn4e_branch2a/FusedBatchNormV3 (13.82k/13.82k flops)
#   ResNet50/bn4d_branch2b/FusedBatchNormV3 (13.82k/13.82k flops)
#   ResNet50/bn4c_branch2b/FusedBatchNormV3 (13.82k/13.82k flops)
#   ResNet50/bn4d_branch2a/FusedBatchNormV3 (13.82k/13.82k flops)
#   ResNet50/bn4b_branch2a/FusedBatchNormV3 (13.82k/13.82k flops)
#   ResNet50/bn4a_branch2b/FusedBatchNormV3 (13.82k/13.82k flops)
#   ResNet50/bn4b_branch2b/FusedBatchNormV3 (13.82k/13.82k flops)
#   ResNet50/bn4a_branch2a/FusedBatchNormV3 (13.82k/13.82k flops)
#   ResNet50/add_29/add (12.29k/12.29k flops)
#   ResNet50/add_30/add (12.29k/12.29k flops)
#   ResNet50/res3a_branch2b/BiasAdd (12.29k/12.29k flops)
#   ResNet50/add_31/add (12.29k/12.29k flops)
#   ResNet50/res3c_branch2b/BiasAdd (12.29k/12.29k flops)
#   ResNet50/res3d_branch2a/BiasAdd (12.29k/12.29k flops)
#   ResNet50/res5a_branch1/BiasAdd (12.29k/12.29k flops)
#   ResNet50/res3c_branch2a/BiasAdd (12.29k/12.29k flops)
#   ResNet50/res3b_branch2a/BiasAdd (12.29k/12.29k flops)
#   ResNet50/res3d_branch2b/BiasAdd (12.29k/12.29k flops)
#   ResNet50/res5a_branch2c/BiasAdd (12.29k/12.29k flops)
#   ResNet50/res3b_branch2b/BiasAdd (12.29k/12.29k flops)
#   ResNet50/res3a_branch2a/BiasAdd (12.29k/12.29k flops)
#   ResNet50/res5b_branch2c/BiasAdd (12.29k/12.29k flops)
#   ResNet50/res5c_branch2c/BiasAdd (12.29k/12.29k flops)
#   ResNet50/bn5b_branch2b/FusedBatchNormV3 (9.22k/9.22k flops)
#   ResNet50/bn5c_branch2a/FusedBatchNormV3 (9.22k/9.22k flops)
#   ResNet50/bn5c_branch2b/FusedBatchNormV3 (9.22k/9.22k flops)
#   ResNet50/bn5b_branch2a/FusedBatchNormV3 (9.22k/9.22k flops)
#   ResNet50/bn5a_branch2b/FusedBatchNormV3 (9.22k/9.22k flops)
#   ResNet50/bn5a_branch2a/FusedBatchNormV3 (9.22k/9.22k flops)
#   ResNet50/avg_pool/AvgPool (8.19k/8.19k flops)
#   ResNet50/fc2/MatMul (8.19k/8.19k flops)
#   ResNet50/res4c_branch2b/BiasAdd (6.14k/6.14k flops)
#   ResNet50/res4a_branch2b/BiasAdd (6.14k/6.14k flops)
#   ResNet50/res4b_branch2a/BiasAdd (6.14k/6.14k flops)
#   ResNet50/res4a_branch2a/BiasAdd (6.14k/6.14k flops)
#   ResNet50/res4b_branch2b/BiasAdd (6.14k/6.14k flops)
#   ResNet50/res4c_branch2a/BiasAdd (6.14k/6.14k flops)
#   ResNet50/res4f_branch2a/BiasAdd (6.14k/6.14k flops)
#   ResNet50/res4d_branch2a/BiasAdd (6.14k/6.14k flops)
#   ResNet50/res4d_branch2b/BiasAdd (6.14k/6.14k flops)
#   ResNet50/res4e_branch2a/BiasAdd (6.14k/6.14k flops)
#   ResNet50/res4e_branch2b/BiasAdd (6.14k/6.14k flops)
#   ResNet50/res4f_branch2b/BiasAdd (6.14k/6.14k flops)
#   ResNet50/res5a_branch2b/BiasAdd (3.07k/3.07k flops)
#   ResNet50/res5b_branch2a/BiasAdd (3.07k/3.07k flops)
#   ResNet50/res5b_branch2b/BiasAdd (3.07k/3.07k flops)
#   ResNet50/res5a_branch2a/BiasAdd (3.07k/3.07k flops)
#   ResNet50/res5c_branch2a/BiasAdd (3.07k/3.07k flops)
#   ResNet50/res5c_branch2b/BiasAdd (3.07k/3.07k flops)
#   ResNet50/fc2/Softmax (10/10 flops)
#   ResNet50/fc2/BiasAdd (2/2 flops)
#
# ======================End of Report==========================
# 2022-03-05 09:18:39.992629: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-03-05 09:18:39.992746: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-03-05 09:18:39.999691: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.006ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.25b flops)
#   ResNet50/conv1/Conv2D (38.54m/38.54m flops)
#   ResNet50/res4e_branch2b/Conv2D (37.75m/37.75m flops)
#   ResNet50/res4b_branch2b/Conv2D (37.75m/37.75m flops)
#   ResNet50/res4a_branch2b/Conv2D (37.75m/37.75m flops)
#   ResNet50/res4c_branch2b/Conv2D (37.75m/37.75m flops)
#   ResNet50/res4d_branch2b/Conv2D (37.75m/37.75m flops)
#   ResNet50/res3d_branch2b/Conv2D (37.75m/37.75m flops)
#   ResNet50/res3c_branch2b/Conv2D (37.75m/37.75m flops)
#   ResNet50/res4f_branch2b/Conv2D (37.75m/37.75m flops)
#   ResNet50/res5a_branch2b/Conv2D (37.75m/37.75m flops)
#   ResNet50/res3a_branch2b/Conv2D (37.75m/37.75m flops)
#   ResNet50/res3b_branch2b/Conv2D (37.75m/37.75m flops)
#   ResNet50/res5c_branch2b/Conv2D (37.75m/37.75m flops)
#   ResNet50/res5b_branch2b/Conv2D (37.75m/37.75m flops)
#   ResNet50/res2b_branch2b/Conv2D (34.28m/34.28m flops)
#   ResNet50/res2c_branch2b/Conv2D (34.28m/34.28m flops)
#   ResNet50/res2a_branch2b/Conv2D (34.28m/34.28m flops)
#   ResNet50/res5a_branch1/Conv2D (33.55m/33.55m flops)
#   ResNet50/res4a_branch1/Conv2D (33.55m/33.55m flops)
#   ResNet50/res3a_branch1/Conv2D (33.55m/33.55m flops)
#   ResNet50/res3b_branch2a/Conv2D (16.78m/16.78m flops)
#   ResNet50/res3d_branch2c/Conv2D (16.78m/16.78m flops)
#   ResNet50/res3d_branch2a/Conv2D (16.78m/16.78m flops)
#   ResNet50/res4c_branch2a/Conv2D (16.78m/16.78m flops)
#   ResNet50/res3a_branch2c/Conv2D (16.78m/16.78m flops)
#   ResNet50/res3c_branch2c/Conv2D (16.78m/16.78m flops)
#   ResNet50/res4a_branch2c/Conv2D (16.78m/16.78m flops)
#   ResNet50/res3b_branch2c/Conv2D (16.78m/16.78m flops)
#   ResNet50/res4b_branch2a/Conv2D (16.78m/16.78m flops)
#   ResNet50/res3c_branch2a/Conv2D (16.78m/16.78m flops)
#   ResNet50/res4b_branch2c/Conv2D (16.78m/16.78m flops)
#   ResNet50/res5c_branch2c/Conv2D (16.78m/16.78m flops)
#   ResNet50/res5c_branch2a/Conv2D (16.78m/16.78m flops)
#   ResNet50/res5b_branch2c/Conv2D (16.78m/16.78m flops)
#   ResNet50/res5b_branch2a/Conv2D (16.78m/16.78m flops)
#   ResNet50/res5a_branch2c/Conv2D (16.78m/16.78m flops)
#   ResNet50/res4f_branch2c/Conv2D (16.78m/16.78m flops)
#   ResNet50/res4f_branch2a/Conv2D (16.78m/16.78m flops)
#   ResNet50/res4e_branch2c/Conv2D (16.78m/16.78m flops)
#   ResNet50/res4e_branch2a/Conv2D (16.78m/16.78m flops)
#   ResNet50/res4d_branch2c/Conv2D (16.78m/16.78m flops)
#   ResNet50/res4d_branch2a/Conv2D (16.78m/16.78m flops)
#   ResNet50/res4c_branch2c/Conv2D (16.78m/16.78m flops)
#   ResNet50/res2a_branch1/Conv2D (15.24m/15.24m flops)
#   ResNet50/res2c_branch2c/Conv2D (15.24m/15.24m flops)
#   ResNet50/res2a_branch2c/Conv2D (15.24m/15.24m flops)
#   ResNet50/res2c_branch2a/Conv2D (15.24m/15.24m flops)
#   ResNet50/res2b_branch2a/Conv2D (15.24m/15.24m flops)
#   ResNet50/res2b_branch2c/Conv2D (15.24m/15.24m flops)
#   ResNet50/res4a_branch2a/Conv2D (8.39m/8.39m flops)
#   ResNet50/res5a_branch2a/Conv2D (8.39m/8.39m flops)
#   ResNet50/res3a_branch2a/Conv2D (8.39m/8.39m flops)
#   ResNet50/res2a_branch2a/Conv2D (3.81m/3.81m flops)
#   ResNet50/max_pooling2d_2/MaxPool (267.84k/267.84k flops)
#   ResNet50/bn_conv1/FusedBatchNormV3 (262.53k/262.53k flops)
#   ResNet50/bn2b_branch2c/FusedBatchNormV3 (239.62k/239.62k flops)
#   ResNet50/bn2a_branch1/FusedBatchNormV3 (239.62k/239.62k flops)
#   ResNet50/bn2a_branch2c/FusedBatchNormV3 (239.62k/239.62k flops)
#   ResNet50/bn2c_branch2c/FusedBatchNormV3 (239.62k/239.62k flops)
#   ResNet50/bn3a_branch1/FusedBatchNormV3 (134.14k/134.14k flops)
#   ResNet50/bn3a_branch2c/FusedBatchNormV3 (134.14k/134.14k flops)
#   ResNet50/bn3b_branch2c/FusedBatchNormV3 (134.14k/134.14k flops)
#   ResNet50/bn3c_branch2c/FusedBatchNormV3 (134.14k/134.14k flops)
#   ResNet50/bn3d_branch2c/FusedBatchNormV3 (134.14k/134.14k flops)
#   ResNet50/conv1/BiasAdd (131.07k/131.07k flops)
#   ResNet50/res2b_branch2c/BiasAdd (119.04k/119.04k flops)
#   ResNet50/res2a_branch2c/BiasAdd (119.04k/119.04k flops)
#   ResNet50/add_33/add (119.04k/119.04k flops)
#   ResNet50/res2a_branch1/BiasAdd (119.04k/119.04k flops)
#   ResNet50/res2c_branch2c/BiasAdd (119.04k/119.04k flops)
#   ResNet50/add_32/add (119.04k/119.04k flops)
#   ResNet50/add_34/add (119.04k/119.04k flops)
#   ResNet50/bn4b_branch2c/FusedBatchNormV3 (71.68k/71.68k flops)
#   ResNet50/bn4a_branch2c/FusedBatchNormV3 (71.68k/71.68k flops)
#   ResNet50/bn4c_branch2c/FusedBatchNormV3 (71.68k/71.68k flops)
#   ResNet50/bn4a_branch1/FusedBatchNormV3 (71.68k/71.68k flops)
#   ResNet50/bn4d_branch2c/FusedBatchNormV3 (71.68k/71.68k flops)
#   ResNet50/bn4e_branch2c/FusedBatchNormV3 (71.68k/71.68k flops)
#   ResNet50/bn4f_branch2c/FusedBatchNormV3 (71.68k/71.68k flops)
#   ResNet50/add_35/add (65.54k/65.54k flops)
#   ResNet50/res3d_branch2c/BiasAdd (65.54k/65.54k flops)
#   ResNet50/add_37/add (65.54k/65.54k flops)
#   ResNet50/res3a_branch1/BiasAdd (65.54k/65.54k flops)
#   ResNet50/res3c_branch2c/BiasAdd (65.54k/65.54k flops)
#   ResNet50/add_36/add (65.54k/65.54k flops)
#   ResNet50/add_38/add (65.54k/65.54k flops)
#   ResNet50/res3a_branch2c/BiasAdd (65.54k/65.54k flops)
#   ResNet50/res3b_branch2c/BiasAdd (65.54k/65.54k flops)
#   ResNet50/bn2a_branch2a/FusedBatchNormV3 (59.90k/59.90k flops)
#   ResNet50/bn2a_branch2b/FusedBatchNormV3 (59.90k/59.90k flops)
#   ResNet50/bn2c_branch2b/FusedBatchNormV3 (59.90k/59.90k flops)
#   ResNet50/bn2c_branch2a/FusedBatchNormV3 (59.90k/59.90k flops)
#   ResNet50/bn2b_branch2b/FusedBatchNormV3 (59.90k/59.90k flops)
#   ResNet50/bn2b_branch2a/FusedBatchNormV3 (59.90k/59.90k flops)
#   ResNet50/bn5a_branch1/FusedBatchNormV3 (45.06k/45.06k flops)
#   ResNet50/bn5c_branch2c/FusedBatchNormV3 (45.06k/45.06k flops)
#   ResNet50/bn5b_branch2c/FusedBatchNormV3 (45.06k/45.06k flops)
#   ResNet50/bn5a_branch2c/FusedBatchNormV3 (45.06k/45.06k flops)
#   ResNet50/bn3c_branch2b/FusedBatchNormV3 (33.54k/33.54k flops)
#   ResNet50/bn3d_branch2b/FusedBatchNormV3 (33.54k/33.54k flops)
#   ResNet50/bn3d_branch2a/FusedBatchNormV3 (33.54k/33.54k flops)
#   ResNet50/bn3c_branch2a/FusedBatchNormV3 (33.54k/33.54k flops)
#   ResNet50/bn3b_branch2b/FusedBatchNormV3 (33.54k/33.54k flops)
#   ResNet50/bn3b_branch2a/FusedBatchNormV3 (33.54k/33.54k flops)
#   ResNet50/bn3a_branch2b/FusedBatchNormV3 (33.54k/33.54k flops)
#   ResNet50/bn3a_branch2a/FusedBatchNormV3 (33.54k/33.54k flops)
#   ResNet50/add_39/add (32.77k/32.77k flops)
#   ResNet50/add_40/add (32.77k/32.77k flops)
#   ResNet50/add_41/add (32.77k/32.77k flops)
#   ResNet50/add_42/add (32.77k/32.77k flops)
#   ResNet50/add_43/add (32.77k/32.77k flops)
#   ResNet50/res4f_branch2c/BiasAdd (32.77k/32.77k flops)
#   ResNet50/add_44/add (32.77k/32.77k flops)
#   ResNet50/res4e_branch2c/BiasAdd (32.77k/32.77k flops)
#   ResNet50/res4a_branch2c/BiasAdd (32.77k/32.77k flops)
#   ResNet50/res4d_branch2c/BiasAdd (32.77k/32.77k flops)
#   ResNet50/res4c_branch2c/BiasAdd (32.77k/32.77k flops)
#   ResNet50/res4a_branch1/BiasAdd (32.77k/32.77k flops)
#   ResNet50/res4b_branch2c/BiasAdd (32.77k/32.77k flops)
#   ResNet50/res2c_branch2b/BiasAdd (29.76k/29.76k flops)
#   ResNet50/res2c_branch2a/BiasAdd (29.76k/29.76k flops)
#   ResNet50/res2b_branch2b/BiasAdd (29.76k/29.76k flops)
#   ResNet50/res2b_branch2a/BiasAdd (29.76k/29.76k flops)
#   ResNet50/res2a_branch2b/BiasAdd (29.76k/29.76k flops)
#   ResNet50/res2a_branch2a/BiasAdd (29.76k/29.76k flops)
#   ResNet50/bn4f_branch2b/FusedBatchNormV3 (17.92k/17.92k flops)
#   ResNet50/bn4f_branch2a/FusedBatchNormV3 (17.92k/17.92k flops)
#   ResNet50/bn4c_branch2a/FusedBatchNormV3 (17.92k/17.92k flops)
#   ResNet50/bn4e_branch2b/FusedBatchNormV3 (17.92k/17.92k flops)
#   ResNet50/bn4c_branch2b/FusedBatchNormV3 (17.92k/17.92k flops)
#   ResNet50/bn4b_branch2a/FusedBatchNormV3 (17.92k/17.92k flops)
#   ResNet50/bn4a_branch2b/FusedBatchNormV3 (17.92k/17.92k flops)
#   ResNet50/bn4b_branch2b/FusedBatchNormV3 (17.92k/17.92k flops)
#   ResNet50/bn4a_branch2a/FusedBatchNormV3 (17.92k/17.92k flops)
#   ResNet50/bn4d_branch2a/FusedBatchNormV3 (17.92k/17.92k flops)
#   ResNet50/bn4d_branch2b/FusedBatchNormV3 (17.92k/17.92k flops)
#   ResNet50/bn4e_branch2a/FusedBatchNormV3 (17.92k/17.92k flops)
#   ResNet50/res3c_branch2a/BiasAdd (16.38k/16.38k flops)
#   ResNet50/res3c_branch2b/BiasAdd (16.38k/16.38k flops)
#   ResNet50/add_46/add (16.38k/16.38k flops)
#   ResNet50/res3a_branch2b/BiasAdd (16.38k/16.38k flops)
#   ResNet50/add_47/add (16.38k/16.38k flops)
#   ResNet50/res5c_branch2c/BiasAdd (16.38k/16.38k flops)
#   ResNet50/avg_pool/AvgPool (16.38k/16.38k flops)
#   ResNet50/res5a_branch1/BiasAdd (16.38k/16.38k flops)
#   ResNet50/fc2/MatMul (16.38k/16.38k flops)
#   ResNet50/res3d_branch2a/BiasAdd (16.38k/16.38k flops)
#   ResNet50/res5b_branch2c/BiasAdd (16.38k/16.38k flops)
#   ResNet50/res3b_branch2a/BiasAdd (16.38k/16.38k flops)
#   ResNet50/res5a_branch2c/BiasAdd (16.38k/16.38k flops)
#   ResNet50/res3d_branch2b/BiasAdd (16.38k/16.38k flops)
#   ResNet50/res3b_branch2b/BiasAdd (16.38k/16.38k flops)
#   ResNet50/add_45/add (16.38k/16.38k flops)
#   ResNet50/res3a_branch2a/BiasAdd (16.38k/16.38k flops)
#   ResNet50/bn5c_branch2b/FusedBatchNormV3 (11.26k/11.26k flops)
#   ResNet50/bn5b_branch2b/FusedBatchNormV3 (11.26k/11.26k flops)
#   ResNet50/bn5c_branch2a/FusedBatchNormV3 (11.26k/11.26k flops)
#   ResNet50/bn5b_branch2a/FusedBatchNormV3 (11.26k/11.26k flops)
#   ResNet50/bn5a_branch2a/FusedBatchNormV3 (11.26k/11.26k flops)
#   ResNet50/bn5a_branch2b/FusedBatchNormV3 (11.26k/11.26k flops)
#   ResNet50/res4f_branch2a/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res4a_branch2b/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res4b_branch2a/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res4a_branch2a/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res4b_branch2b/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res4c_branch2a/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res4c_branch2b/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res4d_branch2a/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res4d_branch2b/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res4e_branch2a/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res4e_branch2b/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res4f_branch2b/BiasAdd (8.19k/8.19k flops)
#   ResNet50/res5b_branch2a/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res5a_branch2b/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res5b_branch2b/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res5a_branch2a/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res5c_branch2a/BiasAdd (4.10k/4.10k flops)
#   ResNet50/res5c_branch2b/BiasAdd (4.10k/4.10k flops)
#   ResNet50/fc2/Softmax (10/10 flops)
#   ResNet50/fc2/BiasAdd (2/2 flops)
#
# ======================End of Report==========================
# 2022-03-05 09:18:42.602456: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-03-05 09:18:42.602571: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-03-05 09:18:42.609517: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.006ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.56b flops)
#   ResNet50/conv1/Conv2D (48.17m/48.17m flops)
#   ResNet50/res4e_branch2b/Conv2D (47.19m/47.19m flops)
#   ResNet50/res4b_branch2b/Conv2D (47.19m/47.19m flops)
#   ResNet50/res4a_branch2b/Conv2D (47.19m/47.19m flops)
#   ResNet50/res4c_branch2b/Conv2D (47.19m/47.19m flops)
#   ResNet50/res4d_branch2b/Conv2D (47.19m/47.19m flops)
#   ResNet50/res3d_branch2b/Conv2D (47.19m/47.19m flops)
#   ResNet50/res3c_branch2b/Conv2D (47.19m/47.19m flops)
#   ResNet50/res4f_branch2b/Conv2D (47.19m/47.19m flops)
#   ResNet50/res5a_branch2b/Conv2D (47.19m/47.19m flops)
#   ResNet50/res3a_branch2b/Conv2D (47.19m/47.19m flops)
#   ResNet50/res3b_branch2b/Conv2D (47.19m/47.19m flops)
#   ResNet50/res5c_branch2b/Conv2D (47.19m/47.19m flops)
#   ResNet50/res5b_branch2b/Conv2D (47.19m/47.19m flops)
#   ResNet50/res2b_branch2b/Conv2D (43.13m/43.13m flops)
#   ResNet50/res2c_branch2b/Conv2D (43.13m/43.13m flops)
#   ResNet50/res2a_branch2b/Conv2D (43.13m/43.13m flops)
#   ResNet50/res5a_branch1/Conv2D (41.94m/41.94m flops)
#   ResNet50/res4a_branch1/Conv2D (41.94m/41.94m flops)
#   ResNet50/res3a_branch1/Conv2D (41.94m/41.94m flops)
#   ResNet50/res3b_branch2a/Conv2D (20.97m/20.97m flops)
#   ResNet50/res3d_branch2c/Conv2D (20.97m/20.97m flops)
#   ResNet50/res3d_branch2a/Conv2D (20.97m/20.97m flops)
#   ResNet50/res4c_branch2a/Conv2D (20.97m/20.97m flops)
#   ResNet50/res3a_branch2c/Conv2D (20.97m/20.97m flops)
#   ResNet50/res3c_branch2c/Conv2D (20.97m/20.97m flops)
#   ResNet50/res4a_branch2c/Conv2D (20.97m/20.97m flops)
#   ResNet50/res3b_branch2c/Conv2D (20.97m/20.97m flops)
#   ResNet50/res4b_branch2a/Conv2D (20.97m/20.97m flops)
#   ResNet50/res3c_branch2a/Conv2D (20.97m/20.97m flops)
#   ResNet50/res4b_branch2c/Conv2D (20.97m/20.97m flops)
#   ResNet50/res5c_branch2c/Conv2D (20.97m/20.97m flops)
#   ResNet50/res5c_branch2a/Conv2D (20.97m/20.97m flops)
#   ResNet50/res5b_branch2c/Conv2D (20.97m/20.97m flops)
#   ResNet50/res5b_branch2a/Conv2D (20.97m/20.97m flops)
#   ResNet50/res5a_branch2c/Conv2D (20.97m/20.97m flops)
#   ResNet50/res4f_branch2c/Conv2D (20.97m/20.97m flops)
#   ResNet50/res4f_branch2a/Conv2D (20.97m/20.97m flops)
#   ResNet50/res4e_branch2c/Conv2D (20.97m/20.97m flops)
#   ResNet50/res4e_branch2a/Conv2D (20.97m/20.97m flops)
#   ResNet50/res4d_branch2c/Conv2D (20.97m/20.97m flops)
#   ResNet50/res4d_branch2a/Conv2D (20.97m/20.97m flops)
#   ResNet50/res4c_branch2c/Conv2D (20.97m/20.97m flops)
#   ResNet50/res2a_branch1/Conv2D (19.17m/19.17m flops)
#   ResNet50/res2c_branch2c/Conv2D (19.17m/19.17m flops)
#   ResNet50/res2a_branch2c/Conv2D (19.17m/19.17m flops)
#   ResNet50/res2c_branch2a/Conv2D (19.17m/19.17m flops)
#   ResNet50/res2b_branch2a/Conv2D (19.17m/19.17m flops)
#   ResNet50/res2b_branch2c/Conv2D (19.17m/19.17m flops)
#   ResNet50/res4a_branch2a/Conv2D (10.49m/10.49m flops)
#   ResNet50/res5a_branch2a/Conv2D (10.49m/10.49m flops)
#   ResNet50/res3a_branch2a/Conv2D (10.49m/10.49m flops)
#   ResNet50/res2a_branch2a/Conv2D (4.79m/4.79m flops)
#   ResNet50/max_pooling2d_3/MaxPool (336.96k/336.96k flops)
#   ResNet50/bn_conv1/FusedBatchNormV3 (328.06k/328.06k flops)
#   ResNet50/bn2b_branch2c/FusedBatchNormV3 (301.06k/301.06k flops)
#   ResNet50/bn2a_branch1/FusedBatchNormV3 (301.06k/301.06k flops)
#   ResNet50/bn2a_branch2c/FusedBatchNormV3 (301.06k/301.06k flops)
#   ResNet50/bn2c_branch2c/FusedBatchNormV3 (301.06k/301.06k flops)
#   ResNet50/bn3a_branch1/FusedBatchNormV3 (166.91k/166.91k flops)
#   ResNet50/bn3a_branch2c/FusedBatchNormV3 (166.91k/166.91k flops)
#   ResNet50/bn3b_branch2c/FusedBatchNormV3 (166.91k/166.91k flops)
#   ResNet50/bn3c_branch2c/FusedBatchNormV3 (166.91k/166.91k flops)
#   ResNet50/bn3d_branch2c/FusedBatchNormV3 (166.91k/166.91k flops)
#   ResNet50/conv1/BiasAdd (163.84k/163.84k flops)
#   ResNet50/res2b_branch2c/BiasAdd (149.76k/149.76k flops)
#   ResNet50/res2a_branch2c/BiasAdd (149.76k/149.76k flops)
#   ResNet50/add_49/add (149.76k/149.76k flops)
#   ResNet50/res2a_branch1/BiasAdd (149.76k/149.76k flops)
#   ResNet50/res2c_branch2c/BiasAdd (149.76k/149.76k flops)
#   ResNet50/add_48/add (149.76k/149.76k flops)
#   ResNet50/add_50/add (149.76k/149.76k flops)
#   ResNet50/bn4b_branch2c/FusedBatchNormV3 (88.06k/88.06k flops)
#   ResNet50/bn4a_branch2c/FusedBatchNormV3 (88.06k/88.06k flops)
#   ResNet50/bn4c_branch2c/FusedBatchNormV3 (88.06k/88.06k flops)
#   ResNet50/bn4a_branch1/FusedBatchNormV3 (88.06k/88.06k flops)
#   ResNet50/bn4d_branch2c/FusedBatchNormV3 (88.06k/88.06k flops)
#   ResNet50/bn4e_branch2c/FusedBatchNormV3 (88.06k/88.06k flops)
#   ResNet50/bn4f_branch2c/FusedBatchNormV3 (88.06k/88.06k flops)
#   ResNet50/add_51/add (81.92k/81.92k flops)
#   ResNet50/res3d_branch2c/BiasAdd (81.92k/81.92k flops)
#   ResNet50/add_53/add (81.92k/81.92k flops)
#   ResNet50/res3a_branch1/BiasAdd (81.92k/81.92k flops)
#   ResNet50/res3c_branch2c/BiasAdd (81.92k/81.92k flops)
#   ResNet50/add_52/add (81.92k/81.92k flops)
#   ResNet50/add_54/add (81.92k/81.92k flops)
#   ResNet50/res3a_branch2c/BiasAdd (81.92k/81.92k flops)
#   ResNet50/res3b_branch2c/BiasAdd (81.92k/81.92k flops)
#   ResNet50/bn2a_branch2a/FusedBatchNormV3 (75.26k/75.26k flops)
#   ResNet50/bn2a_branch2b/FusedBatchNormV3 (75.26k/75.26k flops)
#   ResNet50/bn2c_branch2b/FusedBatchNormV3 (75.26k/75.26k flops)
#   ResNet50/bn2c_branch2a/FusedBatchNormV3 (75.26k/75.26k flops)
#   ResNet50/bn2b_branch2b/FusedBatchNormV3 (75.26k/75.26k flops)
#   ResNet50/bn2b_branch2a/FusedBatchNormV3 (75.26k/75.26k flops)
#   ResNet50/bn5a_branch1/FusedBatchNormV3 (53.25k/53.25k flops)
#   ResNet50/bn5c_branch2c/FusedBatchNormV3 (53.25k/53.25k flops)
#   ResNet50/bn5b_branch2c/FusedBatchNormV3 (53.25k/53.25k flops)
#   ResNet50/bn5a_branch2c/FusedBatchNormV3 (53.25k/53.25k flops)
#   ResNet50/bn3c_branch2b/FusedBatchNormV3 (41.73k/41.73k flops)
#   ResNet50/bn3d_branch2b/FusedBatchNormV3 (41.73k/41.73k flops)
#   ResNet50/bn3d_branch2a/FusedBatchNormV3 (41.73k/41.73k flops)
#   ResNet50/bn3c_branch2a/FusedBatchNormV3 (41.73k/41.73k flops)
#   ResNet50/bn3b_branch2b/FusedBatchNormV3 (41.73k/41.73k flops)
#   ResNet50/bn3b_branch2a/FusedBatchNormV3 (41.73k/41.73k flops)
#   ResNet50/bn3a_branch2b/FusedBatchNormV3 (41.73k/41.73k flops)
#   ResNet50/bn3a_branch2a/FusedBatchNormV3 (41.73k/41.73k flops)
#   ResNet50/add_55/add (40.96k/40.96k flops)
#   ResNet50/add_56/add (40.96k/40.96k flops)
#   ResNet50/add_57/add (40.96k/40.96k flops)
#   ResNet50/add_58/add (40.96k/40.96k flops)
#   ResNet50/add_59/add (40.96k/40.96k flops)
#   ResNet50/res4f_branch2c/BiasAdd (40.96k/40.96k flops)
#   ResNet50/add_60/add (40.96k/40.96k flops)
#   ResNet50/res4e_branch2c/BiasAdd (40.96k/40.96k flops)
#   ResNet50/res4a_branch2c/BiasAdd (40.96k/40.96k flops)
#   ResNet50/res4d_branch2c/BiasAdd (40.96k/40.96k flops)
#   ResNet50/res4c_branch2c/BiasAdd (40.96k/40.96k flops)
#   ResNet50/res4a_branch1/BiasAdd (40.96k/40.96k flops)
#   ResNet50/res4b_branch2c/BiasAdd (40.96k/40.96k flops)
#   ResNet50/res2c_branch2b/BiasAdd (37.44k/37.44k flops)
#   ResNet50/res2c_branch2a/BiasAdd (37.44k/37.44k flops)
#   ResNet50/res2b_branch2b/BiasAdd (37.44k/37.44k flops)
#   ResNet50/res2b_branch2a/BiasAdd (37.44k/37.44k flops)
#   ResNet50/res2a_branch2b/BiasAdd (37.44k/37.44k flops)
#   ResNet50/res2a_branch2a/BiasAdd (37.44k/37.44k flops)
#   ResNet50/bn4f_branch2b/FusedBatchNormV3 (22.02k/22.02k flops)
#   ResNet50/bn4f_branch2a/FusedBatchNormV3 (22.02k/22.02k flops)
#   ResNet50/bn4c_branch2a/FusedBatchNormV3 (22.02k/22.02k flops)
#   ResNet50/bn4e_branch2b/FusedBatchNormV3 (22.02k/22.02k flops)
#   ResNet50/bn4c_branch2b/FusedBatchNormV3 (22.02k/22.02k flops)
#   ResNet50/bn4b_branch2a/FusedBatchNormV3 (22.02k/22.02k flops)
#   ResNet50/bn4a_branch2b/FusedBatchNormV3 (22.02k/22.02k flops)
#   ResNet50/bn4b_branch2b/FusedBatchNormV3 (22.02k/22.02k flops)
#   ResNet50/bn4a_branch2a/FusedBatchNormV3 (22.02k/22.02k flops)
#   ResNet50/bn4d_branch2a/FusedBatchNormV3 (22.02k/22.02k flops)
#   ResNet50/bn4d_branch2b/FusedBatchNormV3 (22.02k/22.02k flops)
#   ResNet50/bn4e_branch2a/FusedBatchNormV3 (22.02k/22.02k flops)
#   ResNet50/res3c_branch2a/BiasAdd (20.48k/20.48k flops)
#   ResNet50/res3c_branch2b/BiasAdd (20.48k/20.48k flops)
#   ResNet50/add_62/add (20.48k/20.48k flops)
#   ResNet50/res3a_branch2b/BiasAdd (20.48k/20.48k flops)
#   ResNet50/add_63/add (20.48k/20.48k flops)
#   ResNet50/res5c_branch2c/BiasAdd (20.48k/20.48k flops)
#   ResNet50/res5a_branch1/BiasAdd (20.48k/20.48k flops)
#   ResNet50/res3d_branch2a/BiasAdd (20.48k/20.48k flops)
#   ResNet50/res5b_branch2c/BiasAdd (20.48k/20.48k flops)
#   ResNet50/res3b_branch2a/BiasAdd (20.48k/20.48k flops)
#   ResNet50/res5a_branch2c/BiasAdd (20.48k/20.48k flops)
#   ResNet50/res3d_branch2b/BiasAdd (20.48k/20.48k flops)
#   ResNet50/res3b_branch2b/BiasAdd (20.48k/20.48k flops)
#   ResNet50/add_61/add (20.48k/20.48k flops)
#   ResNet50/res3a_branch2a/BiasAdd (20.48k/20.48k flops)
#   ResNet50/fc2/MatMul (16.38k/16.38k flops)
#   ResNet50/avg_pool/AvgPool (16.38k/16.38k flops)
#   ResNet50/bn5c_branch2b/FusedBatchNormV3 (13.31k/13.31k flops)
#   ResNet50/bn5b_branch2b/FusedBatchNormV3 (13.31k/13.31k flops)
#   ResNet50/bn5c_branch2a/FusedBatchNormV3 (13.31k/13.31k flops)
#   ResNet50/bn5b_branch2a/FusedBatchNormV3 (13.31k/13.31k flops)
#   ResNet50/bn5a_branch2a/FusedBatchNormV3 (13.31k/13.31k flops)
#   ResNet50/bn5a_branch2b/FusedBatchNormV3 (13.31k/13.31k flops)
#   ResNet50/res4f_branch2a/BiasAdd (10.24k/10.24k flops)
# ...
#   ResNet50/res4e_branch2c/BiasAdd (172.03k/172.03k flops)
#   ResNet50/res4a_branch2c/BiasAdd (172.03k/172.03k flops)
#   ResNet50/res4d_branch2c/BiasAdd (172.03k/172.03k flops)
#   ResNet50/res4c_branch2c/BiasAdd (172.03k/172.03k flops)
#   ResNet50/res4a_branch1/BiasAdd (172.03k/172.03k flops)
#   ResNet50/res4b_branch2c/BiasAdd (172.03k/172.03k flops)
#   ResNet50/res2c_branch2b/BiasAdd (165.44k/165.44k flops)
#   ResNet50/res2c_branch2a/BiasAdd (165.44k/165.44k flops)
#   ResNet50/res2b_branch2b/BiasAdd (165.44k/165.44k flops)
#   ResNet50/res2b_branch2a/BiasAdd (165.44k/165.44k flops)
#   ResNet50/res2a_branch2b/BiasAdd (165.44k/165.44k flops)
#   ResNet50/res2a_branch2a/BiasAdd (165.44k/165.44k flops)
#   ResNet50/bn4f_branch2b/FusedBatchNormV3 (87.55k/87.55k flops)
#   ResNet50/bn4f_branch2a/FusedBatchNormV3 (87.55k/87.55k flops)
#   ResNet50/bn4c_branch2a/FusedBatchNormV3 (87.55k/87.55k flops)
#   ResNet50/bn4e_branch2b/FusedBatchNormV3 (87.55k/87.55k flops)
#   ResNet50/bn4c_branch2b/FusedBatchNormV3 (87.55k/87.55k flops)
#   ResNet50/bn4b_branch2a/FusedBatchNormV3 (87.55k/87.55k flops)
#   ResNet50/bn4a_branch2b/FusedBatchNormV3 (87.55k/87.55k flops)
#   ResNet50/bn4b_branch2b/FusedBatchNormV3 (87.55k/87.55k flops)
#   ResNet50/bn4a_branch2a/FusedBatchNormV3 (87.55k/87.55k flops)
#   ResNet50/bn4d_branch2a/FusedBatchNormV3 (87.55k/87.55k flops)
#   ResNet50/bn4d_branch2b/FusedBatchNormV3 (87.55k/87.55k flops)
#   ResNet50/bn4e_branch2a/FusedBatchNormV3 (87.55k/87.55k flops)
#   ResNet50/res3c_branch2a/BiasAdd (86.02k/86.02k flops)
#   ResNet50/res3c_branch2b/BiasAdd (86.02k/86.02k flops)
#   ResNet50/add_558/add (86.02k/86.02k flops)
#   ResNet50/res3a_branch2b/BiasAdd (86.02k/86.02k flops)
#   ResNet50/add_559/add (86.02k/86.02k flops)
#   ResNet50/res5c_branch2c/BiasAdd (86.02k/86.02k flops)
#   ResNet50/res5a_branch1/BiasAdd (86.02k/86.02k flops)
#   ResNet50/res3d_branch2a/BiasAdd (86.02k/86.02k flops)
#   ResNet50/res5b_branch2c/BiasAdd (86.02k/86.02k flops)
#   ResNet50/res3b_branch2a/BiasAdd (86.02k/86.02k flops)
#   ResNet50/res5a_branch2c/BiasAdd (86.02k/86.02k flops)
#   ResNet50/res3d_branch2b/BiasAdd (86.02k/86.02k flops)
#   ResNet50/res3b_branch2b/BiasAdd (86.02k/86.02k flops)
#   ResNet50/add_557/add (86.02k/86.02k flops)
#   ResNet50/res3a_branch2a/BiasAdd (86.02k/86.02k flops)
#   ResNet50/fc2/MatMul (73.73k/73.73k flops)
#   ResNet50/avg_pool/AvgPool (73.73k/73.73k flops)
#   ResNet50/bn5c_branch2b/FusedBatchNormV3 (46.08k/46.08k flops)
#   ResNet50/bn5b_branch2b/FusedBatchNormV3 (46.08k/46.08k flops)
#   ResNet50/bn5c_branch2a/FusedBatchNormV3 (46.08k/46.08k flops)
#   ResNet50/bn5b_branch2a/FusedBatchNormV3 (46.08k/46.08k flops)
#   ResNet50/bn5a_branch2a/FusedBatchNormV3 (46.08k/46.08k flops)
#   ResNet50/bn5a_branch2b/FusedBatchNormV3 (46.08k/46.08k flops)
#   ResNet50/res4f_branch2a/BiasAdd (43.01k/43.01k flops)
#   ResNet50/res4a_branch2b/BiasAdd (43.01k/43.01k flops)
#   ResNet50/res4b_branch2a/BiasAdd (43.01k/43.01k flops)
#   ResNet50/res4a_branch2a/BiasAdd (43.01k/43.01k flops)
#   ResNet50/res4b_branch2b/BiasAdd (43.01k/43.01k flops)
#   ResNet50/res4c_branch2a/BiasAdd (43.01k/43.01k flops)
#   ResNet50/res4c_branch2b/BiasAdd (43.01k/43.01k flops)
#   ResNet50/res4d_branch2a/BiasAdd (43.01k/43.01k flops)
#   ResNet50/res4d_branch2b/BiasAdd (43.01k/43.01k flops)
#   ResNet50/res4e_branch2a/BiasAdd (43.01k/43.01k flops)
#   ResNet50/res4e_branch2b/BiasAdd (43.01k/43.01k flops)
#   ResNet50/res4f_branch2b/BiasAdd (43.01k/43.01k flops)
#   ResNet50/res5b_branch2a/BiasAdd (21.50k/21.50k flops)
#   ResNet50/res5a_branch2b/BiasAdd (21.50k/21.50k flops)
#   ResNet50/res5b_branch2b/BiasAdd (21.50k/21.50k flops)
#   ResNet50/res5a_branch2a/BiasAdd (21.50k/21.50k flops)
#   ResNet50/res5c_branch2a/BiasAdd (21.50k/21.50k flops)
#   ResNet50/res5c_branch2b/BiasAdd (21.50k/21.50k flops)
#   ResNet50/fc2/Softmax (10/10 flops)
#   ResNet50/fc2/BiasAdd (2/2 flops)
#
# ======================End of Report==========================
# 2022-03-05 09:19:59.980313: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-03-05 09:19:59.980431: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-03-05 09:19:59.987521: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.007ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/7.70b flops)
#   ResNet50/conv1/Conv2D (236.03m/236.03m flops)
#   ResNet50/res4e_branch2b/Conv2D (231.21m/231.21m flops)
#   ResNet50/res4b_branch2b/Conv2D (231.21m/231.21m flops)
#   ResNet50/res4a_branch2b/Conv2D (231.21m/231.21m flops)
#   ResNet50/res4c_branch2b/Conv2D (231.21m/231.21m flops)
#   ResNet50/res4d_branch2b/Conv2D (231.21m/231.21m flops)
#   ResNet50/res3d_branch2b/Conv2D (231.21m/231.21m flops)
#   ResNet50/res3c_branch2b/Conv2D (231.21m/231.21m flops)
#   ResNet50/res4f_branch2b/Conv2D (231.21m/231.21m flops)
#   ResNet50/res5a_branch2b/Conv2D (231.21m/231.21m flops)
#   ResNet50/res3a_branch2b/Conv2D (231.21m/231.21m flops)
#   ResNet50/res3b_branch2b/Conv2D (231.21m/231.21m flops)
#   ResNet50/res5c_branch2b/Conv2D (231.21m/231.21m flops)
#   ResNet50/res5b_branch2b/Conv2D (231.21m/231.21m flops)
#   ResNet50/res2b_branch2b/Conv2D (223.03m/223.03m flops)
#   ResNet50/res2c_branch2b/Conv2D (223.03m/223.03m flops)
#   ResNet50/res2a_branch2b/Conv2D (223.03m/223.03m flops)
#   ResNet50/res5a_branch1/Conv2D (205.52m/205.52m flops)
#   ResNet50/res4a_branch1/Conv2D (205.52m/205.52m flops)
#   ResNet50/res3a_branch1/Conv2D (205.52m/205.52m flops)
#   ResNet50/res3b_branch2a/Conv2D (102.76m/102.76m flops)
#   ResNet50/res3d_branch2c/Conv2D (102.76m/102.76m flops)
#   ResNet50/res3d_branch2a/Conv2D (102.76m/102.76m flops)
#   ResNet50/res4c_branch2a/Conv2D (102.76m/102.76m flops)
#   ResNet50/res3a_branch2c/Conv2D (102.76m/102.76m flops)
#   ResNet50/res3c_branch2c/Conv2D (102.76m/102.76m flops)
#   ResNet50/res4a_branch2c/Conv2D (102.76m/102.76m flops)
#   ResNet50/res3b_branch2c/Conv2D (102.76m/102.76m flops)
#   ResNet50/res4b_branch2a/Conv2D (102.76m/102.76m flops)
#   ResNet50/res3c_branch2a/Conv2D (102.76m/102.76m flops)
#   ResNet50/res4b_branch2c/Conv2D (102.76m/102.76m flops)
#   ResNet50/res5c_branch2c/Conv2D (102.76m/102.76m flops)
#   ResNet50/res5c_branch2a/Conv2D (102.76m/102.76m flops)
#   ResNet50/res5b_branch2c/Conv2D (102.76m/102.76m flops)
#   ResNet50/res5b_branch2a/Conv2D (102.76m/102.76m flops)
#   ResNet50/res5a_branch2c/Conv2D (102.76m/102.76m flops)
#   ResNet50/res4f_branch2c/Conv2D (102.76m/102.76m flops)
#   ResNet50/res4f_branch2a/Conv2D (102.76m/102.76m flops)
#   ResNet50/res4e_branch2c/Conv2D (102.76m/102.76m flops)
#   ResNet50/res4e_branch2a/Conv2D (102.76m/102.76m flops)
#   ResNet50/res4d_branch2c/Conv2D (102.76m/102.76m flops)
#   ResNet50/res4d_branch2a/Conv2D (102.76m/102.76m flops)
#   ResNet50/res4c_branch2c/Conv2D (102.76m/102.76m flops)
#   ResNet50/res2a_branch1/Conv2D (99.12m/99.12m flops)
#   ResNet50/res2c_branch2c/Conv2D (99.12m/99.12m flops)
#   ResNet50/res2a_branch2c/Conv2D (99.12m/99.12m flops)
#   ResNet50/res2c_branch2a/Conv2D (99.12m/99.12m flops)
#   ResNet50/res2b_branch2a/Conv2D (99.12m/99.12m flops)
#   ResNet50/res2b_branch2c/Conv2D (99.12m/99.12m flops)
#   ResNet50/res4a_branch2a/Conv2D (51.38m/51.38m flops)
#   ResNet50/res5a_branch2a/Conv2D (51.38m/51.38m flops)
#   ResNet50/res3a_branch2a/Conv2D (51.38m/51.38m flops)
#   ResNet50/res2a_branch2a/Conv2D (24.78m/24.78m flops)
#   ResNet50/max_pooling2d_35/MaxPool (1.74m/1.74m flops)
#   ResNet50/bn_conv1/FusedBatchNormV3 (1.61m/1.61m flops)
#   ResNet50/bn2b_branch2c/FusedBatchNormV3 (1.55m/1.55m flops)
#   ResNet50/bn2a_branch1/FusedBatchNormV3 (1.55m/1.55m flops)
#   ResNet50/bn2a_branch2c/FusedBatchNormV3 (1.55m/1.55m flops)
#   ResNet50/bn2c_branch2c/FusedBatchNormV3 (1.55m/1.55m flops)
#   ResNet50/bn3a_branch1/FusedBatchNormV3 (805.89k/805.89k flops)
#   ResNet50/bn3a_branch2c/FusedBatchNormV3 (805.89k/805.89k flops)
#   ResNet50/bn3b_branch2c/FusedBatchNormV3 (805.89k/805.89k flops)
#   ResNet50/bn3c_branch2c/FusedBatchNormV3 (805.89k/805.89k flops)
#   ResNet50/bn3d_branch2c/FusedBatchNormV3 (805.89k/805.89k flops)
#   ResNet50/conv1/BiasAdd (802.82k/802.82k flops)
#   ResNet50/res2b_branch2c/BiasAdd (774.40k/774.40k flops)
#   ResNet50/res2a_branch2c/BiasAdd (774.40k/774.40k flops)
#   ResNet50/add_561/add (774.40k/774.40k flops)
#   ResNet50/res2a_branch1/BiasAdd (774.40k/774.40k flops)
#   ResNet50/res2c_branch2c/BiasAdd (774.40k/774.40k flops)
#   ResNet50/add_560/add (774.40k/774.40k flops)
#   ResNet50/add_562/add (774.40k/774.40k flops)
#   ResNet50/bn4b_branch2c/FusedBatchNormV3 (407.55k/407.55k flops)
#   ResNet50/bn4a_branch2c/FusedBatchNormV3 (407.55k/407.55k flops)
#   ResNet50/bn4c_branch2c/FusedBatchNormV3 (407.55k/407.55k flops)
#   ResNet50/bn4a_branch1/FusedBatchNormV3 (407.55k/407.55k flops)
#   ResNet50/bn4d_branch2c/FusedBatchNormV3 (407.55k/407.55k flops)
#   ResNet50/bn4e_branch2c/FusedBatchNormV3 (407.55k/407.55k flops)
#   ResNet50/bn4f_branch2c/FusedBatchNormV3 (407.55k/407.55k flops)
#   ResNet50/add_563/add (401.41k/401.41k flops)
#   ResNet50/res3d_branch2c/BiasAdd (401.41k/401.41k flops)
#   ResNet50/add_565/add (401.41k/401.41k flops)
#   ResNet50/res3a_branch1/BiasAdd (401.41k/401.41k flops)
#   ResNet50/res3c_branch2c/BiasAdd (401.41k/401.41k flops)
#   ResNet50/add_564/add (401.41k/401.41k flops)
#   ResNet50/add_566/add (401.41k/401.41k flops)
#   ResNet50/res3a_branch2c/BiasAdd (401.41k/401.41k flops)
#   ResNet50/res3b_branch2c/BiasAdd (401.41k/401.41k flops)
#   ResNet50/bn2a_branch2a/FusedBatchNormV3 (387.58k/387.58k flops)
#   ResNet50/bn2a_branch2b/FusedBatchNormV3 (387.58k/387.58k flops)
#   ResNet50/bn2c_branch2b/FusedBatchNormV3 (387.58k/387.58k flops)
#   ResNet50/bn2c_branch2a/FusedBatchNormV3 (387.58k/387.58k flops)
#   ResNet50/bn2b_branch2b/FusedBatchNormV3 (387.58k/387.58k flops)
#   ResNet50/bn2b_branch2a/FusedBatchNormV3 (387.58k/387.58k flops)
#   ResNet50/bn5a_branch1/FusedBatchNormV3 (212.99k/212.99k flops)
#   ResNet50/bn5c_branch2c/FusedBatchNormV3 (212.99k/212.99k flops)
#   ResNet50/bn5b_branch2c/FusedBatchNormV3 (212.99k/212.99k flops)
#   ResNet50/bn5a_branch2c/FusedBatchNormV3 (212.99k/212.99k flops)
#   ResNet50/bn3c_branch2b/FusedBatchNormV3 (201.47k/201.47k flops)
#   ResNet50/bn3d_branch2b/FusedBatchNormV3 (201.47k/201.47k flops)
#   ResNet50/bn3d_branch2a/FusedBatchNormV3 (201.47k/201.47k flops)
#   ResNet50/bn3c_branch2a/FusedBatchNormV3 (201.47k/201.47k flops)
#   ResNet50/bn3b_branch2b/FusedBatchNormV3 (201.47k/201.47k flops)
#   ResNet50/bn3b_branch2a/FusedBatchNormV3 (201.47k/201.47k flops)
#   ResNet50/bn3a_branch2b/FusedBatchNormV3 (201.47k/201.47k flops)
#   ResNet50/bn3a_branch2a/FusedBatchNormV3 (201.47k/201.47k flops)
#   ResNet50/add_567/add (200.70k/200.70k flops)
#   ResNet50/add_568/add (200.70k/200.70k flops)
#   ResNet50/add_569/add (200.70k/200.70k flops)
#   ResNet50/add_570/add (200.70k/200.70k flops)
#   ResNet50/add_571/add (200.70k/200.70k flops)
#   ResNet50/res4f_branch2c/BiasAdd (200.70k/200.70k flops)
#   ResNet50/add_572/add (200.70k/200.70k flops)
#   ResNet50/res4e_branch2c/BiasAdd (200.70k/200.70k flops)
#   ResNet50/res4a_branch2c/BiasAdd (200.70k/200.70k flops)
#   ResNet50/res4d_branch2c/BiasAdd (200.70k/200.70k flops)
#   ResNet50/res4c_branch2c/BiasAdd (200.70k/200.70k flops)
#   ResNet50/res4a_branch1/BiasAdd (200.70k/200.70k flops)
#   ResNet50/res4b_branch2c/BiasAdd (200.70k/200.70k flops)
#   ResNet50/res2c_branch2b/BiasAdd (193.60k/193.60k flops)
#   ResNet50/res2c_branch2a/BiasAdd (193.60k/193.60k flops)
#   ResNet50/res2b_branch2b/BiasAdd (193.60k/193.60k flops)
#   ResNet50/res2b_branch2a/BiasAdd (193.60k/193.60k flops)
#   ResNet50/res2a_branch2b/BiasAdd (193.60k/193.60k flops)
#   ResNet50/res2a_branch2a/BiasAdd (193.60k/193.60k flops)
#   ResNet50/bn4f_branch2b/FusedBatchNormV3 (101.89k/101.89k flops)
#   ResNet50/bn4f_branch2a/FusedBatchNormV3 (101.89k/101.89k flops)
#   ResNet50/bn4c_branch2a/FusedBatchNormV3 (101.89k/101.89k flops)
#   ResNet50/bn4e_branch2b/FusedBatchNormV3 (101.89k/101.89k flops)
#   ResNet50/bn4c_branch2b/FusedBatchNormV3 (101.89k/101.89k flops)
#   ResNet50/bn4b_branch2a/FusedBatchNormV3 (101.89k/101.89k flops)
#   ResNet50/bn4a_branch2b/FusedBatchNormV3 (101.89k/101.89k flops)
#   ResNet50/bn4b_branch2b/FusedBatchNormV3 (101.89k/101.89k flops)
#   ResNet50/bn4a_branch2a/FusedBatchNormV3 (101.89k/101.89k flops)
#   ResNet50/bn4d_branch2a/FusedBatchNormV3 (101.89k/101.89k flops)
#   ResNet50/bn4d_branch2b/FusedBatchNormV3 (101.89k/101.89k flops)
#   ResNet50/bn4e_branch2a/FusedBatchNormV3 (101.89k/101.89k flops)
#   ResNet50/res3c_branch2a/BiasAdd (100.35k/100.35k flops)
#   ResNet50/res3c_branch2b/BiasAdd (100.35k/100.35k flops)
#   ResNet50/add_574/add (100.35k/100.35k flops)
#   ResNet50/res3a_branch2b/BiasAdd (100.35k/100.35k flops)
#   ResNet50/add_575/add (100.35k/100.35k flops)
#   ResNet50/res5c_branch2c/BiasAdd (100.35k/100.35k flops)
#   ResNet50/res5a_branch1/BiasAdd (100.35k/100.35k flops)
#   ResNet50/res3d_branch2a/BiasAdd (100.35k/100.35k flops)
#   ResNet50/res5b_branch2c/BiasAdd (100.35k/100.35k flops)
#   ResNet50/res3b_branch2a/BiasAdd (100.35k/100.35k flops)
#   ResNet50/res5a_branch2c/BiasAdd (100.35k/100.35k flops)
#   ResNet50/res3d_branch2b/BiasAdd (100.35k/100.35k flops)
#   ResNet50/res3b_branch2b/BiasAdd (100.35k/100.35k flops)
#   ResNet50/add_573/add (100.35k/100.35k flops)
#   ResNet50/res3a_branch2a/BiasAdd (100.35k/100.35k flops)
#   ResNet50/fc2/MatMul (73.73k/73.73k flops)
#   ResNet50/avg_pool/AvgPool (73.73k/73.73k flops)
#   ResNet50/bn5c_branch2b/FusedBatchNormV3 (53.25k/53.25k flops)
#   ResNet50/bn5b_branch2b/FusedBatchNormV3 (53.25k/53.25k flops)
#   ResNet50/bn5c_branch2a/FusedBatchNormV3 (53.25k/53.25k flops)
#   ResNet50/bn5b_branch2a/FusedBatchNormV3 (53.25k/53.25k flops)
#   ResNet50/bn5a_branch2a/FusedBatchNormV3 (53.25k/53.25k flops)
#   ResNet50/bn5a_branch2b/FusedBatchNormV3 (53.25k/53.25k flops)
#   ResNet50/res4f_branch2a/BiasAdd (50.18k/50.18k flops)
#   ResNet50/res4a_branch2b/BiasAdd (50.18k/50.18k flops)
#   ResNet50/res4b_branch2a/BiasAdd (50.18k/50.18k flops)
#   ResNet50/res4a_branch2a/BiasAdd (50.18k/50.18k flops)
#   ResNet50/res4b_branch2b/BiasAdd (50.18k/50.18k flops)
#   ResNet50/res4c_branch2a/BiasAdd (50.18k/50.18k flops)
#   ResNet50/res4c_branch2b/BiasAdd (50.18k/50.18k flops)
#   ResNet50/res4d_branch2a/BiasAdd (50.18k/50.18k flops)
#   ResNet50/res4d_branch2b/BiasAdd (50.18k/50.18k flops)
#   ResNet50/res4e_branch2a/BiasAdd (50.18k/50.18k flops)
#   ResNet50/res4e_branch2b/BiasAdd (50.18k/50.18k flops)
#   ResNet50/res4f_branch2b/BiasAdd (50.18k/50.18k flops)
#   ResNet50/res5b_branch2a/BiasAdd (25.09k/25.09k flops)
#   ResNet50/res5a_branch2b/BiasAdd (25.09k/25.09k flops)
#   ResNet50/res5b_branch2b/BiasAdd (25.09k/25.09k flops)
#   ResNet50/res5a_branch2a/BiasAdd (25.09k/25.09k flops)
#   ResNet50/res5c_branch2a/BiasAdd (25.09k/25.09k flops)
#   ResNet50/res5c_branch2b/BiasAdd (25.09k/25.09k flops)
#   ResNet50/fc2/Softmax (10/10 flops)
#   ResNet50/fc2/BiasAdd (2/2 flops)
#
# ======================End of Report==========================
