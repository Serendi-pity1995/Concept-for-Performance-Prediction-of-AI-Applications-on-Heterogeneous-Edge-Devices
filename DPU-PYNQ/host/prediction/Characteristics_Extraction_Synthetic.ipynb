# %%
import os
import csv
import numpy as np
import tensorflow as tf
import keras
from keras_flops import get_flops
from itertools import product

def get_total_number_of_neurons(model, include_output_layer):
    '''
    Args:
        model: Keras model
        include_output_layer: A boolean parameter. Whether or not to include output layer's neurons into the calculation

    Returns: number of neurons in the given model
    '''
    num_layers = len(model.layers)
    total_num_of_neurons = 0
    for layer_index in range(num_layers):
        layer = model.layers[layer_index]
        # since we multiply layer output dimensions, initial value is set to 1.
        num_neurons_in_layer = 1
        for i in range(1, len(layer.output.shape)):
            try:
                # when it is a valid layer to count neurons, an output dimension of the layer can be convertible to int.
                num_neurons_in_layer *= int(layer.output.shape[i])
            except Exception:
                # if the output dimension of layer cannot be convertible to int,
                # just pass that layer since it is not a valid layer to count neurons
                pass
        # if num_neurons_in_layer is not still 1, it means we have a valid layer to count neurons
        if not num_neurons_in_layer == 1:
            # when it is an output layer
            if layer_index == (num_layers - 1):
                if include_output_layer:
                    total_num_of_neurons += num_neurons_in_layer
            else:  # when it is not an output layer
                total_num_of_neurons += num_neurons_in_layer
    return total_num_of_neurons


with open("para_count_synthetic.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "step","number_of_layers", "FLOPs_G", "Total_params_M", "Memory_M", "total_num_of_neurons_M"],])

path = "../synthetic_h5" 
files= os.listdir(path) 
model_num = 1
input_shape_range =range(32,512,2)

for shape_x in input_shape_range:
    shape_y = shape_x
    for step in range(1,11):
        file = "synthetic_{input_x}_{input_y}_{step}.h5".format(input_x=shape_x,input_y=shape_y,step=step)
        if file in files: 
            model_name = str(file)
            if not os.path.isdir(file): 
                model = keras.models.load_model("../synthetic_h5/{}".format(model_name))
                num_neurons = get_total_number_of_neurons(model= model, include_output_layer= True)
                num_neurons_M = num_neurons/10**6    
                # how to compute the memory allocated by the activations of a model
                batch = 1
                shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
                else 1 for s in l.output_shape])) 
                for l in model.layers]))
                memory = (shapes_count * 4 * batch)/10**6
                print(memory)
                layers_length = len(model.layers)
                Total_params = round(model.count_params()/10 ** 6,2)
                FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
                with open("para_count_synthetic.csv","a+") as csvfile:
                    writer = csv.writer(csvfile)
                    writer.writerows([[model_num, shape_x, shape_y, step, layers_length, FLOPs, Total_params, memory, num_neurons_M],])

                    model_num = model_num + 1
# Out:
# 2022-05-16 04:47:23.759030: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-05-16 04:47:23.759061: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-05-16 04:47:24.827680: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-05-16 04:47:24.827711: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-16 04:47:24.827725: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2022-05-16 04:47:24.827860: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 9.899092
# WARNING:tensorflow:From /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py:5063: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# 2022-05-16 04:47:25.304098: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:47:25.304272: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:47:25.325399: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.008ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/564.79m flops)
#   mnist_classifier/conv2d_176/Conv2D (397.01m/397.01m flops)
#   mnist_classifier/conv2d_177/Conv2D (89.67m/89.67m flops)
#   mnist_classifier/conv2d_178/Conv2D (32.00m/32.00m flops)
#   mnist_classifier/conv2d_175/Conv2D (26.96m/26.96m flops)
#   mnist_classifier/conv2d_179/Conv2D (8.13m/8.13m flops)
#   mnist_classifier/dense_141/MatMul (3.36m/3.36m flops)
#   mnist_classifier/dense_140/MatMul (2.64m/2.64m flops)
#   mnist_classifier/conv2d_175/BiasAdd (1.50m/1.50m flops)
#   mnist_classifier/max_pooling2d_175/MaxPool (1.50m/1.50m flops)
#   mnist_classifier/dense_142/MatMul (1.06m/1.06m flops)
#   mnist_classifier/conv2d_176/BiasAdd (367.60k/367.60k flops)
#   mnist_classifier/max_pooling2d_176/MaxPool (358.11k/358.11k flops)
#   mnist_classifier/conv2d_177/BiasAdd (80.35k/80.35k flops)
#   mnist_classifier/max_pooling2d_177/MaxPool (80.35k/80.35k flops)
#   mnist_classifier/conv2d_178/BiasAdd (28.67k/28.67k flops)
#   mnist_classifier/max_pooling2d_178/MaxPool (28.67k/28.67k flops)
#   mnist_classifier/dense_143/MatMul (8.32k/8.32k flops)
#   mnist_classifier/max_pooling2d_179/MaxPool (4.03k/4.03k flops)
#   mnist_classifier/conv2d_179/BiasAdd (4.03k/4.03k flops)
#   mnist_classifier/dense_140/BiasAdd (1.31k/1.31k flops)
#   mnist_classifier/dense_141/BiasAdd (1.28k/1.28k flops)
#   mnist_classifier/dense_142/BiasAdd (416/416 flops)
#   mnist_classifier/dense_143/Softmax (50/50 flops)
#   mnist_classifier/dense_143/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 6.215412
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/300.40m flops)
#   mnist_classifier/conv2d_181/Conv2D (174.17m/174.17m flops)
#   mnist_classifier/conv2d_182/Conv2D (69.42m/69.42m flops)
#   mnist_classifier/conv2d_183/Conv2D (27.43m/27.43m flops)
#   mnist_classifier/conv2d_180/Conv2D (15.28m/15.28m flops)
#   mnist_classifier/conv2d_184/Conv2D (5.97m/5.97m flops)
#   mnist_classifier/dense_144/MatMul (2.60m/2.60m flops)
#   mnist_classifier/dense_145/MatMul (2.60m/2.60m flops)
#   mnist_classifier/conv2d_180/BiasAdd (848.78k/848.78k flops)
#   mnist_classifier/max_pooling2d_180/MaxPool (848.78k/848.78k flops)
#   mnist_classifier/dense_146/MatMul (442.37k/442.37k flops)
#   mnist_classifier/conv2d_181/BiasAdd (284.59k/284.59k flops)
#   mnist_classifier/max_pooling2d_181/MaxPool (277.25k/277.25k flops)
#   mnist_classifier/conv2d_182/BiasAdd (80.35k/80.35k flops)
#   mnist_classifier/max_pooling2d_182/MaxPool (80.35k/80.35k flops)
#   mnist_classifier/conv2d_183/BiasAdd (24.58k/24.58k flops)
#   mnist_classifier/max_pooling2d_183/MaxPool (24.58k/24.58k flops)
#   mnist_classifier/dense_147/MatMul (5.12k/5.12k flops)
#   mnist_classifier/max_pooling2d_184/MaxPool (3.46k/3.46k flops)
#   mnist_classifier/conv2d_184/BiasAdd (3.46k/3.46k flops)
#   mnist_classifier/dense_144/BiasAdd (1.50k/1.50k flops)
#   mnist_classifier/dense_145/BiasAdd (864/864 flops)
#   mnist_classifier/dense_146/BiasAdd (256/256 flops)
#   mnist_classifier/dense_147/Softmax (50/50 flops)
#   mnist_classifier/dense_147/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-05-16 04:47:25.656112: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:47:25.656198: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:47:25.657430: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 7.256676
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/391.05m flops)
#   mnist_classifier/conv2d_11/Conv2D (247.60m/247.60m flops)
#   mnist_classifier/conv2d_12/Conv2D (81.18m/81.18m flops)
#   mnist_classifier/conv2d_13/Conv2D (28.20m/28.20m flops)
#   mnist_classifier/conv2d_10/Conv2D (17.97m/17.97m flops)
#   mnist_classifier/conv2d_14/Conv2D (6.74m/6.74m flops)
#   mnist_classifier/dense_8/MatMul (3.47m/3.47m flops)
#   mnist_classifier/dense_9/MatMul (2.42m/2.42m flops)
#   mnist_classifier/conv2d_10/BiasAdd (998.56k/998.56k flops)
#   mnist_classifier/max_pooling2d_10/MaxPool (998.56k/998.56k flops)
#   mnist_classifier/dense_10/MatMul (573.44k/573.44k flops)
#   mnist_classifier/conv2d_11/BiasAdd (343.88k/343.88k flops)
#   mnist_classifier/max_pooling2d_11/MaxPool (335.01k/335.01k flops)
#   mnist_classifier/conv2d_12/BiasAdd (77.76k/77.76k flops)
#   mnist_classifier/max_pooling2d_12/MaxPool (77.76k/77.76k flops)
#   mnist_classifier/conv2d_13/BiasAdd (26.11k/26.11k flops)
#   mnist_classifier/max_pooling2d_13/MaxPool (26.11k/26.11k flops)
#   mnist_classifier/dense_11/MatMul (8.96k/8.96k flops)
#   mnist_classifier/max_pooling2d_14/MaxPool (3.67k/3.67k flops)
#   mnist_classifier/conv2d_14/BiasAdd (3.67k/3.67k flops)
#   mnist_classifier/dense_8/BiasAdd (1.89k/1.89k flops)
#   mnist_classifier/dense_9/BiasAdd (640/640 flops)
#   mnist_classifier/dense_10/BiasAdd (448/448 flops)
#   mnist_classifier/dense_11/Softmax (50/50 flops)
#   mnist_classifier/dense_11/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# 2022-05-16 04:47:25.892145: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:47:25.892252: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:47:25.893601: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 9.80702
# 2022-05-16 04:47:26.157966: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:47:26.158050: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:47:26.159257: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/540.96m flops)
#   mnist_classifier/conv2d_16/Conv2D (384.20m/384.20m flops)
#   mnist_classifier/conv2d_17/Conv2D (86.78m/86.78m flops)
#   mnist_classifier/conv2d_15/Conv2D (26.96m/26.96m flops)
#   mnist_classifier/conv2d_18/Conv2D (25.14m/25.14m flops)
#   mnist_classifier/conv2d_19/Conv2D (5.02m/5.02m flops)
#   mnist_classifier/dense_13/MatMul (4.33m/4.33m flops)
#   mnist_classifier/dense_12/MatMul (2.33m/2.33m flops)
#   mnist_classifier/dense_14/MatMul (2.26m/2.26m flops)
#   mnist_classifier/conv2d_15/BiasAdd (1.50m/1.50m flops)
#   mnist_classifier/max_pooling2d_15/MaxPool (1.50m/1.50m flops)
#   mnist_classifier/conv2d_16/BiasAdd (355.74k/355.74k flops)
#   mnist_classifier/max_pooling2d_16/MaxPool (346.56k/346.56k flops)
#   mnist_classifier/conv2d_17/BiasAdd (80.35k/80.35k flops)
#   mnist_classifier/max_pooling2d_17/MaxPool (80.35k/80.35k flops)
#   mnist_classifier/conv2d_18/BiasAdd (22.53k/22.53k flops)
#   mnist_classifier/max_pooling2d_18/MaxPool (22.53k/22.53k flops)
#   mnist_classifier/dense_15/MatMul (15.36k/15.36k flops)
#   mnist_classifier/max_pooling2d_19/MaxPool (3.17k/3.17k flops)
#   mnist_classifier/conv2d_19/BiasAdd (3.17k/3.17k flops)
#   mnist_classifier/dense_13/BiasAdd (1.47k/1.47k flops)
#   mnist_classifier/dense_12/BiasAdd (1.47k/1.47k flops)
#   mnist_classifier/dense_14/BiasAdd (768/768 flops)
#   mnist_classifier/dense_15/Softmax (50/50 flops)
#   mnist_classifier/dense_15/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 6.369516
# 2022-05-16 04:47:26.539255: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:47:26.539327: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:47:26.540568: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/258.88m flops)
#   mnist_classifier/conv2d_1/Conv2D (154.11m/154.11m flops)
#   mnist_classifier/conv2d_2/Conv2D (49.64m/49.64m flops)
#   mnist_classifier/conv2d_3/Conv2D (22.19m/22.19m flops)
#   mnist_classifier/conv2d/Conv2D (17.08m/17.08m flops)
#   mnist_classifier/conv2d_4/Conv2D (4.79m/4.79m flops)
#   mnist_classifier/dense_1/MatMul (4.69m/4.69m flops)
#   mnist_classifier/dense/MatMul (2.58m/2.58m flops)
#   mnist_classifier/dense_2/MatMul (1.26m/1.26m flops)
#   mnist_classifier/conv2d/BiasAdd (948.63k/948.63k flops)
#   mnist_classifier/max_pooling2d/MaxPool (948.63k/948.63k flops)
#   mnist_classifier/conv2d_1/BiasAdd (225.30k/225.30k flops)
#   mnist_classifier/max_pooling2d_1/MaxPool (219.49k/219.49k flops)
#   mnist_classifier/conv2d_2/BiasAdd (72.58k/72.58k flops)
#   mnist_classifier/max_pooling2d_2/MaxPool (72.58k/72.58k flops)
#   mnist_classifier/conv2d_3/BiasAdd (22.02k/22.02k flops)
#   mnist_classifier/max_pooling2d_3/MaxPool (22.02k/22.02k flops)
#   mnist_classifier/dense_3/MatMul (8.96k/8.96k flops)
#   mnist_classifier/max_pooling2d_4/MaxPool (3.10k/3.10k flops)
#   mnist_classifier/conv2d_4/BiasAdd (3.10k/3.10k flops)
#   mnist_classifier/dense/BiasAdd (1.66k/1.66k flops)
#   mnist_classifier/dense_1/BiasAdd (1.41k/1.41k flops)
#   mnist_classifier/dense_2/BiasAdd (448/448 flops)
#   mnist_classifier/dense_3/Softmax (50/50 flops)
#   mnist_classifier/dense_3/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 8.214236
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/437.49m flops)
#   mnist_classifier/conv2d_6/Conv2D (286.87m/286.87m flops)
#   mnist_classifier/conv2d_7/Conv2D (75.77m/75.77m flops)
#   mnist_classifier/conv2d_8/Conv2D (32.61m/32.61m flops)
#   mnist_classifier/conv2d_5/Conv2D (21.57m/21.57m flops)
#   mnist_classifier/conv2d_9/Conv2D (9.64m/9.64m flops)
#   mnist_classifier/dense_5/MatMul (3.10m/3.10m flops)
#   mnist_classifier/dense_4/MatMul (2.95m/2.95m flops)
#   mnist_classifier/dense_6/MatMul (1.70m/1.70m flops)
#   mnist_classifier/conv2d_5/BiasAdd (1.20m/1.20m flops)
#   mnist_classifier/max_pooling2d_5/MaxPool (1.20m/1.20m flops)
#   mnist_classifier/conv2d_6/BiasAdd (332.02k/332.02k flops)
#   mnist_classifier/max_pooling2d_6/MaxPool (323.46k/323.46k flops)
#   mnist_classifier/conv2d_7/BiasAdd (75.17k/75.17k flops)
#   mnist_classifier/max_pooling2d_7/MaxPool (75.17k/75.17k flops)
#   mnist_classifier/conv2d_8/BiasAdd (31.23k/31.23k flops)
#   mnist_classifier/max_pooling2d_8/MaxPool (31.23k/31.23k flops)
#   mnist_classifier/dense_7/MatMul (14.72k/14.72k flops)
#   mnist_classifier/max_pooling2d_9/MaxPool (4.39k/4.39k flops)
#   mnist_classifier/conv2d_9/BiasAdd (4.39k/4.39k flops)
#   mnist_classifier/dense_4/BiasAdd (1.34k/1.34k flops)
#   mnist_classifier/dense_5/BiasAdd (1.15k/1.15k flops)
#   mnist_classifier/dense_6/BiasAdd (736/736 flops)
#   mnist_classifier/dense_7/Softmax (50/50 flops)
#   mnist_classifier/dense_7/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# 2022-05-16 04:47:26.850664: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:47:26.850738: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:47:26.851994: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 8.876292
# 2022-05-16 04:47:27.140353: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:47:27.140425: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:47:27.141695: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/502.40m flops)
#   mnist_classifier/conv2d_11/Conv2D (344.07m/344.07m flops)
#   mnist_classifier/conv2d_12/Conv2D (89.67m/89.67m flops)
#   mnist_classifier/conv2d_13/Conv2D (26.86m/26.86m flops)
#   mnist_classifier/conv2d_10/Conv2D (23.37m/23.37m flops)
#   mnist_classifier/conv2d_14/Conv2D (5.73m/5.73m flops)
#   mnist_classifier/dense_9/MatMul (4.58m/4.58m flops)
#   mnist_classifier/dense_8/MatMul (2.82m/2.82m flops)
#   mnist_classifier/dense_10/MatMul (1.76m/1.76m flops)
#   mnist_classifier/conv2d_10/BiasAdd (1.30m/1.30m flops)
#   mnist_classifier/max_pooling2d_10/MaxPool (1.30m/1.30m flops)
#   mnist_classifier/conv2d_11/BiasAdd (367.60k/367.60k flops)
#   mnist_classifier/max_pooling2d_11/MaxPool (358.11k/358.11k flops)
#   mnist_classifier/conv2d_12/BiasAdd (80.35k/80.35k flops)
#   mnist_classifier/max_pooling2d_12/MaxPool (80.35k/80.35k flops)
#   mnist_classifier/conv2d_13/BiasAdd (24.06k/24.06k flops)
#   mnist_classifier/max_pooling2d_13/MaxPool (24.06k/24.06k flops)
#   mnist_classifier/dense_11/MatMul (12.80k/12.80k flops)
#   mnist_classifier/max_pooling2d_14/MaxPool (3.38k/3.38k flops)
#   mnist_classifier/conv2d_14/BiasAdd (3.38k/3.38k flops)
#   mnist_classifier/dense_8/BiasAdd (1.66k/1.66k flops)
#   mnist_classifier/dense_9/BiasAdd (1.38k/1.38k flops)
#   mnist_classifier/dense_10/BiasAdd (640/640 flops)
#   mnist_classifier/dense_11/Softmax (50/50 flops)
#   mnist_classifier/dense_11/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 6.394276
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/325.96m flops)
#   mnist_classifier/conv2d_16/Conv2D (203.20m/203.20m flops)
#   mnist_classifier/conv2d_17/Conv2D (78.38m/78.38m flops)
#   mnist_classifier/conv2d_18/Conv2D (18.25m/18.25m flops)
#   mnist_classifier/conv2d_15/Conv2D (15.28m/15.28m flops)
#   mnist_classifier/dense_13/MatMul (3.15m/3.15m flops)
#   mnist_classifier/conv2d_19/Conv2D (2.82m/2.82m flops)
#   mnist_classifier/dense_12/MatMul (1.67m/1.67m flops)
#   mnist_classifier/conv2d_15/BiasAdd (848.78k/848.78k flops)
#   mnist_classifier/max_pooling2d_15/MaxPool (848.78k/848.78k flops)
#   mnist_classifier/dense_14/MatMul (645.12k/645.12k flops)
#   mnist_classifier/conv2d_16/BiasAdd (332.02k/332.02k flops)
#   mnist_classifier/max_pooling2d_16/MaxPool (323.46k/323.46k flops)
#   mnist_classifier/conv2d_17/BiasAdd (77.76k/77.76k flops)
#   mnist_classifier/max_pooling2d_17/MaxPool (77.76k/77.76k flops)
#   mnist_classifier/conv2d_18/BiasAdd (16.90k/16.90k flops)
#   mnist_classifier/max_pooling2d_18/MaxPool (16.90k/16.90k flops)
#   mnist_classifier/dense_15/MatMul (5.76k/5.76k flops)
#   mnist_classifier/max_pooling2d_19/MaxPool (2.38k/2.38k flops)
#   mnist_classifier/conv2d_19/BiasAdd (2.38k/2.38k flops)
#   mnist_classifier/dense_12/BiasAdd (1.41k/1.41k flops)
#   mnist_classifier/dense_13/BiasAdd (1.12k/1.12k flops)
#   mnist_classifier/dense_14/BiasAdd (288/288 flops)
#   mnist_classifier/dense_15/Softmax (50/50 flops)
#   mnist_classifier/dense_15/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-05-16 04:47:27.458810: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:47:27.458880: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:47:27.460141: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 9.756492
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/525.57m flops)
#   mnist_classifier/conv2d_21/Conv2D (384.20m/384.20m flops)
#   mnist_classifier/conv2d_22/Conv2D (83.98m/83.98m flops)
#   mnist_classifier/conv2d_20/Conv2D (26.96m/26.96m flops)
#   mnist_classifier/conv2d_23/Conv2D (17.69m/17.69m flops)
#   mnist_classifier/conv2d_24/Conv2D (2.65m/2.65m flops)
#   mnist_classifier/dense_17/MatMul (2.51m/2.51m flops)
#   mnist_classifier/dense_18/MatMul (2.37m/2.37m flops)
#   mnist_classifier/conv2d_20/BiasAdd (1.50m/1.50m flops)
#   mnist_classifier/max_pooling2d_20/MaxPool (1.50m/1.50m flops)
#   mnist_classifier/dense_16/MatMul (1.29m/1.29m flops)
#   mnist_classifier/conv2d_21/BiasAdd (355.74k/355.74k flops)
#   mnist_classifier/max_pooling2d_21/MaxPool (346.56k/346.56k flops)
#   mnist_classifier/conv2d_22/BiasAdd (77.76k/77.76k flops)
#   mnist_classifier/max_pooling2d_22/MaxPool (77.76k/77.76k flops)
#   mnist_classifier/dense_19/MatMul (21.12k/21.12k flops)
#   mnist_classifier/conv2d_23/BiasAdd (16.38k/16.38k flops)
#   mnist_classifier/max_pooling2d_23/MaxPool (16.38k/16.38k flops)
#   mnist_classifier/max_pooling2d_24/MaxPool (2.30k/2.30k flops)
#   mnist_classifier/conv2d_24/BiasAdd (2.30k/2.30k flops)
#   mnist_classifier/dense_17/BiasAdd (1.12k/1.12k flops)
#   mnist_classifier/dense_16/BiasAdd (1.12k/1.12k flops)
#   mnist_classifier/dense_18/BiasAdd (1.06k/1.06k flops)
#   mnist_classifier/dense_19/Softmax (50/50 flops)
#   mnist_classifier/dense_19/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-05-16 04:47:27.676792: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:47:27.676865: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:47:27.678050: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 8.017108
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/429.27m flops)
#   mnist_classifier/conv2d_26/Conv2D (294.55m/294.55m flops)
#   mnist_classifier/conv2d_27/Conv2D (86.78m/86.78m flops)
#   mnist_classifier/conv2d_25/Conv2D (20.67m/20.67m flops)
#   mnist_classifier/conv2d_28/Conv2D (18.28m/18.28m flops)
#   mnist_classifier/conv2d_29/Conv2D (2.65m/2.65m flops)
#   mnist_classifier/dense_21/MatMul (1.44m/1.44m flops)
#   mnist_classifier/dense_20/MatMul (1.18m/1.18m flops)
#   mnist_classifier/conv2d_25/BiasAdd (1.15m/1.15m flops)
#   mnist_classifier/max_pooling2d_25/MaxPool (1.15m/1.15m flops)
#   mnist_classifier/dense_22/MatMul (495.62k/495.62k flops)
#   mnist_classifier/conv2d_26/BiasAdd (355.74k/355.74k flops)
#   mnist_classifier/max_pooling2d_26/MaxPool (346.56k/346.56k flops)
#   mnist_classifier/conv2d_27/BiasAdd (80.35k/80.35k flops)
#   mnist_classifier/max_pooling2d_27/MaxPool (80.35k/80.35k flops)
#   mnist_classifier/conv2d_28/BiasAdd (16.38k/16.38k flops)
#   mnist_classifier/max_pooling2d_28/MaxPool (16.38k/16.38k flops)
#   mnist_classifier/dense_23/MatMul (7.04k/7.04k flops)
#   mnist_classifier/max_pooling2d_29/MaxPool (2.30k/2.30k flops)
#   mnist_classifier/conv2d_29/BiasAdd (2.30k/2.30k flops)
#   mnist_classifier/dense_20/BiasAdd (1.02k/1.02k flops)
#   mnist_classifier/dense_21/BiasAdd (704/704 flops)
#   mnist_classifier/dense_22/BiasAdd (352/352 flops)
#   mnist_classifier/dense_23/Softmax (50/50 flops)
#   mnist_classifier/dense_23/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 13.392172
# 2022-05-16 04:47:27.905335: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:47:27.905406: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:47:27.906615: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/721.01m flops)
#   mnist_classifier/conv2d_21/Conv2D (488.22m/488.22m flops)
#   mnist_classifier/conv2d_22/Conv2D (120.99m/120.99m flops)
#   mnist_classifier/conv2d_23/Conv2D (49.10m/49.10m flops)
#   mnist_classifier/conv2d_20/Conv2D (36.39m/36.39m flops)
#   mnist_classifier/conv2d_24/Conv2D (13.94m/13.94m flops)
#   mnist_classifier/dense_16/MatMul (4.28m/4.28m flops)
#   mnist_classifier/conv2d_20/BiasAdd (2.02m/2.02m flops)
#   mnist_classifier/max_pooling2d_20/MaxPool (2.02m/2.02m flops)
#   mnist_classifier/dense_17/MatMul (1.79m/1.79m flops)
#   mnist_classifier/dense_18/MatMul (942.08k/942.08k flops)
#   mnist_classifier/conv2d_21/BiasAdd (484.34k/484.34k flops)
#   mnist_classifier/max_pooling2d_21/MaxPool (473.98k/473.98k flops)
#   mnist_classifier/conv2d_22/BiasAdd (120.03k/120.03k flops)
#   mnist_classifier/max_pooling2d_22/MaxPool (120.03k/120.03k flops)
#   mnist_classifier/conv2d_23/BiasAdd (44.00k/44.00k flops)
#   mnist_classifier/max_pooling2d_23/MaxPool (44.00k/44.00k flops)
#   mnist_classifier/dense_19/MatMul (12.80k/12.80k flops)
#   mnist_classifier/max_pooling2d_24/MaxPool (7.04k/7.04k flops)
#   mnist_classifier/conv2d_24/BiasAdd (7.04k/7.04k flops)
#   mnist_classifier/dense_16/BiasAdd (1.22k/1.22k flops)
#   mnist_classifier/dense_17/BiasAdd (736/736 flops)
#   mnist_classifier/dense_18/BiasAdd (640/640 flops)
#   mnist_classifier/dense_19/Softmax (50/50 flops)
#   mnist_classifier/dense_19/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# 2022-05-16 04:47:28.108774: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:47:28.108891: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:47:28.110190: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 12.456012
# 2022-05-16 04:47:28.422526: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:47:28.422599: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:47:28.423868: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/634.25m flops)
#   mnist_classifier/conv2d_26/Conv2D (420.96m/420.96m flops)
#   mnist_classifier/conv2d_27/Conv2D (112.35m/112.35m flops)
#   mnist_classifier/conv2d_28/Conv2D (40.18m/40.18m flops)
#   mnist_classifier/conv2d_25/Conv2D (33.79m/33.79m flops)
#   mnist_classifier/conv2d_29/Conv2D (9.33m/9.33m flops)
#   mnist_classifier/dense_20/MatMul (5.81m/5.81m flops)
#   mnist_classifier/dense_21/MatMul (4.90m/4.90m flops)
#   mnist_classifier/dense_22/MatMul (1.95m/1.95m flops)
#   mnist_classifier/conv2d_25/BiasAdd (1.88m/1.88m flops)
#   mnist_classifier/max_pooling2d_25/MaxPool (1.88m/1.88m flops)
#   mnist_classifier/conv2d_26/BiasAdd (449.75k/449.75k flops)
#   mnist_classifier/max_pooling2d_26/MaxPool (440.13k/440.13k flops)
#   mnist_classifier/conv2d_27/BiasAdd (120.03k/120.03k flops)
#   mnist_classifier/max_pooling2d_27/MaxPool (120.03k/120.03k flops)
#   mnist_classifier/conv2d_28/BiasAdd (36.00k/36.00k flops)
#   mnist_classifier/max_pooling2d_28/MaxPool (36.00k/36.00k flops)
#   mnist_classifier/dense_23/MatMul (16.00k/16.00k flops)
#   mnist_classifier/max_pooling2d_29/MaxPool (5.76k/5.76k flops)
#   mnist_classifier/conv2d_29/BiasAdd (5.76k/5.76k flops)
#   mnist_classifier/dense_20/BiasAdd (2.02k/2.02k flops)
#   mnist_classifier/dense_21/BiasAdd (1.22k/1.22k flops)
#   mnist_classifier/dense_22/BiasAdd (800/800 flops)
#   mnist_classifier/dense_23/Softmax (50/50 flops)
#   mnist_classifier/dense_23/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 8.873532
# 2022-05-16 04:47:28.892185: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:47:28.892256: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:47:28.893461: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/467.77m flops)
#   mnist_classifier/conv2d_31/Conv2D (259.05m/259.05m flops)
#   mnist_classifier/conv2d_32/Conv2D (105.10m/105.10m flops)
#   mnist_classifier/conv2d_33/Conv2D (49.28m/49.28m flops)
#   mnist_classifier/conv2d_30/Conv2D (20.79m/20.79m flops)
#   mnist_classifier/conv2d_34/Conv2D (16.04m/16.04m flops)
#   mnist_classifier/dense_24/MatMul (7.61m/7.61m flops)
#   mnist_classifier/dense_25/MatMul (4.64m/4.64m flops)
#   mnist_classifier/dense_26/MatMul (1.70m/1.70m flops)
#   mnist_classifier/conv2d_30/BiasAdd (1.16m/1.16m flops)
#   mnist_classifier/max_pooling2d_30/MaxPool (1.16m/1.16m flops)
#   mnist_classifier/conv2d_31/BiasAdd (449.75k/449.75k flops)
#   mnist_classifier/max_pooling2d_31/MaxPool (440.13k/440.13k flops)
#   mnist_classifier/conv2d_32/BiasAdd (112.29k/112.29k flops)
#   mnist_classifier/max_pooling2d_32/MaxPool (112.29k/112.29k flops)
#   mnist_classifier/conv2d_33/BiasAdd (47.20k/47.20k flops)
#   mnist_classifier/max_pooling2d_33/MaxPool (47.20k/47.20k flops)
#   mnist_classifier/dense_27/MatMul (14.72k/14.72k flops)
#   mnist_classifier/max_pooling2d_34/MaxPool (7.55k/7.55k flops)
#   mnist_classifier/conv2d_34/BiasAdd (7.55k/7.55k flops)
#   mnist_classifier/dense_24/BiasAdd (2.02k/2.02k flops)
#   mnist_classifier/dense_25/BiasAdd (1.15k/1.15k flops)
#   mnist_classifier/dense_26/BiasAdd (736/736 flops)
#   mnist_classifier/dense_27/Softmax (50/50 flops)
#   mnist_classifier/dense_27/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 14.190668
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/777.51m flops)
#   mnist_classifier/conv2d_36/Conv2D (560.46m/560.46m flops)
#   mnist_classifier/conv2d_37/Conv2D (129.63m/129.63m flops)
#   mnist_classifier/conv2d_35/Conv2D (38.99m/38.99m flops)
#   mnist_classifier/conv2d_38/Conv2D (31.25m/31.25m flops)
#   mnist_classifier/conv2d_39/Conv2D (5.64m/5.64m flops)
#   mnist_classifier/dense_28/MatMul (3.66m/3.66m flops)
#   mnist_classifier/conv2d_35/BiasAdd (2.17m/2.17m flops)
#   mnist_classifier/max_pooling2d_35/MaxPool (2.17m/2.17m flops)
#   mnist_classifier/dense_29/MatMul (1.88m/1.88m flops)
#   mnist_classifier/conv2d_36/BiasAdd (518.94k/518.94k flops)
#   mnist_classifier/max_pooling2d_36/MaxPool (507.84k/507.84k flops)
#   mnist_classifier/dense_30/MatMul (331.78k/331.78k flops)
#   mnist_classifier/conv2d_37/BiasAdd (120.03k/120.03k flops)
#   mnist_classifier/max_pooling2d_37/MaxPool (120.03k/120.03k flops)
#   mnist_classifier/conv2d_38/BiasAdd (28.00k/28.00k flops)
#   mnist_classifier/max_pooling2d_38/MaxPool (28.00k/28.00k flops)
#   mnist_classifier/dense_31/MatMul (5.76k/5.76k flops)
#   mnist_classifier/max_pooling2d_39/MaxPool (4.48k/4.48k flops)
#   mnist_classifier/conv2d_39/BiasAdd (4.48k/4.48k flops)
#   mnist_classifier/dense_28/BiasAdd (1.63k/1.63k flops)
#   mnist_classifier/dense_29/BiasAdd (576/576 flops)
#   mnist_classifier/dense_30/BiasAdd (288/288 flops)
#   mnist_classifier/dense_31/Softmax (50/50 flops)
#   mnist_classifier/dense_31/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-05-16 04:47:29.327070: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:47:29.327150: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:47:29.328381: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 10.478108
# 2022-05-16 04:47:29.563833: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:47:29.563905: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:47:29.565142: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# ...
# 94.648108
# 2022-05-16 04:48:47.254610: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:48:47.254690: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:48:47.256276: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/5.74b flops)
#   mnist_classifier/conv2d_306/Conv2D (3.89b/3.89b flops)
#   mnist_classifier/conv2d_307/Conv2D (931.05m/931.05m flops)
#   mnist_classifier/conv2d_308/Conv2D (398.97m/398.97m flops)
#   mnist_classifier/conv2d_305/Conv2D (254.99m/254.99m flops)
#   mnist_classifier/conv2d_309/Conv2D (158.14m/158.14m flops)
#   mnist_classifier/dense_244/MatMul (66.58m/66.58m flops)
#   mnist_classifier/max_pooling2d_305/MaxPool (14.17m/14.17m flops)
#   mnist_classifier/conv2d_305/BiasAdd (14.17m/14.17m flops)
#   mnist_classifier/dense_245/MatMul (3.98m/3.98m flops)
#   mnist_classifier/conv2d_306/BiasAdd (3.48m/3.48m flops)
#   mnist_classifier/max_pooling2d_306/MaxPool (3.45m/3.45m flops)
#   mnist_classifier/dense_246/MatMul (1.25m/1.25m flops)
#   mnist_classifier/conv2d_307/BiasAdd (834.27k/834.27k flops)
#   mnist_classifier/max_pooling2d_307/MaxPool (834.27k/834.27k flops)
#   mnist_classifier/conv2d_308/BiasAdd (357.50k/357.50k flops)
#   mnist_classifier/max_pooling2d_308/MaxPool (357.50k/357.50k flops)
#   mnist_classifier/max_pooling2d_309/MaxPool (77.06k/77.06k flops)
#   mnist_classifier/conv2d_309/BiasAdd (77.06k/77.06k flops)
#   mnist_classifier/dense_247/MatMul (10.88k/10.88k flops)
#   mnist_classifier/dense_244/BiasAdd (1.73k/1.73k flops)
#   mnist_classifier/dense_245/BiasAdd (1.15k/1.15k flops)
#   mnist_classifier/dense_246/BiasAdd (544/544 flops)
#   mnist_classifier/dense_247/Softmax (50/50 flops)
#   mnist_classifier/dense_247/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 65.669244
# 2022-05-16 04:48:50.150645: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:48:50.150717: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:48:50.152321: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/3.51b flops)
#   mnist_classifier/conv2d_311/Conv2D (1.94b/1.94b flops)
#   mnist_classifier/conv2d_312/Conv2D (720.81m/720.81m flops)
#   mnist_classifier/conv2d_313/Conv2D (412.97m/412.97m flops)
#   mnist_classifier/conv2d_314/Conv2D (169.43m/169.43m flops)
#   mnist_classifier/conv2d_310/Conv2D (164.51m/164.51m flops)
#   mnist_classifier/dense_248/MatMul (71.47m/71.47m flops)
#   mnist_classifier/max_pooling2d_310/MaxPool (9.14m/9.14m flops)
#   mnist_classifier/conv2d_310/BiasAdd (9.14m/9.14m flops)
#   mnist_classifier/dense_249/MatMul (3.33m/3.33m flops)
#   mnist_classifier/conv2d_311/BiasAdd (2.70m/2.70m flops)
#   mnist_classifier/max_pooling2d_311/MaxPool (2.67m/2.67m flops)
#   mnist_classifier/dense_250/MatMul (1.60m/1.60m flops)
#   mnist_classifier/conv2d_312/BiasAdd (834.27k/834.27k flops)
#   mnist_classifier/max_pooling2d_312/MaxPool (834.27k/834.27k flops)
#   mnist_classifier/conv2d_313/BiasAdd (370.05k/370.05k flops)
#   mnist_classifier/max_pooling2d_313/MaxPool (370.05k/370.05k flops)
#   mnist_classifier/max_pooling2d_314/MaxPool (79.77k/79.77k flops)
#   mnist_classifier/conv2d_314/BiasAdd (79.77k/79.77k flops)
#   mnist_classifier/dense_251/MatMul (17.28k/17.28k flops)
#   mnist_classifier/dense_248/BiasAdd (1.79k/1.79k flops)
#   mnist_classifier/dense_249/BiasAdd (928/928 flops)
#   mnist_classifier/dense_250/BiasAdd (864/864 flops)
#   mnist_classifier/dense_251/Softmax (50/50 flops)
#   mnist_classifier/dense_251/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 88.958988
# 2022-05-16 04:48:53.244709: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:48:53.244780: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:48:53.246330: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/5.19b flops)
#   mnist_classifier/conv2d_316/Conv2D (3.40b/3.40b flops)
#   mnist_classifier/conv2d_317/Conv2D (870.98m/870.98m flops)
#   mnist_classifier/conv2d_318/Conv2D (398.97m/398.97m flops)
#   mnist_classifier/conv2d_315/Conv2D (238.54m/238.54m flops)
#   mnist_classifier/conv2d_319/Conv2D (158.14m/158.14m flops)
#   mnist_classifier/dense_252/MatMul (77.68m/77.68m flops)
#   mnist_classifier/max_pooling2d_315/MaxPool (13.25m/13.25m flops)
#   mnist_classifier/conv2d_315/BiasAdd (13.25m/13.25m flops)
#   mnist_classifier/dense_253/MatMul (6.19m/6.19m flops)
#   mnist_classifier/conv2d_316/BiasAdd (3.26m/3.26m flops)
#   mnist_classifier/max_pooling2d_316/MaxPool (3.23m/3.23m flops)
#   mnist_classifier/dense_254/MatMul (1.18m/1.18m flops)
#   mnist_classifier/conv2d_317/BiasAdd (834.27k/834.27k flops)
#   mnist_classifier/max_pooling2d_317/MaxPool (834.27k/834.27k flops)
#   mnist_classifier/conv2d_318/BiasAdd (357.50k/357.50k flops)
#   mnist_classifier/max_pooling2d_318/MaxPool (357.50k/357.50k flops)
#   mnist_classifier/max_pooling2d_319/MaxPool (77.06k/77.06k flops)
#   mnist_classifier/conv2d_319/BiasAdd (77.06k/77.06k flops)
#   mnist_classifier/dense_255/MatMul (7.68k/7.68k flops)
#   mnist_classifier/dense_252/BiasAdd (2.02k/2.02k flops)
#   mnist_classifier/dense_253/BiasAdd (1.54k/1.54k flops)
#   mnist_classifier/dense_254/BiasAdd (384/384 flops)
#   mnist_classifier/dense_255/Softmax (50/50 flops)
#   mnist_classifier/dense_255/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 72.550532
# 2022-05-16 04:48:56.416042: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:48:56.416116: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:48:56.417698: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/4.14b flops)
#   mnist_classifier/conv2d_321/Conv2D (2.58b/2.58b flops)
#   mnist_classifier/conv2d_322/Conv2D (842.88m/842.88m flops)
#   mnist_classifier/conv2d_323/Conv2D (338.69m/338.69m flops)
#   mnist_classifier/conv2d_320/Conv2D (180.96m/180.96m flops)
#   mnist_classifier/conv2d_324/Conv2D (121.68m/121.68m flops)
#   mnist_classifier/dense_256/MatMul (40.02m/40.02m flops)
#   mnist_classifier/max_pooling2d_320/MaxPool (10.05m/10.05m flops)
#   mnist_classifier/conv2d_320/BiasAdd (10.05m/10.05m flops)
#   mnist_classifier/conv2d_321/BiasAdd (3.26m/3.26m flops)
#   mnist_classifier/max_pooling2d_321/MaxPool (3.23m/3.23m flops)
#   mnist_classifier/dense_257/MatMul (2.58m/2.58m flops)
#   mnist_classifier/dense_258/MatMul (1.60m/1.60m flops)
#   mnist_classifier/conv2d_322/BiasAdd (807.36k/807.36k flops)
#   mnist_classifier/max_pooling2d_322/MaxPool (807.36k/807.36k flops)
#   mnist_classifier/conv2d_323/BiasAdd (313.60k/313.60k flops)
#   mnist_classifier/max_pooling2d_323/MaxPool (313.60k/313.60k flops)
#   mnist_classifier/max_pooling2d_324/MaxPool (67.60k/67.60k flops)
#   mnist_classifier/conv2d_324/BiasAdd (67.60k/67.60k flops)
#   mnist_classifier/dense_259/MatMul (14.72k/14.72k flops)
#   mnist_classifier/dense_256/BiasAdd (1.18k/1.18k flops)
#   mnist_classifier/dense_257/BiasAdd (1.09k/1.09k flops)
#   mnist_classifier/dense_258/BiasAdd (736/736 flops)
#   mnist_classifier/dense_259/Softmax (50/50 flops)
#   mnist_classifier/dense_259/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 91.607796
# 2022-05-16 04:48:58.120667: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:48:58.120777: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:48:58.122421: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/5.34b flops)
#   mnist_classifier/conv2d_326/Conv2D (3.76b/3.76b flops)
#   mnist_classifier/conv2d_327/Conv2D (931.05m/931.05m flops)
#   mnist_classifier/conv2d_328/Conv2D (265.98m/265.98m flops)
#   mnist_classifier/conv2d_325/Conv2D (246.76m/246.76m flops)
#   mnist_classifier/conv2d_329/Conv2D (70.28m/70.28m flops)
#   mnist_classifier/dense_260/MatMul (30.41m/30.41m flops)
#   mnist_classifier/max_pooling2d_325/MaxPool (13.71m/13.71m flops)
#   mnist_classifier/conv2d_325/BiasAdd (13.71m/13.71m flops)
#   mnist_classifier/conv2d_326/BiasAdd (3.48m/3.48m flops)
#   mnist_classifier/max_pooling2d_326/MaxPool (3.45m/3.45m flops)
#   mnist_classifier/dense_261/MatMul (1.44m/1.44m flops)
#   mnist_classifier/conv2d_327/BiasAdd (834.27k/834.27k flops)
#   mnist_classifier/max_pooling2d_327/MaxPool (834.27k/834.27k flops)
#   mnist_classifier/dense_262/MatMul (311.30k/311.30k flops)
#   mnist_classifier/conv2d_328/BiasAdd (238.34k/238.34k flops)
#   mnist_classifier/max_pooling2d_328/MaxPool (238.34k/238.34k flops)
#   mnist_classifier/max_pooling2d_329/MaxPool (51.38k/51.38k flops)
#   mnist_classifier/conv2d_329/BiasAdd (51.38k/51.38k flops)
#   mnist_classifier/dense_263/MatMul (5.12k/5.12k flops)
#   mnist_classifier/dense_260/BiasAdd (1.18k/1.18k flops)
#   mnist_classifier/dense_261/BiasAdd (608/608 flops)
#   mnist_classifier/dense_262/BiasAdd (256/256 flops)
#   mnist_classifier/dense_263/Softmax (50/50 flops)
#   mnist_classifier/dense_263/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
