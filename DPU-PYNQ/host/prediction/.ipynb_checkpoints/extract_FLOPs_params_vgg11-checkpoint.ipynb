# %%
import os
import csv
import numpy as np
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, ZeroPadding2D, Dropout, Activation
from itertools import product
from keras_flops import get_flops
print("TensorFlow version:", tf.__version__)

model_num = 1
input_shape_range =range(32,64,32)

with open("para_count_vgg11.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "FLOPs", "Total_params", "Memory"],])
          
for shape_x in input_shape_range:
    
    shape_y = shape_x

    inputs = Input(shape=(shape_x, shape_y, 1))
    
    zeroPadding1 = ZeroPadding2D(padding=1)(inputs)

    conv1 = Conv2D(64, (3,3), padding='same', activation='relu')(zeroPadding1)
    pool1 = MaxPooling2D(pool_size=2)(conv1)
    
    zeroPadding2 = ZeroPadding2D(padding=1)(pool1)

    conv2 = Conv2D(128, (3,3), padding='same', activation='relu')(zeroPadding2)
    pool2 = MaxPooling2D(pool_size=2)(conv2)

    zeroPadding3 = ZeroPadding2D(padding=1)(pool2)
    conv3 = Conv2D(256, (3,3), padding='same', activation='relu')(zeroPadding3)
                                 
    zeroPadding4 = ZeroPadding2D(padding=1)(conv3)
    conv4 = Conv2D(256, (3,3), padding='same', activation='relu')(zeroPadding4)
    pool3 = MaxPooling2D(pool_size=2)(conv4)
                                 
    zeroPadding5 = ZeroPadding2D(padding=1)(pool3)
    conv5 = Conv2D(512, (3,3), padding='same', activation='relu')(zeroPadding5)
                                 
    zeroPadding6 = ZeroPadding2D(padding=1)(conv5)
    conv6 = Conv2D(512, (3,3), padding='same', activation='relu')(zeroPadding6)
    pool4 = MaxPooling2D(pool_size=2)(conv6)

    zeroPadding7 = ZeroPadding2D(padding=1)(pool4)
    conv7 = Conv2D(512, (3,3), padding='same', activation='relu')(zeroPadding7)
                                 
    zeroPadding8 = ZeroPadding2D(padding=1)(conv7)
    conv8 = Conv2D(512, (3,3), padding='same', activation='relu')(zeroPadding8)
    pool5 = MaxPooling2D(pool_size=2)(conv8)

    conv9 = Conv2D(4096, (7,7), padding='same', activation='relu')(pool5)
    drop1 = Dropout(0.5)(conv9)
    
    conv10 = Conv2D(4096, (1,1), padding='same', activation='relu')(pool5)
    drop2 = Dropout(0.5)(conv10)
                        
    conv11 = Conv2D(10, (1,1))(drop2)

    flat = Flatten()(conv11)

    outputs = Activation('softmax')(flat)


    model = Model(inputs=inputs, outputs=outputs)
    # how to compute the memory allocated by the activations of a model
    batch = 1
    shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
    else 1 for s in l.output_shape])) 
    for l in model.layers]))
    memory = (shapes_count * 4 * batch)/10**6
    print(memory)
    
    Total_params = round(model.count_params()/10 ** 6,2)
    FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
    with open("para_count_vgg11.csv","a+") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerows([[model_num, shape_x, shape_y, FLOPs, Total_params, memory],])

        model_num = model_num + 1
# Out:
# TensorFlow version: 2.6.0
# 3.010964
# 2022-04-04 09:47:23.623046: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-04 09:47:23.623164: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-04 09:47:23.624554: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.63b flops)
#   model_7/conv2d_82/Conv2D (471.86m/471.86m flops)
#   model_7/conv2d_84/Conv2D (382.21m/382.21m flops)
#   model_7/conv2d_83/Conv2D (231.21m/231.21m flops)
#   model_7/conv2d_80/Conv2D (199.36m/199.36m flops)
#   model_7/conv2d_81/Conv2D (150.99m/150.99m flops)
#   model_7/conv2d_79/Conv2D (71.37m/71.37m flops)
#   model_7/conv2d_86/Conv2D (67.11m/67.11m flops)
#   model_7/conv2d_78/Conv2D (53.23m/53.23m flops)
#   model_7/conv2d_77/Conv2D (1.33m/1.33m flops)
#   model_7/conv2d_87/Conv2D (1.31m/1.31m flops)
#   model_7/conv2d_77/BiasAdd (73.98k/73.98k flops)
#   model_7/max_pooling2d_35/MaxPool (73.98k/73.98k flops)
#   model_7/conv2d_86/BiasAdd (65.54k/65.54k flops)
#   model_7/conv2d_82/BiasAdd (51.20k/51.20k flops)
#   model_7/max_pooling2d_38/MaxPool (51.20k/51.20k flops)
#   model_7/conv2d_78/BiasAdd (46.21k/46.21k flops)
#   model_7/conv2d_80/BiasAdd (43.26k/43.26k flops)
#   model_7/max_pooling2d_36/MaxPool (41.47k/41.47k flops)
#   model_7/conv2d_84/BiasAdd (41.47k/41.47k flops)
#   model_7/max_pooling2d_37/MaxPool (36.86k/36.86k flops)
#   model_7/max_pooling2d_39/MaxPool (32.77k/32.77k flops)
#   model_7/conv2d_81/BiasAdd (32.77k/32.77k flops)
#   model_7/conv2d_79/BiasAdd (30.98k/30.98k flops)
#   model_7/conv2d_83/BiasAdd (25.09k/25.09k flops)
#   model_7/activation_7/Softmax (800/800 flops)
#   model_7/conv2d_87/BiasAdd (160/160 flops)
#
# ======================End of Report==========================

# %%
import os
import csv
import numpy as np
import keras
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, ZeroPadding2D, Dropout, Activation
from itertools import product
from keras_flops import get_flops
def get_total_number_of_neurons(model, include_output_layer):
    '''
    Args:
        model: Keras model
        include_output_layer: A boolean parameter. Whether or not to include output layer's neurons into the calculation

    Returns: number of neurons in the given model
    '''
    num_layers = len(model.layers)
    total_num_of_neurons = 0
    for layer_index in range(num_layers):
        layer = model.layers[layer_index]
        # since we multiply layer output dimensions, initial value is set to 1.
        num_neurons_in_layer = 1
        for i in range(1, len(layer.output.shape)):
            try:
                # when it is a valid layer to count neurons, an output dimension of the layer can be convertible to int.
                num_neurons_in_layer *= int(layer.output.shape[i])
            except Exception:
                # if the output dimension of layer cannot be convertible to int,
                # just pass that layer since it is not a valid layer to count neurons
                pass
        # if num_neurons_in_layer is not still 1, it means we have a valid layer to count neurons
        if not num_neurons_in_layer == 1:
            # when it is an output layer
            if layer_index == (num_layers - 1):
                if include_output_layer:
                    total_num_of_neurons += num_neurons_in_layer
            else:  # when it is not an output layer
                total_num_of_neurons += num_neurons_in_layer
    return total_num_of_neurons
model_num = 1
input_shape_range =range(32,512,2)

with open("para_count_vgg11.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "step","number_of_layers", "FLOPs_G", "Total_params_M", "Memory_M", "total_num_of_neurons_M"],])

path = "../vgg11_h5" #文件夹目录
files= os.listdir(path) #得到文件夹下的所有文件名称
for shape_x in input_shape_range:
    shape_y = shape_x
    for step in range(1,11):
        file = "vgg11_{input_x}_{input_y}_{step}.h5".format(input_x=shape_x,input_y=shape_y,step=step)
        if file in files: #遍历文件夹
            model_name = str(file)
            if not os.path.isdir(file): #判断是否是文件夹，不是文件夹才打开
                model = keras.models.load_model("../vgg11_h5/{}".format(model_name))
                num_neurons = get_total_number_of_neurons(model= model, include_output_layer= True)
#                 print("total_number_of_neurons:",num_neurons/1000000,"M")
                num_neurons_M = num_neurons/10**6
                # how to compute the memory allocated by the activations of a model
                batch = 1
                shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
                else 1 for s in l.output_shape])) 
                for l in model.layers]))
                memory = (shapes_count * 4 * batch)/10**6
                print(memory)
                layers_length = len(model.layers)
                Total_params = round(model.count_params()/10 ** 6,2)
                FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
                with open("para_count_vgg11.csv","a+") as csvfile:
                    writer = csv.writer(csvfile)
                    writer.writerows([[model_num, shape_x, shape_y, step, layers_length, FLOPs, Total_params, memory, num_neurons_M],])

                    model_num = model_num + 1
# Out:
# 2022-05-14 14:25:11.508796: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-05-14 14:25:11.508827: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-05-14 14:25:12.718546: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-05-14 14:25:12.718577: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-14 14:25:12.718594: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2022-05-14 14:25:12.718723: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.883084
# WARNING:tensorflow:From /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py:5063: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# 2022-05-14 14:25:13.255436: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:13.255584: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:13.277914: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.007ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/912.58m flops)
#   model_24/conv2d_269/Conv2D (265.42m/265.42m flops)
#   model_24/conv2d_271/Conv2D (184.32m/184.32m flops)
#   model_24/conv2d_267/Conv2D (133.17m/133.17m flops)
#   model_24/conv2d_270/Conv2D (117.96m/117.96m flops)
#   model_24/conv2d_268/Conv2D (92.16m/92.16m flops)
#   model_24/conv2d_266/Conv2D (51.84m/51.84m flops)
#   model_24/conv2d_265/Conv2D (41.99m/41.99m flops)
#   model_24/conv2d_273/Conv2D (22.53m/22.53m flops)
#   model_24/conv2d_264/Conv2D (1.80m/1.80m flops)
#   model_24/conv2d_274/Conv2D (704.00k/704.00k flops)
#   model_24/max_pooling2d_120/MaxPool (100.00k/100.00k flops)
#   model_24/conv2d_264/BiasAdd (100.00k/100.00k flops)
#   model_24/conv2d_265/BiasAdd (58.32k/58.32k flops)
#   model_24/max_pooling2d_121/MaxPool (54.08k/54.08k flops)
#   model_24/conv2d_267/BiasAdd (46.24k/46.24k flops)
#   model_24/conv2d_269/BiasAdd (46.08k/46.08k flops)
#   model_24/max_pooling2d_123/MaxPool (46.08k/46.08k flops)
#   model_24/max_pooling2d_122/MaxPool (40.96k/40.96k flops)
#   model_24/conv2d_266/BiasAdd (36.00k/36.00k flops)
#   model_24/conv2d_273/BiasAdd (35.20k/35.20k flops)
#   model_24/max_pooling2d_124/MaxPool (32.00k/32.00k flops)
#   model_24/conv2d_271/BiasAdd (32.00k/32.00k flops)
#   model_24/conv2d_268/BiasAdd (32.00k/32.00k flops)
#   model_24/conv2d_270/BiasAdd (20.48k/20.48k flops)
#   model_24/dense_24/MatMul (5.00k/5.00k flops)
#   model_24/conv2d_274/BiasAdd (250/250 flops)
#   model_24/dense_24/Softmax (50/50 flops)
#   model_24/dense_24/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 3.580172
# 2022-05-14 14:25:13.760141: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:13.760232: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:13.761679: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.33b flops)
#   model_25/conv2d_280/Conv2D (382.21m/382.21m flops)
#   model_25/conv2d_282/Conv2D (265.42m/265.42m flops)
#   model_25/conv2d_278/Conv2D (191.77m/191.77m flops)
#   model_25/conv2d_281/Conv2D (169.87m/169.87m flops)
#   model_25/conv2d_279/Conv2D (132.71m/132.71m flops)
#   model_25/conv2d_277/Conv2D (74.65m/74.65m flops)
#   model_25/conv2d_276/Conv2D (60.47m/60.47m flops)
#   model_25/conv2d_284/Conv2D (44.24m/44.24m flops)
#   model_25/conv2d_275/Conv2D (2.16m/2.16m flops)
#   model_25/conv2d_285/Conv2D (1.15m/1.15m flops)
#   model_25/max_pooling2d_125/MaxPool (120.00k/120.00k flops)
#   model_25/conv2d_275/BiasAdd (120.00k/120.00k flops)
#   model_25/conv2d_276/BiasAdd (69.98k/69.98k flops)
#   model_25/max_pooling2d_126/MaxPool (64.90k/64.90k flops)
#   model_25/conv2d_284/BiasAdd (57.60k/57.60k flops)
#   model_25/conv2d_278/BiasAdd (55.49k/55.49k flops)
#   model_25/conv2d_280/BiasAdd (55.30k/55.30k flops)
#   model_25/max_pooling2d_128/MaxPool (55.30k/55.30k flops)
#   model_25/max_pooling2d_127/MaxPool (49.15k/49.15k flops)
#   model_25/conv2d_277/BiasAdd (43.20k/43.20k flops)
#   model_25/max_pooling2d_129/MaxPool (38.40k/38.40k flops)
#   model_25/conv2d_282/BiasAdd (38.40k/38.40k flops)
#   model_25/conv2d_279/BiasAdd (38.40k/38.40k flops)
#   model_25/conv2d_281/BiasAdd (24.58k/24.58k flops)
#   model_25/dense_25/MatMul (5.00k/5.00k flops)
#   model_25/conv2d_285/BiasAdd (250/250 flops)
#   model_25/dense_25/Softmax (50/50 flops)
#   model_25/dense_25/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 4.27726
# 2022-05-14 14:25:14.315522: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:14.315636: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:14.317151: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.82b flops)
#   model_26/conv2d_291/Conv2D (520.22m/520.22m flops)
#   model_26/conv2d_293/Conv2D (361.27m/361.27m flops)
#   model_26/conv2d_289/Conv2D (261.02m/261.02m flops)
#   model_26/conv2d_292/Conv2D (231.21m/231.21m flops)
#   model_26/conv2d_290/Conv2D (180.63m/180.63m flops)
#   model_26/conv2d_288/Conv2D (101.61m/101.61m flops)
#   model_26/conv2d_287/Conv2D (82.30m/82.30m flops)
#   model_26/conv2d_295/Conv2D (71.68m/71.68m flops)
#   model_26/conv2d_286/Conv2D (2.52m/2.52m flops)
#   model_26/conv2d_296/Conv2D (1.60m/1.60m flops)
#   model_26/max_pooling2d_130/MaxPool (140.00k/140.00k flops)
#   model_26/conv2d_286/BiasAdd (140.00k/140.00k flops)
#   model_26/conv2d_287/BiasAdd (81.65k/81.65k flops)
#   model_26/conv2d_295/BiasAdd (80.00k/80.00k flops)
#   model_26/max_pooling2d_131/MaxPool (75.71k/75.71k flops)
#   model_26/conv2d_289/BiasAdd (64.74k/64.74k flops)
#   model_26/conv2d_291/BiasAdd (64.51k/64.51k flops)
#   model_26/max_pooling2d_133/MaxPool (64.51k/64.51k flops)
#   model_26/max_pooling2d_132/MaxPool (57.34k/57.34k flops)
#   model_26/conv2d_288/BiasAdd (50.40k/50.40k flops)
#   model_26/max_pooling2d_134/MaxPool (44.80k/44.80k flops)
#   model_26/conv2d_293/BiasAdd (44.80k/44.80k flops)
#   model_26/conv2d_290/BiasAdd (44.80k/44.80k flops)
#   model_26/conv2d_292/BiasAdd (28.67k/28.67k flops)
#   model_26/dense_26/MatMul (5.00k/5.00k flops)
#   model_26/conv2d_296/BiasAdd (250/250 flops)
#   model_26/dense_26/Softmax (50/50 flops)
#   model_26/dense_26/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 4.974348
# 2022-05-14 14:25:14.954945: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:14.955019: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:14.956444: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/2.38b flops)
#   model_27/conv2d_302/Conv2D (679.48m/679.48m flops)
#   model_27/conv2d_304/Conv2D (471.86m/471.86m flops)
#   model_27/conv2d_300/Conv2D (340.92m/340.92m flops)
#   model_27/conv2d_303/Conv2D (301.99m/301.99m flops)
#   model_27/conv2d_301/Conv2D (235.93m/235.93m flops)
#   model_27/conv2d_299/Conv2D (132.71m/132.71m flops)
#   model_27/conv2d_298/Conv2D (107.50m/107.50m flops)
#   model_27/conv2d_306/Conv2D (104.86m/104.86m flops)
#   model_27/conv2d_297/Conv2D (2.88m/2.88m flops)
#   model_27/conv2d_307/Conv2D (2.05m/2.05m flops)
#   model_27/max_pooling2d_135/MaxPool (160.00k/160.00k flops)
#   model_27/conv2d_297/BiasAdd (160.00k/160.00k flops)
#   model_27/conv2d_306/BiasAdd (102.40k/102.40k flops)
#   model_27/conv2d_298/BiasAdd (93.31k/93.31k flops)
#   model_27/max_pooling2d_136/MaxPool (86.53k/86.53k flops)
#   model_27/conv2d_300/BiasAdd (73.98k/73.98k flops)
#   model_27/conv2d_302/BiasAdd (73.73k/73.73k flops)
#   model_27/max_pooling2d_138/MaxPool (73.73k/73.73k flops)
#   model_27/max_pooling2d_137/MaxPool (65.54k/65.54k flops)
#   model_27/conv2d_299/BiasAdd (57.60k/57.60k flops)
#   model_27/max_pooling2d_139/MaxPool (51.20k/51.20k flops)
#   model_27/conv2d_304/BiasAdd (51.20k/51.20k flops)
#   model_27/conv2d_301/BiasAdd (51.20k/51.20k flops)
#   model_27/conv2d_303/BiasAdd (32.77k/32.77k flops)
#   model_27/dense_27/MatMul (5.00k/5.00k flops)
#   model_27/conv2d_307/BiasAdd (250/250 flops)
#   model_27/dense_27/Softmax (50/50 flops)
#   model_27/dense_27/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 6.382892
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.79b flops)
#   model_28/conv2d_313/Conv2D (532.68m/532.68m flops)
#   model_28/conv2d_311/Conv2D (311.50m/311.50m flops)
#   model_28/conv2d_315/Conv2D (265.42m/265.42m flops)
#   model_28/conv2d_312/Conv2D (207.36m/207.36m flops)
#   model_28/conv2d_314/Conv2D (184.32m/184.32m flops)
#   model_28/conv2d_310/Conv2D (132.71m/132.71m flops)
#   model_28/conv2d_309/Conv2D (111.51m/111.51m flops)
#   model_28/conv2d_317/Conv2D (32.44m/32.44m flops)
#   model_28/conv2d_308/Conv2D (5.08m/5.08m flops)
#   model_28/conv2d_318/Conv2D (1.01m/1.01m flops)
#   model_28/conv2d_308/BiasAdd (282.24k/282.24k flops)
#   model_28/max_pooling2d_140/MaxPool (282.24k/282.24k flops)
#   model_28/conv2d_309/BiasAdd (154.88k/154.88k flops)
#   model_28/max_pooling2d_141/MaxPool (154.88k/154.88k flops)
#   model_28/conv2d_311/BiasAdd (108.16k/108.16k flops)
#   model_28/max_pooling2d_142/MaxPool (108.16k/108.16k flops)
#   model_28/conv2d_313/BiasAdd (92.48k/92.48k flops)
#   model_28/conv2d_310/BiasAdd (92.16k/92.16k flops)
#   model_28/max_pooling2d_143/MaxPool (81.92k/81.92k flops)
#   model_28/conv2d_312/BiasAdd (72.00k/72.00k flops)
#   model_28/conv2d_317/BiasAdd (50.69k/50.69k flops)
#   model_28/max_pooling2d_144/MaxPool (46.08k/46.08k flops)
#   model_28/conv2d_315/BiasAdd (46.08k/46.08k flops)
#   model_28/conv2d_314/BiasAdd (32.00k/32.00k flops)
#   model_28/dense_28/MatMul (7.20k/7.20k flops)
#   model_28/conv2d_318/BiasAdd (360/360 flops)
#   model_28/dense_28/Softmax (50/50 flops)
#   model_28/dense_28/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# 2022-05-14 14:25:15.687355: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:15.687429: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:15.688885: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 7.830188
# 2022-05-14 14:25:16.000077: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:16.000152: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:16.001611: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/2.59b flops)
#   model_29/conv2d_324/Conv2D (767.07m/767.07m flops)
#   model_29/conv2d_322/Conv2D (448.56m/448.56m flops)
#   model_29/conv2d_326/Conv2D (382.21m/382.21m flops)
#   model_29/conv2d_323/Conv2D (298.60m/298.60m flops)
#   model_29/conv2d_325/Conv2D (265.42m/265.42m flops)
#   model_29/conv2d_321/Conv2D (191.10m/191.10m flops)
#   model_29/conv2d_320/Conv2D (160.58m/160.58m flops)
#   model_29/conv2d_328/Conv2D (63.70m/63.70m flops)
#   model_29/conv2d_319/Conv2D (6.10m/6.10m flops)
#   model_29/conv2d_329/Conv2D (1.66m/1.66m flops)
#   model_29/conv2d_319/BiasAdd (338.69k/338.69k flops)
#   model_29/max_pooling2d_145/MaxPool (338.69k/338.69k flops)
#   model_29/conv2d_320/BiasAdd (185.86k/185.86k flops)
#   model_29/max_pooling2d_146/MaxPool (185.86k/185.86k flops)
#   model_29/conv2d_322/BiasAdd (129.79k/129.79k flops)
#   model_29/max_pooling2d_147/MaxPool (129.79k/129.79k flops)
#   model_29/conv2d_324/BiasAdd (110.98k/110.98k flops)
#   model_29/conv2d_321/BiasAdd (110.59k/110.59k flops)
#   model_29/max_pooling2d_148/MaxPool (98.30k/98.30k flops)
#   model_29/conv2d_323/BiasAdd (86.40k/86.40k flops)
#   model_29/conv2d_328/BiasAdd (82.94k/82.94k flops)
#   model_29/max_pooling2d_149/MaxPool (55.30k/55.30k flops)
#   model_29/conv2d_326/BiasAdd (55.30k/55.30k flops)
#   model_29/conv2d_325/BiasAdd (38.40k/38.40k flops)
#   model_29/dense_29/MatMul (7.20k/7.20k flops)
#   model_29/conv2d_329/BiasAdd (360/360 flops)
#   model_29/dense_29/Softmax (50/50 flops)
#   model_29/dense_29/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 9.277484
# 2022-05-14 14:25:16.452755: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:16.452831: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:16.454309: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/3.54b flops)
#   model_30/conv2d_335/Conv2D (1.04b/1.04b flops)
#   model_30/conv2d_333/Conv2D (610.54m/610.54m flops)
#   model_30/conv2d_337/Conv2D (520.22m/520.22m flops)
#   model_30/conv2d_334/Conv2D (406.43m/406.43m flops)
#   model_30/conv2d_336/Conv2D (361.27m/361.27m flops)
#   model_30/conv2d_332/Conv2D (260.11m/260.11m flops)
#   model_30/conv2d_331/Conv2D (218.57m/218.57m flops)
#   model_30/conv2d_339/Conv2D (103.22m/103.22m flops)
#   model_30/conv2d_330/Conv2D (7.11m/7.11m flops)
#   model_30/conv2d_340/Conv2D (2.30m/2.30m flops)
#   model_30/conv2d_330/BiasAdd (395.14k/395.14k flops)
#   model_30/max_pooling2d_150/MaxPool (395.14k/395.14k flops)
#   model_30/conv2d_331/BiasAdd (216.83k/216.83k flops)
#   model_30/max_pooling2d_151/MaxPool (216.83k/216.83k flops)
#   model_30/conv2d_333/BiasAdd (151.42k/151.42k flops)
#   model_30/max_pooling2d_152/MaxPool (151.42k/151.42k flops)
#   model_30/conv2d_335/BiasAdd (129.47k/129.47k flops)
#   model_30/conv2d_332/BiasAdd (129.02k/129.02k flops)
#   model_30/conv2d_339/BiasAdd (115.20k/115.20k flops)
#   model_30/max_pooling2d_153/MaxPool (114.69k/114.69k flops)
#   model_30/conv2d_334/BiasAdd (100.80k/100.80k flops)
#   model_30/max_pooling2d_154/MaxPool (64.51k/64.51k flops)
#   model_30/conv2d_337/BiasAdd (64.51k/64.51k flops)
#   model_30/conv2d_336/BiasAdd (44.80k/44.80k flops)
#   model_30/dense_30/MatMul (7.20k/7.20k flops)
#   model_30/conv2d_340/BiasAdd (360/360 flops)
#   model_30/dense_30/Softmax (50/50 flops)
#   model_30/dense_30/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 10.72478
# 2022-05-14 14:25:17.101623: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:17.101702: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:17.103187: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/4.63b flops)
#   model_31/conv2d_346/Conv2D (1.36b/1.36b flops)
#   model_31/conv2d_344/Conv2D (797.44m/797.44m flops)
#   model_31/conv2d_348/Conv2D (679.48m/679.48m flops)
#   model_31/conv2d_345/Conv2D (530.84m/530.84m flops)
#   model_31/conv2d_347/Conv2D (471.86m/471.86m flops)
#   model_31/conv2d_343/Conv2D (339.74m/339.74m flops)
#   model_31/conv2d_342/Conv2D (285.47m/285.47m flops)
#   model_31/conv2d_350/Conv2D (150.99m/150.99m flops)
#   model_31/conv2d_341/Conv2D (8.13m/8.13m flops)
#   model_31/conv2d_351/Conv2D (2.95m/2.95m flops)
#   model_31/conv2d_341/BiasAdd (451.58k/451.58k flops)
#   model_31/max_pooling2d_155/MaxPool (451.58k/451.58k flops)
#   model_31/conv2d_342/BiasAdd (247.81k/247.81k flops)
#   model_31/max_pooling2d_156/MaxPool (247.81k/247.81k flops)
#   model_31/conv2d_344/BiasAdd (173.06k/173.06k flops)
#   model_31/max_pooling2d_157/MaxPool (173.06k/173.06k flops)
#   model_31/conv2d_346/BiasAdd (147.97k/147.97k flops)
#   model_31/conv2d_343/BiasAdd (147.46k/147.46k flops)
#   model_31/conv2d_350/BiasAdd (147.46k/147.46k flops)
#   model_31/max_pooling2d_158/MaxPool (131.07k/131.07k flops)
#   model_31/conv2d_345/BiasAdd (115.20k/115.20k flops)
#   model_31/max_pooling2d_159/MaxPool (73.73k/73.73k flops)
#   model_31/conv2d_348/BiasAdd (73.73k/73.73k flops)
#   model_31/conv2d_347/BiasAdd (51.20k/51.20k flops)
#   model_31/dense_31/MatMul (7.20k/7.20k flops)
#   model_31/conv2d_351/BiasAdd (360/360 flops)
#   model_31/dense_31/Softmax (50/50 flops)
#   model_31/dense_31/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 11.001356
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/2.81b flops)
#   model_32/conv2d_357/Conv2D (812.85m/812.85m flops)
#   model_32/conv2d_355/Conv2D (532.68m/532.68m flops)
#   model_32/conv2d_359/Conv2D (361.27m/361.27m flops)
#   model_32/conv2d_356/Conv2D (332.70m/332.70m flops)
#   model_32/conv2d_358/Conv2D (265.42m/265.42m flops)
#   model_32/conv2d_354/Conv2D (235.93m/235.93m flops)
#   model_32/conv2d_353/Conv2D (214.33m/214.33m flops)
#   model_32/conv2d_361/Conv2D (44.15m/44.15m flops)
#   model_32/conv2d_352/Conv2D (10.03m/10.03m flops)
#   model_32/conv2d_362/Conv2D (1.38m/1.38m flops)
#   model_32/conv2d_352/BiasAdd (556.96k/556.96k flops)
#   model_32/max_pooling2d_160/MaxPool (556.96k/556.96k flops)
#   model_32/conv2d_353/BiasAdd (297.68k/297.68k flops)
#   model_32/max_pooling2d_161/MaxPool (288.00k/288.00k flops)
#   model_32/conv2d_355/BiasAdd (184.96k/184.96k flops)
#   model_32/max_pooling2d_162/MaxPool (184.96k/184.96k flops)
#   model_32/conv2d_354/BiasAdd (163.84k/163.84k flops)
#   model_32/conv2d_357/BiasAdd (141.12k/141.12k flops)
#   model_32/max_pooling2d_163/MaxPool (128.00k/128.00k flops)
#   model_32/conv2d_356/BiasAdd (115.52k/115.52k flops)
#   model_32/conv2d_361/BiasAdd (68.99k/68.99k flops)
#   model_32/max_pooling2d_164/MaxPool (62.72k/62.72k flops)
#   model_32/conv2d_359/BiasAdd (62.72k/62.72k flops)
#   model_32/conv2d_358/BiasAdd (46.08k/46.08k flops)
#   model_32/dense_32/MatMul (9.80k/9.80k flops)
#   model_32/conv2d_362/BiasAdd (490/490 flops)
#   model_32/dense_32/Softmax (50/50 flops)
#   model_32/dense_32/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# 2022-05-14 14:25:17.835231: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:17.835307: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:17.836850: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 13.43054
# 2022-05-14 14:25:18.150451: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:18.150524: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:18.152048: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/4.07b flops)
#   model_33/conv2d_368/Conv2D (1.17b/1.17b flops)
#   model_33/conv2d_366/Conv2D (767.07m/767.07m flops)
#   model_33/conv2d_370/Conv2D (520.22m/520.22m flops)
#   model_33/conv2d_367/Conv2D (479.08m/479.08m flops)
#   model_33/conv2d_369/Conv2D (382.21m/382.21m flops)
#   model_33/conv2d_365/Conv2D (339.74m/339.74m flops)
#   model_33/conv2d_364/Conv2D (308.63m/308.63m flops)
#   model_33/conv2d_372/Conv2D (86.70m/86.70m flops)
#   model_33/conv2d_363/Conv2D (12.03m/12.03m flops)
#   model_33/conv2d_373/Conv2D (2.26m/2.26m flops)
#   model_33/conv2d_363/BiasAdd (668.35k/668.35k flops)
#   model_33/max_pooling2d_165/MaxPool (668.35k/668.35k flops)
#   model_33/conv2d_364/BiasAdd (357.22k/357.22k flops)
#   model_33/max_pooling2d_166/MaxPool (345.60k/345.60k flops)
#   model_33/conv2d_366/BiasAdd (221.95k/221.95k flops)
#   model_33/max_pooling2d_167/MaxPool (221.95k/221.95k flops)
#   model_33/conv2d_365/BiasAdd (196.61k/196.61k flops)
#   model_33/conv2d_368/BiasAdd (169.34k/169.34k flops)
#   model_33/max_pooling2d_168/MaxPool (153.60k/153.60k flops)
#   model_33/conv2d_367/BiasAdd (138.62k/138.62k flops)
#   model_33/conv2d_372/BiasAdd (112.90k/112.90k flops)
#   model_33/max_pooling2d_169/MaxPool (75.26k/75.26k flops)
#   model_33/conv2d_370/BiasAdd (75.26k/75.26k flops)
#   model_33/conv2d_369/BiasAdd (55.30k/55.30k flops)
#   model_33/dense_33/MatMul (9.80k/9.80k flops)
#   model_33/conv2d_373/BiasAdd (490/490 flops)
#   model_33/dense_33/Softmax (50/50 flops)
#   model_33/dense_33/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 15.859724
# 2022-05-14 14:25:18.512309: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:18.512388: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:18.513840: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/5.56b flops)
#   model_34/conv2d_379/Conv2D (1.59b/1.59b flops)
#   model_34/conv2d_377/Conv2D (1.04b/1.04b flops)
#   model_34/conv2d_381/Conv2D (708.08m/708.08m flops)
#   model_34/conv2d_378/Conv2D (652.09m/652.09m flops)
#   model_34/conv2d_380/Conv2D (520.22m/520.22m flops)
#   model_34/conv2d_376/Conv2D (462.42m/462.42m flops)
#   model_34/conv2d_375/Conv2D (420.09m/420.09m flops)
#   model_34/conv2d_383/Conv2D (140.49m/140.49m flops)
#   model_34/conv2d_374/Conv2D (14.04m/14.04m flops)
#   model_34/conv2d_384/Conv2D (3.14m/3.14m flops)
#   model_34/conv2d_374/BiasAdd (779.74k/779.74k flops)
#   model_34/max_pooling2d_170/MaxPool (779.74k/779.74k flops)
#   model_34/conv2d_375/BiasAdd (416.75k/416.75k flops)
#   model_34/max_pooling2d_171/MaxPool (403.20k/403.20k flops)
#   model_34/conv2d_377/BiasAdd (258.94k/258.94k flops)
#   model_34/max_pooling2d_172/MaxPool (258.94k/258.94k flops)
#   model_34/conv2d_376/BiasAdd (229.38k/229.38k flops)
#   model_34/conv2d_379/BiasAdd (197.57k/197.57k flops)
#   model_34/max_pooling2d_173/MaxPool (179.20k/179.20k flops)
#   model_34/conv2d_378/BiasAdd (161.73k/161.73k flops)
#   model_34/conv2d_383/BiasAdd (156.80k/156.80k flops)
#   model_34/max_pooling2d_174/MaxPool (87.81k/87.81k flops)
#   model_34/conv2d_381/BiasAdd (87.81k/87.81k flops)
#   model_34/conv2d_380/BiasAdd (64.51k/64.51k flops)
#   model_34/dense_34/MatMul (9.80k/9.80k flops)
#   model_34/conv2d_384/BiasAdd (490/490 flops)
#   model_34/dense_34/Softmax (50/50 flops)
#   model_34/dense_34/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 18.288908
# 2022-05-14 14:25:18.927699: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:18.927775: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:18.929276: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/7.28b flops)
#   model_35/conv2d_390/Conv2D (2.08b/2.08b flops)
#   model_35/conv2d_388/Conv2D (1.36b/1.36b flops)
#   model_35/conv2d_392/Conv2D (924.84m/924.84m flops)
#   model_35/conv2d_389/Conv2D (851.71m/851.71m flops)
#   model_35/conv2d_391/Conv2D (679.48m/679.48m flops)
#   model_35/conv2d_387/Conv2D (603.98m/603.98m flops)
#   model_35/conv2d_386/Conv2D (548.68m/548.68m flops)
#   model_35/conv2d_394/Conv2D (205.52m/205.52m flops)
#   model_35/conv2d_385/Conv2D (16.04m/16.04m flops)
#   model_35/conv2d_395/Conv2D (4.01m/4.01m flops)
#   model_35/conv2d_385/BiasAdd (891.14k/891.14k flops)
#   model_35/max_pooling2d_175/MaxPool (891.14k/891.14k flops)
#   model_35/conv2d_386/BiasAdd (476.29k/476.29k flops)
#   model_35/max_pooling2d_176/MaxPool (460.80k/460.80k flops)
#   model_35/conv2d_388/BiasAdd (295.94k/295.94k flops)
#   model_35/max_pooling2d_177/MaxPool (295.94k/295.94k flops)
#   model_35/conv2d_387/BiasAdd (262.14k/262.14k flops)
#   model_35/conv2d_390/BiasAdd (225.79k/225.79k flops)
#   model_35/max_pooling2d_178/MaxPool (204.80k/204.80k flops)
#   model_35/conv2d_394/BiasAdd (200.70k/200.70k flops)
#   model_35/conv2d_389/BiasAdd (184.83k/184.83k flops)
#   model_35/max_pooling2d_179/MaxPool (100.35k/100.35k flops)
#   model_35/conv2d_392/BiasAdd (100.35k/100.35k flops)
#   model_35/conv2d_391/BiasAdd (73.73k/73.73k flops)
#   model_35/dense_35/MatMul (9.80k/9.80k flops)
#   model_35/conv2d_395/BiasAdd (490/490 flops)
#   model_35/dense_35/Softmax (50/50 flops)
#   model_35/dense_35/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 17.148076
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/4.14b flops)
#   model_36/conv2d_401/Conv2D (1.15b/1.15b flops)
#   model_36/conv2d_399/Conv2D (852.02m/852.02m flops)
#   model_36/conv2d_400/Conv2D (487.53m/487.53m flops)
#   model_36/conv2d_403/Conv2D (471.86m/471.86m flops)
#   model_36/conv2d_398/Conv2D (387.30m/387.30m flops)
#   model_36/conv2d_402/Conv2D (361.27m/361.27m flops)
#   model_36/conv2d_397/Conv2D (350.44m/350.44m flops)
#   model_36/conv2d_405/Conv2D (57.67m/57.67m flops)
#   model_36/conv2d_396/Conv2D (16.63m/16.63m flops)
#   model_36/conv2d_406/Conv2D (1.80m/1.80m flops)
#   model_36/conv2d_396/BiasAdd (924.16k/924.16k flops)
#   model_36/max_pooling2d_180/MaxPool (924.16k/924.16k flops)
#   model_36/conv2d_397/BiasAdd (486.72k/486.72k flops)
#   model_36/max_pooling2d_181/MaxPool (486.72k/486.72k flops)
#   model_36/conv2d_399/BiasAdd (295.84k/295.84k flops)
#   model_36/max_pooling2d_182/MaxPool (282.24k/282.24k flops)
#   model_36/conv2d_398/BiasAdd (268.96k/268.96k flops)
#   model_36/conv2d_401/BiasAdd (200.00k/200.00k flops)
#   model_36/max_pooling2d_183/MaxPool (184.32k/184.32k flops)
#   model_36/conv2d_400/BiasAdd (169.28k/169.28k flops)
#   model_36/conv2d_405/BiasAdd (90.11k/90.11k flops)
#   model_36/max_pooling2d_184/MaxPool (81.92k/81.92k flops)
#   model_36/conv2d_403/BiasAdd (81.92k/81.92k flops)
#   model_36/conv2d_402/BiasAdd (62.72k/62.72k flops)
#   model_36/dense_36/MatMul (12.80k/12.80k flops)
#   model_36/conv2d_406/BiasAdd (640/640 flops)
#   model_36/dense_36/Softmax (50/50 flops)
#   model_36/dense_36/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# 2022-05-14 14:25:19.511411: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:19.511485: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:19.512990: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 20.872748
# 2022-05-14 14:25:19.828194: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:19.828267: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:19.829710: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/5.99b flops)
#   model_37/conv2d_412/Conv2D (1.66b/1.66b flops)
#   model_37/conv2d_410/Conv2D (1.23b/1.23b flops)
#   model_37/conv2d_411/Conv2D (702.04m/702.04m flops)
#   model_37/conv2d_414/Conv2D (679.48m/679.48m flops)
#   model_37/conv2d_409/Conv2D (557.72m/557.72m flops)
#   model_37/conv2d_413/Conv2D (520.22m/520.22m flops)
#   model_37/conv2d_408/Conv2D (504.63m/504.63m flops)
#   model_37/conv2d_416/Conv2D (113.25m/113.25m flops)
#   model_37/conv2d_407/Conv2D (19.96m/19.96m flops)
#   model_37/conv2d_417/Conv2D (2.95m/2.95m flops)
#   model_37/conv2d_407/BiasAdd (1.11m/1.11m flops)
#   model_37/max_pooling2d_185/MaxPool (1.11m/1.11m flops)
#   model_37/conv2d_408/BiasAdd (584.06k/584.06k flops)
#   model_37/max_pooling2d_186/MaxPool (584.06k/584.06k flops)
#   model_37/conv2d_410/BiasAdd (355.01k/355.01k flops)
#   model_37/max_pooling2d_187/MaxPool (338.69k/338.69k flops)
#   model_37/conv2d_409/BiasAdd (322.75k/322.75k flops)
#   model_37/conv2d_412/BiasAdd (240.00k/240.00k flops)
#   model_37/max_pooling2d_188/MaxPool (221.18k/221.18k flops)
#   model_37/conv2d_411/BiasAdd (203.14k/203.14k flops)
#   model_37/conv2d_416/BiasAdd (147.46k/147.46k flops)
#   model_37/max_pooling2d_189/MaxPool (98.30k/98.30k flops)
#   model_37/conv2d_414/BiasAdd (98.30k/98.30k flops)
#   model_37/conv2d_413/BiasAdd (75.26k/75.26k flops)
#   model_37/dense_37/MatMul (12.80k/12.80k flops)
#   model_37/conv2d_417/BiasAdd (640/640 flops)
#   model_37/dense_37/Softmax (50/50 flops)
#   model_37/dense_37/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 24.59742
# 2022-05-14 14:25:20.187262: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:20.187344: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# ...
# 2022-05-14 14:25:22.840543: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:22.842012: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/14.64b flops)
#   model_43/conv2d_478/Conv2D (3.97b/3.97b flops)
#   model_43/conv2d_476/Conv2D (3.07b/3.07b flops)
#   model_43/conv2d_477/Conv2D (1.72b/1.72b flops)
#   model_43/conv2d_480/Conv2D (1.53b/1.53b flops)
#   model_43/conv2d_475/Conv2D (1.42b/1.42b flops)
#   model_43/conv2d_474/Conv2D (1.33b/1.33b flops)
#   model_43/conv2d_479/Conv2D (1.21b/1.21b flops)
#   model_43/conv2d_482/Conv2D (339.74m/339.74m flops)
#   model_43/conv2d_473/Conv2D (39.85m/39.85m flops)
#   model_43/conv2d_483/Conv2D (6.64m/6.64m flops)
#   model_43/conv2d_473/BiasAdd (2.21m/2.21m flops)
#   model_43/max_pooling2d_215/MaxPool (2.21m/2.21m flops)
#   model_43/conv2d_474/BiasAdd (1.16m/1.16m flops)
#   model_43/max_pooling2d_216/MaxPool (1.13m/1.13m flops)
#   model_43/conv2d_476/BiasAdd (665.86k/665.86k flops)
#   model_43/max_pooling2d_217/MaxPool (640.00k/640.00k flops)
#   model_43/conv2d_475/BiasAdd (614.66k/614.66k flops)
#   model_43/conv2d_478/BiasAdd (430.59k/430.59k flops)
#   model_43/max_pooling2d_218/MaxPool (401.41k/401.41k flops)
#   model_43/conv2d_477/BiasAdd (373.25k/373.25k flops)
#   model_43/conv2d_482/BiasAdd (331.78k/331.78k flops)
#   model_43/max_pooling2d_219/MaxPool (165.89k/165.89k flops)
#   model_43/conv2d_480/BiasAdd (165.89k/165.89k flops)
#   model_43/conv2d_479/BiasAdd (131.07k/131.07k flops)
#   model_43/dense_43/MatMul (16.20k/16.20k flops)
#   model_43/conv2d_483/BiasAdd (810/810 flops)
#   model_43/dense_43/Softmax (50/50 flops)
#   model_43/dense_43/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 33.922604
# 2022-05-14 14:25:23.613696: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:23.613820: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:23.615330: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/7.85b flops)
#   model_44/conv2d_489/Conv2D (2.13b/2.13b flops)
#   model_44/conv2d_487/Conv2D (1.66b/1.66b flops)
#   model_44/conv2d_488/Conv2D (943.72m/943.72m flops)
#   model_44/conv2d_491/Conv2D (812.85m/812.85m flops)
#   model_44/conv2d_486/Conv2D (775.07m/775.07m flops)
#   model_44/conv2d_485/Conv2D (722.53m/722.53m flops)
#   model_44/conv2d_490/Conv2D (665.40m/665.40m flops)
#   model_44/conv2d_493/Conv2D (90.11m/90.11m flops)
#   model_44/conv2d_484/Conv2D (34.85m/34.85m flops)
#   model_44/conv2d_494/Conv2D (2.82m/2.82m flops)
#   model_44/max_pooling2d_220/MaxPool (1.94m/1.94m flops)
#   model_44/conv2d_484/BiasAdd (1.94m/1.94m flops)
#   model_44/max_pooling2d_221/MaxPool (1.00m/1.00m flops)
#   model_44/conv2d_485/BiasAdd (1.00m/1.00m flops)
#   model_44/conv2d_487/BiasAdd (576.00k/576.00k flops)
#   model_44/max_pooling2d_222/MaxPool (576.00k/576.00k flops)
#   model_44/conv2d_486/BiasAdd (538.24k/538.24k flops)
#   model_44/max_pooling2d_223/MaxPool (369.92k/369.92k flops)
#   model_44/conv2d_489/BiasAdd (369.92k/369.92k flops)
#   model_44/conv2d_488/BiasAdd (327.68k/327.68k flops)
#   model_44/conv2d_491/BiasAdd (141.12k/141.12k flops)
#   model_44/conv2d_493/BiasAdd (140.80k/140.80k flops)
#   model_44/max_pooling2d_224/MaxPool (128.00k/128.00k flops)
#   model_44/conv2d_490/BiasAdd (115.52k/115.52k flops)
#   model_44/dense_44/MatMul (20.00k/20.00k flops)
#   model_44/conv2d_494/BiasAdd (1.00k/1.00k flops)
#   model_44/dense_44/Softmax (50/50 flops)
#   model_44/dense_44/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 41.158316
# 2022-05-14 14:25:23.966941: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:23.967015: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:23.968535: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/11.34b flops)
#   model_45/conv2d_500/Conv2D (3.07b/3.07b flops)
#   model_45/conv2d_498/Conv2D (2.39b/2.39b flops)
#   model_45/conv2d_499/Conv2D (1.36b/1.36b flops)
#   model_45/conv2d_502/Conv2D (1.17b/1.17b flops)
#   model_45/conv2d_497/Conv2D (1.12b/1.12b flops)
#   model_45/conv2d_496/Conv2D (1.04b/1.04b flops)
#   model_45/conv2d_501/Conv2D (958.17m/958.17m flops)
#   model_45/conv2d_504/Conv2D (176.95m/176.95m flops)
#   model_45/conv2d_495/Conv2D (41.82m/41.82m flops)
#   model_45/conv2d_505/Conv2D (4.61m/4.61m flops)
#   model_45/conv2d_495/BiasAdd (2.32m/2.32m flops)
#   model_45/max_pooling2d_225/MaxPool (2.32m/2.32m flops)
#   model_45/conv2d_496/BiasAdd (1.20m/1.20m flops)
#   model_45/max_pooling2d_226/MaxPool (1.20m/1.20m flops)
#   model_45/conv2d_498/BiasAdd (691.20k/691.20k flops)
#   model_45/max_pooling2d_227/MaxPool (691.20k/691.20k flops)
#   model_45/conv2d_497/BiasAdd (645.89k/645.89k flops)
#   model_45/conv2d_500/BiasAdd (443.90k/443.90k flops)
#   model_45/max_pooling2d_228/MaxPool (443.90k/443.90k flops)
#   model_45/conv2d_499/BiasAdd (393.22k/393.22k flops)
#   model_45/conv2d_504/BiasAdd (230.40k/230.40k flops)
#   model_45/conv2d_502/BiasAdd (169.34k/169.34k flops)
#   model_45/max_pooling2d_229/MaxPool (153.60k/153.60k flops)
#   model_45/conv2d_501/BiasAdd (138.62k/138.62k flops)
#   model_45/dense_45/MatMul (20.00k/20.00k flops)
#   model_45/conv2d_505/BiasAdd (1.00k/1.00k flops)
#   model_45/dense_45/Softmax (50/50 flops)
#   model_45/dense_45/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 48.394028
# 2022-05-14 14:25:24.445095: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:24.445167: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:24.446632: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/15.46b flops)
#   model_46/conv2d_511/Conv2D (4.18b/4.18b flops)
#   model_46/conv2d_509/Conv2D (3.25b/3.25b flops)
#   model_46/conv2d_510/Conv2D (1.85b/1.85b flops)
#   model_46/conv2d_513/Conv2D (1.59b/1.59b flops)
#   model_46/conv2d_508/Conv2D (1.52b/1.52b flops)
#   model_46/conv2d_507/Conv2D (1.42b/1.42b flops)
#   model_46/conv2d_512/Conv2D (1.30b/1.30b flops)
#   model_46/conv2d_515/Conv2D (286.72m/286.72m flops)
#   model_46/conv2d_506/Conv2D (48.79m/48.79m flops)
#   model_46/conv2d_516/Conv2D (6.40m/6.40m flops)
#   model_46/conv2d_506/BiasAdd (2.71m/2.71m flops)
#   model_46/max_pooling2d_230/MaxPool (2.71m/2.71m flops)
#   model_46/conv2d_507/BiasAdd (1.40m/1.40m flops)
#   model_46/max_pooling2d_231/MaxPool (1.40m/1.40m flops)
#   model_46/conv2d_509/BiasAdd (806.40k/806.40k flops)
#   model_46/max_pooling2d_232/MaxPool (806.40k/806.40k flops)
#   model_46/conv2d_508/BiasAdd (753.54k/753.54k flops)
#   model_46/conv2d_511/BiasAdd (517.89k/517.89k flops)
#   model_46/max_pooling2d_233/MaxPool (517.89k/517.89k flops)
#   model_46/conv2d_510/BiasAdd (458.75k/458.75k flops)
#   model_46/conv2d_515/BiasAdd (320.00k/320.00k flops)
#   model_46/conv2d_513/BiasAdd (197.57k/197.57k flops)
#   model_46/max_pooling2d_234/MaxPool (179.20k/179.20k flops)
#   model_46/conv2d_512/BiasAdd (161.73k/161.73k flops)
#   model_46/dense_46/MatMul (20.00k/20.00k flops)
#   model_46/conv2d_516/BiasAdd (1.00k/1.00k flops)
#   model_46/dense_46/Softmax (50/50 flops)
#   model_46/dense_46/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 55.62974
# 2022-05-14 14:25:25.091784: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-14 14:25:25.091864: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-14 14:25:25.093398: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/20.23b flops)
#   model_47/conv2d_522/Conv2D (5.45b/5.45b flops)
#   model_47/conv2d_520/Conv2D (4.25b/4.25b flops)
#   model_47/conv2d_521/Conv2D (2.42b/2.42b flops)
#   model_47/conv2d_524/Conv2D (2.08b/2.08b flops)
#   model_47/conv2d_519/Conv2D (1.98b/1.98b flops)
#   model_47/conv2d_518/Conv2D (1.85b/1.85b flops)
#   model_47/conv2d_523/Conv2D (1.70b/1.70b flops)
#   model_47/conv2d_526/Conv2D (419.43m/419.43m flops)
#   model_47/conv2d_517/Conv2D (55.76m/55.76m flops)
#   model_47/conv2d_527/Conv2D (8.19m/8.19m flops)
#   model_47/conv2d_517/BiasAdd (3.10m/3.10m flops)
#   model_47/max_pooling2d_235/MaxPool (3.10m/3.10m flops)
#   model_47/conv2d_518/BiasAdd (1.61m/1.61m flops)
#   model_47/max_pooling2d_236/MaxPool (1.61m/1.61m flops)
#   model_47/conv2d_520/BiasAdd (921.60k/921.60k flops)
#   model_47/max_pooling2d_237/MaxPool (921.60k/921.60k flops)
#   model_47/conv2d_519/BiasAdd (861.18k/861.18k flops)
#   model_47/conv2d_522/BiasAdd (591.87k/591.87k flops)
#   model_47/max_pooling2d_238/MaxPool (591.87k/591.87k flops)
#   model_47/conv2d_521/BiasAdd (524.29k/524.29k flops)
#   model_47/conv2d_526/BiasAdd (409.60k/409.60k flops)
#   model_47/conv2d_524/BiasAdd (225.79k/225.79k flops)
#   model_47/max_pooling2d_239/MaxPool (204.80k/204.80k flops)
#   model_47/conv2d_523/BiasAdd (184.83k/184.83k flops)
#   model_47/dense_47/MatMul (20.00k/20.00k flops)
#   model_47/conv2d_527/BiasAdd (1.00k/1.00k flops)
#   model_47/dense_47/Softmax (50/50 flops)
#   model_47/dense_47/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
