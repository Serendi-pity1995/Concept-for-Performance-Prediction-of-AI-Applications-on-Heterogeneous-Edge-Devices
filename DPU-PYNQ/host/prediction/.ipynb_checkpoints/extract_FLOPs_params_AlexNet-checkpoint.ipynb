# %%
import os
import csv
import numpy as np
import tensorflow as tf
import keras
from keras.models import Model
from keras_flops import get_flops
from itertools import product

def get_total_number_of_neurons(model, include_output_layer):
    '''
    Args:
        model: Keras model
        include_output_layer: A boolean parameter. Whether or not to include output layer's neurons into the calculation

    Returns: number of neurons in the given model
    '''
    num_layers = len(model.layers)
    total_num_of_neurons = 0
    for layer_index in range(num_layers):
        layer = model.layers[layer_index]
        # since we multiply layer output dimensions, initial value is set to 1.
        num_neurons_in_layer = 1
        for i in range(1, len(layer.output.shape)):
            try:
                # when it is a valid layer to count neurons, an output dimension of the layer can be convertible to int.
                num_neurons_in_layer *= int(layer.output.shape[i])
            except Exception:
                # if the output dimension of layer cannot be convertible to int,
                # just pass that layer since it is not a valid layer to count neurons
                pass
        # if num_neurons_in_layer is not still 1, it means we have a valid layer to count neurons
        if not num_neurons_in_layer == 1:
            # when it is an output layer
            if layer_index == (num_layers - 1):
                if include_output_layer:
                    total_num_of_neurons += num_neurons_in_layer
            else:  # when it is not an output layer
                total_num_of_neurons += num_neurons_in_layer
    return total_num_of_neurons


with open("para_count_AlexNet.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "step","number_of_layers", "FLOPs_G", "Total_params_M", "Memory_M", "total_num_of_neurons_M"],])

path = "../AlexNet_h5" #文件夹目录
files= os.listdir(path) #得到文件夹下的所有文件名称
model_num = 1
input_shape_range =range(224,512,32)

for shape_x in input_shape_range:
    shape_y = shape_x
    for step in range(1,11):
        file = "AlexNet_{input_x}_{input_y}_{step}.h5".format(input_x=shape_x,input_y=shape_y,step=step)
        if file in files: #遍历文件夹
            model_name = str(file)
            if not os.path.isdir(file): #判断是否是文件夹，不是文件夹才打开
                model = keras.models.load_model("../AlexNet_h5/{}".format(model_name))
                num_neurons = get_total_number_of_neurons(model= model, include_output_layer= True)
                num_neurons_M = num_neurons/10**6    
                # how to compute the memory allocated by the activations of a model
                batch = 1
                shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
                else 1 for s in l.output_shape])) 
                for l in model.layers]))
                memory = (shapes_count * 4 * batch)/10**6
                print(memory)
                layers_length = len(model.layers)
                Total_params = round(model.count_params()/10 ** 6,2)
                FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
                with open("para_count_AlexNet.csv","a+") as csvfile:
                    writer = csv.writer(csvfile)
                    writer.writerows([[model_num, shape_x, shape_y, step, layers_length, FLOPs, Total_params, memory, num_neurons_M],])

                    model_num = model_num + 1
# Out:
# 2022-04-13 05:47:18.862497: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-04-13 05:47:18.862514: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-04-13 05:47:19.997110: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-04-13 05:47:19.997127: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-13 05:47:19.997142: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2022-04-13 05:47:19.997278: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 1.769764
# 2022-04-13 05:47:20.558681: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:20.558797: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:20.579366: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.007ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# WARNING:tensorflow:From /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py:5063: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/507.66m flops)
#   model/conv2d_8/Conv2D (258.75m/258.75m flops)
#   model/conv2d_10/Conv2D (95.55m/95.55m flops)
#   model/conv2d_9/Conv2D (71.66m/71.66m flops)
#   model/conv2d_7/Conv2D (46.57m/46.57m flops)
#   model/conv2d_11/Conv2D (27.65m/27.65m flops)
#   model/dense_1/MatMul (5.69m/5.69m flops)
#   model/dense/MatMul (760.00k/760.00k flops)
#   model/max_pooling2d_4/MaxPool (401.54k/401.54k flops)
#   model/conv2d_7/BiasAdd (192.46k/192.46k flops)
#   model/max_pooling2d_5/MaxPool (145.80k/145.80k flops)
#   model/batch_normalization_3/FusedBatchNormV3 (89.63k/89.63k flops)
#   model/conv2d_8/BiasAdd (78.41k/78.41k flops)
#   model/dense_2/MatMul (37.44k/37.44k flops)
#   model/batch_normalization_4/FusedBatchNormV3 (33.37k/33.37k flops)
#   model/conv2d_9/BiasAdd (24.58k/24.58k flops)
#   model/conv2d_10/BiasAdd (13.82k/13.82k flops)
#   model/conv2d_11/BiasAdd (4.00k/4.00k flops)
#   model/max_pooling2d_6/MaxPool (2.25k/2.25k flops)
#   model/batch_normalization_5/FusedBatchNormV3 (2.00k/2.00k flops)
#   model/dense_1/BiasAdd (1.87k/1.87k flops)
#   model/dense/BiasAdd (1.52k/1.52k flops)
#   model/dense_2/Softmax (50/50 flops)
#   model/dense_2/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.90386
# 2022-04-13 05:47:21.140910: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:21.140985: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:21.142399: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.006ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/589.52m flops)
#   model_1/conv2d_13/Conv2D (319.25m/319.25m flops)
#   model_1/conv2d_15/Conv2D (95.55m/95.55m flops)
#   model_1/conv2d_14/Conv2D (85.82m/85.82m flops)
#   model_1/conv2d_12/Conv2D (47.99m/47.99m flops)
#   model_1/conv2d_16/Conv2D (26.32m/26.32m flops)
#   model_1/dense_4/MatMul (12.46m/12.46m flops)
#   model_1/dense_3/MatMul (1.01m/1.01m flops)
#   model_1/max_pooling2d_7/MaxPool (413.71k/413.71k flops)
#   model_1/conv2d_12/BiasAdd (198.29k/198.29k flops)
#   model_1/max_pooling2d_8/MaxPool (174.60k/174.60k flops)
#   model_1/conv2d_13/BiasAdd (93.90k/93.90k flops)
#   model_1/batch_normalization_6/FusedBatchNormV3 (92.34k/92.34k flops)
#   model_1/dense_5/MatMul (58.56k/58.56k flops)
#   model_1/batch_normalization_7/FusedBatchNormV3 (39.96k/39.96k flops)
#   model_1/conv2d_14/BiasAdd (24.58k/24.58k flops)
#   model_1/conv2d_15/BiasAdd (13.82k/13.82k flops)
#   model_1/conv2d_16/BiasAdd (3.81k/3.81k flops)
#   model_1/dense_4/BiasAdd (2.93k/2.93k flops)
#   model_1/max_pooling2d_9/MaxPool (2.14k/2.14k flops)
#   model_1/dense_3/BiasAdd (2.13k/2.13k flops)
#   model_1/batch_normalization_8/FusedBatchNormV3 (1.90k/1.90k flops)
#   model_1/dense_5/Softmax (50/50 flops)
#   model_1/dense_5/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.129228
# 2022-04-13 05:47:21.839616: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:21.839704: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:21.841117: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/585.79m flops)
#   model_2/conv2d_18/Conv2D (336.48m/336.48m flops)
#   model_2/conv2d_20/Conv2D (95.55m/95.55m flops)
#   model_2/conv2d_19/Conv2D (69.89m/69.89m flops)
#   model_2/conv2d_17/Conv2D (62.10m/62.10m flops)
#   model_2/conv2d_21/Conv2D (14.16m/14.16m flops)
#   model_2/dense_7/MatMul (6.07m/6.07m flops)
#   model_2/max_pooling2d_10/MaxPool (535.39k/535.39k flops)
#   model_2/dense_6/MatMul (274.43k/274.43k flops)
#   model_2/conv2d_17/BiasAdd (256.61k/256.61k flops)
#   model_2/max_pooling2d_11/MaxPool (142.20k/142.20k flops)
#   model_2/batch_normalization_9/FusedBatchNormV3 (119.50k/119.50k flops)
#   model_2/conv2d_18/BiasAdd (76.47k/76.47k flops)
#   model_2/dense_8/MatMul (56.64k/56.64k flops)
#   model_2/batch_normalization_10/FusedBatchNormV3 (32.55k/32.55k flops)
#   model_2/conv2d_19/BiasAdd (24.58k/24.58k flops)
#   model_2/conv2d_20/BiasAdd (13.82k/13.82k flops)
#   model_2/dense_7/BiasAdd (2.83k/2.83k flops)
#   model_2/conv2d_21/BiasAdd (2.05k/2.05k flops)
#   model_2/max_pooling2d_12/MaxPool (1.15k/1.15k flops)
#   model_2/dense_6/BiasAdd (1.07k/1.07k flops)
#   model_2/batch_normalization_11/FusedBatchNormV3 (1.02k/1.02k flops)
#   model_2/dense_8/Softmax (50/50 flops)
#   model_2/dense_8/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.046612
# 2022-04-13 05:47:22.244005: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:22.244097: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:22.245555: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.006ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/686.77m flops)
#   model_3/conv2d_23/Conv2D (396.40m/396.40m flops)
#   model_3/conv2d_24/Conv2D (103.51m/103.51m flops)
#   model_3/conv2d_25/Conv2D (95.55m/95.55m flops)
#   model_3/conv2d_22/Conv2D (49.40m/49.40m flops)
#   model_3/conv2d_26/Conv2D (28.09m/28.09m flops)
#   model_3/dense_10/MatMul (11.48m/11.48m flops)
#   model_3/dense_9/MatMul (1.15m/1.15m flops)
#   model_3/max_pooling2d_13/MaxPool (425.88k/425.88k flops)
#   model_3/max_pooling2d_14/MaxPool (210.60k/210.60k flops)
#   model_3/conv2d_22/BiasAdd (204.12k/204.12k flops)
#   model_3/conv2d_23/BiasAdd (113.26k/113.26k flops)
#   model_3/batch_normalization_12/FusedBatchNormV3 (95.06k/95.06k flops)
#   model_3/dense_11/MatMul (50.88k/50.88k flops)
#   model_3/batch_normalization_13/FusedBatchNormV3 (48.20k/48.20k flops)
#   model_3/conv2d_24/BiasAdd (24.58k/24.58k flops)
#   model_3/conv2d_25/BiasAdd (13.82k/13.82k flops)
#   model_3/conv2d_26/BiasAdd (4.06k/4.06k flops)
#   model_3/dense_10/BiasAdd (2.54k/2.54k flops)
#   model_3/max_pooling2d_15/MaxPool (2.29k/2.29k flops)
#   model_3/dense_9/BiasAdd (2.26k/2.26k flops)
#   model_3/batch_normalization_14/FusedBatchNormV3 (2.03k/2.03k flops)
#   model_3/dense_11/Softmax (50/50 flops)
#   model_3/dense_11/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.972668
# 2022-04-13 05:47:22.906868: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:22.906944: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:22.908313: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/624.80m flops)
#   model_4/conv2d_28/Conv2D (355.74m/355.74m flops)
#   model_4/conv2d_30/Conv2D (95.55m/95.55m flops)
#   model_4/conv2d_29/Conv2D (92.90m/92.90m flops)
#   model_4/conv2d_27/Conv2D (49.40m/49.40m flops)
#   model_4/conv2d_31/Conv2D (19.02m/19.02m flops)
#   model_4/dense_13/MatMul (10.30m/10.30m flops)
#   model_4/dense_12/MatMul (743.04k/743.04k flops)
#   model_4/max_pooling2d_16/MaxPool (425.88k/425.88k flops)
#   model_4/conv2d_27/BiasAdd (204.12k/204.12k flops)
#   model_4/max_pooling2d_17/MaxPool (189.00k/189.00k flops)
#   model_4/conv2d_28/BiasAdd (101.64k/101.64k flops)
#   model_4/batch_normalization_15/FusedBatchNormV3 (95.06k/95.06k flops)
#   model_4/dense_14/MatMul (47.68k/47.68k flops)
#   model_4/batch_normalization_16/FusedBatchNormV3 (43.26k/43.26k flops)
#   model_4/conv2d_29/BiasAdd (24.58k/24.58k flops)
#   model_4/conv2d_30/BiasAdd (13.82k/13.82k flops)
#   model_4/conv2d_31/BiasAdd (2.75k/2.75k flops)
#   model_4/dense_13/BiasAdd (2.38k/2.38k flops)
#   model_4/dense_12/BiasAdd (2.16k/2.16k flops)
#   model_4/max_pooling2d_18/MaxPool (1.55k/1.55k flops)
#   model_4/batch_normalization_17/FusedBatchNormV3 (1.38k/1.38k flops)
#   model_4/dense_14/Softmax (50/50 flops)
#   model_4/dense_14/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.220324
# 2022-04-13 05:47:23.544313: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:23.544415: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:23.545980: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.006ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/671.89m flops)
#   model_5/conv2d_33/Conv2D (391.85m/391.85m flops)
#   model_5/conv2d_35/Conv2D (95.55m/95.55m flops)
#   model_5/conv2d_34/Conv2D (81.40m/81.40m flops)
#   model_5/conv2d_32/Conv2D (62.10m/62.10m flops)
#   model_5/conv2d_36/Conv2D (22.34m/22.34m flops)
#   model_5/dense_16/MatMul (16.22m/16.22m flops)
#   model_5/dense_15/MatMul (1.13m/1.13m flops)
#   model_5/max_pooling2d_19/MaxPool (535.39k/535.39k flops)
#   model_5/conv2d_32/BiasAdd (256.61k/256.61k flops)
#   model_5/max_pooling2d_20/MaxPool (165.60k/165.60k flops)
#   model_5/batch_normalization_18/FusedBatchNormV3 (119.50k/119.50k flops)
#   model_5/conv2d_33/BiasAdd (89.06k/89.06k flops)
#   model_5/dense_17/MatMul (57.92k/57.92k flops)
#   model_5/batch_normalization_19/FusedBatchNormV3 (37.90k/37.90k flops)
#   model_5/conv2d_34/BiasAdd (24.58k/24.58k flops)
#   model_5/conv2d_35/BiasAdd (13.82k/13.82k flops)
#   model_5/conv2d_36/BiasAdd (3.23k/3.23k flops)
#   model_5/dense_16/BiasAdd (2.90k/2.90k flops)
#   model_5/dense_15/BiasAdd (2.80k/2.80k flops)
#   model_5/max_pooling2d_21/MaxPool (1.82k/1.82k flops)
#   model_5/batch_normalization_20/FusedBatchNormV3 (1.62k/1.62k flops)
#   model_5/dense_17/Softmax (50/50 flops)
#   model_5/dense_17/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.769796
# 2022-04-13 05:47:24.391966: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:24.392045: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:24.393479: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/485.67m flops)
#   model_6/conv2d_38/Conv2D (236.97m/236.97m flops)
#   model_6/conv2d_40/Conv2D (95.55m/95.55m flops)
#   model_6/conv2d_39/Conv2D (63.70m/63.70m flops)
#   model_6/conv2d_37/Conv2D (47.99m/47.99m flops)
#   model_6/conv2d_41/Conv2D (23.22m/23.22m flops)
#   model_6/dense_19/MatMul (16.03m/16.03m flops)
#   model_6/dense_18/MatMul (1.16m/1.16m flops)
#   model_6/max_pooling2d_22/MaxPool (413.71k/413.71k flops)
#   model_6/conv2d_37/BiasAdd (198.29k/198.29k flops)
#   model_6/max_pooling2d_23/MaxPool (129.60k/129.60k flops)
#   model_6/batch_normalization_21/FusedBatchNormV3 (92.34k/92.34k flops)
#   model_6/conv2d_38/BiasAdd (69.70k/69.70k flops)
#   model_6/dense_20/MatMul (57.92k/57.92k flops)
#   model_6/batch_normalization_22/FusedBatchNormV3 (29.66k/29.66k flops)
#   model_6/conv2d_39/BiasAdd (24.58k/24.58k flops)
#   model_6/conv2d_40/BiasAdd (13.82k/13.82k flops)
#   model_6/conv2d_41/BiasAdd (3.36k/3.36k flops)
#   model_6/dense_19/BiasAdd (2.90k/2.90k flops)
#   model_6/dense_18/BiasAdd (2.77k/2.77k flops)
#   model_6/max_pooling2d_24/MaxPool (1.89k/1.89k flops)
#   model_6/batch_normalization_23/FusedBatchNormV3 (1.68k/1.68k flops)
#   model_6/dense_20/Softmax (50/50 flops)
#   model_6/dense_20/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.253884
# 2022-04-13 05:47:25.183847: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:25.183932: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:25.185376: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/641.18m flops)
#   model_7/conv2d_43/Conv2D (373.07m/373.07m flops)
#   model_7/conv2d_45/Conv2D (95.55m/95.55m flops)
#   model_7/conv2d_44/Conv2D (72.55m/72.55m flops)
#   model_7/conv2d_42/Conv2D (66.33m/66.33m flops)
#   model_7/conv2d_46/Conv2D (25.21m/25.21m flops)
#   model_7/dense_22/MatMul (6.48m/6.48m flops)
#   model_7/dense_21/MatMul (663.94k/663.94k flops)
#   model_7/max_pooling2d_25/MaxPool (571.90k/571.90k flops)
#   model_7/conv2d_42/BiasAdd (274.10k/274.10k flops)
#   model_7/max_pooling2d_26/MaxPool (147.60k/147.60k flops)
#   model_7/batch_normalization_24/FusedBatchNormV3 (127.65k/127.65k flops)
#   model_7/conv2d_43/BiasAdd (79.38k/79.38k flops)
#   model_7/dense_23/MatMul (44.48k/44.48k flops)
#   model_7/batch_normalization_25/FusedBatchNormV3 (33.78k/33.78k flops)
#   model_7/conv2d_44/BiasAdd (24.58k/24.58k flops)
#   model_7/conv2d_45/BiasAdd (13.82k/13.82k flops)
#   model_7/conv2d_46/BiasAdd (3.65k/3.65k flops)
#   model_7/dense_22/BiasAdd (2.22k/2.22k flops)
#   model_7/max_pooling2d_27/MaxPool (2.05k/2.05k flops)
#   model_7/batch_normalization_26/FusedBatchNormV3 (1.82k/1.82k flops)
#   model_7/dense_21/BiasAdd (1.46k/1.46k flops)
#   model_7/dense_23/Softmax (50/50 flops)
#   model_7/dense_23/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.733892
# 2022-04-13 05:47:25.686136: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:25.686220: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:25.687695: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/491.51m flops)
#   model_8/conv2d_48/Conv2D (250.91m/250.91m flops)
#   model_8/conv2d_50/Conv2D (95.55m/95.55m flops)
#   model_8/conv2d_49/Conv2D (71.66m/71.66m flops)
#   model_8/conv2d_47/Conv2D (45.16m/45.16m flops)
#   model_8/conv2d_51/Conv2D (18.80m/18.80m flops)
#   model_8/dense_25/MatMul (7.75m/7.75m flops)
#   model_8/dense_24/MatMul (669.12k/669.12k flops)
#   model_8/max_pooling2d_28/MaxPool (389.38k/389.38k flops)
#   model_8/conv2d_47/BiasAdd (186.62k/186.62k flops)
#   model_8/max_pooling2d_29/MaxPool (145.80k/145.80k flops)
#   model_8/batch_normalization_27/FusedBatchNormV3 (86.91k/86.91k flops)
#   model_8/conv2d_48/BiasAdd (78.41k/78.41k flops)
#   model_8/dense_26/MatMul (39.36k/39.36k flops)
#   model_8/batch_normalization_28/FusedBatchNormV3 (33.37k/33.37k flops)
#   model_8/conv2d_49/BiasAdd (24.58k/24.58k flops)
#   model_8/conv2d_50/BiasAdd (13.82k/13.82k flops)
#   model_8/conv2d_51/BiasAdd (2.72k/2.72k flops)
#   model_8/dense_25/BiasAdd (1.97k/1.97k flops)
#   model_8/dense_24/BiasAdd (1.97k/1.97k flops)
#   model_8/max_pooling2d_30/MaxPool (1.53k/1.53k flops)
#   model_8/batch_normalization_29/FusedBatchNormV3 (1.36k/1.36k flops)
#   model_8/dense_26/Softmax (50/50 flops)
#   model_8/dense_26/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.026564
# 2022-04-13 05:47:26.084250: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:26.084335: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:26.085747: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/581.10m flops)
#   model_9/conv2d_53/Conv2D (321.38m/321.38m flops)
#   model_9/conv2d_55/Conv2D (95.55m/95.55m flops)
#   model_9/conv2d_54/Conv2D (73.43m/73.43m flops)
#   model_9/conv2d_52/Conv2D (56.45m/56.45m flops)
#   model_9/conv2d_56/Conv2D (22.34m/22.34m flops)
#   model_9/dense_28/MatMul (10.07m/10.07m flops)
#   model_9/dense_27/MatMul (665.79k/665.79k flops)
#   model_9/max_pooling2d_31/MaxPool (486.72k/486.72k flops)
#   model_9/conv2d_52/BiasAdd (233.28k/233.28k flops)
#   model_9/max_pooling2d_32/MaxPool (149.40k/149.40k flops)
#   model_9/batch_normalization_30/FusedBatchNormV3 (108.64k/108.64k flops)
#   model_9/conv2d_53/BiasAdd (80.34k/80.34k flops)
#   model_9/dense_29/MatMul (61.12k/61.12k flops)
#   model_9/batch_normalization_31/FusedBatchNormV3 (34.20k/34.20k flops)
#   model_9/conv2d_54/BiasAdd (24.58k/24.58k flops)
#   model_9/conv2d_55/BiasAdd (13.82k/13.82k flops)
#   model_9/conv2d_56/BiasAdd (3.23k/3.23k flops)
#   model_9/dense_28/BiasAdd (3.06k/3.06k flops)
#   model_9/max_pooling2d_33/MaxPool (1.82k/1.82k flops)
#   model_9/dense_27/BiasAdd (1.65k/1.65k flops)
#   model_9/batch_normalization_32/FusedBatchNormV3 (1.62k/1.62k flops)
#   model_9/dense_29/Softmax (50/50 flops)
#   model_9/dense_29/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 3.224972
# 2022-04-13 05:47:26.494984: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:26.495069: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:26.496506: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.006ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.09b flops)
#   model_10/conv2d_58/Conv2D (648.15m/648.15m flops)
#   model_10/conv2d_60/Conv2D (169.87m/169.87m flops)
#   model_10/conv2d_59/Conv2D (141.00m/141.00m flops)
#   model_10/conv2d_57/Conv2D (87.44m/87.44m flops)
#   model_10/conv2d_61/Conv2D (33.84m/33.84m flops)
#   model_10/dense_31/MatMul (10.78m/10.78m flops)
#   model_10/dense_30/MatMul (2.00m/2.00m flops)
#   model_10/max_pooling2d_34/MaxPool (761.40k/761.40k flops)
#   model_10/conv2d_57/BiasAdd (361.34k/361.34k flops)
#   model_10/max_pooling2d_35/MaxPool (264.38k/264.38k flops)
#   model_10/batch_normalization_33/FusedBatchNormV3 (169.76k/169.76k flops)
#   model_10/conv2d_58/BiasAdd (137.90k/137.90k flops)
#   model_10/batch_normalization_34/FusedBatchNormV3 (59.98k/59.98k flops)
#   model_10/dense_32/MatMul (58.56k/58.56k flops)
#   model_10/conv2d_59/BiasAdd (38.40k/38.40k flops)
#   model_10/conv2d_60/BiasAdd (24.58k/24.58k flops)
#   model_10/max_pooling2d_36/MaxPool (4.90k/4.90k flops)
#   model_10/conv2d_61/BiasAdd (4.90k/4.90k flops)
#   model_10/dense_31/BiasAdd (2.93k/2.93k flops)
#   model_10/batch_normalization_35/FusedBatchNormV3 (1.90k/1.90k flops)
#   model_10/dense_30/BiasAdd (1.84k/1.84k flops)
#   model_10/dense_32/Softmax (50/50 flops)
#   model_10/dense_32/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 3.310732
# 2022-04-13 05:47:26.918579: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:26.918674: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:26.920174: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.007ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/1.19b flops)
#   model_11/conv2d_63/Conv2D (724.40m/724.40m flops)
#   model_11/conv2d_65/Conv2D (169.87m/169.87m flops)
#   model_11/conv2d_64/Conv2D (157.59m/157.59m flops)
#   model_11/conv2d_62/Conv2D (87.44m/87.44m flops)
#   model_11/conv2d_66/Conv2D (41.31m/41.31m flops)
#   model_11/dense_34/MatMul (4.75m/4.75m flops)
#   model_11/dense_33/MatMul (1.55m/1.55m flops)
#   model_11/max_pooling2d_37/MaxPool (761.40k/761.40k flops)
#   model_11/conv2d_62/BiasAdd (361.34k/361.34k flops)
#   model_11/max_pooling2d_38/MaxPool (295.49k/295.49k flops)
#   model_11/batch_normalization_36/FusedBatchNormV3 (169.76k/169.76k flops)
#   model_11/conv2d_63/BiasAdd (154.13k/154.13k flops)
#   model_11/batch_normalization_37/FusedBatchNormV3 (67.03k/67.03k flops)
#   model_11/dense_35/MatMul (40.64k/40.64k flops)
#   model_11/conv2d_64/BiasAdd (38.40k/38.40k flops)
#   model_11/conv2d_65/BiasAdd (24.58k/24.58k flops)
#   model_11/max_pooling2d_39/MaxPool (5.98k/5.98k flops)
#   model_11/conv2d_66/BiasAdd (5.98k/5.98k flops)
#   model_11/batch_normalization_38/FusedBatchNormV3 (2.32k/2.32k flops)
#   model_11/dense_34/BiasAdd (2.03k/2.03k flops)
#   model_11/dense_33/BiasAdd (1.17k/1.17k flops)
#   model_11/dense_35/Softmax (50/50 flops)
#   model_11/dense_35/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.939116
# 2022-04-13 05:47:27.288541: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:27.288617: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:27.290143: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/973.48m flops)
#   model_12/conv2d_68/Conv2D (522.41m/522.41m flops)
#   model_12/conv2d_70/Conv2D (169.87m/169.87m flops)
#   model_12/conv2d_69/Conv2D (127.18m/127.18m flops)
#   model_12/conv2d_67/Conv2D (78.14m/78.14m flops)
#   model_12/conv2d_71/Conv2D (61.21m/61.21m flops)
#   model_12/dense_37/MatMul (9.02m/9.02m flops)
#   model_12/dense_36/MatMul (3.94m/3.94m flops)
#   model_12/max_pooling2d_40/MaxPool (680.40k/680.40k flops)
#   model_12/conv2d_67/BiasAdd (322.90k/322.90k flops)
#   model_12/max_pooling2d_41/MaxPool (238.46k/238.46k flops)
#   model_12/batch_normalization_39/FusedBatchNormV3 (151.70k/151.70k flops)
#   model_12/conv2d_68/BiasAdd (124.38k/124.38k flops)
#   model_12/batch_normalization_40/FusedBatchNormV3 (54.10k/54.10k flops)
#   model_12/dense_38/MatMul (45.12k/45.12k flops)
#   model_12/conv2d_69/BiasAdd (38.40k/38.40k flops)
#   model_12/conv2d_70/BiasAdd (24.58k/24.58k flops)
#   model_12/max_pooling2d_42/MaxPool (8.86k/8.86k flops)
#   model_12/conv2d_71/BiasAdd (8.86k/8.86k flops)
#   model_12/batch_normalization_41/FusedBatchNormV3 (3.44k/3.44k flops)
#   model_12/dense_37/BiasAdd (2.26k/2.26k flops)
#   model_12/dense_36/BiasAdd (2.00k/2.00k flops)
#   model_12/dense_38/Softmax (50/50 flops)
#   model_12/dense_38/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.556556
# 2022-04-13 05:47:27.730176: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:27.730258: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:27.731728: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/851.12m flops)
#   model_13/conv2d_73/Conv2D (428.31m/428.31m flops)
#   model_13/conv2d_75/Conv2D (169.87m/169.87m flops)
#   model_13/conv2d_74/Conv2D (132.71m/132.71m flops)
#   model_13/conv2d_72/Conv2D (61.40m/61.40m flops)
#   model_13/conv2d_76/Conv2D (38.82m/38.82m flops)
#   model_13/dense_40/MatMul (15.27m/15.27m flops)
#   model_13/dense_39/MatMul (3.25m/3.25m flops)
#   model_13/max_pooling2d_43/MaxPool (534.60k/534.60k flops)
#   model_13/conv2d_72/BiasAdd (253.70k/253.70k flops)
#   model_13/max_pooling2d_44/MaxPool (248.83k/248.83k flops)
#   model_13/conv2d_73/BiasAdd (129.79k/129.79k flops)
#   model_13/batch_normalization_42/FusedBatchNormV3 (119.20k/119.20k flops)
#   model_13/dense_41/MatMul (58.56k/58.56k flops)
#   model_13/batch_normalization_43/FusedBatchNormV3 (56.45k/56.45k flops)
#   model_13/conv2d_74/BiasAdd (38.40k/38.40k flops)
#   model_13/conv2d_75/BiasAdd (24.58k/24.58k flops)
#   model_13/max_pooling2d_45/MaxPool (5.62k/5.62k flops)
#   model_13/conv2d_76/BiasAdd (5.62k/5.62k flops)
#   model_13/dense_40/BiasAdd (2.93k/2.93k flops)
#   model_13/dense_39/BiasAdd (2.61k/2.61k flops)
#   model_13/batch_normalization_44/FusedBatchNormV3 (2.18k/2.18k flops)
#   model_13/dense_41/Softmax (50/50 flops)
#   model_13/dense_41/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.710028
# 2022-04-13 05:47:28.213754: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:28.213838: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:28.215287: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.006ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/818.73m flops)
#   model_14/conv2d_78/Conv2D (405.60m/405.60m flops)
#   model_14/conv2d_80/Conv2D (169.87m/169.87m flops)
#   model_14/conv2d_79/Conv2D (103.68m/103.68m flops)
#   model_14/conv2d_77/Conv2D (74.42m/74.42m flops)
#   model_14/conv2d_81/Conv2D (53.25m/53.25m flops)
#   model_14/dense_43/MatMul (7.73m/7.73m flops)
#   model_14/dense_42/MatMul (2.60m/2.60m flops)
#   model_14/max_pooling2d_46/MaxPool (648.00k/648.00k flops)
#   model_14/conv2d_77/BiasAdd (307.52k/307.52k flops)
#   model_14/max_pooling2d_47/MaxPool (194.40k/194.40k flops)
#   model_14/batch_normalization_45/FusedBatchNormV3 (144.48k/144.48k flops)
#   model_14/conv2d_78/BiasAdd (101.40k/101.40k flops)
#   model_14/dense_44/MatMul (50.88k/50.88k flops)
#   model_14/batch_normalization_46/FusedBatchNormV3 (44.10k/44.10k flops)
#   model_14/conv2d_79/BiasAdd (38.40k/38.40k flops)
#   model_14/conv2d_80/BiasAdd (24.58k/24.58k flops)
#   model_14/max_pooling2d_48/MaxPool (7.70k/7.70k flops)
#   model_14/conv2d_81/BiasAdd (7.70k/7.70k flops)
#   model_14/batch_normalization_47/FusedBatchNormV3 (3.00k/3.00k flops)
#   model_14/dense_43/BiasAdd (2.54k/2.54k flops)
#   model_14/dense_42/BiasAdd (1.52k/1.52k flops)
#   model_14/dense_44/Softmax (50/50 flops)
#   model_14/dense_44/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.625548
# 2022-04-13 05:47:28.615204: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:47:28.615290: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:47:28.616715: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# ...
#   model_84/batch_normalization_255/FusedBatchNormV3 (538.72k/538.72k flops)
#   model_84/batch_normalization_256/FusedBatchNormV3 (260.74k/260.74k flops)
#   model_84/conv2d_429/BiasAdd (221.18k/221.18k flops)
#   model_84/conv2d_430/BiasAdd (185.86k/185.86k flops)
#   model_84/max_pooling2d_258/MaxPool (163.30k/163.30k flops)
#   model_84/conv2d_431/BiasAdd (89.60k/89.60k flops)
#   model_84/dense_254/MatMul (52.80k/52.80k flops)
#   model_84/batch_normalization_257/FusedBatchNormV3 (37.63k/37.63k flops)
#   model_84/dense_253/BiasAdd (2.64k/2.64k flops)
#   model_84/dense_252/BiasAdd (1.42k/1.42k flops)
#   model_84/dense_254/Softmax (50/50 flops)
#   model_84/dense_254/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 10.939148
# 2022-04-13 05:49:03.078805: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:49:03.078937: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:49:03.080652: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/4.34b flops)
#   model_85/conv2d_433/Conv2D (1.68b/1.68b flops)
#   model_85/conv2d_435/Conv2D (1.28b/1.28b flops)
#   model_85/conv2d_434/Conv2D (605.16m/605.16m flops)
#   model_85/conv2d_436/Conv2D (420.25m/420.25m flops)
#   model_85/conv2d_432/Conv2D (256.09m/256.09m flops)
#   model_85/dense_255/MatMul (70.52m/70.52m flops)
#   model_85/dense_256/MatMul (17.14m/17.14m flops)
#   model_85/max_pooling2d_259/MaxPool (2.30m/2.30m flops)
#   model_85/conv2d_432/BiasAdd (1.06m/1.06m flops)
#   model_85/max_pooling2d_260/MaxPool (924.77k/924.77k flops)
#   model_85/batch_normalization_258/FusedBatchNormV3 (511.78k/511.78k flops)
#   model_85/conv2d_433/BiasAdd (443.23k/443.23k flops)
#   model_85/conv2d_434/BiasAdd (221.18k/221.18k flops)
#   model_85/batch_normalization_259/FusedBatchNormV3 (206.42k/206.42k flops)
#   model_85/conv2d_435/BiasAdd (185.86k/185.86k flops)
#   model_85/max_pooling2d_261/MaxPool (110.81k/110.81k flops)
#   model_85/conv2d_436/BiasAdd (60.80k/60.80k flops)
#   model_85/dense_257/MatMul (59.84k/59.84k flops)
#   model_85/batch_normalization_260/FusedBatchNormV3 (25.54k/25.54k flops)
#   model_85/dense_256/BiasAdd (2.99k/2.99k flops)
#   model_85/dense_255/BiasAdd (2.86k/2.86k flops)
#   model_85/dense_257/Softmax (50/50 flops)
#   model_85/dense_257/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 12.275548
# 2022-04-13 05:49:06.164316: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:49:06.164432: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:49:06.166215: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/5.42b flops)
#   model_86/conv2d_438/Conv2D (2.52b/2.52b flops)
#   model_86/conv2d_440/Conv2D (1.28b/1.28b flops)
#   model_86/conv2d_439/Conv2D (883.85m/883.85m flops)
#   model_86/conv2d_441/Conv2D (409.19m/409.19m flops)
#   model_86/conv2d_437/Conv2D (262.83m/262.83m flops)
#   model_86/dense_258/MatMul (44.12m/44.12m flops)
#   model_86/dense_259/MatMul (8.54m/8.54m flops)
#   model_86/max_pooling2d_262/MaxPool (2.36m/2.36m flops)
#   model_86/max_pooling2d_263/MaxPool (1.35m/1.35m flops)
#   model_86/conv2d_437/BiasAdd (1.09m/1.09m flops)
#   model_86/conv2d_438/BiasAdd (647.35k/647.35k flops)
#   model_86/batch_normalization_261/FusedBatchNormV3 (525.25k/525.25k flops)
#   model_86/batch_normalization_262/FusedBatchNormV3 (301.48k/301.48k flops)
#   model_86/conv2d_439/BiasAdd (221.18k/221.18k flops)
#   model_86/conv2d_440/BiasAdd (185.86k/185.86k flops)
#   model_86/max_pooling2d_264/MaxPool (107.89k/107.89k flops)
#   model_86/conv2d_441/BiasAdd (59.20k/59.20k flops)
#   model_86/dense_260/MatMul (46.40k/46.40k flops)
#   model_86/batch_normalization_263/FusedBatchNormV3 (24.86k/24.86k flops)
#   model_86/dense_259/BiasAdd (2.32k/2.32k flops)
#   model_86/dense_258/BiasAdd (1.84k/1.84k flops)
#   model_86/dense_260/Softmax (50/50 flops)
#   model_86/dense_260/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 11.898844
# 2022-04-13 05:49:08.205380: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:49:08.205452: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:49:08.207226: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/5.35b flops)
#   model_87/conv2d_443/Conv2D (2.45b/2.45b flops)
#   model_87/conv2d_445/Conv2D (1.28b/1.28b flops)
#   model_87/conv2d_444/Conv2D (955.51m/955.51m flops)
#   model_87/conv2d_446/Conv2D (387.07m/387.07m flops)
#   model_87/conv2d_442/Conv2D (235.87m/235.87m flops)
#   model_87/dense_261/MatMul (25.76m/25.76m flops)
#   model_87/dense_262/MatMul (6.14m/6.14m flops)
#   model_87/max_pooling2d_265/MaxPool (2.12m/2.12m flops)
#   model_87/max_pooling2d_266/MaxPool (1.46m/1.46m flops)
#   model_87/conv2d_442/BiasAdd (974.68k/974.68k flops)
#   model_87/conv2d_443/BiasAdd (699.84k/699.84k flops)
#   model_87/batch_normalization_264/FusedBatchNormV3 (471.38k/471.38k flops)
#   model_87/batch_normalization_265/FusedBatchNormV3 (325.92k/325.92k flops)
#   model_87/conv2d_444/BiasAdd (221.18k/221.18k flops)
#   model_87/conv2d_445/BiasAdd (185.86k/185.86k flops)
#   model_87/max_pooling2d_267/MaxPool (102.06k/102.06k flops)
#   model_87/conv2d_446/BiasAdd (56.00k/56.00k flops)
#   model_87/dense_263/MatMul (54.08k/54.08k flops)
#   model_87/batch_normalization_266/FusedBatchNormV3 (23.52k/23.52k flops)
#   model_87/dense_262/BiasAdd (2.70k/2.70k flops)
#   model_87/dense_261/BiasAdd (1.14k/1.14k flops)
#   model_87/dense_263/Softmax (50/50 flops)
#   model_87/dense_263/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 11.878716
# 2022-04-13 05:49:09.458411: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:49:09.458528: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:49:09.460218: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/5.54b flops)
#   model_88/conv2d_448/Conv2D (2.41b/2.41b flops)
#   model_88/conv2d_450/Conv2D (1.28b/1.28b flops)
#   model_88/conv2d_449/Conv2D (995.33m/995.33m flops)
#   model_88/conv2d_451/Conv2D (519.78m/519.78m flops)
#   model_88/conv2d_447/Conv2D (222.39m/222.39m flops)
#   model_88/dense_264/MatMul (88.20m/88.20m flops)
#   model_88/dense_265/MatMul (17.14m/17.14m flops)
#   model_88/max_pooling2d_268/MaxPool (2.00m/2.00m flops)
#   model_88/max_pooling2d_269/MaxPool (1.52m/1.52m flops)
#   model_88/conv2d_447/BiasAdd (918.98k/918.98k flops)
#   model_88/conv2d_448/BiasAdd (729.00k/729.00k flops)
#   model_88/batch_normalization_267/FusedBatchNormV3 (444.44k/444.44k flops)
#   model_88/batch_normalization_268/FusedBatchNormV3 (339.50k/339.50k flops)
#   model_88/conv2d_449/BiasAdd (221.18k/221.18k flops)
#   model_88/conv2d_450/BiasAdd (185.86k/185.86k flops)
#   model_88/max_pooling2d_270/MaxPool (137.05k/137.05k flops)
#   model_88/conv2d_451/BiasAdd (75.20k/75.20k flops)
#   model_88/dense_266/MatMul (59.20k/59.20k flops)
#   model_88/batch_normalization_269/FusedBatchNormV3 (31.58k/31.58k flops)
#   model_88/dense_265/BiasAdd (2.96k/2.96k flops)
#   model_88/dense_264/BiasAdd (2.90k/2.90k flops)
#   model_88/dense_266/Softmax (50/50 flops)
#   model_88/dense_266/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 13.941948
# 2022-04-13 05:49:13.172097: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:49:13.172227: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:49:13.173958: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.02ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/6.36b flops)
#   model_89/conv2d_453/Conv2D (3.34b/3.34b flops)
#   model_89/conv2d_455/Conv2D (1.28b/1.28b flops)
#   model_89/conv2d_454/Conv2D (971.44m/971.44m flops)
#   model_89/conv2d_456/Conv2D (364.95m/364.95m flops)
#   model_89/conv2d_452/Conv2D (316.74m/316.74m flops)
#   model_89/dense_267/MatMul (56.45m/56.45m flops)
#   model_89/dense_268/MatMul (14.78m/14.78m flops)
#   model_89/max_pooling2d_271/MaxPool (2.85m/2.85m flops)
#   model_89/max_pooling2d_272/MaxPool (1.48m/1.48m flops)
#   model_89/conv2d_452/BiasAdd (1.31m/1.31m flops)
#   model_89/conv2d_453/BiasAdd (711.50k/711.50k flops)
#   model_89/batch_normalization_270/FusedBatchNormV3 (633.00k/633.00k flops)
#   model_89/batch_normalization_271/FusedBatchNormV3 (331.35k/331.35k flops)
#   model_89/conv2d_454/BiasAdd (221.18k/221.18k flops)
#   model_89/conv2d_455/BiasAdd (185.86k/185.86k flops)
#   model_89/max_pooling2d_273/MaxPool (96.23k/96.23k flops)
#   model_89/dense_269/MatMul (56.00k/56.00k flops)
#   model_89/conv2d_456/BiasAdd (52.80k/52.80k flops)
#   model_89/batch_normalization_272/FusedBatchNormV3 (22.18k/22.18k flops)
#   model_89/dense_268/BiasAdd (2.80k/2.80k flops)
#   model_89/dense_267/BiasAdd (2.64k/2.64k flops)
#   model_89/dense_269/Softmax (50/50 flops)
#   model_89/dense_269/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
