# %%
import os
import csv
import numpy as np
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from itertools import product
from keras_flops import get_flops
print("TensorFlow version:", tf.__version__)



def VGG19(input_shape):
    
    """
    Implementation of the popular ResNet50 the following architecture:
    CONV2D -> CONV2D -> MAXPOOL -> CONV2D -> CONV2D -> MAXPOOL -> CONV2D -> CONV2D -> CONV2D -> CONV2D -> MAXPOOL->
    CONV2D -> CONV2D -> CONV2D -> CONV2D -> MAXPOOL -> CONV2D -> CONV2D -> CONV2D -> CONV2D -> MAXPOOL ->
    CONV2D -> CONV2D -> CONV2D -> CONV2D -> MAXPOOL -> Flatten -> Dense -> Dense -> TopLayer
    

    Arguments:
    input_shape -- shape of the images of the dataset
    
    Returns:
    model -- a Model() instance in Keras
    """
    
    X_input = Input(input_shape)
    #Block 1
    X = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(X_input)
    X = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(X)
    X = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(X)
    #Block 2
    X = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(X)
    X = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(X)
    X = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(X)
    #Block 3
    X = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(X)
    X = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(X)
    X = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(X)
    X = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv4')(X)
    X = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(X)
    #Block 4
    X = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(X)
    X = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(X)
    X = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(X)
    X = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv4')(X)    
    X = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(X)
    #Block 5
    X = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(X)
    X = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(X)
    X = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(X)
    X = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv4')(X)    
    X = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(X)
    
    
    X = Flatten(name='flatten')(X)
    X = Dense(4096, activation='relu', name='fc1')(X)
    X = Dense(4096, activation='relu', name='fc2')(X)    
    
    # 输出层
    outputs = Dense(10, activation='softmax')(X)
    
    model = Model(inputs=X_input, outputs=outputs)

    
    return model

model_num = 1
input_shape_range =range(32,224,32)

with open("para_count_vgg19.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "FLOPs", "Total_params", "Memory"],])
          
for shape_x in input_shape_range:
    shape_y = shape_x

    input_shape = (shape_x, shape_y, 1)
    model = VGG19(input_shape)
    model.summary()
    # how to compute the memory allocated by the activations of a model
    batch = 1
    shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
    else 1 for s in l.output_shape])) 
    for l in model.layers]))
    memory = (shapes_count * 4 * batch)/10**6
    print(memory)

    Total_params = round(model.count_params()/10 ** 6,2)
    #FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
    with open("para_count_vgg19.csv","a+") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerows([[model_num, shape_x, shape_y, FLOPs, Total_params, memory],])

        model_num = model_num + 1
# Out:
# 2022-04-02 03:46:22.752601: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-04-02 03:46:22.752633: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# TensorFlow version: 2.6.0
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 1)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        640
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              2101248
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense (Dense)                (None, 10)                40970
# =================================================================
# Total params: 38,946,762
# Trainable params: 38,946,762
# Non-trainable params: 0
# _________________________________________________________________
# 1.372204
# 2022-04-02 03:46:23.752032: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-04-02 03:46:23.752063: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-02 03:46:23.752077: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2022-04-02 03:46:23.752238: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 64, 64, 1)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        640
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              8392704
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 45,238,218
# Trainable params: 45,238,218
# Non-trainable params: 0
# _________________________________________________________________
# 5.39038
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 96, 96, 1)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 96, 96, 64)        640
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 96, 96, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 48, 48, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 48, 48, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 48, 48, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 24, 24, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 24, 24, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 24, 24, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 24, 24, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 24, 24, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 12, 12, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 12, 12, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              18878464
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 55,723,978
# Trainable params: 55,723,978
# Non-trainable params: 0
# _________________________________________________________________
# 12.08734
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 128, 128, 1)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 128, 64)      640
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 128, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              33558528
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 70,404,042
# Trainable params: 70,404,042
# Non-trainable params: 0
# _________________________________________________________________
# 21.463084
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 160, 160, 1)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 160, 160, 64)      640
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 160, 160, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 80, 80, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 80, 80, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 80, 80, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 40, 40, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 40, 40, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 40, 40, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 40, 40, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 40, 40, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 20, 20, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 20, 20, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 10, 10, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 5, 5, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              52432896
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 89,278,410
# Trainable params: 89,278,410
# Non-trainable params: 0
# _________________________________________________________________
# 33.517612
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 192, 192, 1)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 192, 192, 64)      640
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 192, 192, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 96, 96, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 96, 96, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 96, 96, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 48, 48, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 48, 48, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 48, 48, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 48, 48, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 48, 48, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 24, 24, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 24, 24, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 24, 24, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 24, 24, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 24, 24, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 12, 12, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              75501568
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 112,347,082
# Trainable params: 112,347,082
# Non-trainable params: 0
# _________________________________________________________________
# 48.250924

# %%
import os
import csv
import numpy as np
import tensorflow as tf
import keras
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from itertools import product
from keras_flops import get_flops

def get_total_number_of_neurons(model, include_output_layer):
    '''
    Args:
        model: Keras model
        include_output_layer: A boolean parameter. Whether or not to include output layer's neurons into the calculation

    Returns: number of neurons in the given model
    '''
    num_layers = len(model.layers)
    total_num_of_neurons = 0
    for layer_index in range(num_layers):
        layer = model.layers[layer_index]
        # since we multiply layer output dimensions, initial value is set to 1.
        num_neurons_in_layer = 1
        for i in range(1, len(layer.output.shape)):
            try:
                # when it is a valid layer to count neurons, an output dimension of the layer can be convertible to int.
                num_neurons_in_layer *= int(layer.output.shape[i])
            except Exception:
                # if the output dimension of layer cannot be convertible to int,
                # just pass that layer since it is not a valid layer to count neurons
                pass
        # if num_neurons_in_layer is not still 1, it means we have a valid layer to count neurons
        if not num_neurons_in_layer == 1:
            # when it is an output layer
            if layer_index == (num_layers - 1):
                if include_output_layer:
                    total_num_of_neurons += num_neurons_in_layer
            else:  # when it is not an output layer
                total_num_of_neurons += num_neurons_in_layer
    return total_num_of_neurons

model_num = 1
input_shape_range =range(48,512,34)

with open("para_count_vgg19.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "step","number_of_layers", "FLOPs_G", "Total_params_M", "Memory_M", "total_num_of_neurons_M"],])
path = "../vgg19_h5" #文件夹目录
files= os.listdir(path) #得到文件夹下的所有文件名称

for shape_x in input_shape_range:
    shape_y = shape_x
    for step in range(1,11):
        file = "vgg19_{input_x}_{input_y}_{step}.h5".format(input_x=shape_x,input_y=shape_y,step=step)
        if file in files: #遍历文件夹
            model_name = str(file)
            if not os.path.isdir(file): #判断是否是文件夹，不是文件夹才打开
                model = keras.models.load_model("../vgg19_h5/{}".format(model_name))
                num_neurons = get_total_number_of_neurons(model= model, include_output_layer= True)
                num_neurons_M = num_neurons/10**6
                # how to compute the memory allocated by the activations of a model
                batch = 1
                shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
                else 1 for s in l.output_shape])) 
                for l in model.layers]))
                memory = (shapes_count * 4 * batch)/10**6
                print(memory)
                layers_length = len(model.layers)
                Total_params = round(model.count_params()/10 ** 6,2)
                FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
                with open("para_count_vgg19.csv","a+") as csvfile:
                    writer = csv.writer(csvfile)
                    writer.writerows([[model_num, shape_x, shape_y, step, layers_length, FLOPs, Total_params, memory, num_neurons_M],])

                    model_num = model_num + 1
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.184988
# 2022-04-13 05:58:16.157965: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:58:16.158114: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:58:16.179892: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.006ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# WARNING:tensorflow:From /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py:5063: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/636.93m flops)
#   model/block3_conv4/Conv2D (73.15m/73.15m flops)
#   model/block3_conv3/Conv2D (72.00m/72.00m flops)
#   model/block4_conv4/Conv2D (68.02m/68.02m flops)
#   model/block4_conv3/Conv2D (67.47m/67.47m flops)
#   model/block3_conv2/Conv2D (66.24m/66.24m flops)
#   model/block1_conv2/Conv2D (61.93m/61.93m flops)
#   model/block4_conv2/Conv2D (41.82m/41.82m flops)
#   model/block2_conv2/Conv2D (36.50m/36.50m flops)
#   model/block3_conv1/Conv2D (29.15m/29.15m flops)
#   model/block4_conv1/Conv2D (21.95m/21.95m flops)
#   model/block2_conv1/Conv2D (19.91m/19.91m flops)
#   model/block5_conv4/Conv2D (18.73m/18.73m flops)
#   model/block5_conv3/Conv2D (18.65m/18.65m flops)
#   model/block5_conv2/Conv2D (18.58m/18.58m flops)
#   model/block5_conv1/Conv2D (17.85m/17.85m flops)
#   model/fc2/MatMul (2.44m/2.44m flops)
#   model/fc1/MatMul (1.13m/1.13m flops)
#   model/block1_conv1/Conv2D (1.03m/1.03m flops)
#   model/block1_conv2/BiasAdd (61.44k/61.44k flops)
#   model/block1_pool/MaxPool (61.44k/61.44k flops)
#   model/block1_conv1/BiasAdd (57.34k/57.34k flops)
#   model/block2_pool/MaxPool (28.16k/28.16k flops)
#   model/block2_conv2/BiasAdd (28.16k/28.16k flops)
#   model/dense/MatMul (22.08k/22.08k flops)
#   model/block2_conv1/BiasAdd (18.43k/18.43k flops)
#   model/block3_conv4/BiasAdd (16.26k/16.26k flops)
#   model/block3_pool/MaxPool (16.26k/16.26k flops)
#   model/block3_conv3/BiasAdd (16.00k/16.00k flops)
#   model/block3_conv2/BiasAdd (16.00k/16.00k flops)
#   model/block3_conv1/BiasAdd (14.72k/14.72k flops)
#   model/block4_pool/MaxPool (7.81k/7.81k flops)
#   model/block4_conv4/BiasAdd (7.81k/7.81k flops)
#   model/block4_conv3/BiasAdd (7.74k/7.74k flops)
#   model/block4_conv2/BiasAdd (7.74k/7.74k flops)
#   model/block4_conv1/BiasAdd (4.80k/4.80k flops)
#   model/block5_conv3/BiasAdd (2.04k/2.04k flops)
#   model/block5_conv4/BiasAdd (2.04k/2.04k flops)
#   model/block5_pool/MaxPool (2.04k/2.04k flops)
#   model/block5_conv1/BiasAdd (2.03k/2.03k flops)
#   model/block5_conv2/BiasAdd (2.03k/2.03k flops)
#   model/fc1/BiasAdd (1.10k/1.10k flops)
#   model/fc2/BiasAdd (1.10k/1.10k flops)
#   model/dense/Softmax (50/50 flops)
#   model/dense/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.169468
# 2022-04-13 05:58:17.363442: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:58:17.363513: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:58:17.365243: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/607.32m flops)
#   model_1/block4_conv4/Conv2D (71.71m/71.71m flops)
#   model_1/block4_conv3/Conv2D (65.40m/65.40m flops)
#   model_1/block1_conv2/Conv2D (62.01m/62.01m flops)
#   model_1/block3_conv4/Conv2D (59.90m/59.90m flops)
#   model_1/block4_conv2/Conv2D (58.83m/58.83m flops)
#   model_1/block3_conv3/Conv2D (49.84m/49.84m flops)
#   model_1/block3_conv2/Conv2D (41.69m/41.69m flops)
#   model_1/block2_conv2/Conv2D (39.56m/39.56m flops)
#   model_1/block4_conv1/Conv2D (32.26m/32.26m flops)
#   model_1/block3_conv1/Conv2D (23.25m/23.25m flops)
#   model_1/block2_conv1/Conv2D (19.78m/19.78m flops)
#   model_1/block5_conv4/Conv2D (18.73m/18.73m flops)
#   model_1/block5_conv3/Conv2D (18.73m/18.73m flops)
#   model_1/block5_conv2/Conv2D (18.65m/18.65m flops)
#   model_1/block5_conv1/Conv2D (18.29m/18.29m flops)
#   model_1/fc2/MatMul (5.40m/5.40m flops)
#   model_1/fc1/MatMul (1.81m/1.81m flops)
#   model_1/block1_conv1/Conv2D (1.07m/1.07m flops)
#   model_1/block1_conv1/BiasAdd (59.39k/59.39k flops)
#   model_1/block1_conv2/BiasAdd (59.39k/59.39k flops)
#   model_1/block1_pool/MaxPool (59.39k/59.39k flops)
#   model_1/dense_1/MatMul (30.40k/30.40k flops)
#   model_1/block2_pool/MaxPool (29.70k/29.70k flops)
#   model_1/block2_conv2/BiasAdd (29.70k/29.70k flops)
#   model_1/block2_conv1/BiasAdd (18.94k/18.94k flops)
#   model_1/block3_conv4/BiasAdd (16.00k/16.00k flops)
#   model_1/block3_pool/MaxPool (16.00k/16.00k flops)
#   model_1/block3_conv3/BiasAdd (13.31k/13.31k flops)
#   model_1/block3_conv2/BiasAdd (13.31k/13.31k flops)
#   model_1/block3_conv1/BiasAdd (11.14k/11.14k flops)
#   model_1/block4_pool/MaxPool (8.00k/8.00k flops)
#   model_1/block4_conv4/BiasAdd (8.00k/8.00k flops)
#   model_1/block4_conv3/BiasAdd (7.97k/7.97k flops)
#   model_1/block4_conv2/BiasAdd (7.30k/7.30k flops)
#   model_1/block4_conv1/BiasAdd (7.17k/7.17k flops)
#   model_1/block5_conv2/BiasAdd (2.04k/2.04k flops)
#   model_1/block5_conv3/BiasAdd (2.04k/2.04k flops)
#   model_1/block5_conv4/BiasAdd (2.04k/2.04k flops)
#   model_1/block5_pool/MaxPool (2.04k/2.04k flops)
#   model_1/block5_conv1/BiasAdd (2.03k/2.03k flops)
#   model_1/fc1/BiasAdd (1.78k/1.78k flops)
#   model_1/fc2/BiasAdd (1.52k/1.52k flops)
#   model_1/dense_1/Softmax (50/50 flops)
#   model_1/dense_1/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.263612
# 2022-04-13 05:58:18.676811: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:58:18.676884: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:58:18.678607: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/708.72m flops)
#   model_2/block4_conv4/Conv2D (74.91m/74.91m flops)
#   model_2/block4_conv3/Conv2D (72.85m/72.85m flops)
#   model_2/block3_conv4/Conv2D (70.85m/70.85m flops)
#   model_2/block2_conv2/Conv2D (68.51m/68.51m flops)
#   model_2/block3_conv3/Conv2D (68.01m/68.01m flops)
#   model_2/block1_conv2/Conv2D (64.14m/64.14m flops)
#   model_2/block4_conv2/Conv2D (62.00m/62.00m flops)
#   model_2/block3_conv2/Conv2D (50.87m/50.87m flops)
#   model_2/block2_conv1/Conv2D (32.62m/32.62m flops)
#   model_2/block4_conv1/Conv2D (31.25m/31.25m flops)
#   model_2/block3_conv1/Conv2D (26.71m/26.71m flops)
#   model_2/block5_conv4/Conv2D (18.73m/18.73m flops)
#   model_2/block5_conv3/Conv2D (18.73m/18.73m flops)
#   model_2/block5_conv2/Conv2D (18.73m/18.73m flops)
#   model_2/block5_conv1/Conv2D (18.73m/18.73m flops)
#   model_2/fc2/MatMul (7.46m/7.46m flops)
#   model_2/fc1/MatMul (2.11m/2.11m flops)
#   model_2/block1_conv1/Conv2D (1.07m/1.07m flops)
#   model_2/block1_conv2/BiasAdd (61.44k/61.44k flops)
#   model_2/block1_pool/MaxPool (61.44k/61.44k flops)
#   model_2/block1_conv1/BiasAdd (59.39k/59.39k flops)
#   model_2/dense_2/MatMul (36.16k/36.16k flops)
#   model_2/block2_pool/MaxPool (32.26k/32.26k flops)
#   model_2/block2_conv2/BiasAdd (32.26k/32.26k flops)
#   model_2/block2_conv1/BiasAdd (30.21k/30.21k flops)
#   model_2/block3_conv4/BiasAdd (16.00k/16.00k flops)
#   model_2/block3_pool/MaxPool (16.00k/16.00k flops)
#   model_2/block3_conv3/BiasAdd (15.74k/15.74k flops)
#   model_2/block3_conv2/BiasAdd (15.36k/15.36k flops)
#   model_2/block3_conv1/BiasAdd (11.78k/11.78k flops)
#   model_2/block4_pool/MaxPool (8.16k/8.16k flops)
#   model_2/block4_conv4/BiasAdd (8.16k/8.16k flops)
#   model_2/block4_conv3/BiasAdd (8.16k/8.16k flops)
#   model_2/block4_conv2/BiasAdd (7.94k/7.94k flops)
#   model_2/block4_conv1/BiasAdd (6.94k/6.94k flops)
#   model_2/fc1/BiasAdd (2.06k/2.06k flops)
#   model_2/block5_conv1/BiasAdd (2.04k/2.04k flops)
#   model_2/block5_conv2/BiasAdd (2.04k/2.04k flops)
#   model_2/block5_conv3/BiasAdd (2.04k/2.04k flops)
#   model_2/block5_conv4/BiasAdd (2.04k/2.04k flops)
#   model_2/block5_pool/MaxPool (2.04k/2.04k flops)
#   model_2/fc2/BiasAdd (1.81k/1.81k flops)
#   model_2/dense_2/Softmax (50/50 flops)
#   model_2/dense_2/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.004316
# 2022-04-13 05:58:20.179376: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:58:20.179488: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:58:20.181193: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/528.84m flops)
#   model_3/block2_conv2/Conv2D (70.85m/70.85m flops)
#   model_3/block4_conv4/Conv2D (63.34m/63.34m flops)
#   model_3/block4_conv3/Conv2D (60.13m/60.13m flops)
#   model_3/block3_conv4/Conv2D (46.99m/46.99m flops)
#   model_3/block4_conv2/Conv2D (42.25m/42.25m flops)
#   model_3/block3_conv3/Conv2D (41.51m/41.51m flops)
#   model_3/block3_conv2/Conv2D (33.55m/33.55m flops)
#   model_3/block1_conv2/Conv2D (25.07m/25.07m flops)
#   model_3/block2_conv1/Conv2D (22.86m/22.86m flops)
#   model_3/block3_conv1/Conv2D (22.86m/22.86m flops)
#   model_3/block4_conv1/Conv2D (19.34m/19.34m flops)
#   model_3/block5_conv4/Conv2D (17.00m/17.00m flops)
#   model_3/block5_conv3/Conv2D (16.73m/16.73m flops)
#   model_3/block5_conv2/Conv2D (16.45m/16.45m flops)
#   model_3/block5_conv1/Conv2D (16.18m/16.18m flops)
#   model_3/fc2/MatMul (10.07m/10.07m flops)
#   model_3/fc1/MatMul (2.68m/2.68m flops)
#   model_3/block1_conv1/Conv2D (626.69k/626.69k flops)
#   model_3/block1_conv2/BiasAdd (40.96k/40.96k flops)
#   model_3/block1_pool/MaxPool (40.96k/40.96k flops)
#   model_3/dense_3/MatMul (36.80k/36.80k flops)
#   model_3/block1_conv1/BiasAdd (34.82k/34.82k flops)
#   model_3/block2_pool/MaxPool (31.74k/31.74k flops)
#   model_3/block2_conv2/BiasAdd (31.74k/31.74k flops)
#   model_3/block2_conv1/BiasAdd (31.74k/31.74k flops)
#   model_3/block3_conv4/BiasAdd (13.18k/13.18k flops)
#   model_3/block3_pool/MaxPool (13.18k/13.18k flops)
#   model_3/block3_conv3/BiasAdd (12.67k/12.67k flops)
#   model_3/block3_conv2/BiasAdd (11.65k/11.65k flops)
#   model_3/block3_conv1/BiasAdd (10.24k/10.24k flops)
#   model_3/block4_pool/MaxPool (7.58k/7.58k flops)
#   model_3/block4_conv4/BiasAdd (7.58k/7.58k flops)
#   model_3/block4_conv3/BiasAdd (7.42k/7.42k flops)
#   model_3/block4_conv2/BiasAdd (7.20k/7.20k flops)
#   model_3/block4_conv1/BiasAdd (5.22k/5.22k flops)
#   model_3/fc1/BiasAdd (2.74k/2.74k flops)
#   model_3/block5_conv4/BiasAdd (1.96k/1.96k flops)
#   model_3/block5_pool/MaxPool (1.96k/1.96k flops)
#   model_3/block5_conv2/BiasAdd (1.93k/1.93k flops)
#   model_3/block5_conv3/BiasAdd (1.93k/1.93k flops)
#   model_3/block5_conv1/BiasAdd (1.90k/1.90k flops)
#   model_3/fc2/BiasAdd (1.84k/1.84k flops)
#   model_3/dense_3/Softmax (50/50 flops)
#   model_3/dense_3/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.057932
# 2022-04-13 05:58:21.569424: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:58:21.569498: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:58:21.571170: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/570.89m flops)
#   model_4/block3_conv4/Conv2D (73.16m/73.16m flops)
#   model_4/block3_conv3/Conv2D (73.16m/73.16m flops)
#   model_4/block3_conv2/Conv2D (68.51m/68.51m flops)
#   model_4/block4_conv4/Conv2D (53.31m/53.31m flops)
#   model_4/block2_conv2/Conv2D (47.85m/47.85m flops)
#   model_4/block4_conv3/Conv2D (39.15m/39.15m flops)
#   model_4/block3_conv1/Conv2D (32.08m/32.08m flops)
#   model_4/block1_conv2/Conv2D (31.85m/31.85m flops)
#   model_4/block4_conv2/Conv2D (31.61m/31.61m flops)
#   model_4/block4_conv1/Conv2D (22.50m/22.50m flops)
#   model_4/block2_conv1/Conv2D (19.46m/19.46m flops)
#   model_4/block5_conv4/Conv2D (18.51m/18.51m flops)
#   model_4/block5_conv3/Conv2D (18.07m/18.07m flops)
#   model_4/block5_conv2/Conv2D (17.71m/17.71m flops)
#   model_4/block5_conv1/Conv2D (17.21m/17.21m flops)
#   model_4/fc2/MatMul (4.24m/4.24m flops)
#   model_4/fc1/MatMul (1.48m/1.48m flops)
#   model_4/block1_conv1/Conv2D (663.55k/663.55k flops)
#   model_4/block1_conv2/BiasAdd (49.15k/49.15k flops)
#   model_4/block1_pool/MaxPool (49.15k/49.15k flops)
#   model_4/block1_conv1/BiasAdd (36.86k/36.86k flops)
#   model_4/block2_pool/MaxPool (30.21k/30.21k flops)
#   model_4/block2_conv2/BiasAdd (30.21k/30.21k flops)
#   model_4/dense_4/MatMul (29.12k/29.12k flops)
#   model_4/block2_conv1/BiasAdd (22.53k/22.53k flops)
#   model_4/block3_conv3/BiasAdd (16.13k/16.13k flops)
#   model_4/block3_conv2/BiasAdd (16.13k/16.13k flops)
#   model_4/block3_conv4/BiasAdd (16.13k/16.13k flops)
#   model_4/block3_pool/MaxPool (16.13k/16.13k flops)
#   model_4/block3_conv1/BiasAdd (15.10k/15.10k flops)
#   model_4/block4_conv4/BiasAdd (7.71k/7.71k flops)
#   model_4/block4_pool/MaxPool (7.71k/7.71k flops)
#   model_4/block4_conv3/BiasAdd (6.14k/6.14k flops)
#   model_4/block4_conv2/BiasAdd (5.66k/5.66k flops)
#   model_4/block4_conv1/BiasAdd (4.96k/4.96k flops)
#   model_4/block5_conv4/BiasAdd (2.03k/2.03k flops)
#   model_4/block5_pool/MaxPool (2.03k/2.03k flops)
#   model_4/block5_conv3/BiasAdd (2.02k/2.02k flops)
#   model_4/block5_conv2/BiasAdd (1.98k/1.98k flops)
#   model_4/block5_conv1/BiasAdd (1.98k/1.98k flops)
#   model_4/fc1/BiasAdd (1.46k/1.46k flops)
#   model_4/fc2/BiasAdd (1.46k/1.46k flops)
#   model_4/dense_4/Softmax (50/50 flops)
#   model_4/dense_4/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.980476
# 2022-04-13 05:58:22.793584: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:58:22.793656: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:58:22.795384: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/589.83m flops)
#   model_5/block4_conv4/Conv2D (74.62m/74.62m flops)
#   model_5/block4_conv3/Conv2D (69.64m/69.64m flops)
#   model_5/block3_conv4/Conv2D (66.34m/66.34m flops)
#   model_5/block3_conv3/Conv2D (63.07m/63.07m flops)
#   model_5/block4_conv2/Conv2D (63.06m/63.06m flops)
#   model_5/block2_conv2/Conv2D (46.08m/46.08m flops)
#   model_5/block3_conv2/Conv2D (34.74m/34.74m flops)
#   model_5/block4_conv1/Conv2D (32.33m/32.33m flops)
#   model_5/block1_conv2/Conv2D (23.59m/23.59m flops)
#   model_5/block5_conv4/Conv2D (18.73m/18.73m flops)
#   model_5/block5_conv3/Conv2D (18.73m/18.73m flops)
#   model_5/block5_conv2/Conv2D (18.73m/18.73m flops)
#   model_5/block5_conv1/Conv2D (18.73m/18.73m flops)
#   model_5/block2_conv1/Conv2D (18.43m/18.43m flops)
#   model_5/block3_conv1/Conv2D (14.98m/14.98m flops)
#   model_5/fc2/MatMul (5.14m/5.14m flops)
#   model_5/fc1/MatMul (1.97m/1.97m flops)
#   model_5/block1_conv1/Conv2D (589.82k/589.82k flops)
#   model_5/block1_conv2/BiasAdd (40.96k/40.96k flops)
#   model_5/block1_pool/MaxPool (40.96k/40.96k flops)
#   model_5/block1_conv1/BiasAdd (32.77k/32.77k flops)
#   model_5/dense_5/MatMul (26.56k/26.56k flops)
#   model_5/block2_pool/MaxPool (25.60k/25.60k flops)
#   model_5/block2_conv2/BiasAdd (25.60k/25.60k flops)
#   model_5/block2_conv1/BiasAdd (25.60k/25.60k flops)
#   model_5/block3_conv4/BiasAdd (15.62k/15.62k flops)
#   model_5/block3_pool/MaxPool (15.62k/15.62k flops)
#   model_5/block3_conv3/BiasAdd (15.10k/15.10k flops)
#   model_5/block3_conv2/BiasAdd (14.85k/14.85k flops)
#   model_5/block3_conv1/BiasAdd (8.32k/8.32k flops)
#   model_5/block4_pool/MaxPool (8.16k/8.16k flops)
#   model_5/block4_conv4/BiasAdd (8.16k/8.16k flops)
#   model_5/block4_conv3/BiasAdd (8.13k/8.13k flops)
#   model_5/block4_conv2/BiasAdd (7.62k/7.62k flops)
#   model_5/block4_conv1/BiasAdd (7.36k/7.36k flops)
#   model_5/block5_conv1/BiasAdd (2.04k/2.04k flops)
#   model_5/block5_conv2/BiasAdd (2.04k/2.04k flops)
#   model_5/block5_conv3/BiasAdd (2.04k/2.04k flops)
#   model_5/block5_conv4/BiasAdd (2.04k/2.04k flops)
#   model_5/block5_pool/MaxPool (2.04k/2.04k flops)
#   model_5/fc1/BiasAdd (1.94k/1.94k flops)
#   model_5/fc2/BiasAdd (1.33k/1.33k flops)
#   model_5/dense_5/Softmax (50/50 flops)
#   model_5/dense_5/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.074044
# 2022-04-13 05:58:23.534047: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:58:23.534159: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:58:23.535905: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/509.18m flops)
#   model_6/block3_conv4/Conv2D (69.70m/69.70m flops)
#   model_6/block4_conv4/Conv2D (60.19m/60.19m flops)
#   model_6/block1_conv2/Conv2D (55.30m/55.30m flops)
#   model_6/block3_conv3/Conv2D (50.74m/50.74m flops)
#   model_6/block4_conv3/Conv2D (48.55m/48.55m flops)
#   model_6/block4_conv2/Conv2D (38.38m/38.38m flops)
#   model_6/block2_conv2/Conv2D (27.13m/27.13m flops)
#   model_6/block3_conv2/Conv2D (25.58m/25.58m flops)
#   model_6/block4_conv1/Conv2D (24.48m/24.48m flops)
#   model_6/block5_conv4/Conv2D (18.65m/18.65m flops)
#   model_6/block5_conv3/Conv2D (18.58m/18.58m flops)
#   model_6/block5_conv2/Conv2D (18.51m/18.51m flops)
#   model_6/block5_conv1/Conv2D (17.71m/17.71m flops)
#   model_6/block2_conv1/Conv2D (17.69m/17.69m flops)
#   model_6/block3_conv1/Conv2D (12.93m/12.93m flops)
#   model_6/fc2/MatMul (2.58m/2.58m flops)
#   model_6/fc1/MatMul (1.19m/1.19m flops)
#   model_6/block1_conv1/Conv2D (921.60k/921.60k flops)
#   model_6/block1_conv2/BiasAdd (61.44k/61.44k flops)
#   model_6/block1_pool/MaxPool (61.44k/61.44k flops)
#   model_6/block1_conv1/BiasAdd (51.20k/51.20k flops)
#   model_6/block2_pool/MaxPool (23.55k/23.55k flops)
#   model_6/block2_conv2/BiasAdd (23.55k/23.55k flops)
#   model_6/dense_6/MatMul (22.08k/22.08k flops)
#   model_6/block2_conv1/BiasAdd (16.38k/16.38k flops)
#   model_6/block3_conv4/BiasAdd (16.00k/16.00k flops)
#   model_6/block3_pool/MaxPool (16.00k/16.00k flops)
#   model_6/block3_conv3/BiasAdd (15.49k/15.49k flops)
#   model_6/block3_conv2/BiasAdd (11.65k/11.65k flops)
#   model_6/block3_conv1/BiasAdd (7.81k/7.81k flops)
#   model_6/block4_pool/MaxPool (7.78k/7.78k flops)
#   model_6/block4_conv4/BiasAdd (7.78k/7.78k flops)
#   model_6/block4_conv3/BiasAdd (6.88k/6.88k flops)
#   model_6/block4_conv2/BiasAdd (6.27k/6.27k flops)
#   model_6/block4_conv1/BiasAdd (5.44k/5.44k flops)
#   model_6/block5_conv4/BiasAdd (2.04k/2.04k flops)
#   model_6/block5_pool/MaxPool (2.04k/2.04k flops)
#   model_6/block5_conv2/BiasAdd (2.03k/2.03k flops)
#   model_6/block5_conv3/BiasAdd (2.03k/2.03k flops)
#   model_6/block5_conv1/BiasAdd (2.02k/2.02k flops)
#   model_6/fc1/BiasAdd (1.17k/1.17k flops)
#   model_6/fc2/BiasAdd (1.10k/1.10k flops)
#   model_6/dense_6/Softmax (50/50 flops)
#   model_6/dense_6/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.101436
# 2022-04-13 05:58:24.220215: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:58:24.220330: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:58:24.222052: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/641.15m flops)
#   model_7/block3_conv4/Conv2D (72.58m/72.58m flops)
#   model_7/block3_conv3/Conv2D (70.27m/70.27m flops)
#   model_7/block4_conv4/Conv2D (70.00m/70.00m flops)
#   model_7/block3_conv2/Conv2D (68.59m/68.59m flops)
#   model_7/block4_conv3/Conv2D (68.58m/68.58m flops)
#   model_7/block2_conv2/Conv2D (55.76m/55.76m flops)
#   model_7/block4_conv2/Conv2D (43.11m/43.11m flops)
#   model_7/block1_conv2/Conv2D (35.39m/35.39m flops)
#   model_7/block3_conv1/Conv2D (30.92m/30.92m flops)
#   model_7/block2_conv1/Conv2D (24.33m/24.33m flops)
#   model_7/block4_conv1/Conv2D (22.35m/22.35m flops)
#   model_7/block5_conv4/Conv2D (18.43m/18.43m flops)
#   model_7/block5_conv3/Conv2D (18.43m/18.43m flops)
#   model_7/block5_conv2/Conv2D (18.43m/18.43m flops)
#   model_7/block5_conv1/Conv2D (18.07m/18.07m flops)
#   model_7/fc2/MatMul (3.44m/3.44m flops)
#   model_7/fc1/MatMul (1.34m/1.34m flops)
#   model_7/block1_conv1/Conv2D (737.28k/737.28k flops)
#   model_7/block1_conv2/BiasAdd (49.15k/49.15k flops)
#   model_7/block1_pool/MaxPool (49.15k/49.15k flops)
#   model_7/block1_conv1/BiasAdd (40.96k/40.96k flops)
#   model_7/block2_pool/MaxPool (28.16k/28.16k flops)
#   model_7/block2_conv2/BiasAdd (28.16k/28.16k flops)
#   model_7/block2_conv1/BiasAdd (28.16k/28.16k flops)
#   model_7/dense_7/MatMul (25.92k/25.92k flops)
#   model_7/block3_conv4/BiasAdd (16.13k/16.13k flops)
#   model_7/block3_pool/MaxPool (16.13k/16.13k flops)
#   model_7/block3_conv3/BiasAdd (16.00k/16.00k flops)
#   model_7/block3_conv1/BiasAdd (15.62k/15.62k flops)
#   model_7/block3_conv2/BiasAdd (15.62k/15.62k flops)
#   model_7/block4_pool/MaxPool (7.94k/7.94k flops)
#   model_7/block4_conv4/BiasAdd (7.94k/7.94k flops)
#   model_7/block4_conv3/BiasAdd (7.84k/7.84k flops)
#   model_7/block4_conv2/BiasAdd (7.78k/7.78k flops)
#   model_7/block4_conv1/BiasAdd (4.93k/4.93k flops)
#   model_7/block5_conv1/BiasAdd (2.02k/2.02k flops)
#   model_7/block5_conv2/BiasAdd (2.02k/2.02k flops)
#   model_7/block5_conv3/BiasAdd (2.02k/2.02k flops)
#   model_7/block5_conv4/BiasAdd (2.02k/2.02k flops)
#   model_7/block5_pool/MaxPool (2.02k/2.02k flops)
#   model_7/fc1/BiasAdd (1.33k/1.33k flops)
#   model_7/fc2/BiasAdd (1.30k/1.30k flops)
#   model_7/dense_7/Softmax (50/50 flops)
#   model_7/dense_7/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.161676
# 2022-04-13 05:58:24.955116: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:58:24.955228: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:58:24.956938: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/686.43m flops)
#   model_8/block4_conv4/Conv2D (72.00m/72.00m flops)
#   model_8/block3_conv4/Conv2D (72.00m/72.00m flops)
#   model_8/block3_conv3/Conv2D (72.00m/72.00m flops)
#   model_8/block4_conv3/Conv2D (71.71m/71.71m flops)
#   model_8/block3_conv2/Conv2D (65.66m/65.66m flops)
#   model_8/block4_conv2/Conv2D (63.97m/63.97m flops)
#   model_8/block2_conv2/Conv2D (54.85m/54.85m flops)
#   model_8/block1_conv2/Conv2D (43.79m/43.79m flops)
#   model_8/block3_conv1/Conv2D (32.57m/32.57m flops)
#   model_8/block4_conv1/Conv2D (32.11m/32.11m flops)
#   model_8/block2_conv1/Conv2D (23.89m/23.89m flops)
#   model_8/block5_conv4/Conv2D (18.58m/18.58m flops)
#   model_8/block5_conv3/Conv2D (18.58m/18.58m flops)
#   model_8/block5_conv2/Conv2D (18.58m/18.58m flops)
#   model_8/block5_conv1/Conv2D (18.29m/18.29m flops)
#   model_8/fc2/MatMul (4.86m/4.86m flops)
#   model_8/fc1/MatMul (1.77m/1.77m flops)
#   model_8/block1_conv1/Conv2D (811.01k/811.01k flops)
#   model_8/block1_conv2/BiasAdd (55.30k/55.30k flops)
#   model_8/block1_pool/MaxPool (55.30k/55.30k flops)
#   model_8/block1_conv1/BiasAdd (45.06k/45.06k flops)
#   model_8/block2_pool/MaxPool (31.74k/31.74k flops)
#   model_8/block2_conv2/BiasAdd (31.74k/31.74k flops)
#   model_8/dense_8/MatMul (27.84k/27.84k flops)
#   model_8/block2_conv1/BiasAdd (24.58k/24.58k flops)
#   model_8/block3_conv3/BiasAdd (16.00k/16.00k flops)
#   model_8/block3_conv2/BiasAdd (16.00k/16.00k flops)
#   model_8/block3_conv4/BiasAdd (16.00k/16.00k flops)
#   model_8/block3_pool/MaxPool (16.00k/16.00k flops)
#   model_8/block3_conv1/BiasAdd (14.59k/14.59k flops)
#   model_8/block4_conv3/BiasAdd (8.00k/8.00k flops)
#   model_8/block4_conv4/BiasAdd (8.00k/8.00k flops)
#   model_8/block4_pool/MaxPool (8.00k/8.00k flops)
#   model_8/block4_conv2/BiasAdd (7.97k/7.97k flops)
#   model_8/block4_conv1/BiasAdd (7.14k/7.14k flops)
#   model_8/block5_conv2/BiasAdd (2.03k/2.03k flops)
#   model_8/block5_conv3/BiasAdd (2.03k/2.03k flops)
#   model_8/block5_conv4/BiasAdd (2.03k/2.03k flops)
#   model_8/block5_pool/MaxPool (2.03k/2.03k flops)
#   model_8/block5_conv1/BiasAdd (2.03k/2.03k flops)
#   model_8/fc1/BiasAdd (1.74k/1.74k flops)
#   model_8/fc2/BiasAdd (1.39k/1.39k flops)
#   model_8/dense_8/Softmax (50/50 flops)
#   model_8/dense_8/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.121052
# 2022-04-13 05:58:25.911919: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:58:25.911992: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:58:25.913643: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/493.48m flops)
#   model_9/block3_conv4/Conv2D (71.40m/71.40m flops)
#   model_9/block1_conv2/Conv2D (66.28m/66.28m flops)
#   model_9/block3_conv3/Conv2D (59.03m/59.03m flops)
#   model_9/block3_conv2/Conv2D (42.58m/42.58m flops)
#   model_9/block4_conv4/Conv2D (38.79m/38.79m flops)
#   model_9/block2_conv2/Conv2D (30.23m/30.23m flops)
#   model_9/block4_conv3/Conv2D (30.19m/30.19m flops)
#   model_9/block4_conv2/Conv2D (23.72m/23.72m flops)
#   model_9/block2_conv1/Conv2D (22.86m/22.86m flops)
#   model_9/block4_conv1/Conv2D (20.92m/20.92m flops)
#   model_9/block5_conv4/Conv2D (18.43m/18.43m flops)
#   model_9/block5_conv3/Conv2D (18.14m/18.14m flops)
#   model_9/block3_conv1/Conv2D (16.63m/16.63m flops)
#   model_9/block5_conv2/Conv2D (15.47m/15.47m flops)
#   model_9/block5_conv1/Conv2D (11.40m/11.40m flops)
#   model_9/fc2/MatMul (4.27m/4.27m flops)
#   model_9/fc1/MatMul (1.68m/1.68m flops)
#   model_9/block1_conv1/Conv2D (1.07m/1.07m flops)
#   model_9/block1_conv2/BiasAdd (63.49k/63.49k flops)
#   model_9/block1_pool/MaxPool (63.49k/63.49k flops)
#   model_9/block1_conv1/BiasAdd (59.39k/59.39k flops)
#   model_9/dense_9/MatMul (25.92k/25.92k flops)
#   model_9/block2_pool/MaxPool (20.99k/20.99k flops)
#   model_9/block2_conv2/BiasAdd (20.99k/20.99k flops)
#   model_9/block2_conv1/BiasAdd (20.48k/20.48k flops)
#   model_9/block3_conv4/BiasAdd (16.26k/16.26k flops)
#   model_9/block3_pool/MaxPool (16.26k/16.26k flops)
#   model_9/block3_conv3/BiasAdd (15.62k/15.62k flops)
#   model_9/block3_conv2/BiasAdd (13.44k/13.44k flops)
#   model_9/block3_conv1/BiasAdd (11.26k/11.26k flops)
#   model_9/block4_pool/MaxPool (5.92k/5.92k flops)
#   model_9/block4_conv4/BiasAdd (5.92k/5.92k flops)
#   model_9/block4_conv3/BiasAdd (5.82k/5.82k flops)
#   model_9/block4_conv2/BiasAdd (4.61k/4.61k flops)
#   model_9/block4_conv1/BiasAdd (4.58k/4.58k flops)
#   model_9/block5_conv4/BiasAdd (2.04k/2.04k flops)
#   model_9/block5_pool/MaxPool (2.04k/2.04k flops)
#   model_9/block5_conv2/BiasAdd (2.01k/2.01k flops)
#   model_9/block5_conv3/BiasAdd (2.01k/2.01k flops)
#   model_9/block5_conv1/BiasAdd (1.71k/1.71k flops)
#   model_9/fc1/BiasAdd (1.65k/1.65k flops)
#   model_9/fc2/BiasAdd (1.30k/1.30k flops)
#   model_9/dense_9/Softmax (50/50 flops)
#   model_9/dense_9/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 4.633068
# 2022-04-13 05:58:26.725776: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:58:26.725862: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:58:26.727596: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/2.36b flops)
#   model_10/block4_conv4/Conv2D (297.29m/297.29m flops)
#   model_10/block1_conv2/Conv2D (283.41m/283.41m flops)
#   model_10/block3_conv4/Conv2D (283.24m/283.24m flops)
#   model_10/block4_conv3/Conv2D (268.03m/268.03m flops)
#   model_10/block4_conv2/Conv2D (201.55m/201.55m flops)
#   model_10/block3_conv3/Conv2D (191.80m/191.80m flops)
#   model_10/block3_conv2/Conv2D (133.15m/133.15m flops)
#   model_10/block2_conv2/Conv2D (118.70m/118.70m flops)
#   model_10/block4_conv1/Conv2D (111.78m/111.78m flops)
#   model_10/block2_conv1/Conv2D (79.99m/79.99m flops)
#   model_10/block5_conv4/Conv2D (74.62m/74.62m flops)
#   model_10/block5_conv1/Conv2D (74.32m/74.32m flops)
#   model_10/block5_conv2/Conv2D (74.32m/74.32m flops)
#   model_10/block5_conv3/Conv2D (74.32m/74.32m flops)
#   model_10/block3_conv1/Conv2D (71.22m/71.22m flops)
#   model_10/fc1/MatMul (8.03m/8.03m flops)
#   model_10/fc2/MatMul (6.49m/6.49m flops)
#   model_10/block1_conv1/Conv2D (4.57m/4.57m flops)
#   model_10/block1_conv1/BiasAdd (253.95k/253.95k flops)
#   model_10/block1_conv2/BiasAdd (253.95k/253.95k flops)
#   model_10/block1_pool/MaxPool (253.95k/253.95k flops)
#   model_10/block2_conv2/BiasAdd (94.21k/94.21k flops)
#   model_10/block2_pool/MaxPool (94.21k/94.21k flops)
#   model_10/block2_conv1/BiasAdd (71.68k/71.68k flops)
#   model_10/block3_pool/MaxPool (65.02k/65.02k flops)
#   model_10/block3_conv4/BiasAdd (65.02k/65.02k flops)
#   model_10/block3_conv3/BiasAdd (61.95k/61.95k flops)
#   model_10/block3_conv2/BiasAdd (44.03k/44.03k flops)
#   model_10/block3_conv1/BiasAdd (43.01k/43.01k flops)
#   model_10/dense_10/MatMul (32.96k/32.96k flops)
#   model_10/block4_conv3/BiasAdd (32.51k/32.51k flops)
#   model_10/block4_pool/MaxPool (32.51k/32.51k flops)
#   model_10/block4_conv4/BiasAdd (32.51k/32.51k flops)
#   model_10/block4_conv2/BiasAdd (29.31k/29.31k flops)
#   model_10/block4_conv1/BiasAdd (24.45k/24.45k flops)
#   model_10/block5_conv4/BiasAdd (8.16k/8.16k flops)
#   model_10/block5_pool/MaxPool (8.16k/8.16k flops)
#   model_10/block5_conv2/BiasAdd (8.13k/8.13k flops)
#   model_10/block5_conv1/BiasAdd (8.13k/8.13k flops)
#   model_10/block5_conv3/BiasAdd (8.13k/8.13k flops)
#   model_10/fc1/BiasAdd (1.97k/1.97k flops)
#   model_10/fc2/BiasAdd (1.65k/1.65k flops)
#   model_10/dense_10/Softmax (50/50 flops)
#   model_10/dense_10/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 3.703788
# 2022-04-13 05:58:28.180550: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 05:58:28.180620: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 05:58:28.182341: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/2.01b flops)
#   model_11/block4_conv4/Conv2D (298.46m/298.46m flops)
#   model_11/block4_conv3/Conv2D (279.73m/279.73m flops)
#   model_11/block4_conv2/Conv2D (245.59m/245.59m flops)
#   model_11/block3_conv4/Conv2D (189.92m/189.92m flops)
#   model_11/block3_conv3/Conv2D (142.44m/142.44m flops)
#   model_11/block1_conv2/Conv2D (117.96m/117.96m flops)
#   model_11/block4_conv1/Conv2D (115.09m/115.09m flops)
#   model_11/block3_conv2/Conv2D (111.48m/111.48m flops)
#   model_11/block2_conv2/Conv2D (87.59m/87.59m flops)
#   model_11/block5_conv1/Conv2D (74.91m/74.91m flops)
#   model_11/block5_conv2/Conv2D (74.91m/74.91m flops)
#   model_11/block5_conv3/Conv2D (74.91m/74.91m flops)
#   model_11/block5_conv4/Conv2D (74.91m/74.91m flops)
#   model_11/block3_conv1/Conv2D (58.39m/58.39m flops)
#   model_11/block2_conv1/Conv2D (49.77m/49.77m flops)
#   model_11/fc1/MatMul (6.46m/6.46m flops)
#   model_11/fc2/MatMul (4.82m/4.82m flops)
#   model_11/block1_conv1/Conv2D (2.36m/2.36m flops)
#   model_11/block1_conv2/BiasAdd (204.80k/204.80k flops)
#   model_11/block1_pool/MaxPool (204.80k/204.80k flops)
#   model_11/block1_conv1/BiasAdd (131.07k/131.07k flops)
#   model_11/block2_conv2/BiasAdd (90.11k/90.11k flops)
#   model_11/block2_pool/MaxPool (90.11k/90.11k flops)
#   model_11/block3_pool/MaxPool (57.34k/57.34k flops)
#   model_11/block3_conv4/BiasAdd (57.34k/57.34k flops)
#   model_11/block2_conv1/BiasAdd (55.30k/55.30k flops)
#   model_11/block3_conv3/BiasAdd (47.10k/47.10k flops)
#   model_11/block3_conv2/BiasAdd (43.01k/43.01k flops)
#   model_11/block3_conv1/BiasAdd (36.86k/36.86k flops)
#   model_11/block4_conv4/BiasAdd (32.64k/32.64k flops)
#   model_11/block4_pool/MaxPool (32.64k/32.64k flops)
#   model_11/block4_conv3/BiasAdd (32.51k/32.51k flops)
#   model_11/block4_conv2/BiasAdd (30.59k/30.59k flops)
#   model_11/dense_11/MatMul (30.40k/30.40k flops)
#   model_11/block4_conv1/BiasAdd (28.54k/28.54k flops)
# ...
# 2022-04-13 06:01:15.780793: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 06:01:15.782701: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/39.04b flops)
#   model_70/block4_conv3/Conv2D (4.76b/4.76b flops)
#   model_70/block4_conv4/Conv2D (4.76b/4.76b flops)
#   model_70/block4_conv2/Conv2D (4.66b/4.66b flops)
#   model_70/block3_conv4/Conv2D (4.39b/4.39b flops)
#   model_70/block3_conv3/Conv2D (3.56b/3.56b flops)
#   model_70/block1_conv2/Conv2D (2.77b/2.77b flops)
#   model_70/block3_conv2/Conv2D (2.54b/2.54b flops)
#   model_70/block4_conv1/Conv2D (2.24b/2.24b flops)
#   model_70/block2_conv2/Conv2D (1.95b/1.95b flops)
#   model_70/block3_conv1/Conv2D (1.28b/1.28b flops)
#   model_70/block5_conv2/Conv2D (1.20b/1.20b flops)
#   model_70/block5_conv3/Conv2D (1.20b/1.20b flops)
#   model_70/block5_conv4/Conv2D (1.20b/1.20b flops)
#   model_70/block5_conv1/Conv2D (1.19b/1.19b flops)
#   model_70/block2_conv1/Conv2D (1.09b/1.09b flops)
#   model_70/fc1/MatMul (170.25m/170.25m flops)
#   model_70/block1_conv1/Conv2D (49.55m/49.55m flops)
#   model_70/fc2/MatMul (10.60m/10.60m flops)
#   model_70/block1_conv2/BiasAdd (3.67m/3.67m flops)
#   model_70/block1_pool/MaxPool (3.67m/3.67m flops)
#   model_70/block1_conv1/BiasAdd (2.75m/2.75m flops)
#   model_70/block2_conv2/BiasAdd (1.64m/1.64m flops)
#   model_70/block2_pool/MaxPool (1.64m/1.64m flops)
#   model_70/block2_conv1/BiasAdd (1.08m/1.08m flops)
#   model_70/block3_pool/MaxPool (999.42k/999.42k flops)
#   model_70/block3_conv4/BiasAdd (999.42k/999.42k flops)
#   model_70/block3_conv3/BiasAdd (999.42k/999.42k flops)
#   model_70/block3_conv2/BiasAdd (811.01k/811.01k flops)
#   model_70/block3_conv1/BiasAdd (712.70k/712.70k flops)
#   model_70/block4_conv3/BiasAdd (520.19k/520.19k flops)
#   model_70/block4_conv2/BiasAdd (520.19k/520.19k flops)
#   model_70/block4_pool/MaxPool (520.19k/520.19k flops)
#   model_70/block4_conv4/BiasAdd (520.19k/520.19k flops)
#   model_70/block4_conv1/BiasAdd (509.95k/509.95k flops)
#   model_70/block5_conv2/BiasAdd (130.56k/130.56k flops)
#   model_70/block5_conv1/BiasAdd (130.56k/130.56k flops)
#   model_70/block5_conv3/BiasAdd (130.56k/130.56k flops)
#   model_70/block5_conv4/BiasAdd (130.56k/130.56k flops)
#   model_70/block5_pool/MaxPool (130.56k/130.56k flops)
#   model_70/dense_70/MatMul (40.64k/40.64k flops)
#   model_70/fc1/BiasAdd (2.61k/2.61k flops)
#   model_70/fc2/BiasAdd (2.03k/2.03k flops)
#   model_70/dense_70/Softmax (50/50 flops)
#   model_70/dense_70/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 66.720044
# 2022-04-13 06:01:23.242687: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 06:01:23.242807: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 06:01:23.244691: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/36.66b flops)
#   model_71/block4_conv4/Conv2D (4.43b/4.43b flops)
#   model_71/block4_conv3/Conv2D (4.26b/4.26b flops)
#   model_71/block4_conv2/Conv2D (3.77b/3.77b flops)
#   model_71/block2_conv2/Conv2D (3.76b/3.76b flops)
#   model_71/block3_conv4/Conv2D (3.43b/3.43b flops)
#   model_71/block3_conv3/Conv2D (3.10b/3.10b flops)
#   model_71/block3_conv2/Conv2D (2.20b/2.20b flops)
#   model_71/block1_conv2/Conv2D (2.15b/2.15b flops)
#   model_71/block4_conv1/Conv2D (1.80b/1.80b flops)
#   model_71/block2_conv1/Conv2D (1.56b/1.56b flops)
#   model_71/block3_conv1/Conv2D (1.25b/1.25b flops)
#   model_71/block5_conv4/Conv2D (1.18b/1.18b flops)
#   model_71/block5_conv2/Conv2D (1.18b/1.18b flops)
#   model_71/block5_conv3/Conv2D (1.18b/1.18b flops)
#   model_71/block5_conv1/Conv2D (1.15b/1.15b flops)
#   model_71/fc1/MatMul (179.99m/179.99m flops)
#   model_71/block1_conv1/Conv2D (44.83m/44.83m flops)
#   model_71/fc2/MatMul (7.71m/7.71m flops)
#   model_71/block1_conv2/BiasAdd (3.15m/3.15m flops)
#   model_71/block1_pool/MaxPool (3.15m/3.15m flops)
#   model_71/block1_conv1/BiasAdd (2.49m/2.49m flops)
#   model_71/block2_conv2/BiasAdd (1.90m/1.90m flops)
#   model_71/block2_pool/MaxPool (1.90m/1.90m flops)
#   model_71/block2_conv1/BiasAdd (1.80m/1.80m flops)
#   model_71/block3_pool/MaxPool (925.70k/925.70k flops)
#   model_71/block3_conv4/BiasAdd (925.70k/925.70k flops)
#   model_71/block3_conv3/BiasAdd (843.78k/843.78k flops)
#   model_71/block3_conv2/BiasAdd (835.58k/835.58k flops)
#   model_71/block3_conv1/BiasAdd (598.02k/598.02k flops)
#   model_71/block4_pool/MaxPool (503.81k/503.81k flops)
#   model_71/block4_conv4/BiasAdd (503.81k/503.81k flops)
#   model_71/block4_conv3/BiasAdd (499.71k/499.71k flops)
#   model_71/block4_conv2/BiasAdd (485.38k/485.38k flops)
#   model_71/block4_conv1/BiasAdd (442.37k/442.37k flops)
#   model_71/block5_conv4/BiasAdd (130.05k/130.05k flops)
#   model_71/block5_pool/MaxPool (130.05k/130.05k flops)
#   model_71/block5_conv2/BiasAdd (129.54k/129.54k flops)
#   model_71/block5_conv1/BiasAdd (129.54k/129.54k flops)
#   model_71/block5_conv3/BiasAdd (129.54k/129.54k flops)
#   model_71/dense_71/MatMul (27.84k/27.84k flops)
#   model_71/fc1/BiasAdd (2.77k/2.77k flops)
#   model_71/fc2/BiasAdd (1.39k/1.39k flops)
#   model_71/dense_71/Softmax (50/50 flops)
#   model_71/dense_71/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 65.106092
# 2022-04-13 06:01:30.715268: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 06:01:30.715394: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 06:01:30.717221: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/39.31b flops)
#   model_72/block4_conv3/Conv2D (4.79b/4.79b flops)
#   model_72/block4_conv4/Conv2D (4.79b/4.79b flops)
#   model_72/block4_conv2/Conv2D (4.46b/4.46b flops)
#   model_72/block3_conv4/Conv2D (4.13b/4.13b flops)
#   model_72/block2_conv2/Conv2D (4.03b/4.03b flops)
#   model_72/block3_conv3/Conv2D (3.50b/3.50b flops)
#   model_72/block3_conv2/Conv2D (2.19b/2.19b flops)
#   model_72/block4_conv1/Conv2D (2.18b/2.18b flops)
#   model_72/block1_conv2/Conv2D (1.59b/1.59b flops)
#   model_72/block2_conv1/Conv2D (1.41b/1.41b flops)
#   model_72/block3_conv1/Conv2D (1.24b/1.24b flops)
#   model_72/block5_conv2/Conv2D (1.20b/1.20b flops)
#   model_72/block5_conv1/Conv2D (1.20b/1.20b flops)
#   model_72/block5_conv3/Conv2D (1.20b/1.20b flops)
#   model_72/block5_conv4/Conv2D (1.20b/1.20b flops)
#   model_72/fc1/MatMul (134.74m/134.74m flops)
#   model_72/block1_conv1/Conv2D (37.75m/37.75m flops)
#   model_72/fc2/MatMul (7.46m/7.46m flops)
#   model_72/block1_conv2/BiasAdd (2.75m/2.75m flops)
#   model_72/block1_pool/MaxPool (2.75m/2.75m flops)
#   model_72/block1_conv1/BiasAdd (2.10m/2.10m flops)
#   model_72/block2_conv2/BiasAdd (1.97m/1.97m flops)
#   model_72/block2_pool/MaxPool (1.97m/1.97m flops)
#   model_72/block2_conv1/BiasAdd (1.87m/1.87m flops)
#   model_72/block3_pool/MaxPool (1.02m/1.02m flops)
#   model_72/block3_conv4/BiasAdd (1.02m/1.02m flops)
#   model_72/block3_conv3/BiasAdd (917.50k/917.50k flops)
#   model_72/block3_conv2/BiasAdd (868.35k/868.35k flops)
#   model_72/block3_conv1/BiasAdd (573.44k/573.44k flops)
#   model_72/block4_conv3/BiasAdd (522.24k/522.24k flops)
#   model_72/block4_conv2/BiasAdd (522.24k/522.24k flops)
#   model_72/block4_pool/MaxPool (522.24k/522.24k flops)
#   model_72/block4_conv4/BiasAdd (522.24k/522.24k flops)
#   model_72/block4_conv1/BiasAdd (485.38k/485.38k flops)
#   model_72/block5_conv2/BiasAdd (130.56k/130.56k flops)
#   model_72/block5_conv1/BiasAdd (130.56k/130.56k flops)
#   model_72/block5_conv3/BiasAdd (130.56k/130.56k flops)
#   model_72/block5_conv4/BiasAdd (130.56k/130.56k flops)
#   model_72/block5_pool/MaxPool (130.56k/130.56k flops)
#   model_72/dense_72/MatMul (36.16k/36.16k flops)
#   model_72/fc1/BiasAdd (2.06k/2.06k flops)
#   model_72/fc2/BiasAdd (1.81k/1.81k flops)
#   model_72/dense_72/Softmax (50/50 flops)
#   model_72/dense_72/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 71.994284
# 2022-04-13 06:01:36.765922: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-04-13 06:01:36.766040: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-04-13 06:01:36.767893: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/42.92b flops)
#   model_73/block4_conv4/Conv2D (4.78b/4.78b flops)
#   model_73/block3_conv4/Conv2D (4.64b/4.64b flops)
#   model_73/block4_conv3/Conv2D (4.64b/4.64b flops)
#   model_73/block3_conv3/Conv2D (4.53b/4.53b flops)
#   model_73/block3_conv2/Conv2D (4.53b/4.53b flops)
#   model_73/block4_conv2/Conv2D (4.39b/4.39b flops)
#   model_73/block1_conv2/Conv2D (3.06b/3.06b flops)
#   model_73/block4_conv1/Conv2D (2.25b/2.25b flops)
#   model_73/block3_conv1/Conv2D (2.08b/2.08b flops)
#   model_73/block2_conv2/Conv2D (2.02b/2.02b flops)
#   model_73/block5_conv1/Conv2D (1.20b/1.20b flops)
#   model_73/block5_conv2/Conv2D (1.20b/1.20b flops)
#   model_73/block5_conv3/Conv2D (1.20b/1.20b flops)
#   model_73/block5_conv4/Conv2D (1.20b/1.20b flops)
#   model_73/block2_conv1/Conv2D (955.51m/955.51m flops)
#   model_73/fc1/MatMul (157.72m/157.72m flops)
#   model_73/block1_conv1/Conv2D (56.62m/56.62m flops)
#   model_73/fc2/MatMul (5.49m/5.49m flops)
#   model_73/block1_conv2/BiasAdd (3.54m/3.54m flops)
#   model_73/block1_pool/MaxPool (3.54m/3.54m flops)
#   model_73/block1_conv1/BiasAdd (3.15m/3.15m flops)
#   model_73/block2_conv2/BiasAdd (1.87m/1.87m flops)
#   model_73/block2_pool/MaxPool (1.87m/1.87m flops)
#   model_73/block3_pool/MaxPool (1.04m/1.04m flops)
#   model_73/block3_conv4/BiasAdd (1.04m/1.04m flops)
#   model_73/block3_conv1/BiasAdd (1.02m/1.02m flops)
#   model_73/block3_conv3/BiasAdd (1.02m/1.02m flops)
#   model_73/block3_conv2/BiasAdd (1.02m/1.02m flops)
#   model_73/block2_conv1/BiasAdd (983.04k/983.04k flops)
#   model_73/block4_conv4/BiasAdd (522.24k/522.24k flops)
#   model_73/block4_pool/MaxPool (522.24k/522.24k flops)
#   model_73/block4_conv3/BiasAdd (520.19k/520.19k flops)
#   model_73/block4_conv2/BiasAdd (507.90k/507.90k flops)
#   model_73/block4_conv1/BiasAdd (491.52k/491.52k flops)
#   model_73/block5_conv2/BiasAdd (130.56k/130.56k flops)
#   model_73/block5_conv1/BiasAdd (130.56k/130.56k flops)
#   model_73/block5_conv3/BiasAdd (130.56k/130.56k flops)
#   model_73/block5_conv4/BiasAdd (130.56k/130.56k flops)
#   model_73/block5_pool/MaxPool (130.56k/130.56k flops)
#   model_73/dense_73/MatMul (22.72k/22.72k flops)
#   model_73/fc1/BiasAdd (2.42k/2.42k flops)
#   model_73/fc2/BiasAdd (1.14k/1.14k flops)
#   model_73/dense_73/Softmax (50/50 flops)
#   model_73/dense_73/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
