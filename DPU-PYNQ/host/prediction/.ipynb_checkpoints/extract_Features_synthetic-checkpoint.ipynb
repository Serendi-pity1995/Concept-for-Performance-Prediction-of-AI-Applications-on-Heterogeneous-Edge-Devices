# %%
import os
import csv
import numpy as np
import tensorflow as tf
import keras
from keras_flops import get_flops
from itertools import product

def get_total_number_of_neurons(model, include_output_layer):
    '''
    Args:
        model: Keras model
        include_output_layer: A boolean parameter. Whether or not to include output layer's neurons into the calculation

    Returns: number of neurons in the given model
    '''
    num_layers = len(model.layers)
    total_num_of_neurons = 0
    for layer_index in range(num_layers):
        layer = model.layers[layer_index]
        # since we multiply layer output dimensions, initial value is set to 1.
        num_neurons_in_layer = 1
        for i in range(1, len(layer.output.shape)):
            try:
                # when it is a valid layer to count neurons, an output dimension of the layer can be convertible to int.
                num_neurons_in_layer *= int(layer.output.shape[i])
            except Exception:
                # if the output dimension of layer cannot be convertible to int,
                # just pass that layer since it is not a valid layer to count neurons
                pass
        # if num_neurons_in_layer is not still 1, it means we have a valid layer to count neurons
        if not num_neurons_in_layer == 1:
            # when it is an output layer
            if layer_index == (num_layers - 1):
                if include_output_layer:
                    total_num_of_neurons += num_neurons_in_layer
            else:  # when it is not an output layer
                total_num_of_neurons += num_neurons_in_layer
    return total_num_of_neurons


with open("para_count_synthetic.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "step","number_of_layers", "FLOPs_G", "Total_params_M", "Memory_M", "total_num_of_neurons_M"],])

path = "../synthetic_h5" #文件夹目录
files= os.listdir(path) #得到文件夹下的所有文件名称
model_num = 1
input_shape_range =range(48,512,34)

for shape_x in input_shape_range:
    shape_y = shape_x
    for step in range(1,11):
        file = "synthetic_{input_x}_{input_y}_{step}.h5".format(input_x=shape_x,input_y=shape_y,step=step)
        if file in files: #遍历文件夹
            model_name = str(file)
            if not os.path.isdir(file): #判断是否是文件夹，不是文件夹才打开
                model = keras.models.load_model("../synthetic_h5/{}".format(model_name))
                num_neurons = get_total_number_of_neurons(model= model, include_output_layer= True)
                num_neurons_M = num_neurons/10**6    
                # how to compute the memory allocated by the activations of a model
                batch = 1
                shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
                else 1 for s in l.output_shape])) 
                for l in model.layers]))
                memory = (shapes_count * 4 * batch)/10**6
                print(memory)
                layers_length = len(model.layers)
                Total_params = round(model.count_params()/10 ** 6,2)
                FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
                with open("para_count_synthetic.csv","a+") as csvfile:
                    writer = csv.writer(csvfile)
                    writer.writerows([[model_num, shape_x, shape_y, step, layers_length, FLOPs, Total_params, memory, num_neurons_M],])

                    model_num = model_num + 1
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.309548
# 2022-05-11 04:31:14.409798: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:14.409874: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:14.410873: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/27.02m flops)
#   mnist_classifier/conv2d_1/Conv2D (9.49m/9.49m flops)
#   mnist_classifier/dense/MatMul (7.33m/7.33m flops)
#   mnist_classifier/dense_1/MatMul (5.75m/5.75m flops)
#   mnist_classifier/dense_2/MatMul (3.47m/3.47m flops)
#   mnist_classifier/conv2d/Conv2D (842.40k/842.40k flops)
#   mnist_classifier/conv2d/BiasAdd (46.80k/46.80k flops)
#   mnist_classifier/max_pooling2d/MaxPool (46.80k/46.80k flops)
#   mnist_classifier/dense_3/MatMul (20.48k/20.48k flops)
#   mnist_classifier/conv2d_1/BiasAdd (10.14k/10.14k flops)
#   mnist_classifier/max_pooling2d_1/MaxPool (8.64k/8.64k flops)
#   mnist_classifier/dense/BiasAdd (1.70k/1.70k flops)
#   mnist_classifier/dense_1/BiasAdd (1.70k/1.70k flops)
#   mnist_classifier/dense_2/BiasAdd (1.02k/1.02k flops)
#   mnist_classifier/dense_3/Softmax (50/50 flops)
#   mnist_classifier/dense_3/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.307268
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/18.98m flops)
#   mnist_classifier/conv2d_3/Conv2D (9.20m/9.20m flops)
#   mnist_classifier/dense_4/MatMul (6.32m/6.32m flops)
#   mnist_classifier/dense_5/MatMul (2.01m/2.01m flops)
#   mnist_classifier/conv2d_2/Conv2D (874.80k/874.80k flops)
#   mnist_classifier/dense_6/MatMul (450.56k/450.56k flops)
#   mnist_classifier/conv2d_2/BiasAdd (48.60k/48.60k flops)
#   mnist_classifier/max_pooling2d_2/MaxPool (48.60k/48.60k flops)
#   mnist_classifier/conv2d_3/BiasAdd (9.46k/9.46k flops)
#   mnist_classifier/max_pooling2d_3/MaxPool (8.06k/8.06k flops)
#   mnist_classifier/dense_7/MatMul (7.04k/7.04k flops)
#   mnist_classifier/dense_4/BiasAdd (1.57k/1.57k flops)
#   mnist_classifier/dense_5/BiasAdd (640/640 flops)
#   mnist_classifier/dense_6/BiasAdd (352/352 flops)
#   mnist_classifier/dense_7/Softmax (50/50 flops)
#   mnist_classifier/dense_7/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-05-11 04:31:14.886389: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:14.886468: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:14.887413: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 0.229212
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/16.27m flops)
#   mnist_classifier/conv2d_5/Conv2D (6.13m/6.13m flops)
#   mnist_classifier/dense_8/MatMul (4.64m/4.64m flops)
#   mnist_classifier/dense_9/MatMul (2.51m/2.51m flops)
#   mnist_classifier/dense_10/MatMul (2.30m/2.30m flops)
#   mnist_classifier/conv2d_4/Conv2D (583.20k/583.20k flops)
#   mnist_classifier/conv2d_4/BiasAdd (32.40k/32.40k flops)
#   mnist_classifier/max_pooling2d_4/MaxPool (32.40k/32.40k flops)
#   mnist_classifier/dense_11/MatMul (21.12k/21.12k flops)
#   mnist_classifier/conv2d_5/BiasAdd (9.46k/9.46k flops)
#   mnist_classifier/max_pooling2d_5/MaxPool (8.06k/8.06k flops)
#   mnist_classifier/dense_8/BiasAdd (1.15k/1.15k flops)
#   mnist_classifier/dense_9/BiasAdd (1.09k/1.09k flops)
#   mnist_classifier/dense_10/BiasAdd (1.06k/1.06k flops)
#   mnist_classifier/dense_11/Softmax (50/50 flops)
#   mnist_classifier/dense_11/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.339628
# 2022-05-11 04:31:15.111329: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:15.111402: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:15.112380: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/65.34m flops)
#   mnist_classifier/conv2d_65/Conv2D (47.41m/47.41m flops)
#   mnist_classifier/conv2d_66/Conv2D (9.02m/9.02m flops)
#   mnist_classifier/conv2d_64/Conv2D (3.74m/3.74m flops)
#   mnist_classifier/dense_93/MatMul (1.68m/1.68m flops)
#   mnist_classifier/conv2d_67/Conv2D (1.66m/1.66m flops)
#   mnist_classifier/dense_92/MatMul (958.46k/958.46k flops)
#   mnist_classifier/dense_94/MatMul (344.06k/344.06k flops)
#   mnist_classifier/conv2d_64/BiasAdd (207.58k/207.58k flops)
#   mnist_classifier/max_pooling2d_63/MaxPool (207.58k/207.58k flops)
#   mnist_classifier/conv2d_65/BiasAdd (48.78k/48.78k flops)
#   mnist_classifier/max_pooling2d_64/MaxPool (45.47k/45.47k flops)
#   mnist_classifier/conv2d_66/BiasAdd (8.64k/8.64k flops)
#   mnist_classifier/max_pooling2d_65/MaxPool (8.64k/8.64k flops)
#   mnist_classifier/dense_95/MatMul (5.12k/5.12k flops)
#   mnist_classifier/max_pooling2d_66/MaxPool (1.54k/1.54k flops)
#   mnist_classifier/conv2d_67/BiasAdd (1.54k/1.54k flops)
#   mnist_classifier/dense_92/BiasAdd (1.25k/1.25k flops)
#   mnist_classifier/dense_93/BiasAdd (672/672 flops)
#   mnist_classifier/dense_94/BiasAdd (256/256 flops)
#   mnist_classifier/dense_95/Softmax (50/50 flops)
#   mnist_classifier/dense_95/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# 2022-05-11 04:31:15.320026: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:15.320105: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:15.321225: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.226196
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/61.17m flops)
#   mnist_classifier/conv2d_69/Conv2D (42.14m/42.14m flops)
#   mnist_classifier/conv2d_70/Conv2D (9.32m/9.32m flops)
#   mnist_classifier/conv2d_68/Conv2D (3.32m/3.32m flops)
#   mnist_classifier/dense_97/MatMul (3.04m/3.04m flops)
#   mnist_classifier/conv2d_71/Conv2D (1.32m/1.32m flops)
#   mnist_classifier/dense_96/MatMul (852.48k/852.48k flops)
#   mnist_classifier/dense_98/MatMul (675.84k/675.84k flops)
#   mnist_classifier/conv2d_68/BiasAdd (184.51k/184.51k flops)
#   mnist_classifier/max_pooling2d_67/MaxPool (184.51k/184.51k flops)
#   mnist_classifier/conv2d_69/BiasAdd (48.78k/48.78k flops)
#   mnist_classifier/max_pooling2d_68/MaxPool (45.47k/45.47k flops)
#   mnist_classifier/conv2d_70/BiasAdd (8.93k/8.93k flops)
#   mnist_classifier/max_pooling2d_69/MaxPool (8.93k/8.93k flops)
#   mnist_classifier/dense_99/MatMul (6.40k/6.40k flops)
#   mnist_classifier/dense_96/BiasAdd (1.44k/1.44k flops)
#   mnist_classifier/max_pooling2d_70/MaxPool (1.18k/1.18k flops)
#   mnist_classifier/conv2d_71/BiasAdd (1.18k/1.18k flops)
#   mnist_classifier/dense_97/BiasAdd (1.06k/1.06k flops)
#   mnist_classifier/dense_98/BiasAdd (320/320 flops)
#   mnist_classifier/dense_99/Softmax (50/50 flops)
#   mnist_classifier/dense_99/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.317748
# 2022-05-11 04:31:15.669658: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:15.669732: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:15.670948: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
#
# 2022-05-11 04:31:15.854770: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:15.854846: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:15.856077: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/66.92m flops)
#   mnist_classifier/conv2d_73/Conv2D (48.80m/48.80m flops)
#   mnist_classifier/conv2d_74/Conv2D (9.96m/9.96m flops)
#   mnist_classifier/conv2d_72/Conv2D (3.60m/3.60m flops)
#   mnist_classifier/conv2d_75/Conv2D (1.61m/1.61m flops)
#   mnist_classifier/dense_101/MatMul (1.31m/1.31m flops)
#   mnist_classifier/dense_100/MatMul (737.28k/737.28k flops)
#   mnist_classifier/dense_102/MatMul (368.64k/368.64k flops)
#   mnist_classifier/conv2d_72/BiasAdd (199.89k/199.89k flops)
#   mnist_classifier/max_pooling2d_71/MaxPool (199.89k/199.89k flops)
#   mnist_classifier/conv2d_73/BiasAdd (52.14k/52.14k flops)
#   mnist_classifier/max_pooling2d_72/MaxPool (48.61k/48.61k flops)
#   mnist_classifier/conv2d_74/BiasAdd (8.93k/8.93k flops)
#   mnist_classifier/max_pooling2d_73/MaxPool (8.93k/8.93k flops)
#   mnist_classifier/dense_103/MatMul (5.76k/5.76k flops)
#   mnist_classifier/max_pooling2d_74/MaxPool (1.44k/1.44k flops)
#   mnist_classifier/conv2d_75/BiasAdd (1.44k/1.44k flops)
#   mnist_classifier/dense_100/BiasAdd (1.02k/1.02k flops)
#   mnist_classifier/dense_101/BiasAdd (640/640 flops)
#   mnist_classifier/dense_102/BiasAdd (288/288 flops)
#   mnist_classifier/dense_103/Softmax (50/50 flops)
#   mnist_classifier/dense_103/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2.335492
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/119.99m flops)
#   mnist_classifier/conv2d_77/Conv2D (76.11m/76.11m flops)
#   mnist_classifier/conv2d_78/Conv2D (25.06m/25.06m flops)
#   mnist_classifier/conv2d_79/Conv2D (5.81m/5.81m flops)
#   mnist_classifier/conv2d_76/Conv2D (5.73m/5.73m flops)
#   mnist_classifier/dense_104/MatMul (3.10m/3.10m flops)
#   mnist_classifier/dense_105/MatMul (2.21m/2.21m flops)
#   mnist_classifier/dense_106/MatMul (1.04m/1.04m flops)
#   mnist_classifier/conv2d_76/BiasAdd (318.10k/318.10k flops)
#   mnist_classifier/max_pooling2d_75/MaxPool (318.10k/318.10k flops)
#   mnist_classifier/conv2d_77/BiasAdd (117.45k/117.45k flops)
#   mnist_classifier/max_pooling2d_76/MaxPool (112.29k/112.29k flops)
#   mnist_classifier/conv2d_78/BiasAdd (24.00k/24.00k flops)
#   mnist_classifier/max_pooling2d_77/MaxPool (24.00k/24.00k flops)
#   mnist_classifier/dense_107/MatMul (10.88k/10.88k flops)
#   mnist_classifier/max_pooling2d_78/MaxPool (5.38k/5.38k flops)
#   mnist_classifier/conv2d_79/BiasAdd (5.38k/5.38k flops)
#   mnist_classifier/dense_104/BiasAdd (1.15k/1.15k flops)
#   mnist_classifier/dense_105/BiasAdd (960/960 flops)
#   mnist_classifier/dense_106/BiasAdd (544/544 flops)
#   mnist_classifier/dense_107/Softmax (50/50 flops)
#   mnist_classifier/dense_107/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-05-11 04:31:16.024070: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:16.024153: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:16.025359: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 1.93578
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/75.22m flops)
#   mnist_classifier/conv2d_81/Conv2D (44.32m/44.32m flops)
#   mnist_classifier/conv2d_82/Conv2D (14.23m/14.23m flops)
#   mnist_classifier/conv2d_80/Conv2D (5.09m/5.09m flops)
#   mnist_classifier/conv2d_83/Conv2D (3.71m/3.71m flops)
#   mnist_classifier/dense_108/MatMul (3.05m/3.05m flops)
#   mnist_classifier/dense_109/MatMul (2.65m/2.65m flops)
#   mnist_classifier/dense_110/MatMul (1.38m/1.38m flops)
#   mnist_classifier/conv2d_80/BiasAdd (282.75k/282.75k flops)
#   mnist_classifier/max_pooling2d_79/MaxPool (282.75k/282.75k flops)
#   mnist_classifier/conv2d_81/BiasAdd (76.95k/76.95k flops)
#   mnist_classifier/max_pooling2d_80/MaxPool (73.57k/73.57k flops)
#   mnist_classifier/conv2d_82/BiasAdd (20.80k/20.80k flops)
#   mnist_classifier/max_pooling2d_81/MaxPool (20.80k/20.80k flops)
#   mnist_classifier/dense_111/MatMul (16.00k/16.00k flops)
#   mnist_classifier/max_pooling2d_82/MaxPool (3.97k/3.97k flops)
#   mnist_classifier/conv2d_83/BiasAdd (3.97k/3.97k flops)
#   mnist_classifier/dense_108/BiasAdd (1.54k/1.54k flops)
#   mnist_classifier/dense_109/BiasAdd (864/864 flops)
#   mnist_classifier/dense_110/BiasAdd (800/800 flops)
#   mnist_classifier/dense_111/Softmax (50/50 flops)
#   mnist_classifier/dense_111/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-05-11 04:31:16.232550: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:16.232638: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:16.233837: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 3.182172
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/173.34m flops)
#   mnist_classifier/conv2d_85/Conv2D (122.03m/122.03m flops)
#   mnist_classifier/conv2d_86/Conv2D (27.68m/27.68m flops)
#   mnist_classifier/conv2d_84/Conv2D (8.59m/8.59m flops)
#   mnist_classifier/conv2d_87/Conv2D (7.71m/7.71m flops)
#   mnist_classifier/dense_112/MatMul (3.98m/3.98m flops)
#   mnist_classifier/dense_113/MatMul (1.62m/1.62m flops)
#   mnist_classifier/conv2d_84/BiasAdd (477.14k/477.14k flops)
#   mnist_classifier/max_pooling2d_83/MaxPool (477.14k/477.14k flops)
#   mnist_classifier/dense_114/MatMul (450.56k/450.56k flops)
#   mnist_classifier/conv2d_85/BiasAdd (125.55k/125.55k flops)
#   mnist_classifier/max_pooling2d_84/MaxPool (120.03k/120.03k flops)
#   mnist_classifier/conv2d_86/BiasAdd (24.80k/24.80k flops)
#   mnist_classifier/max_pooling2d_85/MaxPool (24.80k/24.80k flops)
#   mnist_classifier/max_pooling2d_86/MaxPool (6.91k/6.91k flops)
#   mnist_classifier/conv2d_87/BiasAdd (6.91k/6.91k flops)
#   mnist_classifier/dense_115/MatMul (6.40k/6.40k flops)
#   mnist_classifier/dense_112/BiasAdd (1.15k/1.15k flops)
#   mnist_classifier/dense_113/BiasAdd (704/704 flops)
#   mnist_classifier/dense_114/BiasAdd (320/320 flops)
#   mnist_classifier/dense_115/Softmax (50/50 flops)
#   mnist_classifier/dense_115/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 5.510724
# 2022-05-11 04:31:16.446943: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:16.447016: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:16.448256: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/288.42m flops)
#   mnist_classifier/conv2d_89/Conv2D (202.01m/202.01m flops)
#   mnist_classifier/conv2d_90/Conv2D (49.11m/49.11m flops)
#   mnist_classifier/conv2d_88/Conv2D (14.86m/14.86m flops)
#   mnist_classifier/conv2d_91/Conv2D (11.82m/11.82m flops)
#   mnist_classifier/dense_116/MatMul (5.60m/5.60m flops)
#   mnist_classifier/dense_117/MatMul (1.77m/1.77m flops)
#   mnist_classifier/dense_118/MatMul (1.05m/1.05m flops)
#   mnist_classifier/conv2d_88/BiasAdd (825.55k/825.55k flops)
#   mnist_classifier/max_pooling2d_87/MaxPool (825.55k/825.55k flops)
#   mnist_classifier/conv2d_89/BiasAdd (215.82k/215.82k flops)
#   mnist_classifier/max_pooling2d_88/MaxPool (208.80k/208.80k flops)
#   mnist_classifier/conv2d_90/BiasAdd (47.04k/47.04k flops)
#   mnist_classifier/max_pooling2d_89/MaxPool (47.04k/47.04k flops)
#   mnist_classifier/dense_119/MatMul (12.16k/12.16k flops)
#   mnist_classifier/max_pooling2d_90/MaxPool (10.94k/10.94k flops)
#   mnist_classifier/conv2d_91/BiasAdd (10.94k/10.94k flops)
#   mnist_classifier/dense_116/BiasAdd (1.02k/1.02k flops)
#   mnist_classifier/dense_117/BiasAdd (864/864 flops)
#   mnist_classifier/dense_118/BiasAdd (608/608 flops)
#   mnist_classifier/dense_119/Softmax (50/50 flops)
#   mnist_classifier/dense_119/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-05-11 04:31:16.649175: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:16.649251: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:16.650501: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 5.484668
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/284.73m flops)
#   mnist_classifier/conv2d_93/Conv2D (195.04m/195.04m flops)
#   mnist_classifier/conv2d_94/Conv2D (45.84m/45.84m flops)
#   mnist_classifier/conv2d_92/Conv2D (14.86m/14.86m flops)
#   mnist_classifier/conv2d_95/Conv2D (14.73m/14.73m flops)
#   mnist_classifier/dense_120/MatMul (9.71m/9.71m flops)
#   mnist_classifier/dense_121/MatMul (1.85m/1.85m flops)
#   mnist_classifier/conv2d_92/BiasAdd (825.55k/825.55k flops)
#   mnist_classifier/max_pooling2d_91/MaxPool (825.55k/825.55k flops)
#   mnist_classifier/dense_122/MatMul (516.10k/516.10k flops)
#   mnist_classifier/conv2d_93/BiasAdd (208.38k/208.38k flops)
#   mnist_classifier/max_pooling2d_92/MaxPool (201.60k/201.60k flops)
#   mnist_classifier/conv2d_94/BiasAdd (45.47k/45.47k flops)
#   mnist_classifier/max_pooling2d_93/MaxPool (45.47k/45.47k flops)
#   mnist_classifier/max_pooling2d_94/MaxPool (14.11k/14.11k flops)
#   mnist_classifier/conv2d_95/BiasAdd (14.11k/14.11k flops)
#   mnist_classifier/dense_123/MatMul (7.68k/7.68k flops)
#   mnist_classifier/dense_120/BiasAdd (1.38k/1.38k flops)
#   mnist_classifier/dense_121/BiasAdd (672/672 flops)
#   mnist_classifier/dense_122/BiasAdd (384/384 flops)
#   mnist_classifier/dense_123/Softmax (50/50 flops)
#   mnist_classifier/dense_123/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# 2022-05-11 04:31:16.872371: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:16.872442: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:16.873618: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 4.156492
# 2022-05-11 04:31:17.133420: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:17.133506: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:17.134734: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/213.15m flops)
#   mnist_classifier/conv2d_97/Conv2D (125.38m/125.38m flops)
#   mnist_classifier/conv2d_98/Conv2D (41.09m/41.09m flops)
#   mnist_classifier/conv2d_99/Conv2D (17.71m/17.71m flops)
#   mnist_classifier/dense_124/MatMul (12.37m/12.37m flops)
#   mnist_classifier/conv2d_96/Conv2D (10.29m/10.29m flops)
#   mnist_classifier/dense_125/MatMul (3.24m/3.24m flops)
#   mnist_classifier/dense_126/MatMul (1.40m/1.40m flops)
#   mnist_classifier/conv2d_96/BiasAdd (571.54k/571.54k flops)
#   mnist_classifier/max_pooling2d_95/MaxPool (571.54k/571.54k flops)
#   mnist_classifier/conv2d_97/BiasAdd (193.49k/193.49k flops)
#   mnist_classifier/max_pooling2d_96/MaxPool (187.20k/187.20k flops)
#   mnist_classifier/conv2d_98/BiasAdd (43.90k/43.90k flops)
#   mnist_classifier/max_pooling2d_97/MaxPool (43.90k/43.90k flops)
#   mnist_classifier/max_pooling2d_98/MaxPool (17.57k/17.57k flops)
#   mnist_classifier/conv2d_99/BiasAdd (17.57k/17.57k flops)
#   mnist_classifier/dense_127/MatMul (12.16k/12.16k flops)
#   mnist_classifier/dense_124/BiasAdd (1.41k/1.41k flops)
#   mnist_classifier/dense_125/BiasAdd (1.15k/1.15k flops)
#   mnist_classifier/dense_126/BiasAdd (608/608 flops)
#   mnist_classifier/dense_127/Softmax (50/50 flops)
#   mnist_classifier/dense_127/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 6.6751
# 2022-05-11 04:31:17.443496: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:17.443569: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:17.444797: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/358.32m flops)
#   mnist_classifier/conv2d_101/Conv2D (215.15m/215.15m flops)
#   mnist_classifier/conv2d_102/Conv2D (78.38m/78.38m flops)
#   mnist_classifier/conv2d_103/Conv2D (22.67m/22.67m flops)
#   mnist_classifier/dense_128/MatMul (16.79m/16.79m flops)
#   mnist_classifier/conv2d_100/Conv2D (16.18m/16.18m flops)
#   mnist_classifier/dense_129/MatMul (4.10m/4.10m flops)
#   mnist_classifier/dense_130/MatMul (2.38m/2.38m flops)
#   mnist_classifier/max_pooling2d_99/MaxPool (898.70k/898.70k flops)
#   mnist_classifier/conv2d_100/BiasAdd (898.70k/898.70k flops)
#   mnist_classifier/conv2d_101/BiasAdd (332.02k/332.02k flops)
#   mnist_classifier/max_pooling2d_100/MaxPool (323.46k/323.46k flops)
#   mnist_classifier/conv2d_102/BiasAdd (77.76k/77.76k flops)
#   mnist_classifier/max_pooling2d_101/MaxPool (77.76k/77.76k flops)
#   mnist_classifier/conv2d_103/BiasAdd (20.99k/20.99k flops)
#   mnist_classifier/max_pooling2d_102/MaxPool (20.99k/20.99k flops)
#   mnist_classifier/dense_131/MatMul (18.56k/18.56k flops)
#   mnist_classifier/dense_128/BiasAdd (1.60k/1.60k flops)
#   mnist_classifier/dense_129/BiasAdd (1.28k/1.28k flops)
#   mnist_classifier/dense_130/BiasAdd (928/928 flops)
#   mnist_classifier/dense_131/Softmax (50/50 flops)
#   mnist_classifier/dense_131/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 5.787052
# 2022-05-11 04:31:17.794911: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:17.794986: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:17.796190: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/234.92m flops)
#   mnist_classifier/conv2d_105/Conv2D (137.88m/137.88m flops)
#   mnist_classifier/conv2d_106/Conv2D (37.23m/37.23m flops)
#   mnist_classifier/dense_132/MatMul (21.01m/21.01m flops)
#   mnist_classifier/conv2d_107/Conv2D (17.42m/17.42m flops)
#   mnist_classifier/conv2d_104/Conv2D (15.28m/15.28m flops)
#   mnist_classifier/dense_133/MatMul (3.27m/3.27m flops)
#   mnist_classifier/conv2d_104/BiasAdd (848.78k/848.78k flops)
#   mnist_classifier/max_pooling2d_103/MaxPool (848.78k/848.78k flops)
#   mnist_classifier/dense_134/MatMul (516.10k/516.10k flops)
#   mnist_classifier/conv2d_105/BiasAdd (225.30k/225.30k flops)
#   mnist_classifier/max_pooling2d_104/MaxPool (219.49k/219.49k flops)
#   mnist_classifier/conv2d_106/BiasAdd (54.43k/54.43k flops)
#   mnist_classifier/max_pooling2d_105/MaxPool (54.43k/54.43k flops)
#   mnist_classifier/max_pooling2d_106/MaxPool (23.04k/23.04k flops)
#   mnist_classifier/conv2d_107/BiasAdd (23.04k/23.04k flops)
#   mnist_classifier/dense_135/MatMul (5.76k/5.76k flops)
#   mnist_classifier/dense_132/BiasAdd (1.82k/1.82k flops)
#   mnist_classifier/dense_133/BiasAdd (896/896 flops)
#   mnist_classifier/dense_134/BiasAdd (288/288 flops)
#   mnist_classifier/dense_135/Softmax (50/50 flops)
#   mnist_classifier/dense_135/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 7.069252
# 2022-05-11 04:31:18.191963: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:18.192039: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:18.193210: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/357.91m flops)
#   mnist_classifier/conv2d_109/Conv2D (230.52m/230.52m flops)
#   mnist_classifier/conv2d_110/Conv2D (70.54m/70.54m flops)
#   mnist_classifier/conv2d_111/Conv2D (18.58m/18.58m flops)
#   mnist_classifier/conv2d_108/Conv2D (17.97m/17.97m flops)
#   mnist_classifier/dense_136/MatMul (14.75m/14.75m flops)
#   mnist_classifier/dense_137/MatMul (2.36m/2.36m flops)
#   mnist_classifier/conv2d_108/BiasAdd (998.56k/998.56k flops)
#   mnist_classifier/max_pooling2d_107/MaxPool (998.56k/998.56k flops)
#   mnist_classifier/dense_138/MatMul (376.83k/376.83k flops)
#   mnist_classifier/conv2d_109/BiasAdd (320.17k/320.17k flops)
#   mnist_classifier/max_pooling2d_108/MaxPool (311.90k/311.90k flops)
#   mnist_classifier/conv2d_110/BiasAdd (72.58k/72.58k flops)
#   mnist_classifier/max_pooling2d_109/MaxPool (72.58k/72.58k flops)
#   mnist_classifier/max_pooling2d_110/MaxPool (18.43k/18.43k flops)
#   mnist_classifier/conv2d_111/BiasAdd (18.43k/18.43k flops)
#   mnist_classifier/dense_139/MatMul (5.12k/5.12k flops)
#   mnist_classifier/dense_136/BiasAdd (1.60k/1.60k flops)
#   mnist_classifier/dense_137/BiasAdd (736/736 flops)
#   mnist_classifier/dense_138/BiasAdd (256/256 flops)
#   mnist_classifier/dense_139/Softmax (50/50 flops)
#   mnist_classifier/dense_139/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 13.229556
# 2022-05-11 04:31:18.631051: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:18.631125: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:18.632386: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/761.57m flops)
#   mnist_classifier/conv2d_113/Conv2D (504.41m/504.41m flops)
#   mnist_classifier/conv2d_114/Conv2D (129.63m/129.63m flops)
#   mnist_classifier/conv2d_115/Conv2D (53.57m/53.57m flops)
#   mnist_classifier/conv2d_112/Conv2D (35.09m/35.09m flops)
#   mnist_classifier/dense_140/MatMul (30.72m/30.72m flops)
#   mnist_classifier/conv2d_112/BiasAdd (1.95m/1.95m flops)
#   mnist_classifier/max_pooling2d_111/MaxPool (1.95m/1.95m flops)
#   mnist_classifier/dense_141/MatMul (1.88m/1.88m flops)
#   mnist_classifier/dense_142/MatMul (989.18k/989.18k flops)
#   mnist_classifier/conv2d_113/BiasAdd (518.94k/518.94k flops)
#   mnist_classifier/max_pooling2d_112/MaxPool (507.84k/507.84k flops)
#   mnist_classifier/conv2d_114/BiasAdd (120.03k/120.03k flops)
#   mnist_classifier/max_pooling2d_113/MaxPool (120.03k/120.03k flops)
#   mnist_classifier/max_pooling2d_114/MaxPool (48.00k/48.00k flops)
#   mnist_classifier/conv2d_115/BiasAdd (48.00k/48.00k flops)
#   mnist_classifier/dense_143/MatMul (13.44k/13.44k flops)
#   mnist_classifier/dense_140/BiasAdd (1.28k/1.28k flops)
#   mnist_classifier/dense_141/BiasAdd (736/736 flops)
#   mnist_classifier/dense_142/BiasAdd (672/672 flops)
#   mnist_classifier/dense_143/Softmax (50/50 flops)
#   mnist_classifier/dense_143/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 9.072052
# 2022-05-11 04:31:19.848209: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:19.848280: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:19.849492: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# ...
# 76.945604
# 2022-05-11 04:31:50.295140: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:50.295209: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:50.296738: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/4.33b flops)
#   mnist_classifier/conv2d_281/Conv2D (3.06b/3.06b flops)
#   mnist_classifier/conv2d_282/Conv2D (755.83m/755.83m flops)
#   mnist_classifier/conv2d_280/Conv2D (207.67m/207.67m flops)
#   mnist_classifier/conv2d_283/Conv2D (192.74m/192.74m flops)
#   mnist_classifier/conv2d_284/Conv2D (45.16m/45.16m flops)
#   mnist_classifier/dense_292/MatMul (33.45m/33.45m flops)
#   mnist_classifier/max_pooling2d_279/MaxPool (11.54m/11.54m flops)
#   mnist_classifier/conv2d_280/BiasAdd (11.54m/11.54m flops)
#   mnist_classifier/dense_293/MatMul (4.84m/4.84m flops)
#   mnist_classifier/conv2d_281/BiasAdd (2.93m/2.93m flops)
#   mnist_classifier/max_pooling2d_280/MaxPool (2.90m/2.90m flops)
#   mnist_classifier/dense_294/MatMul (1.32m/1.32m flops)
#   mnist_classifier/conv2d_282/BiasAdd (699.84k/699.84k flops)
#   mnist_classifier/max_pooling2d_281/MaxPool (699.84k/699.84k flops)
#   mnist_classifier/conv2d_283/BiasAdd (178.46k/178.46k flops)
#   mnist_classifier/max_pooling2d_282/MaxPool (178.46k/178.46k flops)
#   mnist_classifier/max_pooling2d_283/MaxPool (38.02k/38.02k flops)
#   mnist_classifier/conv2d_284/BiasAdd (38.02k/38.02k flops)
#   mnist_classifier/dense_295/MatMul (9.60k/9.60k flops)
#   mnist_classifier/dense_292/BiasAdd (1.76k/1.76k flops)
#   mnist_classifier/dense_293/BiasAdd (1.38k/1.38k flops)
#   mnist_classifier/dense_294/BiasAdd (480/480 flops)
#   mnist_classifier/dense_295/Softmax (50/50 flops)
#   mnist_classifier/dense_295/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 50.337764
# 2022-05-11 04:31:51.815427: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:51.815556: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:51.817035: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/2.25b flops)
#   mnist_classifier/conv2d_286/Conv2D (1.33b/1.33b flops)
#   mnist_classifier/conv2d_287/Conv2D (370.36m/370.36m flops)
#   mnist_classifier/conv2d_288/Conv2D (220.78m/220.78m flops)
#   mnist_classifier/conv2d_285/Conv2D (128.90m/128.90m flops)
#   mnist_classifier/conv2d_289/Conv2D (120.93m/120.93m flops)
#   mnist_classifier/dense_296/MatMul (56.73m/56.73m flops)
#   mnist_classifier/max_pooling2d_284/MaxPool (7.16m/7.16m flops)
#   mnist_classifier/conv2d_285/BiasAdd (7.16m/7.16m flops)
#   mnist_classifier/dense_297/MatMul (3.27m/3.27m flops)
#   mnist_classifier/conv2d_286/BiasAdd (2.05m/2.05m flops)
#   mnist_classifier/max_pooling2d_285/MaxPool (2.03m/2.03m flops)
#   mnist_classifier/conv2d_287/BiasAdd (489.89k/489.89k flops)
#   mnist_classifier/max_pooling2d_286/MaxPool (489.89k/489.89k flops)
#   mnist_classifier/dense_298/MatMul (458.75k/458.75k flops)
#   mnist_classifier/conv2d_288/BiasAdd (292.03k/292.03k flops)
#   mnist_classifier/max_pooling2d_287/MaxPool (292.03k/292.03k flops)
#   mnist_classifier/max_pooling2d_288/MaxPool (62.21k/62.21k flops)
#   mnist_classifier/conv2d_289/BiasAdd (62.21k/62.21k flops)
#   mnist_classifier/dense_299/MatMul (5.12k/5.12k flops)
#   mnist_classifier/dense_296/BiasAdd (1.82k/1.82k flops)
#   mnist_classifier/dense_297/BiasAdd (896/896 flops)
#   mnist_classifier/dense_298/BiasAdd (256/256 flops)
#   mnist_classifier/dense_299/Softmax (50/50 flops)
#   mnist_classifier/dense_299/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 68.795684
# 2022-05-11 04:31:54.121982: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:54.122101: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:54.123621: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/3.79b flops)
#   mnist_classifier/conv2d_291/Conv2D (2.21b/2.21b flops)
#   mnist_classifier/conv2d_292/Conv2D (705.31m/705.31m flops)
#   mnist_classifier/conv2d_293/Conv2D (391.97m/391.97m flops)
#   mnist_classifier/conv2d_294/Conv2D (187.10m/187.10m flops)
#   mnist_classifier/conv2d_290/Conv2D (172.73m/172.73m flops)
#   mnist_classifier/dense_300/MatMul (83.15m/83.15m flops)
#   mnist_classifier/max_pooling2d_289/MaxPool (9.60m/9.60m flops)
#   mnist_classifier/conv2d_290/BiasAdd (9.60m/9.60m flops)
#   mnist_classifier/dense_301/MatMul (6.48m/6.48m flops)
#   mnist_classifier/dense_302/MatMul (4.28m/4.28m flops)
#   mnist_classifier/conv2d_291/BiasAdd (2.92m/2.92m flops)
#   mnist_classifier/max_pooling2d_290/MaxPool (2.90m/2.90m flops)
#   mnist_classifier/conv2d_292/BiasAdd (753.54k/753.54k flops)
#   mnist_classifier/max_pooling2d_291/MaxPool (753.54k/753.54k flops)
#   mnist_classifier/conv2d_293/BiasAdd (388.86k/388.86k flops)
#   mnist_classifier/max_pooling2d_292/MaxPool (388.86k/388.86k flops)
#   mnist_classifier/max_pooling2d_293/MaxPool (83.82k/83.82k flops)
#   mnist_classifier/conv2d_294/BiasAdd (83.82k/83.82k flops)
#   mnist_classifier/dense_303/MatMul (26.24k/26.24k flops)
#   mnist_classifier/dense_300/BiasAdd (1.98k/1.98k flops)
#   mnist_classifier/dense_301/BiasAdd (1.63k/1.63k flops)
#   mnist_classifier/dense_302/BiasAdd (1.31k/1.31k flops)
#   mnist_classifier/dense_303/Softmax (50/50 flops)
#   mnist_classifier/dense_303/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 86.15262
# 2022-05-11 04:31:57.422068: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:31:57.422140: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:31:57.423621: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/4.93b flops)
#   mnist_classifier/conv2d_296/Conv2D (3.17b/3.17b flops)
#   mnist_classifier/conv2d_297/Conv2D (840.95m/840.95m flops)
#   mnist_classifier/conv2d_298/Conv2D (405.97m/405.97m flops)
#   mnist_classifier/conv2d_295/Conv2D (230.31m/230.31m flops)
#   mnist_classifier/conv2d_299/Conv2D (163.73m/163.73m flops)
#   mnist_classifier/dense_304/MatMul (72.77m/72.77m flops)
#   mnist_classifier/max_pooling2d_294/MaxPool (12.80m/12.80m flops)
#   mnist_classifier/conv2d_295/BiasAdd (12.80m/12.80m flops)
#   mnist_classifier/dense_305/MatMul (6.18m/6.18m flops)
#   mnist_classifier/conv2d_296/BiasAdd (3.15m/3.15m flops)
#   mnist_classifier/max_pooling2d_295/MaxPool (3.12m/3.12m flops)
#   mnist_classifier/dense_306/MatMul (1.17m/1.17m flops)
#   mnist_classifier/conv2d_297/BiasAdd (834.27k/834.27k flops)
#   mnist_classifier/max_pooling2d_296/MaxPool (834.27k/834.27k flops)
#   mnist_classifier/conv2d_298/BiasAdd (363.78k/363.78k flops)
#   mnist_classifier/max_pooling2d_297/MaxPool (363.78k/363.78k flops)
#   mnist_classifier/max_pooling2d_298/MaxPool (78.42k/78.42k flops)
#   mnist_classifier/conv2d_299/BiasAdd (78.42k/78.42k flops)
#   mnist_classifier/dense_307/MatMul (7.04k/7.04k flops)
#   mnist_classifier/dense_304/BiasAdd (1.86k/1.86k flops)
#   mnist_classifier/dense_305/BiasAdd (1.66k/1.66k flops)
#   mnist_classifier/dense_306/BiasAdd (352/352 flops)
#   mnist_classifier/dense_307/Softmax (50/50 flops)
#   mnist_classifier/dense_307/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 84.994076
# 2022-05-11 04:32:00.235012: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-11 04:32:00.235129: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-11 04:32:00.236770: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/5.02b flops)
#   mnist_classifier/conv2d_301/Conv2D (3.38b/3.38b flops)
#   mnist_classifier/conv2d_302/Conv2D (931.05m/931.05m flops)
#   mnist_classifier/conv2d_303/Conv2D (307.98m/307.98m flops)
#   mnist_classifier/conv2d_300/Conv2D (222.09m/222.09m flops)
#   mnist_classifier/conv2d_304/Conv2D (94.23m/94.23m flops)
#   mnist_classifier/dense_308/MatMul (45.69m/45.69m flops)
#   mnist_classifier/max_pooling2d_299/MaxPool (12.34m/12.34m flops)
#   mnist_classifier/conv2d_300/BiasAdd (12.34m/12.34m flops)
#   mnist_classifier/conv2d_301/BiasAdd (3.48m/3.48m flops)
#   mnist_classifier/max_pooling2d_300/MaxPool (3.45m/3.45m flops)
#   mnist_classifier/dense_309/MatMul (2.46m/2.46m flops)
#   mnist_classifier/dense_310/MatMul (1.13m/1.13m flops)
#   mnist_classifier/conv2d_302/BiasAdd (834.27k/834.27k flops)
#   mnist_classifier/max_pooling2d_301/MaxPool (834.27k/834.27k flops)
#   mnist_classifier/conv2d_303/BiasAdd (275.97k/275.97k flops)
#   mnist_classifier/max_pooling2d_302/MaxPool (275.97k/275.97k flops)
#   mnist_classifier/max_pooling2d_303/MaxPool (59.49k/59.49k flops)
#   mnist_classifier/conv2d_304/BiasAdd (59.49k/59.49k flops)
#   mnist_classifier/dense_311/MatMul (14.08k/14.08k flops)
#   mnist_classifier/dense_308/BiasAdd (1.54k/1.54k flops)
#   mnist_classifier/dense_309/BiasAdd (800/800 flops)
#   mnist_classifier/dense_310/BiasAdd (704/704 flops)
#   mnist_classifier/dense_311/Softmax (50/50 flops)
#   mnist_classifier/dense_311/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
