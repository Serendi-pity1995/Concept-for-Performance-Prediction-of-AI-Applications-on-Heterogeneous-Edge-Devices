# %%
import os
import csv
import numpy as np
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from itertools import product
from keras_flops import get_flops
print("TensorFlow version:", tf.__version__)



def VGG19(input_shape):
    
    """
    Implementation of the popular ResNet50 the following architecture:
    CONV2D -> CONV2D -> MAXPOOL -> CONV2D -> CONV2D -> MAXPOOL -> CONV2D -> CONV2D -> CONV2D -> CONV2D -> MAXPOOL->
    CONV2D -> CONV2D -> CONV2D -> CONV2D -> MAXPOOL -> CONV2D -> CONV2D -> CONV2D -> CONV2D -> MAXPOOL ->
    CONV2D -> CONV2D -> CONV2D -> CONV2D -> MAXPOOL -> Flatten -> Dense -> Dense -> TopLayer
    

    Arguments:
    input_shape -- shape of the images of the dataset
    
    Returns:
    model -- a Model() instance in Keras
    """
    
    X_input = Input(input_shape)
    #Block 1
    X = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(X_input)
    X = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(X)
    X = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(X)
    #Block 2
    X = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(X)
    X = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(X)
    X = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(X)
    #Block 3
    X = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(X)
    X = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(X)
    X = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(X)
    X = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv4')(X)
    X = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(X)
    #Block 4
    X = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(X)
    X = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(X)
    X = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(X)
    X = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv4')(X)    
    X = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(X)
    #Block 5
    X = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(X)
    X = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(X)
    X = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(X)
    X = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv4')(X)    
    X = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(X)
    
    
    X = Flatten(name='flatten')(X)
    X = Dense(4096, activation='relu', name='fc1')(X)
    X = Dense(4096, activation='relu', name='fc2')(X)    
    
    # 输出层
    outputs = Dense(10, activation='softmax')(X)
    
    model = Model(inputs=X_input, outputs=outputs)

    
    return model

model_num = 1
input_shape_range =range(32,224,32)

with open("para_count_vgg19.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "FLOPs", "Total_params", "Memory"],])
          
for shape_x in input_shape_range:
    shape_y = shape_x

    input_shape = (shape_x, shape_y, 1)
    model = VGG19(input_shape)
    model.summary()
    # how to compute the memory allocated by the activations of a model
    batch = 1
    shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
    else 1 for s in l.output_shape])) 
    for l in model.layers]))
    memory = (shapes_count * 4 * batch)/10**6
    print(memory)

    Total_params = round(model.count_params()/10 ** 6,2)
    #FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
    with open("para_count_vgg19.csv","a+") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerows([[model_num, shape_x, shape_y, FLOPs, Total_params, memory],])

        model_num = model_num + 1
# Out:
# 2022-04-02 03:46:22.752601: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-04-02 03:46:22.752633: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# TensorFlow version: 2.6.0
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 1)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        640
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              2101248
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense (Dense)                (None, 10)                40970
# =================================================================
# Total params: 38,946,762
# Trainable params: 38,946,762
# Non-trainable params: 0
# _________________________________________________________________
# 1.372204
# 2022-04-02 03:46:23.752032: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-04-02 03:46:23.752063: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-02 03:46:23.752077: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2022-04-02 03:46:23.752238: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 64, 64, 1)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        640
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              8392704
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 45,238,218
# Trainable params: 45,238,218
# Non-trainable params: 0
# _________________________________________________________________
# 5.39038
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 96, 96, 1)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 96, 96, 64)        640
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 96, 96, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 48, 48, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 48, 48, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 48, 48, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 24, 24, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 24, 24, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 24, 24, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 24, 24, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 24, 24, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 12, 12, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 12, 12, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              18878464
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 55,723,978
# Trainable params: 55,723,978
# Non-trainable params: 0
# _________________________________________________________________
# 12.08734
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 128, 128, 1)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 128, 64)      640
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 128, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              33558528
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 70,404,042
# Trainable params: 70,404,042
# Non-trainable params: 0
# _________________________________________________________________
# 21.463084
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 160, 160, 1)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 160, 160, 64)      640
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 160, 160, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 80, 80, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 80, 80, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 80, 80, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 40, 40, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 40, 40, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 40, 40, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 40, 40, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 40, 40, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 20, 20, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 20, 20, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 10, 10, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 5, 5, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              52432896
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 89,278,410
# Trainable params: 89,278,410
# Non-trainable params: 0
# _________________________________________________________________
# 33.517612
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 192, 192, 1)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 192, 192, 64)      640
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 192, 192, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 96, 96, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 96, 96, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 96, 96, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 48, 48, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 48, 48, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 48, 48, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 48, 48, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 48, 48, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 24, 24, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 24, 24, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 24, 24, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 24, 24, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 24, 24, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 12, 12, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              75501568
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 112,347,082
# Trainable params: 112,347,082
# Non-trainable params: 0
# _________________________________________________________________
# 48.250924

# %%
import os
import csv
import numpy as np
import tensorflow as tf
import keras
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from itertools import product
from keras_flops import get_flops

def get_total_number_of_neurons(model, include_output_layer):
    '''
    Args:
        model: Keras model
        include_output_layer: A boolean parameter. Whether or not to include output layer's neurons into the calculation

    Returns: number of neurons in the given model
    '''
    num_layers = len(model.layers)
    total_num_of_neurons = 0
    for layer_index in range(num_layers):
        layer = model.layers[layer_index]
        # since we multiply layer output dimensions, initial value is set to 1.
        num_neurons_in_layer = 1
        for i in range(1, len(layer.output.shape)):
            try:
                # when it is a valid layer to count neurons, an output dimension of the layer can be convertible to int.
                num_neurons_in_layer *= int(layer.output.shape[i])
            except Exception:
                # if the output dimension of layer cannot be convertible to int,
                # just pass that layer since it is not a valid layer to count neurons
                pass
        # if num_neurons_in_layer is not still 1, it means we have a valid layer to count neurons
        if not num_neurons_in_layer == 1:
            # when it is an output layer
            if layer_index == (num_layers - 1):
                if include_output_layer:
                    total_num_of_neurons += num_neurons_in_layer
            else:  # when it is not an output layer
                total_num_of_neurons += num_neurons_in_layer
    return total_num_of_neurons

model_num = 1
input_shape_range =range(32,512,2)

with open("para_count_vgg19.csv","w") as csvfile:
         writer = csv.writer(csvfile)
         writer.writerows([["model_num", "input_horizontal", "input_vertical", "step","number_of_layers", "FLOPs_G", "Total_params_M", "Memory_M", "total_num_of_neurons_M"],])
path = "../vgg19_h5" #文件夹目录
files= os.listdir(path) #得到文件夹下的所有文件名称

for shape_x in input_shape_range:
    shape_y = shape_x
    for step in range(1,11):
        file = "vgg19_{input_x}_{input_y}_{step}.h5".format(input_x=shape_x,input_y=shape_y,step=step)
        if file in files: #遍历文件夹
            model_name = str(file)
            if not os.path.isdir(file): #判断是否是文件夹，不是文件夹才打开
                model = keras.models.load_model("../vgg19_h5/{}".format(model_name))
                num_neurons = get_total_number_of_neurons(model= model, include_output_layer= True)
                num_neurons_M = num_neurons/10**6
                # how to compute the memory allocated by the activations of a model
                batch = 1
                shapes_count = int(np.sum([np.prod(np.array([s if isinstance(s, int) 
                else 1 for s in l.output_shape])) 
                for l in model.layers]))
                memory = (shapes_count * 4 * batch)/10**6
                print(memory)
                layers_length = len(model.layers)
                Total_params = round(model.count_params()/10 ** 6,2)
                FLOPs = round(get_flops(model, batch_size=1)/10 ** 9,2)
                with open("para_count_vgg19.csv","a+") as csvfile:
                    writer = csv.writer(csvfile)
                    writer.writerows([[model_num, shape_x, shape_y, step, layers_length, FLOPs, Total_params, memory, num_neurons_M],])

                    model_num = model_num + 1
# Out:
# 2022-05-16 04:21:23.752787: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-05-16 04:21:23.752803: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-05-16 04:21:24.887474: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu:/usr/local/lib:/opt/vitis_ai/conda/envs/vitis-ai-tensorflow/lib
# 2022-05-16 04:21:24.887491: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-16 04:21:24.887508: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2022-05-16 04:21:24.887633: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.241852
# 2022-05-16 04:21:25.533888: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:21:25.533989: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:21:25.553789: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.008ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# WARNING:tensorflow:From /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py:5063: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/653.58m flops)
#   model/block4_conv4/Conv2D (72.85m/72.85m flops)
#   model/block3_conv4/Conv2D (70.28m/70.28m flops)
#   model/block2_conv2/Conv2D (68.59m/68.59m flops)
#   model/block3_conv3/Conv2D (65.18m/65.18m flops)
#   model/block1_conv2/Conv2D (64.14m/64.14m flops)
#   model/block4_conv3/Conv2D (63.71m/63.71m flops)
#   model/block3_conv2/Conv2D (43.45m/43.45m flops)
#   model/block4_conv2/Conv2D (40.85m/40.85m flops)
#   model/block2_conv1/Conv2D (33.73m/33.73m flops)
#   model/block3_conv1/Conv2D (23.05m/23.05m flops)
#   model/block4_conv1/Conv2D (22.71m/22.71m flops)
#   model/block5_conv4/Conv2D (18.73m/18.73m flops)
#   model/block5_conv3/Conv2D (18.73m/18.73m flops)
#   model/block5_conv2/Conv2D (18.73m/18.73m flops)
#   model/block5_conv1/Conv2D (18.73m/18.73m flops)
#   model/fc2/MatMul (6.61m/6.61m flops)
#   model/fc1/MatMul (2.01m/2.01m flops)
#   model/block1_conv1/Conv2D (1.07m/1.07m flops)
#   model/block1_conv2/BiasAdd (61.44k/61.44k flops)
#   model/block1_pool/MaxPool (61.44k/61.44k flops)
#   model/block1_conv1/BiasAdd (59.39k/59.39k flops)
#   model/dense/MatMul (33.60k/33.60k flops)
#   model/block2_pool/MaxPool (31.23k/31.23k flops)
#   model/block2_conv2/BiasAdd (31.23k/31.23k flops)
#   model/block2_conv1/BiasAdd (31.23k/31.23k flops)
#   model/block3_conv4/BiasAdd (15.87k/15.87k flops)
#   model/block3_pool/MaxPool (15.87k/15.87k flops)
#   model/block3_conv3/BiasAdd (15.74k/15.74k flops)
#   model/block3_conv2/BiasAdd (14.72k/14.72k flops)
#   model/block3_conv1/BiasAdd (10.50k/10.50k flops)
#   model/block4_pool/MaxPool (8.16k/8.16k flops)
#   model/block4_conv4/BiasAdd (8.16k/8.16k flops)
#   model/block4_conv3/BiasAdd (7.94k/7.94k flops)
#   model/block4_conv2/BiasAdd (7.14k/7.14k flops)
#   model/block4_conv1/BiasAdd (5.09k/5.09k flops)
#   model/block5_conv1/BiasAdd (2.04k/2.04k flops)
#   model/block5_conv2/BiasAdd (2.04k/2.04k flops)
#   model/block5_conv3/BiasAdd (2.04k/2.04k flops)
#   model/block5_conv4/BiasAdd (2.04k/2.04k flops)
#   model/block5_pool/MaxPool (2.04k/2.04k flops)
#   model/fc1/BiasAdd (1.97k/1.97k flops)
#   model/fc2/BiasAdd (1.68k/1.68k flops)
#   model/dense/Softmax (50/50 flops)
#   model/dense/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.944028
# 2022-05-16 04:21:26.956110: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:21:26.956186: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:21:26.957839: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/503.95m flops)
#   model_1/block4_conv4/Conv2D (68.47m/68.47m flops)
#   model_1/block3_conv4/Conv2D (58.32m/58.32m flops)
#   model_1/block3_conv3/Conv2D (57.29m/57.29m flops)
#   model_1/block4_conv3/Conv2D (53.64m/53.64m flops)
#   model_1/block3_conv2/Conv2D (51.66m/51.66m flops)
#   model_1/block4_conv2/Conv2D (28.43m/28.43m flops)
#   model_1/block1_conv2/Conv2D (28.02m/28.02m flops)
#   model_1/block2_conv2/Conv2D (25.29m/25.29m flops)
#   model_1/block3_conv1/Conv2D (22.80m/22.80m flops)
#   model_1/block5_conv4/Conv2D (18.73m/18.73m flops)
#   model_1/block5_conv3/Conv2D (18.65m/18.65m flops)
#   model_1/block5_conv2/Conv2D (18.58m/18.58m flops)
#   model_1/block5_conv1/Conv2D (18.58m/18.58m flops)
#   model_1/block4_conv1/Conv2D (16.14m/16.14m flops)
#   model_1/block2_conv1/Conv2D (10.32m/10.32m flops)
#   model_1/fc2/MatMul (5.92m/5.92m flops)
#   model_1/fc1/MatMul (2.07m/2.07m flops)
#   model_1/block1_conv1/Conv2D (700.42k/700.42k flops)
#   model_1/block1_conv2/BiasAdd (40.96k/40.96k flops)
#   model_1/block1_pool/MaxPool (40.96k/40.96k flops)
#   model_1/block1_conv1/BiasAdd (38.91k/38.91k flops)
#   model_1/dense_1/MatMul (29.12k/29.12k flops)
#   model_1/block2_pool/MaxPool (25.09k/25.09k flops)
#   model_1/block2_conv2/BiasAdd (25.09k/25.09k flops)
#   model_1/block3_conv4/BiasAdd (14.46k/14.46k flops)
#   model_1/block3_pool/MaxPool (14.46k/14.46k flops)
#   model_1/block3_conv3/BiasAdd (14.34k/14.34k flops)
#   model_1/block2_conv1/BiasAdd (14.34k/14.34k flops)
#   model_1/block3_conv2/BiasAdd (14.21k/14.21k flops)
#   model_1/block3_conv1/BiasAdd (12.93k/12.93k flops)
#   model_1/block4_pool/MaxPool (8.13k/8.13k flops)
#   model_1/block4_conv4/BiasAdd (8.13k/8.13k flops)
#   model_1/block4_conv3/BiasAdd (7.49k/7.49k flops)
#   model_1/block4_conv2/BiasAdd (6.37k/6.37k flops)
#   model_1/block4_conv1/BiasAdd (3.97k/3.97k flops)
#   model_1/block5_conv3/BiasAdd (2.04k/2.04k flops)
#   model_1/block5_conv4/BiasAdd (2.04k/2.04k flops)
#   model_1/block5_pool/MaxPool (2.04k/2.04k flops)
#   model_1/block5_conv1/BiasAdd (2.03k/2.03k flops)
#   model_1/block5_conv2/BiasAdd (2.03k/2.03k flops)
#   model_1/fc1/BiasAdd (2.03k/2.03k flops)
#   model_1/fc2/BiasAdd (1.46k/1.46k flops)
#   model_1/dense_1/Softmax (50/50 flops)
#   model_1/dense_1/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.95646
# 2022-05-16 04:21:28.247600: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:21:28.247669: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:21:28.249409: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/454.59m flops)
#   model_2/block4_conv4/Conv2D (63.89m/63.89m flops)
#   model_2/block3_conv4/Conv2D (54.74m/54.74m flops)
#   model_2/block4_conv3/Conv2D (49.00m/49.00m flops)
#   model_2/block3_conv3/Conv2D (43.79m/43.79m flops)
#   model_2/block1_conv2/Conv2D (35.39m/35.39m flops)
#   model_2/block2_conv2/Conv2D (30.97m/30.97m flops)
#   model_2/block4_conv2/Conv2D (28.98m/28.98m flops)
#   model_2/block3_conv2/Conv2D (25.95m/25.95m flops)
#   model_2/block5_conv4/Conv2D (18.58m/18.58m flops)
#   model_2/block5_conv3/Conv2D (17.92m/17.92m flops)
#   model_2/block2_conv1/Conv2D (17.69m/17.69m flops)
#   model_2/block4_conv1/Conv2D (17.61m/17.61m flops)
#   model_2/block5_conv2/Conv2D (16.65m/16.65m flops)
#   model_2/block5_conv1/Conv2D (16.04m/16.04m flops)
#   model_2/block3_conv1/Conv2D (12.39m/12.39m flops)
#   model_2/fc2/MatMul (2.73m/2.73m flops)
#   model_2/fc1/MatMul (1.19m/1.19m flops)
#   model_2/block1_conv1/Conv2D (737.28k/737.28k flops)
#   model_2/block1_conv2/BiasAdd (49.15k/49.15k flops)
#   model_2/block1_pool/MaxPool (49.15k/49.15k flops)
#   model_2/block1_conv1/BiasAdd (40.96k/40.96k flops)
#   model_2/dense_2/MatMul (23.36k/23.36k flops)
#   model_2/block2_pool/MaxPool (21.50k/21.50k flops)
#   model_2/block2_conv2/BiasAdd (21.50k/21.50k flops)
#   model_2/block2_conv1/BiasAdd (20.48k/20.48k flops)
#   model_2/block3_conv4/BiasAdd (14.08k/14.08k flops)
#   model_2/block3_pool/MaxPool (14.08k/14.08k flops)
#   model_2/block3_conv3/BiasAdd (13.82k/13.82k flops)
#   model_2/block3_conv2/BiasAdd (11.26k/11.26k flops)
#   model_2/block3_conv1/BiasAdd (8.19k/8.19k flops)
#   model_2/block4_pool/MaxPool (7.55k/7.55k flops)
#   model_2/block4_conv4/BiasAdd (7.55k/7.55k flops)
#   model_2/block4_conv3/BiasAdd (7.52k/7.52k flops)
#   model_2/block4_conv2/BiasAdd (5.79k/5.79k flops)
#   model_2/block4_conv1/BiasAdd (4.45k/4.45k flops)
#   model_2/block5_conv3/BiasAdd (2.03k/2.03k flops)
#   model_2/block5_conv4/BiasAdd (2.03k/2.03k flops)
#   model_2/block5_pool/MaxPool (2.03k/2.03k flops)
#   model_2/block5_conv2/BiasAdd (1.96k/1.96k flops)
#   model_2/block5_conv1/BiasAdd (1.89k/1.89k flops)
#   model_2/fc1/BiasAdd (1.17k/1.17k flops)
#   model_2/fc2/BiasAdd (1.17k/1.17k flops)
#   model_2/dense_2/Softmax (50/50 flops)
#   model_2/dense_2/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.201276
# 2022-05-16 04:21:29.235612: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:21:29.235683: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:21:29.237434: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/689.14m flops)
#   model_3/block3_conv4/Conv2D (74.32m/74.32m flops)
#   model_3/block3_conv3/Conv2D (73.74m/73.74m flops)
#   model_3/block4_conv4/Conv2D (71.43m/71.43m flops)
#   model_3/block3_conv2/Conv2D (71.41m/71.41m flops)
#   model_3/block2_conv2/Conv2D (67.46m/67.46m flops)
#   model_3/block4_conv3/Conv2D (61.39m/61.39m flops)
#   model_3/block1_conv2/Conv2D (47.78m/47.78m flops)
#   model_3/block4_conv2/Conv2D (44.62m/44.62m flops)
#   model_3/block3_conv1/Conv2D (34.57m/34.57m flops)
#   model_3/block2_conv1/Conv2D (29.86m/29.86m flops)
#   model_3/block4_conv1/Conv2D (26.48m/26.48m flops)
#   model_3/block5_conv4/Conv2D (18.73m/18.73m flops)
#   model_3/block5_conv3/Conv2D (18.65m/18.65m flops)
#   model_3/block5_conv2/Conv2D (18.58m/18.58m flops)
#   model_3/block5_conv1/Conv2D (18.21m/18.21m flops)
#   model_3/fc2/MatMul (8.20m/8.20m flops)
#   model_3/fc1/MatMul (2.40m/2.40m flops)
#   model_3/block1_conv1/Conv2D (884.74k/884.74k flops)
#   model_3/block1_conv2/BiasAdd (55.30k/55.30k flops)
#   model_3/block1_pool/MaxPool (55.30k/55.30k flops)
#   model_3/block1_conv1/BiasAdd (49.15k/49.15k flops)
#   model_3/dense_3/MatMul (34.88k/34.88k flops)
#   model_3/block2_pool/MaxPool (31.23k/31.23k flops)
#   model_3/block2_conv2/BiasAdd (31.23k/31.23k flops)
#   model_3/block2_conv1/BiasAdd (30.72k/30.72k flops)
#   model_3/block3_conv3/BiasAdd (16.26k/16.26k flops)
#   model_3/block3_conv4/BiasAdd (16.26k/16.26k flops)
#   model_3/block3_pool/MaxPool (16.26k/16.26k flops)
#   model_3/block3_conv2/BiasAdd (16.13k/16.13k flops)
#   model_3/block3_conv1/BiasAdd (15.74k/15.74k flops)
#   model_3/block4_conv3/BiasAdd (7.97k/7.97k flops)
#   model_3/block4_conv4/BiasAdd (7.97k/7.97k flops)
#   model_3/block4_pool/MaxPool (7.97k/7.97k flops)
#   model_3/block4_conv2/BiasAdd (6.85k/6.85k flops)
#   model_3/block4_conv1/BiasAdd (5.79k/5.79k flops)
#   model_3/fc1/BiasAdd (2.35k/2.35k flops)
#   model_3/block5_conv3/BiasAdd (2.04k/2.04k flops)
#   model_3/block5_conv4/BiasAdd (2.04k/2.04k flops)
#   model_3/block5_pool/MaxPool (2.04k/2.04k flops)
#   model_3/block5_conv2/BiasAdd (2.03k/2.03k flops)
#   model_3/block5_conv1/BiasAdd (2.03k/2.03k flops)
#   model_3/fc2/BiasAdd (1.74k/1.74k flops)
#   model_3/dense_3/Softmax (50/50 flops)
#   model_3/dense_3/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.129084
# 2022-05-16 04:21:30.696618: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:21:30.696689: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:21:30.698359: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/645.95m flops)
#   model_4/block4_conv4/Conv2D (74.91m/74.91m flops)
#   model_4/block3_conv4/Conv2D (74.32m/74.32m flops)
#   model_4/block4_conv3/Conv2D (69.62m/69.62m flops)
#   model_4/block3_conv3/Conv2D (66.71m/66.71m flops)
#   model_4/block4_conv2/Conv2D (59.52m/59.52m flops)
#   model_4/block1_conv2/Conv2D (46.08m/46.08m flops)
#   model_4/block3_conv2/Conv2D (44.65m/44.65m flops)
#   model_4/block2_conv2/Conv2D (43.08m/43.08m flops)
#   model_4/block4_conv1/Conv2D (31.89m/31.89m flops)
#   model_4/block3_conv1/Conv2D (22.33m/22.33m flops)
#   model_4/block2_conv1/Conv2D (18.89m/18.89m flops)
#   model_4/block5_conv4/Conv2D (18.73m/18.73m flops)
#   model_4/block5_conv3/Conv2D (18.73m/18.73m flops)
#   model_4/block5_conv2/Conv2D (18.73m/18.73m flops)
#   model_4/block5_conv1/Conv2D (18.73m/18.73m flops)
#   model_4/fc2/MatMul (14.65m/14.65m flops)
#   model_4/fc1/MatMul (3.05m/3.05m flops)
#   model_4/block1_conv1/Conv2D (921.60k/921.60k flops)
#   model_4/block1_conv1/BiasAdd (51.20k/51.20k flops)
#   model_4/block1_conv2/BiasAdd (51.20k/51.20k flops)
#   model_4/block1_pool/MaxPool (51.20k/51.20k flops)
#   model_4/dense_4/MatMul (48.96k/48.96k flops)
#   model_4/block2_pool/MaxPool (29.18k/29.18k flops)
#   model_4/block2_conv2/BiasAdd (29.18k/29.18k flops)
#   model_4/block2_conv1/BiasAdd (20.99k/20.99k flops)
#   model_4/block3_conv3/BiasAdd (16.26k/16.26k flops)
#   model_4/block3_conv4/BiasAdd (16.26k/16.26k flops)
#   model_4/block3_pool/MaxPool (16.26k/16.26k flops)
#   model_4/block3_conv2/BiasAdd (14.59k/14.59k flops)
#   model_4/block3_conv1/BiasAdd (10.88k/10.88k flops)
#   model_4/block4_conv3/BiasAdd (8.16k/8.16k flops)
#   model_4/block4_conv4/BiasAdd (8.16k/8.16k flops)
#   model_4/block4_pool/MaxPool (8.16k/8.16k flops)
#   model_4/block4_conv2/BiasAdd (7.58k/7.58k flops)
#   model_4/block4_conv1/BiasAdd (6.98k/6.98k flops)
#   model_4/fc1/BiasAdd (2.99k/2.99k flops)
#   model_4/fc2/BiasAdd (2.45k/2.45k flops)
#   model_4/block5_conv2/BiasAdd (2.04k/2.04k flops)
#   model_4/block5_conv3/BiasAdd (2.04k/2.04k flops)
#   model_4/block5_conv4/BiasAdd (2.04k/2.04k flops)
#   model_4/block5_pool/MaxPool (2.04k/2.04k flops)
#   model_4/block5_conv1/BiasAdd (2.04k/2.04k flops)
#   model_4/dense_4/Softmax (50/50 flops)
#   model_4/dense_4/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.052028
# 2022-05-16 04:21:32.317342: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:21:32.317412: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:21:32.319092: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/552.58m flops)
#   model_5/block3_conv4/Conv2D (73.74m/73.74m flops)
#   model_5/block4_conv4/Conv2D (71.97m/71.97m flops)
#   model_5/block4_conv3/Conv2D (65.76m/65.76m flops)
#   model_5/block3_conv3/Conv2D (49.93m/49.93m flops)
#   model_5/block1_conv2/Conv2D (49.77m/49.77m flops)
#   model_5/block4_conv2/Conv2D (48.58m/48.58m flops)
#   model_5/block3_conv2/Conv2D (32.10m/32.10m flops)
#   model_5/block4_conv1/Conv2D (26.48m/26.48m flops)
#   model_5/block2_conv2/Conv2D (21.68m/21.68m flops)
#   model_5/block5_conv4/Conv2D (18.73m/18.73m flops)
#   model_5/block5_conv3/Conv2D (18.73m/18.73m flops)
#   model_5/block5_conv2/Conv2D (18.73m/18.73m flops)
#   model_5/block5_conv1/Conv2D (18.73m/18.73m flops)
#   model_5/block3_conv1/Conv2D (15.68m/15.68m flops)
#   model_5/block2_conv1/Conv2D (13.93m/13.93m flops)
#   model_5/fc2/MatMul (4.92m/4.92m flops)
#   model_5/fc1/MatMul (1.84m/1.84m flops)
#   model_5/block1_conv1/Conv2D (921.60k/921.60k flops)
#   model_5/block1_conv2/BiasAdd (55.30k/55.30k flops)
#   model_5/block1_pool/MaxPool (55.30k/55.30k flops)
#   model_5/block1_conv1/BiasAdd (51.20k/51.20k flops)
#   model_5/dense_5/MatMul (27.20k/27.20k flops)
#   model_5/block2_pool/MaxPool (21.50k/21.50k flops)
#   model_5/block2_conv2/BiasAdd (21.50k/21.50k flops)
#   model_5/block3_conv4/BiasAdd (16.26k/16.26k flops)
#   model_5/block3_pool/MaxPool (16.26k/16.26k flops)
#   model_5/block3_conv3/BiasAdd (16.13k/16.13k flops)
#   model_5/block2_conv1/BiasAdd (14.34k/14.34k flops)
#   model_5/block3_conv2/BiasAdd (11.01k/11.01k flops)
#   model_5/block3_conv1/BiasAdd (10.37k/10.37k flops)
#   model_5/block4_pool/MaxPool (8.16k/8.16k flops)
#   model_5/block4_conv4/BiasAdd (8.16k/8.16k flops)
#   model_5/block4_conv3/BiasAdd (7.84k/7.84k flops)
#   model_5/block4_conv2/BiasAdd (7.46k/7.46k flops)
#   model_5/block4_conv1/BiasAdd (5.79k/5.79k flops)
#   model_5/block5_conv4/BiasAdd (2.04k/2.04k flops)
#   model_5/block5_pool/MaxPool (2.04k/2.04k flops)
#   model_5/block5_conv3/BiasAdd (2.04k/2.04k flops)
#   model_5/block5_conv2/BiasAdd (2.04k/2.04k flops)
#   model_5/block5_conv1/BiasAdd (2.04k/2.04k flops)
#   model_5/fc1/BiasAdd (1.81k/1.81k flops)
#   model_5/fc2/BiasAdd (1.36k/1.36k flops)
#   model_5/dense_5/Softmax (50/50 flops)
#   model_5/dense_5/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.094396
# 2022-05-16 04:21:33.550426: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:21:33.550505: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:21:33.552469: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/667.56m flops)
#   model_6/block4_conv4/Conv2D (74.62m/74.62m flops)
#   model_6/block3_conv4/Conv2D (74.32m/74.32m flops)
#   model_6/block3_conv3/Conv2D (74.32m/74.32m flops)
#   model_6/block2_conv2/Conv2D (73.16m/73.16m flops)
#   model_6/block4_conv3/Conv2D (71.10m/71.10m flops)
#   model_6/block3_conv2/Conv2D (64.96m/64.96m flops)
#   model_6/block4_conv2/Conv2D (44.51m/44.51m flops)
#   model_6/block3_conv1/Conv2D (32.22m/32.22m flops)
#   model_6/block1_conv2/Conv2D (28.02m/28.02m flops)
#   model_6/block4_conv1/Conv2D (23.26m/23.26m flops)
#   model_6/block2_conv1/Conv2D (23.22m/23.22m flops)
#   model_6/block5_conv4/Conv2D (18.73m/18.73m flops)
#   model_6/block5_conv3/Conv2D (18.73m/18.73m flops)
#   model_6/block5_conv2/Conv2D (18.73m/18.73m flops)
#   model_6/block5_conv1/Conv2D (18.73m/18.73m flops)
#   model_6/fc2/MatMul (5.56m/5.56m flops)
#   model_6/fc1/MatMul (2.30m/2.30m flops)
#   model_6/block1_conv1/Conv2D (700.42k/700.42k flops)
#   model_6/block1_conv2/BiasAdd (40.96k/40.96k flops)
#   model_6/block1_pool/MaxPool (40.96k/40.96k flops)
#   model_6/block1_conv1/BiasAdd (38.91k/38.91k flops)
#   model_6/block2_conv1/BiasAdd (32.26k/32.26k flops)
#   model_6/block2_pool/MaxPool (32.26k/32.26k flops)
#   model_6/block2_conv2/BiasAdd (32.26k/32.26k flops)
#   model_6/dense_6/MatMul (24.64k/24.64k flops)
#   model_6/block3_conv3/BiasAdd (16.26k/16.26k flops)
#   model_6/block3_conv2/BiasAdd (16.26k/16.26k flops)
#   model_6/block3_conv4/BiasAdd (16.26k/16.26k flops)
#   model_6/block3_pool/MaxPool (16.26k/16.26k flops)
#   model_6/block3_conv1/BiasAdd (14.21k/14.21k flops)
#   model_6/block4_conv4/BiasAdd (8.16k/8.16k flops)
#   model_6/block4_pool/MaxPool (8.16k/8.16k flops)
#   model_6/block4_conv3/BiasAdd (8.13k/8.13k flops)
#   model_6/block4_conv2/BiasAdd (7.78k/7.78k flops)
#   model_6/block4_conv1/BiasAdd (5.09k/5.09k flops)
#   model_6/fc1/BiasAdd (2.26k/2.26k flops)
#   model_6/block5_conv2/BiasAdd (2.04k/2.04k flops)
#   model_6/block5_conv3/BiasAdd (2.04k/2.04k flops)
#   model_6/block5_conv4/BiasAdd (2.04k/2.04k flops)
#   model_6/block5_pool/MaxPool (2.04k/2.04k flops)
#   model_6/block5_conv1/BiasAdd (2.04k/2.04k flops)
#   model_6/fc2/BiasAdd (1.23k/1.23k flops)
#   model_6/dense_6/Softmax (50/50 flops)
#   model_6/dense_6/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.073564
# 2022-05-16 04:21:34.875549: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:21:34.875619: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:21:34.877346: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/608.24m flops)
#   model_7/block3_conv4/Conv2D (70.25m/70.25m flops)
#   model_7/block2_conv2/Conv2D (68.59m/68.59m flops)
#   model_7/block4_conv4/Conv2D (66.48m/66.48m flops)
#   model_7/block3_conv3/Conv2D (65.79m/65.79m flops)
#   model_7/block3_conv2/Conv2D (57.64m/57.64m flops)
#   model_7/block4_conv3/Conv2D (56.45m/56.45m flops)
#   model_7/block4_conv2/Conv2D (33.03m/33.03m flops)
#   model_7/block3_conv1/Conv2D (29.80m/29.80m flops)
#   model_7/block1_conv2/Conv2D (27.13m/27.13m flops)
#   model_7/block2_conv1/Conv2D (25.86m/25.86m flops)
#   model_7/block4_conv1/Conv2D (19.45m/19.45m flops)
#   model_7/block5_conv4/Conv2D (18.73m/18.73m flops)
#   model_7/block5_conv3/Conv2D (18.73m/18.73m flops)
#   model_7/block5_conv2/Conv2D (18.73m/18.73m flops)
#   model_7/block5_conv1/Conv2D (18.51m/18.51m flops)
#   model_7/fc2/MatMul (9.48m/9.48m flops)
#   model_7/fc1/MatMul (2.63m/2.63m flops)
#   model_7/block1_conv1/Conv2D (589.82k/589.82k flops)
#   model_7/block1_conv2/BiasAdd (47.10k/47.10k flops)
#   model_7/block1_pool/MaxPool (47.10k/47.10k flops)
#   model_7/dense_7/MatMul (36.80k/36.80k flops)
#   model_7/block1_conv1/BiasAdd (32.77k/32.77k flops)
#   model_7/block2_pool/MaxPool (31.23k/31.23k flops)
#   model_7/block2_conv2/BiasAdd (31.23k/31.23k flops)
#   model_7/block2_conv1/BiasAdd (31.23k/31.23k flops)
#   model_7/block3_conv4/BiasAdd (16.13k/16.13k flops)
#   model_7/block3_pool/MaxPool (16.13k/16.13k flops)
#   model_7/block3_conv3/BiasAdd (15.49k/15.49k flops)
#   model_7/block3_conv2/BiasAdd (15.10k/15.10k flops)
#   model_7/block3_conv1/BiasAdd (13.57k/13.57k flops)
#   model_7/block4_pool/MaxPool (8.06k/8.06k flops)
#   model_7/block4_conv4/BiasAdd (8.06k/8.06k flops)
#   model_7/block4_conv3/BiasAdd (7.33k/7.33k flops)
#   model_7/block4_conv2/BiasAdd (6.85k/6.85k flops)
#   model_7/block4_conv1/BiasAdd (4.29k/4.29k flops)
#   model_7/fc1/BiasAdd (2.58k/2.58k flops)
#   model_7/block5_conv1/BiasAdd (2.04k/2.04k flops)
#   model_7/block5_conv2/BiasAdd (2.04k/2.04k flops)
#   model_7/block5_conv3/BiasAdd (2.04k/2.04k flops)
#   model_7/block5_conv4/BiasAdd (2.04k/2.04k flops)
#   model_7/block5_pool/MaxPool (2.04k/2.04k flops)
#   model_7/fc2/BiasAdd (1.84k/1.84k flops)
#   model_7/dense_7/Softmax (50/50 flops)
#   model_7/dense_7/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.177468
# 2022-05-16 04:21:36.203739: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:21:36.203811: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:21:36.205506: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/648.23m flops)
#   model_8/block4_conv4/Conv2D (74.62m/74.62m flops)
#   model_8/block4_conv3/Conv2D (71.69m/71.69m flops)
#   model_8/block4_conv2/Conv2D (69.15m/69.15m flops)
#   model_8/block3_conv4/Conv2D (63.07m/63.07m flops)
#   model_8/block1_conv2/Conv2D (59.72m/59.72m flops)
#   model_8/block3_conv3/Conv2D (58.26m/58.26m flops)
#   model_8/block3_conv2/Conv2D (46.71m/46.71m flops)
#   model_8/block2_conv2/Conv2D (43.79m/43.79m flops)
#   model_8/block4_conv1/Conv2D (33.30m/33.30m flops)
#   model_8/block2_conv1/Conv2D (24.33m/24.33m flops)
#   model_8/block3_conv1/Conv2D (23.14m/23.14m flops)
#   model_8/block5_conv4/Conv2D (18.73m/18.73m flops)
#   model_8/block5_conv3/Conv2D (18.73m/18.73m flops)
#   model_8/block5_conv2/Conv2D (18.73m/18.73m flops)
#   model_8/block5_conv1/Conv2D (18.73m/18.73m flops)
#   model_8/fc2/MatMul (2.88m/2.88m flops)
#   model_8/fc1/MatMul (1.26m/1.26m flops)
#   model_8/block1_conv1/Conv2D (995.33k/995.33k flops)
#   model_8/block1_conv2/BiasAdd (61.44k/61.44k flops)
#   model_8/block1_pool/MaxPool (61.44k/61.44k flops)
#   model_8/block1_conv1/BiasAdd (55.30k/55.30k flops)
#   model_8/block2_pool/MaxPool (27.65k/27.65k flops)
#   model_8/block2_conv2/BiasAdd (27.65k/27.65k flops)
#   model_8/dense_8/MatMul (23.36k/23.36k flops)
#   model_8/block2_conv1/BiasAdd (22.53k/22.53k flops)
#   model_8/block3_conv4/BiasAdd (15.10k/15.10k flops)
#   model_8/block3_pool/MaxPool (15.10k/15.10k flops)
#   model_8/block3_conv3/BiasAdd (14.85k/14.85k flops)
#   model_8/block3_conv2/BiasAdd (13.95k/13.95k flops)
#   model_8/block3_conv1/BiasAdd (11.90k/11.90k flops)
#   model_8/block4_pool/MaxPool (8.16k/8.16k flops)
#   model_8/block4_conv4/BiasAdd (8.16k/8.16k flops)
#   model_8/block4_conv3/BiasAdd (8.13k/8.13k flops)
#   model_8/block4_conv2/BiasAdd (7.84k/7.84k flops)
#   model_8/block4_conv1/BiasAdd (7.84k/7.84k flops)
#   model_8/block5_conv1/BiasAdd (2.04k/2.04k flops)
#   model_8/block5_conv2/BiasAdd (2.04k/2.04k flops)
#   model_8/block5_conv3/BiasAdd (2.04k/2.04k flops)
#   model_8/block5_conv4/BiasAdd (2.04k/2.04k flops)
#   model_8/block5_pool/MaxPool (2.04k/2.04k flops)
#   model_8/fc1/BiasAdd (1.23k/1.23k flops)
#   model_8/fc2/BiasAdd (1.17k/1.17k flops)
#   model_8/dense_8/Softmax (50/50 flops)
#   model_8/dense_8/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1.007996
# 2022-05-16 04:21:37.198921: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:21:37.198998: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:21:37.200795: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/546.23m flops)
#   model_9/block4_conv4/Conv2D (73.15m/73.15m flops)
#   model_9/block4_conv3/Conv2D (70.56m/70.56m flops)
#   model_9/block3_conv4/Conv2D (68.58m/68.58m flops)
#   model_9/block3_conv3/Conv2D (61.33m/61.33m flops)
#   model_9/block4_conv2/Conv2D (49.39m/49.39m flops)
#   model_9/block1_conv2/Conv2D (42.39m/42.39m flops)
#   model_9/block3_conv2/Conv2D (27.37m/27.37m flops)
#   model_9/block4_conv1/Conv2D (24.80m/24.80m flops)
#   model_9/block2_conv2/Conv2D (23.11m/23.11m flops)
#   model_9/block5_conv4/Conv2D (18.65m/18.65m flops)
#   model_9/block5_conv3/Conv2D (18.58m/18.58m flops)
#   model_9/block5_conv2/Conv2D (18.58m/18.58m flops)
#   model_9/block5_conv1/Conv2D (18.58m/18.58m flops)
#   model_9/block2_conv1/Conv2D (15.21m/15.21m flops)
#   model_9/block3_conv1/Conv2D (9.46m/9.46m flops)
#   model_9/fc2/MatMul (3.76m/3.76m flops)
#   model_9/fc1/MatMul (1.52m/1.52m flops)
#   model_9/block1_conv1/Conv2D (847.87k/847.87k flops)
#   model_9/block1_conv2/BiasAdd (51.20k/51.20k flops)
#   model_9/block1_pool/MaxPool (51.20k/51.20k flops)
#   model_9/block1_conv1/BiasAdd (47.10k/47.10k flops)
#   model_9/dense_9/MatMul (25.28k/25.28k flops)
#   model_9/block2_pool/MaxPool (19.46k/19.46k flops)
#   model_9/block2_conv2/BiasAdd (19.46k/19.46k flops)
#   model_9/block2_conv1/BiasAdd (16.90k/16.90k flops)
#   model_9/block3_conv4/BiasAdd (15.74k/15.74k flops)
#   model_9/block3_pool/MaxPool (15.74k/15.74k flops)
#   model_9/block3_conv3/BiasAdd (15.49k/15.49k flops)
#   model_9/block3_conv2/BiasAdd (14.08k/14.08k flops)
#   model_9/block4_pool/MaxPool (8.13k/8.13k flops)
#   model_9/block4_conv4/BiasAdd (8.13k/8.13k flops)
#   model_9/block4_conv3/BiasAdd (8.00k/8.00k flops)
#   model_9/block4_conv2/BiasAdd (7.84k/7.84k flops)
#   model_9/block3_conv1/BiasAdd (6.91k/6.91k flops)
#   model_9/block4_conv1/BiasAdd (5.60k/5.60k flops)
#   model_9/block5_conv4/BiasAdd (2.04k/2.04k flops)
#   model_9/block5_pool/MaxPool (2.04k/2.04k flops)
#   model_9/block5_conv1/BiasAdd (2.03k/2.03k flops)
#   model_9/block5_conv2/BiasAdd (2.03k/2.03k flops)
#   model_9/block5_conv3/BiasAdd (2.03k/2.03k flops)
#   model_9/fc1/BiasAdd (1.49k/1.49k flops)
#   model_9/fc2/BiasAdd (1.26k/1.26k flops)
#   model_9/dense_9/Softmax (50/50 flops)
#   model_9/dense_9/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 4.589292
# 2022-05-16 04:21:37.933095: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:21:37.933163: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:21:37.934910: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/2.87b flops)
#   model_10/block4_conv4/Conv2D (299.64m/299.64m flops)
#   model_10/block4_conv3/Conv2D (298.46m/298.46m flops)
#   model_10/block4_conv2/Conv2D (293.78m/293.78m flops)
#   model_10/block2_conv2/Conv2D (292.63m/292.63m flops)
#   model_10/block3_conv4/Conv2D (290.30m/290.30m flops)
#   model_10/block3_conv3/Conv2D (285.70m/285.70m flops)
#   model_10/block3_conv2/Conv2D (258.27m/258.27m flops)
#   model_10/block4_conv1/Conv2D (145.73m/145.73m flops)
#   model_10/block1_conv2/Conv2D (138.02m/138.02m flops)
#   model_10/block3_conv1/Conv2D (131.22m/131.22m flops)
#   model_10/block2_conv1/Conv2D (120.77m/120.77m flops)
#   model_10/block5_conv2/Conv2D (74.91m/74.91m flops)
#   model_10/block5_conv1/Conv2D (74.91m/74.91m flops)
#   model_10/block5_conv3/Conv2D (74.91m/74.91m flops)
#   model_10/block5_conv4/Conv2D (74.91m/74.91m flops)
#   model_10/fc1/MatMul (5.55m/5.55m flops)
#   model_10/fc2/MatMul (3.18m/3.18m flops)
#   model_10/block1_conv1/Conv2D (2.65m/2.65m flops)
#   model_10/block1_conv2/BiasAdd (212.99k/212.99k flops)
#   model_10/block1_pool/MaxPool (212.99k/212.99k flops)
#   model_10/block1_conv1/BiasAdd (147.46k/147.46k flops)
#   model_10/block2_conv1/BiasAdd (129.02k/129.02k flops)
#   model_10/block2_conv2/BiasAdd (129.02k/129.02k flops)
#   model_10/block2_pool/MaxPool (129.02k/129.02k flops)
#   model_10/block3_pool/MaxPool (64.51k/64.51k flops)
#   model_10/block3_conv4/BiasAdd (64.51k/64.51k flops)
#   model_10/block3_conv3/BiasAdd (64.00k/64.00k flops)
#   model_10/block3_conv2/BiasAdd (63.49k/63.49k flops)
#   model_10/block3_conv1/BiasAdd (57.86k/57.86k flops)
#   model_10/block4_conv3/BiasAdd (32.64k/32.64k flops)
#   model_10/block4_pool/MaxPool (32.64k/32.64k flops)
#   model_10/block4_conv4/BiasAdd (32.64k/32.64k flops)
#   model_10/block4_conv2/BiasAdd (32.51k/32.51k flops)
#   model_10/block4_conv1/BiasAdd (32.13k/32.13k flops)
#   model_10/dense_10/MatMul (23.36k/23.36k flops)
#   model_10/block5_conv2/BiasAdd (8.16k/8.16k flops)
#   model_10/block5_conv1/BiasAdd (8.16k/8.16k flops)
#   model_10/block5_conv3/BiasAdd (8.16k/8.16k flops)
#   model_10/block5_conv4/BiasAdd (8.16k/8.16k flops)
#   model_10/block5_pool/MaxPool (8.16k/8.16k flops)
#   model_10/fc1/BiasAdd (1.36k/1.36k flops)
#   model_10/fc2/BiasAdd (1.17k/1.17k flops)
#   model_10/dense_10/Softmax (50/50 flops)
#   model_10/dense_10/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 4.099628
# 2022-05-16 04:21:38.761134: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:21:38.761221: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:21:38.762897: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/2.58b flops)
#   model_11/block4_conv4/Conv2D (288.00m/288.00m flops)
#   model_11/block3_conv4/Conv2D (283.39m/283.39m flops)
#   model_11/block2_conv2/Conv2D (274.27m/274.27m flops)
#   model_11/block4_conv3/Conv2D (269.57m/269.57m flops)
#   model_11/block3_conv3/Conv2D (262.99m/262.99m flops)
#   model_11/block3_conv2/Conv2D (248.02m/248.02m flops)
# ...
# 2022-05-16 04:24:22.915021: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/24.18b flops)
#   model_81/block3_conv4/Conv2D (2.97b/2.97b flops)
#   model_81/block4_conv4/Conv2D (2.94b/2.94b flops)
#   model_81/block4_conv3/Conv2D (2.76b/2.76b flops)
#   model_81/block3_conv3/Conv2D (2.64b/2.64b flops)
#   model_81/block3_conv2/Conv2D (2.03b/2.03b flops)
#   model_81/block4_conv2/Conv2D (1.72b/1.72b flops)
#   model_81/block1_conv2/Conv2D (1.70b/1.70b flops)
#   model_81/block2_conv2/Conv2D (1.54b/1.54b flops)
#   model_81/block4_conv1/Conv2D (924.77m/924.77m flops)
#   model_81/block2_conv1/Conv2D (870.64m/870.64m flops)
#   model_81/block3_conv1/Conv2D (841.83m/841.83m flops)
#   model_81/block5_conv4/Conv2D (785.02m/785.02m flops)
#   model_81/block5_conv3/Conv2D (778.86m/778.86m flops)
#   model_81/block5_conv2/Conv2D (775.78m/775.78m flops)
#   model_81/block5_conv1/Conv2D (763.52m/763.52m flops)
#   model_81/fc1/MatMul (79.32m/79.32m flops)
#   model_81/block1_conv1/Conv2D (32.71m/32.71m flops)
#   model_81/fc2/MatMul (6.98m/6.98m flops)
#   model_81/block1_conv2/BiasAdd (2.25m/2.25m flops)
#   model_81/block1_pool/MaxPool (2.25m/2.25m flops)
#   model_81/block1_conv1/BiasAdd (1.82m/1.82m flops)
#   model_81/block2_conv2/BiasAdd (995.07k/995.07k flops)
#   model_81/block2_pool/MaxPool (995.07k/995.07k flops)
#   model_81/block2_conv1/BiasAdd (930.18k/930.18k flops)
#   model_81/block3_pool/MaxPool (676.00k/676.00k flops)
#   model_81/block3_conv4/BiasAdd (676.00k/676.00k flops)
#   model_81/block3_conv3/BiasAdd (659.78k/659.78k flops)
#   model_81/block3_conv2/BiasAdd (600.29k/600.29k flops)
#   model_81/block3_conv1/BiasAdd (508.35k/508.35k flops)
#   model_81/block4_pool/MaxPool (336.65k/336.65k flops)
#   model_81/block4_conv4/BiasAdd (336.65k/336.65k flops)
#   model_81/block4_conv3/BiasAdd (328.54k/328.54k flops)
#   model_81/block4_conv2/BiasAdd (315.02k/315.02k flops)
#   model_81/block4_conv1/BiasAdd (205.50k/205.50k flops)
#   model_81/block5_conv4/BiasAdd (86.19k/86.19k flops)
#   model_81/block5_conv2/BiasAdd (85.51k/85.51k flops)
#   model_81/block5_conv3/BiasAdd (85.51k/85.51k flops)
#   model_81/block5_conv1/BiasAdd (85.18k/85.18k flops)
#   model_81/block5_pool/MaxPool (73.44k/73.44k flops)
#   model_81/dense_81/MatMul (32.32k/32.32k flops)
#   model_81/fc1/BiasAdd (2.16k/2.16k flops)
#   model_81/fc2/BiasAdd (1.62k/1.62k flops)
#   model_81/dense_81/Softmax (50/50 flops)
#   model_81/dense_81/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 42.65122
# 2022-05-16 04:24:26.951935: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:24:26.952026: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:24:26.953836: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/23.69b flops)
#   model_82/block3_conv4/Conv2D (2.97b/2.97b flops)
#   model_82/block4_conv4/Conv2D (2.72b/2.72b flops)
#   model_82/block3_conv3/Conv2D (2.71b/2.71b flops)
#   model_82/block4_conv3/Conv2D (2.49b/2.49b flops)
#   model_82/block3_conv2/Conv2D (2.35b/2.35b flops)
#   model_82/block4_conv2/Conv2D (1.91b/1.91b flops)
#   model_82/block1_conv2/Conv2D (1.58b/1.58b flops)
#   model_82/block2_conv2/Conv2D (1.21b/1.21b flops)
#   model_82/block4_conv1/Conv2D (1.10b/1.10b flops)
#   model_82/block3_conv1/Conv2D (850.40m/850.40m flops)
#   model_82/block5_conv3/Conv2D (791.22m/791.22m flops)
#   model_82/block5_conv4/Conv2D (791.22m/791.22m flops)
#   model_82/block5_conv2/Conv2D (744.68m/744.68m flops)
#   model_82/block5_conv1/Conv2D (700.88m/700.88m flops)
#   model_82/block2_conv1/Conv2D (662.72m/662.72m flops)
#   model_82/fc1/MatMul (58.16m/58.16m flops)
#   model_82/block1_conv1/Conv2D (34.27m/34.27m flops)
#   model_82/fc2/MatMul (4.71m/4.71m flops)
#   model_82/block1_conv2/BiasAdd (1.99m/1.99m flops)
#   model_82/block1_pool/MaxPool (1.99m/1.99m flops)
#   model_82/block1_conv1/BiasAdd (1.90m/1.90m flops)
#   model_82/block2_conv2/BiasAdd (908.54k/908.54k flops)
#   model_82/block2_pool/MaxPool (908.54k/908.54k flops)
#   model_82/block2_conv1/BiasAdd (800.38k/800.38k flops)
#   model_82/block3_pool/MaxPool (686.82k/686.82k flops)
#   model_82/block3_conv4/BiasAdd (686.82k/686.82k flops)
#   model_82/block3_conv3/BiasAdd (648.96k/648.96k flops)
#   model_82/block3_conv2/BiasAdd (627.33k/627.33k flops)
#   model_82/block3_conv1/BiasAdd (562.43k/562.43k flops)
#   model_82/block4_pool/MaxPool (324.48k/324.48k flops)
#   model_82/block4_conv4/BiasAdd (324.48k/324.48k flops)
#   model_82/block4_conv3/BiasAdd (315.02k/315.02k flops)
#   model_82/block4_conv2/BiasAdd (297.44k/297.44k flops)
#   model_82/block4_conv1/BiasAdd (240.66k/240.66k flops)
#   model_82/block5_conv2/BiasAdd (86.19k/86.19k flops)
#   model_82/block5_conv3/BiasAdd (86.19k/86.19k flops)
#   model_82/block5_conv4/BiasAdd (86.19k/86.19k flops)
#   model_82/block5_conv1/BiasAdd (81.12k/81.12k flops)
#   model_82/block5_pool/MaxPool (73.44k/73.44k flops)
#   model_82/dense_82/MatMul (29.76k/29.76k flops)
#   model_82/fc1/BiasAdd (1.58k/1.58k flops)
#   model_82/fc2/BiasAdd (1.49k/1.49k flops)
#   model_82/dense_82/Softmax (50/50 flops)
#   model_82/dense_82/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 44.68426
# 2022-05-16 04:24:30.131825: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:24:30.131899: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:24:30.133749: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/27.33b flops)
#   model_83/block4_conv3/Conv2D (3.16b/3.16b flops)
#   model_83/block4_conv4/Conv2D (3.16b/3.16b flops)
#   model_83/block4_conv2/Conv2D (3.07b/3.07b flops)
#   model_83/block3_conv4/Conv2D (2.99b/2.99b flops)
#   model_83/block3_conv3/Conv2D (2.80b/2.80b flops)
#   model_83/block2_conv2/Conv2D (2.70b/2.70b flops)
#   model_83/block3_conv2/Conv2D (1.67b/1.67b flops)
#   model_83/block4_conv1/Conv2D (1.53b/1.53b flops)
#   model_83/block1_conv2/Conv2D (1.25b/1.25b flops)
#   model_83/block3_conv1/Conv2D (883.10m/883.10m flops)
#   model_83/block2_conv1/Conv2D (856.63m/856.63m flops)
#   model_83/block5_conv1/Conv2D (791.22m/791.22m flops)
#   model_83/block5_conv2/Conv2D (791.22m/791.22m flops)
#   model_83/block5_conv3/Conv2D (791.22m/791.22m flops)
#   model_83/block5_conv4/Conv2D (791.22m/791.22m flops)
#   model_83/fc1/MatMul (44.06m/44.06m flops)
#   model_83/block1_conv1/Conv2D (31.15m/31.15m flops)
#   model_83/fc2/MatMul (2.65m/2.65m flops)
#   model_83/block1_conv1/BiasAdd (1.73m/1.73m flops)
#   model_83/block1_conv2/BiasAdd (1.73m/1.73m flops)
#   model_83/block1_pool/MaxPool (1.73m/1.73m flops)
#   model_83/block2_conv2/BiasAdd (1.36m/1.36m flops)
#   model_83/block2_pool/MaxPool (1.36m/1.36m flops)
#   model_83/block2_conv1/BiasAdd (1.19m/1.19m flops)
#   model_83/block3_pool/MaxPool (686.82k/686.82k flops)
#   model_83/block3_conv4/BiasAdd (686.82k/686.82k flops)
#   model_83/block3_conv3/BiasAdd (654.37k/654.37k flops)
#   model_83/block3_conv2/BiasAdd (643.55k/643.55k flops)
#   model_83/block3_conv1/BiasAdd (389.38k/389.38k flops)
#   model_83/block4_conv3/BiasAdd (344.76k/344.76k flops)
#   model_83/block4_conv2/BiasAdd (344.76k/344.76k flops)
#   model_83/block4_pool/MaxPool (344.76k/344.76k flops)
#   model_83/block4_conv4/BiasAdd (344.76k/344.76k flops)
#   model_83/block4_conv1/BiasAdd (333.94k/333.94k flops)
#   model_83/block5_conv2/BiasAdd (86.19k/86.19k flops)
#   model_83/block5_conv1/BiasAdd (86.19k/86.19k flops)
#   model_83/block5_conv3/BiasAdd (86.19k/86.19k flops)
#   model_83/block5_conv4/BiasAdd (86.19k/86.19k flops)
#   model_83/block5_pool/MaxPool (73.44k/73.44k flops)
#   model_83/dense_83/MatMul (22.08k/22.08k flops)
#   model_83/fc1/BiasAdd (1.20k/1.20k flops)
#   model_83/fc2/BiasAdd (1.10k/1.10k flops)
#   model_83/dense_83/Softmax (50/50 flops)
#   model_83/dense_83/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 36.124844
# 2022-05-16 04:24:32.971157: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-05-16 04:24:32.971247: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-05-16 04:24:32.973022: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.004ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/21.74b flops)
#   model_84/block4_conv4/Conv2D (3.09b/3.09b flops)
#   model_84/block4_conv3/Conv2D (3.05b/3.05b flops)
#   model_84/block3_conv4/Conv2D (2.85b/2.85b flops)
#   model_84/block4_conv2/Conv2D (2.73b/2.73b flops)
#   model_84/block3_conv3/Conv2D (2.30b/2.30b flops)
#   model_84/block4_conv1/Conv2D (1.37b/1.37b flops)
#   model_84/block1_conv2/Conv2D (996.80m/996.80m flops)
#   model_84/block5_conv4/Conv2D (791.22m/791.22m flops)
#   model_84/block5_conv3/Conv2D (791.22m/791.22m flops)
#   model_84/block5_conv2/Conv2D (788.12m/788.12m flops)
#   model_84/block5_conv1/Conv2D (781.94m/781.94m flops)
#   model_84/block3_conv2/Conv2D (714.89m/714.89m flops)
#   model_84/block2_conv2/Conv2D (700.10m/700.10m flops)
#   model_84/block2_conv1/Conv2D (451.68m/451.68m flops)
#   model_84/block3_conv1/Conv2D (217.27m/217.27m flops)
#   model_84/fc1/MatMul (71.09m/71.09m flops)
#   model_84/block1_conv1/Conv2D (24.92m/24.92m flops)
#   model_84/fc2/MatMul (6.75m/6.75m flops)
#   model_84/block1_conv2/BiasAdd (1.73m/1.73m flops)
#   model_84/block1_pool/MaxPool (1.73m/1.73m flops)
#   model_84/block1_conv1/BiasAdd (1.38m/1.38m flops)
#   model_84/block3_pool/MaxPool (681.41k/681.41k flops)
#   model_84/block3_conv4/BiasAdd (681.41k/681.41k flops)
#   model_84/block2_pool/MaxPool (670.59k/670.59k flops)
#   model_84/block2_conv2/BiasAdd (670.59k/670.59k flops)
#   model_84/block3_conv3/BiasAdd (627.33k/627.33k flops)
#   model_84/block2_conv1/BiasAdd (627.33k/627.33k flops)
#   model_84/block3_conv2/BiasAdd (551.62k/551.62k flops)
#   model_84/block4_conv4/BiasAdd (342.06k/342.06k flops)
#   model_84/block4_pool/MaxPool (342.06k/342.06k flops)
#   model_84/block4_conv3/BiasAdd (339.35k/339.35k flops)
#   model_84/block4_conv2/BiasAdd (338.00k/338.00k flops)
#   model_84/block4_conv1/BiasAdd (302.85k/302.85k flops)
#   model_84/block3_conv1/BiasAdd (194.69k/194.69k flops)
#   model_84/block5_conv2/BiasAdd (86.19k/86.19k flops)
#   model_84/block5_conv3/BiasAdd (86.19k/86.19k flops)
#   model_84/block5_conv4/BiasAdd (86.19k/86.19k flops)
#   model_84/block5_conv1/BiasAdd (85.85k/85.85k flops)
#   model_84/block5_pool/MaxPool (73.44k/73.44k flops)
#   model_84/dense_84/MatMul (34.88k/34.88k flops)
#   model_84/fc1/BiasAdd (1.94k/1.94k flops)
#   model_84/fc2/BiasAdd (1.74k/1.74k flops)
#   model_84/dense_84/Softmax (50/50 flops)
#   model_84/dense_84/BiasAdd (10/10 flops)
#
# ======================End of Report==========================
