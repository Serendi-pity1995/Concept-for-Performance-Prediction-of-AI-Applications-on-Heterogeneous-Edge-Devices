# %%
import pandas
import statsmodels.formula.api as sm
import matplotlib.pyplot as plt
df = pandas.read_csv("pred_result_AlexNet.csv")
x = df["index"]
y1 = df["error_2variables"]
y2 = df["error_3variables"]

plt.xlabel("index")
plt.ylabel("error(%)")
plt.title("prediction error ")
plt.scatter(x, y1)

# %%
import pandas
import statsmodels.formula.api as sm
import matplotlib.pyplot as plt
df = pandas.read_csv("pred_result_AlexNet.csv")
x = df["index"]
y1 = df["error_2variables"]
y2 = df["error_3variables"]

plt.xlabel("index")
plt.ylabel("error(%)")
plt.title("prediction error ")
plt.scatter(x, y2)
