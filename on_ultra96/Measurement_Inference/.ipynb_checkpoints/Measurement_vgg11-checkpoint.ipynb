# %%
from pynq_dpu import DpuOverlay
from time import time
import numpy as np
from six.moves import urllib
import csv
import os
from itertools import product
model_num = 0
with open("model_result_vgg11.csv","w") as csvfile: 
    writer = csv.writer(csvfile)
    writer.writerow(["index","input_horizontal","input_vertical","step","Execution time","Throughout"])

path = "./xmodel_vgg11" 
files= os.listdir(path) 


input_shape_range =range(32,512,2)
step_range =range(1,11,1)            
for shape_x,step in product(input_shape_range,step_range):
    shape_y = shape_x
    file = "vgg11_{input_x}_{input_y}_{step}.xmodel".format(input_x=shape_x,input_y=shape_y,step=step)
    if file in files: 
        model_name = str(file)
        if not os.path.isdir(file): 
            #Prepare the overlay
            overlay = DpuOverlay("dpu.bit")
            overlay.load_model("./xmodel_vgg11/{}".format(file))

            opener = urllib.request.build_opener()
            opener.addheaders = [('User-agent', 'Mozilla/5.0')]
            urllib.request.install_opener(opener)

            #load test data

            test_data = np.random.randint(0,255,size=[100,shape_x,shape_y,1])
            test_label = np.random.randint(0,10,size=[100,])
            test_data = test_data.astype('float32')
            test_data /= 255.0
            
            print("Total number of test images: {}".format(test_data.shape[0]))
            print("  Dimension of each picture: {}x{}".format(test_data.shape[1],
                                                              test_data.shape[2]))

            #use VART 
            dpu = overlay.runner

            inputTensors = dpu.get_input_tensors()
            outputTensors = dpu.get_output_tensors()

            shapeIn = tuple(inputTensors[0].dims)
            shapeOut = tuple(outputTensors[0].dims)
            outputSize = int(outputTensors[0].get_data_size() / shapeIn[0])

            softmax = np.empty(outputSize)

            output_data = [np.empty(shapeOut, dtype=np.float32, order="C")]
            input_data = [np.empty(shapeIn, dtype=np.float32, order="C")]
            image = input_data[0]

            def calculate_softmax(data):
                result = np.exp(data)
                return result


            #Run DPU to make predictions

            total = test_data.shape[0]
            predictions = np.empty_like(test_label)
            print("Classifying {} digit pictures ...".format(total))

            start = time()
            for i in range(total):
                image[0,...] = test_data[i]
                job_id = dpu.execute_async(input_data, output_data)
                dpu.wait(job_id)
                temp = [j.reshape(1, outputSize) for j in output_data]
                softmax = calculate_softmax(temp[0][0])
                predictions[i] = softmax.argmax()

            stop = time()
            correct = np.sum(predictions==test_label)
            execution_time = (stop-start)*10
            print("Overall accuracy: {}".format(correct/total))
            print("  Execution time/per picture: {:.4f}ms".format(execution_time))
            print("      Throughput: {:.4f}FPS".format(total/execution_time))

            with open("model_result_vgg11.csv","a+") as csvfile: 
                writer = csv.writer(csvfile)
                writer.writerows([[model_num,shape_x,shape_y,step,execution_time,total/execution_time],])
                model_num += 1


            #clean up 
            del overlay
            del dpu
# Out:
# Total number of test images: 100
#   Dimension of each picture: 32x32
# Classifying 100 digit pictures ...
# Overall accuracy: 0.14
#   Execution time/per picture: 4.4230ms
#       Throughput: 22.6088FPS
# Total number of test images: 100
#   Dimension of each picture: 32x32
# Classifying 100 digit pictures ...
# Overall accuracy: 0.13
#   Execution time/per picture: 5.0948ms
#       Throughput: 19.6278FPS
# Total number of test images: 100
#   Dimension of each picture: 32x32
# Classifying 100 digit pictures ...
# Overall accuracy: 0.14
#   Execution time/per picture: 4.4321ms
#       Throughput: 22.5627FPS
# Total number of test images: 100
#   Dimension of each picture: 32x32
# Classifying 100 digit pictures ...
# Overall accuracy: 0.12
#   Execution time/per picture: 4.1366ms
#       Throughput: 24.1743FPS
# Total number of test images: 100
#   Dimension of each picture: 32x32
# Classifying 100 digit pictures ...
# Overall accuracy: 0.09
#   Execution time/per picture: 4.1514ms
#       Throughput: 24.0881FPS
# Total number of test images: 100
#   Dimension of each picture: 32x32
# Classifying 100 digit pictures ...
# Overall accuracy: 0.13
#   Execution time/per picture: 4.8956ms
#       Throughput: 20.4264FPS
# Total number of test images: 100
#   Dimension of each picture: 32x32
# Classifying 100 digit pictures ...
# Overall accuracy: 0.06
#   Execution time/per picture: 4.6570ms
#       Throughput: 21.4729FPS
# Total number of test images: 100
#   Dimension of each picture: 32x32
# Classifying 100 digit pictures ...
# Overall accuracy: 0.13
#   Execution time/per picture: 4.2651ms
#       Throughput: 23.4459FPS
# Total number of test images: 100
#   Dimension of each picture: 32x32
# Classifying 100 digit pictures ...
# Overall accuracy: 0.11
#   Execution time/per picture: 4.4211ms
#       Throughput: 22.6187FPS
# Total number of test images: 100
#   Dimension of each picture: 32x32
# Classifying 100 digit pictures ...
# Overall accuracy: 0.13
#   Execution time/per picture: 4.4115ms
#       Throughput: 22.6679FPS
# Total number of test images: 100
#   Dimension of each picture: 64x64
# Classifying 100 digit pictures ...
# Overall accuracy: 0.07
#   Execution time/per picture: 7.2573ms
#       Throughput: 13.7792FPS
# Total number of test images: 100
#   Dimension of each picture: 64x64
# Classifying 100 digit pictures ...
# Overall accuracy: 0.12
#   Execution time/per picture: 8.0697ms
#       Throughput: 12.3920FPS
# Total number of test images: 100
#   Dimension of each picture: 64x64
# Classifying 100 digit pictures ...
# Overall accuracy: 0.06
#   Execution time/per picture: 7.0371ms
#       Throughput: 14.2103FPS
# Total number of test images: 100
#   Dimension of each picture: 64x64
# Classifying 100 digit pictures ...
# Overall accuracy: 0.14
#   Execution time/per picture: 7.2374ms
#       Throughput: 13.8171FPS
# Total number of test images: 100
#   Dimension of each picture: 64x64
# Classifying 100 digit pictures ...
# Overall accuracy: 0.11
#   Execution time/per picture: 7.0397ms
#       Throughput: 14.2051FPS
# Total number of test images: 100
#   Dimension of each picture: 64x64
# Classifying 100 digit pictures ...
# Overall accuracy: 0.11
#   Execution time/per picture: 7.6056ms
#       Throughput: 13.1482FPS
# Total number of test images: 100
#   Dimension of each picture: 64x64
# Classifying 100 digit pictures ...
# Overall accuracy: 0.08
#   Execution time/per picture: 8.8929ms
#       Throughput: 11.2449FPS
# Total number of test images: 100
#   Dimension of each picture: 64x64
# Classifying 100 digit pictures ...
# Overall accuracy: 0.1
#   Execution time/per picture: 7.8505ms
#       Throughput: 12.7380FPS
# Total number of test images: 100
#   Dimension of each picture: 64x64
# Classifying 100 digit pictures ...
# Overall accuracy: 0.13
#   Execution time/per picture: 5.5503ms
#       Throughput: 18.0170FPS
# Total number of test images: 100
#   Dimension of each picture: 64x64
# Classifying 100 digit pictures ...
# Overall accuracy: 0.11
#   Execution time/per picture: 8.3008ms
#       Throughput: 12.0470FPS
# Total number of test images: 100
#   Dimension of each picture: 96x96
# Classifying 100 digit pictures ...
# Overall accuracy: 0.1
#   Execution time/per picture: 11.5860ms
#       Throughput: 8.6311FPS
# Total number of test images: 100
#   Dimension of each picture: 96x96
# Classifying 100 digit pictures ...
# Overall accuracy: 0.09
#   Execution time/per picture: 11.3054ms
#       Throughput: 8.8454FPS
# Total number of test images: 100
#   Dimension of each picture: 96x96
# Classifying 100 digit pictures ...
# Overall accuracy: 0.03
#   Execution time/per picture: 12.0387ms
#       Throughput: 8.3065FPS
# Total number of test images: 100
#   Dimension of each picture: 96x96
# Classifying 100 digit pictures ...
# Overall accuracy: 0.05
#   Execution time/per picture: 11.7945ms
#       Throughput: 8.4785FPS
# Total number of test images: 100
#   Dimension of each picture: 96x96
# Classifying 100 digit pictures ...
# Overall accuracy: 0.11
#   Execution time/per picture: 8.2689ms
#       Throughput: 12.0934FPS
# Total number of test images: 100
#   Dimension of each picture: 96x96
# Classifying 100 digit pictures ...
# Overall accuracy: 0.08
#   Execution time/per picture: 10.2760ms
#       Throughput: 9.7314FPS
# Total number of test images: 100
#   Dimension of each picture: 96x96
# Classifying 100 digit pictures ...
# Overall accuracy: 0.08
#   Execution time/per picture: 9.1751ms
#       Throughput: 10.8990FPS
# Total number of test images: 100
#   Dimension of each picture: 96x96
# Classifying 100 digit pictures ...
# Overall accuracy: 0.08
#   Execution time/per picture: 11.7655ms
#       Throughput: 8.4994FPS
# Total number of test images: 100
#   Dimension of each picture: 96x96
# Classifying 100 digit pictures ...
# Overall accuracy: 0.13
#   Execution time/per picture: 13.1434ms
#       Throughput: 7.6084FPS
# Total number of test images: 100
#   Dimension of each picture: 96x96
# Classifying 100 digit pictures ...
# Overall accuracy: 0.11
#   Execution time/per picture: 12.6611ms
#       Throughput: 7.8982FPS
# Total number of test images: 100
#   Dimension of each picture: 128x128
# Classifying 100 digit pictures ...
# Overall accuracy: 0.09
#   Execution time/per picture: 11.9336ms
#       Throughput: 8.3797FPS
# Total number of test images: 100
#   Dimension of each picture: 128x128
# Classifying 100 digit pictures ...
# Overall accuracy: 0.1
#   Execution time/per picture: 14.7021ms
#       Throughput: 6.8018FPS
# Total number of test images: 100
#   Dimension of each picture: 128x128
# Classifying 100 digit pictures ...
# Overall accuracy: 0.11
#   Execution time/per picture: 15.5091ms
#       Throughput: 6.4478FPS
# Total number of test images: 100
#   Dimension of each picture: 128x128
# Classifying 100 digit pictures ...
# Overall accuracy: 0.08
#   Execution time/per picture: 17.6966ms
#       Throughput: 5.6508FPS
# Total number of test images: 100
#   Dimension of each picture: 128x128
# Classifying 100 digit pictures ...
# Overall accuracy: 0.05
#   Execution time/per picture: 13.0517ms
#       Throughput: 7.6619FPS
# Total number of test images: 100
#   Dimension of each picture: 128x128
# Classifying 100 digit pictures ...
# Overall accuracy: 0.12
#   Execution time/per picture: 14.3186ms
#       Throughput: 6.9839FPS
# Total number of test images: 100
#   Dimension of each picture: 128x128
# Classifying 100 digit pictures ...
# Overall accuracy: 0.1
#   Execution time/per picture: 14.0160ms
#       Throughput: 7.1347FPS
# Total number of test images: 100
#   Dimension of each picture: 128x128
# Classifying 100 digit pictures ...
# Overall accuracy: 0.11
#   Execution time/per picture: 15.2208ms
#       Throughput: 6.5700FPS
# Total number of test images: 100
#   Dimension of each picture: 128x128
# Classifying 100 digit pictures ...
# Overall accuracy: 0.04
#   Execution time/per picture: 15.5694ms
#       Throughput: 6.4228FPS
# Total number of test images: 100
#   Dimension of each picture: 128x128
# Classifying 100 digit pictures ...
# Overall accuracy: 0.11
#   Execution time/per picture: 11.1839ms
#       Throughput: 8.9414FPS
# Total number of test images: 100
#   Dimension of each picture: 160x160
# Classifying 100 digit pictures ...
# Overall accuracy: 0.07
#   Execution time/per picture: 24.2502ms
#       Throughput: 4.1237FPS
# Total number of test images: 100
#   Dimension of each picture: 160x160
# Classifying 100 digit pictures ...
# Overall accuracy: 0.06
#   Execution time/per picture: 23.8273ms
#       Throughput: 4.1969FPS
# Total number of test images: 100
#   Dimension of each picture: 160x160
# Classifying 100 digit pictures ...
# Overall accuracy: 0.11
#   Execution time/per picture: 17.8590ms
#       Throughput: 5.5994FPS
# Total number of test images: 100
#   Dimension of each picture: 160x160
# Classifying 100 digit pictures ...
# Overall accuracy: 0.12
#   Execution time/per picture: 27.0156ms
#       Throughput: 3.7016FPS
# Total number of test images: 100
#   Dimension of each picture: 160x160
# Classifying 100 digit pictures ...
# Overall accuracy: 0.11
#   Execution time/per picture: 17.0321ms
#       Throughput: 5.8713FPS
# Total number of test images: 100
#   Dimension of each picture: 160x160
# Classifying 100 digit pictures ...
# Overall accuracy: 0.11
#   Execution time/per picture: 14.4367ms
#       Throughput: 6.9268FPS
# Total number of test images: 100
#   Dimension of each picture: 160x160
# Classifying 100 digit pictures ...
# Overall accuracy: 0.08
#   Execution time/per picture: 25.1749ms
#       Throughput: 3.9722FPS
# Total number of test images: 100
#   Dimension of each picture: 160x160
# Classifying 100 digit pictures ...
# Overall accuracy: 0.13
#   Execution time/per picture: 24.9872ms
#       Throughput: 4.0020FPS
# Total number of test images: 100
#   Dimension of each picture: 160x160
# Classifying 100 digit pictures ...
# Overall accuracy: 0.19
#   Execution time/per picture: 20.6256ms
#       Throughput: 4.8484FPS
# Total number of test images: 100
#   Dimension of each picture: 160x160
# Classifying 100 digit pictures ...
# Overall accuracy: 0.1
#   Execution time/per picture: 9.9348ms
#       Throughput: 10.0656FPS
# Total number of test images: 100
#   Dimension of each picture: 192x192
# Classifying 100 digit pictures ...
# Overall accuracy: 0.13
#   Execution time/per picture: 27.9257ms
#       Throughput: 3.5809FPS
# Total number of test images: 100
#   Dimension of each picture: 192x192
# Classifying 100 digit pictures ...
# Overall accuracy: 0.1
#   Execution time/per picture: 32.2812ms
#       Throughput: 3.0978FPS
# Total number of test images: 100
#   Dimension of each picture: 192x192
# Classifying 100 digit pictures ...
# Overall accuracy: 0.05
#   Execution time/per picture: 30.1412ms
#       Throughput: 3.3177FPS
# Total number of test images: 100
#   Dimension of each picture: 192x192
# Classifying 100 digit pictures ...
# Overall accuracy: 0.1
#   Execution time/per picture: 30.5320ms
#       Throughput: 3.2753FPS
# Total number of test images: 100
#   Dimension of each picture: 192x192
# Classifying 100 digit pictures ...
# Overall accuracy: 0.17
#   Execution time/per picture: 28.1569ms
#       Throughput: 3.5515FPS
# Total number of test images: 100
#   Dimension of each picture: 192x192
# Classifying 100 digit pictures ...
# Overall accuracy: 0.14
#   Execution time/per picture: 27.1127ms
#       Throughput: 3.6883FPS
# Total number of test images: 100
#   Dimension of each picture: 192x192
# Classifying 100 digit pictures ...
# Overall accuracy: 0.12
#   Execution time/per picture: 28.4375ms
#       Throughput: 3.5165FPS
# Total number of test images: 100
#   Dimension of each picture: 192x192
# Classifying 100 digit pictures ...
# Overall accuracy: 0.09
#   Execution time/per picture: 20.5480ms
#       Throughput: 4.8666FPS
# Total number of test images: 100
#   Dimension of each picture: 192x192
# Classifying 100 digit pictures ...
# Overall accuracy: 0.06
#   Execution time/per picture: 26.7124ms
#       Throughput: 3.7436FPS
# Total number of test images: 100
#   Dimension of each picture: 192x192
# Classifying 100 digit pictures ...
# Overall accuracy: 0.08
#   Execution time/per picture: 27.8661ms
#       Throughput: 3.5886FPS
# Total number of test images: 100
#   Dimension of each picture: 224x224
# Classifying 100 digit pictures ...
# Overall accuracy: 0.1
#   Execution time/per picture: 24.7654ms
#       Throughput: 4.0379FPS
# Total number of test images: 100
#   Dimension of each picture: 224x224
# Classifying 100 digit pictures ...
# Overall accuracy: 0.1
#   Execution time/per picture: 43.1508ms
#       Throughput: 2.3175FPS
# Total number of test images: 100
#   Dimension of each picture: 224x224
# Classifying 100 digit pictures ...
# Overall accuracy: 0.08
#   Execution time/per picture: 31.6193ms
#       Throughput: 3.1626FPS
# Total number of test images: 100
#   Dimension of each picture: 224x224
# Classifying 100 digit pictures ...
# Overall accuracy: 0.15
#   Execution time/per picture: 29.4664ms
#       Throughput: 3.3937FPS
# Total number of test images: 100
#   Dimension of each picture: 224x224
# Classifying 100 digit pictures ...
# Overall accuracy: 0.15
#   Execution time/per picture: 37.1485ms
#       Throughput: 2.6919FPS
# Total number of test images: 100
#   Dimension of each picture: 224x224
# Classifying 100 digit pictures ...
# Overall accuracy: 0.12
#   Execution time/per picture: 41.4923ms
#       Throughput: 2.4101FPS
# Total number of test images: 100
#   Dimension of each picture: 224x224
# Classifying 100 digit pictures ...
# Overall accuracy: 0.07
#   Execution time/per picture: 29.0879ms
#       Throughput: 3.4379FPS
# Total number of test images: 100
#   Dimension of each picture: 224x224
# Classifying 100 digit pictures ...
# Overall accuracy: 0.11
#   Execution time/per picture: 30.7051ms
#       Throughput: 3.2568FPS
# Total number of test images: 100
#   Dimension of each picture: 224x224
# Classifying 100 digit pictures ...
# Overall accuracy: 0.11
#   Execution time/per picture: 39.0349ms
#       Throughput: 2.5618FPS
# Total number of test images: 100
#   Dimension of each picture: 224x224
# Classifying 100 digit pictures ...
# Overall accuracy: 0.09
#   Execution time/per picture: 31.7203ms
#       Throughput: 3.1526FPS
# Total number of test images: 100
#   Dimension of each picture: 256x256
# Classifying 100 digit pictures ...
# Overall accuracy: 0.11
#   Execution time/per picture: 38.1315ms
#       Throughput: 2.6225FPS
# Total number of test images: 100
#   Dimension of each picture: 256x256
# Classifying 100 digit pictures ...
# Overall accuracy: 0.08
#   Execution time/per picture: 39.6856ms
#       Throughput: 2.5198FPS
# Total number of test images: 100
#   Dimension of each picture: 256x256
# Classifying 100 digit pictures ...
# Overall accuracy: 0.09
#   Execution time/per picture: 36.7428ms
#       Throughput: 2.7216FPS
# Total number of test images: 100
#   Dimension of each picture: 256x256
# Classifying 100 digit pictures ...
# Overall accuracy: 0.05
#   Execution time/per picture: 33.5758ms
#       Throughput: 2.9783FPS
# Total number of test images: 100
#   Dimension of each picture: 256x256
# Classifying 100 digit pictures ...
# Overall accuracy: 0.15
#   Execution time/per picture: 50.8932ms
#       Throughput: 1.9649FPS
# Total number of test images: 100
#   Dimension of each picture: 256x256
# Classifying 100 digit pictures ...
# Overall accuracy: 0.09
#   Execution time/per picture: 44.8150ms
#       Throughput: 2.2314FPS
# Total number of test images: 100
#   Dimension of each picture: 256x256
# Classifying 100 digit pictures ...
# Overall accuracy: 0.1
#   Execution time/per picture: 43.8634ms
#       Throughput: 2.2798FPS
# Total number of test images: 100
#   Dimension of each picture: 256x256
# Classifying 100 digit pictures ...
# Overall accuracy: 0.08
#   Execution time/per picture: 45.3331ms
#       Throughput: 2.2059FPS
# Total number of test images: 100
#   Dimension of each picture: 256x256
# Classifying 100 digit pictures ...
# Overall accuracy: 0.14
#   Execution time/per picture: 48.8020ms
#       Throughput: 2.0491FPS
# Total number of test images: 100
#   Dimension of each picture: 256x256
# Classifying 100 digit pictures ...
# Overall accuracy: 0.13
#   Execution time/per picture: 46.9541ms
#       Throughput: 2.1297FPS
# Total number of test images: 100
#   Dimension of each picture: 288x288
# Classifying 100 digit pictures ...
# Overall accuracy: 0.06
#   Execution time/per picture: 32.1579ms
#       Throughput: 3.1097FPS
# Total number of test images: 100
#   Dimension of each picture: 288x288
# Classifying 100 digit pictures ...
# Overall accuracy: 0.1
#   Execution time/per picture: 41.5891ms
#       Throughput: 2.4045FPS
# Total number of test images: 100
#   Dimension of each picture: 288x288
# Classifying 100 digit pictures ...
# Overall accuracy: 0.08
#   Execution time/per picture: 57.4408ms
#       Throughput: 1.7409FPS
# Total number of test images: 100
#   Dimension of each picture: 288x288
# Classifying 100 digit pictures ...
# Overall accuracy: 0.12
#   Execution time/per picture: 56.1975ms
#       Throughput: 1.7794FPS
# Total number of test images: 100
#   Dimension of each picture: 288x288
# Classifying 100 digit pictures ...
# Overall accuracy: 0.09
#   Execution time/per picture: 34.7041ms
#       Throughput: 2.8815FPS
# Total number of test images: 100
#   Dimension of each picture: 288x288
# Classifying 100 digit pictures ...
# Overall accuracy: 0.12
#   Execution time/per picture: 63.0182ms
#       Throughput: 1.5868FPS
# Total number of test images: 100
#   Dimension of each picture: 288x288
# Classifying 100 digit pictures ...
# Overall accuracy: 0.07
#   Execution time/per picture: 53.6478ms
#       Throughput: 1.8640FPS
# Total number of test images: 100
#   Dimension of each picture: 288x288
# Classifying 100 digit pictures ...
# Overall accuracy: 0.08
#   Execution time/per picture: 56.4489ms
#       Throughput: 1.7715FPS
# Total number of test images: 100
#   Dimension of each picture: 288x288
# Classifying 100 digit pictures ...
# Overall accuracy: 0.17
#   Execution time/per picture: 67.4310ms
#       Throughput: 1.4830FPS
# Total number of test images: 100
#   Dimension of each picture: 288x288
# Classifying 100 digit pictures ...
# Overall accuracy: 0.07
#   Execution time/per picture: 61.2181ms
#       Throughput: 1.6335FPS
# Total number of test images: 100
#   Dimension of each picture: 320x320
# Classifying 100 digit pictures ...
# Overall accuracy: 0.12
#   Execution time/per picture: 80.9221ms
#       Throughput: 1.2358FPS
# Total number of test images: 100
#   Dimension of each picture: 320x320
# Classifying 100 digit pictures ...
# Overall accuracy: 0.07
#   Execution time/per picture: 54.9821ms
#       Throughput: 1.8188FPS
# Total number of test images: 100
#   Dimension of each picture: 320x320
# Classifying 100 digit pictures ...
# Overall accuracy: 0.1
#   Execution time/per picture: 57.9868ms
#       Throughput: 1.7245FPS
# Total number of test images: 100
#   Dimension of each picture: 320x320
# Classifying 100 digit pictures ...
# Overall accuracy: 0.06
#   Execution time/per picture: 73.2227ms
#       Throughput: 1.3657FPS
# Total number of test images: 100
#   Dimension of each picture: 320x320
# Classifying 100 digit pictures ...
# Overall accuracy: 0.08
#   Execution time/per picture: 68.7128ms
#       Throughput: 1.4553FPS
# Total number of test images: 100
#   Dimension of each picture: 320x320
# Classifying 100 digit pictures ...
# Overall accuracy: 0.14
#   Execution time/per picture: 72.0659ms
#       Throughput: 1.3876FPS
# Total number of test images: 100
#   Dimension of each picture: 320x320
# Classifying 100 digit pictures ...
# Overall accuracy: 0.1
#   Execution time/per picture: 70.8874ms
#       Throughput: 1.4107FPS
# Total number of test images: 100
#   Dimension of each picture: 320x320
# Classifying 100 digit pictures ...
# Overall accuracy: 0.08
#   Execution time/per picture: 69.3189ms
#       Throughput: 1.4426FPS
# Total number of test images: 100
#   Dimension of each picture: 320x320
# Classifying 100 digit pictures ...
# Overall accuracy: 0.05
#   Execution time/per picture: 54.9171ms
#       Throughput: 1.8209FPS
# Total number of test images: 100
#   Dimension of each picture: 320x320
# Classifying 100 digit pictures ...
# Overall accuracy: 0.1
#   Execution time/per picture: 83.0323ms
#       Throughput: 1.2044FPS
